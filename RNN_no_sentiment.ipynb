# %% [markdown]
# <a href="https://colab.research.google.com/github/hj2222222/API/blob/main/RNN_no_sentiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import os
import math
import matplotlib.pyplot as plt
import keras
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras import optimizers
from tensorflow.keras.layers import LSTM, Dropout, Dense, Conv1D, MaxPooling1D, Flatten
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Bidirectional
from keras.layers import Dropout,TimeDistributed, Flatten
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from tensorflow.keras.losses import Huber
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


stock_data = pd.read_csv('/content/drive/MyDrive/산업 AI 캡스톤/DATA/Total_Data/Final_Feature_kospi_sen_all.csv')
stock_data
# Out:
#          Date  Kospi_close  Kospi_high  ko_interest  oil_open  ex_JP_low  \
# 0    20210105      2990.57       0.795          0.0     0.213      0.590
# 1    20210106      2968.21       0.819          0.0     0.219      0.596
# 2    20210107      3031.68       0.839          0.0     0.225      0.597
# 3    20210108      3152.18       0.855          0.0     0.230      0.584
# 4    20210111      3148.45       0.914          0.0     0.232      0.584
# ..        ...          ...         ...          ...       ...        ...
# 583  20230623      2570.10       0.601          1.0     0.651      0.028
# 584  20230626      2582.20       0.602          1.0     0.651      0.024
# 585  20230627      2581.39       0.594          1.0     0.651      0.000
# 586  20230628      2564.19       0.592          1.0     0.651      0.011
# 587  20230629      2550.02       0.597          1.0     0.651      0.020
#
#      gold_low  us500_low  klue_bert_score_summarize_content  oil_vol  \
# 0       0.661      0.581                             -0.536    0.013
# 1       0.650      0.585                              1.381    0.006
# 2       0.670      0.608                              1.845    0.007
# 3       0.631      0.615                              2.497    0.004
# 4       0.623      0.617                             -0.951    0.009
# ..        ...        ...                                ...      ...
# 583     0.212      0.830                              0.402    0.000
# 584     0.212      0.825                             -0.385    0.000
# 585     0.208      0.828                             -0.447    0.000
# 586     0.217      0.838                              0.777    0.000
# 587     0.208      0.842                             -0.038    0.000
#
#      research_kospi  dji_vol  us500_vol  \
# 0             0.413    0.280      0.349
# 1             0.628    0.470      0.527
# 2             0.427    0.378      0.410
# 3             0.512    0.318      0.371
# 4             0.881    0.287      0.334
# ..              ...      ...        ...
# 583           0.125    0.316      0.526
# 584           0.120    0.170      0.207
# 585           0.118    0.206      0.226
# 586           0.128    0.174      0.246
# 587           0.127    0.189      0.241
#
#      kofinbert_score_summarize_content_kospi  kofinbert_score_title_kospi  \
# 0                                      0.157                        0.195
# 1                                      1.236                        0.569
# 2                                      0.537                        1.395
# 3                                      0.697                       -1.382
# 4                                      0.331                       -0.044
# ..                                       ...                          ...
# 583                                    0.834                       -0.339
# 584                                   -0.196                        0.681
# 585                                   -0.208                        0.625
# 586                                    1.099                        0.892
# 587                                    0.382                       -0.145
#
#      klue_bert_score_title
# 0                    0.823
# 1                    0.722
# 2                   -0.675
# 3                    1.124
# 4                    0.730
# ..                     ...
# 583                  0.831
# 584                 -0.001
# 585                 -0.097
# 586                  0.253
# 587                 -0.378
#
# [588 rows x 16 columns]

# %%
def accuracy(list1,list2):
  list1 = list1.flatten().tolist()
  list2 = list2.flatten().tolist()
  value_1 = []
  value_2 = []
  j = 0
  if len(list1) == len(list2):
    for i in range(len(list1)-1):
      if list1[i+1] > list1[i]:
        value_1.append(1)
      elif list1[i+1] == list1[i]:
        value_1.append(0)
      else:
        value_1.append(-1)
    for i in range(len(list1)-1):
      if list2[i+1] > list2[i]:
        value_2.append(1)
      elif list2[i+1] == list2[i]:
        value_2.append(0)
      else:
        value_2.append(-1)
    for i in range(len(value_1)):
      if value_1[i] == value_2[i]:
        j = j + 1
    accuracy = j/len(value_1) * 100
    print("accuracy : %d" % accuracy)
  else:
    print("길이가 다릅니다.")

# %%
def calculate_mape(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
# 데이터 전처리
data = stock_data['Kospi_close'].values.reshape(-1, 1)
stock_data = stock_data.drop(['Kospi_close'],axis=1)
stock_data = stock_data.drop(['Date'],axis=1)

# %%
name = [stock_data.columns]

close = ['kofinbert_score_summarize_content_kospi',
        'kofinbert_score_title_kospi', 'klue_bert_score_summarize_content',
        'klue_bert_score_title']

stock_data = stock_data.drop(close, axis=1)

# %%
# 데이터 분할
train_size = int(len(data) * 0.85)
train_data, test_data = data[:train_size], data[train_size:]
train_data_t, test_data_t = stock_data[:train_size], stock_data[train_size:]

def create_dataset(dataset, data, look_back=10):
    X, y = [], []
    for i in range(len(data) - look_back):
        X.append(dataset[i:(i + look_back)])
        y.append(data[i + look_back])
    return np.array(X), np.array(y)

look_back = 5  # 몇 일 동안의 데이터를 사용할 것인지 설정

trainX, trainY = create_dataset(train_data_t, train_data, look_back)
testX, testY = create_dataset(test_data_t,test_data, look_back)
print(trainX.shape)
print(trainY.shape)
print(testX.shape)
print(testY.shape)
# Out:
# (494, 5, 10)
# (494, 1)
# (84, 5, 10)
# (84, 1)

# %%
earlystopping = EarlyStopping(monitor='val_loss', patience=50)

# %%
# 모델 생성
model = Sequential()
model.add(GRU(units=1024, activation='relu', return_sequences=True, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dropout(0.3))
model.add(GRU(units=512, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=256, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=128, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=64, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=32, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(units=1))
model.summary()

# loss = Huber()
# optimizer = Adam(0.0005)
# model.compile(loss=Huber(), optimizer=optimizer, metrics=['mse'])
model.compile(optimizer='adam', loss='mean_squared_error')

filename = os.path.join('tmp', 'ckeckpointer.ckpt')
checkpoint = ModelCheckpoint(filename,
                             save_weights_only=True,
                             save_best_only=True,
                             monitor='val_loss',
                             verbose=1)

# 모델 학습
history = model.fit(trainX, trainY, epochs=1000, batch_size=64,
          validation_split=0.1, verbose=2,callbacks=[checkpoint])

model.save_weights('./lstm_weights.h1')

model.load_weights(filename)

plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()
plt.show()

# 예측
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# MSE 계산
trainMSE = mean_squared_error(trainY, trainPredict)
testMSE = mean_squared_error(testY, testPredict)

# MAPE 계산
trainMAPE = calculate_mape(trainY, trainPredict)
testMAPE = calculate_mape(testY, testPredict)

print(f'Training MSE: {trainMSE:.3f}')
print(f'Testing MSE: {testMSE:.3f}')
print(f'Training MAPE: {trainMAPE:.3f}%')
print(f'Testing MAPE: {testMAPE:.3f}%')

accuracy(testPredict,testY)

# 예측 시각화
plt.plot(trainY, label='Actual Price')
plt.plot(trainPredict, label='Predicted Price')
plt.legend()
plt.title('Training Data')
plt.show()

plt.plot(testY, label='Actual Price')
plt.plot(testPredict, label='Predicted Price')
plt.legend()
plt.title('Testing Data')
plt.show()
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 5, 1024)           3182592
#
#  dropout (Dropout)           (None, 5, 1024)           0
#
#  gru_1 (GRU)                 (None, 5, 512)            2362368
#
#  dropout_1 (Dropout)         (None, 5, 512)            0
#
#  gru_2 (GRU)                 (None, 5, 256)            591360
#
#  dropout_2 (Dropout)         (None, 5, 256)            0
#
#  gru_3 (GRU)                 (None, 5, 128)            148224
#
#  dropout_3 (Dropout)         (None, 5, 128)            0
#
#  gru_4 (GRU)                 (None, 5, 64)             37248
#
#  dropout_4 (Dropout)         (None, 5, 64)             0
#
#  gru_5 (GRU)                 (None, 32)                9408
#
#  dropout_5 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 6331233 (24.15 MB)
# Trainable params: 6331233 (24.15 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/1000
#
# Epoch 1: val_loss improved from inf to 5704745.00000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 19s - loss: 8167213.5000 - val_loss: 5704745.0000 - 19s/epoch - 3s/step
# Epoch 2/1000
#
# Epoch 2: val_loss improved from 5704745.00000 to 2898711.75000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 7704712.0000 - val_loss: 2898711.7500 - 816ms/epoch - 117ms/step
# Epoch 3/1000
#
# Epoch 3: val_loss improved from 2898711.75000 to 496771.43750, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 2489912.5000 - val_loss: 496771.4375 - 769ms/epoch - 110ms/step
# Epoch 4/1000
#
# Epoch 4: val_loss improved from 496771.43750 to 338579.59375, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 1606103.8750 - val_loss: 338579.5938 - 808ms/epoch - 115ms/step
# Epoch 5/1000
#
# Epoch 5: val_loss did not improve from 338579.59375
# 7/7 - 1s - loss: 1290873.3750 - val_loss: 616913.7500 - 525ms/epoch - 75ms/step
# Epoch 6/1000
#
# Epoch 6: val_loss did not improve from 338579.59375
# 7/7 - 1s - loss: 1210168.5000 - val_loss: 589353.6250 - 621ms/epoch - 89ms/step
# Epoch 7/1000
#
# Epoch 7: val_loss improved from 338579.59375 to 158245.32812, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 1076310.8750 - val_loss: 158245.3281 - 762ms/epoch - 109ms/step
# Epoch 8/1000
#
# Epoch 8: val_loss did not improve from 158245.32812
# 7/7 - 1s - loss: 989997.0000 - val_loss: 521977.5938 - 532ms/epoch - 76ms/step
# Epoch 9/1000
#
# Epoch 9: val_loss did not improve from 158245.32812
# 7/7 - 1s - loss: 906881.4375 - val_loss: 303871.0938 - 547ms/epoch - 78ms/step
# Epoch 10/1000
#
# Epoch 10: val_loss did not improve from 158245.32812
# 7/7 - 0s - loss: 791371.9375 - val_loss: 209319.3125 - 499ms/epoch - 71ms/step
# Epoch 11/1000
#
# Epoch 11: val_loss did not improve from 158245.32812
# 7/7 - 1s - loss: 839620.6875 - val_loss: 288091.5938 - 520ms/epoch - 74ms/step
# Epoch 12/1000
#
# Epoch 12: val_loss did not improve from 158245.32812
# 7/7 - 1s - loss: 757672.1875 - val_loss: 529601.0625 - 556ms/epoch - 79ms/step
# Epoch 13/1000
#
# Epoch 13: val_loss did not improve from 158245.32812
# 7/7 - 1s - loss: 814751.5625 - val_loss: 173160.4531 - 520ms/epoch - 74ms/step
# Epoch 14/1000
#
# Epoch 14: val_loss did not improve from 158245.32812
# 7/7 - 1s - loss: 726581.1875 - val_loss: 305795.5625 - 513ms/epoch - 73ms/step
# Epoch 15/1000
#
# Epoch 15: val_loss improved from 158245.32812 to 17763.02734, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 783370.6875 - val_loss: 17763.0273 - 790ms/epoch - 113ms/step
# Epoch 16/1000
#
# Epoch 16: val_loss did not improve from 17763.02734
# 7/7 - 1s - loss: 686020.8125 - val_loss: 101174.5469 - 545ms/epoch - 78ms/step
# Epoch 17/1000
#
# Epoch 17: val_loss improved from 17763.02734 to 12373.61914, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 583314.3125 - val_loss: 12373.6191 - 705ms/epoch - 101ms/step
# Epoch 18/1000
#
# Epoch 18: val_loss did not improve from 12373.61914
# 7/7 - 1s - loss: 642560.0000 - val_loss: 15974.9404 - 914ms/epoch - 131ms/step
# Epoch 19/1000
#
# Epoch 19: val_loss did not improve from 12373.61914
# 7/7 - 1s - loss: 620970.3750 - val_loss: 28999.9258 - 1s/epoch - 158ms/step
# Epoch 20/1000
#
# Epoch 20: val_loss did not improve from 12373.61914
# 7/7 - 1s - loss: 690031.6875 - val_loss: 33604.0664 - 1s/epoch - 150ms/step
# Epoch 21/1000
#
# Epoch 21: val_loss did not improve from 12373.61914
# 7/7 - 1s - loss: 738394.8125 - val_loss: 51835.5469 - 1s/epoch - 154ms/step
# Epoch 22/1000
#
# Epoch 22: val_loss did not improve from 12373.61914
# 7/7 - 1s - loss: 568310.8750 - val_loss: 53446.5391 - 1s/epoch - 170ms/step
# Epoch 23/1000
#
# Epoch 23: val_loss did not improve from 12373.61914
# 7/7 - 1s - loss: 557620.3125 - val_loss: 75658.2734 - 802ms/epoch - 115ms/step
# Epoch 24/1000
#
# Epoch 24: val_loss improved from 12373.61914 to 4275.82764, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 558789.5000 - val_loss: 4275.8276 - 849ms/epoch - 121ms/step
# Epoch 25/1000
#
# Epoch 25: val_loss improved from 4275.82764 to 4155.66260, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 544081.4375 - val_loss: 4155.6626 - 724ms/epoch - 103ms/step
# Epoch 26/1000
#
# Epoch 26: val_loss did not improve from 4155.66260
# 7/7 - 1s - loss: 542525.1250 - val_loss: 118617.2969 - 511ms/epoch - 73ms/step
# Epoch 27/1000
#
# Epoch 27: val_loss did not improve from 4155.66260
# 7/7 - 1s - loss: 467769.4375 - val_loss: 15608.1162 - 528ms/epoch - 75ms/step
# Epoch 28/1000
#
# Epoch 28: val_loss did not improve from 4155.66260
# 7/7 - 1s - loss: 511945.6562 - val_loss: 54015.4648 - 536ms/epoch - 77ms/step
# Epoch 29/1000
#
# Epoch 29: val_loss did not improve from 4155.66260
# 7/7 - 1s - loss: 535178.2500 - val_loss: 37483.9766 - 542ms/epoch - 77ms/step
# Epoch 30/1000
#
# Epoch 30: val_loss improved from 4155.66260 to 3958.64282, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 572651.1250 - val_loss: 3958.6428 - 743ms/epoch - 106ms/step
# Epoch 31/1000
#
# Epoch 31: val_loss did not improve from 3958.64282
# 7/7 - 1s - loss: 533177.1875 - val_loss: 41685.2891 - 555ms/epoch - 79ms/step
# Epoch 32/1000
#
# Epoch 32: val_loss improved from 3958.64282 to 3583.76807, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 469827.9062 - val_loss: 3583.7681 - 780ms/epoch - 111ms/step
# Epoch 33/1000
#
# Epoch 33: val_loss did not improve from 3583.76807
# 7/7 - 1s - loss: 425797.5625 - val_loss: 15294.6797 - 561ms/epoch - 80ms/step
# Epoch 34/1000
#
# Epoch 34: val_loss improved from 3583.76807 to 3341.15991, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 506531.7500 - val_loss: 3341.1599 - 725ms/epoch - 104ms/step
# Epoch 35/1000
#
# Epoch 35: val_loss did not improve from 3341.15991
# 7/7 - 1s - loss: 465007.2812 - val_loss: 16313.0703 - 533ms/epoch - 76ms/step
# Epoch 36/1000
#
# Epoch 36: val_loss did not improve from 3341.15991
# 7/7 - 1s - loss: 453552.9062 - val_loss: 30577.9453 - 517ms/epoch - 74ms/step
# Epoch 37/1000
#
# Epoch 37: val_loss did not improve from 3341.15991
# 7/7 - 1s - loss: 456342.6250 - val_loss: 6650.2300 - 559ms/epoch - 80ms/step
# Epoch 38/1000
#
# Epoch 38: val_loss did not improve from 3341.15991
# 7/7 - 1s - loss: 426964.8750 - val_loss: 5085.8105 - 533ms/epoch - 76ms/step
# Epoch 39/1000
#
# Epoch 39: val_loss did not improve from 3341.15991
# 7/7 - 1s - loss: 424779.9062 - val_loss: 13404.8301 - 577ms/epoch - 82ms/step
# Epoch 40/1000
#
# Epoch 40: val_loss did not improve from 3341.15991
# 7/7 - 1s - loss: 381054.0938 - val_loss: 64616.3906 - 1s/epoch - 156ms/step
# Epoch 41/1000
#
# Epoch 41: val_loss did not improve from 3341.15991
# 7/7 - 1s - loss: 393745.6875 - val_loss: 4032.3218 - 1s/epoch - 147ms/step
# Epoch 42/1000
#
# Epoch 42: val_loss did not improve from 3341.15991
# 7/7 - 1s - loss: 393192.0000 - val_loss: 23911.7598 - 1s/epoch - 160ms/step
# Epoch 43/1000
#
# Epoch 43: val_loss did not improve from 3341.15991
# 7/7 - 1s - loss: 413053.7812 - val_loss: 23051.5723 - 1s/epoch - 147ms/step
# Epoch 44/1000
#
# Epoch 44: val_loss did not improve from 3341.15991
# 7/7 - 1s - loss: 403512.1562 - val_loss: 11726.0186 - 1s/epoch - 159ms/step
# Epoch 45/1000
#
# Epoch 45: val_loss did not improve from 3341.15991
# 7/7 - 1s - loss: 373267.0312 - val_loss: 5582.6758 - 669ms/epoch - 96ms/step
# Epoch 46/1000
#
# Epoch 46: val_loss did not improve from 3341.15991
# 7/7 - 1s - loss: 348571.7812 - val_loss: 4710.7480 - 526ms/epoch - 75ms/step
# Epoch 47/1000
#
# Epoch 47: val_loss did not improve from 3341.15991
# 7/7 - 1s - loss: 367227.6875 - val_loss: 5127.0513 - 561ms/epoch - 80ms/step
# Epoch 48/1000
#
# Epoch 48: val_loss did not improve from 3341.15991
# 7/7 - 1s - loss: 372227.3438 - val_loss: 101418.9609 - 514ms/epoch - 73ms/step
# Epoch 49/1000
#
# Epoch 49: val_loss did not improve from 3341.15991
# 7/7 - 1s - loss: 389742.0312 - val_loss: 3912.8296 - 547ms/epoch - 78ms/step
# Epoch 50/1000
#
# Epoch 50: val_loss improved from 3341.15991 to 2514.80933, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 359959.0000 - val_loss: 2514.8093 - 726ms/epoch - 104ms/step
# Epoch 51/1000
#
# Epoch 51: val_loss did not improve from 2514.80933
# 7/7 - 1s - loss: 376302.2812 - val_loss: 59298.5195 - 575ms/epoch - 82ms/step
# Epoch 52/1000
#
# Epoch 52: val_loss improved from 2514.80933 to 2326.24707, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 401369.5625 - val_loss: 2326.2471 - 717ms/epoch - 102ms/step
# Epoch 53/1000
#
# Epoch 53: val_loss did not improve from 2326.24707
# 7/7 - 1s - loss: 397763.5000 - val_loss: 17293.7168 - 516ms/epoch - 74ms/step
# Epoch 54/1000
#
# Epoch 54: val_loss did not improve from 2326.24707
# 7/7 - 1s - loss: 405214.4062 - val_loss: 132841.0625 - 516ms/epoch - 74ms/step
# Epoch 55/1000
#
# Epoch 55: val_loss did not improve from 2326.24707
# 7/7 - 1s - loss: 370220.2500 - val_loss: 118512.9219 - 541ms/epoch - 77ms/step
# Epoch 56/1000
#
# Epoch 56: val_loss did not improve from 2326.24707
# 7/7 - 1s - loss: 402386.8438 - val_loss: 20863.8359 - 528ms/epoch - 75ms/step
# Epoch 57/1000
#
# Epoch 57: val_loss did not improve from 2326.24707
# 7/7 - 1s - loss: 392309.3750 - val_loss: 2514.8794 - 532ms/epoch - 76ms/step
# Epoch 58/1000
#
# Epoch 58: val_loss did not improve from 2326.24707
# 7/7 - 1s - loss: 379705.4062 - val_loss: 53101.2617 - 544ms/epoch - 78ms/step
# Epoch 59/1000
#
# Epoch 59: val_loss did not improve from 2326.24707
# 7/7 - 1s - loss: 340774.5312 - val_loss: 50567.2969 - 546ms/epoch - 78ms/step
# Epoch 60/1000
#
# Epoch 60: val_loss did not improve from 2326.24707
# 7/7 - 1s - loss: 345773.9062 - val_loss: 48697.1602 - 573ms/epoch - 82ms/step
# Epoch 61/1000
#
# Epoch 61: val_loss did not improve from 2326.24707
# 7/7 - 1s - loss: 352615.0000 - val_loss: 39277.0508 - 542ms/epoch - 77ms/step
# Epoch 62/1000
#
# Epoch 62: val_loss did not improve from 2326.24707
# 7/7 - 1s - loss: 336235.6250 - val_loss: 33888.5781 - 508ms/epoch - 73ms/step
# Epoch 63/1000
#
# Epoch 63: val_loss did not improve from 2326.24707
# 7/7 - 1s - loss: 345840.5625 - val_loss: 40669.1758 - 921ms/epoch - 132ms/step
# Epoch 64/1000
#
# Epoch 64: val_loss did not improve from 2326.24707
# 7/7 - 1s - loss: 343571.3438 - val_loss: 4263.6060 - 1s/epoch - 146ms/step
# Epoch 65/1000
#
# Epoch 65: val_loss did not improve from 2326.24707
# 7/7 - 1s - loss: 357487.3438 - val_loss: 4827.8638 - 1s/epoch - 161ms/step
# Epoch 66/1000
#
# Epoch 66: val_loss did not improve from 2326.24707
# 7/7 - 1s - loss: 333370.3438 - val_loss: 17283.6719 - 1s/epoch - 151ms/step
# Epoch 67/1000
#
# Epoch 67: val_loss did not improve from 2326.24707
# 7/7 - 1s - loss: 319660.9375 - val_loss: 21159.0645 - 1s/epoch - 158ms/step
# Epoch 68/1000
#
# Epoch 68: val_loss did not improve from 2326.24707
# 7/7 - 1s - loss: 358276.2500 - val_loss: 26949.1602 - 852ms/epoch - 122ms/step
# Epoch 69/1000
#
# Epoch 69: val_loss did not improve from 2326.24707
# 7/7 - 1s - loss: 318083.0312 - val_loss: 7885.7251 - 556ms/epoch - 79ms/step
# Epoch 70/1000
#
# Epoch 70: val_loss did not improve from 2326.24707
# 7/7 - 1s - loss: 286067.0000 - val_loss: 5847.1636 - 542ms/epoch - 77ms/step
# Epoch 71/1000
#
# Epoch 71: val_loss did not improve from 2326.24707
# 7/7 - 1s - loss: 296010.2812 - val_loss: 46332.9297 - 595ms/epoch - 85ms/step
# Epoch 72/1000
#
# Epoch 72: val_loss did not improve from 2326.24707
# 7/7 - 1s - loss: 335987.2500 - val_loss: 74229.0000 - 536ms/epoch - 77ms/step
# Epoch 73/1000
#
# Epoch 73: val_loss did not improve from 2326.24707
# 7/7 - 1s - loss: 344542.6562 - val_loss: 22510.5332 - 534ms/epoch - 76ms/step
# Epoch 74/1000
#
# Epoch 74: val_loss did not improve from 2326.24707
# 7/7 - 1s - loss: 332851.5625 - val_loss: 31555.0801 - 544ms/epoch - 78ms/step
# Epoch 75/1000
#
# Epoch 75: val_loss did not improve from 2326.24707
# 7/7 - 1s - loss: 322603.1562 - val_loss: 20775.4258 - 513ms/epoch - 73ms/step
# Epoch 76/1000
#
# Epoch 76: val_loss did not improve from 2326.24707
# 7/7 - 1s - loss: 276832.0625 - val_loss: 31033.1719 - 560ms/epoch - 80ms/step
# Epoch 77/1000
#
# Epoch 77: val_loss did not improve from 2326.24707
# 7/7 - 1s - loss: 292742.8438 - val_loss: 80583.5547 - 520ms/epoch - 74ms/step
# Epoch 78/1000
#
# Epoch 78: val_loss did not improve from 2326.24707
# 7/7 - 1s - loss: 268140.5938 - val_loss: 38143.6055 - 505ms/epoch - 72ms/step
# Epoch 79/1000
#
# Epoch 79: val_loss did not improve from 2326.24707
# 7/7 - 1s - loss: 275750.8438 - val_loss: 35094.0391 - 553ms/epoch - 79ms/step
# Epoch 80/1000
#
# Epoch 80: val_loss did not improve from 2326.24707
# 7/7 - 1s - loss: 305794.5938 - val_loss: 14778.7070 - 539ms/epoch - 77ms/step
# Epoch 81/1000
#
# Epoch 81: val_loss did not improve from 2326.24707
# 7/7 - 1s - loss: 303673.7188 - val_loss: 19789.9844 - 535ms/epoch - 76ms/step
# Epoch 82/1000
#
# Epoch 82: val_loss improved from 2326.24707 to 1972.45776, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 287118.7500 - val_loss: 1972.4578 - 1s/epoch - 206ms/step
# Epoch 83/1000
#
# Epoch 83: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 364969.8438 - val_loss: 2237.7122 - 1s/epoch - 202ms/step
# Epoch 84/1000
#
# Epoch 84: val_loss did not improve from 1972.45776
# 7/7 - 2s - loss: 361355.1250 - val_loss: 58025.8281 - 2s/epoch - 243ms/step
# Epoch 85/1000
#
# Epoch 85: val_loss did not improve from 1972.45776
# 7/7 - 2s - loss: 334406.9062 - val_loss: 100361.0625 - 2s/epoch - 237ms/step
# Epoch 86/1000
#
# Epoch 86: val_loss did not improve from 1972.45776
# 7/7 - 2s - loss: 305028.5625 - val_loss: 43176.2734 - 2s/epoch - 219ms/step
# Epoch 87/1000
#
# Epoch 87: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 318521.6875 - val_loss: 2342.8286 - 995ms/epoch - 142ms/step
# Epoch 88/1000
#
# Epoch 88: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 363869.9062 - val_loss: 10117.4092 - 736ms/epoch - 105ms/step
# Epoch 89/1000
#
# Epoch 89: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 279484.6562 - val_loss: 7134.9824 - 548ms/epoch - 78ms/step
# Epoch 90/1000
#
# Epoch 90: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 290215.6875 - val_loss: 10472.0410 - 504ms/epoch - 72ms/step
# Epoch 91/1000
#
# Epoch 91: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 309226.3438 - val_loss: 22414.4805 - 520ms/epoch - 74ms/step
# Epoch 92/1000
#
# Epoch 92: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 290180.0312 - val_loss: 18950.8398 - 524ms/epoch - 75ms/step
# Epoch 93/1000
#
# Epoch 93: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 344436.3750 - val_loss: 45581.8242 - 1s/epoch - 148ms/step
# Epoch 94/1000
#
# Epoch 94: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 309558.0938 - val_loss: 109318.1719 - 913ms/epoch - 130ms/step
# Epoch 95/1000
#
# Epoch 95: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 313708.0000 - val_loss: 62741.6992 - 740ms/epoch - 106ms/step
# Epoch 96/1000
#
# Epoch 96: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 283745.4688 - val_loss: 22856.4844 - 1s/epoch - 151ms/step
# Epoch 97/1000
#
# Epoch 97: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 299181.7812 - val_loss: 77179.0625 - 519ms/epoch - 74ms/step
# Epoch 98/1000
#
# Epoch 98: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 338838.3125 - val_loss: 224063.9219 - 547ms/epoch - 78ms/step
# Epoch 99/1000
#
# Epoch 99: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 291131.3438 - val_loss: 93145.5469 - 585ms/epoch - 84ms/step
# Epoch 100/1000
#
# Epoch 100: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 331512.7812 - val_loss: 33024.0469 - 538ms/epoch - 77ms/step
# Epoch 101/1000
#
# Epoch 101: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 328813.7188 - val_loss: 13375.4229 - 529ms/epoch - 76ms/step
# Epoch 102/1000
#
# Epoch 102: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 256652.5781 - val_loss: 2879.4207 - 530ms/epoch - 76ms/step
# Epoch 103/1000
#
# Epoch 103: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 274719.3438 - val_loss: 64423.5742 - 535ms/epoch - 76ms/step
# Epoch 104/1000
#
# Epoch 104: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 286816.8750 - val_loss: 40488.9062 - 932ms/epoch - 133ms/step
# Epoch 105/1000
#
# Epoch 105: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 289944.4375 - val_loss: 6169.0898 - 1s/epoch - 148ms/step
# Epoch 106/1000
#
# Epoch 106: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 267227.7812 - val_loss: 2016.5693 - 1s/epoch - 170ms/step
# Epoch 107/1000
#
# Epoch 107: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 304502.0625 - val_loss: 2257.8643 - 993ms/epoch - 142ms/step
# Epoch 108/1000
#
# Epoch 108: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 284850.5000 - val_loss: 2945.3860 - 1s/epoch - 156ms/step
# Epoch 109/1000
#
# Epoch 109: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 280307.7188 - val_loss: 15950.0664 - 801ms/epoch - 114ms/step
# Epoch 110/1000
#
# Epoch 110: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 306139.3438 - val_loss: 40103.4062 - 582ms/epoch - 83ms/step
# Epoch 111/1000
#
# Epoch 111: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 250712.3594 - val_loss: 15301.3203 - 528ms/epoch - 75ms/step
# Epoch 112/1000
#
# Epoch 112: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 287413.9062 - val_loss: 2513.6223 - 560ms/epoch - 80ms/step
# Epoch 113/1000
#
# Epoch 113: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 288131.2500 - val_loss: 24605.5801 - 546ms/epoch - 78ms/step
# Epoch 114/1000
#
# Epoch 114: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 267921.5938 - val_loss: 65289.1211 - 527ms/epoch - 75ms/step
# Epoch 115/1000
#
# Epoch 115: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 247702.0469 - val_loss: 12887.5850 - 532ms/epoch - 76ms/step
# Epoch 116/1000
#
# Epoch 116: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 276893.8750 - val_loss: 19762.1328 - 513ms/epoch - 73ms/step
# Epoch 117/1000
#
# Epoch 117: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 252716.3281 - val_loss: 2215.3430 - 549ms/epoch - 78ms/step
# Epoch 118/1000
#
# Epoch 118: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 287211.5000 - val_loss: 5719.7583 - 534ms/epoch - 76ms/step
# Epoch 119/1000
#
# Epoch 119: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 344284.4062 - val_loss: 28786.1543 - 533ms/epoch - 76ms/step
# Epoch 120/1000
#
# Epoch 120: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 328411.4688 - val_loss: 94271.5000 - 500ms/epoch - 71ms/step
# Epoch 121/1000
#
# Epoch 121: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 279141.6250 - val_loss: 21949.8555 - 529ms/epoch - 76ms/step
# Epoch 122/1000
#
# Epoch 122: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 269145.3750 - val_loss: 5162.2373 - 550ms/epoch - 79ms/step
# Epoch 123/1000
#
# Epoch 123: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 262369.9062 - val_loss: 38793.1406 - 595ms/epoch - 85ms/step
# Epoch 124/1000
#
# Epoch 124: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 244585.2969 - val_loss: 24154.1172 - 532ms/epoch - 76ms/step
# Epoch 125/1000
#
# Epoch 125: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 268302.4062 - val_loss: 41428.9766 - 555ms/epoch - 79ms/step
# Epoch 126/1000
#
# Epoch 126: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 275853.3438 - val_loss: 35967.9883 - 567ms/epoch - 81ms/step
# Epoch 127/1000
#
# Epoch 127: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 302752.2500 - val_loss: 72155.6016 - 510ms/epoch - 73ms/step
# Epoch 128/1000
#
# Epoch 128: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 253851.9844 - val_loss: 71792.0547 - 1s/epoch - 151ms/step
# Epoch 129/1000
#
# Epoch 129: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 264177.9375 - val_loss: 40046.2891 - 1s/epoch - 154ms/step
# Epoch 130/1000
#
# Epoch 130: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 275426.7812 - val_loss: 38339.3594 - 1s/epoch - 158ms/step
# Epoch 131/1000
#
# Epoch 131: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 277591.1562 - val_loss: 126882.3672 - 1s/epoch - 157ms/step
# Epoch 132/1000
#
# Epoch 132: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 290348.2188 - val_loss: 62714.6094 - 1s/epoch - 146ms/step
# Epoch 133/1000
#
# Epoch 133: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 245137.2656 - val_loss: 5739.2402 - 731ms/epoch - 104ms/step
# Epoch 134/1000
#
# Epoch 134: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 299683.7500 - val_loss: 8385.1357 - 520ms/epoch - 74ms/step
# Epoch 135/1000
#
# Epoch 135: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 314278.9062 - val_loss: 52625.7891 - 538ms/epoch - 77ms/step
# Epoch 136/1000
#
# Epoch 136: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 261873.4531 - val_loss: 68921.2812 - 547ms/epoch - 78ms/step
# Epoch 137/1000
#
# Epoch 137: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 277100.9062 - val_loss: 47650.1953 - 521ms/epoch - 74ms/step
# Epoch 138/1000
#
# Epoch 138: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 300154.5625 - val_loss: 36192.3789 - 513ms/epoch - 73ms/step
# Epoch 139/1000
#
# Epoch 139: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 300840.9062 - val_loss: 8060.5825 - 519ms/epoch - 74ms/step
# Epoch 140/1000
#
# Epoch 140: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 254896.2812 - val_loss: 72747.9766 - 547ms/epoch - 78ms/step
# Epoch 141/1000
#
# Epoch 141: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 254959.4062 - val_loss: 47063.0664 - 507ms/epoch - 72ms/step
# Epoch 142/1000
#
# Epoch 142: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 251935.1406 - val_loss: 47440.2266 - 526ms/epoch - 75ms/step
# Epoch 143/1000
#
# Epoch 143: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 258318.5156 - val_loss: 55489.3203 - 532ms/epoch - 76ms/step
# Epoch 144/1000
#
# Epoch 144: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 258004.9375 - val_loss: 90704.6797 - 514ms/epoch - 73ms/step
# Epoch 145/1000
#
# Epoch 145: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 241770.7812 - val_loss: 25819.6953 - 528ms/epoch - 75ms/step
# Epoch 146/1000
#
# Epoch 146: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 287175.6562 - val_loss: 46026.0859 - 547ms/epoch - 78ms/step
# Epoch 147/1000
#
# Epoch 147: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 281591.3750 - val_loss: 59296.2812 - 617ms/epoch - 88ms/step
# Epoch 148/1000
#
# Epoch 148: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 266166.7812 - val_loss: 8785.8760 - 557ms/epoch - 80ms/step
# Epoch 149/1000
#
# Epoch 149: val_loss did not improve from 1972.45776
# 7/7 - 0s - loss: 271865.5625 - val_loss: 20633.3594 - 496ms/epoch - 71ms/step
# Epoch 150/1000
#
# Epoch 150: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 277517.4688 - val_loss: 61787.1016 - 528ms/epoch - 75ms/step
# Epoch 151/1000
#
# Epoch 151: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 258312.8281 - val_loss: 88121.9922 - 542ms/epoch - 77ms/step
# Epoch 152/1000
#
# Epoch 152: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 301098.9062 - val_loss: 7531.0850 - 992ms/epoch - 142ms/step
# Epoch 153/1000
#
# Epoch 153: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 257290.7500 - val_loss: 6542.6250 - 1s/epoch - 144ms/step
# Epoch 154/1000
#
# Epoch 154: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 275670.7812 - val_loss: 102115.3828 - 1s/epoch - 154ms/step
# Epoch 155/1000
#
# Epoch 155: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 246587.1094 - val_loss: 69811.1094 - 1s/epoch - 145ms/step
# Epoch 156/1000
#
# Epoch 156: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 255829.6719 - val_loss: 16464.7246 - 1s/epoch - 152ms/step
# Epoch 157/1000
#
# Epoch 157: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 258987.1094 - val_loss: 18419.4141 - 892ms/epoch - 127ms/step
# Epoch 158/1000
#
# Epoch 158: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 281766.9062 - val_loss: 31338.6895 - 521ms/epoch - 74ms/step
# Epoch 159/1000
#
# Epoch 159: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 290000.4375 - val_loss: 51672.7617 - 508ms/epoch - 73ms/step
# Epoch 160/1000
#
# Epoch 160: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 273556.0312 - val_loss: 72030.6250 - 526ms/epoch - 75ms/step
# Epoch 161/1000
#
# Epoch 161: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 278680.3125 - val_loss: 48935.9297 - 538ms/epoch - 77ms/step
# Epoch 162/1000
#
# Epoch 162: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 242765.9531 - val_loss: 31277.9980 - 526ms/epoch - 75ms/step
# Epoch 163/1000
#
# Epoch 163: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 270564.7812 - val_loss: 38971.1523 - 511ms/epoch - 73ms/step
# Epoch 164/1000
#
# Epoch 164: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 252833.7812 - val_loss: 7433.5361 - 546ms/epoch - 78ms/step
# Epoch 165/1000
#
# Epoch 165: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 278269.4375 - val_loss: 3720.8938 - 523ms/epoch - 75ms/step
# Epoch 166/1000
#
# Epoch 166: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 312952.6562 - val_loss: 20737.0859 - 529ms/epoch - 76ms/step
# Epoch 167/1000
#
# Epoch 167: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 283614.5000 - val_loss: 76526.8281 - 556ms/epoch - 79ms/step
# Epoch 168/1000
#
# Epoch 168: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 249095.0312 - val_loss: 22657.6855 - 547ms/epoch - 78ms/step
# Epoch 169/1000
#
# Epoch 169: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 266171.9688 - val_loss: 52039.0391 - 524ms/epoch - 75ms/step
# Epoch 170/1000
#
# Epoch 170: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 279438.6250 - val_loss: 49539.7383 - 520ms/epoch - 74ms/step
# Epoch 171/1000
#
# Epoch 171: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 287388.0625 - val_loss: 9589.6885 - 546ms/epoch - 78ms/step
# Epoch 172/1000
#
# Epoch 172: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 242246.4219 - val_loss: 38086.2617 - 553ms/epoch - 79ms/step
# Epoch 173/1000
#
# Epoch 173: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 244176.7969 - val_loss: 39502.8789 - 590ms/epoch - 84ms/step
# Epoch 174/1000
#
# Epoch 174: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 256306.3281 - val_loss: 18558.8457 - 510ms/epoch - 73ms/step
# Epoch 175/1000
#
# Epoch 175: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 243222.9375 - val_loss: 38852.4922 - 626ms/epoch - 89ms/step
# Epoch 176/1000
#
# Epoch 176: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 255589.3906 - val_loss: 54794.6914 - 984ms/epoch - 141ms/step
# Epoch 177/1000
#
# Epoch 177: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 264363.4688 - val_loss: 49259.6719 - 1s/epoch - 159ms/step
# Epoch 178/1000
#
# Epoch 178: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 253542.3438 - val_loss: 18380.0410 - 1s/epoch - 162ms/step
# Epoch 179/1000
#
# Epoch 179: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 262000.9844 - val_loss: 8995.1621 - 1s/epoch - 157ms/step
# Epoch 180/1000
#
# Epoch 180: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 289248.6562 - val_loss: 29106.3008 - 963ms/epoch - 138ms/step
# Epoch 181/1000
#
# Epoch 181: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 241129.8750 - val_loss: 51467.8281 - 911ms/epoch - 130ms/step
# Epoch 182/1000
#
# Epoch 182: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 232927.3438 - val_loss: 12573.3242 - 613ms/epoch - 88ms/step
# Epoch 183/1000
#
# Epoch 183: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 265412.3438 - val_loss: 3181.0247 - 645ms/epoch - 92ms/step
# Epoch 184/1000
#
# Epoch 184: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 291104.9688 - val_loss: 77637.4141 - 520ms/epoch - 74ms/step
# Epoch 185/1000
#
# Epoch 185: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 242402.5156 - val_loss: 114369.8984 - 544ms/epoch - 78ms/step
# Epoch 186/1000
#
# Epoch 186: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 253783.0938 - val_loss: 67149.5312 - 548ms/epoch - 78ms/step
# Epoch 187/1000
#
# Epoch 187: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 253075.3750 - val_loss: 9774.8154 - 518ms/epoch - 74ms/step
# Epoch 188/1000
#
# Epoch 188: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 241447.2031 - val_loss: 7748.5474 - 504ms/epoch - 72ms/step
# Epoch 189/1000
#
# Epoch 189: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 265267.1875 - val_loss: 14262.0771 - 502ms/epoch - 72ms/step
# Epoch 190/1000
#
# Epoch 190: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 253406.7344 - val_loss: 31083.9941 - 525ms/epoch - 75ms/step
# Epoch 191/1000
#
# Epoch 191: val_loss did not improve from 1972.45776
# 7/7 - 0s - loss: 269620.8750 - val_loss: 65743.7344 - 499ms/epoch - 71ms/step
# Epoch 192/1000
#
# Epoch 192: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 244408.0312 - val_loss: 41472.3320 - 530ms/epoch - 76ms/step
# Epoch 193/1000
#
# Epoch 193: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 247425.6875 - val_loss: 59590.1367 - 540ms/epoch - 77ms/step
# Epoch 194/1000
#
# Epoch 194: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 230423.8125 - val_loss: 57013.0586 - 586ms/epoch - 84ms/step
# Epoch 195/1000
#
# Epoch 195: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 231846.5469 - val_loss: 51618.3203 - 514ms/epoch - 73ms/step
# Epoch 196/1000
#
# Epoch 196: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 286877.6875 - val_loss: 16402.7520 - 557ms/epoch - 80ms/step
# Epoch 197/1000
#
# Epoch 197: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 270341.5312 - val_loss: 31185.9043 - 575ms/epoch - 82ms/step
# Epoch 198/1000
#
# Epoch 198: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 281726.5625 - val_loss: 46248.7500 - 574ms/epoch - 82ms/step
# Epoch 199/1000
#
# Epoch 199: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 266295.4062 - val_loss: 18883.1719 - 730ms/epoch - 104ms/step
# Epoch 200/1000
#
# Epoch 200: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 285164.1562 - val_loss: 47814.3867 - 1s/epoch - 164ms/step
# Epoch 201/1000
#
# Epoch 201: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 248650.3281 - val_loss: 70503.5000 - 1s/epoch - 154ms/step
# Epoch 202/1000
#
# Epoch 202: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 256583.4844 - val_loss: 78739.2422 - 1s/epoch - 156ms/step
# Epoch 203/1000
#
# Epoch 203: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 272661.4688 - val_loss: 53988.7969 - 1s/epoch - 159ms/step
# Epoch 204/1000
#
# Epoch 204: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 282679.5625 - val_loss: 8834.3623 - 1s/epoch - 147ms/step
# Epoch 205/1000
#
# Epoch 205: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 245410.6875 - val_loss: 20106.4668 - 504ms/epoch - 72ms/step
# Epoch 206/1000
#
# Epoch 206: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 254959.7344 - val_loss: 59032.8633 - 562ms/epoch - 80ms/step
# Epoch 207/1000
#
# Epoch 207: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 271453.2188 - val_loss: 42896.0391 - 620ms/epoch - 89ms/step
# Epoch 208/1000
#
# Epoch 208: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 254891.3281 - val_loss: 66036.6328 - 531ms/epoch - 76ms/step
# Epoch 209/1000
#
# Epoch 209: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 215421.8125 - val_loss: 74115.8203 - 561ms/epoch - 80ms/step
# Epoch 210/1000
#
# Epoch 210: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 244408.5156 - val_loss: 25049.9727 - 537ms/epoch - 77ms/step
# Epoch 211/1000
#
# Epoch 211: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 278030.2812 - val_loss: 79596.8438 - 536ms/epoch - 77ms/step
# Epoch 212/1000
#
# Epoch 212: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 287726.3750 - val_loss: 40430.7617 - 541ms/epoch - 77ms/step
# Epoch 213/1000
#
# Epoch 213: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 285466.4062 - val_loss: 126938.3203 - 550ms/epoch - 79ms/step
# Epoch 214/1000
#
# Epoch 214: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 256398.0781 - val_loss: 70926.9609 - 537ms/epoch - 77ms/step
# Epoch 215/1000
#
# Epoch 215: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 271004.5000 - val_loss: 15232.4062 - 842ms/epoch - 120ms/step
# Epoch 216/1000
#
# Epoch 216: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 248884.2500 - val_loss: 10590.6016 - 556ms/epoch - 79ms/step
# Epoch 217/1000
#
# Epoch 217: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 227743.2969 - val_loss: 6855.6494 - 548ms/epoch - 78ms/step
# Epoch 218/1000
#
# Epoch 218: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 280761.3438 - val_loss: 33396.7422 - 612ms/epoch - 87ms/step
# Epoch 219/1000
#
# Epoch 219: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 279346.9688 - val_loss: 27033.5898 - 574ms/epoch - 82ms/step
# Epoch 220/1000
#
# Epoch 220: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 249481.7188 - val_loss: 12098.6885 - 528ms/epoch - 75ms/step
# Epoch 221/1000
#
# Epoch 221: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 259678.9219 - val_loss: 12078.5098 - 505ms/epoch - 72ms/step
# Epoch 222/1000
#
# Epoch 222: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 218475.0625 - val_loss: 44677.5781 - 741ms/epoch - 106ms/step
# Epoch 223/1000
#
# Epoch 223: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 242886.3750 - val_loss: 98116.7031 - 1s/epoch - 161ms/step
# Epoch 224/1000
#
# Epoch 224: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 253773.3906 - val_loss: 109580.7031 - 1s/epoch - 156ms/step
# Epoch 225/1000
#
# Epoch 225: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 257464.0469 - val_loss: 7841.0527 - 1s/epoch - 148ms/step
# Epoch 226/1000
#
# Epoch 226: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 270505.9375 - val_loss: 4664.0322 - 1s/epoch - 153ms/step
# Epoch 227/1000
#
# Epoch 227: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 259270.4688 - val_loss: 113381.8516 - 981ms/epoch - 140ms/step
# Epoch 228/1000
#
# Epoch 228: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 248119.4219 - val_loss: 52303.6406 - 584ms/epoch - 83ms/step
# Epoch 229/1000
#
# Epoch 229: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 263434.8750 - val_loss: 31988.1523 - 508ms/epoch - 73ms/step
# Epoch 230/1000
#
# Epoch 230: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 240821.8438 - val_loss: 8555.6660 - 561ms/epoch - 80ms/step
# Epoch 231/1000
#
# Epoch 231: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 227810.0938 - val_loss: 6058.5625 - 545ms/epoch - 78ms/step
# Epoch 232/1000
#
# Epoch 232: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 247662.3125 - val_loss: 18669.3691 - 513ms/epoch - 73ms/step
# Epoch 233/1000
#
# Epoch 233: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 260273.9219 - val_loss: 28720.7520 - 533ms/epoch - 76ms/step
# Epoch 234/1000
#
# Epoch 234: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 233455.5625 - val_loss: 35243.9141 - 516ms/epoch - 74ms/step
# Epoch 235/1000
#
# Epoch 235: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 270745.4688 - val_loss: 25273.6797 - 525ms/epoch - 75ms/step
# Epoch 236/1000
#
# Epoch 236: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 246581.5781 - val_loss: 38003.9883 - 506ms/epoch - 72ms/step
# Epoch 237/1000
#
# Epoch 237: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 248887.0156 - val_loss: 25303.1406 - 584ms/epoch - 83ms/step
# Epoch 238/1000
#
# Epoch 238: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 268893.7188 - val_loss: 16148.2275 - 536ms/epoch - 77ms/step
# Epoch 239/1000
#
# Epoch 239: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 265986.7500 - val_loss: 34914.5469 - 523ms/epoch - 75ms/step
# Epoch 240/1000
#
# Epoch 240: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 243705.3906 - val_loss: 67885.4609 - 545ms/epoch - 78ms/step
# Epoch 241/1000
#
# Epoch 241: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 243352.4375 - val_loss: 7781.4639 - 576ms/epoch - 82ms/step
# Epoch 242/1000
#
# Epoch 242: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 250284.4219 - val_loss: 6725.2437 - 540ms/epoch - 77ms/step
# Epoch 243/1000
#
# Epoch 243: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 267820.0312 - val_loss: 9645.2314 - 536ms/epoch - 77ms/step
# Epoch 244/1000
#
# Epoch 244: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 244693.6719 - val_loss: 25063.0352 - 535ms/epoch - 76ms/step
# Epoch 245/1000
#
# Epoch 245: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 240747.7812 - val_loss: 99995.6016 - 520ms/epoch - 74ms/step
# Epoch 246/1000
#
# Epoch 246: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 230218.9375 - val_loss: 59598.5312 - 987ms/epoch - 141ms/step
# Epoch 247/1000
#
# Epoch 247: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 235875.0938 - val_loss: 8596.6641 - 1s/epoch - 146ms/step
# Epoch 248/1000
#
# Epoch 248: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 282577.4375 - val_loss: 26822.5957 - 1s/epoch - 155ms/step
# Epoch 249/1000
#
# Epoch 249: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 231500.5156 - val_loss: 69706.5703 - 1s/epoch - 147ms/step
# Epoch 250/1000
#
# Epoch 250: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 262053.4062 - val_loss: 24246.7305 - 1s/epoch - 144ms/step
# Epoch 251/1000
#
# Epoch 251: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 224929.0938 - val_loss: 27282.7578 - 893ms/epoch - 128ms/step
# Epoch 252/1000
#
# Epoch 252: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 227814.0938 - val_loss: 39763.6211 - 515ms/epoch - 74ms/step
# Epoch 253/1000
#
# Epoch 253: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 248639.7188 - val_loss: 18205.5527 - 561ms/epoch - 80ms/step
# Epoch 254/1000
#
# Epoch 254: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 210006.2031 - val_loss: 19516.7207 - 531ms/epoch - 76ms/step
# Epoch 255/1000
#
# Epoch 255: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 240958.7188 - val_loss: 42739.7383 - 530ms/epoch - 76ms/step
# Epoch 256/1000
#
# Epoch 256: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 230419.8750 - val_loss: 39138.7617 - 550ms/epoch - 79ms/step
# Epoch 257/1000
#
# Epoch 257: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 245864.0469 - val_loss: 40382.0586 - 524ms/epoch - 75ms/step
# Epoch 258/1000
#
# Epoch 258: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 225082.2188 - val_loss: 18217.4316 - 540ms/epoch - 77ms/step
# Epoch 259/1000
#
# Epoch 259: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 273022.5625 - val_loss: 73365.1172 - 530ms/epoch - 76ms/step
# Epoch 260/1000
#
# Epoch 260: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 233171.3438 - val_loss: 8715.9658 - 511ms/epoch - 73ms/step
# Epoch 261/1000
#
# Epoch 261: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 232399.0156 - val_loss: 52148.8594 - 524ms/epoch - 75ms/step
# Epoch 262/1000
#
# Epoch 262: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 243624.9219 - val_loss: 46723.1797 - 505ms/epoch - 72ms/step
# Epoch 263/1000
#
# Epoch 263: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 255412.1406 - val_loss: 9047.4902 - 553ms/epoch - 79ms/step
# Epoch 264/1000
#
# Epoch 264: val_loss did not improve from 1972.45776
# 7/7 - 0s - loss: 254991.8438 - val_loss: 93879.5469 - 491ms/epoch - 70ms/step
# Epoch 265/1000
#
# Epoch 265: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 246280.8281 - val_loss: 60497.0000 - 522ms/epoch - 75ms/step
# Epoch 266/1000
#
# Epoch 266: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 267379.5625 - val_loss: 5966.8311 - 515ms/epoch - 74ms/step
# Epoch 267/1000
#
# Epoch 267: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 233277.7344 - val_loss: 19592.0840 - 549ms/epoch - 78ms/step
# Epoch 268/1000
#
# Epoch 268: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 259757.7344 - val_loss: 23516.2852 - 530ms/epoch - 76ms/step
# Epoch 269/1000
#
# Epoch 269: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 236679.2969 - val_loss: 42871.7109 - 597ms/epoch - 85ms/step
# Epoch 270/1000
#
# Epoch 270: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 252536.9688 - val_loss: 36423.3555 - 762ms/epoch - 109ms/step
# Epoch 271/1000
#
# Epoch 271: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 246701.6719 - val_loss: 31652.0059 - 962ms/epoch - 137ms/step
# Epoch 272/1000
#
# Epoch 272: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 225876.5000 - val_loss: 20663.0742 - 1s/epoch - 161ms/step
# Epoch 273/1000
#
# Epoch 273: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 252137.9531 - val_loss: 42618.5703 - 1s/epoch - 156ms/step
# Epoch 274/1000
#
# Epoch 274: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 267623.8438 - val_loss: 104476.7969 - 1s/epoch - 161ms/step
# Epoch 275/1000
#
# Epoch 275: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 248949.2969 - val_loss: 48477.1953 - 841ms/epoch - 120ms/step
# Epoch 276/1000
#
# Epoch 276: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 213152.3281 - val_loss: 57827.9492 - 633ms/epoch - 90ms/step
# Epoch 277/1000
#
# Epoch 277: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 231376.9062 - val_loss: 44629.2188 - 570ms/epoch - 81ms/step
# Epoch 278/1000
#
# Epoch 278: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 227281.6094 - val_loss: 24204.2695 - 602ms/epoch - 86ms/step
# Epoch 279/1000
#
# Epoch 279: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 237255.6406 - val_loss: 25613.1152 - 539ms/epoch - 77ms/step
# Epoch 280/1000
#
# Epoch 280: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 260404.2188 - val_loss: 45488.5234 - 520ms/epoch - 74ms/step
# Epoch 281/1000
#
# Epoch 281: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 256979.2656 - val_loss: 137083.6875 - 515ms/epoch - 74ms/step
# Epoch 282/1000
#
# Epoch 282: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 259207.5469 - val_loss: 54055.7344 - 533ms/epoch - 76ms/step
# Epoch 283/1000
#
# Epoch 283: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 251820.2656 - val_loss: 21397.9746 - 564ms/epoch - 81ms/step
# Epoch 284/1000
#
# Epoch 284: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 246630.0781 - val_loss: 13371.6055 - 554ms/epoch - 79ms/step
# Epoch 285/1000
#
# Epoch 285: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 239187.2188 - val_loss: 19947.2070 - 535ms/epoch - 76ms/step
# Epoch 286/1000
#
# Epoch 286: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 229595.8125 - val_loss: 26479.4902 - 576ms/epoch - 82ms/step
# Epoch 287/1000
#
# Epoch 287: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 234936.5000 - val_loss: 30684.3945 - 553ms/epoch - 79ms/step
# Epoch 288/1000
#
# Epoch 288: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 253364.4844 - val_loss: 40766.5742 - 531ms/epoch - 76ms/step
# Epoch 289/1000
#
# Epoch 289: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 229856.1406 - val_loss: 64382.3555 - 508ms/epoch - 73ms/step
# Epoch 290/1000
#
# Epoch 290: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 228341.4844 - val_loss: 36081.2930 - 516ms/epoch - 74ms/step
# Epoch 291/1000
#
# Epoch 291: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 226110.3750 - val_loss: 32499.2402 - 557ms/epoch - 80ms/step
# Epoch 292/1000
#
# Epoch 292: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 235863.0469 - val_loss: 3506.0674 - 546ms/epoch - 78ms/step
# Epoch 293/1000
#
# Epoch 293: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 286266.5625 - val_loss: 66235.2266 - 532ms/epoch - 76ms/step
# Epoch 294/1000
#
# Epoch 294: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 259764.0156 - val_loss: 113881.8594 - 734ms/epoch - 105ms/step
# Epoch 295/1000
#
# Epoch 295: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 239030.6250 - val_loss: 9683.8701 - 1s/epoch - 166ms/step
# Epoch 296/1000
#
# Epoch 296: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 242957.5156 - val_loss: 4757.4468 - 1s/epoch - 164ms/step
# Epoch 297/1000
#
# Epoch 297: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 254429.9844 - val_loss: 81564.3438 - 1s/epoch - 146ms/step
# Epoch 298/1000
#
# Epoch 298: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 234626.9219 - val_loss: 19105.4082 - 988ms/epoch - 141ms/step
# Epoch 299/1000
#
# Epoch 299: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 214923.9062 - val_loss: 25343.6953 - 891ms/epoch - 127ms/step
# Epoch 300/1000
#
# Epoch 300: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 198280.1406 - val_loss: 30199.7695 - 602ms/epoch - 86ms/step
# Epoch 301/1000
#
# Epoch 301: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 238569.9062 - val_loss: 37403.3359 - 523ms/epoch - 75ms/step
# Epoch 302/1000
#
# Epoch 302: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 272962.6875 - val_loss: 38155.0391 - 541ms/epoch - 77ms/step
# Epoch 303/1000
#
# Epoch 303: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 244906.3125 - val_loss: 37106.8203 - 518ms/epoch - 74ms/step
# Epoch 304/1000
#
# Epoch 304: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 222275.0938 - val_loss: 55154.7305 - 521ms/epoch - 74ms/step
# Epoch 305/1000
#
# ...
# 7/7 - 1s - loss: 178530.7500 - val_loss: 3292.5537 - 587ms/epoch - 84ms/step
# Epoch 893/1000
#
# Epoch 893: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 184246.0000 - val_loss: 4969.8677 - 562ms/epoch - 80ms/step
# Epoch 894/1000
#
# Epoch 894: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 208566.1562 - val_loss: 33115.6445 - 777ms/epoch - 111ms/step
# Epoch 895/1000
#
# Epoch 895: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 188354.8594 - val_loss: 3400.6350 - 548ms/epoch - 78ms/step
# Epoch 896/1000
#
# Epoch 896: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 192196.5781 - val_loss: 9017.3662 - 542ms/epoch - 77ms/step
# Epoch 897/1000
#
# Epoch 897: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 196533.2500 - val_loss: 4409.2427 - 559ms/epoch - 80ms/step
# Epoch 898/1000
#
# Epoch 898: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 191102.5156 - val_loss: 3320.1465 - 514ms/epoch - 73ms/step
# Epoch 899/1000
#
# Epoch 899: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 167237.7812 - val_loss: 8952.9570 - 540ms/epoch - 77ms/step
# Epoch 900/1000
#
# Epoch 900: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 184476.9375 - val_loss: 6600.0215 - 525ms/epoch - 75ms/step
# Epoch 901/1000
#
# Epoch 901: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 179091.3750 - val_loss: 4987.1221 - 537ms/epoch - 77ms/step
# Epoch 902/1000
#
# Epoch 902: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 141940.6875 - val_loss: 3167.4028 - 511ms/epoch - 73ms/step
# Epoch 903/1000
#
# Epoch 903: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 171267.4062 - val_loss: 7856.4307 - 538ms/epoch - 77ms/step
# Epoch 904/1000
#
# Epoch 904: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 178387.5156 - val_loss: 13619.2412 - 538ms/epoch - 77ms/step
# Epoch 905/1000
#
# Epoch 905: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 186665.9688 - val_loss: 12077.8633 - 550ms/epoch - 79ms/step
# Epoch 906/1000
#
# Epoch 906: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 195845.2031 - val_loss: 3080.1619 - 548ms/epoch - 78ms/step
# Epoch 907/1000
#
# Epoch 907: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 168890.5625 - val_loss: 7492.5737 - 674ms/epoch - 96ms/step
# Epoch 908/1000
#
# Epoch 908: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 154489.0781 - val_loss: 14945.4873 - 1s/epoch - 161ms/step
# Epoch 909/1000
#
# Epoch 909: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 156904.3438 - val_loss: 3212.1729 - 1s/epoch - 150ms/step
# Epoch 910/1000
#
# Epoch 910: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 179308.4219 - val_loss: 26921.5625 - 1s/epoch - 162ms/step
# Epoch 911/1000
#
# Epoch 911: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 186496.3750 - val_loss: 6603.4927 - 1s/epoch - 145ms/step
# Epoch 912/1000
#
# Epoch 912: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 194669.4062 - val_loss: 7084.0640 - 1s/epoch - 149ms/step
# Epoch 913/1000
#
# Epoch 913: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 182799.4219 - val_loss: 4191.5630 - 653ms/epoch - 93ms/step
# Epoch 914/1000
#
# Epoch 914: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 185668.2188 - val_loss: 3197.8953 - 581ms/epoch - 83ms/step
# Epoch 915/1000
#
# Epoch 915: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 183806.0781 - val_loss: 7980.1108 - 548ms/epoch - 78ms/step
# Epoch 916/1000
#
# Epoch 916: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 152386.8281 - val_loss: 8527.9561 - 566ms/epoch - 81ms/step
# Epoch 917/1000
#
# Epoch 917: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 160269.6562 - val_loss: 12291.5322 - 530ms/epoch - 76ms/step
# Epoch 918/1000
#
# Epoch 918: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 145910.4375 - val_loss: 3016.0662 - 528ms/epoch - 75ms/step
# Epoch 919/1000
#
# Epoch 919: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 169297.0312 - val_loss: 4282.5796 - 552ms/epoch - 79ms/step
# Epoch 920/1000
#
# Epoch 920: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 160146.8281 - val_loss: 3693.6118 - 541ms/epoch - 77ms/step
# Epoch 921/1000
#
# Epoch 921: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 169451.2812 - val_loss: 13561.6953 - 529ms/epoch - 76ms/step
# Epoch 922/1000
#
# Epoch 922: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 154868.7344 - val_loss: 9006.9141 - 540ms/epoch - 77ms/step
# Epoch 923/1000
#
# Epoch 923: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 196982.9844 - val_loss: 6842.0688 - 594ms/epoch - 85ms/step
# Epoch 924/1000
#
# Epoch 924: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 180537.0781 - val_loss: 4551.9976 - 505ms/epoch - 72ms/step
# Epoch 925/1000
#
# Epoch 925: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 189436.8281 - val_loss: 4179.1230 - 574ms/epoch - 82ms/step
# Epoch 926/1000
#
# Epoch 926: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 172827.5625 - val_loss: 4650.5776 - 573ms/epoch - 82ms/step
# Epoch 927/1000
#
# Epoch 927: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 190070.8906 - val_loss: 5282.8926 - 531ms/epoch - 76ms/step
# Epoch 928/1000
#
# Epoch 928: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 206890.0469 - val_loss: 3452.2632 - 546ms/epoch - 78ms/step
# Epoch 929/1000
#
# Epoch 929: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 187369.8750 - val_loss: 3852.5781 - 543ms/epoch - 78ms/step
# Epoch 930/1000
#
# Epoch 930: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 182738.8125 - val_loss: 9176.9453 - 547ms/epoch - 78ms/step
# Epoch 931/1000
#
# Epoch 931: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 196007.3438 - val_loss: 3612.8918 - 895ms/epoch - 128ms/step
# Epoch 932/1000
#
# Epoch 932: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 177364.5625 - val_loss: 18200.2012 - 1s/epoch - 165ms/step
# Epoch 933/1000
#
# Epoch 933: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 171865.1406 - val_loss: 6644.7275 - 1s/epoch - 167ms/step
# Epoch 934/1000
#
# Epoch 934: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 174239.6875 - val_loss: 15426.6846 - 971ms/epoch - 139ms/step
# Epoch 935/1000
#
# Epoch 935: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 185811.9219 - val_loss: 3152.2712 - 1s/epoch - 165ms/step
# Epoch 936/1000
#
# Epoch 936: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 205037.4531 - val_loss: 12833.7773 - 829ms/epoch - 118ms/step
# Epoch 937/1000
#
# Epoch 937: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 177382.4219 - val_loss: 5809.5586 - 530ms/epoch - 76ms/step
# Epoch 938/1000
#
# Epoch 938: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 196223.8438 - val_loss: 5454.1543 - 577ms/epoch - 82ms/step
# Epoch 939/1000
#
# Epoch 939: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 180865.9219 - val_loss: 28280.1270 - 587ms/epoch - 84ms/step
# Epoch 940/1000
#
# Epoch 940: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 174490.4688 - val_loss: 3881.0874 - 622ms/epoch - 89ms/step
# Epoch 941/1000
#
# Epoch 941: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 160797.1406 - val_loss: 8561.4697 - 526ms/epoch - 75ms/step
# Epoch 942/1000
#
# Epoch 942: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 175088.5938 - val_loss: 3582.8191 - 579ms/epoch - 83ms/step
# Epoch 943/1000
#
# Epoch 943: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 149578.5938 - val_loss: 3126.6436 - 599ms/epoch - 86ms/step
# Epoch 944/1000
#
# Epoch 944: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 199929.6562 - val_loss: 8328.5166 - 565ms/epoch - 81ms/step
# Epoch 945/1000
#
# Epoch 945: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 179298.4531 - val_loss: 7846.4111 - 537ms/epoch - 77ms/step
# Epoch 946/1000
#
# Epoch 946: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 190068.4219 - val_loss: 11629.1611 - 591ms/epoch - 84ms/step
# Epoch 947/1000
#
# Epoch 947: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 167488.0000 - val_loss: 3305.2791 - 599ms/epoch - 86ms/step
# Epoch 948/1000
#
# Epoch 948: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 166607.0312 - val_loss: 12725.8496 - 560ms/epoch - 80ms/step
# Epoch 949/1000
#
# Epoch 949: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 164238.9531 - val_loss: 11129.8828 - 574ms/epoch - 82ms/step
# Epoch 950/1000
#
# Epoch 950: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 195814.3906 - val_loss: 3629.8091 - 581ms/epoch - 83ms/step
# Epoch 951/1000
#
# Epoch 951: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 166941.7812 - val_loss: 5079.2437 - 598ms/epoch - 85ms/step
# Epoch 952/1000
#
# Epoch 952: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 192892.5781 - val_loss: 3461.0044 - 577ms/epoch - 82ms/step
# Epoch 953/1000
#
# Epoch 953: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 180290.3438 - val_loss: 8279.0127 - 711ms/epoch - 102ms/step
# Epoch 954/1000
#
# Epoch 954: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 181031.6094 - val_loss: 15367.5811 - 1s/epoch - 178ms/step
# Epoch 955/1000
#
# Epoch 955: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 167066.1094 - val_loss: 2970.9216 - 1s/epoch - 167ms/step
# Epoch 956/1000
#
# Epoch 956: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 195062.5938 - val_loss: 6106.9688 - 1s/epoch - 157ms/step
# Epoch 957/1000
#
# Epoch 957: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 165447.2500 - val_loss: 7557.5420 - 1s/epoch - 157ms/step
# Epoch 958/1000
#
# Epoch 958: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 188431.9688 - val_loss: 11774.5498 - 1s/epoch - 153ms/step
# Epoch 959/1000
#
# Epoch 959: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 186610.0469 - val_loss: 25742.5605 - 751ms/epoch - 107ms/step
# Epoch 960/1000
#
# Epoch 960: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 167636.7812 - val_loss: 22685.0996 - 575ms/epoch - 82ms/step
# Epoch 961/1000
#
# Epoch 961: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 175377.0625 - val_loss: 24884.8418 - 594ms/epoch - 85ms/step
# Epoch 962/1000
#
# Epoch 962: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 188125.5781 - val_loss: 4254.7280 - 566ms/epoch - 81ms/step
# Epoch 963/1000
#
# Epoch 963: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 182088.9062 - val_loss: 4313.5195 - 582ms/epoch - 83ms/step
# Epoch 964/1000
#
# Epoch 964: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 170006.8906 - val_loss: 9347.1807 - 547ms/epoch - 78ms/step
# Epoch 965/1000
#
# Epoch 965: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 180343.9688 - val_loss: 7800.6938 - 575ms/epoch - 82ms/step
# Epoch 966/1000
#
# Epoch 966: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 163056.2656 - val_loss: 14130.8896 - 555ms/epoch - 79ms/step
# Epoch 967/1000
#
# Epoch 967: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 169875.1562 - val_loss: 3679.1108 - 625ms/epoch - 89ms/step
# Epoch 968/1000
#
# Epoch 968: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 172473.7656 - val_loss: 8951.1533 - 598ms/epoch - 85ms/step
# Epoch 969/1000
#
# Epoch 969: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 181342.5781 - val_loss: 6250.0576 - 557ms/epoch - 80ms/step
# Epoch 970/1000
#
# Epoch 970: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 193336.1094 - val_loss: 33450.8711 - 542ms/epoch - 77ms/step
# Epoch 971/1000
#
# Epoch 971: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 192632.3594 - val_loss: 14165.9199 - 557ms/epoch - 80ms/step
# Epoch 972/1000
#
# Epoch 972: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 192407.8594 - val_loss: 3455.8538 - 534ms/epoch - 76ms/step
# Epoch 973/1000
#
# Epoch 973: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 192913.0312 - val_loss: 12110.8555 - 551ms/epoch - 79ms/step
# Epoch 974/1000
#
# Epoch 974: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 194788.1875 - val_loss: 30482.9844 - 529ms/epoch - 76ms/step
# Epoch 975/1000
#
# Epoch 975: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 207336.7344 - val_loss: 3133.0010 - 516ms/epoch - 74ms/step
# Epoch 976/1000
#
# Epoch 976: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 189389.0781 - val_loss: 3222.2275 - 553ms/epoch - 79ms/step
# Epoch 977/1000
#
# Epoch 977: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 201959.8906 - val_loss: 11835.4326 - 892ms/epoch - 127ms/step
# Epoch 978/1000
#
# Epoch 978: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 193381.2188 - val_loss: 7969.6377 - 1s/epoch - 151ms/step
# Epoch 979/1000
#
# Epoch 979: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 159452.1562 - val_loss: 9354.0088 - 1s/epoch - 147ms/step
# Epoch 980/1000
#
# Epoch 980: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 157898.8125 - val_loss: 5696.4932 - 1s/epoch - 161ms/step
# Epoch 981/1000
#
# Epoch 981: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 184500.5781 - val_loss: 3274.7107 - 1s/epoch - 161ms/step
# Epoch 982/1000
#
# Epoch 982: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 171875.2188 - val_loss: 36730.6016 - 905ms/epoch - 129ms/step
# Epoch 983/1000
#
# Epoch 983: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 193981.4844 - val_loss: 27863.8398 - 597ms/epoch - 85ms/step
# Epoch 984/1000
#
# Epoch 984: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 197807.1562 - val_loss: 3410.8013 - 563ms/epoch - 80ms/step
# Epoch 985/1000
#
# Epoch 985: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 186386.9531 - val_loss: 3184.9556 - 557ms/epoch - 80ms/step
# Epoch 986/1000
#
# Epoch 986: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 185593.1562 - val_loss: 3217.6008 - 536ms/epoch - 77ms/step
# Epoch 987/1000
#
# Epoch 987: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 155340.7969 - val_loss: 6492.5767 - 560ms/epoch - 80ms/step
# Epoch 988/1000
#
# Epoch 988: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 171568.1562 - val_loss: 3928.5281 - 555ms/epoch - 79ms/step
# Epoch 989/1000
#
# Epoch 989: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 180410.8906 - val_loss: 3663.8940 - 531ms/epoch - 76ms/step
# Epoch 990/1000
#
# Epoch 990: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 170901.3281 - val_loss: 4173.8511 - 554ms/epoch - 79ms/step
# Epoch 991/1000
#
# Epoch 991: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 173993.2188 - val_loss: 9904.6260 - 554ms/epoch - 79ms/step
# Epoch 992/1000
#
# Epoch 992: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 172846.8125 - val_loss: 3082.0627 - 550ms/epoch - 79ms/step
# Epoch 993/1000
#
# Epoch 993: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 155313.2188 - val_loss: 3212.5024 - 544ms/epoch - 78ms/step
# Epoch 994/1000
#
# Epoch 994: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 164027.4062 - val_loss: 3282.1951 - 546ms/epoch - 78ms/step
# Epoch 995/1000
#
# Epoch 995: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 174150.9531 - val_loss: 4887.5947 - 548ms/epoch - 78ms/step
# Epoch 996/1000
#
# Epoch 996: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 176241.0469 - val_loss: 3062.0127 - 535ms/epoch - 76ms/step
# Epoch 997/1000
#
# Epoch 997: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 178930.4375 - val_loss: 12956.8467 - 555ms/epoch - 79ms/step
# Epoch 998/1000
#
# Epoch 998: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 185157.9062 - val_loss: 22584.2793 - 518ms/epoch - 74ms/step
# Epoch 999/1000
#
# Epoch 999: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 170151.4531 - val_loss: 3289.5662 - 526ms/epoch - 75ms/step
# Epoch 1000/1000
#
# Epoch 1000: val_loss did not improve from 1972.45776
# 7/7 - 1s - loss: 173896.9531 - val_loss: 4069.8535 - 619ms/epoch - 88ms/step
# 16/16 [==============================] - 1s 9ms/step
# 3/3 [==============================] - 0s 11ms/step
# Training MSE: 6079.466
# Testing MSE: 3031.846
# Training MAPE: 2.233%
# Testing MAPE: 1.778%
# accuracy : 54

# %%
# 모델 생성
model = Sequential()
model.add(Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(MaxPooling1D(pool_size=2))
model.add(GRU(units=1024, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=512, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=256, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=128, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=64, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=32, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=16, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(units=1))
model.summary()


# loss = Huber()
# optimizer = Adam(0.0005)
# model.compile(loss=Huber(), optimizer=optimizer, metrics=['mse'])
model.compile(optimizer='adam', loss='mean_squared_error')

filename = os.path.join('tmp', 'ckeckpointer.ckpt')
checkpoint = ModelCheckpoint(filename,
                             save_weights_only=True,
                             save_best_only=True,
                             monitor='val_loss',
                             verbose=1)

# 모델 학습
history = model.fit(trainX, trainY, epochs=1000, batch_size=64,
          validation_split=0.1, verbose=2,callbacks=[checkpoint])

model.save_weights('./lstm_weights.h2')

model.load_weights(filename)

plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()
plt.show()

# 예측
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# MSE 계산
trainMSE = mean_squared_error(trainY, trainPredict)
testMSE = mean_squared_error(testY, testPredict)

# MAPE 계산
trainMAPE = calculate_mape(trainY, trainPredict)
testMAPE = calculate_mape(testY, testPredict)

print(f'Training MSE: {trainMSE:.3f}')
print(f'Testing MSE: {testMSE:.3f}')
print(f'Training MAPE: {trainMAPE:.3f}%')
print(f'Testing MAPE: {testMAPE:.3f}%')

accuracy(testPredict,testY)

# 예측 시각화
plt.plot(trainY, label='Actual Price')
plt.plot(trainPredict, label='Predicted Price')
plt.legend()
plt.title('Training Data')
plt.show()

plt.plot(testY, label='Actual Price')
plt.plot(testPredict, label='Predicted Price')
plt.legend()
plt.title('Testing Data')
plt.show()
# Out:
# WARNING:tensorflow:Layer gru_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 3, 256)            7936
#
#  max_pooling1d (MaxPooling1  (None, 1, 256)            0
#  D)
#
#  gru_6 (GRU)                 (None, 1, 1024)           3938304
#
#  dropout_6 (Dropout)         (None, 1, 1024)           0
#
#  gru_7 (GRU)                 (None, 1, 512)            2362368
#
#  dropout_7 (Dropout)         (None, 1, 512)            0
#
#  gru_8 (GRU)                 (None, 1, 256)            591360
#
#  dropout_8 (Dropout)         (None, 1, 256)            0
#
#  gru_9 (GRU)                 (None, 1, 128)            148224
#
#  dropout_9 (Dropout)         (None, 1, 128)            0
#
#  gru_10 (GRU)                (None, 1, 64)             37248
#
#  dropout_10 (Dropout)        (None, 1, 64)             0
#
#  gru_11 (GRU)                (None, 1, 32)             9408
#
#  dropout_11 (Dropout)        (None, 1, 32)             0
#
#  gru_12 (GRU)                (None, 16)                2400
#
#  dropout_12 (Dropout)        (None, 16)                0
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 7097265 (27.07 MB)
# Trainable params: 7097265 (27.07 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/1000
#
# Epoch 1: val_loss improved from inf to 5710783.50000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 18s - loss: 8167917.5000 - val_loss: 5710783.5000 - 18s/epoch - 3s/step
# Epoch 2/1000
#
# Epoch 2: val_loss improved from 5710783.50000 to 5694114.50000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 8166204.5000 - val_loss: 5694114.5000 - 580ms/epoch - 83ms/step
# Epoch 3/1000
#
# Epoch 3: val_loss improved from 5694114.50000 to 4839913.50000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 7995156.0000 - val_loss: 4839913.5000 - 825ms/epoch - 118ms/step
# Epoch 4/1000
#
# Epoch 4: val_loss improved from 4839913.50000 to 197505.09375, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 5810183.5000 - val_loss: 197505.0938 - 829ms/epoch - 118ms/step
# Epoch 5/1000
#
# Epoch 5: val_loss improved from 197505.09375 to 16815.59180, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 2542193.5000 - val_loss: 16815.5918 - 823ms/epoch - 118ms/step
# Epoch 6/1000
#
# Epoch 6: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 2294359.2500 - val_loss: 116205.9375 - 458ms/epoch - 65ms/step
# Epoch 7/1000
#
# Epoch 7: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1852899.0000 - val_loss: 33974.0195 - 487ms/epoch - 70ms/step
# Epoch 8/1000
#
# Epoch 8: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 2122321.5000 - val_loss: 248697.7031 - 416ms/epoch - 59ms/step
# Epoch 9/1000
#
# Epoch 9: val_loss did not improve from 16815.59180
# 7/7 - 1s - loss: 1801786.0000 - val_loss: 43681.8398 - 505ms/epoch - 72ms/step
# Epoch 10/1000
#
# Epoch 10: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1795848.5000 - val_loss: 196535.2031 - 471ms/epoch - 67ms/step
# Epoch 11/1000
#
# Epoch 11: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1773027.7500 - val_loss: 195855.3594 - 408ms/epoch - 58ms/step
# Epoch 12/1000
#
# Epoch 12: val_loss did not improve from 16815.59180
# 7/7 - 1s - loss: 1652944.0000 - val_loss: 379436.0000 - 503ms/epoch - 72ms/step
# Epoch 13/1000
#
# Epoch 13: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1615653.3750 - val_loss: 319083.4375 - 243ms/epoch - 35ms/step
# Epoch 14/1000
#
# Epoch 14: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1616092.8750 - val_loss: 387213.8438 - 240ms/epoch - 34ms/step
# Epoch 15/1000
#
# Epoch 15: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1453723.1250 - val_loss: 308789.8750 - 242ms/epoch - 35ms/step
# Epoch 16/1000
#
# Epoch 16: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1672091.0000 - val_loss: 477343.8438 - 243ms/epoch - 35ms/step
# Epoch 17/1000
#
# Epoch 17: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1612274.2500 - val_loss: 247523.2188 - 230ms/epoch - 33ms/step
# Epoch 18/1000
#
# Epoch 18: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1643529.5000 - val_loss: 390631.5625 - 245ms/epoch - 35ms/step
# Epoch 19/1000
#
# Epoch 19: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1489186.5000 - val_loss: 94873.8438 - 242ms/epoch - 35ms/step
# Epoch 20/1000
#
# Epoch 20: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1434468.8750 - val_loss: 268631.7812 - 240ms/epoch - 34ms/step
# Epoch 21/1000
#
# Epoch 21: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1334863.8750 - val_loss: 85617.4766 - 233ms/epoch - 33ms/step
# Epoch 22/1000
#
# Epoch 22: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1487319.2500 - val_loss: 462146.8750 - 241ms/epoch - 34ms/step
# Epoch 23/1000
#
# Epoch 23: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1463819.2500 - val_loss: 36320.1445 - 257ms/epoch - 37ms/step
# Epoch 24/1000
#
# Epoch 24: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1551411.8750 - val_loss: 645499.8125 - 238ms/epoch - 34ms/step
# Epoch 25/1000
#
# Epoch 25: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1504608.6250 - val_loss: 209591.8438 - 241ms/epoch - 34ms/step
# Epoch 26/1000
#
# Epoch 26: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1488310.8750 - val_loss: 413125.6875 - 243ms/epoch - 35ms/step
# Epoch 27/1000
#
# Epoch 27: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1523368.8750 - val_loss: 151542.0156 - 259ms/epoch - 37ms/step
# Epoch 28/1000
#
# Epoch 28: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1497871.7500 - val_loss: 383637.4375 - 265ms/epoch - 38ms/step
# Epoch 29/1000
#
# Epoch 29: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1294307.0000 - val_loss: 181264.2812 - 238ms/epoch - 34ms/step
# Epoch 30/1000
#
# Epoch 30: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1556937.5000 - val_loss: 297503.7188 - 256ms/epoch - 37ms/step
# Epoch 31/1000
#
# Epoch 31: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1389535.1250 - val_loss: 63094.6992 - 234ms/epoch - 33ms/step
# Epoch 32/1000
#
# Epoch 32: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1263007.8750 - val_loss: 206643.5938 - 246ms/epoch - 35ms/step
# Epoch 33/1000
#
# Epoch 33: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1163488.7500 - val_loss: 91980.3438 - 235ms/epoch - 34ms/step
# Epoch 34/1000
#
# Epoch 34: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1332248.3750 - val_loss: 101829.8828 - 239ms/epoch - 34ms/step
# Epoch 35/1000
#
# Epoch 35: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1408244.3750 - val_loss: 324340.1875 - 270ms/epoch - 39ms/step
# Epoch 36/1000
#
# Epoch 36: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1317387.1250 - val_loss: 23668.6777 - 260ms/epoch - 37ms/step
# Epoch 37/1000
#
# Epoch 37: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1210436.6250 - val_loss: 293021.7500 - 249ms/epoch - 36ms/step
# Epoch 38/1000
#
# Epoch 38: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1305447.1250 - val_loss: 164469.5938 - 248ms/epoch - 35ms/step
# Epoch 39/1000
#
# Epoch 39: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1165437.7500 - val_loss: 114413.8438 - 275ms/epoch - 39ms/step
# Epoch 40/1000
#
# Epoch 40: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1120544.1250 - val_loss: 243919.4844 - 246ms/epoch - 35ms/step
# Epoch 41/1000
#
# Epoch 41: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1139232.8750 - val_loss: 36061.5820 - 244ms/epoch - 35ms/step
# Epoch 42/1000
#
# Epoch 42: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1325471.8750 - val_loss: 312942.4062 - 253ms/epoch - 36ms/step
# Epoch 43/1000
#
# Epoch 43: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1325046.7500 - val_loss: 77922.0234 - 277ms/epoch - 40ms/step
# Epoch 44/1000
#
# Epoch 44: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1266425.1250 - val_loss: 169422.2344 - 257ms/epoch - 37ms/step
# Epoch 45/1000
#
# Epoch 45: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1199588.0000 - val_loss: 182161.2969 - 254ms/epoch - 36ms/step
# Epoch 46/1000
#
# Epoch 46: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1173942.7500 - val_loss: 65049.1055 - 239ms/epoch - 34ms/step
# Epoch 47/1000
#
# Epoch 47: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1187150.0000 - val_loss: 127985.2812 - 268ms/epoch - 38ms/step
# Epoch 48/1000
#
# Epoch 48: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1235060.0000 - val_loss: 73860.0547 - 268ms/epoch - 38ms/step
# Epoch 49/1000
#
# Epoch 49: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1062229.3750 - val_loss: 58726.1484 - 247ms/epoch - 35ms/step
# Epoch 50/1000
#
# Epoch 50: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1051692.1250 - val_loss: 79905.3516 - 267ms/epoch - 38ms/step
# Epoch 51/1000
#
# Epoch 51: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1170401.2500 - val_loss: 123208.5000 - 263ms/epoch - 38ms/step
# Epoch 52/1000
#
# Epoch 52: val_loss did not improve from 16815.59180
# 7/7 - 0s - loss: 1029598.1875 - val_loss: 69249.1719 - 432ms/epoch - 62ms/step
# Epoch 53/1000
#
# Epoch 53: val_loss improved from 16815.59180 to 6935.73828, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 1113185.2500 - val_loss: 6935.7383 - 851ms/epoch - 122ms/step
# Epoch 54/1000
#
# Epoch 54: val_loss did not improve from 6935.73828
# 7/7 - 0s - loss: 1140958.2500 - val_loss: 220478.2969 - 484ms/epoch - 69ms/step
# Epoch 55/1000
#
# Epoch 55: val_loss did not improve from 6935.73828
# 7/7 - 1s - loss: 1168013.0000 - val_loss: 8733.2314 - 502ms/epoch - 72ms/step
# Epoch 56/1000
#
# Epoch 56: val_loss did not improve from 6935.73828
# 7/7 - 0s - loss: 1037290.3125 - val_loss: 217794.0469 - 483ms/epoch - 69ms/step
# Epoch 57/1000
#
# Epoch 57: val_loss did not improve from 6935.73828
# 7/7 - 0s - loss: 1149042.7500 - val_loss: 11524.5010 - 447ms/epoch - 64ms/step
# Epoch 58/1000
#
# Epoch 58: val_loss did not improve from 6935.73828
# 7/7 - 0s - loss: 1139626.1250 - val_loss: 215520.3594 - 439ms/epoch - 63ms/step
# Epoch 59/1000
#
# Epoch 59: val_loss did not improve from 6935.73828
# 7/7 - 0s - loss: 1124680.7500 - val_loss: 31896.6504 - 393ms/epoch - 56ms/step
# Epoch 60/1000
#
# Epoch 60: val_loss did not improve from 6935.73828
# 7/7 - 0s - loss: 1103258.5000 - val_loss: 177873.1250 - 493ms/epoch - 70ms/step
# Epoch 61/1000
#
# Epoch 61: val_loss did not improve from 6935.73828
# 7/7 - 0s - loss: 1041050.8750 - val_loss: 80464.0078 - 479ms/epoch - 68ms/step
# Epoch 62/1000
#
# Epoch 62: val_loss did not improve from 6935.73828
# 7/7 - 0s - loss: 1024610.0625 - val_loss: 41818.1602 - 478ms/epoch - 68ms/step
# Epoch 63/1000
#
# Epoch 63: val_loss did not improve from 6935.73828
# 7/7 - 0s - loss: 892863.1875 - val_loss: 106178.9531 - 395ms/epoch - 56ms/step
# Epoch 64/1000
#
# Epoch 64: val_loss did not improve from 6935.73828
# 7/7 - 0s - loss: 1069811.1250 - val_loss: 19246.2051 - 267ms/epoch - 38ms/step
# Epoch 65/1000
#
# Epoch 65: val_loss did not improve from 6935.73828
# 7/7 - 0s - loss: 1111539.6250 - val_loss: 125849.5625 - 263ms/epoch - 38ms/step
# Epoch 66/1000
#
# Epoch 66: val_loss did not improve from 6935.73828
# 7/7 - 0s - loss: 1112298.0000 - val_loss: 8390.8984 - 264ms/epoch - 38ms/step
# Epoch 67/1000
#
# Epoch 67: val_loss did not improve from 6935.73828
# 7/7 - 0s - loss: 1193543.7500 - val_loss: 296217.9062 - 240ms/epoch - 34ms/step
# Epoch 68/1000
#
# Epoch 68: val_loss improved from 6935.73828 to 4428.50635, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 0s - loss: 1022351.1250 - val_loss: 4428.5063 - 493ms/epoch - 70ms/step
# Epoch 69/1000
#
# Epoch 69: val_loss did not improve from 4428.50635
# 7/7 - 0s - loss: 1047030.0625 - val_loss: 9252.1572 - 229ms/epoch - 33ms/step
# Epoch 70/1000
#
# Epoch 70: val_loss did not improve from 4428.50635
# 7/7 - 0s - loss: 892712.0625 - val_loss: 75962.3516 - 259ms/epoch - 37ms/step
# Epoch 71/1000
#
# Epoch 71: val_loss did not improve from 4428.50635
# 7/7 - 0s - loss: 914549.0000 - val_loss: 60301.2109 - 284ms/epoch - 41ms/step
# Epoch 72/1000
#
# Epoch 72: val_loss did not improve from 4428.50635
# 7/7 - 0s - loss: 980016.4375 - val_loss: 10416.0156 - 243ms/epoch - 35ms/step
# Epoch 73/1000
#
# Epoch 73: val_loss did not improve from 4428.50635
# 7/7 - 0s - loss: 941749.1875 - val_loss: 85869.1484 - 240ms/epoch - 34ms/step
# Epoch 74/1000
#
# Epoch 74: val_loss did not improve from 4428.50635
# 7/7 - 0s - loss: 890689.8125 - val_loss: 10284.0361 - 249ms/epoch - 36ms/step
# Epoch 75/1000
#
# Epoch 75: val_loss did not improve from 4428.50635
# 7/7 - 0s - loss: 1012795.1250 - val_loss: 21576.1230 - 248ms/epoch - 35ms/step
# Epoch 76/1000
#
# Epoch 76: val_loss did not improve from 4428.50635
# 7/7 - 0s - loss: 955881.3125 - val_loss: 37471.7070 - 270ms/epoch - 39ms/step
# Epoch 77/1000
#
# Epoch 77: val_loss did not improve from 4428.50635
# 7/7 - 0s - loss: 1036142.0000 - val_loss: 12644.2246 - 243ms/epoch - 35ms/step
# Epoch 78/1000
#
# Epoch 78: val_loss did not improve from 4428.50635
# 7/7 - 0s - loss: 948499.6875 - val_loss: 299300.9688 - 258ms/epoch - 37ms/step
# Epoch 79/1000
#
# Epoch 79: val_loss did not improve from 4428.50635
# 7/7 - 0s - loss: 1058703.8750 - val_loss: 29805.3008 - 322ms/epoch - 46ms/step
# Epoch 80/1000
#
# Epoch 80: val_loss did not improve from 4428.50635
# 7/7 - 0s - loss: 910957.5000 - val_loss: 75493.6406 - 251ms/epoch - 36ms/step
# Epoch 81/1000
#
# Epoch 81: val_loss did not improve from 4428.50635
# 7/7 - 0s - loss: 825461.5000 - val_loss: 26765.7520 - 260ms/epoch - 37ms/step
# Epoch 82/1000
#
# Epoch 82: val_loss did not improve from 4428.50635
# 7/7 - 0s - loss: 919375.3750 - val_loss: 63910.9961 - 274ms/epoch - 39ms/step
# Epoch 83/1000
#
# Epoch 83: val_loss did not improve from 4428.50635
# 7/7 - 0s - loss: 913939.3750 - val_loss: 16445.9082 - 248ms/epoch - 35ms/step
# Epoch 84/1000
#
# Epoch 84: val_loss improved from 4428.50635 to 3140.69067, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 0s - loss: 893313.5625 - val_loss: 3140.6907 - 476ms/epoch - 68ms/step
# Epoch 85/1000
#
# Epoch 85: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 893474.8750 - val_loss: 116448.9062 - 262ms/epoch - 37ms/step
# Epoch 86/1000
#
# Epoch 86: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 914253.0625 - val_loss: 25287.6523 - 241ms/epoch - 34ms/step
# Epoch 87/1000
#
# Epoch 87: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 825980.5625 - val_loss: 149296.2344 - 239ms/epoch - 34ms/step
# Epoch 88/1000
#
# Epoch 88: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 877260.5625 - val_loss: 88573.5469 - 260ms/epoch - 37ms/step
# Epoch 89/1000
#
# Epoch 89: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 983600.8750 - val_loss: 7593.4414 - 239ms/epoch - 34ms/step
# Epoch 90/1000
#
# Epoch 90: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 925398.9375 - val_loss: 124245.5000 - 286ms/epoch - 41ms/step
# Epoch 91/1000
#
# Epoch 91: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 957094.0625 - val_loss: 90034.4531 - 238ms/epoch - 34ms/step
# Epoch 92/1000
#
# Epoch 92: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 890356.1875 - val_loss: 8978.6260 - 259ms/epoch - 37ms/step
# Epoch 93/1000
#
# Epoch 93: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 972973.8125 - val_loss: 216695.0625 - 251ms/epoch - 36ms/step
# Epoch 94/1000
#
# Epoch 94: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 818720.5000 - val_loss: 15028.1084 - 259ms/epoch - 37ms/step
# Epoch 95/1000
#
# Epoch 95: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 848372.6250 - val_loss: 29454.7441 - 237ms/epoch - 34ms/step
# Epoch 96/1000
#
# Epoch 96: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 838726.5625 - val_loss: 97767.6797 - 251ms/epoch - 36ms/step
# Epoch 97/1000
#
# Epoch 97: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 915463.3750 - val_loss: 13648.5752 - 254ms/epoch - 36ms/step
# Epoch 98/1000
#
# Epoch 98: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 841632.8125 - val_loss: 119008.2422 - 243ms/epoch - 35ms/step
# Epoch 99/1000
#
# Epoch 99: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 847499.0000 - val_loss: 16156.5547 - 256ms/epoch - 37ms/step
# Epoch 100/1000
#
# Epoch 100: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 860212.3125 - val_loss: 79070.2734 - 465ms/epoch - 66ms/step
# Epoch 101/1000
#
# Epoch 101: val_loss did not improve from 3140.69067
# 7/7 - 1s - loss: 866485.1875 - val_loss: 53266.6992 - 516ms/epoch - 74ms/step
# Epoch 102/1000
#
# Epoch 102: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 856040.5000 - val_loss: 63001.8594 - 450ms/epoch - 64ms/step
# Epoch 103/1000
#
# Epoch 103: val_loss did not improve from 3140.69067
# 7/7 - 1s - loss: 1008230.5000 - val_loss: 47110.1211 - 520ms/epoch - 74ms/step
# Epoch 104/1000
#
# Epoch 104: val_loss did not improve from 3140.69067
# 7/7 - 1s - loss: 907686.9375 - val_loss: 126135.1875 - 529ms/epoch - 76ms/step
# Epoch 105/1000
#
# Epoch 105: val_loss did not improve from 3140.69067
# 7/7 - 1s - loss: 893376.0625 - val_loss: 38590.0859 - 519ms/epoch - 74ms/step
# Epoch 106/1000
#
# Epoch 106: val_loss did not improve from 3140.69067
# 7/7 - 1s - loss: 873073.5000 - val_loss: 28336.4883 - 580ms/epoch - 83ms/step
# Epoch 107/1000
#
# Epoch 107: val_loss did not improve from 3140.69067
# 7/7 - 1s - loss: 833459.7500 - val_loss: 9140.3848 - 505ms/epoch - 72ms/step
# Epoch 108/1000
#
# Epoch 108: val_loss did not improve from 3140.69067
# 7/7 - 1s - loss: 842761.3750 - val_loss: 15637.4697 - 510ms/epoch - 73ms/step
# Epoch 109/1000
#
# Epoch 109: val_loss did not improve from 3140.69067
# 7/7 - 1s - loss: 798634.6250 - val_loss: 8935.3623 - 524ms/epoch - 75ms/step
# Epoch 110/1000
#
# Epoch 110: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 891225.0625 - val_loss: 6688.4932 - 483ms/epoch - 69ms/step
# Epoch 111/1000
#
# Epoch 111: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 840380.3125 - val_loss: 25812.1992 - 486ms/epoch - 69ms/step
# Epoch 112/1000
#
# Epoch 112: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 839696.5625 - val_loss: 16271.8828 - 325ms/epoch - 46ms/step
# Epoch 113/1000
#
# Epoch 113: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 743993.5625 - val_loss: 24430.3379 - 252ms/epoch - 36ms/step
# Epoch 114/1000
#
# Epoch 114: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 846799.1250 - val_loss: 56033.6016 - 246ms/epoch - 35ms/step
# Epoch 115/1000
#
# Epoch 115: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 811995.3750 - val_loss: 108749.7578 - 264ms/epoch - 38ms/step
# Epoch 116/1000
#
# Epoch 116: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 853416.9375 - val_loss: 13884.6133 - 238ms/epoch - 34ms/step
# Epoch 117/1000
#
# Epoch 117: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 741373.2500 - val_loss: 224715.2656 - 247ms/epoch - 35ms/step
# Epoch 118/1000
#
# Epoch 118: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 848451.8750 - val_loss: 16552.9473 - 255ms/epoch - 36ms/step
# Epoch 119/1000
#
# Epoch 119: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 928686.3125 - val_loss: 292628.3750 - 259ms/epoch - 37ms/step
# Epoch 120/1000
#
# Epoch 120: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 859375.5000 - val_loss: 93239.9766 - 284ms/epoch - 41ms/step
# Epoch 121/1000
#
# Epoch 121: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 930440.3125 - val_loss: 70701.5312 - 262ms/epoch - 37ms/step
# Epoch 122/1000
#
# Epoch 122: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 869394.6250 - val_loss: 45172.6406 - 289ms/epoch - 41ms/step
# Epoch 123/1000
#
# Epoch 123: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 850101.3750 - val_loss: 4834.9902 - 262ms/epoch - 37ms/step
# Epoch 124/1000
#
# Epoch 124: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 870197.5000 - val_loss: 5689.2339 - 273ms/epoch - 39ms/step
# Epoch 125/1000
#
# Epoch 125: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 865098.0625 - val_loss: 131112.4531 - 240ms/epoch - 34ms/step
# Epoch 126/1000
#
# Epoch 126: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 825862.4375 - val_loss: 3274.1338 - 254ms/epoch - 36ms/step
# Epoch 127/1000
#
# Epoch 127: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 858134.5000 - val_loss: 41280.2539 - 251ms/epoch - 36ms/step
# Epoch 128/1000
#
# Epoch 128: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 832605.9375 - val_loss: 83635.2031 - 245ms/epoch - 35ms/step
# Epoch 129/1000
#
# Epoch 129: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 817436.3125 - val_loss: 48407.6602 - 263ms/epoch - 38ms/step
# Epoch 130/1000
#
# Epoch 130: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 909248.0000 - val_loss: 175723.1250 - 227ms/epoch - 32ms/step
# Epoch 131/1000
#
# Epoch 131: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 835695.5625 - val_loss: 32292.7207 - 250ms/epoch - 36ms/step
# Epoch 132/1000
#
# Epoch 132: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 868480.3125 - val_loss: 10815.9902 - 262ms/epoch - 37ms/step
# Epoch 133/1000
#
# Epoch 133: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 840717.5000 - val_loss: 67396.7109 - 237ms/epoch - 34ms/step
# Epoch 134/1000
#
# Epoch 134: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 846716.1875 - val_loss: 5439.9082 - 233ms/epoch - 33ms/step
# Epoch 135/1000
#
# Epoch 135: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 816106.9375 - val_loss: 45485.9531 - 247ms/epoch - 35ms/step
# Epoch 136/1000
#
# Epoch 136: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 842309.7500 - val_loss: 41519.4648 - 260ms/epoch - 37ms/step
# Epoch 137/1000
#
# Epoch 137: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 830949.8125 - val_loss: 8177.3862 - 243ms/epoch - 35ms/step
# Epoch 138/1000
#
# Epoch 138: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 847320.8750 - val_loss: 92505.4609 - 246ms/epoch - 35ms/step
# Epoch 139/1000
#
# Epoch 139: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 771371.6250 - val_loss: 7056.1113 - 269ms/epoch - 38ms/step
# Epoch 140/1000
#
# Epoch 140: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 870352.8750 - val_loss: 63095.6836 - 278ms/epoch - 40ms/step
# Epoch 141/1000
#
# Epoch 141: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 782168.5000 - val_loss: 6793.5562 - 249ms/epoch - 36ms/step
# Epoch 142/1000
#
# Epoch 142: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 893122.9375 - val_loss: 70599.0391 - 250ms/epoch - 36ms/step
# Epoch 143/1000
#
# Epoch 143: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 850270.5000 - val_loss: 179867.8438 - 245ms/epoch - 35ms/step
# Epoch 144/1000
#
# Epoch 144: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 870527.0000 - val_loss: 3693.4441 - 230ms/epoch - 33ms/step
# Epoch 145/1000
#
# Epoch 145: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 863386.9375 - val_loss: 81813.3828 - 255ms/epoch - 36ms/step
# Epoch 146/1000
#
# Epoch 146: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 847207.1250 - val_loss: 34233.6914 - 229ms/epoch - 33ms/step
# Epoch 147/1000
#
# Epoch 147: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 866797.1250 - val_loss: 13605.9072 - 231ms/epoch - 33ms/step
# Epoch 148/1000
#
# Epoch 148: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 825710.1250 - val_loss: 180078.5156 - 220ms/epoch - 31ms/step
# Epoch 149/1000
#
# Epoch 149: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 850086.5000 - val_loss: 36233.6445 - 245ms/epoch - 35ms/step
# Epoch 150/1000
#
# Epoch 150: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 854520.8125 - val_loss: 57005.3438 - 238ms/epoch - 34ms/step
# Epoch 151/1000
#
# Epoch 151: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 882195.3125 - val_loss: 89695.5703 - 431ms/epoch - 62ms/step
# Epoch 152/1000
#
# Epoch 152: val_loss did not improve from 3140.69067
# 7/7 - 0s - loss: 775225.4375 - val_loss: 3980.6406 - 481ms/epoch - 69ms/step
# Epoch 153/1000
#
# Epoch 153: val_loss did not improve from 3140.69067
# 7/7 - 1s - loss: 828404.7500 - val_loss: 73421.1328 - 504ms/epoch - 72ms/step
# Epoch 154/1000
#
# Epoch 154: val_loss improved from 3140.69067 to 2907.32495, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 770544.4375 - val_loss: 2907.3250 - 791ms/epoch - 113ms/step
# Epoch 155/1000
#
# Epoch 155: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 908275.8125 - val_loss: 2913.3960 - 453ms/epoch - 65ms/step
# Epoch 156/1000
#
# Epoch 156: val_loss did not improve from 2907.32495
# 7/7 - 1s - loss: 911842.1875 - val_loss: 62860.2812 - 502ms/epoch - 72ms/step
# Epoch 157/1000
#
# Epoch 157: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 838488.8750 - val_loss: 13211.1133 - 448ms/epoch - 64ms/step
# Epoch 158/1000
#
# Epoch 158: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 749173.7500 - val_loss: 106470.7969 - 476ms/epoch - 68ms/step
# Epoch 159/1000
#
# Epoch 159: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 843636.7500 - val_loss: 66824.5391 - 465ms/epoch - 66ms/step
# Epoch 160/1000
#
# Epoch 160: val_loss did not improve from 2907.32495
# 7/7 - 1s - loss: 815424.4375 - val_loss: 124925.8125 - 521ms/epoch - 74ms/step
# Epoch 161/1000
#
# Epoch 161: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 784022.2500 - val_loss: 79655.5391 - 488ms/epoch - 70ms/step
# Epoch 162/1000
#
# Epoch 162: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 878978.6875 - val_loss: 96104.1406 - 390ms/epoch - 56ms/step
# Epoch 163/1000
#
# Epoch 163: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 961831.8125 - val_loss: 26004.3418 - 273ms/epoch - 39ms/step
# Epoch 164/1000
#
# Epoch 164: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 903084.4375 - val_loss: 66044.3203 - 247ms/epoch - 35ms/step
# Epoch 165/1000
#
# Epoch 165: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 789846.3125 - val_loss: 51127.7383 - 245ms/epoch - 35ms/step
# Epoch 166/1000
#
# Epoch 166: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 722211.2500 - val_loss: 6793.7051 - 263ms/epoch - 38ms/step
# Epoch 167/1000
#
# Epoch 167: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 830176.8750 - val_loss: 131543.9219 - 275ms/epoch - 39ms/step
# Epoch 168/1000
#
# Epoch 168: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 798837.6250 - val_loss: 24199.6602 - 264ms/epoch - 38ms/step
# Epoch 169/1000
#
# Epoch 169: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 864280.5000 - val_loss: 92154.2969 - 257ms/epoch - 37ms/step
# Epoch 170/1000
#
# Epoch 170: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 799996.5625 - val_loss: 111114.1172 - 259ms/epoch - 37ms/step
# Epoch 171/1000
#
# Epoch 171: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 882888.0625 - val_loss: 15942.8633 - 284ms/epoch - 41ms/step
# Epoch 172/1000
#
# Epoch 172: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 777683.1250 - val_loss: 61720.8906 - 244ms/epoch - 35ms/step
# Epoch 173/1000
#
# Epoch 173: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 865860.6250 - val_loss: 395310.1875 - 247ms/epoch - 35ms/step
# Epoch 174/1000
#
# Epoch 174: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 979319.3750 - val_loss: 22832.5293 - 239ms/epoch - 34ms/step
# Epoch 175/1000
#
# Epoch 175: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 973901.8125 - val_loss: 7771.4419 - 269ms/epoch - 38ms/step
# Epoch 176/1000
#
# Epoch 176: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 959060.6875 - val_loss: 256549.1875 - 237ms/epoch - 34ms/step
# Epoch 177/1000
#
# Epoch 177: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 884925.9375 - val_loss: 24437.9082 - 273ms/epoch - 39ms/step
# Epoch 178/1000
#
# Epoch 178: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 942720.8750 - val_loss: 175685.3594 - 258ms/epoch - 37ms/step
# Epoch 179/1000
#
# Epoch 179: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 908683.0000 - val_loss: 399343.1250 - 248ms/epoch - 35ms/step
# Epoch 180/1000
#
# Epoch 180: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 931456.5000 - val_loss: 3666.2590 - 257ms/epoch - 37ms/step
# Epoch 181/1000
#
# Epoch 181: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 862291.7500 - val_loss: 248315.3125 - 276ms/epoch - 39ms/step
# Epoch 182/1000
#
# Epoch 182: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 850362.9375 - val_loss: 5706.3013 - 292ms/epoch - 42ms/step
# Epoch 183/1000
#
# Epoch 183: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 822263.5625 - val_loss: 26362.0996 - 259ms/epoch - 37ms/step
# Epoch 184/1000
#
# Epoch 184: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 866833.9375 - val_loss: 94713.6562 - 257ms/epoch - 37ms/step
# Epoch 185/1000
#
# Epoch 185: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 750803.6250 - val_loss: 7936.1431 - 292ms/epoch - 42ms/step
# Epoch 186/1000
#
# Epoch 186: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 977021.5000 - val_loss: 111594.1172 - 267ms/epoch - 38ms/step
# Epoch 187/1000
#
# Epoch 187: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 845147.8750 - val_loss: 54207.5195 - 275ms/epoch - 39ms/step
# Epoch 188/1000
#
# Epoch 188: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 823259.5625 - val_loss: 57796.4297 - 268ms/epoch - 38ms/step
# Epoch 189/1000
#
# Epoch 189: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 739479.8125 - val_loss: 109237.6875 - 263ms/epoch - 38ms/step
# Epoch 190/1000
#
# Epoch 190: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 804181.1875 - val_loss: 51659.5000 - 294ms/epoch - 42ms/step
# Epoch 191/1000
#
# Epoch 191: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 798079.0000 - val_loss: 122066.2578 - 261ms/epoch - 37ms/step
# Epoch 192/1000
#
# Epoch 192: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 794371.2500 - val_loss: 42708.5312 - 254ms/epoch - 36ms/step
# Epoch 193/1000
#
# Epoch 193: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 836874.7500 - val_loss: 12710.3096 - 282ms/epoch - 40ms/step
# Epoch 194/1000
#
# Epoch 194: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 752191.8750 - val_loss: 178196.3594 - 304ms/epoch - 43ms/step
# Epoch 195/1000
#
# Epoch 195: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 774227.3125 - val_loss: 43885.4766 - 265ms/epoch - 38ms/step
# Epoch 196/1000
#
# Epoch 196: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 806477.8125 - val_loss: 45667.4102 - 272ms/epoch - 39ms/step
# Epoch 197/1000
#
# Epoch 197: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 778141.3125 - val_loss: 60852.0898 - 285ms/epoch - 41ms/step
# Epoch 198/1000
#
# Epoch 198: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 744917.6250 - val_loss: 11755.2246 - 256ms/epoch - 37ms/step
# Epoch 199/1000
#
# Epoch 199: val_loss did not improve from 2907.32495
# 7/7 - 0s - loss: 829241.9375 - val_loss: 137267.1875 - 371ms/epoch - 53ms/step
# Epoch 200/1000
#
# Epoch 200: val_loss did not improve from 2907.32495
# 7/7 - 1s - loss: 776275.2500 - val_loss: 18521.9492 - 516ms/epoch - 74ms/step
# Epoch 201/1000
#
# Epoch 201: val_loss did not improve from 2907.32495
# 7/7 - 1s - loss: 734191.5625 - val_loss: 48241.3711 - 527ms/epoch - 75ms/step
# Epoch 202/1000
#
# Epoch 202: val_loss improved from 2907.32495 to 2712.38696, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 732316.6250 - val_loss: 2712.3870 - 799ms/epoch - 114ms/step
# Epoch 203/1000
#
# Epoch 203: val_loss did not improve from 2712.38696
# 7/7 - 0s - loss: 887027.8750 - val_loss: 64228.4414 - 491ms/epoch - 70ms/step
# Epoch 204/1000
#
# Epoch 204: val_loss did not improve from 2712.38696
# 7/7 - 0s - loss: 819421.7500 - val_loss: 140843.9062 - 394ms/epoch - 56ms/step
# Epoch 205/1000
#
# Epoch 205: val_loss did not improve from 2712.38696
# 7/7 - 0s - loss: 761686.5625 - val_loss: 49932.6016 - 497ms/epoch - 71ms/step
# Epoch 206/1000
#
# Epoch 206: val_loss did not improve from 2712.38696
# 7/7 - 0s - loss: 983344.3750 - val_loss: 231058.8750 - 495ms/epoch - 71ms/step
# Epoch 207/1000
#
# Epoch 207: val_loss did not improve from 2712.38696
# 7/7 - 0s - loss: 828362.3750 - val_loss: 75299.5234 - 443ms/epoch - 63ms/step
# Epoch 208/1000
#
# Epoch 208: val_loss did not improve from 2712.38696
# 7/7 - 1s - loss: 827695.8125 - val_loss: 95948.2734 - 547ms/epoch - 78ms/step
# Epoch 209/1000
#
# Epoch 209: val_loss did not improve from 2712.38696
# 7/7 - 0s - loss: 789669.2500 - val_loss: 54128.0312 - 472ms/epoch - 67ms/step
# Epoch 210/1000
#
# Epoch 210: val_loss did not improve from 2712.38696
# 7/7 - 0s - loss: 839640.8125 - val_loss: 122015.3594 - 380ms/epoch - 54ms/step
# Epoch 211/1000
#
# Epoch 211: val_loss did not improve from 2712.38696
# 7/7 - 0s - loss: 831889.3125 - val_loss: 82518.4922 - 312ms/epoch - 45ms/step
# Epoch 212/1000
#
# Epoch 212: val_loss did not improve from 2712.38696
# 7/7 - 0s - loss: 821481.2500 - val_loss: 59467.3555 - 262ms/epoch - 37ms/step
# Epoch 213/1000
#
# Epoch 213: val_loss did not improve from 2712.38696
# 7/7 - 0s - loss: 709180.4375 - val_loss: 58472.6406 - 237ms/epoch - 34ms/step
# Epoch 214/1000
#
# Epoch 214: val_loss did not improve from 2712.38696
# 7/7 - 0s - loss: 742463.6250 - val_loss: 23061.6133 - 245ms/epoch - 35ms/step
# Epoch 215/1000
#
# Epoch 215: val_loss did not improve from 2712.38696
# 7/7 - 0s - loss: 847858.0000 - val_loss: 5048.9902 - 257ms/epoch - 37ms/step
# Epoch 216/1000
#
# Epoch 216: val_loss did not improve from 2712.38696
# 7/7 - 0s - loss: 808473.3750 - val_loss: 42455.0156 - 256ms/epoch - 37ms/step
# Epoch 217/1000
#
# Epoch 217: val_loss did not improve from 2712.38696
# 7/7 - 0s - loss: 889403.7500 - val_loss: 64856.1094 - 244ms/epoch - 35ms/step
# Epoch 218/1000
#
# Epoch 218: val_loss did not improve from 2712.38696
# 7/7 - 0s - loss: 742819.3750 - val_loss: 8334.4824 - 247ms/epoch - 35ms/step
# Epoch 219/1000
#
# Epoch 219: val_loss did not improve from 2712.38696
# 7/7 - 0s - loss: 815189.2500 - val_loss: 89882.4219 - 234ms/epoch - 33ms/step
# Epoch 220/1000
#
# Epoch 220: val_loss did not improve from 2712.38696
# 7/7 - 0s - loss: 810509.6250 - val_loss: 53433.8789 - 262ms/epoch - 37ms/step
# Epoch 221/1000
#
# Epoch 221: val_loss did not improve from 2712.38696
# 7/7 - 0s - loss: 762350.4375 - val_loss: 43327.0156 - 233ms/epoch - 33ms/step
# Epoch 222/1000
#
# Epoch 222: val_loss did not improve from 2712.38696
# 7/7 - 0s - loss: 799771.6875 - val_loss: 189789.3594 - 246ms/epoch - 35ms/step
# Epoch 223/1000
#
# Epoch 223: val_loss did not improve from 2712.38696
# 7/7 - 0s - loss: 803262.5625 - val_loss: 75638.6172 - 237ms/epoch - 34ms/step
# Epoch 224/1000
#
# Epoch 224: val_loss did not improve from 2712.38696
# 7/7 - 0s - loss: 778148.4375 - val_loss: 115034.1484 - 232ms/epoch - 33ms/step
# Epoch 225/1000
#
# Epoch 225: val_loss did not improve from 2712.38696
# 7/7 - 0s - loss: 709272.3125 - val_loss: 40888.7852 - 234ms/epoch - 33ms/step
# Epoch 226/1000
#
# Epoch 226: val_loss did not improve from 2712.38696
# 7/7 - 0s - loss: 846841.4375 - val_loss: 117258.0391 - 247ms/epoch - 35ms/step
# Epoch 227/1000
#
# Epoch 227: val_loss did not improve from 2712.38696
# 7/7 - 0s - loss: 798579.3125 - val_loss: 7388.8838 - 221ms/epoch - 32ms/step
# Epoch 228/1000
#
# Epoch 228: val_loss did not improve from 2712.38696
# 7/7 - 0s - loss: 802972.5625 - val_loss: 57573.6211 - 227ms/epoch - 32ms/step
# Epoch 229/1000
#
# Epoch 229: val_loss did not improve from 2712.38696
# 7/7 - 0s - loss: 831744.5625 - val_loss: 59938.3047 - 230ms/epoch - 33ms/step
# Epoch 230/1000
#
# Epoch 230: val_loss did not improve from 2712.38696
# 7/7 - 0s - loss: 754382.6875 - val_loss: 36642.1211 - 251ms/epoch - 36ms/step
# Epoch 231/1000
#
# Epoch 231: val_loss did not improve from 2712.38696
# 7/7 - 0s - loss: 811569.7500 - val_loss: 22484.2695 - 224ms/epoch - 32ms/step
# Epoch 232/1000
#
# Epoch 232: val_loss did not improve from 2712.38696
# 7/7 - 0s - loss: 733076.3750 - val_loss: 76097.6484 - 252ms/epoch - 36ms/step
# Epoch 233/1000
#
# Epoch 233: val_loss did not improve from 2712.38696
# 7/7 - 0s - loss: 743077.3750 - val_loss: 96692.2500 - 260ms/epoch - 37ms/step
# Epoch 234/1000
#
# Epoch 234: val_loss did not improve from 2712.38696
# 7/7 - 0s - loss: 717148.1875 - val_loss: 69884.5938 - 239ms/epoch - 34ms/step
# Epoch 235/1000
#
# Epoch 235: val_loss did not improve from 2712.38696
# 7/7 - 0s - loss: 778633.5625 - val_loss: 61323.1445 - 234ms/epoch - 33ms/step
# Epoch 236/1000
#
# Epoch 236: val_loss did not improve from 2712.38696
# 7/7 - 0s - loss: 834867.4375 - val_loss: 48298.7500 - 249ms/epoch - 36ms/step
# Epoch 237/1000
#
# Epoch 237: val_loss did not improve from 2712.38696
# 7/7 - 0s - loss: 777268.5625 - val_loss: 159269.9688 - 226ms/epoch - 32ms/step
# Epoch 238/1000
#
# Epoch 238: val_loss did not improve from 2712.38696
# 7/7 - 0s - loss: 768309.8125 - val_loss: 4398.3257 - 233ms/epoch - 33ms/step
# Epoch 239/1000
#
# Epoch 239: val_loss did not improve from 2712.38696
# 7/7 - 0s - loss: 739937.8750 - val_loss: 88541.3984 - 221ms/epoch - 32ms/step
# Epoch 240/1000
#
# Epoch 240: val_loss did not improve from 2712.38696
# 7/7 - 0s - loss: 782690.5000 - val_loss: 2839.0271 - 252ms/epoch - 36ms/step
# Epoch 241/1000
#
# Epoch 241: val_loss improved from 2712.38696 to 2588.06348, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 0s - loss: 802991.3750 - val_loss: 2588.0635 - 462ms/epoch - 66ms/step
# Epoch 242/1000
#
# Epoch 242: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 721712.6250 - val_loss: 59137.6016 - 251ms/epoch - 36ms/step
# Epoch 243/1000
#
# Epoch 243: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 848089.5625 - val_loss: 101792.9219 - 234ms/epoch - 33ms/step
# Epoch 244/1000
#
# Epoch 244: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 789315.1875 - val_loss: 42410.4492 - 251ms/epoch - 36ms/step
# Epoch 245/1000
#
# Epoch 245: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 764892.1250 - val_loss: 223984.3438 - 237ms/epoch - 34ms/step
# Epoch 246/1000
#
# Epoch 246: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 806689.3750 - val_loss: 3593.7134 - 237ms/epoch - 34ms/step
# Epoch 247/1000
#
# Epoch 247: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 959534.9375 - val_loss: 129295.3281 - 228ms/epoch - 33ms/step
# Epoch 248/1000
#
# Epoch 248: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 815899.2500 - val_loss: 5133.6689 - 253ms/epoch - 36ms/step
# Epoch 249/1000
#
# Epoch 249: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 760517.5625 - val_loss: 50337.5195 - 247ms/epoch - 35ms/step
# Epoch 250/1000
#
# Epoch 250: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 815998.1875 - val_loss: 77428.9766 - 262ms/epoch - 37ms/step
# Epoch 251/1000
#
# Epoch 251: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 828606.1250 - val_loss: 66069.8906 - 412ms/epoch - 59ms/step
# Epoch 252/1000
#
# Epoch 252: val_loss did not improve from 2588.06348
# 7/7 - 1s - loss: 819977.2500 - val_loss: 162664.6094 - 532ms/epoch - 76ms/step
# Epoch 253/1000
#
# Epoch 253: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 686942.0625 - val_loss: 102681.8828 - 446ms/epoch - 64ms/step
# Epoch 254/1000
#
# Epoch 254: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 825478.6875 - val_loss: 82522.8828 - 471ms/epoch - 67ms/step
# Epoch 255/1000
#
# Epoch 255: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 681719.0000 - val_loss: 24462.6621 - 481ms/epoch - 69ms/step
# Epoch 256/1000
#
# Epoch 256: val_loss did not improve from 2588.06348
# 7/7 - 1s - loss: 729479.6250 - val_loss: 32686.5293 - 501ms/epoch - 72ms/step
# Epoch 257/1000
#
# Epoch 257: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 696301.1875 - val_loss: 104156.1875 - 494ms/epoch - 71ms/step
# Epoch 258/1000
#
# Epoch 258: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 804831.6250 - val_loss: 58502.3203 - 463ms/epoch - 66ms/step
# Epoch 259/1000
#
# Epoch 259: val_loss did not improve from 2588.06348
# 7/7 - 1s - loss: 841223.0000 - val_loss: 105507.8828 - 510ms/epoch - 73ms/step
# Epoch 260/1000
#
# Epoch 260: val_loss did not improve from 2588.06348
# 7/7 - 1s - loss: 803808.7500 - val_loss: 134405.2656 - 524ms/epoch - 75ms/step
# Epoch 261/1000
#
# Epoch 261: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 803051.2500 - val_loss: 37264.0547 - 453ms/epoch - 65ms/step
# Epoch 262/1000
#
# Epoch 262: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 838370.1875 - val_loss: 118128.9219 - 485ms/epoch - 69ms/step
# Epoch 263/1000
#
# Epoch 263: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 765834.3750 - val_loss: 40694.8945 - 247ms/epoch - 35ms/step
# Epoch 264/1000
#
# Epoch 264: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 804014.1250 - val_loss: 73771.9375 - 268ms/epoch - 38ms/step
# Epoch 265/1000
#
# Epoch 265: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 830741.9375 - val_loss: 59408.0703 - 242ms/epoch - 35ms/step
# Epoch 266/1000
#
# Epoch 266: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 843226.7500 - val_loss: 74737.3203 - 233ms/epoch - 33ms/step
# Epoch 267/1000
#
# Epoch 267: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 786140.8125 - val_loss: 72416.5000 - 238ms/epoch - 34ms/step
# Epoch 268/1000
#
# Epoch 268: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 818376.7500 - val_loss: 49022.6211 - 235ms/epoch - 34ms/step
# Epoch 269/1000
#
# Epoch 269: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 764383.4375 - val_loss: 20917.1973 - 238ms/epoch - 34ms/step
# Epoch 270/1000
#
# Epoch 270: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 825146.1875 - val_loss: 53228.8984 - 239ms/epoch - 34ms/step
# Epoch 271/1000
#
# Epoch 271: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 782149.3750 - val_loss: 36658.9609 - 234ms/epoch - 33ms/step
# Epoch 272/1000
#
# Epoch 272: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 872474.8125 - val_loss: 15455.2129 - 251ms/epoch - 36ms/step
# Epoch 273/1000
#
# Epoch 273: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 756809.7500 - val_loss: 98688.2969 - 244ms/epoch - 35ms/step
# Epoch 274/1000
#
# Epoch 274: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 754986.0625 - val_loss: 18788.4316 - 259ms/epoch - 37ms/step
# Epoch 275/1000
#
# Epoch 275: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 763963.5625 - val_loss: 29631.1641 - 228ms/epoch - 33ms/step
# Epoch 276/1000
#
# Epoch 276: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 841212.8750 - val_loss: 145646.4062 - 249ms/epoch - 36ms/step
# Epoch 277/1000
#
# Epoch 277: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 757221.7500 - val_loss: 73021.2031 - 265ms/epoch - 38ms/step
# Epoch 278/1000
#
# Epoch 278: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 741398.9375 - val_loss: 24391.6953 - 243ms/epoch - 35ms/step
# Epoch 279/1000
#
# Epoch 279: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 761246.4375 - val_loss: 61178.0703 - 242ms/epoch - 35ms/step
# Epoch 280/1000
#
# Epoch 280: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 771188.2500 - val_loss: 46345.9336 - 246ms/epoch - 35ms/step
# Epoch 281/1000
#
# Epoch 281: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 751860.4375 - val_loss: 95236.4375 - 237ms/epoch - 34ms/step
# Epoch 282/1000
#
# Epoch 282: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 854604.0625 - val_loss: 121095.4219 - 230ms/epoch - 33ms/step
# Epoch 283/1000
#
# Epoch 283: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 830744.5000 - val_loss: 20861.9902 - 238ms/epoch - 34ms/step
# Epoch 284/1000
#
# Epoch 284: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 777923.6250 - val_loss: 29822.9473 - 262ms/epoch - 37ms/step
# Epoch 285/1000
#
# Epoch 285: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 861513.1250 - val_loss: 102617.2266 - 251ms/epoch - 36ms/step
# Epoch 286/1000
#
# Epoch 286: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 761246.2500 - val_loss: 123419.2188 - 306ms/epoch - 44ms/step
# Epoch 287/1000
#
# Epoch 287: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 786118.9375 - val_loss: 4492.9604 - 432ms/epoch - 62ms/step
# Epoch 288/1000
#
# Epoch 288: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 847998.4375 - val_loss: 95009.6875 - 254ms/epoch - 36ms/step
# Epoch 289/1000
#
# Epoch 289: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 881622.2500 - val_loss: 81499.3828 - 229ms/epoch - 33ms/step
# Epoch 290/1000
#
# Epoch 290: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 781357.8125 - val_loss: 2618.0298 - 256ms/epoch - 37ms/step
# Epoch 291/1000
#
# Epoch 291: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 796041.8125 - val_loss: 152934.0625 - 270ms/epoch - 39ms/step
# Epoch 292/1000
#
# Epoch 292: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 739988.7500 - val_loss: 48318.9102 - 254ms/epoch - 36ms/step
# Epoch 293/1000
#
# Epoch 293: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 765618.5000 - val_loss: 15989.0352 - 233ms/epoch - 33ms/step
# Epoch 294/1000
#
# Epoch 294: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 817373.5000 - val_loss: 45944.2500 - 230ms/epoch - 33ms/step
# Epoch 295/1000
#
# Epoch 295: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 767697.3125 - val_loss: 13790.1826 - 254ms/epoch - 36ms/step
# Epoch 296/1000
#
# Epoch 296: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 798921.6875 - val_loss: 54042.8008 - 256ms/epoch - 37ms/step
# Epoch 297/1000
#
# Epoch 297: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 761319.8125 - val_loss: 15002.2441 - 255ms/epoch - 36ms/step
# Epoch 298/1000
#
# Epoch 298: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 783097.7500 - val_loss: 91850.4766 - 261ms/epoch - 37ms/step
# Epoch 299/1000
#
# Epoch 299: val_loss did not improve from 2588.06348
# ...
# Epoch 893/1000
#
# Epoch 893: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 671142.2500 - val_loss: 65324.1445 - 248ms/epoch - 35ms/step
# Epoch 894/1000
#
# Epoch 894: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 655575.4375 - val_loss: 15263.2773 - 245ms/epoch - 35ms/step
# Epoch 895/1000
#
# Epoch 895: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 699930.3750 - val_loss: 28860.7949 - 253ms/epoch - 36ms/step
# Epoch 896/1000
#
# Epoch 896: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 715419.3750 - val_loss: 74398.2969 - 293ms/epoch - 42ms/step
# Epoch 897/1000
#
# Epoch 897: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 752905.8125 - val_loss: 19789.4922 - 261ms/epoch - 37ms/step
# Epoch 898/1000
#
# Epoch 898: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 691578.8750 - val_loss: 93919.3438 - 259ms/epoch - 37ms/step
# Epoch 899/1000
#
# Epoch 899: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 685744.0000 - val_loss: 16031.9551 - 275ms/epoch - 39ms/step
# Epoch 900/1000
#
# Epoch 900: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 719877.5000 - val_loss: 158230.0781 - 281ms/epoch - 40ms/step
# Epoch 901/1000
#
# Epoch 901: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 780162.9375 - val_loss: 55659.5312 - 284ms/epoch - 41ms/step
# Epoch 902/1000
#
# Epoch 902: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 717638.0000 - val_loss: 77538.6562 - 292ms/epoch - 42ms/step
# Epoch 903/1000
#
# Epoch 903: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 817877.9375 - val_loss: 51537.7812 - 310ms/epoch - 44ms/step
# Epoch 904/1000
#
# Epoch 904: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 656110.2500 - val_loss: 35668.1914 - 279ms/epoch - 40ms/step
# Epoch 905/1000
#
# Epoch 905: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 678735.2500 - val_loss: 47731.9219 - 294ms/epoch - 42ms/step
# Epoch 906/1000
#
# Epoch 906: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 651333.7500 - val_loss: 38425.5391 - 281ms/epoch - 40ms/step
# Epoch 907/1000
#
# Epoch 907: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 684101.6250 - val_loss: 13981.0078 - 294ms/epoch - 42ms/step
# Epoch 908/1000
#
# Epoch 908: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 704669.0000 - val_loss: 20250.1895 - 273ms/epoch - 39ms/step
# Epoch 909/1000
#
# Epoch 909: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 707942.7500 - val_loss: 35034.3750 - 293ms/epoch - 42ms/step
# Epoch 910/1000
#
# Epoch 910: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 695474.0625 - val_loss: 50341.5781 - 284ms/epoch - 41ms/step
# Epoch 911/1000
#
# Epoch 911: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 687721.8750 - val_loss: 88688.7422 - 264ms/epoch - 38ms/step
# Epoch 912/1000
#
# Epoch 912: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 674479.1250 - val_loss: 41506.8164 - 280ms/epoch - 40ms/step
# Epoch 913/1000
#
# Epoch 913: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 694949.3750 - val_loss: 103769.5312 - 306ms/epoch - 44ms/step
# Epoch 914/1000
#
# Epoch 914: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 683292.5625 - val_loss: 8927.6045 - 415ms/epoch - 59ms/step
# Epoch 915/1000
#
# Epoch 915: val_loss did not improve from 2588.06348
# 7/7 - 1s - loss: 713482.8750 - val_loss: 141720.0469 - 521ms/epoch - 74ms/step
# Epoch 916/1000
#
# Epoch 916: val_loss did not improve from 2588.06348
# 7/7 - 1s - loss: 789535.2500 - val_loss: 24246.5098 - 558ms/epoch - 80ms/step
# Epoch 917/1000
#
# Epoch 917: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 730850.0625 - val_loss: 38296.5586 - 489ms/epoch - 70ms/step
# Epoch 918/1000
#
# Epoch 918: val_loss did not improve from 2588.06348
# 7/7 - 1s - loss: 676219.1875 - val_loss: 118560.3672 - 504ms/epoch - 72ms/step
# Epoch 919/1000
#
# Epoch 919: val_loss did not improve from 2588.06348
# 7/7 - 1s - loss: 708717.5000 - val_loss: 29440.0449 - 516ms/epoch - 74ms/step
# Epoch 920/1000
#
# Epoch 920: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 640114.8750 - val_loss: 69660.7266 - 499ms/epoch - 71ms/step
# Epoch 921/1000
#
# Epoch 921: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 610792.8125 - val_loss: 58892.1289 - 489ms/epoch - 70ms/step
# Epoch 922/1000
#
# Epoch 922: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 612002.6875 - val_loss: 34288.1836 - 448ms/epoch - 64ms/step
# Epoch 923/1000
#
# Epoch 923: val_loss did not improve from 2588.06348
# 7/7 - 1s - loss: 691862.9375 - val_loss: 42900.0391 - 525ms/epoch - 75ms/step
# Epoch 924/1000
#
# Epoch 924: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 677802.3750 - val_loss: 39864.4844 - 412ms/epoch - 59ms/step
# Epoch 925/1000
#
# Epoch 925: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 786943.0000 - val_loss: 44799.6094 - 491ms/epoch - 70ms/step
# Epoch 926/1000
#
# Epoch 926: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 725223.1250 - val_loss: 14116.2773 - 445ms/epoch - 64ms/step
# Epoch 927/1000
#
# Epoch 927: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 700169.0625 - val_loss: 28405.6094 - 236ms/epoch - 34ms/step
# Epoch 928/1000
#
# Epoch 928: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 751526.7500 - val_loss: 34693.4688 - 270ms/epoch - 39ms/step
# Epoch 929/1000
#
# Epoch 929: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 629657.8750 - val_loss: 58679.6719 - 246ms/epoch - 35ms/step
# Epoch 930/1000
#
# Epoch 930: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 674827.9375 - val_loss: 84137.8672 - 265ms/epoch - 38ms/step
# Epoch 931/1000
#
# Epoch 931: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 702508.1250 - val_loss: 74146.7734 - 239ms/epoch - 34ms/step
# Epoch 932/1000
#
# Epoch 932: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 739174.0000 - val_loss: 178128.0000 - 272ms/epoch - 39ms/step
# Epoch 933/1000
#
# Epoch 933: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 656038.7500 - val_loss: 15634.2715 - 233ms/epoch - 33ms/step
# Epoch 934/1000
#
# Epoch 934: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 723511.3750 - val_loss: 105576.7266 - 263ms/epoch - 38ms/step
# Epoch 935/1000
#
# Epoch 935: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 760663.3750 - val_loss: 38799.8945 - 251ms/epoch - 36ms/step
# Epoch 936/1000
#
# Epoch 936: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 581474.8125 - val_loss: 34787.4336 - 238ms/epoch - 34ms/step
# Epoch 937/1000
#
# Epoch 937: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 679196.8750 - val_loss: 36295.4609 - 239ms/epoch - 34ms/step
# Epoch 938/1000
#
# Epoch 938: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 755160.3125 - val_loss: 51083.5703 - 298ms/epoch - 43ms/step
# Epoch 939/1000
#
# Epoch 939: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 672306.0000 - val_loss: 18324.2617 - 257ms/epoch - 37ms/step
# Epoch 940/1000
#
# Epoch 940: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 673675.9375 - val_loss: 61468.5938 - 254ms/epoch - 36ms/step
# Epoch 941/1000
#
# Epoch 941: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 696594.3750 - val_loss: 58568.0391 - 277ms/epoch - 40ms/step
# Epoch 942/1000
#
# Epoch 942: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 665526.1875 - val_loss: 92118.5781 - 283ms/epoch - 40ms/step
# Epoch 943/1000
#
# Epoch 943: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 677203.6875 - val_loss: 69832.8125 - 254ms/epoch - 36ms/step
# Epoch 944/1000
#
# Epoch 944: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 660014.1250 - val_loss: 37313.0312 - 248ms/epoch - 35ms/step
# Epoch 945/1000
#
# Epoch 945: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 719446.5000 - val_loss: 47238.7188 - 269ms/epoch - 38ms/step
# Epoch 946/1000
#
# Epoch 946: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 731543.0000 - val_loss: 47379.2305 - 252ms/epoch - 36ms/step
# Epoch 947/1000
#
# Epoch 947: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 777359.2500 - val_loss: 50089.5547 - 245ms/epoch - 35ms/step
# Epoch 948/1000
#
# Epoch 948: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 695108.3125 - val_loss: 29396.6094 - 253ms/epoch - 36ms/step
# Epoch 949/1000
#
# Epoch 949: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 644310.0000 - val_loss: 78706.6484 - 251ms/epoch - 36ms/step
# Epoch 950/1000
#
# Epoch 950: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 644614.5625 - val_loss: 89908.9922 - 259ms/epoch - 37ms/step
# Epoch 951/1000
#
# Epoch 951: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 623021.9375 - val_loss: 19149.7578 - 271ms/epoch - 39ms/step
# Epoch 952/1000
#
# Epoch 952: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 715377.8750 - val_loss: 92674.8828 - 256ms/epoch - 37ms/step
# Epoch 953/1000
#
# Epoch 953: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 714706.8750 - val_loss: 9029.1758 - 262ms/epoch - 37ms/step
# Epoch 954/1000
#
# Epoch 954: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 681403.8125 - val_loss: 55210.3359 - 252ms/epoch - 36ms/step
# Epoch 955/1000
#
# Epoch 955: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 811425.5625 - val_loss: 17472.6875 - 231ms/epoch - 33ms/step
# Epoch 956/1000
#
# Epoch 956: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 714832.0625 - val_loss: 62721.2734 - 243ms/epoch - 35ms/step
# Epoch 957/1000
#
# Epoch 957: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 687766.1875 - val_loss: 12750.0996 - 238ms/epoch - 34ms/step
# Epoch 958/1000
#
# Epoch 958: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 767442.0000 - val_loss: 64341.3789 - 226ms/epoch - 32ms/step
# Epoch 959/1000
#
# Epoch 959: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 693606.0625 - val_loss: 15104.9561 - 240ms/epoch - 34ms/step
# Epoch 960/1000
#
# Epoch 960: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 800220.5625 - val_loss: 128710.6406 - 234ms/epoch - 33ms/step
# Epoch 961/1000
#
# Epoch 961: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 744492.2500 - val_loss: 27070.2051 - 256ms/epoch - 37ms/step
# Epoch 962/1000
#
# Epoch 962: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 612857.8750 - val_loss: 30474.0723 - 243ms/epoch - 35ms/step
# Epoch 963/1000
#
# Epoch 963: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 693592.1875 - val_loss: 70920.2188 - 261ms/epoch - 37ms/step
# Epoch 964/1000
#
# Epoch 964: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 711924.0625 - val_loss: 30348.8496 - 253ms/epoch - 36ms/step
# Epoch 965/1000
#
# Epoch 965: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 702016.3125 - val_loss: 16757.5918 - 349ms/epoch - 50ms/step
# Epoch 966/1000
#
# Epoch 966: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 659719.6250 - val_loss: 57620.9531 - 447ms/epoch - 64ms/step
# Epoch 967/1000
#
# Epoch 967: val_loss did not improve from 2588.06348
# 7/7 - 1s - loss: 654517.0000 - val_loss: 110438.2188 - 512ms/epoch - 73ms/step
# Epoch 968/1000
#
# Epoch 968: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 774491.3125 - val_loss: 22422.9473 - 483ms/epoch - 69ms/step
# Epoch 969/1000
#
# Epoch 969: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 657354.9375 - val_loss: 83085.6562 - 499ms/epoch - 71ms/step
# Epoch 970/1000
#
# Epoch 970: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 638862.9375 - val_loss: 19022.7070 - 445ms/epoch - 64ms/step
# Epoch 971/1000
#
# Epoch 971: val_loss did not improve from 2588.06348
# 7/7 - 1s - loss: 740678.1875 - val_loss: 95503.5234 - 505ms/epoch - 72ms/step
# Epoch 972/1000
#
# Epoch 972: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 725147.6875 - val_loss: 46858.4766 - 487ms/epoch - 70ms/step
# Epoch 973/1000
#
# Epoch 973: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 758941.5625 - val_loss: 4535.3130 - 422ms/epoch - 60ms/step
# Epoch 974/1000
#
# Epoch 974: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 703083.8750 - val_loss: 97298.9688 - 477ms/epoch - 68ms/step
# Epoch 975/1000
#
# Epoch 975: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 639551.8125 - val_loss: 45156.2031 - 495ms/epoch - 71ms/step
# Epoch 976/1000
#
# Epoch 976: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 677893.6875 - val_loss: 92021.6484 - 497ms/epoch - 71ms/step
# Epoch 977/1000
#
# Epoch 977: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 639777.6875 - val_loss: 82335.7188 - 458ms/epoch - 65ms/step
# Epoch 978/1000
#
# Epoch 978: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 671592.0000 - val_loss: 4957.1162 - 248ms/epoch - 35ms/step
# Epoch 979/1000
#
# Epoch 979: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 722290.5000 - val_loss: 93505.1484 - 269ms/epoch - 38ms/step
# Epoch 980/1000
#
# Epoch 980: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 728358.1875 - val_loss: 11311.7998 - 249ms/epoch - 36ms/step
# Epoch 981/1000
#
# Epoch 981: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 728496.7500 - val_loss: 39074.7695 - 245ms/epoch - 35ms/step
# Epoch 982/1000
#
# Epoch 982: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 663890.2500 - val_loss: 49300.7734 - 265ms/epoch - 38ms/step
# Epoch 983/1000
#
# Epoch 983: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 638205.0000 - val_loss: 33036.6602 - 282ms/epoch - 40ms/step
# Epoch 984/1000
#
# Epoch 984: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 717094.1250 - val_loss: 68295.8828 - 239ms/epoch - 34ms/step
# Epoch 985/1000
#
# Epoch 985: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 701960.3750 - val_loss: 30588.8105 - 244ms/epoch - 35ms/step
# Epoch 986/1000
#
# Epoch 986: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 689942.8750 - val_loss: 91901.1406 - 262ms/epoch - 37ms/step
# Epoch 987/1000
#
# Epoch 987: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 791118.3125 - val_loss: 87553.0000 - 295ms/epoch - 42ms/step
# Epoch 988/1000
#
# Epoch 988: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 771715.8750 - val_loss: 108067.9375 - 253ms/epoch - 36ms/step
# Epoch 989/1000
#
# Epoch 989: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 757506.8125 - val_loss: 118796.5781 - 238ms/epoch - 34ms/step
# Epoch 990/1000
#
# Epoch 990: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 707400.3750 - val_loss: 19251.6445 - 257ms/epoch - 37ms/step
# Epoch 991/1000
#
# Epoch 991: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 660108.6875 - val_loss: 58535.4297 - 262ms/epoch - 37ms/step
# Epoch 992/1000
#
# Epoch 992: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 659206.2500 - val_loss: 44906.2734 - 253ms/epoch - 36ms/step
# Epoch 993/1000
#
# Epoch 993: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 688188.6875 - val_loss: 9990.6953 - 230ms/epoch - 33ms/step
# Epoch 994/1000
#
# Epoch 994: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 686201.0000 - val_loss: 83316.8906 - 238ms/epoch - 34ms/step
# Epoch 995/1000
#
# Epoch 995: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 640443.1250 - val_loss: 23355.0195 - 249ms/epoch - 36ms/step
# Epoch 996/1000
#
# Epoch 996: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 736871.2500 - val_loss: 79285.2656 - 253ms/epoch - 36ms/step
# Epoch 997/1000
#
# Epoch 997: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 716491.2500 - val_loss: 23139.6055 - 232ms/epoch - 33ms/step
# Epoch 998/1000
#
# Epoch 998: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 602918.8750 - val_loss: 43139.6367 - 250ms/epoch - 36ms/step
# Epoch 999/1000
#
# Epoch 999: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 677705.3750 - val_loss: 45203.5586 - 233ms/epoch - 33ms/step
# Epoch 1000/1000
#
# Epoch 1000: val_loss did not improve from 2588.06348
# 7/7 - 0s - loss: 724033.4375 - val_loss: 48628.4141 - 258ms/epoch - 37ms/step
# 16/16 [==============================] - 1s 6ms/step
# 3/3 [==============================] - 0s 16ms/step
# Training MSE: 19209.799
# Testing MSE: 2217.799
# Training MAPE: 3.981%
# Testing MAPE: 1.503%
# accuracy : 55

# %%
# 모델 생성
model = Sequential()
model.add(Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(units=1024, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(units=512, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(units=256, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(units=128, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(units=64, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(units=32, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(units=16, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(units=1))
model.summary()

# loss = Huber()
# optimizer = Adam(0.0005)
# model.compile(loss=Huber(), optimizer=optimizer, metrics=['mse'])

model.compile(optimizer='adam', loss='mean_squared_error')

filename = os.path.join('tmp', 'ckeckpointer.ckpt')
checkpoint = ModelCheckpoint(filename,
                             save_weights_only=True,
                             save_best_only=True,
                             monitor='val_loss',
                             verbose=1)

# 모델 학습
history = model.fit(trainX, trainY, epochs=1000, batch_size=64,
          validation_split=0.1, verbose=2,callbacks=[checkpoint])

model.save_weights('./lstm_weights.h3')

model.load_weights(filename)

plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()
plt.show()

# 예측
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# MSE 계산
trainMSE = mean_squared_error(trainY, trainPredict)
testMSE = mean_squared_error(testY, testPredict)

# MAPE 계산
trainMAPE = calculate_mape(trainY, trainPredict)
testMAPE = calculate_mape(testY, testPredict)

print(f'Training MSE: {trainMSE:.3f}')
print(f'Testing MSE: {testMSE:.3f}')
print(f'Training MAPE: {trainMAPE:.3f}%')
print(f'Testing MAPE: {testMAPE:.3f}%')

accuracy(testPredict,testY)

# 예측 시각화
plt.plot(trainY, label='Actual Price')
plt.plot(trainPredict, label='Predicted Price')
plt.legend()
plt.title('Training Data')
plt.show()

plt.plot(testY, label='Actual Price')
plt.plot(testPredict, label='Predicted Price')
plt.legend()
plt.title('Testing Data')
plt.show()
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, 3, 256)            7936
#
#  max_pooling1d_1 (MaxPoolin  (None, 1, 256)            0
#  g1D)
#
#  lstm (LSTM)                 (None, 1, 1024)           5246976
#
#  dropout_13 (Dropout)        (None, 1, 1024)           0
#
#  lstm_1 (LSTM)               (None, 1, 512)            3147776
#
#  dropout_14 (Dropout)        (None, 1, 512)            0
#
#  lstm_2 (LSTM)               (None, 1, 256)            787456
#
#  dropout_15 (Dropout)        (None, 1, 256)            0
#
#  lstm_3 (LSTM)               (None, 1, 128)            197120
#
#  dropout_16 (Dropout)        (None, 1, 128)            0
#
#  lstm_4 (LSTM)               (None, 1, 64)             49408
#
#  dropout_17 (Dropout)        (None, 1, 64)             0
#
#  lstm_5 (LSTM)               (None, 1, 32)             12416
#
#  dropout_18 (Dropout)        (None, 1, 32)             0
#
#  lstm_6 (LSTM)               (None, 16)                3136
#
#  dropout_19 (Dropout)        (None, 16)                0
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 9452241 (36.06 MB)
# Trainable params: 9452241 (36.06 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/1000
#
# Epoch 1: val_loss improved from inf to 5710932.00000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 13s - loss: 8167962.5000 - val_loss: 5710932.0000 - 13s/epoch - 2s/step
# Epoch 2/1000
#
# Epoch 2: val_loss improved from 5710932.00000 to 5710869.00000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 8167898.0000 - val_loss: 5710869.0000 - 540ms/epoch - 77ms/step
# Epoch 3/1000
#
# Epoch 3: val_loss improved from 5710869.00000 to 5700475.00000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 8167229.0000 - val_loss: 5700475.0000 - 556ms/epoch - 79ms/step
# Epoch 4/1000
#
# Epoch 4: val_loss improved from 5700475.00000 to 4832547.00000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 8015508.0000 - val_loss: 4832547.0000 - 528ms/epoch - 75ms/step
# Epoch 5/1000
#
# Epoch 5: val_loss improved from 4832547.00000 to 1515906.12500, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 6563029.0000 - val_loss: 1515906.1250 - 535ms/epoch - 76ms/step
# Epoch 6/1000
#
# Epoch 6: val_loss improved from 1515906.12500 to 1062146.37500, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 3469088.0000 - val_loss: 1062146.3750 - 658ms/epoch - 94ms/step
# Epoch 7/1000
#
# Epoch 7: val_loss improved from 1062146.37500 to 130997.02344, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 3238938.2500 - val_loss: 130997.0234 - 842ms/epoch - 120ms/step
# Epoch 8/1000
#
# Epoch 8: val_loss did not improve from 130997.02344
# 7/7 - 0s - loss: 2949750.2500 - val_loss: 237590.6250 - 403ms/epoch - 58ms/step
# Epoch 9/1000
#
# Epoch 9: val_loss improved from 130997.02344 to 17183.39453, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 3s - loss: 2714426.2500 - val_loss: 17183.3945 - 3s/epoch - 379ms/step
# Epoch 10/1000
#
# Epoch 10: val_loss did not improve from 17183.39453
# 7/7 - 0s - loss: 2470498.0000 - val_loss: 204354.6406 - 400ms/epoch - 57ms/step
# Epoch 11/1000
#
# Epoch 11: val_loss did not improve from 17183.39453
# 7/7 - 0s - loss: 2444225.2500 - val_loss: 278875.6250 - 385ms/epoch - 55ms/step
# Epoch 12/1000
#
# Epoch 12: val_loss did not improve from 17183.39453
# 7/7 - 0s - loss: 2349585.2500 - val_loss: 60527.0000 - 224ms/epoch - 32ms/step
# Epoch 13/1000
#
# Epoch 13: val_loss did not improve from 17183.39453
# 7/7 - 0s - loss: 2254416.2500 - val_loss: 98888.4375 - 216ms/epoch - 31ms/step
# Epoch 14/1000
#
# Epoch 14: val_loss did not improve from 17183.39453
# 7/7 - 0s - loss: 2009639.2500 - val_loss: 418408.2812 - 230ms/epoch - 33ms/step
# Epoch 15/1000
#
# Epoch 15: val_loss did not improve from 17183.39453
# 7/7 - 0s - loss: 1974126.2500 - val_loss: 192067.7656 - 210ms/epoch - 30ms/step
# Epoch 16/1000
#
# Epoch 16: val_loss did not improve from 17183.39453
# 7/7 - 0s - loss: 1737790.3750 - val_loss: 185237.3594 - 211ms/epoch - 30ms/step
# Epoch 17/1000
#
# Epoch 17: val_loss did not improve from 17183.39453
# 7/7 - 0s - loss: 1875636.8750 - val_loss: 214452.2031 - 221ms/epoch - 32ms/step
# Epoch 18/1000
#
# Epoch 18: val_loss did not improve from 17183.39453
# 7/7 - 0s - loss: 1740097.5000 - val_loss: 157679.1406 - 236ms/epoch - 34ms/step
# Epoch 19/1000
#
# Epoch 19: val_loss did not improve from 17183.39453
# 7/7 - 0s - loss: 1814072.7500 - val_loss: 306220.8125 - 226ms/epoch - 32ms/step
# Epoch 20/1000
#
# Epoch 20: val_loss did not improve from 17183.39453
# 7/7 - 0s - loss: 1757848.2500 - val_loss: 133213.4219 - 205ms/epoch - 29ms/step
# Epoch 21/1000
#
# Epoch 21: val_loss did not improve from 17183.39453
# 7/7 - 0s - loss: 1777045.2500 - val_loss: 319817.0938 - 212ms/epoch - 30ms/step
# Epoch 22/1000
#
# Epoch 22: val_loss did not improve from 17183.39453
# 7/7 - 0s - loss: 1675455.3750 - val_loss: 73078.1797 - 218ms/epoch - 31ms/step
# Epoch 23/1000
#
# Epoch 23: val_loss did not improve from 17183.39453
# 7/7 - 0s - loss: 1674211.0000 - val_loss: 60454.7109 - 209ms/epoch - 30ms/step
# Epoch 24/1000
#
# Epoch 24: val_loss did not improve from 17183.39453
# 7/7 - 0s - loss: 1587953.8750 - val_loss: 124723.6328 - 245ms/epoch - 35ms/step
# Epoch 25/1000
#
# Epoch 25: val_loss improved from 17183.39453 to 10793.01855, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 0s - loss: 1592002.5000 - val_loss: 10793.0186 - 489ms/epoch - 70ms/step
# Epoch 26/1000
#
# Epoch 26: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1496911.1250 - val_loss: 167142.7344 - 218ms/epoch - 31ms/step
# Epoch 27/1000
#
# Epoch 27: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1479990.7500 - val_loss: 76922.9609 - 226ms/epoch - 32ms/step
# Epoch 28/1000
#
# Epoch 28: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1344710.0000 - val_loss: 158354.5781 - 228ms/epoch - 33ms/step
# Epoch 29/1000
#
# Epoch 29: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1315560.8750 - val_loss: 145242.5938 - 215ms/epoch - 31ms/step
# Epoch 30/1000
#
# Epoch 30: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1442884.3750 - val_loss: 94201.4766 - 218ms/epoch - 31ms/step
# Epoch 31/1000
#
# Epoch 31: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1388933.3750 - val_loss: 332390.5938 - 205ms/epoch - 29ms/step
# Epoch 32/1000
#
# Epoch 32: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1194189.5000 - val_loss: 49854.7305 - 225ms/epoch - 32ms/step
# Epoch 33/1000
#
# Epoch 33: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1425272.6250 - val_loss: 438989.8438 - 217ms/epoch - 31ms/step
# Epoch 34/1000
#
# Epoch 34: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1410896.6250 - val_loss: 20136.9941 - 224ms/epoch - 32ms/step
# Epoch 35/1000
#
# Epoch 35: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1274833.0000 - val_loss: 355868.1875 - 200ms/epoch - 29ms/step
# Epoch 36/1000
#
# Epoch 36: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1254253.3750 - val_loss: 110668.1797 - 211ms/epoch - 30ms/step
# Epoch 37/1000
#
# Epoch 37: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1287217.1250 - val_loss: 330256.6562 - 232ms/epoch - 33ms/step
# Epoch 38/1000
#
# Epoch 38: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1202382.7500 - val_loss: 239502.2812 - 211ms/epoch - 30ms/step
# Epoch 39/1000
#
# Epoch 39: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1237559.6250 - val_loss: 371285.4688 - 233ms/epoch - 33ms/step
# Epoch 40/1000
#
# Epoch 40: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1238137.3750 - val_loss: 142227.5625 - 212ms/epoch - 30ms/step
# Epoch 41/1000
#
# Epoch 41: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1347102.8750 - val_loss: 122606.9609 - 234ms/epoch - 33ms/step
# Epoch 42/1000
#
# Epoch 42: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1120632.7500 - val_loss: 184326.6406 - 243ms/epoch - 35ms/step
# Epoch 43/1000
#
# Epoch 43: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1291451.2500 - val_loss: 57969.3008 - 220ms/epoch - 31ms/step
# Epoch 44/1000
#
# Epoch 44: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1167075.8750 - val_loss: 119816.2500 - 205ms/epoch - 29ms/step
# Epoch 45/1000
#
# Epoch 45: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1314805.6250 - val_loss: 25998.9883 - 209ms/epoch - 30ms/step
# Epoch 46/1000
#
# Epoch 46: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1130962.0000 - val_loss: 231966.2969 - 211ms/epoch - 30ms/step
# Epoch 47/1000
#
# Epoch 47: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1159362.6250 - val_loss: 19709.8516 - 210ms/epoch - 30ms/step
# Epoch 48/1000
#
# Epoch 48: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1286125.8750 - val_loss: 164777.3438 - 230ms/epoch - 33ms/step
# Epoch 49/1000
#
# Epoch 49: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1107108.8750 - val_loss: 22954.2598 - 226ms/epoch - 32ms/step
# Epoch 50/1000
#
# Epoch 50: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1152984.8750 - val_loss: 89696.2969 - 233ms/epoch - 33ms/step
# Epoch 51/1000
#
# Epoch 51: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1186842.1250 - val_loss: 65529.7891 - 231ms/epoch - 33ms/step
# Epoch 52/1000
#
# Epoch 52: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1009568.5625 - val_loss: 152254.5156 - 243ms/epoch - 35ms/step
# Epoch 53/1000
#
# Epoch 53: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1129653.2500 - val_loss: 54131.1094 - 236ms/epoch - 34ms/step
# Epoch 54/1000
#
# Epoch 54: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1165458.2500 - val_loss: 91240.8203 - 295ms/epoch - 42ms/step
# Epoch 55/1000
#
# Epoch 55: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1279657.2500 - val_loss: 192703.1406 - 364ms/epoch - 52ms/step
# Epoch 56/1000
#
# Epoch 56: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1185224.5000 - val_loss: 18954.0254 - 431ms/epoch - 62ms/step
# Epoch 57/1000
#
# Epoch 57: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1055140.5000 - val_loss: 149284.6250 - 466ms/epoch - 67ms/step
# Epoch 58/1000
#
# Epoch 58: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1120631.3750 - val_loss: 43502.0117 - 450ms/epoch - 64ms/step
# Epoch 59/1000
#
# Epoch 59: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1021848.8125 - val_loss: 129608.6406 - 484ms/epoch - 69ms/step
# Epoch 60/1000
#
# Epoch 60: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1119867.7500 - val_loss: 22438.7402 - 450ms/epoch - 64ms/step
# Epoch 61/1000
#
# Epoch 61: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1140966.7500 - val_loss: 156252.7656 - 425ms/epoch - 61ms/step
# Epoch 62/1000
#
# Epoch 62: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1159279.3750 - val_loss: 15600.7627 - 452ms/epoch - 65ms/step
# Epoch 63/1000
#
# Epoch 63: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1099638.0000 - val_loss: 15230.0664 - 378ms/epoch - 54ms/step
# Epoch 64/1000
#
# Epoch 64: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1216059.1250 - val_loss: 33777.1836 - 452ms/epoch - 65ms/step
# Epoch 65/1000
#
# Epoch 65: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1049937.6250 - val_loss: 71024.1328 - 406ms/epoch - 58ms/step
# Epoch 66/1000
#
# Epoch 66: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1064502.7500 - val_loss: 21764.9023 - 387ms/epoch - 55ms/step
# Epoch 67/1000
#
# Epoch 67: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1221819.6250 - val_loss: 275263.1562 - 416ms/epoch - 59ms/step
# Epoch 68/1000
#
# Epoch 68: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1123996.1250 - val_loss: 21656.6777 - 324ms/epoch - 46ms/step
# Epoch 69/1000
#
# Epoch 69: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1043937.0000 - val_loss: 162939.0000 - 222ms/epoch - 32ms/step
# Epoch 70/1000
#
# Epoch 70: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1063488.3750 - val_loss: 38763.9727 - 240ms/epoch - 34ms/step
# Epoch 71/1000
#
# Epoch 71: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1107931.2500 - val_loss: 103182.5391 - 216ms/epoch - 31ms/step
# Epoch 72/1000
#
# Epoch 72: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1073465.6250 - val_loss: 12937.8486 - 243ms/epoch - 35ms/step
# Epoch 73/1000
#
# Epoch 73: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 988190.3125 - val_loss: 230498.7812 - 240ms/epoch - 34ms/step
# Epoch 74/1000
#
# Epoch 74: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1077095.7500 - val_loss: 69696.1016 - 235ms/epoch - 34ms/step
# Epoch 75/1000
#
# Epoch 75: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1058080.7500 - val_loss: 106715.6016 - 206ms/epoch - 29ms/step
# Epoch 76/1000
#
# Epoch 76: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1037765.1875 - val_loss: 100310.4375 - 235ms/epoch - 34ms/step
# Epoch 77/1000
#
# Epoch 77: val_loss did not improve from 10793.01855
# 7/7 - 0s - loss: 1069120.3750 - val_loss: 352454.0312 - 232ms/epoch - 33ms/step
# Epoch 78/1000
#
# Epoch 78: val_loss improved from 10793.01855 to 10387.46094, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 1002647.5000 - val_loss: 10387.4609 - 521ms/epoch - 74ms/step
# Epoch 79/1000
#
# Epoch 79: val_loss improved from 10387.46094 to 6417.93994, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 949831.1250 - val_loss: 6417.9399 - 569ms/epoch - 81ms/step
# Epoch 80/1000
#
# Epoch 80: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 1015227.6875 - val_loss: 6451.4971 - 212ms/epoch - 30ms/step
# Epoch 81/1000
#
# Epoch 81: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 890892.7500 - val_loss: 117174.4219 - 223ms/epoch - 32ms/step
# Epoch 82/1000
#
# Epoch 82: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 1056364.3750 - val_loss: 85224.6328 - 210ms/epoch - 30ms/step
# Epoch 83/1000
#
# Epoch 83: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 942890.3750 - val_loss: 144356.9375 - 209ms/epoch - 30ms/step
# Epoch 84/1000
#
# Epoch 84: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 980989.1875 - val_loss: 166005.9062 - 206ms/epoch - 29ms/step
# Epoch 85/1000
#
# Epoch 85: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 1120063.0000 - val_loss: 21202.4629 - 215ms/epoch - 31ms/step
# Epoch 86/1000
#
# Epoch 86: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 1018361.4375 - val_loss: 198022.9062 - 222ms/epoch - 32ms/step
# Epoch 87/1000
#
# Epoch 87: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 1116254.7500 - val_loss: 18002.3477 - 212ms/epoch - 30ms/step
# Epoch 88/1000
#
# Epoch 88: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 1024591.2500 - val_loss: 78937.2656 - 206ms/epoch - 29ms/step
# Epoch 89/1000
#
# Epoch 89: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 1136072.2500 - val_loss: 99887.5469 - 211ms/epoch - 30ms/step
# Epoch 90/1000
#
# Epoch 90: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 1062444.8750 - val_loss: 46733.9453 - 201ms/epoch - 29ms/step
# Epoch 91/1000
#
# Epoch 91: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 938827.8125 - val_loss: 65779.5781 - 209ms/epoch - 30ms/step
# Epoch 92/1000
#
# Epoch 92: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 1093624.6250 - val_loss: 43128.7148 - 240ms/epoch - 34ms/step
# Epoch 93/1000
#
# Epoch 93: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 1040260.1875 - val_loss: 189663.7344 - 217ms/epoch - 31ms/step
# Epoch 94/1000
#
# Epoch 94: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 1016219.9375 - val_loss: 26176.2441 - 196ms/epoch - 28ms/step
# Epoch 95/1000
#
# Epoch 95: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 972310.5625 - val_loss: 125832.9531 - 210ms/epoch - 30ms/step
# Epoch 96/1000
#
# Epoch 96: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 839398.0000 - val_loss: 18956.3730 - 224ms/epoch - 32ms/step
# Epoch 97/1000
#
# Epoch 97: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 1027188.7500 - val_loss: 127600.2891 - 239ms/epoch - 34ms/step
# Epoch 98/1000
#
# Epoch 98: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 1038926.1250 - val_loss: 49585.6641 - 222ms/epoch - 32ms/step
# Epoch 99/1000
#
# Epoch 99: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 964263.3750 - val_loss: 76336.4766 - 219ms/epoch - 31ms/step
# Epoch 100/1000
#
# Epoch 100: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 920337.1250 - val_loss: 61368.0898 - 217ms/epoch - 31ms/step
# Epoch 101/1000
#
# Epoch 101: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 952907.3125 - val_loss: 65841.3984 - 233ms/epoch - 33ms/step
# Epoch 102/1000
#
# Epoch 102: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 900408.6250 - val_loss: 49274.9805 - 228ms/epoch - 33ms/step
# Epoch 103/1000
#
# Epoch 103: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 1032711.8125 - val_loss: 187322.8594 - 217ms/epoch - 31ms/step
# Epoch 104/1000
#
# Epoch 104: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 977810.0625 - val_loss: 19099.5957 - 215ms/epoch - 31ms/step
# Epoch 105/1000
#
# Epoch 105: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 904354.3125 - val_loss: 88167.5312 - 251ms/epoch - 36ms/step
# Epoch 106/1000
#
# Epoch 106: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 901441.1250 - val_loss: 9570.1982 - 233ms/epoch - 33ms/step
# Epoch 107/1000
#
# Epoch 107: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 1030705.7500 - val_loss: 109414.7578 - 220ms/epoch - 31ms/step
# Epoch 108/1000
#
# Epoch 108: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 967508.8750 - val_loss: 16662.4531 - 211ms/epoch - 30ms/step
# Epoch 109/1000
#
# Epoch 109: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 1149875.6250 - val_loss: 82188.3828 - 301ms/epoch - 43ms/step
# Epoch 110/1000
#
# Epoch 110: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 866767.6250 - val_loss: 125473.1562 - 474ms/epoch - 68ms/step
# Epoch 111/1000
#
# Epoch 111: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 1005158.1875 - val_loss: 63550.8164 - 414ms/epoch - 59ms/step
# Epoch 112/1000
#
# Epoch 112: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 871156.3125 - val_loss: 79873.5625 - 453ms/epoch - 65ms/step
# Epoch 113/1000
#
# Epoch 113: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 842133.5000 - val_loss: 68733.5312 - 457ms/epoch - 65ms/step
# Epoch 114/1000
#
# Epoch 114: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 905543.0000 - val_loss: 159172.0938 - 396ms/epoch - 57ms/step
# Epoch 115/1000
#
# Epoch 115: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 921116.1875 - val_loss: 22837.3359 - 361ms/epoch - 52ms/step
# Epoch 116/1000
#
# Epoch 116: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 798710.4375 - val_loss: 43386.8281 - 446ms/epoch - 64ms/step
# Epoch 117/1000
#
# Epoch 117: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 903322.6250 - val_loss: 70394.1719 - 433ms/epoch - 62ms/step
# Epoch 118/1000
#
# Epoch 118: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 891489.5625 - val_loss: 104346.0000 - 409ms/epoch - 58ms/step
# Epoch 119/1000
#
# Epoch 119: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 855334.0000 - val_loss: 15712.2383 - 414ms/epoch - 59ms/step
# Epoch 120/1000
#
# Epoch 120: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 837633.3750 - val_loss: 156598.4531 - 384ms/epoch - 55ms/step
# Epoch 121/1000
#
# Epoch 121: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 895401.8125 - val_loss: 23346.3301 - 420ms/epoch - 60ms/step
# Epoch 122/1000
#
# Epoch 122: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 879871.6250 - val_loss: 34032.4844 - 384ms/epoch - 55ms/step
# Epoch 123/1000
#
# Epoch 123: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 807634.8750 - val_loss: 57909.5703 - 299ms/epoch - 43ms/step
# Epoch 124/1000
#
# Epoch 124: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 869923.7500 - val_loss: 28618.7500 - 200ms/epoch - 29ms/step
# Epoch 125/1000
#
# Epoch 125: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 794415.2500 - val_loss: 49749.3281 - 211ms/epoch - 30ms/step
# Epoch 126/1000
#
# Epoch 126: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 887993.5000 - val_loss: 10759.4629 - 207ms/epoch - 30ms/step
# Epoch 127/1000
#
# Epoch 127: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 892642.0625 - val_loss: 25929.1484 - 205ms/epoch - 29ms/step
# Epoch 128/1000
#
# Epoch 128: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 921986.4375 - val_loss: 17786.5996 - 205ms/epoch - 29ms/step
# Epoch 129/1000
#
# Epoch 129: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 933515.6250 - val_loss: 18248.1445 - 264ms/epoch - 38ms/step
# Epoch 130/1000
#
# Epoch 130: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 794070.4375 - val_loss: 35895.8750 - 231ms/epoch - 33ms/step
# Epoch 131/1000
#
# Epoch 131: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 985852.7500 - val_loss: 83672.1719 - 209ms/epoch - 30ms/step
# Epoch 132/1000
#
# Epoch 132: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 877801.2500 - val_loss: 14751.2715 - 223ms/epoch - 32ms/step
# Epoch 133/1000
#
# Epoch 133: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 807585.5000 - val_loss: 111544.8438 - 202ms/epoch - 29ms/step
# Epoch 134/1000
#
# Epoch 134: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 881062.6250 - val_loss: 35846.8359 - 219ms/epoch - 31ms/step
# Epoch 135/1000
#
# Epoch 135: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 782486.2500 - val_loss: 14485.2578 - 211ms/epoch - 30ms/step
# Epoch 136/1000
#
# Epoch 136: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 803899.5625 - val_loss: 14367.2422 - 231ms/epoch - 33ms/step
# Epoch 137/1000
#
# Epoch 137: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 856888.0625 - val_loss: 63187.8906 - 216ms/epoch - 31ms/step
# Epoch 138/1000
#
# Epoch 138: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 999957.5625 - val_loss: 35221.0039 - 205ms/epoch - 29ms/step
# Epoch 139/1000
#
# Epoch 139: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 872190.5625 - val_loss: 19925.7656 - 222ms/epoch - 32ms/step
# Epoch 140/1000
#
# Epoch 140: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 835701.7500 - val_loss: 21299.5352 - 227ms/epoch - 32ms/step
# Epoch 141/1000
#
# Epoch 141: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 740557.3750 - val_loss: 70225.0938 - 252ms/epoch - 36ms/step
# Epoch 142/1000
#
# Epoch 142: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 801247.8750 - val_loss: 52905.7891 - 236ms/epoch - 34ms/step
# Epoch 143/1000
#
# Epoch 143: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 850670.6875 - val_loss: 26926.6875 - 221ms/epoch - 32ms/step
# Epoch 144/1000
#
# Epoch 144: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 918892.8750 - val_loss: 74456.8438 - 210ms/epoch - 30ms/step
# Epoch 145/1000
#
# Epoch 145: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 865822.2500 - val_loss: 13248.1201 - 235ms/epoch - 34ms/step
# Epoch 146/1000
#
# Epoch 146: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 814170.4375 - val_loss: 20537.2227 - 229ms/epoch - 33ms/step
# Epoch 147/1000
#
# Epoch 147: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 760604.4375 - val_loss: 7299.3765 - 222ms/epoch - 32ms/step
# Epoch 148/1000
#
# Epoch 148: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 728611.0000 - val_loss: 80884.3281 - 219ms/epoch - 31ms/step
# Epoch 149/1000
#
# Epoch 149: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 800252.6875 - val_loss: 7031.4126 - 245ms/epoch - 35ms/step
# Epoch 150/1000
#
# Epoch 150: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 836854.0625 - val_loss: 79723.2031 - 228ms/epoch - 33ms/step
# Epoch 151/1000
#
# Epoch 151: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 886783.5625 - val_loss: 15284.4902 - 217ms/epoch - 31ms/step
# Epoch 152/1000
#
# Epoch 152: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 699167.4375 - val_loss: 23083.7344 - 217ms/epoch - 31ms/step
# Epoch 153/1000
#
# Epoch 153: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 839559.2500 - val_loss: 25533.5098 - 232ms/epoch - 33ms/step
# Epoch 154/1000
#
# Epoch 154: val_loss did not improve from 6417.93994
# 7/7 - 0s - loss: 749639.9375 - val_loss: 31688.5996 - 214ms/epoch - 31ms/step
# Epoch 155/1000
#
# Epoch 155: val_loss improved from 6417.93994 to 4423.23389, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 876401.3125 - val_loss: 4423.2339 - 504ms/epoch - 72ms/step
# Epoch 156/1000
#
# Epoch 156: val_loss did not improve from 4423.23389
# 7/7 - 0s - loss: 839157.5625 - val_loss: 139997.4375 - 223ms/epoch - 32ms/step
# Epoch 157/1000
#
# Epoch 157: val_loss did not improve from 4423.23389
# 7/7 - 0s - loss: 816799.4375 - val_loss: 31349.8145 - 213ms/epoch - 30ms/step
# Epoch 158/1000
#
# Epoch 158: val_loss did not improve from 4423.23389
# 7/7 - 0s - loss: 959192.5000 - val_loss: 431973.9062 - 219ms/epoch - 31ms/step
# Epoch 159/1000
#
# Epoch 159: val_loss did not improve from 4423.23389
# 7/7 - 0s - loss: 947754.0625 - val_loss: 13639.9941 - 208ms/epoch - 30ms/step
# Epoch 160/1000
#
# Epoch 160: val_loss did not improve from 4423.23389
# 7/7 - 0s - loss: 1038186.0000 - val_loss: 77260.0859 - 218ms/epoch - 31ms/step
# Epoch 161/1000
#
# Epoch 161: val_loss did not improve from 4423.23389
# 7/7 - 0s - loss: 792160.8125 - val_loss: 56448.8984 - 210ms/epoch - 30ms/step
# Epoch 162/1000
#
# Epoch 162: val_loss did not improve from 4423.23389
# 7/7 - 0s - loss: 866485.9375 - val_loss: 43306.3984 - 206ms/epoch - 29ms/step
# Epoch 163/1000
#
# Epoch 163: val_loss did not improve from 4423.23389
# 7/7 - 0s - loss: 872843.6875 - val_loss: 116974.8984 - 208ms/epoch - 30ms/step
# Epoch 164/1000
#
# Epoch 164: val_loss did not improve from 4423.23389
# 7/7 - 0s - loss: 770350.0000 - val_loss: 10316.4971 - 220ms/epoch - 31ms/step
# Epoch 165/1000
#
# Epoch 165: val_loss did not improve from 4423.23389
# 7/7 - 0s - loss: 874429.1250 - val_loss: 290836.8750 - 214ms/epoch - 31ms/step
# Epoch 166/1000
#
# Epoch 166: val_loss improved from 4423.23389 to 4402.80957, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 885901.6875 - val_loss: 4402.8096 - 740ms/epoch - 106ms/step
# Epoch 167/1000
#
# Epoch 167: val_loss did not improve from 4402.80957
# 7/7 - 0s - loss: 795642.2500 - val_loss: 61659.1758 - 441ms/epoch - 63ms/step
# Epoch 168/1000
#
# Epoch 168: val_loss did not improve from 4402.80957
# 7/7 - 0s - loss: 778331.3125 - val_loss: 101131.6328 - 432ms/epoch - 62ms/step
# Epoch 169/1000
#
# Epoch 169: val_loss did not improve from 4402.80957
# 7/7 - 0s - loss: 853493.1875 - val_loss: 20465.1484 - 393ms/epoch - 56ms/step
# Epoch 170/1000
#
# Epoch 170: val_loss did not improve from 4402.80957
# 7/7 - 0s - loss: 759080.7500 - val_loss: 50591.5781 - 428ms/epoch - 61ms/step
# Epoch 171/1000
#
# Epoch 171: val_loss did not improve from 4402.80957
# 7/7 - 0s - loss: 765883.9375 - val_loss: 27293.2852 - 387ms/epoch - 55ms/step
# Epoch 172/1000
#
# Epoch 172: val_loss did not improve from 4402.80957
# 7/7 - 0s - loss: 830447.5625 - val_loss: 29066.8945 - 484ms/epoch - 69ms/step
# Epoch 173/1000
#
# Epoch 173: val_loss did not improve from 4402.80957
# 7/7 - 0s - loss: 835232.1250 - val_loss: 33732.7539 - 366ms/epoch - 52ms/step
# Epoch 174/1000
#
# Epoch 174: val_loss did not improve from 4402.80957
# 7/7 - 0s - loss: 776829.2500 - val_loss: 6115.5464 - 392ms/epoch - 56ms/step
# Epoch 175/1000
#
# Epoch 175: val_loss did not improve from 4402.80957
# 7/7 - 0s - loss: 749097.0000 - val_loss: 95582.2266 - 420ms/epoch - 60ms/step
# Epoch 176/1000
#
# Epoch 176: val_loss did not improve from 4402.80957
# 7/7 - 0s - loss: 819490.7500 - val_loss: 20377.2852 - 435ms/epoch - 62ms/step
# Epoch 177/1000
#
# Epoch 177: val_loss did not improve from 4402.80957
# 7/7 - 0s - loss: 780591.8750 - val_loss: 8897.6836 - 423ms/epoch - 60ms/step
# Epoch 178/1000
#
# Epoch 178: val_loss did not improve from 4402.80957
# 7/7 - 0s - loss: 835329.0625 - val_loss: 73375.7891 - 392ms/epoch - 56ms/step
# Epoch 179/1000
#
# Epoch 179: val_loss did not improve from 4402.80957
# 7/7 - 0s - loss: 756102.9375 - val_loss: 18359.8867 - 331ms/epoch - 47ms/step
# Epoch 180/1000
#
# Epoch 180: val_loss did not improve from 4402.80957
# 7/7 - 0s - loss: 789301.1875 - val_loss: 27895.0977 - 230ms/epoch - 33ms/step
# Epoch 181/1000
#
# Epoch 181: val_loss did not improve from 4402.80957
# 7/7 - 0s - loss: 744143.0625 - val_loss: 83592.6484 - 227ms/epoch - 32ms/step
# Epoch 182/1000
#
# Epoch 182: val_loss did not improve from 4402.80957
# 7/7 - 0s - loss: 833086.1250 - val_loss: 69362.7734 - 214ms/epoch - 31ms/step
# Epoch 183/1000
#
# Epoch 183: val_loss did not improve from 4402.80957
# 7/7 - 0s - loss: 762183.8125 - val_loss: 17943.8594 - 248ms/epoch - 35ms/step
# Epoch 184/1000
#
# Epoch 184: val_loss did not improve from 4402.80957
# 7/7 - 0s - loss: 771945.2500 - val_loss: 71483.3203 - 223ms/epoch - 32ms/step
# Epoch 185/1000
#
# Epoch 185: val_loss did not improve from 4402.80957
# 7/7 - 0s - loss: 831260.5625 - val_loss: 196518.8750 - 229ms/epoch - 33ms/step
# Epoch 186/1000
#
# Epoch 186: val_loss improved from 4402.80957 to 4002.77637, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 0s - loss: 926895.0625 - val_loss: 4002.7764 - 495ms/epoch - 71ms/step
# Epoch 187/1000
#
# Epoch 187: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 784169.6875 - val_loss: 20870.7656 - 236ms/epoch - 34ms/step
# Epoch 188/1000
#
# Epoch 188: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 802257.8750 - val_loss: 4229.9121 - 238ms/epoch - 34ms/step
# Epoch 189/1000
#
# Epoch 189: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 844585.4375 - val_loss: 122582.7266 - 218ms/epoch - 31ms/step
# Epoch 190/1000
#
# Epoch 190: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 729727.4375 - val_loss: 5745.6738 - 219ms/epoch - 31ms/step
# Epoch 191/1000
#
# Epoch 191: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 869882.1875 - val_loss: 53826.9102 - 226ms/epoch - 32ms/step
# Epoch 192/1000
#
# Epoch 192: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 839850.1875 - val_loss: 93182.6172 - 212ms/epoch - 30ms/step
# Epoch 193/1000
#
# Epoch 193: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 806195.7500 - val_loss: 46015.6445 - 228ms/epoch - 33ms/step
# Epoch 194/1000
#
# Epoch 194: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 755761.2500 - val_loss: 62183.1602 - 245ms/epoch - 35ms/step
# Epoch 195/1000
#
# Epoch 195: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 826850.6250 - val_loss: 34719.5156 - 222ms/epoch - 32ms/step
# Epoch 196/1000
#
# Epoch 196: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 744629.6875 - val_loss: 38981.6719 - 230ms/epoch - 33ms/step
# Epoch 197/1000
#
# Epoch 197: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 721597.5625 - val_loss: 27742.3418 - 234ms/epoch - 33ms/step
# Epoch 198/1000
#
# Epoch 198: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 762834.8750 - val_loss: 40677.4141 - 218ms/epoch - 31ms/step
# Epoch 199/1000
#
# Epoch 199: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 723443.6875 - val_loss: 26025.8359 - 205ms/epoch - 29ms/step
# Epoch 200/1000
#
# Epoch 200: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 699306.3125 - val_loss: 18865.3125 - 222ms/epoch - 32ms/step
# Epoch 201/1000
#
# Epoch 201: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 856898.3125 - val_loss: 79933.8672 - 228ms/epoch - 33ms/step
# Epoch 202/1000
#
# Epoch 202: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 750744.1875 - val_loss: 8839.3936 - 225ms/epoch - 32ms/step
# Epoch 203/1000
#
# Epoch 203: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 834180.1875 - val_loss: 138303.9219 - 206ms/epoch - 29ms/step
# Epoch 204/1000
#
# Epoch 204: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 747430.6250 - val_loss: 81106.7969 - 215ms/epoch - 31ms/step
# Epoch 205/1000
#
# Epoch 205: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 803384.4375 - val_loss: 32311.3945 - 210ms/epoch - 30ms/step
# Epoch 206/1000
#
# Epoch 206: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 818190.2500 - val_loss: 60550.0117 - 216ms/epoch - 31ms/step
# Epoch 207/1000
#
# Epoch 207: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 764386.6875 - val_loss: 5447.8188 - 221ms/epoch - 32ms/step
# Epoch 208/1000
#
# Epoch 208: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 785692.8750 - val_loss: 53915.9297 - 198ms/epoch - 28ms/step
# Epoch 209/1000
#
# Epoch 209: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 827932.6875 - val_loss: 38607.0508 - 221ms/epoch - 32ms/step
# Epoch 210/1000
#
# Epoch 210: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 808386.1875 - val_loss: 39050.7031 - 209ms/epoch - 30ms/step
# Epoch 211/1000
#
# Epoch 211: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 870471.0000 - val_loss: 156447.7344 - 209ms/epoch - 30ms/step
# Epoch 212/1000
#
# Epoch 212: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 814019.3125 - val_loss: 53941.0781 - 246ms/epoch - 35ms/step
# Epoch 213/1000
#
# Epoch 213: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 706939.2500 - val_loss: 35568.9297 - 217ms/epoch - 31ms/step
# Epoch 214/1000
#
# Epoch 214: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 726492.0625 - val_loss: 49055.3789 - 221ms/epoch - 32ms/step
# Epoch 215/1000
#
# Epoch 215: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 787836.3750 - val_loss: 20273.3965 - 218ms/epoch - 31ms/step
# Epoch 216/1000
#
# Epoch 216: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 793370.9375 - val_loss: 71245.4688 - 222ms/epoch - 32ms/step
# Epoch 217/1000
#
# Epoch 217: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 777484.8750 - val_loss: 82514.3672 - 202ms/epoch - 29ms/step
# Epoch 218/1000
#
# Epoch 218: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 786502.0000 - val_loss: 4665.2446 - 225ms/epoch - 32ms/step
# Epoch 219/1000
#
# Epoch 219: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 930929.5000 - val_loss: 58509.3359 - 209ms/epoch - 30ms/step
# Epoch 220/1000
#
# Epoch 220: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 786837.9375 - val_loss: 79714.5625 - 206ms/epoch - 29ms/step
# Epoch 221/1000
#
# Epoch 221: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 782519.5000 - val_loss: 7711.6021 - 201ms/epoch - 29ms/step
# Epoch 222/1000
#
# Epoch 222: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 786091.3750 - val_loss: 74917.1016 - 333ms/epoch - 48ms/step
# Epoch 223/1000
#
# Epoch 223: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 717548.5625 - val_loss: 45511.9609 - 441ms/epoch - 63ms/step
# Epoch 224/1000
#
# Epoch 224: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 716827.2500 - val_loss: 7567.1377 - 419ms/epoch - 60ms/step
# Epoch 225/1000
#
# Epoch 225: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 701400.0625 - val_loss: 64424.6484 - 391ms/epoch - 56ms/step
# Epoch 226/1000
#
# Epoch 226: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 821749.3125 - val_loss: 263181.7188 - 396ms/epoch - 57ms/step
# Epoch 227/1000
#
# Epoch 227: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 776112.0000 - val_loss: 8219.2383 - 423ms/epoch - 60ms/step
# Epoch 228/1000
#
# Epoch 228: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 742950.0625 - val_loss: 89480.5234 - 388ms/epoch - 55ms/step
# Epoch 229/1000
#
# Epoch 229: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 745422.0625 - val_loss: 14272.9326 - 398ms/epoch - 57ms/step
# Epoch 230/1000
#
# Epoch 230: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 818935.1875 - val_loss: 92034.5781 - 437ms/epoch - 62ms/step
# Epoch 231/1000
#
# Epoch 231: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 774491.6250 - val_loss: 6446.1768 - 331ms/epoch - 47ms/step
# Epoch 232/1000
#
# Epoch 232: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 837212.2500 - val_loss: 86110.2891 - 410ms/epoch - 59ms/step
# Epoch 233/1000
#
# Epoch 233: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 802344.0000 - val_loss: 31959.1680 - 436ms/epoch - 62ms/step
# Epoch 234/1000
#
# Epoch 234: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 852500.4375 - val_loss: 48817.3906 - 403ms/epoch - 58ms/step
# Epoch 235/1000
#
# Epoch 235: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 685323.6875 - val_loss: 42470.3750 - 422ms/epoch - 60ms/step
# Epoch 236/1000
#
# Epoch 236: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 725192.1250 - val_loss: 4882.3374 - 260ms/epoch - 37ms/step
# Epoch 237/1000
#
# Epoch 237: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 822375.5625 - val_loss: 81226.6719 - 212ms/epoch - 30ms/step
# Epoch 238/1000
#
# Epoch 238: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 718313.3750 - val_loss: 46371.7656 - 221ms/epoch - 32ms/step
# Epoch 239/1000
#
# Epoch 239: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 783346.4375 - val_loss: 20320.0703 - 222ms/epoch - 32ms/step
# Epoch 240/1000
#
# Epoch 240: val_loss did not improve from 4002.77637
# 7/7 - 0s - loss: 831851.3750 - val_loss: 132088.3438 - 209ms/epoch - 30ms/step
# Epoch 241/1000
#
# Epoch 241: val_loss improved from 4002.77637 to 3958.98071, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 786780.6250 - val_loss: 3958.9807 - 523ms/epoch - 75ms/step
# Epoch 242/1000
#
# Epoch 242: val_loss did not improve from 3958.98071
# 7/7 - 0s - loss: 829565.3750 - val_loss: 40567.9961 - 244ms/epoch - 35ms/step
# Epoch 243/1000
#
# Epoch 243: val_loss did not improve from 3958.98071
# 7/7 - 0s - loss: 764443.3125 - val_loss: 9385.5879 - 233ms/epoch - 33ms/step
# Epoch 244/1000
#
# Epoch 244: val_loss did not improve from 3958.98071
# 7/7 - 0s - loss: 760872.9375 - val_loss: 12365.1729 - 224ms/epoch - 32ms/step
# Epoch 245/1000
#
# Epoch 245: val_loss did not improve from 3958.98071
# 7/7 - 0s - loss: 803684.5625 - val_loss: 79455.8828 - 266ms/epoch - 38ms/step
# Epoch 246/1000
#
# Epoch 246: val_loss did not improve from 3958.98071
# 7/7 - 0s - loss: 800622.6875 - val_loss: 10730.0508 - 238ms/epoch - 34ms/step
# Epoch 247/1000
#
# Epoch 247: val_loss did not improve from 3958.98071
# 7/7 - 0s - loss: 674812.5625 - val_loss: 53773.6211 - 236ms/epoch - 34ms/step
# Epoch 248/1000
#
# Epoch 248: val_loss did not improve from 3958.98071
# 7/7 - 0s - loss: 736284.0625 - val_loss: 156427.7031 - 222ms/epoch - 32ms/step
# Epoch 249/1000
#
# Epoch 249: val_loss did not improve from 3958.98071
# 7/7 - 0s - loss: 781334.5625 - val_loss: 10932.6240 - 210ms/epoch - 30ms/step
# Epoch 250/1000
#
# Epoch 250: val_loss did not improve from 3958.98071
# 7/7 - 0s - loss: 854100.2500 - val_loss: 125152.6875 - 206ms/epoch - 29ms/step
# Epoch 251/1000
#
# Epoch 251: val_loss did not improve from 3958.98071
# 7/7 - 0s - loss: 908057.0625 - val_loss: 104635.2578 - 231ms/epoch - 33ms/step
# Epoch 252/1000
#
# Epoch 252: val_loss did not improve from 3958.98071
# 7/7 - 0s - loss: 802765.5625 - val_loss: 12321.4277 - 230ms/epoch - 33ms/step
# Epoch 253/1000
#
# Epoch 253: val_loss did not improve from 3958.98071
# 7/7 - 0s - loss: 793750.7500 - val_loss: 8026.8755 - 207ms/epoch - 30ms/step
# Epoch 254/1000
#
# Epoch 254: val_loss did not improve from 3958.98071
# 7/7 - 0s - loss: 684251.7500 - val_loss: 58677.1914 - 218ms/epoch - 31ms/step
# Epoch 255/1000
#
# Epoch 255: val_loss did not improve from 3958.98071
# 7/7 - 0s - loss: 801360.1875 - val_loss: 67010.1875 - 208ms/epoch - 30ms/step
# Epoch 256/1000
#
# Epoch 256: val_loss did not improve from 3958.98071
# 7/7 - 0s - loss: 796552.6250 - val_loss: 196731.5000 - 217ms/epoch - 31ms/step
# Epoch 257/1000
#
# Epoch 257: val_loss did not improve from 3958.98071
# 7/7 - 0s - loss: 943254.2500 - val_loss: 102825.0469 - 211ms/epoch - 30ms/step
# Epoch 258/1000
#
# Epoch 258: val_loss did not improve from 3958.98071
# 7/7 - 0s - loss: 674306.8125 - val_loss: 72570.7734 - 217ms/epoch - 31ms/step
# Epoch 259/1000
#
# Epoch 259: val_loss did not improve from 3958.98071
# 7/7 - 0s - loss: 739725.5000 - val_loss: 131063.1328 - 206ms/epoch - 29ms/step
# Epoch 260/1000
#
# Epoch 260: val_loss improved from 3958.98071 to 3331.34033, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 789547.1250 - val_loss: 3331.3403 - 518ms/epoch - 74ms/step
# Epoch 261/1000
#
# Epoch 261: val_loss did not improve from 3331.34033
# 7/7 - 0s - loss: 778948.1875 - val_loss: 56801.5352 - 212ms/epoch - 30ms/step
# Epoch 262/1000
#
# Epoch 262: val_loss did not improve from 3331.34033
# 7/7 - 0s - loss: 805451.1250 - val_loss: 103716.4375 - 241ms/epoch - 34ms/step
# Epoch 263/1000
#
# Epoch 263: val_loss did not improve from 3331.34033
# 7/7 - 0s - loss: 767271.4375 - val_loss: 46555.4102 - 203ms/epoch - 29ms/step
# Epoch 264/1000
#
# Epoch 264: val_loss did not improve from 3331.34033
# 7/7 - 0s - loss: 796308.3750 - val_loss: 14310.1709 - 240ms/epoch - 34ms/step
# Epoch 265/1000
#
# Epoch 265: val_loss did not improve from 3331.34033
# 7/7 - 0s - loss: 729072.8125 - val_loss: 3743.9609 - 212ms/epoch - 30ms/step
# Epoch 266/1000
#
# Epoch 266: val_loss did not improve from 3331.34033
# 7/7 - 0s - loss: 737049.4375 - val_loss: 237694.8438 - 217ms/epoch - 31ms/step
# Epoch 267/1000
#
# Epoch 267: val_loss did not improve from 3331.34033
# 7/7 - 0s - loss: 849716.6250 - val_loss: 21758.7949 - 249ms/epoch - 36ms/step
# Epoch 268/1000
#
# Epoch 268: val_loss did not improve from 3331.34033
# 7/7 - 0s - loss: 946831.5625 - val_loss: 99469.8828 - 236ms/epoch - 34ms/step
# Epoch 269/1000
#
# Epoch 269: val_loss did not improve from 3331.34033
# 7/7 - 0s - loss: 928204.3125 - val_loss: 137738.9062 - 224ms/epoch - 32ms/step
# Epoch 270/1000
#
# Epoch 270: val_loss did not improve from 3331.34033
# 7/7 - 0s - loss: 812819.7500 - val_loss: 3490.6306 - 227ms/epoch - 32ms/step
# Epoch 271/1000
#
# Epoch 271: val_loss did not improve from 3331.34033
# 7/7 - 0s - loss: 856483.3750 - val_loss: 144824.3438 - 210ms/epoch - 30ms/step
# Epoch 272/1000
#
# Epoch 272: val_loss did not improve from 3331.34033
# 7/7 - 0s - loss: 748327.8125 - val_loss: 4881.7715 - 210ms/epoch - 30ms/step
# Epoch 273/1000
#
# Epoch 273: val_loss did not improve from 3331.34033
# 7/7 - 0s - loss: 851292.4375 - val_loss: 131330.6250 - 223ms/epoch - 32ms/step
# Epoch 274/1000
#
# Epoch 274: val_loss did not improve from 3331.34033
# 7/7 - 0s - loss: 793984.6250 - val_loss: 44622.6289 - 235ms/epoch - 34ms/step
# Epoch 275/1000
#
# Epoch 275: val_loss did not improve from 3331.34033
# 7/7 - 0s - loss: 804694.0000 - val_loss: 90052.0938 - 262ms/epoch - 37ms/step
# Epoch 276/1000
#
# Epoch 276: val_loss did not improve from 3331.34033
# 7/7 - 0s - loss: 759193.5000 - val_loss: 8964.0928 - 224ms/epoch - 32ms/step
# Epoch 277/1000
#
# Epoch 277: val_loss did not improve from 3331.34033
# 7/7 - 0s - loss: 766394.0000 - val_loss: 170115.5938 - 336ms/epoch - 48ms/step
# Epoch 278/1000
#
# Epoch 278: val_loss did not improve from 3331.34033
# 7/7 - 0s - loss: 851218.3125 - val_loss: 3874.4150 - 491ms/epoch - 70ms/step
# Epoch 279/1000
#
# Epoch 279: val_loss did not improve from 3331.34033
# 7/7 - 0s - loss: 745353.9375 - val_loss: 197280.6875 - 483ms/epoch - 69ms/step
# Epoch 280/1000
#
# Epoch 280: val_loss did not improve from 3331.34033
# 7/7 - 1s - loss: 843605.6875 - val_loss: 16791.7617 - 504ms/epoch - 72ms/step
# Epoch 281/1000
#
# Epoch 281: val_loss did not improve from 3331.34033
# 7/7 - 0s - loss: 826051.7500 - val_loss: 34083.8984 - 460ms/epoch - 66ms/step
# Epoch 282/1000
#
# Epoch 282: val_loss did not improve from 3331.34033
# 7/7 - 1s - loss: 790029.8125 - val_loss: 63989.0195 - 506ms/epoch - 72ms/step
# Epoch 283/1000
#
# Epoch 283: val_loss did not improve from 3331.34033
# 7/7 - 0s - loss: 722732.3125 - val_loss: 17492.4766 - 481ms/epoch - 69ms/step
# Epoch 284/1000
#
# Epoch 284: val_loss did not improve from 3331.34033
# 7/7 - 0s - loss: 768308.6875 - val_loss: 100510.3203 - 499ms/epoch - 71ms/step
# Epoch 285/1000
#
# Epoch 285: val_loss did not improve from 3331.34033
# 7/7 - 0s - loss: 743266.7500 - val_loss: 3358.8140 - 463ms/epoch - 66ms/step
# Epoch 286/1000
#
# Epoch 286: val_loss did not improve from 3331.34033
# 7/7 - 0s - loss: 754662.3125 - val_loss: 67595.2734 - 462ms/epoch - 66ms/step
# Epoch 287/1000
#
# Epoch 287: val_loss did not improve from 3331.34033
# 7/7 - 0s - loss: 786871.3750 - val_loss: 11831.8486 - 479ms/epoch - 68ms/step
# Epoch 288/1000
#
# Epoch 288: val_loss did not improve from 3331.34033
# 7/7 - 0s - loss: 748999.4375 - val_loss: 97204.1016 - 459ms/epoch - 66ms/step
# Epoch 289/1000
#
# Epoch 289: val_loss improved from 3331.34033 to 3231.81055, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 833579.3750 - val_loss: 3231.8105 - 801ms/epoch - 114ms/step
# Epoch 290/1000
#
# Epoch 290: val_loss did not improve from 3231.81055
# 7/7 - 0s - loss: 908183.6250 - val_loss: 10102.0898 - 304ms/epoch - 43ms/step
# Epoch 291/1000
#
# Epoch 291: val_loss did not improve from 3231.81055
# 7/7 - 0s - loss: 760031.6875 - val_loss: 102854.4375 - 249ms/epoch - 36ms/step
# Epoch 292/1000
#
# Epoch 292: val_loss did not improve from 3231.81055
# 7/7 - 0s - loss: 758977.8125 - val_loss: 3492.5461 - 213ms/epoch - 30ms/step
# Epoch 293/1000
#
# Epoch 293: val_loss did not improve from 3231.81055
# 7/7 - 0s - loss: 674926.0625 - val_loss: 202033.4375 - 223ms/epoch - 32ms/step
# Epoch 294/1000
#
# Epoch 294: val_loss did not improve from 3231.81055
# 7/7 - 0s - loss: 736985.8125 - val_loss: 13337.0762 - 203ms/epoch - 29ms/step
# Epoch 295/1000
#
# Epoch 295: val_loss did not improve from 3231.81055
# 7/7 - 0s - loss: 829583.8125 - val_loss: 80704.2969 - 206ms/epoch - 29ms/step
# Epoch 296/1000
#
# Epoch 296: val_loss did not improve from 3231.81055
# 7/7 - 0s - loss: 714152.8750 - val_loss: 117638.1016 - 204ms/epoch - 29ms/step
# Epoch 297/1000
#
# ...
# Epoch 893/1000
#
# Epoch 893: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 710468.4375 - val_loss: 36625.2148 - 208ms/epoch - 30ms/step
# Epoch 894/1000
#
# Epoch 894: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 616461.2500 - val_loss: 21769.3906 - 222ms/epoch - 32ms/step
# Epoch 895/1000
#
# Epoch 895: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 705303.6875 - val_loss: 44040.3281 - 235ms/epoch - 34ms/step
# Epoch 896/1000
#
# Epoch 896: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 660184.4375 - val_loss: 64772.4336 - 268ms/epoch - 38ms/step
# Epoch 897/1000
#
# Epoch 897: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 640021.7500 - val_loss: 18227.0469 - 375ms/epoch - 54ms/step
# Epoch 898/1000
#
# Epoch 898: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 748341.5625 - val_loss: 110776.7969 - 426ms/epoch - 61ms/step
# Epoch 899/1000
#
# Epoch 899: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 698770.0000 - val_loss: 44233.8359 - 466ms/epoch - 67ms/step
# Epoch 900/1000
#
# Epoch 900: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 685470.0000 - val_loss: 49397.0508 - 418ms/epoch - 60ms/step
# Epoch 901/1000
#
# Epoch 901: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 754755.0000 - val_loss: 56832.4883 - 439ms/epoch - 63ms/step
# Epoch 902/1000
#
# Epoch 902: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 706040.5625 - val_loss: 16186.9863 - 425ms/epoch - 61ms/step
# Epoch 903/1000
#
# Epoch 903: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 671184.5625 - val_loss: 44362.6406 - 447ms/epoch - 64ms/step
# Epoch 904/1000
#
# Epoch 904: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 596620.8125 - val_loss: 149197.0156 - 417ms/epoch - 60ms/step
# Epoch 905/1000
#
# Epoch 905: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 705250.0625 - val_loss: 25191.8320 - 409ms/epoch - 58ms/step
# Epoch 906/1000
#
# Epoch 906: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 689976.5000 - val_loss: 113049.4609 - 446ms/epoch - 64ms/step
# Epoch 907/1000
#
# Epoch 907: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 719761.8750 - val_loss: 59448.5938 - 410ms/epoch - 59ms/step
# Epoch 908/1000
#
# Epoch 908: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 583545.5000 - val_loss: 9743.0742 - 416ms/epoch - 59ms/step
# Epoch 909/1000
#
# Epoch 909: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 708872.8125 - val_loss: 203930.0469 - 369ms/epoch - 53ms/step
# Epoch 910/1000
#
# Epoch 910: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 696698.6875 - val_loss: 12223.1377 - 358ms/epoch - 51ms/step
# Epoch 911/1000
#
# Epoch 911: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 639237.1250 - val_loss: 104695.5000 - 229ms/epoch - 33ms/step
# Epoch 912/1000
#
# Epoch 912: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 694346.3125 - val_loss: 83548.5703 - 200ms/epoch - 29ms/step
# Epoch 913/1000
#
# Epoch 913: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 689865.5625 - val_loss: 43933.5234 - 226ms/epoch - 32ms/step
# Epoch 914/1000
#
# Epoch 914: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 601383.5625 - val_loss: 114003.5000 - 233ms/epoch - 33ms/step
# Epoch 915/1000
#
# Epoch 915: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 695321.1250 - val_loss: 82149.8984 - 210ms/epoch - 30ms/step
# Epoch 916/1000
#
# Epoch 916: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 671873.0000 - val_loss: 126221.5391 - 215ms/epoch - 31ms/step
# Epoch 917/1000
#
# Epoch 917: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 591596.1250 - val_loss: 7162.5820 - 230ms/epoch - 33ms/step
# Epoch 918/1000
#
# Epoch 918: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 690068.0625 - val_loss: 60169.4609 - 226ms/epoch - 32ms/step
# Epoch 919/1000
#
# Epoch 919: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 759528.1875 - val_loss: 65201.4492 - 205ms/epoch - 29ms/step
# Epoch 920/1000
#
# Epoch 920: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 652455.9375 - val_loss: 42109.7812 - 215ms/epoch - 31ms/step
# Epoch 921/1000
#
# Epoch 921: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 696986.6250 - val_loss: 47814.7969 - 210ms/epoch - 30ms/step
# Epoch 922/1000
#
# Epoch 922: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 615016.3750 - val_loss: 62478.9688 - 212ms/epoch - 30ms/step
# Epoch 923/1000
#
# Epoch 923: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 646407.6250 - val_loss: 64929.7188 - 205ms/epoch - 29ms/step
# Epoch 924/1000
#
# Epoch 924: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 634691.4375 - val_loss: 45640.6484 - 226ms/epoch - 32ms/step
# Epoch 925/1000
#
# Epoch 925: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 718007.5625 - val_loss: 106928.9219 - 238ms/epoch - 34ms/step
# Epoch 926/1000
#
# Epoch 926: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 704961.1250 - val_loss: 68040.5234 - 225ms/epoch - 32ms/step
# Epoch 927/1000
#
# Epoch 927: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 687461.3125 - val_loss: 53500.7656 - 223ms/epoch - 32ms/step
# Epoch 928/1000
#
# Epoch 928: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 674063.3750 - val_loss: 43150.5898 - 216ms/epoch - 31ms/step
# Epoch 929/1000
#
# Epoch 929: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 757943.3750 - val_loss: 65315.5117 - 235ms/epoch - 34ms/step
# Epoch 930/1000
#
# Epoch 930: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 728909.9375 - val_loss: 48683.7891 - 230ms/epoch - 33ms/step
# Epoch 931/1000
#
# Epoch 931: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 754667.6250 - val_loss: 89130.7578 - 227ms/epoch - 32ms/step
# Epoch 932/1000
#
# Epoch 932: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 768953.7500 - val_loss: 21019.7148 - 247ms/epoch - 35ms/step
# Epoch 933/1000
#
# Epoch 933: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 647794.0000 - val_loss: 35037.0039 - 209ms/epoch - 30ms/step
# Epoch 934/1000
#
# Epoch 934: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 717499.0000 - val_loss: 7367.7524 - 230ms/epoch - 33ms/step
# Epoch 935/1000
#
# Epoch 935: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 655464.6250 - val_loss: 114176.9219 - 237ms/epoch - 34ms/step
# Epoch 936/1000
#
# Epoch 936: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 649140.8750 - val_loss: 18079.4492 - 223ms/epoch - 32ms/step
# Epoch 937/1000
#
# Epoch 937: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 718330.6875 - val_loss: 80571.2812 - 219ms/epoch - 31ms/step
# Epoch 938/1000
#
# Epoch 938: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 723591.9375 - val_loss: 64690.1797 - 230ms/epoch - 33ms/step
# Epoch 939/1000
#
# Epoch 939: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 694945.4375 - val_loss: 99519.4688 - 217ms/epoch - 31ms/step
# Epoch 940/1000
#
# Epoch 940: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 599834.1875 - val_loss: 57949.9062 - 220ms/epoch - 31ms/step
# Epoch 941/1000
#
# Epoch 941: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 645510.5625 - val_loss: 39412.3359 - 205ms/epoch - 29ms/step
# Epoch 942/1000
#
# Epoch 942: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 662420.1875 - val_loss: 79086.8906 - 219ms/epoch - 31ms/step
# Epoch 943/1000
#
# Epoch 943: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 694247.5000 - val_loss: 39427.5742 - 233ms/epoch - 33ms/step
# Epoch 944/1000
#
# Epoch 944: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 650688.1875 - val_loss: 10671.5801 - 207ms/epoch - 30ms/step
# Epoch 945/1000
#
# Epoch 945: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 644042.7500 - val_loss: 55315.2617 - 228ms/epoch - 33ms/step
# Epoch 946/1000
#
# Epoch 946: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 604327.2500 - val_loss: 19738.0449 - 233ms/epoch - 33ms/step
# Epoch 947/1000
#
# Epoch 947: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 645656.6250 - val_loss: 30364.0391 - 229ms/epoch - 33ms/step
# Epoch 948/1000
#
# Epoch 948: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 646316.4375 - val_loss: 54789.8594 - 216ms/epoch - 31ms/step
# Epoch 949/1000
#
# Epoch 949: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 632010.0625 - val_loss: 13284.5576 - 243ms/epoch - 35ms/step
# Epoch 950/1000
#
# Epoch 950: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 585385.1250 - val_loss: 102389.2969 - 218ms/epoch - 31ms/step
# Epoch 951/1000
#
# Epoch 951: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 617992.5000 - val_loss: 10944.5078 - 227ms/epoch - 32ms/step
# Epoch 952/1000
#
# Epoch 952: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 687929.3750 - val_loss: 91746.1172 - 218ms/epoch - 31ms/step
# Epoch 953/1000
#
# Epoch 953: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 640427.9375 - val_loss: 4420.7607 - 225ms/epoch - 32ms/step
# Epoch 954/1000
#
# Epoch 954: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 672247.0625 - val_loss: 77443.0469 - 384ms/epoch - 55ms/step
# Epoch 955/1000
#
# Epoch 955: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 640053.0625 - val_loss: 49075.1133 - 409ms/epoch - 58ms/step
# Epoch 956/1000
#
# Epoch 956: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 663404.1875 - val_loss: 61592.0195 - 457ms/epoch - 65ms/step
# Epoch 957/1000
#
# Epoch 957: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 582194.3125 - val_loss: 23209.9375 - 419ms/epoch - 60ms/step
# Epoch 958/1000
#
# Epoch 958: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 601441.5000 - val_loss: 47829.1484 - 414ms/epoch - 59ms/step
# Epoch 959/1000
#
# Epoch 959: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 702963.4375 - val_loss: 103904.1094 - 414ms/epoch - 59ms/step
# Epoch 960/1000
#
# Epoch 960: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 629705.2500 - val_loss: 32061.1367 - 400ms/epoch - 57ms/step
# Epoch 961/1000
#
# Epoch 961: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 620602.8125 - val_loss: 77232.0938 - 432ms/epoch - 62ms/step
# Epoch 962/1000
#
# Epoch 962: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 629741.0000 - val_loss: 35580.9609 - 385ms/epoch - 55ms/step
# Epoch 963/1000
#
# Epoch 963: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 688198.4375 - val_loss: 121217.1328 - 394ms/epoch - 56ms/step
# Epoch 964/1000
#
# Epoch 964: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 612586.3125 - val_loss: 28872.7500 - 398ms/epoch - 57ms/step
# Epoch 965/1000
#
# Epoch 965: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 611788.8750 - val_loss: 61918.5781 - 402ms/epoch - 57ms/step
# Epoch 966/1000
#
# Epoch 966: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 605912.1250 - val_loss: 55378.6289 - 364ms/epoch - 52ms/step
# Epoch 967/1000
#
# Epoch 967: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 611310.8750 - val_loss: 35512.3281 - 400ms/epoch - 57ms/step
# Epoch 968/1000
#
# Epoch 968: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 627593.0625 - val_loss: 16948.3984 - 371ms/epoch - 53ms/step
# Epoch 969/1000
#
# Epoch 969: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 541760.7500 - val_loss: 113458.8594 - 225ms/epoch - 32ms/step
# Epoch 970/1000
#
# Epoch 970: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 623636.7500 - val_loss: 37319.1680 - 215ms/epoch - 31ms/step
# Epoch 971/1000
#
# Epoch 971: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 604058.1875 - val_loss: 120722.1016 - 223ms/epoch - 32ms/step
# Epoch 972/1000
#
# Epoch 972: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 624189.6875 - val_loss: 24142.2344 - 226ms/epoch - 32ms/step
# Epoch 973/1000
#
# Epoch 973: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 676313.5625 - val_loss: 91947.9297 - 214ms/epoch - 31ms/step
# Epoch 974/1000
#
# Epoch 974: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 687672.1250 - val_loss: 15397.7236 - 221ms/epoch - 32ms/step
# Epoch 975/1000
#
# Epoch 975: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 696811.0000 - val_loss: 56744.6562 - 209ms/epoch - 30ms/step
# Epoch 976/1000
#
# Epoch 976: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 680416.1250 - val_loss: 39112.5078 - 235ms/epoch - 34ms/step
# Epoch 977/1000
#
# Epoch 977: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 631845.6875 - val_loss: 35810.1602 - 215ms/epoch - 31ms/step
# Epoch 978/1000
#
# Epoch 978: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 638255.0625 - val_loss: 19084.8691 - 198ms/epoch - 28ms/step
# Epoch 979/1000
#
# Epoch 979: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 619372.8125 - val_loss: 91704.0781 - 215ms/epoch - 31ms/step
# Epoch 980/1000
#
# Epoch 980: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 679250.8750 - val_loss: 30538.8242 - 218ms/epoch - 31ms/step
# Epoch 981/1000
#
# Epoch 981: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 673370.3750 - val_loss: 30626.9043 - 213ms/epoch - 30ms/step
# Epoch 982/1000
#
# Epoch 982: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 617940.3125 - val_loss: 45909.5547 - 230ms/epoch - 33ms/step
# Epoch 983/1000
#
# Epoch 983: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 585719.8125 - val_loss: 136932.8906 - 215ms/epoch - 31ms/step
# Epoch 984/1000
#
# Epoch 984: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 621437.5000 - val_loss: 62678.4648 - 228ms/epoch - 33ms/step
# Epoch 985/1000
#
# Epoch 985: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 583091.7500 - val_loss: 106807.0625 - 220ms/epoch - 31ms/step
# Epoch 986/1000
#
# Epoch 986: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 604290.0625 - val_loss: 55057.5312 - 214ms/epoch - 31ms/step
# Epoch 987/1000
#
# Epoch 987: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 711553.1250 - val_loss: 36407.9453 - 213ms/epoch - 30ms/step
# Epoch 988/1000
#
# Epoch 988: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 592680.3125 - val_loss: 15151.4883 - 223ms/epoch - 32ms/step
# Epoch 989/1000
#
# Epoch 989: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 635947.4375 - val_loss: 31815.4199 - 252ms/epoch - 36ms/step
# Epoch 990/1000
#
# Epoch 990: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 611760.0000 - val_loss: 6157.5586 - 218ms/epoch - 31ms/step
# Epoch 991/1000
#
# Epoch 991: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 674473.0625 - val_loss: 85790.2266 - 212ms/epoch - 30ms/step
# Epoch 992/1000
#
# Epoch 992: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 601864.3125 - val_loss: 11697.5498 - 220ms/epoch - 31ms/step
# Epoch 993/1000
#
# Epoch 993: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 701565.5000 - val_loss: 105806.6562 - 235ms/epoch - 34ms/step
# Epoch 994/1000
#
# Epoch 994: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 664446.2500 - val_loss: 14073.2539 - 235ms/epoch - 34ms/step
# Epoch 995/1000
#
# Epoch 995: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 684824.6250 - val_loss: 73102.0078 - 216ms/epoch - 31ms/step
# Epoch 996/1000
#
# Epoch 996: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 664656.6250 - val_loss: 3827.7112 - 288ms/epoch - 41ms/step
# Epoch 997/1000
#
# Epoch 997: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 602222.3125 - val_loss: 64054.1484 - 220ms/epoch - 31ms/step
# Epoch 998/1000
#
# Epoch 998: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 659535.2500 - val_loss: 48570.0195 - 223ms/epoch - 32ms/step
# Epoch 999/1000
#
# Epoch 999: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 765249.5625 - val_loss: 89040.3281 - 225ms/epoch - 32ms/step
# Epoch 1000/1000
#
# Epoch 1000: val_loss did not improve from 2068.98584
# 7/7 - 0s - loss: 644151.1250 - val_loss: 8778.1660 - 239ms/epoch - 34ms/step
# 16/16 [==============================] - 1s 4ms/step
# 3/3 [==============================] - 0s 7ms/step
# Training MSE: 24601.647
# Testing MSE: 1871.394
# Training MAPE: 4.747%
# Testing MAPE: 1.409%
# accuracy : 51

# %%
# 모델 생성
model = Sequential()
model.add(LSTM(units=1024, activation='relu', return_sequences=True, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dropout(0.3))
model.add(LSTM(units=512, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(units=256, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(units=128, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(units=64, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(units=32, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(units=16, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(units=1))
model.summary()

# loss = Huber()
# optimizer = Adam(0.0005)
# model.compile(loss=Huber(), optimizer=optimizer, metrics=['mse'])

model.compile(optimizer='adam', loss='mean_squared_error')

filename = os.path.join('tmp', 'ckeckpointer.ckpt')
checkpoint = ModelCheckpoint(filename,
                             save_weights_only=True,
                             save_best_only=True,
                             monitor='val_loss',
                             verbose=1)

# 모델 학습
history = model.fit(trainX, trainY, epochs=1000, batch_size=64,
          validation_split=0.1, verbose=2,callbacks=[checkpoint])

model.save_weights('./lstm_weights.h3')

model.load_weights(filename)

plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()
plt.show()

# 예측
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# MSE 계산
trainMSE = mean_squared_error(trainY, trainPredict)
testMSE = mean_squared_error(testY, testPredict)

# MAPE 계산
trainMAPE = calculate_mape(trainY, trainPredict)
testMAPE = calculate_mape(testY, testPredict)

print(f'Training MSE: {trainMSE:.3f}')
print(f'Testing MSE: {testMSE:.3f}')
print(f'Training MAPE: {trainMAPE:.3f}%')
print(f'Testing MAPE: {testMAPE:.3f}%')

accuracy(testPredict,testY)

# 예측 시각화
plt.plot(trainY, label='Actual Price')
plt.plot(trainPredict, label='Predicted Price')
plt.legend()
plt.title('Training Data')
plt.show()

plt.plot(testY, label='Actual Price')
plt.plot(testPredict, label='Predicted Price')
plt.legend()
plt.title('Testing Data')
plt.show()
# Out:
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_7 (LSTM)               (None, 5, 1024)           4239360
#
#  dropout_20 (Dropout)        (None, 5, 1024)           0
#
#  lstm_8 (LSTM)               (None, 5, 512)            3147776
#
#  dropout_21 (Dropout)        (None, 5, 512)            0
#
#  lstm_9 (LSTM)               (None, 5, 256)            787456
#
#  dropout_22 (Dropout)        (None, 5, 256)            0
#
#  lstm_10 (LSTM)              (None, 5, 128)            197120
#
#  dropout_23 (Dropout)        (None, 5, 128)            0
#
#  lstm_11 (LSTM)              (None, 5, 64)             49408
#
#  dropout_24 (Dropout)        (None, 5, 64)             0
#
#  lstm_12 (LSTM)              (None, 5, 32)             12416
#
#  dropout_25 (Dropout)        (None, 5, 32)             0
#
#  lstm_13 (LSTM)              (None, 16)                3136
#
#  dropout_26 (Dropout)        (None, 16)                0
#
#  dense_3 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 8436689 (32.18 MB)
# Trainable params: 8436689 (32.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/1000
#
# Epoch 1: val_loss improved from inf to 5710771.00000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 12s - loss: 8167914.0000 - val_loss: 5710771.0000 - 12s/epoch - 2s/step
# Epoch 2/1000
#
# Epoch 2: val_loss improved from 5710771.00000 to 5352837.00000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 8116478.5000 - val_loss: 5352837.0000 - 854ms/epoch - 122ms/step
# Epoch 3/1000
#
# Epoch 3: val_loss improved from 5352837.00000 to 331110.84375, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 6711164.0000 - val_loss: 331110.8438 - 829ms/epoch - 118ms/step
# Epoch 4/1000
#
# Epoch 4: val_loss did not improve from 331110.84375
# 7/7 - 1s - loss: 4088067.5000 - val_loss: 425952.1562 - 705ms/epoch - 101ms/step
# Epoch 5/1000
#
# Epoch 5: val_loss improved from 331110.84375 to 53854.00000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 3s - loss: 3692744.0000 - val_loss: 53854.0000 - 3s/epoch - 460ms/step
# Epoch 6/1000
#
# Epoch 6: val_loss improved from 53854.00000 to 44831.27344, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 3272158.5000 - val_loss: 44831.2734 - 1s/epoch - 178ms/step
# Epoch 7/1000
#
# Epoch 7: val_loss did not improve from 44831.27344
# 7/7 - 1s - loss: 3205927.5000 - val_loss: 305382.9062 - 539ms/epoch - 77ms/step
# Epoch 8/1000
#
# Epoch 8: val_loss did not improve from 44831.27344
# 7/7 - 1s - loss: 2697790.0000 - val_loss: 505144.0000 - 586ms/epoch - 84ms/step
# Epoch 9/1000
#
# Epoch 9: val_loss did not improve from 44831.27344
# 7/7 - 1s - loss: 2710096.7500 - val_loss: 330550.9062 - 549ms/epoch - 78ms/step
# Epoch 10/1000
#
# Epoch 10: val_loss did not improve from 44831.27344
# 7/7 - 1s - loss: 2859354.0000 - val_loss: 447498.8125 - 532ms/epoch - 76ms/step
# Epoch 11/1000
#
# Epoch 11: val_loss did not improve from 44831.27344
# 7/7 - 1s - loss: 2526656.0000 - val_loss: 99557.4688 - 538ms/epoch - 77ms/step
# Epoch 12/1000
#
# Epoch 12: val_loss did not improve from 44831.27344
# 7/7 - 1s - loss: 2590771.0000 - val_loss: 862137.1875 - 564ms/epoch - 81ms/step
# Epoch 13/1000
#
# Epoch 13: val_loss improved from 44831.27344 to 33489.82031, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 2598046.2500 - val_loss: 33489.8203 - 846ms/epoch - 121ms/step
# Epoch 14/1000
#
# Epoch 14: val_loss did not improve from 33489.82031
# 7/7 - 1s - loss: 2412335.2500 - val_loss: 205436.6875 - 524ms/epoch - 75ms/step
# Epoch 15/1000
#
# Epoch 15: val_loss did not improve from 33489.82031
# 7/7 - 1s - loss: 2404517.2500 - val_loss: 42448.6797 - 525ms/epoch - 75ms/step
# Epoch 16/1000
#
# Epoch 16: val_loss did not improve from 33489.82031
# 7/7 - 1s - loss: 2061198.5000 - val_loss: 229020.5625 - 573ms/epoch - 82ms/step
# Epoch 17/1000
#
# Epoch 17: val_loss did not improve from 33489.82031
# 7/7 - 1s - loss: 1859799.8750 - val_loss: 436441.1875 - 584ms/epoch - 83ms/step
# Epoch 18/1000
#
# Epoch 18: val_loss did not improve from 33489.82031
# 7/7 - 1s - loss: 1883941.2500 - val_loss: 206528.8125 - 535ms/epoch - 76ms/step
# Epoch 19/1000
#
# Epoch 19: val_loss did not improve from 33489.82031
# 7/7 - 1s - loss: 1983153.5000 - val_loss: 86194.8203 - 522ms/epoch - 75ms/step
# Epoch 20/1000
#
# Epoch 20: val_loss did not improve from 33489.82031
# 7/7 - 1s - loss: 1917188.5000 - val_loss: 841279.0625 - 555ms/epoch - 79ms/step
# Epoch 21/1000
#
# Epoch 21: val_loss did not improve from 33489.82031
# 7/7 - 1s - loss: 1855339.3750 - val_loss: 256901.6875 - 586ms/epoch - 84ms/step
# Epoch 22/1000
#
# Epoch 22: val_loss did not improve from 33489.82031
# 7/7 - 1s - loss: 1752814.7500 - val_loss: 289528.3125 - 541ms/epoch - 77ms/step
# Epoch 23/1000
#
# Epoch 23: val_loss did not improve from 33489.82031
# 7/7 - 1s - loss: 1729428.1250 - val_loss: 336604.7188 - 532ms/epoch - 76ms/step
# Epoch 24/1000
#
# Epoch 24: val_loss did not improve from 33489.82031
# 7/7 - 1s - loss: 1600951.3750 - val_loss: 380635.1250 - 715ms/epoch - 102ms/step
# Epoch 25/1000
#
# Epoch 25: val_loss did not improve from 33489.82031
# 7/7 - 1s - loss: 1448062.1250 - val_loss: 339207.1875 - 1s/epoch - 155ms/step
# Epoch 26/1000
#
# Epoch 26: val_loss did not improve from 33489.82031
# 7/7 - 1s - loss: 1334622.3750 - val_loss: 411077.5312 - 1s/epoch - 157ms/step
# Epoch 27/1000
#
# Epoch 27: val_loss did not improve from 33489.82031
# 7/7 - 1s - loss: 1522680.2500 - val_loss: 438928.5625 - 1s/epoch - 160ms/step
# Epoch 28/1000
#
# Epoch 28: val_loss did not improve from 33489.82031
# 7/7 - 1s - loss: 1375386.2500 - val_loss: 267036.6250 - 1s/epoch - 158ms/step
# Epoch 29/1000
#
# Epoch 29: val_loss did not improve from 33489.82031
# 7/7 - 1s - loss: 1402329.1250 - val_loss: 487338.8125 - 925ms/epoch - 132ms/step
# Epoch 30/1000
#
# Epoch 30: val_loss did not improve from 33489.82031
# 7/7 - 1s - loss: 1324786.5000 - val_loss: 153649.0469 - 605ms/epoch - 86ms/step
# Epoch 31/1000
#
# Epoch 31: val_loss did not improve from 33489.82031
# 7/7 - 1s - loss: 1307137.2500 - val_loss: 117469.4219 - 556ms/epoch - 79ms/step
# Epoch 32/1000
#
# Epoch 32: val_loss did not improve from 33489.82031
# 7/7 - 1s - loss: 1463361.5000 - val_loss: 140843.4688 - 524ms/epoch - 75ms/step
# Epoch 33/1000
#
# Epoch 33: val_loss did not improve from 33489.82031
# 7/7 - 1s - loss: 1395115.2500 - val_loss: 439245.4688 - 566ms/epoch - 81ms/step
# Epoch 34/1000
#
# Epoch 34: val_loss did not improve from 33489.82031
# 7/7 - 1s - loss: 1274448.2500 - val_loss: 118368.4688 - 539ms/epoch - 77ms/step
# Epoch 35/1000
#
# Epoch 35: val_loss did not improve from 33489.82031
# 7/7 - 1s - loss: 1208267.1250 - val_loss: 99776.1484 - 510ms/epoch - 73ms/step
# Epoch 36/1000
#
# Epoch 36: val_loss did not improve from 33489.82031
# 7/7 - 1s - loss: 1274521.5000 - val_loss: 352233.5938 - 533ms/epoch - 76ms/step
# Epoch 37/1000
#
# Epoch 37: val_loss did not improve from 33489.82031
# 7/7 - 1s - loss: 1255289.1250 - val_loss: 43882.2031 - 555ms/epoch - 79ms/step
# Epoch 38/1000
#
# Epoch 38: val_loss improved from 33489.82031 to 9203.05664, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 1040836.5625 - val_loss: 9203.0566 - 808ms/epoch - 115ms/step
# Epoch 39/1000
#
# Epoch 39: val_loss did not improve from 9203.05664
# 7/7 - 1s - loss: 1106088.7500 - val_loss: 33534.6406 - 570ms/epoch - 81ms/step
# Epoch 40/1000
#
# Epoch 40: val_loss improved from 9203.05664 to 6886.71143, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 1130131.8750 - val_loss: 6886.7114 - 786ms/epoch - 112ms/step
# Epoch 41/1000
#
# Epoch 41: val_loss did not improve from 6886.71143
# 7/7 - 1s - loss: 1046508.7500 - val_loss: 10499.6826 - 519ms/epoch - 74ms/step
# Epoch 42/1000
#
# Epoch 42: val_loss improved from 6886.71143 to 3434.10938, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 1028761.6875 - val_loss: 3434.1094 - 829ms/epoch - 118ms/step
# Epoch 43/1000
#
# Epoch 43: val_loss did not improve from 3434.10938
# 7/7 - 1s - loss: 877285.5000 - val_loss: 72300.9297 - 561ms/epoch - 80ms/step
# Epoch 44/1000
#
# Epoch 44: val_loss did not improve from 3434.10938
# 7/7 - 1s - loss: 926614.6250 - val_loss: 174563.0156 - 553ms/epoch - 79ms/step
# Epoch 45/1000
#
# Epoch 45: val_loss improved from 3434.10938 to 3347.23755, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 875790.7500 - val_loss: 3347.2375 - 772ms/epoch - 110ms/step
# Epoch 46/1000
#
# Epoch 46: val_loss improved from 3347.23755 to 3041.56836, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 1081400.8750 - val_loss: 3041.5684 - 1s/epoch - 190ms/step
# Epoch 47/1000
#
# Epoch 47: val_loss did not improve from 3041.56836
# 7/7 - 1s - loss: 1088752.7500 - val_loss: 347263.6875 - 1s/epoch - 166ms/step
# Epoch 48/1000
#
# Epoch 48: val_loss did not improve from 3041.56836
# 7/7 - 1s - loss: 898340.1875 - val_loss: 165686.8438 - 1s/epoch - 162ms/step
# Epoch 49/1000
#
# Epoch 49: val_loss did not improve from 3041.56836
# 7/7 - 1s - loss: 858557.0000 - val_loss: 5233.9277 - 1s/epoch - 164ms/step
# Epoch 50/1000
#
# Epoch 50: val_loss did not improve from 3041.56836
# 7/7 - 1s - loss: 792552.4375 - val_loss: 23119.5273 - 1s/epoch - 160ms/step
# Epoch 51/1000
#
# Epoch 51: val_loss improved from 3041.56836 to 2730.77124, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 854694.3125 - val_loss: 2730.7712 - 847ms/epoch - 121ms/step
# Epoch 52/1000
#
# Epoch 52: val_loss did not improve from 2730.77124
# 7/7 - 1s - loss: 790665.0625 - val_loss: 73251.2891 - 541ms/epoch - 77ms/step
# Epoch 53/1000
#
# Epoch 53: val_loss did not improve from 2730.77124
# 7/7 - 1s - loss: 781527.0625 - val_loss: 18060.2754 - 504ms/epoch - 72ms/step
# Epoch 54/1000
#
# Epoch 54: val_loss did not improve from 2730.77124
# 7/7 - 1s - loss: 843237.5000 - val_loss: 8189.4995 - 524ms/epoch - 75ms/step
# Epoch 55/1000
#
# Epoch 55: val_loss did not improve from 2730.77124
# 7/7 - 1s - loss: 730245.5000 - val_loss: 36789.5508 - 516ms/epoch - 74ms/step
# Epoch 56/1000
#
# Epoch 56: val_loss did not improve from 2730.77124
# 7/7 - 1s - loss: 742834.4375 - val_loss: 82759.8984 - 562ms/epoch - 80ms/step
# Epoch 57/1000
#
# Epoch 57: val_loss did not improve from 2730.77124
# 7/7 - 1s - loss: 770361.8750 - val_loss: 42286.3516 - 545ms/epoch - 78ms/step
# Epoch 58/1000
#
# Epoch 58: val_loss improved from 2730.77124 to 2647.78687, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 642652.4375 - val_loss: 2647.7869 - 761ms/epoch - 109ms/step
# Epoch 59/1000
#
# Epoch 59: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 665192.5000 - val_loss: 73650.8281 - 532ms/epoch - 76ms/step
# Epoch 60/1000
#
# Epoch 60: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 726554.3750 - val_loss: 43072.6484 - 504ms/epoch - 72ms/step
# Epoch 61/1000
#
# Epoch 61: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 669384.3750 - val_loss: 3819.4109 - 532ms/epoch - 76ms/step
# Epoch 62/1000
#
# Epoch 62: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 650814.1250 - val_loss: 45114.5781 - 525ms/epoch - 75ms/step
# Epoch 63/1000
#
# Epoch 63: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 680228.6250 - val_loss: 3551.3977 - 546ms/epoch - 78ms/step
# Epoch 64/1000
#
# Epoch 64: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 721506.9375 - val_loss: 31008.1855 - 569ms/epoch - 81ms/step
# Epoch 65/1000
#
# Epoch 65: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 592274.7500 - val_loss: 81885.2891 - 511ms/epoch - 73ms/step
# Epoch 66/1000
#
# Epoch 66: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 586165.6875 - val_loss: 107517.8516 - 556ms/epoch - 79ms/step
# Epoch 67/1000
#
# Epoch 67: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 645165.5000 - val_loss: 80378.3438 - 530ms/epoch - 76ms/step
# Epoch 68/1000
#
# Epoch 68: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 598160.8125 - val_loss: 72633.0469 - 558ms/epoch - 80ms/step
# Epoch 69/1000
#
# Epoch 69: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 660506.8750 - val_loss: 91611.5078 - 1s/epoch - 151ms/step
# Epoch 70/1000
#
# Epoch 70: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 616001.3750 - val_loss: 112236.0000 - 1s/epoch - 176ms/step
# Epoch 71/1000
#
# Epoch 71: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 559328.1875 - val_loss: 15800.4951 - 1s/epoch - 159ms/step
# Epoch 72/1000
#
# Epoch 72: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 575408.4375 - val_loss: 109912.8828 - 1s/epoch - 160ms/step
# Epoch 73/1000
#
# Epoch 73: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 616878.3125 - val_loss: 5557.4663 - 1s/epoch - 154ms/step
# Epoch 74/1000
#
# Epoch 74: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 674620.2500 - val_loss: 12918.1553 - 685ms/epoch - 98ms/step
# Epoch 75/1000
#
# Epoch 75: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 615077.5625 - val_loss: 9138.0859 - 568ms/epoch - 81ms/step
# Epoch 76/1000
#
# Epoch 76: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 571020.7500 - val_loss: 135786.4531 - 515ms/epoch - 74ms/step
# Epoch 77/1000
#
# Epoch 77: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 588202.2500 - val_loss: 45539.7500 - 536ms/epoch - 77ms/step
# Epoch 78/1000
#
# Epoch 78: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 560209.1250 - val_loss: 8018.7251 - 537ms/epoch - 77ms/step
# Epoch 79/1000
#
# Epoch 79: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 494211.0625 - val_loss: 18122.6992 - 551ms/epoch - 79ms/step
# Epoch 80/1000
#
# Epoch 80: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 580256.7500 - val_loss: 92423.1875 - 571ms/epoch - 82ms/step
# Epoch 81/1000
#
# Epoch 81: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 574108.1875 - val_loss: 19060.3770 - 514ms/epoch - 73ms/step
# Epoch 82/1000
#
# Epoch 82: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 563831.9375 - val_loss: 70908.7734 - 525ms/epoch - 75ms/step
# Epoch 83/1000
#
# Epoch 83: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 541862.9375 - val_loss: 54183.9883 - 545ms/epoch - 78ms/step
# Epoch 84/1000
#
# Epoch 84: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 541944.5000 - val_loss: 27300.9609 - 550ms/epoch - 79ms/step
# Epoch 85/1000
#
# Epoch 85: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 550852.5625 - val_loss: 84814.9219 - 542ms/epoch - 77ms/step
# Epoch 86/1000
#
# Epoch 86: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 529253.6875 - val_loss: 136707.3594 - 533ms/epoch - 76ms/step
# Epoch 87/1000
#
# Epoch 87: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 553858.3750 - val_loss: 44907.4414 - 533ms/epoch - 76ms/step
# Epoch 88/1000
#
# Epoch 88: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 610825.4375 - val_loss: 151501.4062 - 547ms/epoch - 78ms/step
# Epoch 89/1000
#
# Epoch 89: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 508676.4375 - val_loss: 58041.8516 - 534ms/epoch - 76ms/step
# Epoch 90/1000
#
# Epoch 90: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 589911.5000 - val_loss: 67434.9141 - 528ms/epoch - 75ms/step
# Epoch 91/1000
#
# Epoch 91: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 509854.6562 - val_loss: 67661.5000 - 533ms/epoch - 76ms/step
# Epoch 92/1000
#
# Epoch 92: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 516719.0625 - val_loss: 73907.1328 - 651ms/epoch - 93ms/step
# Epoch 93/1000
#
# Epoch 93: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 517092.0312 - val_loss: 90632.6094 - 1s/epoch - 174ms/step
# Epoch 94/1000
#
# Epoch 94: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 493616.4688 - val_loss: 81606.5312 - 1s/epoch - 160ms/step
# Epoch 95/1000
#
# Epoch 95: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 523005.7812 - val_loss: 57509.2617 - 1s/epoch - 151ms/step
# Epoch 96/1000
#
# Epoch 96: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 570222.1250 - val_loss: 56887.4141 - 1s/epoch - 156ms/step
# Epoch 97/1000
#
# Epoch 97: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 559510.9375 - val_loss: 130167.7578 - 1s/epoch - 150ms/step
# Epoch 98/1000
#
# Epoch 98: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 554178.0625 - val_loss: 107959.3203 - 535ms/epoch - 76ms/step
# Epoch 99/1000
#
# Epoch 99: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 500432.8750 - val_loss: 46659.4609 - 525ms/epoch - 75ms/step
# Epoch 100/1000
#
# Epoch 100: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 518206.8125 - val_loss: 62289.1758 - 513ms/epoch - 73ms/step
# Epoch 101/1000
#
# Epoch 101: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 543621.6250 - val_loss: 64786.6484 - 599ms/epoch - 86ms/step
# Epoch 102/1000
#
# Epoch 102: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 530044.1250 - val_loss: 75140.6172 - 502ms/epoch - 72ms/step
# Epoch 103/1000
#
# Epoch 103: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 551765.2500 - val_loss: 4384.2124 - 579ms/epoch - 83ms/step
# Epoch 104/1000
#
# Epoch 104: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 599901.8125 - val_loss: 138749.0000 - 512ms/epoch - 73ms/step
# Epoch 105/1000
#
# Epoch 105: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 513992.2188 - val_loss: 59283.0469 - 528ms/epoch - 75ms/step
# Epoch 106/1000
#
# Epoch 106: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 533642.4375 - val_loss: 21139.8223 - 509ms/epoch - 73ms/step
# Epoch 107/1000
#
# Epoch 107: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 593373.3750 - val_loss: 89969.5938 - 581ms/epoch - 83ms/step
# Epoch 108/1000
#
# Epoch 108: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 515360.0938 - val_loss: 72483.3125 - 521ms/epoch - 74ms/step
# Epoch 109/1000
#
# Epoch 109: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 495808.0312 - val_loss: 67155.8984 - 564ms/epoch - 81ms/step
# Epoch 110/1000
#
# Epoch 110: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 521989.9375 - val_loss: 96533.4297 - 532ms/epoch - 76ms/step
# Epoch 111/1000
#
# Epoch 111: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 511485.4062 - val_loss: 27087.4492 - 552ms/epoch - 79ms/step
# Epoch 112/1000
#
# Epoch 112: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 542699.5625 - val_loss: 31980.8105 - 565ms/epoch - 81ms/step
# Epoch 113/1000
#
# Epoch 113: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 576926.8750 - val_loss: 75567.2969 - 604ms/epoch - 86ms/step
# Epoch 114/1000
#
# Epoch 114: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 513543.2500 - val_loss: 89614.0781 - 512ms/epoch - 73ms/step
# Epoch 115/1000
#
# Epoch 115: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 504674.2812 - val_loss: 67223.7500 - 504ms/epoch - 72ms/step
# Epoch 116/1000
#
# Epoch 116: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 470778.7812 - val_loss: 141003.2031 - 862ms/epoch - 123ms/step
# Epoch 117/1000
#
# Epoch 117: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 510415.8125 - val_loss: 8272.5488 - 1s/epoch - 167ms/step
# Epoch 118/1000
#
# Epoch 118: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 567097.5000 - val_loss: 142384.9062 - 1s/epoch - 154ms/step
# Epoch 119/1000
#
# Epoch 119: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 570050.6250 - val_loss: 54567.6016 - 1s/epoch - 154ms/step
# Epoch 120/1000
#
# Epoch 120: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 507966.1250 - val_loss: 80538.4297 - 1s/epoch - 159ms/step
# Epoch 121/1000
#
# Epoch 121: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 513844.8438 - val_loss: 109485.7578 - 888ms/epoch - 127ms/step
# Epoch 122/1000
#
# Epoch 122: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 514647.4375 - val_loss: 47336.5312 - 518ms/epoch - 74ms/step
# Epoch 123/1000
#
# Epoch 123: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 533731.4375 - val_loss: 62802.4297 - 583ms/epoch - 83ms/step
# Epoch 124/1000
#
# Epoch 124: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 452648.0938 - val_loss: 54936.7188 - 555ms/epoch - 79ms/step
# Epoch 125/1000
#
# Epoch 125: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 548478.5000 - val_loss: 68894.8672 - 516ms/epoch - 74ms/step
# Epoch 126/1000
#
# Epoch 126: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 494044.4688 - val_loss: 130294.4219 - 530ms/epoch - 76ms/step
# Epoch 127/1000
#
# Epoch 127: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 544702.4375 - val_loss: 56959.8711 - 553ms/epoch - 79ms/step
# Epoch 128/1000
#
# Epoch 128: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 512650.0625 - val_loss: 158585.4844 - 553ms/epoch - 79ms/step
# Epoch 129/1000
#
# Epoch 129: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 453573.5625 - val_loss: 42309.3086 - 518ms/epoch - 74ms/step
# Epoch 130/1000
#
# Epoch 130: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 532327.2500 - val_loss: 162990.4062 - 549ms/epoch - 78ms/step
# Epoch 131/1000
#
# Epoch 131: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 523937.5938 - val_loss: 37763.1445 - 552ms/epoch - 79ms/step
# Epoch 132/1000
#
# Epoch 132: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 543524.8750 - val_loss: 99617.0625 - 535ms/epoch - 76ms/step
# Epoch 133/1000
#
# Epoch 133: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 472326.4062 - val_loss: 70959.3516 - 515ms/epoch - 74ms/step
# Epoch 134/1000
#
# Epoch 134: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 586634.3125 - val_loss: 125085.6172 - 514ms/epoch - 73ms/step
# Epoch 135/1000
#
# Epoch 135: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 559575.0000 - val_loss: 85135.4219 - 596ms/epoch - 85ms/step
# Epoch 136/1000
#
# Epoch 136: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 458270.9062 - val_loss: 81593.8438 - 616ms/epoch - 88ms/step
# Epoch 137/1000
#
# Epoch 137: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 504625.2188 - val_loss: 161122.6719 - 533ms/epoch - 76ms/step
# Epoch 138/1000
#
# Epoch 138: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 478866.5938 - val_loss: 111598.9609 - 506ms/epoch - 72ms/step
# Epoch 139/1000
#
# Epoch 139: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 424841.4688 - val_loss: 58503.3047 - 576ms/epoch - 82ms/step
# Epoch 140/1000
#
# Epoch 140: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 484605.7812 - val_loss: 157694.5156 - 1s/epoch - 171ms/step
# Epoch 141/1000
#
# Epoch 141: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 428845.8750 - val_loss: 102383.6328 - 1s/epoch - 166ms/step
# Epoch 142/1000
#
# Epoch 142: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 469677.6875 - val_loss: 112241.1797 - 1s/epoch - 169ms/step
# Epoch 143/1000
#
# Epoch 143: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 478310.3750 - val_loss: 67024.9688 - 1s/epoch - 164ms/step
# Epoch 144/1000
#
# Epoch 144: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 455677.3438 - val_loss: 68227.3984 - 927ms/epoch - 132ms/step
# Epoch 145/1000
#
# Epoch 145: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 497264.0938 - val_loss: 64496.4531 - 680ms/epoch - 97ms/step
# Epoch 146/1000
#
# Epoch 146: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 486902.4062 - val_loss: 44643.8633 - 533ms/epoch - 76ms/step
# Epoch 147/1000
#
# Epoch 147: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 438284.5312 - val_loss: 78034.9766 - 562ms/epoch - 80ms/step
# Epoch 148/1000
#
# Epoch 148: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 475393.4688 - val_loss: 51789.8398 - 573ms/epoch - 82ms/step
# Epoch 149/1000
#
# Epoch 149: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 550949.8750 - val_loss: 180188.2344 - 514ms/epoch - 73ms/step
# Epoch 150/1000
#
# Epoch 150: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 492140.8750 - val_loss: 23232.6797 - 562ms/epoch - 80ms/step
# Epoch 151/1000
#
# Epoch 151: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 436888.3750 - val_loss: 138112.2188 - 531ms/epoch - 76ms/step
# Epoch 152/1000
#
# Epoch 152: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 482659.9062 - val_loss: 45988.8789 - 535ms/epoch - 76ms/step
# Epoch 153/1000
#
# Epoch 153: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 473804.5625 - val_loss: 193728.6875 - 504ms/epoch - 72ms/step
# Epoch 154/1000
#
# Epoch 154: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 521624.4062 - val_loss: 74994.5625 - 547ms/epoch - 78ms/step
# Epoch 155/1000
#
# Epoch 155: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 473101.4062 - val_loss: 87062.2188 - 520ms/epoch - 74ms/step
# Epoch 156/1000
#
# Epoch 156: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 483914.5312 - val_loss: 158815.0000 - 528ms/epoch - 75ms/step
# Epoch 157/1000
#
# Epoch 157: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 475914.0625 - val_loss: 7763.5601 - 502ms/epoch - 72ms/step
# Epoch 158/1000
#
# Epoch 158: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 538011.8750 - val_loss: 5363.8257 - 567ms/epoch - 81ms/step
# Epoch 159/1000
#
# Epoch 159: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 507977.2188 - val_loss: 62352.8203 - 508ms/epoch - 73ms/step
# Epoch 160/1000
#
# Epoch 160: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 489939.4688 - val_loss: 5169.1826 - 539ms/epoch - 77ms/step
# Epoch 161/1000
#
# Epoch 161: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 472168.8438 - val_loss: 52220.1406 - 519ms/epoch - 74ms/step
# Epoch 162/1000
#
# Epoch 162: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 479628.5312 - val_loss: 18024.5684 - 617ms/epoch - 88ms/step
# Epoch 163/1000
#
# Epoch 163: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 497861.7812 - val_loss: 82691.3984 - 706ms/epoch - 101ms/step
# Epoch 164/1000
#
# Epoch 164: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 499604.4688 - val_loss: 27362.4219 - 1s/epoch - 163ms/step
# Epoch 165/1000
#
# Epoch 165: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 493599.6250 - val_loss: 57587.3203 - 1s/epoch - 162ms/step
# Epoch 166/1000
#
# Epoch 166: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 462380.0312 - val_loss: 40689.6133 - 1s/epoch - 154ms/step
# Epoch 167/1000
#
# Epoch 167: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 437072.8750 - val_loss: 15003.5840 - 1s/epoch - 150ms/step
# Epoch 168/1000
#
# Epoch 168: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 390800.0312 - val_loss: 59172.1055 - 1s/epoch - 156ms/step
# Epoch 169/1000
#
# Epoch 169: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 452553.5000 - val_loss: 4785.2676 - 600ms/epoch - 86ms/step
# Epoch 170/1000
#
# Epoch 170: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 530503.7500 - val_loss: 72254.4141 - 544ms/epoch - 78ms/step
# Epoch 171/1000
#
# Epoch 171: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 430004.4062 - val_loss: 60592.8203 - 564ms/epoch - 81ms/step
# Epoch 172/1000
#
# Epoch 172: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 440660.2500 - val_loss: 58656.8281 - 521ms/epoch - 74ms/step
# Epoch 173/1000
#
# Epoch 173: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 444466.3125 - val_loss: 36400.0703 - 539ms/epoch - 77ms/step
# Epoch 174/1000
#
# Epoch 174: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 477041.7188 - val_loss: 29590.1094 - 511ms/epoch - 73ms/step
# Epoch 175/1000
#
# Epoch 175: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 458208.1562 - val_loss: 22023.6934 - 537ms/epoch - 77ms/step
# Epoch 176/1000
#
# Epoch 176: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 421837.9375 - val_loss: 54343.2617 - 538ms/epoch - 77ms/step
# Epoch 177/1000
#
# Epoch 177: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 464316.5312 - val_loss: 31658.9395 - 524ms/epoch - 75ms/step
# Epoch 178/1000
#
# Epoch 178: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 428590.6875 - val_loss: 17772.0898 - 524ms/epoch - 75ms/step
# Epoch 179/1000
#
# Epoch 179: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 408106.9688 - val_loss: 11372.1201 - 591ms/epoch - 84ms/step
# Epoch 180/1000
#
# Epoch 180: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 449389.3125 - val_loss: 31765.9727 - 545ms/epoch - 78ms/step
# Epoch 181/1000
#
# Epoch 181: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 437251.1562 - val_loss: 25232.6953 - 550ms/epoch - 79ms/step
# Epoch 182/1000
#
# Epoch 182: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 391818.3125 - val_loss: 61110.4297 - 522ms/epoch - 75ms/step
# Epoch 183/1000
#
# Epoch 183: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 400244.2500 - val_loss: 15893.8887 - 523ms/epoch - 75ms/step
# Epoch 184/1000
#
# Epoch 184: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 469574.5000 - val_loss: 27753.2832 - 540ms/epoch - 77ms/step
# Epoch 185/1000
#
# Epoch 185: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 439467.0625 - val_loss: 31749.5859 - 503ms/epoch - 72ms/step
# Epoch 186/1000
#
# Epoch 186: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 419284.0625 - val_loss: 24237.6406 - 592ms/epoch - 85ms/step
# Epoch 187/1000
#
# Epoch 187: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 401103.7812 - val_loss: 69669.4375 - 969ms/epoch - 138ms/step
# Epoch 188/1000
#
# Epoch 188: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 433459.9688 - val_loss: 11600.9336 - 1s/epoch - 165ms/step
# Epoch 189/1000
#
# Epoch 189: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 384515.8125 - val_loss: 73829.6172 - 1s/epoch - 177ms/step
# Epoch 190/1000
#
# Epoch 190: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 414528.2188 - val_loss: 12329.2373 - 1s/epoch - 151ms/step
# Epoch 191/1000
#
# Epoch 191: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 420536.7188 - val_loss: 28919.6484 - 1s/epoch - 159ms/step
# Epoch 192/1000
#
# Epoch 192: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 358604.2500 - val_loss: 7356.6660 - 835ms/epoch - 119ms/step
# Epoch 193/1000
#
# Epoch 193: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 452898.8125 - val_loss: 51347.8906 - 548ms/epoch - 78ms/step
# Epoch 194/1000
#
# Epoch 194: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 420748.4688 - val_loss: 4920.2852 - 549ms/epoch - 78ms/step
# Epoch 195/1000
#
# Epoch 195: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 383963.2812 - val_loss: 93273.1406 - 524ms/epoch - 75ms/step
# Epoch 196/1000
#
# Epoch 196: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 391816.5000 - val_loss: 6796.9487 - 554ms/epoch - 79ms/step
# Epoch 197/1000
#
# Epoch 197: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 401724.8438 - val_loss: 86453.4609 - 514ms/epoch - 73ms/step
# Epoch 198/1000
#
# Epoch 198: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 370087.2188 - val_loss: 5783.5537 - 522ms/epoch - 75ms/step
# Epoch 199/1000
#
# Epoch 199: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 455740.1875 - val_loss: 39715.9648 - 528ms/epoch - 75ms/step
# Epoch 200/1000
#
# Epoch 200: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 375871.1562 - val_loss: 7969.3862 - 583ms/epoch - 83ms/step
# Epoch 201/1000
#
# Epoch 201: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 423914.0312 - val_loss: 37862.4844 - 545ms/epoch - 78ms/step
# Epoch 202/1000
#
# Epoch 202: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 422426.1250 - val_loss: 14222.7266 - 534ms/epoch - 76ms/step
# Epoch 203/1000
#
# Epoch 203: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 395476.6250 - val_loss: 41036.3359 - 541ms/epoch - 77ms/step
# Epoch 204/1000
#
# Epoch 204: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 424051.7812 - val_loss: 13755.5430 - 587ms/epoch - 84ms/step
# Epoch 205/1000
#
# Epoch 205: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 359737.5000 - val_loss: 40901.4336 - 531ms/epoch - 76ms/step
# Epoch 206/1000
#
# Epoch 206: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 400673.6250 - val_loss: 7588.4648 - 537ms/epoch - 77ms/step
# Epoch 207/1000
#
# Epoch 207: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 405056.1875 - val_loss: 52030.4883 - 551ms/epoch - 79ms/step
# Epoch 208/1000
#
# Epoch 208: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 390278.1875 - val_loss: 12800.9473 - 523ms/epoch - 75ms/step
# Epoch 209/1000
#
# Epoch 209: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 383333.5938 - val_loss: 27021.9746 - 552ms/epoch - 79ms/step
# Epoch 210/1000
#
# Epoch 210: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 471789.9688 - val_loss: 24627.2402 - 563ms/epoch - 80ms/step
# Epoch 211/1000
#
# Epoch 211: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 405796.4375 - val_loss: 33653.1953 - 1s/epoch - 166ms/step
# Epoch 212/1000
#
# Epoch 212: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 395115.0625 - val_loss: 32658.1895 - 1s/epoch - 158ms/step
# Epoch 213/1000
#
# Epoch 213: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 404731.6875 - val_loss: 41184.7500 - 1s/epoch - 173ms/step
# Epoch 214/1000
#
# Epoch 214: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 420691.0000 - val_loss: 6627.7852 - 1s/epoch - 166ms/step
# Epoch 215/1000
#
# Epoch 215: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 433075.3750 - val_loss: 27762.2773 - 1s/epoch - 150ms/step
# Epoch 216/1000
#
# Epoch 216: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 363928.2812 - val_loss: 7484.9482 - 609ms/epoch - 87ms/step
# Epoch 217/1000
#
# Epoch 217: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 487801.0000 - val_loss: 38709.8359 - 529ms/epoch - 76ms/step
# Epoch 218/1000
#
# Epoch 218: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 376628.0625 - val_loss: 13032.3174 - 561ms/epoch - 80ms/step
# Epoch 219/1000
#
# Epoch 219: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 419616.9375 - val_loss: 14832.1797 - 536ms/epoch - 77ms/step
# Epoch 220/1000
#
# Epoch 220: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 423420.7500 - val_loss: 8726.2764 - 540ms/epoch - 77ms/step
# Epoch 221/1000
#
# Epoch 221: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 418751.8438 - val_loss: 33910.3477 - 512ms/epoch - 73ms/step
# Epoch 222/1000
#
# Epoch 222: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 449204.2500 - val_loss: 11360.8564 - 532ms/epoch - 76ms/step
# Epoch 223/1000
#
# Epoch 223: val_loss did not improve from 2647.78687
# 7/7 - 0s - loss: 405556.8750 - val_loss: 40628.8359 - 498ms/epoch - 71ms/step
# Epoch 224/1000
#
# Epoch 224: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 421762.6875 - val_loss: 7543.5776 - 618ms/epoch - 88ms/step
# Epoch 225/1000
#
# Epoch 225: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 468990.6875 - val_loss: 58603.7500 - 534ms/epoch - 76ms/step
# Epoch 226/1000
#
# Epoch 226: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 428376.7812 - val_loss: 5704.1689 - 603ms/epoch - 86ms/step
# Epoch 227/1000
#
# Epoch 227: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 385754.4375 - val_loss: 64409.7891 - 551ms/epoch - 79ms/step
# Epoch 228/1000
#
# Epoch 228: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 391690.7500 - val_loss: 4738.0840 - 568ms/epoch - 81ms/step
# Epoch 229/1000
#
# Epoch 229: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 428341.5000 - val_loss: 69417.7734 - 560ms/epoch - 80ms/step
# Epoch 230/1000
#
# Epoch 230: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 364784.7500 - val_loss: 5460.2661 - 521ms/epoch - 74ms/step
# Epoch 231/1000
#
# Epoch 231: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 412242.4062 - val_loss: 44956.7109 - 591ms/epoch - 84ms/step
# Epoch 232/1000
#
# Epoch 232: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 366970.2188 - val_loss: 9715.4805 - 529ms/epoch - 76ms/step
# Epoch 233/1000
#
# Epoch 233: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 411454.4062 - val_loss: 24741.8379 - 538ms/epoch - 77ms/step
# Epoch 234/1000
#
# Epoch 234: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 371789.2188 - val_loss: 31920.8203 - 765ms/epoch - 109ms/step
# Epoch 235/1000
#
# Epoch 235: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 356146.4375 - val_loss: 13161.5752 - 1s/epoch - 170ms/step
# Epoch 236/1000
#
# Epoch 236: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 375626.3750 - val_loss: 18716.1504 - 1s/epoch - 163ms/step
# Epoch 237/1000
#
# Epoch 237: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 363566.4375 - val_loss: 38384.1016 - 1s/epoch - 144ms/step
# Epoch 238/1000
#
# Epoch 238: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 385456.5000 - val_loss: 46308.1406 - 1s/epoch - 165ms/step
# Epoch 239/1000
#
# Epoch 239: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 417387.9688 - val_loss: 6864.8862 - 876ms/epoch - 125ms/step
# Epoch 240/1000
#
# Epoch 240: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 414495.6875 - val_loss: 75468.6562 - 614ms/epoch - 88ms/step
# Epoch 241/1000
#
# Epoch 241: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 412949.4375 - val_loss: 6886.2812 - 548ms/epoch - 78ms/step
# Epoch 242/1000
#
# Epoch 242: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 404871.2188 - val_loss: 30079.3691 - 536ms/epoch - 77ms/step
# Epoch 243/1000
#
# Epoch 243: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 387402.8438 - val_loss: 19713.0273 - 530ms/epoch - 76ms/step
# Epoch 244/1000
#
# Epoch 244: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 415079.3125 - val_loss: 43746.7148 - 563ms/epoch - 80ms/step
# Epoch 245/1000
#
# Epoch 245: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 367769.7188 - val_loss: 21359.9258 - 559ms/epoch - 80ms/step
# Epoch 246/1000
#
# Epoch 246: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 426670.2812 - val_loss: 71166.4531 - 753ms/epoch - 108ms/step
# Epoch 247/1000
#
# Epoch 247: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 380767.3125 - val_loss: 15698.7930 - 553ms/epoch - 79ms/step
# Epoch 248/1000
#
# Epoch 248: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 372110.9688 - val_loss: 55770.1055 - 587ms/epoch - 84ms/step
# Epoch 249/1000
#
# Epoch 249: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 395478.2812 - val_loss: 13923.8760 - 528ms/epoch - 75ms/step
# Epoch 250/1000
#
# Epoch 250: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 424834.7500 - val_loss: 49983.2109 - 604ms/epoch - 86ms/step
# Epoch 251/1000
#
# Epoch 251: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 354131.7812 - val_loss: 30138.5547 - 552ms/epoch - 79ms/step
# Epoch 252/1000
#
# Epoch 252: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 404081.9375 - val_loss: 21011.6797 - 539ms/epoch - 77ms/step
# Epoch 253/1000
#
# Epoch 253: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 408654.6562 - val_loss: 25513.0098 - 548ms/epoch - 78ms/step
# Epoch 254/1000
#
# Epoch 254: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 398483.7500 - val_loss: 26959.7305 - 527ms/epoch - 75ms/step
# Epoch 255/1000
#
# Epoch 255: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 428613.2188 - val_loss: 26116.6699 - 583ms/epoch - 83ms/step
# Epoch 256/1000
#
# Epoch 256: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 359366.0938 - val_loss: 26364.3066 - 591ms/epoch - 84ms/step
# Epoch 257/1000
#
# Epoch 257: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 368081.9688 - val_loss: 25310.4551 - 989ms/epoch - 141ms/step
# Epoch 258/1000
#
# Epoch 258: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 407607.9375 - val_loss: 22432.3770 - 1s/epoch - 159ms/step
# Epoch 259/1000
#
# Epoch 259: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 390524.0625 - val_loss: 24626.7832 - 1s/epoch - 172ms/step
# Epoch 260/1000
#
# Epoch 260: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 408534.4062 - val_loss: 37014.3984 - 938ms/epoch - 134ms/step
# Epoch 261/1000
#
# Epoch 261: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 406221.9062 - val_loss: 40940.7109 - 1s/epoch - 165ms/step
# Epoch 262/1000
#
# Epoch 262: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 381176.5000 - val_loss: 12080.8271 - 825ms/epoch - 118ms/step
# Epoch 263/1000
#
# Epoch 263: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 444256.0625 - val_loss: 61432.8008 - 531ms/epoch - 76ms/step
# Epoch 264/1000
#
# Epoch 264: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 391744.0000 - val_loss: 28272.3906 - 512ms/epoch - 73ms/step
# Epoch 265/1000
#
# Epoch 265: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 385221.6250 - val_loss: 52679.1758 - 633ms/epoch - 90ms/step
# Epoch 266/1000
#
# Epoch 266: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 375180.3750 - val_loss: 14526.3477 - 541ms/epoch - 77ms/step
# Epoch 267/1000
#
# Epoch 267: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 385454.8438 - val_loss: 44937.0547 - 544ms/epoch - 78ms/step
# Epoch 268/1000
#
# Epoch 268: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 461796.5312 - val_loss: 10105.8291 - 564ms/epoch - 81ms/step
# Epoch 269/1000
#
# Epoch 269: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 349286.3125 - val_loss: 28759.7969 - 588ms/epoch - 84ms/step
# Epoch 270/1000
#
# Epoch 270: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 399973.0312 - val_loss: 38965.7891 - 556ms/epoch - 79ms/step
# Epoch 271/1000
#
# Epoch 271: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 377399.3125 - val_loss: 12733.6699 - 535ms/epoch - 76ms/step
# Epoch 272/1000
#
# Epoch 272: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 409551.5625 - val_loss: 71619.1484 - 560ms/epoch - 80ms/step
# Epoch 273/1000
#
# Epoch 273: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 394745.4688 - val_loss: 37037.2773 - 508ms/epoch - 73ms/step
# Epoch 274/1000
#
# Epoch 274: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 436983.5625 - val_loss: 19731.7617 - 532ms/epoch - 76ms/step
# Epoch 275/1000
#
# Epoch 275: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 434873.8750 - val_loss: 65574.1875 - 524ms/epoch - 75ms/step
# Epoch 276/1000
#
# Epoch 276: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 367336.6562 - val_loss: 27654.3477 - 576ms/epoch - 82ms/step
# Epoch 277/1000
#
# Epoch 277: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 394870.0625 - val_loss: 23839.1641 - 512ms/epoch - 73ms/step
# Epoch 278/1000
#
# Epoch 278: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 378471.7812 - val_loss: 24461.6875 - 513ms/epoch - 73ms/step
# Epoch 279/1000
#
# Epoch 279: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 405054.4062 - val_loss: 20951.9395 - 577ms/epoch - 82ms/step
# Epoch 280/1000
#
# Epoch 280: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 410790.2812 - val_loss: 55928.1484 - 732ms/epoch - 105ms/step
# Epoch 281/1000
#
# Epoch 281: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 384954.6875 - val_loss: 11003.5078 - 1s/epoch - 176ms/step
# Epoch 282/1000
#
# Epoch 282: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 356160.6250 - val_loss: 29010.7207 - 1s/epoch - 165ms/step
# Epoch 283/1000
#
# Epoch 283: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 355543.2188 - val_loss: 22698.9492 - 1s/epoch - 163ms/step
# Epoch 284/1000
#
# Epoch 284: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 331901.5000 - val_loss: 35157.6797 - 1s/epoch - 162ms/step
# Epoch 285/1000
#
# Epoch 285: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 345824.8438 - val_loss: 29531.6797 - 907ms/epoch - 130ms/step
# Epoch 286/1000
#
# Epoch 286: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 385659.6875 - val_loss: 48687.2383 - 545ms/epoch - 78ms/step
# Epoch 287/1000
#
# Epoch 287: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 435739.3750 - val_loss: 12781.3701 - 579ms/epoch - 83ms/step
# Epoch 288/1000
#
# Epoch 288: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 360290.8125 - val_loss: 27780.4492 - 529ms/epoch - 76ms/step
# Epoch 289/1000
#
# Epoch 289: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 376693.7188 - val_loss: 13889.8096 - 540ms/epoch - 77ms/step
# Epoch 290/1000
#
# Epoch 290: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 401029.0000 - val_loss: 31026.2148 - 567ms/epoch - 81ms/step
# Epoch 291/1000
#
# Epoch 291: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 408117.5000 - val_loss: 25427.1250 - 582ms/epoch - 83ms/step
# Epoch 292/1000
#
# Epoch 292: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 354698.3125 - val_loss: 68732.0781 - 512ms/epoch - 73ms/step
# Epoch 293/1000
#
# Epoch 293: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 406314.6250 - val_loss: 22968.0332 - 533ms/epoch - 76ms/step
# Epoch 294/1000
#
# Epoch 294: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 391686.3438 - val_loss: 55967.8242 - 595ms/epoch - 85ms/step
# Epoch 295/1000
#
# Epoch 295: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 412670.1250 - val_loss: 28293.3828 - 532ms/epoch - 76ms/step
# Epoch 296/1000
#
# Epoch 296: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 367541.3125 - val_loss: 24026.6758 - 530ms/epoch - 76ms/step
# Epoch 297/1000
#
# Epoch 297: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 392203.2500 - val_loss: 34329.3242 - 545ms/epoch - 78ms/step
# Epoch 298/1000
#
# Epoch 298: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 415704.4375 - val_loss: 4449.9868 - 513ms/epoch - 73ms/step
# Epoch 299/1000
#
# Epoch 299: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 393817.1250 - val_loss: 100311.3984 - 564ms/epoch - 81ms/step
# Epoch 300/1000
#
# Epoch 300: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 464373.7188 - val_loss: 7743.9390 - 523ms/epoch - 75ms/step
# Epoch 301/1000
#
# Epoch 301: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 421950.5938 - val_loss: 23028.6973 - 528ms/epoch - 75ms/step
# Epoch 302/1000
#
# Epoch 302: val_loss did not improve from 2647.78687
# ...
# 7/7 - 1s - loss: 318594.7500 - val_loss: 27832.2656 - 549ms/epoch - 78ms/step
# Epoch 893/1000
#
# Epoch 893: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 273584.1875 - val_loss: 42173.3281 - 601ms/epoch - 86ms/step
# Epoch 894/1000
#
# Epoch 894: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 306645.1250 - val_loss: 8262.2412 - 1s/epoch - 143ms/step
# Epoch 895/1000
#
# Epoch 895: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 277428.2188 - val_loss: 23958.9941 - 1s/epoch - 153ms/step
# Epoch 896/1000
#
# Epoch 896: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 296015.5000 - val_loss: 12638.4277 - 1s/epoch - 173ms/step
# Epoch 897/1000
#
# Epoch 897: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 288805.6562 - val_loss: 31820.6172 - 991ms/epoch - 142ms/step
# Epoch 898/1000
#
# Epoch 898: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 297602.3438 - val_loss: 23730.5234 - 1s/epoch - 152ms/step
# Epoch 899/1000
#
# Epoch 899: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 293240.0000 - val_loss: 15008.1064 - 827ms/epoch - 118ms/step
# Epoch 900/1000
#
# Epoch 900: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 274196.4375 - val_loss: 9889.5986 - 530ms/epoch - 76ms/step
# Epoch 901/1000
#
# Epoch 901: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 292713.0000 - val_loss: 11656.0986 - 616ms/epoch - 88ms/step
# Epoch 902/1000
#
# Epoch 902: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 294148.1562 - val_loss: 7647.9248 - 506ms/epoch - 72ms/step
# Epoch 903/1000
#
# Epoch 903: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 345292.2500 - val_loss: 28845.5742 - 536ms/epoch - 77ms/step
# Epoch 904/1000
#
# Epoch 904: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 292942.7500 - val_loss: 15751.3174 - 519ms/epoch - 74ms/step
# Epoch 905/1000
#
# Epoch 905: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 287030.8125 - val_loss: 11982.3750 - 541ms/epoch - 77ms/step
# Epoch 906/1000
#
# Epoch 906: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 273967.8438 - val_loss: 11457.6934 - 519ms/epoch - 74ms/step
# Epoch 907/1000
#
# Epoch 907: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 320170.8750 - val_loss: 24750.5293 - 528ms/epoch - 75ms/step
# Epoch 908/1000
#
# Epoch 908: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 294456.2500 - val_loss: 31036.0957 - 513ms/epoch - 73ms/step
# Epoch 909/1000
#
# Epoch 909: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 279683.2500 - val_loss: 34549.3633 - 577ms/epoch - 82ms/step
# Epoch 910/1000
#
# Epoch 910: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 277031.6250 - val_loss: 53660.4883 - 552ms/epoch - 79ms/step
# Epoch 911/1000
#
# Epoch 911: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 311093.5938 - val_loss: 16130.3174 - 539ms/epoch - 77ms/step
# Epoch 912/1000
#
# Epoch 912: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 282458.9688 - val_loss: 13517.2275 - 518ms/epoch - 74ms/step
# Epoch 913/1000
#
# Epoch 913: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 275315.4375 - val_loss: 31774.2246 - 538ms/epoch - 77ms/step
# Epoch 914/1000
#
# Epoch 914: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 297517.7812 - val_loss: 9193.0195 - 583ms/epoch - 83ms/step
# Epoch 915/1000
#
# Epoch 915: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 274878.1875 - val_loss: 27752.6855 - 531ms/epoch - 76ms/step
# Epoch 916/1000
#
# Epoch 916: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 302209.3125 - val_loss: 16011.8926 - 530ms/epoch - 76ms/step
# Epoch 917/1000
#
# Epoch 917: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 256890.8125 - val_loss: 20413.7559 - 528ms/epoch - 75ms/step
# Epoch 918/1000
#
# Epoch 918: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 311925.1562 - val_loss: 10604.5742 - 1s/epoch - 162ms/step
# Epoch 919/1000
#
# Epoch 919: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 303419.6875 - val_loss: 17711.9551 - 1s/epoch - 166ms/step
# Epoch 920/1000
#
# Epoch 920: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 304757.3438 - val_loss: 15759.1387 - 1s/epoch - 144ms/step
# Epoch 921/1000
#
# Epoch 921: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 315503.4688 - val_loss: 7334.4512 - 1s/epoch - 149ms/step
# Epoch 922/1000
#
# Epoch 922: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 255138.4844 - val_loss: 55048.1602 - 1s/epoch - 171ms/step
# Epoch 923/1000
#
# Epoch 923: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 315139.7500 - val_loss: 12893.9736 - 692ms/epoch - 99ms/step
# Epoch 924/1000
#
# Epoch 924: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 328960.1875 - val_loss: 32743.4082 - 537ms/epoch - 77ms/step
# Epoch 925/1000
#
# Epoch 925: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 254863.1719 - val_loss: 10661.9180 - 514ms/epoch - 73ms/step
# Epoch 926/1000
#
# Epoch 926: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 271585.5000 - val_loss: 8490.3789 - 658ms/epoch - 94ms/step
# Epoch 927/1000
#
# Epoch 927: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 293995.3750 - val_loss: 26123.6953 - 581ms/epoch - 83ms/step
# Epoch 928/1000
#
# Epoch 928: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 328062.1875 - val_loss: 24316.7559 - 542ms/epoch - 77ms/step
# Epoch 929/1000
#
# Epoch 929: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 273928.6250 - val_loss: 11919.9697 - 527ms/epoch - 75ms/step
# Epoch 930/1000
#
# Epoch 930: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 284310.1250 - val_loss: 15945.3271 - 635ms/epoch - 91ms/step
# Epoch 931/1000
#
# Epoch 931: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 287894.3438 - val_loss: 7872.8140 - 574ms/epoch - 82ms/step
# Epoch 932/1000
#
# Epoch 932: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 283545.2500 - val_loss: 18993.2031 - 543ms/epoch - 78ms/step
# Epoch 933/1000
#
# Epoch 933: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 317725.1250 - val_loss: 41379.0156 - 567ms/epoch - 81ms/step
# Epoch 934/1000
#
# Epoch 934: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 318305.8750 - val_loss: 25459.1367 - 512ms/epoch - 73ms/step
# Epoch 935/1000
#
# Epoch 935: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 306039.2812 - val_loss: 49186.4961 - 554ms/epoch - 79ms/step
# Epoch 936/1000
#
# Epoch 936: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 303781.5625 - val_loss: 9389.1143 - 504ms/epoch - 72ms/step
# Epoch 937/1000
#
# Epoch 937: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 327120.9688 - val_loss: 23562.6504 - 533ms/epoch - 76ms/step
# Epoch 938/1000
#
# Epoch 938: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 299021.2812 - val_loss: 28087.2051 - 571ms/epoch - 82ms/step
# Epoch 939/1000
#
# Epoch 939: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 263395.9375 - val_loss: 20911.8984 - 597ms/epoch - 85ms/step
# Epoch 940/1000
#
# Epoch 940: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 283016.2812 - val_loss: 16690.2773 - 508ms/epoch - 73ms/step
# Epoch 941/1000
#
# Epoch 941: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 306314.7500 - val_loss: 27912.1504 - 1s/epoch - 166ms/step
# Epoch 942/1000
#
# Epoch 942: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 339468.7500 - val_loss: 12156.4297 - 1s/epoch - 166ms/step
# Epoch 943/1000
#
# Epoch 943: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 314089.5938 - val_loss: 43748.4102 - 1s/epoch - 178ms/step
# Epoch 944/1000
#
# Epoch 944: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 311742.0625 - val_loss: 14899.3203 - 771ms/epoch - 110ms/step
# Epoch 945/1000
#
# Epoch 945: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 319443.2500 - val_loss: 35415.6133 - 1s/epoch - 164ms/step
# Epoch 946/1000
#
# Epoch 946: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 294778.6250 - val_loss: 18498.8379 - 731ms/epoch - 104ms/step
# Epoch 947/1000
#
# Epoch 947: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 260813.3125 - val_loss: 25047.2559 - 520ms/epoch - 74ms/step
# Epoch 948/1000
#
# Epoch 948: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 317843.0000 - val_loss: 10936.5811 - 522ms/epoch - 75ms/step
# Epoch 949/1000
#
# Epoch 949: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 283915.7812 - val_loss: 19598.9121 - 536ms/epoch - 77ms/step
# Epoch 950/1000
#
# Epoch 950: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 283164.8750 - val_loss: 25218.7969 - 598ms/epoch - 85ms/step
# Epoch 951/1000
#
# Epoch 951: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 292372.6875 - val_loss: 25252.3906 - 510ms/epoch - 73ms/step
# Epoch 952/1000
#
# Epoch 952: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 292759.7500 - val_loss: 28835.9844 - 530ms/epoch - 76ms/step
# Epoch 953/1000
#
# Epoch 953: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 301990.9062 - val_loss: 9797.8496 - 559ms/epoch - 80ms/step
# Epoch 954/1000
#
# Epoch 954: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 295174.1562 - val_loss: 7403.7188 - 542ms/epoch - 77ms/step
# Epoch 955/1000
#
# Epoch 955: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 317378.0938 - val_loss: 22192.8008 - 511ms/epoch - 73ms/step
# Epoch 956/1000
#
# Epoch 956: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 316224.9375 - val_loss: 9826.5400 - 532ms/epoch - 76ms/step
# Epoch 957/1000
#
# Epoch 957: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 282037.5625 - val_loss: 32804.7891 - 537ms/epoch - 77ms/step
# Epoch 958/1000
#
# Epoch 958: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 325709.8125 - val_loss: 7489.7124 - 519ms/epoch - 74ms/step
# Epoch 959/1000
#
# Epoch 959: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 284404.1562 - val_loss: 14325.4424 - 526ms/epoch - 75ms/step
# Epoch 960/1000
#
# Epoch 960: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 288608.0312 - val_loss: 10941.2002 - 560ms/epoch - 80ms/step
# Epoch 961/1000
#
# Epoch 961: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 292915.9688 - val_loss: 32163.7754 - 537ms/epoch - 77ms/step
# Epoch 962/1000
#
# Epoch 962: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 335780.9062 - val_loss: 18107.3750 - 550ms/epoch - 79ms/step
# Epoch 963/1000
#
# Epoch 963: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 288615.3750 - val_loss: 14373.5146 - 530ms/epoch - 76ms/step
# Epoch 964/1000
#
# Epoch 964: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 283874.6250 - val_loss: 24042.8301 - 629ms/epoch - 90ms/step
# Epoch 965/1000
#
# Epoch 965: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 283881.8438 - val_loss: 32180.0508 - 1s/epoch - 161ms/step
# Epoch 966/1000
#
# Epoch 966: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 315589.3125 - val_loss: 17258.1270 - 1s/epoch - 166ms/step
# Epoch 967/1000
#
# Epoch 967: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 294273.7188 - val_loss: 16750.5527 - 1s/epoch - 170ms/step
# Epoch 968/1000
#
# Epoch 968: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 285923.8438 - val_loss: 22069.1152 - 1s/epoch - 159ms/step
# Epoch 969/1000
#
# Epoch 969: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 284655.5938 - val_loss: 16367.9902 - 1s/epoch - 202ms/step
# Epoch 970/1000
#
# Epoch 970: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 296758.4375 - val_loss: 21204.2402 - 1s/epoch - 188ms/step
# Epoch 971/1000
#
# Epoch 971: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 296915.6875 - val_loss: 13311.1260 - 1s/epoch - 146ms/step
# Epoch 972/1000
#
# Epoch 972: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 270764.1562 - val_loss: 16586.0645 - 1s/epoch - 149ms/step
# Epoch 973/1000
#
# Epoch 973: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 304307.5938 - val_loss: 14209.8428 - 1s/epoch - 150ms/step
# Epoch 974/1000
#
# Epoch 974: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 306307.1562 - val_loss: 19626.9199 - 1s/epoch - 158ms/step
# Epoch 975/1000
#
# Epoch 975: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 275946.0938 - val_loss: 27552.3457 - 1s/epoch - 162ms/step
# Epoch 976/1000
#
# Epoch 976: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 273779.8438 - val_loss: 37837.3477 - 955ms/epoch - 136ms/step
# Epoch 977/1000
#
# Epoch 977: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 282517.2500 - val_loss: 12520.8076 - 546ms/epoch - 78ms/step
# Epoch 978/1000
#
# Epoch 978: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 280194.0000 - val_loss: 14331.7871 - 537ms/epoch - 77ms/step
# Epoch 979/1000
#
# Epoch 979: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 285984.2812 - val_loss: 4178.1338 - 534ms/epoch - 76ms/step
# Epoch 980/1000
#
# Epoch 980: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 295828.6250 - val_loss: 24406.6445 - 514ms/epoch - 73ms/step
# Epoch 981/1000
#
# Epoch 981: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 276822.4688 - val_loss: 20272.3594 - 523ms/epoch - 75ms/step
# Epoch 982/1000
#
# Epoch 982: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 306598.9688 - val_loss: 12188.9951 - 632ms/epoch - 90ms/step
# Epoch 983/1000
#
# Epoch 983: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 300473.1875 - val_loss: 19587.9316 - 583ms/epoch - 83ms/step
# Epoch 984/1000
#
# Epoch 984: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 282837.6562 - val_loss: 26872.7324 - 516ms/epoch - 74ms/step
# Epoch 985/1000
#
# Epoch 985: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 259663.4219 - val_loss: 33651.2617 - 689ms/epoch - 98ms/step
# Epoch 986/1000
#
# Epoch 986: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 315989.6875 - val_loss: 21697.3457 - 1s/epoch - 170ms/step
# Epoch 987/1000
#
# Epoch 987: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 296235.9062 - val_loss: 17035.5371 - 1s/epoch - 167ms/step
# Epoch 988/1000
#
# Epoch 988: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 283916.6562 - val_loss: 9305.4658 - 1s/epoch - 155ms/step
# Epoch 989/1000
#
# Epoch 989: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 304380.3750 - val_loss: 21098.1797 - 1s/epoch - 151ms/step
# Epoch 990/1000
#
# Epoch 990: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 251935.4219 - val_loss: 16869.0137 - 944ms/epoch - 135ms/step
# Epoch 991/1000
#
# Epoch 991: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 308542.9062 - val_loss: 19232.4355 - 612ms/epoch - 87ms/step
# Epoch 992/1000
#
# Epoch 992: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 295339.3125 - val_loss: 14481.4600 - 573ms/epoch - 82ms/step
# Epoch 993/1000
#
# Epoch 993: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 267201.1875 - val_loss: 23038.5684 - 581ms/epoch - 83ms/step
# Epoch 994/1000
#
# Epoch 994: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 268528.7812 - val_loss: 29315.5195 - 561ms/epoch - 80ms/step
# Epoch 995/1000
#
# Epoch 995: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 301643.5000 - val_loss: 33440.2969 - 579ms/epoch - 83ms/step
# Epoch 996/1000
#
# Epoch 996: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 309195.1250 - val_loss: 30600.4668 - 534ms/epoch - 76ms/step
# Epoch 997/1000
#
# Epoch 997: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 263950.5000 - val_loss: 28560.7148 - 508ms/epoch - 73ms/step
# Epoch 998/1000
#
# Epoch 998: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 304816.5000 - val_loss: 16045.6426 - 567ms/epoch - 81ms/step
# Epoch 999/1000
#
# Epoch 999: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 272826.1875 - val_loss: 20746.8809 - 533ms/epoch - 76ms/step
# Epoch 1000/1000
#
# Epoch 1000: val_loss did not improve from 2647.78687
# 7/7 - 1s - loss: 281737.3438 - val_loss: 17834.7109 - 514ms/epoch - 73ms/step
# 16/16 [==============================] - 1s 8ms/step
# 3/3 [==============================] - 0s 9ms/step
# Training MSE: 7282.590
# Testing MSE: 4769.143
# Training MAPE: 2.387%
# Testing MAPE: 2.352%
# accuracy : 49
