# %% [markdown]
# <a href="https://colab.research.google.com/github/hj2222222/API/blob/main/V5_2_experiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import os
import math
import matplotlib.pyplot as plt
import keras
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras import optimizers
from tensorflow.keras.layers import LSTM, Dropout, Dense, Conv1D, MaxPooling1D, Flatten
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Bidirectional
from keras.layers import Dropout, Flatten,TimeDistributed
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from tensorflow.keras.losses import Huber
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


stock_data = pd.read_csv('/content/drive/MyDrive/산업 AI 캡스톤/DATA/Total_Data/Final_Feature_kospi_sen_all.csv')
stock_data
# Out:
#          Date  Kospi_close  Kospi_high  ko_interest  oil_open  ex_JP_low  \
# 0    20210105      2990.57       0.795          0.0     0.213      0.590
# 1    20210106      2968.21       0.819          0.0     0.219      0.596
# 2    20210107      3031.68       0.839          0.0     0.225      0.597
# 3    20210108      3152.18       0.855          0.0     0.230      0.584
# 4    20210111      3148.45       0.914          0.0     0.232      0.584
# ..        ...          ...         ...          ...       ...        ...
# 583  20230623      2570.10       0.601          1.0     0.651      0.028
# 584  20230626      2582.20       0.602          1.0     0.651      0.024
# 585  20230627      2581.39       0.594          1.0     0.651      0.000
# 586  20230628      2564.19       0.592          1.0     0.651      0.011
# 587  20230629      2550.02       0.597          1.0     0.651      0.020
#
#      gold_low  us500_low  klue_bert_score_summarize_content  oil_vol  \
# 0       0.661      0.581                             -0.536    0.013
# 1       0.650      0.585                              1.381    0.006
# 2       0.670      0.608                              1.845    0.007
# 3       0.631      0.615                              2.497    0.004
# 4       0.623      0.617                             -0.951    0.009
# ..        ...        ...                                ...      ...
# 583     0.212      0.830                              0.402    0.000
# 584     0.212      0.825                             -0.385    0.000
# 585     0.208      0.828                             -0.447    0.000
# 586     0.217      0.838                              0.777    0.000
# 587     0.208      0.842                             -0.038    0.000
#
#      research_kospi  dji_vol  us500_vol  \
# 0             0.413    0.280      0.349
# 1             0.628    0.470      0.527
# 2             0.427    0.378      0.410
# 3             0.512    0.318      0.371
# 4             0.881    0.287      0.334
# ..              ...      ...        ...
# 583           0.125    0.316      0.526
# 584           0.120    0.170      0.207
# 585           0.118    0.206      0.226
# 586           0.128    0.174      0.246
# 587           0.127    0.189      0.241
#
#      kofinbert_score_summarize_content_kospi  kofinbert_score_title_kospi  \
# 0                                      0.157                        0.195
# 1                                      1.236                        0.569
# 2                                      0.537                        1.395
# 3                                      0.697                       -1.382
# 4                                      0.331                       -0.044
# ..                                       ...                          ...
# 583                                    0.834                       -0.339
# 584                                   -0.196                        0.681
# 585                                   -0.208                        0.625
# 586                                    1.099                        0.892
# 587                                    0.382                       -0.145
#
#      klue_bert_score_title
# 0                    0.823
# 1                    0.722
# 2                   -0.675
# 3                    1.124
# 4                    0.730
# ..                     ...
# 583                  0.831
# 584                 -0.001
# 585                 -0.097
# 586                  0.253
# 587                 -0.378
#
# [588 rows x 16 columns]

# %%
# 데이터 전처리
data = stock_data['Kospi_close'].values.reshape(-1, 1)
stock_data = stock_data.drop(['Kospi_close'],axis=1)
stock_data = stock_data.drop(['Date'],axis=1)

# %%
name = [stock_data.columns]

close_1 = ['klue_bert_score_summarize_content',
        'kofinbert_score_summarize_content_kospi']

stock_data_1 = stock_data.drop(close_1, axis=1)

# %%
# 데이터 분할
train_size = int(len(data) * 0.85)
train_data, test_data = data[:train_size], data[train_size:]
train_data_t_1, test_data_t_1 = stock_data_1[:train_size], stock_data_1[train_size:]
train_data_t_2, test_data_t_2 = stock_data[:train_size], stock_data[train_size:]

def create_dataset(dataset, data, look_back=10):
    X, y = [], []
    for i in range(len(data) - look_back):
        X.append(dataset[i:(i + look_back)])
        y.append(data[i + look_back])
    return np.array(X), np.array(y)

look_back = 5  # 몇 일 동안의 데이터를 사용할 것인지 설정

trainX, trainY = create_dataset(train_data_t_1, train_data, look_back)
testX, testY = create_dataset(test_data_t_1,test_data, look_back)
print(trainX.shape)
print(trainY.shape)
print(testX.shape)
print(testY.shape)
# Out:
# (494, 5, 12)
# (494, 1)
# (84, 5, 12)
# (84, 1)

# %%
def accuracy(list1,list2):
  list1 = list1.flatten().tolist()
  list2 = list2.flatten().tolist()
  value_1 = []
  value_2 = []
  j = 0
  if len(list1) == len(list2):
    for i in range(len(list1)-1):
      if list1[i+1] > list1[i]:
        value_1.append(1)
      elif list1[i+1] == list1[i]:
        value_1.append(0)
      else:
        value_1.append(-1)
    for i in range(len(list1)-1):
      if list2[i+1] > list2[i]:
        value_2.append(1)
      elif list2[i+1] == list2[i]:
        value_2.append(0)
      else:
        value_2.append(-1)
    for i in range(len(value_1)):
      if value_1[i] == value_2[i]:
        j = j + 1
    accuracy = j/len(value_1) * 100
    print("accuracy : %d" % accuracy)
  else:
    print("길이가 다릅니다.")

# %%
# 모델 생성 LSTM
model = Sequential()
model.add(LSTM(units=1024, activation='relu', return_sequences=True, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dropout(0.3))
model.add(LSTM(units=512, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(units=256, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(units=128, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(units=64, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(units=32, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(units=16, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(units=1))
model.summary()

# loss = Huber()
# optimizer = Adam(0.0005)
# model.compile(loss=Huber(), optimizer=optimizer, metrics=['mse'])

model.compile(optimizer='adam', loss='mean_squared_error')

filename = os.path.join('tmp', 'ckeckpointer.ckpt')
checkpoint = ModelCheckpoint(filename,
                             save_weights_only=True,
                             save_best_only=True,
                             monitor='val_loss',
                             verbose=1)

# 모델 학습
history = model.fit(trainX, trainY, epochs=1000, batch_size=64,
          validation_split=0.1, verbose=2,callbacks=[checkpoint])

model.save_weights('./ko_t_LSTM_weights.h3')

model.load_weights(filename)

plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()
plt.show()

# 예측
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# MSE 계산
trainMSE = mean_squared_error(trainY, trainPredict)
testMSE = mean_squared_error(testY, testPredict)

print(f'Training MSE: {trainMSE}')
print(f'Testing MSE: {testMSE}')

accuracy(testPredict,testY)

# 예측 시각화
plt.plot(trainY, label='Actual Price')
plt.plot(trainPredict, label='Predicted Price')
plt.legend()
plt.title('Training Data')
plt.show()

plt.plot(testY, label='Actual Price')
plt.plot(testPredict, label='Predicted Price')
plt.legend()
plt.title('Testing Data')
plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 5, 1024)           4247552
#
#  dropout (Dropout)           (None, 5, 1024)           0
#
#  lstm_1 (LSTM)               (None, 5, 512)            3147776
#
#  dropout_1 (Dropout)         (None, 5, 512)            0
#
#  lstm_2 (LSTM)               (None, 5, 256)            787456
#
#  dropout_2 (Dropout)         (None, 5, 256)            0
#
#  lstm_3 (LSTM)               (None, 5, 128)            197120
#
#  dropout_3 (Dropout)         (None, 5, 128)            0
#
#  lstm_4 (LSTM)               (None, 5, 64)             49408
#
#  dropout_4 (Dropout)         (None, 5, 64)             0
#
#  lstm_5 (LSTM)               (None, 5, 32)             12416
#
#  dropout_5 (Dropout)         (None, 5, 32)             0
#
#  lstm_6 (LSTM)               (None, 16)                3136
#
#  dropout_6 (Dropout)         (None, 16)                0
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 8444881 (32.21 MB)
# Trainable params: 8444881 (32.21 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/1000
#
# Epoch 1: val_loss improved from inf to 5710793.00000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 18s - loss: 8167921.5000 - val_loss: 5710793.0000 - 18s/epoch - 3s/step
# Epoch 2/1000
#
# Epoch 2: val_loss improved from 5710793.00000 to 5569314.50000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 6s - loss: 8150966.0000 - val_loss: 5569314.5000 - 6s/epoch - 847ms/step
# Epoch 3/1000
#
# Epoch 3: val_loss improved from 5569314.50000 to 5053598.00000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 7s - loss: 7794901.5000 - val_loss: 5053598.0000 - 7s/epoch - 951ms/step
# Epoch 4/1000
#
# Epoch 4: val_loss improved from 5053598.00000 to 4054661.75000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 5s - loss: 6031246.5000 - val_loss: 4054661.7500 - 5s/epoch - 701ms/step
# Epoch 5/1000
#
# Epoch 5: val_loss improved from 4054661.75000 to 46964.04688, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 6s - loss: 4831800.0000 - val_loss: 46964.0469 - 6s/epoch - 786ms/step
# Epoch 6/1000
#
# Epoch 6: val_loss did not improve from 46964.04688
# 7/7 - 7s - loss: 4853548.5000 - val_loss: 682003.0625 - 7s/epoch - 939ms/step
# Epoch 7/1000
#
# Epoch 7: val_loss did not improve from 46964.04688
# 7/7 - 5s - loss: 4801578.0000 - val_loss: 733060.3125 - 5s/epoch - 658ms/step
# Epoch 8/1000
#
# Epoch 8: val_loss did not improve from 46964.04688
# 7/7 - 5s - loss: 5007821.5000 - val_loss: 4816074.0000 - 5s/epoch - 683ms/step
# Epoch 9/1000
#
# Epoch 9: val_loss did not improve from 46964.04688
# 7/7 - 7s - loss: 4622435.5000 - val_loss: 1805061.6250 - 7s/epoch - 995ms/step
# Epoch 10/1000
#
# Epoch 10: val_loss did not improve from 46964.04688
# 7/7 - 5s - loss: 4467539.0000 - val_loss: 1735472.6250 - 5s/epoch - 681ms/step
# Epoch 11/1000
#
# Epoch 11: val_loss did not improve from 46964.04688
# 7/7 - 6s - loss: 4108136.2500 - val_loss: 1321235.6250 - 6s/epoch - 927ms/step
# Epoch 12/1000
#
# Epoch 12: val_loss did not improve from 46964.04688
# 7/7 - 7s - loss: 3436998.0000 - val_loss: 1802133.5000 - 7s/epoch - 1s/step
# Epoch 13/1000
#
# Epoch 13: val_loss did not improve from 46964.04688
# 7/7 - 5s - loss: 3514170.7500 - val_loss: 866655.0625 - 5s/epoch - 761ms/step
# Epoch 14/1000
#
# Epoch 14: val_loss did not improve from 46964.04688
# 7/7 - 5s - loss: 3286236.0000 - val_loss: 301172.7500 - 5s/epoch - 668ms/step
# Epoch 15/1000
#
# Epoch 15: val_loss did not improve from 46964.04688
# 7/7 - 9s - loss: 3208523.0000 - val_loss: 1964545.1250 - 9s/epoch - 1s/step
# Epoch 16/1000
#
# Epoch 16: val_loss did not improve from 46964.04688
# 7/7 - 5s - loss: 3548942.7500 - val_loss: 3539354.0000 - 5s/epoch - 691ms/step
# Epoch 17/1000
#
# Epoch 17: val_loss did not improve from 46964.04688
# 7/7 - 5s - loss: 3503034.0000 - val_loss: 3454648.0000 - 5s/epoch - 670ms/step
# Epoch 18/1000
#
# Epoch 18: val_loss did not improve from 46964.04688
# 7/7 - 6s - loss: 3223094.7500 - val_loss: 1855003.6250 - 6s/epoch - 913ms/step
# Epoch 19/1000
#
# Epoch 19: val_loss did not improve from 46964.04688
# 7/7 - 5s - loss: 2582340.5000 - val_loss: 1717030.8750 - 5s/epoch - 768ms/step
# Epoch 20/1000
#
# Epoch 20: val_loss improved from 46964.04688 to 27718.76758, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 5s - loss: 2634558.2500 - val_loss: 27718.7676 - 5s/epoch - 709ms/step
# Epoch 21/1000
#
# Epoch 21: val_loss did not improve from 27718.76758
# 7/7 - 6s - loss: 2188262.0000 - val_loss: 112295.7891 - 6s/epoch - 867ms/step
# Epoch 22/1000
#
# Epoch 22: val_loss did not improve from 27718.76758
# 7/7 - 6s - loss: 2121423.5000 - val_loss: 32830.7734 - 6s/epoch - 826ms/step
# Epoch 23/1000
#
# Epoch 23: val_loss improved from 27718.76758 to 19007.08203, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 5s - loss: 2328279.0000 - val_loss: 19007.0820 - 5s/epoch - 685ms/step
# Epoch 24/1000
#
# Epoch 24: val_loss did not improve from 19007.08203
# 7/7 - 5s - loss: 2265625.7500 - val_loss: 1069824.5000 - 5s/epoch - 783ms/step
# Epoch 25/1000
#
# Epoch 25: val_loss did not improve from 19007.08203
# 7/7 - 6s - loss: 2493332.2500 - val_loss: 204320.1562 - 6s/epoch - 904ms/step
# Epoch 26/1000
#
# Epoch 26: val_loss did not improve from 19007.08203
# 7/7 - 5s - loss: 2128938.5000 - val_loss: 376976.0000 - 5s/epoch - 663ms/step
# Epoch 27/1000
#
# Epoch 27: val_loss did not improve from 19007.08203
# 7/7 - 5s - loss: 1986615.7500 - val_loss: 531692.8125 - 5s/epoch - 699ms/step
# Epoch 28/1000
#
# Epoch 28: val_loss did not improve from 19007.08203
# 7/7 - 7s - loss: 2013353.6250 - val_loss: 479584.5625 - 7s/epoch - 1s/step
# Epoch 29/1000
#
# Epoch 29: val_loss did not improve from 19007.08203
# 7/7 - 5s - loss: 1778770.1250 - val_loss: 694717.6250 - 5s/epoch - 672ms/step
# Epoch 30/1000
#
# Epoch 30: val_loss did not improve from 19007.08203
# 7/7 - 5s - loss: 1568966.2500 - val_loss: 626427.6875 - 5s/epoch - 665ms/step
# Epoch 31/1000
#
# Epoch 31: val_loss did not improve from 19007.08203
# 7/7 - 7s - loss: 1327780.5000 - val_loss: 414711.8438 - 7s/epoch - 977ms/step
# Epoch 32/1000
#
# Epoch 32: val_loss did not improve from 19007.08203
# 7/7 - 5s - loss: 1629899.0000 - val_loss: 370572.6875 - 5s/epoch - 734ms/step
# Epoch 33/1000
#
# Epoch 33: val_loss improved from 19007.08203 to 18947.06445, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 5s - loss: 1529844.5000 - val_loss: 18947.0645 - 5s/epoch - 695ms/step
# Epoch 34/1000
#
# Epoch 34: val_loss did not improve from 18947.06445
# 7/7 - 6s - loss: 1505230.2500 - val_loss: 331854.3125 - 6s/epoch - 909ms/step
# Epoch 35/1000
#
# Epoch 35: val_loss did not improve from 18947.06445
# 7/7 - 6s - loss: 1265135.0000 - val_loss: 110670.8516 - 6s/epoch - 789ms/step
# Epoch 36/1000
#
# Epoch 36: val_loss did not improve from 18947.06445
# 7/7 - 5s - loss: 1422874.2500 - val_loss: 343590.7500 - 5s/epoch - 664ms/step
# Epoch 37/1000
#
# Epoch 37: val_loss did not improve from 18947.06445
# 7/7 - 6s - loss: 1317544.7500 - val_loss: 343736.4062 - 6s/epoch - 809ms/step
# Epoch 38/1000
#
# Epoch 38: val_loss did not improve from 18947.06445
# 7/7 - 6s - loss: 1383967.1250 - val_loss: 273971.9688 - 6s/epoch - 881ms/step
# Epoch 39/1000
#
# Epoch 39: val_loss did not improve from 18947.06445
# 7/7 - 5s - loss: 1403309.5000 - val_loss: 343981.0312 - 5s/epoch - 656ms/step
# Epoch 40/1000
#
# Epoch 40: val_loss did not improve from 18947.06445
# 7/7 - 5s - loss: 1316722.2500 - val_loss: 465969.1562 - 5s/epoch - 714ms/step
# Epoch 41/1000
#
# Epoch 41: val_loss did not improve from 18947.06445
# 7/7 - 7s - loss: 1502279.3750 - val_loss: 181636.0781 - 7s/epoch - 965ms/step
# Epoch 42/1000
#
# Epoch 42: val_loss did not improve from 18947.06445
# 7/7 - 5s - loss: 1313960.5000 - val_loss: 639289.3125 - 5s/epoch - 666ms/step
# Epoch 43/1000
#
# Epoch 43: val_loss did not improve from 18947.06445
# 7/7 - 5s - loss: 1307582.3750 - val_loss: 433711.7500 - 5s/epoch - 654ms/step
# Epoch 44/1000
#
# Epoch 44: val_loss did not improve from 18947.06445
# 7/7 - 7s - loss: 1369909.6250 - val_loss: 301511.6875 - 7s/epoch - 929ms/step
# Epoch 45/1000
#
# Epoch 45: val_loss did not improve from 18947.06445
# 7/7 - 5s - loss: 1263230.2500 - val_loss: 112877.0938 - 5s/epoch - 739ms/step
# Epoch 46/1000
#
# Epoch 46: val_loss did not improve from 18947.06445
# 7/7 - 5s - loss: 1177919.3750 - val_loss: 331335.1875 - 5s/epoch - 650ms/step
# Epoch 47/1000
#
# Epoch 47: val_loss did not improve from 18947.06445
# 7/7 - 6s - loss: 1231581.7500 - val_loss: 567727.3750 - 6s/epoch - 828ms/step
# Epoch 48/1000
#
# Epoch 48: val_loss did not improve from 18947.06445
# 7/7 - 6s - loss: 1195284.0000 - val_loss: 631995.4375 - 6s/epoch - 847ms/step
# Epoch 49/1000
#
# Epoch 49: val_loss did not improve from 18947.06445
# 7/7 - 4s - loss: 1059536.2500 - val_loss: 779707.2500 - 4s/epoch - 637ms/step
# Epoch 50/1000
#
# Epoch 50: val_loss did not improve from 18947.06445
# 7/7 - 5s - loss: 1116423.2500 - val_loss: 853067.8125 - 5s/epoch - 730ms/step
# Epoch 51/1000
#
# Epoch 51: val_loss did not improve from 18947.06445
# 7/7 - 7s - loss: 1195984.6250 - val_loss: 672171.2500 - 7s/epoch - 944ms/step
# Epoch 52/1000
#
# Epoch 52: val_loss did not improve from 18947.06445
# 7/7 - 4s - loss: 1215927.1250 - val_loss: 643700.2500 - 4s/epoch - 641ms/step
# Epoch 53/1000
#
# Epoch 53: val_loss did not improve from 18947.06445
# 7/7 - 5s - loss: 1049260.3750 - val_loss: 463814.4688 - 5s/epoch - 780ms/step
# Epoch 54/1000
#
# Epoch 54: val_loss did not improve from 18947.06445
# 7/7 - 8s - loss: 1075136.7500 - val_loss: 310574.3125 - 8s/epoch - 1s/step
# Epoch 55/1000
#
# Epoch 55: val_loss did not improve from 18947.06445
# 7/7 - 6s - loss: 1087284.7500 - val_loss: 495536.4688 - 6s/epoch - 898ms/step
# Epoch 56/1000
#
# Epoch 56: val_loss did not improve from 18947.06445
# 7/7 - 5s - loss: 1197405.0000 - val_loss: 334893.5938 - 5s/epoch - 672ms/step
# Epoch 57/1000
#
# Epoch 57: val_loss did not improve from 18947.06445
# 7/7 - 5s - loss: 1089430.0000 - val_loss: 274549.8125 - 5s/epoch - 757ms/step
# Epoch 58/1000
#
# Epoch 58: val_loss did not improve from 18947.06445
# 7/7 - 7s - loss: 1074703.7500 - val_loss: 590555.9375 - 7s/epoch - 940ms/step
# Epoch 59/1000
#
# Epoch 59: val_loss did not improve from 18947.06445
# 7/7 - 5s - loss: 1120761.6250 - val_loss: 773762.7500 - 5s/epoch - 658ms/step
# Epoch 60/1000
#
# Epoch 60: val_loss did not improve from 18947.06445
# 7/7 - 5s - loss: 1176313.7500 - val_loss: 509253.4062 - 5s/epoch - 670ms/step
# Epoch 61/1000
#
# Epoch 61: val_loss did not improve from 18947.06445
# 7/7 - 7s - loss: 1099114.5000 - val_loss: 755414.7500 - 7s/epoch - 1s/step
# Epoch 62/1000
#
# Epoch 62: val_loss did not improve from 18947.06445
# 7/7 - 6s - loss: 1051081.5000 - val_loss: 392691.5938 - 6s/epoch - 854ms/step
# Epoch 63/1000
#
# Epoch 63: val_loss did not improve from 18947.06445
# 7/7 - 5s - loss: 1010442.7500 - val_loss: 284018.4688 - 5s/epoch - 659ms/step
# Epoch 64/1000
#
# Epoch 64: val_loss did not improve from 18947.06445
# 7/7 - 7s - loss: 953488.6250 - val_loss: 717259.7500 - 7s/epoch - 970ms/step
# Epoch 65/1000
#
# Epoch 65: val_loss did not improve from 18947.06445
# 7/7 - 5s - loss: 1025770.0625 - val_loss: 718710.3125 - 5s/epoch - 706ms/step
# Epoch 66/1000
#
# Epoch 66: val_loss did not improve from 18947.06445
# 7/7 - 6s - loss: 1056641.5000 - val_loss: 507901.0938 - 6s/epoch - 887ms/step
# Epoch 67/1000
#
# Epoch 67: val_loss did not improve from 18947.06445
# 7/7 - 7s - loss: 1069445.8750 - val_loss: 310947.2812 - 7s/epoch - 1s/step
# Epoch 68/1000
#
# Epoch 68: val_loss did not improve from 18947.06445
# 7/7 - 5s - loss: 1000046.2500 - val_loss: 317252.9688 - 5s/epoch - 688ms/step
# Epoch 69/1000
#
# Epoch 69: val_loss did not improve from 18947.06445
# 7/7 - 5s - loss: 1081854.8750 - val_loss: 493523.1875 - 5s/epoch - 664ms/step
# Epoch 70/1000
#
# Epoch 70: val_loss did not improve from 18947.06445
# 7/7 - 6s - loss: 1097971.3750 - val_loss: 114580.1719 - 6s/epoch - 920ms/step
# Epoch 71/1000
#
# Epoch 71: val_loss did not improve from 18947.06445
# 7/7 - 5s - loss: 1171017.8750 - val_loss: 357525.0000 - 5s/epoch - 764ms/step
# Epoch 72/1000
#
# Epoch 72: val_loss did not improve from 18947.06445
# 7/7 - 5s - loss: 1127780.1250 - val_loss: 723049.6250 - 5s/epoch - 652ms/step
# Epoch 73/1000
#
# Epoch 73: val_loss did not improve from 18947.06445
# 7/7 - 6s - loss: 1151897.0000 - val_loss: 435995.6250 - 6s/epoch - 811ms/step
# Epoch 74/1000
#
# Epoch 74: val_loss did not improve from 18947.06445
# 7/7 - 6s - loss: 884002.2500 - val_loss: 619897.2500 - 6s/epoch - 854ms/step
# Epoch 75/1000
#
# Epoch 75: val_loss did not improve from 18947.06445
# 7/7 - 5s - loss: 1017438.5000 - val_loss: 626708.3750 - 5s/epoch - 656ms/step
# Epoch 76/1000
#
# Epoch 76: val_loss did not improve from 18947.06445
# 7/7 - 5s - loss: 938338.8750 - val_loss: 444285.2500 - 5s/epoch - 705ms/step
# Epoch 77/1000
#
# Epoch 77: val_loss did not improve from 18947.06445
# 7/7 - 7s - loss: 993627.5625 - val_loss: 508416.5312 - 7s/epoch - 967ms/step
# Epoch 78/1000
#
# Epoch 78: val_loss did not improve from 18947.06445
# 7/7 - 5s - loss: 888961.2500 - val_loss: 206801.4219 - 5s/epoch - 666ms/step
# Epoch 79/1000
#
# Epoch 79: val_loss did not improve from 18947.06445
# 7/7 - 5s - loss: 904980.3750 - val_loss: 374090.1250 - 5s/epoch - 675ms/step
# Epoch 80/1000
#
# Epoch 80: val_loss did not improve from 18947.06445
# 7/7 - 7s - loss: 908241.0625 - val_loss: 59788.7266 - 7s/epoch - 972ms/step
# Epoch 81/1000
#
# Epoch 81: val_loss did not improve from 18947.06445
# 7/7 - 5s - loss: 1027840.4375 - val_loss: 363181.3750 - 5s/epoch - 720ms/step
# Epoch 82/1000
#
# Epoch 82: val_loss improved from 18947.06445 to 5997.95898, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 5s - loss: 836164.4375 - val_loss: 5997.9590 - 5s/epoch - 694ms/step
# Epoch 83/1000
#
# Epoch 83: val_loss improved from 5997.95898 to 5631.85986, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 7s - loss: 968159.5625 - val_loss: 5631.8599 - 7s/epoch - 972ms/step
# Epoch 84/1000
#
# Epoch 84: val_loss did not improve from 5631.85986
# 7/7 - 5s - loss: 983261.8125 - val_loss: 108042.9375 - 5s/epoch - 768ms/step
# Epoch 85/1000
#
# Epoch 85: val_loss did not improve from 5631.85986
# 7/7 - 5s - loss: 1058087.2500 - val_loss: 31598.3770 - 5s/epoch - 662ms/step
# Epoch 86/1000
#
# Epoch 86: val_loss did not improve from 5631.85986
# 7/7 - 6s - loss: 841584.1250 - val_loss: 336148.2500 - 6s/epoch - 809ms/step
# Epoch 87/1000
#
# Epoch 87: val_loss did not improve from 5631.85986
# 7/7 - 6s - loss: 887904.8125 - val_loss: 570863.0625 - 6s/epoch - 874ms/step
# Epoch 88/1000
#
# Epoch 88: val_loss did not improve from 5631.85986
# 7/7 - 5s - loss: 814633.8125 - val_loss: 77513.2891 - 5s/epoch - 661ms/step
# Epoch 89/1000
#
# Epoch 89: val_loss did not improve from 5631.85986
# 7/7 - 5s - loss: 820394.5000 - val_loss: 43708.9219 - 5s/epoch - 750ms/step
# Epoch 90/1000
#
# Epoch 90: val_loss did not improve from 5631.85986
# 7/7 - 7s - loss: 819505.5625 - val_loss: 217163.2812 - 7s/epoch - 932ms/step
# Epoch 91/1000
#
# Epoch 91: val_loss did not improve from 5631.85986
# 7/7 - 5s - loss: 734350.2500 - val_loss: 39612.0742 - 5s/epoch - 664ms/step
# Epoch 92/1000
#
# Epoch 92: val_loss did not improve from 5631.85986
# 7/7 - 5s - loss: 758849.5625 - val_loss: 122224.5938 - 5s/epoch - 662ms/step
# Epoch 93/1000
#
# Epoch 93: val_loss did not improve from 5631.85986
# 7/7 - 7s - loss: 759616.1250 - val_loss: 197831.8750 - 7s/epoch - 1s/step
# Epoch 94/1000
#
# Epoch 94: val_loss did not improve from 5631.85986
# 7/7 - 5s - loss: 810240.1875 - val_loss: 154925.5781 - 5s/epoch - 689ms/step
# Epoch 95/1000
#
# Epoch 95: val_loss did not improve from 5631.85986
# 7/7 - 5s - loss: 754590.8750 - val_loss: 85645.3203 - 5s/epoch - 657ms/step
# Epoch 96/1000
#
# Epoch 96: val_loss improved from 5631.85986 to 2945.43604, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 8s - loss: 690573.0625 - val_loss: 2945.4360 - 8s/epoch - 1s/step
# Epoch 97/1000
#
# Epoch 97: val_loss did not improve from 2945.43604
# 7/7 - 7s - loss: 756709.5625 - val_loss: 11920.6875 - 7s/epoch - 1s/step
# Epoch 98/1000
#
# Epoch 98: val_loss did not improve from 2945.43604
# 7/7 - 5s - loss: 762167.8750 - val_loss: 13066.2363 - 5s/epoch - 669ms/step
# Epoch 99/1000
#
# Epoch 99: val_loss did not improve from 2945.43604
# 7/7 - 5s - loss: 788050.6250 - val_loss: 46510.2344 - 5s/epoch - 678ms/step
# Epoch 100/1000
#
# Epoch 100: val_loss did not improve from 2945.43604
# 7/7 - 7s - loss: 715572.8750 - val_loss: 30170.2793 - 7s/epoch - 1s/step
# Epoch 101/1000
#
# Epoch 101: val_loss did not improve from 2945.43604
# 7/7 - 5s - loss: 684793.0625 - val_loss: 88862.0625 - 5s/epoch - 686ms/step
# Epoch 102/1000
#
# Epoch 102: val_loss did not improve from 2945.43604
# 7/7 - 5s - loss: 700355.8125 - val_loss: 14260.6289 - 5s/epoch - 668ms/step
# Epoch 103/1000
#
# Epoch 103: val_loss did not improve from 2945.43604
# 7/7 - 6s - loss: 999275.1250 - val_loss: 236084.9375 - 6s/epoch - 913ms/step
# Epoch 104/1000
#
# Epoch 104: val_loss did not improve from 2945.43604
# 7/7 - 5s - loss: 853543.6875 - val_loss: 494256.8438 - 5s/epoch - 782ms/step
# Epoch 105/1000
#
# Epoch 105: val_loss did not improve from 2945.43604
# 7/7 - 5s - loss: 735150.0625 - val_loss: 197087.5156 - 5s/epoch - 671ms/step
# Epoch 106/1000
#
# Epoch 106: val_loss improved from 2945.43604 to 2608.20801, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 6s - loss: 634519.5625 - val_loss: 2608.2080 - 6s/epoch - 863ms/step
# Epoch 107/1000
#
# Epoch 107: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 693784.1250 - val_loss: 140439.5938 - 6s/epoch - 848ms/step
# Epoch 108/1000
#
# Epoch 108: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 682067.0000 - val_loss: 160198.0938 - 5s/epoch - 665ms/step
# Epoch 109/1000
#
# Epoch 109: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 621053.1875 - val_loss: 34400.4844 - 5s/epoch - 731ms/step
# Epoch 110/1000
#
# Epoch 110: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 526767.5000 - val_loss: 116945.6484 - 7s/epoch - 972ms/step
# Epoch 111/1000
#
# Epoch 111: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 614900.6875 - val_loss: 107891.8672 - 5s/epoch - 663ms/step
# Epoch 112/1000
#
# Epoch 112: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 641071.0000 - val_loss: 50417.5586 - 5s/epoch - 667ms/step
# Epoch 113/1000
#
# Epoch 113: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 560675.6250 - val_loss: 27105.7598 - 7s/epoch - 979ms/step
# Epoch 114/1000
#
# Epoch 114: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 585488.5625 - val_loss: 15696.6367 - 5s/epoch - 697ms/step
# Epoch 115/1000
#
# Epoch 115: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 578191.5625 - val_loss: 15384.1396 - 5s/epoch - 649ms/step
# Epoch 116/1000
#
# Epoch 116: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 643083.5625 - val_loss: 14060.6396 - 6s/epoch - 861ms/step
# Epoch 117/1000
#
# Epoch 117: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 549760.4375 - val_loss: 41150.2656 - 6s/epoch - 796ms/step
# Epoch 118/1000
#
# Epoch 118: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 527198.6250 - val_loss: 40224.8789 - 5s/epoch - 645ms/step
# Epoch 119/1000
#
# Epoch 119: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 538285.5625 - val_loss: 49088.3359 - 5s/epoch - 741ms/step
# Epoch 120/1000
#
# Epoch 120: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 496442.3750 - val_loss: 5848.6606 - 6s/epoch - 927ms/step
# Epoch 121/1000
#
# Epoch 121: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 523402.5625 - val_loss: 3547.4824 - 5s/epoch - 662ms/step
# Epoch 122/1000
#
# Epoch 122: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 486677.2500 - val_loss: 7568.3364 - 5s/epoch - 677ms/step
# Epoch 123/1000
#
# Epoch 123: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 520454.3438 - val_loss: 44685.9805 - 7s/epoch - 1s/step
# Epoch 124/1000
#
# Epoch 124: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 558366.5625 - val_loss: 3423.7434 - 5s/epoch - 665ms/step
# Epoch 125/1000
#
# Epoch 125: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 564516.7500 - val_loss: 8345.0283 - 5s/epoch - 646ms/step
# Epoch 126/1000
#
# Epoch 126: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 560651.5625 - val_loss: 12624.4434 - 7s/epoch - 930ms/step
# Epoch 127/1000
#
# Epoch 127: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 500501.3750 - val_loss: 24144.1504 - 5s/epoch - 755ms/step
# Epoch 128/1000
#
# Epoch 128: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 572081.6875 - val_loss: 29311.9766 - 5s/epoch - 645ms/step
# Epoch 129/1000
#
# Epoch 129: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 498849.5938 - val_loss: 22745.7070 - 6s/epoch - 815ms/step
# Epoch 130/1000
#
# Epoch 130: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 498497.7188 - val_loss: 111115.9219 - 6s/epoch - 854ms/step
# Epoch 131/1000
#
# Epoch 131: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 508562.3750 - val_loss: 112457.4375 - 5s/epoch - 653ms/step
# Epoch 132/1000
#
# Epoch 132: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 449940.4375 - val_loss: 15164.3125 - 5s/epoch - 704ms/step
# Epoch 133/1000
#
# Epoch 133: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 504385.3438 - val_loss: 162135.0156 - 7s/epoch - 969ms/step
# Epoch 134/1000
#
# Epoch 134: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 505217.8438 - val_loss: 17035.6777 - 5s/epoch - 654ms/step
# Epoch 135/1000
#
# Epoch 135: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 513999.5312 - val_loss: 5333.9604 - 5s/epoch - 651ms/step
# Epoch 136/1000
#
# Epoch 136: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 446422.1250 - val_loss: 47360.9219 - 7s/epoch - 942ms/step
# Epoch 137/1000
#
# Epoch 137: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 479635.8438 - val_loss: 59793.7539 - 5s/epoch - 737ms/step
# Epoch 138/1000
#
# Epoch 138: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 513708.2188 - val_loss: 13557.0430 - 5s/epoch - 644ms/step
# Epoch 139/1000
#
# Epoch 139: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 476511.7188 - val_loss: 24825.8457 - 7s/epoch - 933ms/step
# Epoch 140/1000
#
# Epoch 140: val_loss did not improve from 2608.20801
# 7/7 - 8s - loss: 483329.0938 - val_loss: 3692.4204 - 8s/epoch - 1s/step
# Epoch 141/1000
#
# Epoch 141: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 486501.6250 - val_loss: 23361.4883 - 5s/epoch - 743ms/step
# Epoch 142/1000
#
# Epoch 142: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 451380.6875 - val_loss: 9164.1436 - 5s/epoch - 664ms/step
# Epoch 143/1000
#
# Epoch 143: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 424951.5312 - val_loss: 23723.3301 - 6s/epoch - 849ms/step
# Epoch 144/1000
#
# Epoch 144: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 436142.7812 - val_loss: 26873.0879 - 6s/epoch - 825ms/step
# Epoch 145/1000
#
# Epoch 145: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 537796.5625 - val_loss: 15555.6387 - 5s/epoch - 654ms/step
# Epoch 146/1000
#
# Epoch 146: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 445433.4062 - val_loss: 38337.6367 - 5s/epoch - 756ms/step
# Epoch 147/1000
#
# Epoch 147: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 454097.5938 - val_loss: 71501.2578 - 6s/epoch - 917ms/step
# Epoch 148/1000
#
# Epoch 148: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 460545.8750 - val_loss: 41709.0898 - 5s/epoch - 655ms/step
# Epoch 149/1000
#
# Epoch 149: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 482153.2188 - val_loss: 11484.7910 - 5s/epoch - 650ms/step
# Epoch 150/1000
#
# Epoch 150: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 419606.1875 - val_loss: 106863.4062 - 7s/epoch - 971ms/step
# Epoch 151/1000
#
# Epoch 151: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 454107.5312 - val_loss: 7487.2026 - 5s/epoch - 705ms/step
# Epoch 152/1000
#
# Epoch 152: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 510330.7500 - val_loss: 91101.7422 - 5s/epoch - 658ms/step
# Epoch 153/1000
#
# Epoch 153: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 439616.0000 - val_loss: 19279.4629 - 6s/epoch - 899ms/step
# Epoch 154/1000
#
# Epoch 154: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 404078.2812 - val_loss: 36943.4531 - 6s/epoch - 800ms/step
# Epoch 155/1000
#
# Epoch 155: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 393487.5312 - val_loss: 26695.2617 - 5s/epoch - 660ms/step
# Epoch 156/1000
#
# Epoch 156: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 413848.9062 - val_loss: 31298.9395 - 6s/epoch - 811ms/step
# Epoch 157/1000
#
# Epoch 157: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 463376.1875 - val_loss: 11616.7949 - 6s/epoch - 881ms/step
# Epoch 158/1000
#
# Epoch 158: val_loss did not improve from 2608.20801
# 7/7 - 4s - loss: 449960.4375 - val_loss: 53443.9258 - 4s/epoch - 641ms/step
# Epoch 159/1000
#
# Epoch 159: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 403135.0938 - val_loss: 10840.4502 - 5s/epoch - 702ms/step
# Epoch 160/1000
#
# Epoch 160: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 381068.4688 - val_loss: 61721.7656 - 7s/epoch - 975ms/step
# Epoch 161/1000
#
# Epoch 161: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 423809.4062 - val_loss: 8856.9717 - 5s/epoch - 658ms/step
# Epoch 162/1000
#
# Epoch 162: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 414330.7812 - val_loss: 79988.2109 - 5s/epoch - 653ms/step
# Epoch 163/1000
#
# Epoch 163: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 394174.1250 - val_loss: 6066.2324 - 6s/epoch - 923ms/step
# Epoch 164/1000
#
# Epoch 164: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 389337.1250 - val_loss: 60543.1289 - 5s/epoch - 769ms/step
# Epoch 165/1000
#
# Epoch 165: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 433398.3125 - val_loss: 25164.3066 - 5s/epoch - 659ms/step
# Epoch 166/1000
#
# Epoch 166: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 384703.9375 - val_loss: 55043.6211 - 6s/epoch - 849ms/step
# Epoch 167/1000
#
# Epoch 167: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 441624.7500 - val_loss: 59734.1914 - 6s/epoch - 840ms/step
# Epoch 168/1000
#
# Epoch 168: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 409730.7500 - val_loss: 7700.2007 - 5s/epoch - 653ms/step
# Epoch 169/1000
#
# Epoch 169: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 410066.8750 - val_loss: 85817.0000 - 5s/epoch - 750ms/step
# Epoch 170/1000
#
# Epoch 170: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 412854.6875 - val_loss: 27225.4707 - 7s/epoch - 934ms/step
# Epoch 171/1000
#
# Epoch 171: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 370568.7188 - val_loss: 27223.6094 - 5s/epoch - 651ms/step
# Epoch 172/1000
#
# Epoch 172: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 423359.3750 - val_loss: 31364.8750 - 5s/epoch - 657ms/step
# Epoch 173/1000
#
# Epoch 173: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 418940.4062 - val_loss: 9761.7578 - 7s/epoch - 991ms/step
# Epoch 174/1000
#
# Epoch 174: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 417305.9062 - val_loss: 16987.0918 - 5s/epoch - 687ms/step
# Epoch 175/1000
#
# Epoch 175: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 429530.8125 - val_loss: 45678.3555 - 5s/epoch - 650ms/step
# Epoch 176/1000
#
# Epoch 176: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 437906.5312 - val_loss: 39755.8242 - 6s/epoch - 908ms/step
# Epoch 177/1000
#
# Epoch 177: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 430139.5000 - val_loss: 19066.1484 - 5s/epoch - 774ms/step
# Epoch 178/1000
#
# Epoch 178: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 358623.6250 - val_loss: 37224.3281 - 5s/epoch - 656ms/step
# Epoch 179/1000
#
# Epoch 179: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 433605.4375 - val_loss: 15271.9229 - 6s/epoch - 829ms/step
# Epoch 180/1000
#
# Epoch 180: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 429170.1562 - val_loss: 56139.1406 - 6s/epoch - 860ms/step
# Epoch 181/1000
#
# Epoch 181: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 401227.2812 - val_loss: 23585.5449 - 5s/epoch - 652ms/step
# Epoch 182/1000
#
# Epoch 182: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 419932.1562 - val_loss: 11859.4746 - 5s/epoch - 783ms/step
# Epoch 183/1000
#
# Epoch 183: val_loss did not improve from 2608.20801
# 7/7 - 8s - loss: 396715.0000 - val_loss: 22488.3691 - 8s/epoch - 1s/step
# Epoch 184/1000
#
# Epoch 184: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 421905.0938 - val_loss: 22639.3730 - 6s/epoch - 916ms/step
# Epoch 185/1000
#
# Epoch 185: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 422006.5938 - val_loss: 33657.8398 - 5s/epoch - 662ms/step
# Epoch 186/1000
#
# Epoch 186: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 381029.7812 - val_loss: 19010.3125 - 5s/epoch - 726ms/step
# Epoch 187/1000
#
# Epoch 187: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 384718.4062 - val_loss: 25809.7266 - 7s/epoch - 966ms/step
# Epoch 188/1000
#
# Epoch 188: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 377211.9688 - val_loss: 33208.7188 - 5s/epoch - 644ms/step
# Epoch 189/1000
#
# Epoch 189: val_loss did not improve from 2608.20801
# 7/7 - 4s - loss: 444603.2188 - val_loss: 10272.2188 - 4s/epoch - 637ms/step
# Epoch 190/1000
#
# Epoch 190: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 350805.5625 - val_loss: 21783.0684 - 7s/epoch - 947ms/step
# Epoch 191/1000
#
# Epoch 191: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 380398.9062 - val_loss: 28478.8652 - 5s/epoch - 744ms/step
# Epoch 192/1000
#
# Epoch 192: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 403423.9375 - val_loss: 19652.3867 - 5s/epoch - 656ms/step
# Epoch 193/1000
#
# Epoch 193: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 393392.7188 - val_loss: 43866.8047 - 6s/epoch - 880ms/step
# Epoch 194/1000
#
# Epoch 194: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 399530.6562 - val_loss: 20028.7344 - 6s/epoch - 808ms/step
# Epoch 195/1000
#
# Epoch 195: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 326031.3125 - val_loss: 65579.2344 - 5s/epoch - 644ms/step
# Epoch 196/1000
#
# Epoch 196: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 404998.3438 - val_loss: 15084.7529 - 5s/epoch - 734ms/step
# Epoch 197/1000
#
# Epoch 197: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 402661.1250 - val_loss: 58797.6602 - 7s/epoch - 941ms/step
# Epoch 198/1000
#
# Epoch 198: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 350128.4062 - val_loss: 17814.8750 - 5s/epoch - 657ms/step
# Epoch 199/1000
#
# Epoch 199: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 385047.3125 - val_loss: 71728.3906 - 5s/epoch - 652ms/step
# Epoch 200/1000
#
# Epoch 200: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 382841.3125 - val_loss: 14130.4189 - 7s/epoch - 984ms/step
# Epoch 201/1000
#
# Epoch 201: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 409308.4062 - val_loss: 50111.5234 - 5s/epoch - 699ms/step
# Epoch 202/1000
#
# Epoch 202: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 424758.2188 - val_loss: 15886.6299 - 5s/epoch - 648ms/step
# Epoch 203/1000
#
# Epoch 203: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 380090.5625 - val_loss: 65915.0078 - 6s/epoch - 880ms/step
# Epoch 204/1000
#
# Epoch 204: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 372591.3438 - val_loss: 33249.2734 - 6s/epoch - 798ms/step
# Epoch 205/1000
#
# Epoch 205: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 400771.9062 - val_loss: 39758.1797 - 5s/epoch - 664ms/step
# Epoch 206/1000
#
# Epoch 206: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 358868.9062 - val_loss: 48722.5391 - 6s/epoch - 804ms/step
# Epoch 207/1000
#
# Epoch 207: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 385232.0312 - val_loss: 89035.4766 - 6s/epoch - 887ms/step
# Epoch 208/1000
#
# Epoch 208: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 379220.4688 - val_loss: 59764.1953 - 5s/epoch - 665ms/step
# Epoch 209/1000
#
# Epoch 209: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 384304.7500 - val_loss: 36111.6406 - 5s/epoch - 728ms/step
# Epoch 210/1000
#
# Epoch 210: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 430639.3438 - val_loss: 75023.5781 - 7s/epoch - 971ms/step
# Epoch 211/1000
#
# Epoch 211: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 413604.1562 - val_loss: 21145.9648 - 5s/epoch - 663ms/step
# Epoch 212/1000
#
# Epoch 212: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 376498.4062 - val_loss: 28834.0977 - 5s/epoch - 664ms/step
# Epoch 213/1000
#
# Epoch 213: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 358890.5312 - val_loss: 51248.0664 - 7s/epoch - 977ms/step
# Epoch 214/1000
#
# Epoch 214: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 329696.1875 - val_loss: 23056.0293 - 5s/epoch - 715ms/step
# Epoch 215/1000
#
# Epoch 215: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 448151.7812 - val_loss: 90872.6094 - 5s/epoch - 691ms/step
# Epoch 216/1000
#
# Epoch 216: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 394217.4375 - val_loss: 12226.8574 - 7s/epoch - 929ms/step
# Epoch 217/1000
#
# Epoch 217: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 376822.7812 - val_loss: 79379.9297 - 5s/epoch - 758ms/step
# Epoch 218/1000
#
# Epoch 218: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 422856.2500 - val_loss: 4716.3784 - 5s/epoch - 652ms/step
# Epoch 219/1000
#
# Epoch 219: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 342490.5312 - val_loss: 88222.5391 - 6s/epoch - 790ms/step
# Epoch 220/1000
#
# Epoch 220: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 416913.7812 - val_loss: 19797.0234 - 6s/epoch - 869ms/step
# Epoch 221/1000
#
# Epoch 221: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 404757.5938 - val_loss: 44499.5391 - 5s/epoch - 660ms/step
# Epoch 222/1000
#
# Epoch 222: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 402494.7500 - val_loss: 85736.9062 - 5s/epoch - 694ms/step
# Epoch 223/1000
#
# Epoch 223: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 364783.3750 - val_loss: 25601.0703 - 7s/epoch - 1s/step
# Epoch 224/1000
#
# Epoch 224: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 405067.3125 - val_loss: 79905.8984 - 5s/epoch - 662ms/step
# Epoch 225/1000
#
# Epoch 225: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 334279.7500 - val_loss: 20935.8789 - 5s/epoch - 661ms/step
# Epoch 226/1000
#
# Epoch 226: val_loss did not improve from 2608.20801
# 7/7 - 8s - loss: 342472.9062 - val_loss: 53562.7695 - 8s/epoch - 1s/step
# Epoch 227/1000
#
# Epoch 227: val_loss did not improve from 2608.20801
# 7/7 - 8s - loss: 402756.2500 - val_loss: 12713.4951 - 8s/epoch - 1s/step
# Epoch 228/1000
#
# Epoch 228: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 351536.2500 - val_loss: 48571.1758 - 5s/epoch - 651ms/step
# Epoch 229/1000
#
# Epoch 229: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 372979.7500 - val_loss: 7394.6851 - 5s/epoch - 664ms/step
# Epoch 230/1000
#
# Epoch 230: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 424793.3125 - val_loss: 93072.6016 - 7s/epoch - 969ms/step
# Epoch 231/1000
#
# Epoch 231: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 346445.6250 - val_loss: 28502.7500 - 5s/epoch - 730ms/step
# Epoch 232/1000
#
# Epoch 232: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 362215.8438 - val_loss: 89033.1172 - 5s/epoch - 650ms/step
# Epoch 233/1000
#
# Epoch 233: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 387324.0938 - val_loss: 11047.0303 - 6s/epoch - 875ms/step
# Epoch 234/1000
#
# Epoch 234: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 403973.7188 - val_loss: 43724.4961 - 6s/epoch - 829ms/step
# Epoch 235/1000
#
# Epoch 235: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 336284.2500 - val_loss: 32823.2266 - 5s/epoch - 653ms/step
# Epoch 236/1000
#
# Epoch 236: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 348979.2500 - val_loss: 24734.1406 - 5s/epoch - 762ms/step
# Epoch 237/1000
#
# Epoch 237: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 346697.6875 - val_loss: 16318.0371 - 6s/epoch - 913ms/step
# Epoch 238/1000
#
# Epoch 238: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 387064.3750 - val_loss: 7228.2686 - 5s/epoch - 654ms/step
# Epoch 239/1000
#
# Epoch 239: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 415180.0938 - val_loss: 27635.9883 - 5s/epoch - 658ms/step
# Epoch 240/1000
#
# Epoch 240: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 383560.8438 - val_loss: 54130.2891 - 7s/epoch - 981ms/step
# Epoch 241/1000
#
# Epoch 241: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 401276.3750 - val_loss: 31831.6074 - 5s/epoch - 705ms/step
# Epoch 242/1000
#
# Epoch 242: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 334027.2500 - val_loss: 27251.6094 - 5s/epoch - 666ms/step
# Epoch 243/1000
#
# Epoch 243: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 349156.3750 - val_loss: 22659.8145 - 6s/epoch - 886ms/step
# Epoch 244/1000
#
# Epoch 244: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 323483.9062 - val_loss: 26499.4473 - 6s/epoch - 786ms/step
# Epoch 245/1000
#
# Epoch 245: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 340929.3125 - val_loss: 6308.0864 - 5s/epoch - 656ms/step
# Epoch 246/1000
#
# Epoch 246: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 365789.5625 - val_loss: 70701.1016 - 6s/epoch - 798ms/step
# Epoch 247/1000
#
# Epoch 247: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 349677.3750 - val_loss: 15993.3672 - 6s/epoch - 881ms/step
# Epoch 248/1000
#
# Epoch 248: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 370944.0000 - val_loss: 17495.3535 - 5s/epoch - 653ms/step
# Epoch 249/1000
#
# Epoch 249: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 340125.8125 - val_loss: 60589.8711 - 5s/epoch - 683ms/step
# Epoch 250/1000
#
# Epoch 250: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 358197.8125 - val_loss: 9562.6504 - 7s/epoch - 964ms/step
# Epoch 251/1000
#
# Epoch 251: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 379776.7500 - val_loss: 23156.4219 - 5s/epoch - 699ms/step
# Epoch 252/1000
#
# Epoch 252: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 335275.9062 - val_loss: 18592.5664 - 5s/epoch - 665ms/step
# Epoch 253/1000
#
# Epoch 253: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 368724.1562 - val_loss: 11548.5537 - 6s/epoch - 906ms/step
# Epoch 254/1000
#
# Epoch 254: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 307364.9688 - val_loss: 39652.1953 - 5s/epoch - 767ms/step
# Epoch 255/1000
#
# Epoch 255: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 351224.6562 - val_loss: 9801.3633 - 5s/epoch - 656ms/step
# Epoch 256/1000
#
# Epoch 256: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 320414.3125 - val_loss: 31705.0176 - 6s/epoch - 818ms/step
# Epoch 257/1000
#
# Epoch 257: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 310580.9375 - val_loss: 59423.0469 - 6s/epoch - 868ms/step
# Epoch 258/1000
#
# Epoch 258: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 343562.8750 - val_loss: 12446.2012 - 5s/epoch - 661ms/step
# Epoch 259/1000
#
# Epoch 259: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 355665.0000 - val_loss: 44195.3594 - 5s/epoch - 729ms/step
# Epoch 260/1000
#
# Epoch 260: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 325526.2188 - val_loss: 13387.3691 - 7s/epoch - 943ms/step
# Epoch 261/1000
#
# Epoch 261: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 315619.5000 - val_loss: 47012.3555 - 5s/epoch - 665ms/step
# Epoch 262/1000
#
# Epoch 262: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 360821.8438 - val_loss: 23073.1816 - 5s/epoch - 657ms/step
# Epoch 263/1000
#
# Epoch 263: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 343977.4688 - val_loss: 19662.1602 - 7s/epoch - 944ms/step
# Epoch 264/1000
#
# Epoch 264: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 334306.9688 - val_loss: 40879.5859 - 5s/epoch - 733ms/step
# Epoch 265/1000
#
# Epoch 265: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 372273.1250 - val_loss: 37436.6758 - 5s/epoch - 645ms/step
# Epoch 266/1000
#
# Epoch 266: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 318262.8125 - val_loss: 48124.2695 - 6s/epoch - 854ms/step
# Epoch 267/1000
#
# Epoch 267: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 324550.1562 - val_loss: 21807.7480 - 6s/epoch - 816ms/step
# Epoch 268/1000
#
# Epoch 268: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 332835.3438 - val_loss: 53914.2148 - 5s/epoch - 661ms/step
# Epoch 269/1000
#
# Epoch 269: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 302339.4375 - val_loss: 16530.4785 - 6s/epoch - 798ms/step
# Epoch 270/1000
#
# Epoch 270: val_loss did not improve from 2608.20801
# 7/7 - 8s - loss: 362035.4688 - val_loss: 28114.9902 - 8s/epoch - 1s/step
# Epoch 271/1000
#
# Epoch 271: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 312761.8125 - val_loss: 41701.2656 - 6s/epoch - 880ms/step
# Epoch 272/1000
#
# Epoch 272: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 343797.7812 - val_loss: 42190.6914 - 5s/epoch - 659ms/step
# Epoch 273/1000
#
# Epoch 273: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 317566.2812 - val_loss: 54175.7344 - 6s/epoch - 847ms/step
# Epoch 274/1000
#
# Epoch 274: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 303984.8750 - val_loss: 12717.9736 - 6s/epoch - 848ms/step
# Epoch 275/1000
#
# Epoch 275: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 363377.8438 - val_loss: 27239.1875 - 5s/epoch - 656ms/step
# Epoch 276/1000
#
# Epoch 276: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 325156.0000 - val_loss: 17242.3379 - 5s/epoch - 717ms/step
# Epoch 277/1000
#
# Epoch 277: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 312067.8125 - val_loss: 31000.6152 - 7s/epoch - 949ms/step
# Epoch 278/1000
#
# Epoch 278: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 308732.2500 - val_loss: 31841.1855 - 5s/epoch - 667ms/step
# Epoch 279/1000
#
# Epoch 279: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 334372.6250 - val_loss: 25236.2617 - 5s/epoch - 674ms/step
# Epoch 280/1000
#
# Epoch 280: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 315720.2188 - val_loss: 59730.7969 - 7s/epoch - 956ms/step
# Epoch 281/1000
#
# Epoch 281: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 359336.4375 - val_loss: 9107.2891 - 5s/epoch - 736ms/step
# Epoch 282/1000
#
# Epoch 282: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 368829.3438 - val_loss: 39074.9219 - 5s/epoch - 669ms/step
# Epoch 283/1000
#
# Epoch 283: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 352760.7188 - val_loss: 48445.5156 - 6s/epoch - 879ms/step
# Epoch 284/1000
#
# Epoch 284: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 361408.1562 - val_loss: 19874.2617 - 6s/epoch - 817ms/step
# Epoch 285/1000
#
# Epoch 285: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 315544.9375 - val_loss: 32568.5254 - 5s/epoch - 671ms/step
# Epoch 286/1000
#
# Epoch 286: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 355412.0000 - val_loss: 7750.1699 - 6s/epoch - 792ms/step
# Epoch 287/1000
#
# Epoch 287: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 352926.6562 - val_loss: 11930.4453 - 6s/epoch - 895ms/step
# Epoch 288/1000
#
# Epoch 288: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 318215.9062 - val_loss: 18312.2734 - 5s/epoch - 660ms/step
# Epoch 289/1000
#
# Epoch 289: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 325089.1562 - val_loss: 14216.6689 - 5s/epoch - 673ms/step
# Epoch 290/1000
#
# Epoch 290: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 338470.8125 - val_loss: 55889.5000 - 7s/epoch - 1s/step
# Epoch 291/1000
#
# Epoch 291: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 334361.1562 - val_loss: 20955.7715 - 5s/epoch - 697ms/step
# Epoch 292/1000
#
# Epoch 292: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 295187.2500 - val_loss: 54653.6289 - 5s/epoch - 656ms/step
# Epoch 293/1000
#
# Epoch 293: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 322497.9688 - val_loss: 47952.1016 - 7s/epoch - 950ms/step
# Epoch 294/1000
#
# Epoch 294: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 340564.1562 - val_loss: 29805.5000 - 5s/epoch - 739ms/step
# Epoch 295/1000
#
# Epoch 295: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 349580.4688 - val_loss: 25086.4609 - 5s/epoch - 662ms/step
# Epoch 296/1000
#
# Epoch 296: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 299871.6875 - val_loss: 34411.8125 - 6s/epoch - 870ms/step
# Epoch 297/1000
#
# Epoch 297: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 326688.4688 - val_loss: 39711.3281 - 6s/epoch - 837ms/step
# Epoch 298/1000
#
# Epoch 298: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 346827.3125 - val_loss: 27405.6602 - 5s/epoch - 655ms/step
# Epoch 299/1000
#
# Epoch 299: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 314090.7500 - val_loss: 60572.1445 - 5s/epoch - 782ms/step
# Epoch 300/1000
#
# Epoch 300: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 336876.2500 - val_loss: 52751.1289 - 6s/epoch - 903ms/step
# Epoch 301/1000
#
# Epoch 301: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 337444.9375 - val_loss: 46832.0234 - 5s/epoch - 673ms/step
# Epoch 302/1000
#
# Epoch 302: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 342357.7812 - val_loss: 27306.8223 - 5s/epoch - 682ms/step
# Epoch 303/1000
#
# Epoch 303: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 324118.3125 - val_loss: 51684.4531 - 7s/epoch - 1s/step
# Epoch 304/1000
#
# Epoch 304: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 349467.8125 - val_loss: 27446.8672 - 5s/epoch - 658ms/step
# Epoch 305/1000
#
# Epoch 305: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 327709.7812 - val_loss: 66328.6094 - 5s/epoch - 663ms/step
# Epoch 306/1000
#
# Epoch 306: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 372420.0938 - val_loss: 37004.6953 - 6s/epoch - 923ms/step
# Epoch 307/1000
#
# Epoch 307: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 296772.5000 - val_loss: 21893.0684 - 5s/epoch - 754ms/step
# Epoch 308/1000
#
# Epoch 308: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 368533.8750 - val_loss: 46154.1797 - 5s/epoch - 659ms/step
# Epoch 309/1000
#
# Epoch 309: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 326152.7812 - val_loss: 16423.9961 - 6s/epoch - 814ms/step
# Epoch 310/1000
#
# Epoch 310: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 357226.8750 - val_loss: 43676.1016 - 6s/epoch - 858ms/step
# Epoch 311/1000
#
# Epoch 311: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 301884.4062 - val_loss: 23678.5352 - 5s/epoch - 648ms/step
# Epoch 312/1000
#
# Epoch 312: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 355509.1875 - val_loss: 54744.6602 - 5s/epoch - 697ms/step
# Epoch 313/1000
#
# Epoch 313: val_loss did not improve from 2608.20801
# ...
#
# Epoch 891: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 291619.2500 - val_loss: 14729.7998 - 7s/epoch - 969ms/step
# Epoch 892/1000
#
# Epoch 892: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 307707.0625 - val_loss: 10740.3877 - 5s/epoch - 716ms/step
# Epoch 893/1000
#
# Epoch 893: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 269157.0312 - val_loss: 17956.6504 - 5s/epoch - 662ms/step
# Epoch 894/1000
#
# Epoch 894: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 275213.0938 - val_loss: 15384.8359 - 6s/epoch - 864ms/step
# Epoch 895/1000
#
# Epoch 895: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 285928.7812 - val_loss: 14128.2490 - 6s/epoch - 809ms/step
# Epoch 896/1000
#
# Epoch 896: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 289920.9062 - val_loss: 17535.2031 - 5s/epoch - 654ms/step
# Epoch 897/1000
#
# Epoch 897: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 275575.7812 - val_loss: 18680.6934 - 6s/epoch - 800ms/step
# Epoch 898/1000
#
# Epoch 898: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 306456.4688 - val_loss: 7899.3774 - 6s/epoch - 881ms/step
# Epoch 899/1000
#
# Epoch 899: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 288575.0312 - val_loss: 21329.2871 - 5s/epoch - 666ms/step
# Epoch 900/1000
#
# Epoch 900: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 295627.4375 - val_loss: 15223.5195 - 5s/epoch - 708ms/step
# Epoch 901/1000
#
# Epoch 901: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 333355.5312 - val_loss: 5802.8081 - 7s/epoch - 982ms/step
# Epoch 902/1000
#
# Epoch 902: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 321437.8125 - val_loss: 30715.6777 - 5s/epoch - 670ms/step
# Epoch 903/1000
#
# Epoch 903: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 297533.5000 - val_loss: 18517.5117 - 5s/epoch - 656ms/step
# Epoch 904/1000
#
# Epoch 904: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 286565.5625 - val_loss: 10898.2471 - 7s/epoch - 942ms/step
# Epoch 905/1000
#
# Epoch 905: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 297331.1562 - val_loss: 14442.3984 - 5s/epoch - 731ms/step
# Epoch 906/1000
#
# Epoch 906: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 264716.8750 - val_loss: 19495.1504 - 5s/epoch - 664ms/step
# Epoch 907/1000
#
# Epoch 907: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 323883.4375 - val_loss: 30577.7441 - 6s/epoch - 844ms/step
# Epoch 908/1000
#
# Epoch 908: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 277258.9688 - val_loss: 36060.4062 - 6s/epoch - 827ms/step
# Epoch 909/1000
#
# Epoch 909: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 280314.0312 - val_loss: 20870.5312 - 5s/epoch - 657ms/step
# Epoch 910/1000
#
# Epoch 910: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 308602.1562 - val_loss: 23358.3750 - 5s/epoch - 742ms/step
# Epoch 911/1000
#
# Epoch 911: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 309988.2188 - val_loss: 20986.7598 - 6s/epoch - 922ms/step
# Epoch 912/1000
#
# Epoch 912: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 272076.0938 - val_loss: 18147.4785 - 7s/epoch - 972ms/step
# Epoch 913/1000
#
# Epoch 913: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 307671.4375 - val_loss: 30358.1582 - 6s/epoch - 896ms/step
# Epoch 914/1000
#
# Epoch 914: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 327042.0625 - val_loss: 11000.2842 - 6s/epoch - 834ms/step
# Epoch 915/1000
#
# Epoch 915: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 312521.6875 - val_loss: 28700.6855 - 5s/epoch - 659ms/step
# Epoch 916/1000
#
# Epoch 916: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 302721.6250 - val_loss: 23178.6777 - 5s/epoch - 735ms/step
# Epoch 917/1000
#
# Epoch 917: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 270499.3438 - val_loss: 10811.4033 - 7s/epoch - 946ms/step
# Epoch 918/1000
#
# Epoch 918: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 277566.8438 - val_loss: 27586.1191 - 5s/epoch - 662ms/step
# Epoch 919/1000
#
# Epoch 919: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 287814.5938 - val_loss: 6019.0532 - 5s/epoch - 644ms/step
# Epoch 920/1000
#
# Epoch 920: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 271872.6562 - val_loss: 30080.7793 - 7s/epoch - 936ms/step
# Epoch 921/1000
#
# Epoch 921: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 303809.7188 - val_loss: 16597.8809 - 5s/epoch - 723ms/step
# Epoch 922/1000
#
# Epoch 922: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 286409.0000 - val_loss: 10921.5283 - 5s/epoch - 645ms/step
# Epoch 923/1000
#
# Epoch 923: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 278799.8125 - val_loss: 20835.8145 - 6s/epoch - 840ms/step
# Epoch 924/1000
#
# Epoch 924: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 283260.1875 - val_loss: 9323.9834 - 6s/epoch - 831ms/step
# Epoch 925/1000
#
# Epoch 925: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 298458.5938 - val_loss: 14702.6221 - 5s/epoch - 649ms/step
# Epoch 926/1000
#
# Epoch 926: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 297416.1875 - val_loss: 34354.3633 - 5s/epoch - 733ms/step
# Epoch 927/1000
#
# Epoch 927: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 268252.3750 - val_loss: 13054.3047 - 7s/epoch - 942ms/step
# Epoch 928/1000
#
# Epoch 928: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 286047.1250 - val_loss: 15645.8486 - 5s/epoch - 651ms/step
# Epoch 929/1000
#
# Epoch 929: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 292264.8438 - val_loss: 16627.2793 - 5s/epoch - 661ms/step
# Epoch 930/1000
#
# Epoch 930: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 275360.0312 - val_loss: 18978.4980 - 7s/epoch - 929ms/step
# Epoch 931/1000
#
# Epoch 931: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 324611.3750 - val_loss: 21581.3652 - 5s/epoch - 757ms/step
# Epoch 932/1000
#
# Epoch 932: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 296599.9688 - val_loss: 34073.6641 - 5s/epoch - 669ms/step
# Epoch 933/1000
#
# Epoch 933: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 276858.5312 - val_loss: 38550.6641 - 6s/epoch - 873ms/step
# Epoch 934/1000
#
# Epoch 934: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 322981.3750 - val_loss: 22696.0605 - 6s/epoch - 821ms/step
# Epoch 935/1000
#
# Epoch 935: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 259874.3906 - val_loss: 18243.5059 - 5s/epoch - 661ms/step
# Epoch 936/1000
#
# Epoch 936: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 261488.2344 - val_loss: 23678.8730 - 5s/epoch - 766ms/step
# Epoch 937/1000
#
# Epoch 937: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 304387.6875 - val_loss: 20740.2871 - 6s/epoch - 916ms/step
# Epoch 938/1000
#
# Epoch 938: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 308244.3125 - val_loss: 23498.5879 - 5s/epoch - 662ms/step
# Epoch 939/1000
#
# Epoch 939: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 285440.8438 - val_loss: 14088.3096 - 5s/epoch - 692ms/step
# Epoch 940/1000
#
# Epoch 940: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 302265.6250 - val_loss: 20529.5039 - 7s/epoch - 972ms/step
# Epoch 941/1000
#
# Epoch 941: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 308383.1562 - val_loss: 17695.8633 - 5s/epoch - 686ms/step
# Epoch 942/1000
#
# Epoch 942: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 286807.3750 - val_loss: 20709.9883 - 5s/epoch - 656ms/step
# Epoch 943/1000
#
# Epoch 943: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 287410.1562 - val_loss: 7231.8589 - 6s/epoch - 909ms/step
# Epoch 944/1000
#
# Epoch 944: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 283297.3125 - val_loss: 13967.3486 - 5s/epoch - 779ms/step
# Epoch 945/1000
#
# Epoch 945: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 319339.4688 - val_loss: 18514.9746 - 5s/epoch - 663ms/step
# Epoch 946/1000
#
# Epoch 946: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 298784.7812 - val_loss: 12216.1367 - 6s/epoch - 826ms/step
# Epoch 947/1000
#
# Epoch 947: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 305098.5938 - val_loss: 24762.6016 - 6s/epoch - 856ms/step
# Epoch 948/1000
#
# Epoch 948: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 294833.4688 - val_loss: 9247.8252 - 5s/epoch - 645ms/step
# Epoch 949/1000
#
# Epoch 949: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 317146.6562 - val_loss: 19112.0723 - 5s/epoch - 693ms/step
# Epoch 950/1000
#
# Epoch 950: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 280177.3438 - val_loss: 17486.9434 - 7s/epoch - 973ms/step
# Epoch 951/1000
#
# Epoch 951: val_loss did not improve from 2608.20801
# 7/7 - 4s - loss: 252445.6875 - val_loss: 10403.3584 - 4s/epoch - 641ms/step
# Epoch 952/1000
#
# Epoch 952: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 278582.5625 - val_loss: 16559.0000 - 5s/epoch - 652ms/step
# Epoch 953/1000
#
# Epoch 953: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 267713.2500 - val_loss: 16843.2871 - 7s/epoch - 929ms/step
# Epoch 954/1000
#
# Epoch 954: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 319013.4062 - val_loss: 9748.0410 - 5s/epoch - 742ms/step
# Epoch 955/1000
#
# Epoch 955: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 303541.1250 - val_loss: 21716.5879 - 5s/epoch - 658ms/step
# Epoch 956/1000
#
# Epoch 956: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 268045.7812 - val_loss: 24918.9121 - 6s/epoch - 824ms/step
# Epoch 957/1000
#
# Epoch 957: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 287848.6875 - val_loss: 12592.3975 - 6s/epoch - 865ms/step
# Epoch 958/1000
#
# Epoch 958: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 287741.9688 - val_loss: 28611.8320 - 5s/epoch - 660ms/step
# Epoch 959/1000
#
# Epoch 959: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 289735.2500 - val_loss: 19598.3555 - 5s/epoch - 751ms/step
# Epoch 960/1000
#
# Epoch 960: val_loss did not improve from 2608.20801
# 7/7 - 8s - loss: 277368.6562 - val_loss: 25094.3633 - 8s/epoch - 1s/step
# Epoch 961/1000
#
# Epoch 961: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 322981.7188 - val_loss: 17771.5234 - 7s/epoch - 969ms/step
# Epoch 962/1000
#
# Epoch 962: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 287202.1562 - val_loss: 7381.1562 - 5s/epoch - 657ms/step
# Epoch 963/1000
#
# Epoch 963: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 283078.1875 - val_loss: 14497.7617 - 6s/epoch - 858ms/step
# Epoch 964/1000
#
# Epoch 964: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 318672.0000 - val_loss: 10136.3115 - 6s/epoch - 833ms/step
# Epoch 965/1000
#
# Epoch 965: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 284549.4375 - val_loss: 5106.0938 - 5s/epoch - 665ms/step
# Epoch 966/1000
#
# Epoch 966: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 317469.6250 - val_loss: 21985.9492 - 5s/epoch - 780ms/step
# Epoch 967/1000
#
# Epoch 967: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 311544.8438 - val_loss: 7220.0181 - 6s/epoch - 910ms/step
# Epoch 968/1000
#
# Epoch 968: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 305016.7500 - val_loss: 13073.8271 - 5s/epoch - 662ms/step
# Epoch 969/1000
#
# Epoch 969: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 282214.1875 - val_loss: 17550.3906 - 5s/epoch - 691ms/step
# Epoch 970/1000
#
# Epoch 970: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 294109.7188 - val_loss: 12629.4326 - 7s/epoch - 1s/step
# Epoch 971/1000
#
# Epoch 971: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 297091.3750 - val_loss: 22872.3906 - 5s/epoch - 656ms/step
# Epoch 972/1000
#
# Epoch 972: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 300999.0000 - val_loss: 10820.6250 - 5s/epoch - 654ms/step
# Epoch 973/1000
#
# Epoch 973: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 279577.5000 - val_loss: 8757.8838 - 7s/epoch - 937ms/step
# Epoch 974/1000
#
# Epoch 974: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 262631.2500 - val_loss: 17193.0469 - 5s/epoch - 728ms/step
# Epoch 975/1000
#
# Epoch 975: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 280106.1562 - val_loss: 9860.4893 - 5s/epoch - 653ms/step
# Epoch 976/1000
#
# Epoch 976: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 300814.9688 - val_loss: 40230.1172 - 6s/epoch - 851ms/step
# Epoch 977/1000
#
# Epoch 977: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 286229.9062 - val_loss: 13697.1338 - 6s/epoch - 832ms/step
# Epoch 978/1000
#
# Epoch 978: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 297413.6875 - val_loss: 15370.0801 - 5s/epoch - 655ms/step
# Epoch 979/1000
#
# Epoch 979: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 289288.2188 - val_loss: 17847.4336 - 5s/epoch - 733ms/step
# Epoch 980/1000
#
# Epoch 980: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 309000.2500 - val_loss: 10094.5303 - 7s/epoch - 944ms/step
# Epoch 981/1000
#
# Epoch 981: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 240674.4531 - val_loss: 22565.2246 - 5s/epoch - 663ms/step
# Epoch 982/1000
#
# Epoch 982: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 255164.5000 - val_loss: 11959.1602 - 5s/epoch - 662ms/step
# Epoch 983/1000
#
# Epoch 983: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 277581.3438 - val_loss: 20958.6191 - 7s/epoch - 964ms/step
# Epoch 984/1000
#
# Epoch 984: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 301679.2812 - val_loss: 18460.9219 - 5s/epoch - 713ms/step
# Epoch 985/1000
#
# Epoch 985: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 300756.8750 - val_loss: 23560.7773 - 5s/epoch - 652ms/step
# Epoch 986/1000
#
# Epoch 986: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 286017.1875 - val_loss: 23495.2168 - 6s/epoch - 832ms/step
# Epoch 987/1000
#
# Epoch 987: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 281568.3438 - val_loss: 20400.5449 - 6s/epoch - 827ms/step
# Epoch 988/1000
#
# Epoch 988: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 339719.8125 - val_loss: 14803.5088 - 5s/epoch - 657ms/step
# Epoch 989/1000
#
# Epoch 989: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 252898.9062 - val_loss: 15910.6826 - 5s/epoch - 757ms/step
# Epoch 990/1000
#
# Epoch 990: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 284042.4688 - val_loss: 24368.3516 - 6s/epoch - 905ms/step
# Epoch 991/1000
#
# Epoch 991: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 298321.3125 - val_loss: 13235.8066 - 5s/epoch - 646ms/step
# Epoch 992/1000
#
# Epoch 992: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 336726.7500 - val_loss: 10109.3037 - 5s/epoch - 648ms/step
# Epoch 993/1000
#
# Epoch 993: val_loss did not improve from 2608.20801
# 7/7 - 7s - loss: 316497.0000 - val_loss: 8874.9404 - 7s/epoch - 991ms/step
# Epoch 994/1000
#
# Epoch 994: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 317695.4688 - val_loss: 12558.2041 - 5s/epoch - 690ms/step
# Epoch 995/1000
#
# Epoch 995: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 265495.1562 - val_loss: 24307.9746 - 5s/epoch - 652ms/step
# Epoch 996/1000
#
# Epoch 996: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 281681.6250 - val_loss: 13611.0488 - 6s/epoch - 891ms/step
# Epoch 997/1000
#
# Epoch 997: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 296077.5625 - val_loss: 18544.9316 - 5s/epoch - 785ms/step
# Epoch 998/1000
#
# Epoch 998: val_loss did not improve from 2608.20801
# 7/7 - 5s - loss: 282296.7500 - val_loss: 23062.2168 - 5s/epoch - 652ms/step
# Epoch 999/1000
#
# Epoch 999: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 302864.5000 - val_loss: 11968.0635 - 6s/epoch - 811ms/step
# Epoch 1000/1000
#
# Epoch 1000: val_loss did not improve from 2608.20801
# 7/7 - 6s - loss: 291812.2188 - val_loss: 17013.7871 - 6s/epoch - 885ms/step
# 16/16 [==============================] - 2s 89ms/step
# 3/3 [==============================] - 0s 90ms/step
# Training MSE: 28850.12005127279
# Testing MSE: 9565.129080219353
# accuracy : 54

# %%
trainX, trainY = create_dataset(train_data_t_2, train_data, look_back)
testX, testY = create_dataset(test_data_t_2,test_data, look_back)

print(trainX.shape)
print(trainY.shape)
print(testX.shape)
print(testY.shape)
# Out:
# (494, 5, 14)
# (494, 1)
# (84, 5, 14)
# (84, 1)

# %%
# 모델 생성 LSTM
model = Sequential()
model.add(LSTM(units=1024, activation='relu', return_sequences=True, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dropout(0.3))
model.add(LSTM(units=512, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(units=256, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(units=128, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(units=64, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(units=32, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(units=16, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(units=1))
model.summary()

# loss = Huber()
# optimizer = Adam(0.0005)
# model.compile(loss=Huber(), optimizer=optimizer, metrics=['mse'])

model.compile(optimizer='adam', loss='mean_squared_error')

filename = os.path.join('tmp', 'ckeckpointer.ckpt')
checkpoint = ModelCheckpoint(filename,
                             save_weights_only=True,
                             save_best_only=True,
                             monitor='val_loss',
                             verbose=1)

# 모델 학습
history = model.fit(trainX, trainY, epochs=1000, batch_size=64,
          validation_split=0.1, verbose=2,callbacks=[checkpoint])

model.save_weights('./ko_t_LSTM_weights.h3')

model.load_weights(filename)

plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()
plt.show()

# 예측
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# MSE 계산
trainMSE = mean_squared_error(trainY, trainPredict)
testMSE = mean_squared_error(testY, testPredict)

print(f'Training MSE: {trainMSE}')
print(f'Testing MSE: {testMSE}')

accuracy(testPredict,testY)

# 예측 시각화
plt.plot(trainY, label='Actual Price')
plt.plot(trainPredict, label='Predicted Price')
plt.legend()
plt.title('Training Data')
plt.show()

plt.plot(testY, label='Actual Price')
plt.plot(testPredict, label='Predicted Price')
plt.legend()
plt.title('Testing Data')
plt.show()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_7 (LSTM)               (None, 5, 1024)           4255744
#
#  dropout_7 (Dropout)         (None, 5, 1024)           0
#
#  lstm_8 (LSTM)               (None, 5, 512)            3147776
#
#  dropout_8 (Dropout)         (None, 5, 512)            0
#
#  lstm_9 (LSTM)               (None, 5, 256)            787456
#
#  dropout_9 (Dropout)         (None, 5, 256)            0
#
#  lstm_10 (LSTM)              (None, 5, 128)            197120
#
#  dropout_10 (Dropout)        (None, 5, 128)            0
#
#  lstm_11 (LSTM)              (None, 5, 64)             49408
#
#  dropout_11 (Dropout)        (None, 5, 64)             0
#
#  lstm_12 (LSTM)              (None, 5, 32)             12416
#
#  dropout_12 (Dropout)        (None, 5, 32)             0
#
#  lstm_13 (LSTM)              (None, 16)                3136
#
#  dropout_13 (Dropout)        (None, 16)                0
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 8453073 (32.25 MB)
# Trainable params: 8453073 (32.25 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/1000
#
# Epoch 1: val_loss improved from inf to 5710894.00000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 17s - loss: 8167944.5000 - val_loss: 5710894.0000 - 17s/epoch - 2s/step
# Epoch 2/1000
#
# Epoch 2: val_loss improved from 5710894.00000 to 5710292.50000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 7s - loss: 8167918.0000 - val_loss: 5710292.5000 - 7s/epoch - 1s/step
# Epoch 3/1000
#
# Epoch 3: val_loss improved from 5710292.50000 to 5709410.00000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 5s - loss: 8167304.0000 - val_loss: 5709410.0000 - 5s/epoch - 726ms/step
# Epoch 4/1000
#
# Epoch 4: val_loss improved from 5709410.00000 to 5606080.50000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 5s - loss: 8127522.0000 - val_loss: 5606080.5000 - 5s/epoch - 686ms/step
# Epoch 5/1000
#
# Epoch 5: val_loss improved from 5606080.50000 to 82072.17188, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 7s - loss: 6916063.0000 - val_loss: 82072.1719 - 7s/epoch - 975ms/step
# Epoch 6/1000
#
# Epoch 6: val_loss did not improve from 82072.17188
# 7/7 - 8s - loss: 6203240.0000 - val_loss: 4753119.5000 - 8s/epoch - 1s/step
# Epoch 7/1000
#
# Epoch 7: val_loss did not improve from 82072.17188
# 7/7 - 5s - loss: 5173434.0000 - val_loss: 391109.3750 - 5s/epoch - 712ms/step
# Epoch 8/1000
#
# Epoch 8: val_loss did not improve from 82072.17188
# 7/7 - 6s - loss: 4496408.5000 - val_loss: 3713057.0000 - 6s/epoch - 820ms/step
# Epoch 9/1000
#
# Epoch 9: val_loss did not improve from 82072.17188
# 7/7 - 6s - loss: 3815800.0000 - val_loss: 712947.6875 - 6s/epoch - 854ms/step
# Epoch 10/1000
#
# Epoch 10: val_loss did not improve from 82072.17188
# 7/7 - 5s - loss: 3419718.2500 - val_loss: 209123.1562 - 5s/epoch - 659ms/step
# Epoch 11/1000
#
# Epoch 11: val_loss did not improve from 82072.17188
# 7/7 - 5s - loss: 3462059.0000 - val_loss: 86269.9219 - 5s/epoch - 763ms/step
# Epoch 12/1000
#
# Epoch 12: val_loss did not improve from 82072.17188
# 7/7 - 7s - loss: 2892762.5000 - val_loss: 96489.5234 - 7s/epoch - 943ms/step
# Epoch 13/1000
#
# Epoch 13: val_loss improved from 82072.17188 to 68797.00781, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 5s - loss: 3264232.2500 - val_loss: 68797.0078 - 5s/epoch - 691ms/step
# Epoch 14/1000
#
# Epoch 14: val_loss did not improve from 68797.00781
# 7/7 - 5s - loss: 2759424.7500 - val_loss: 204921.9375 - 5s/epoch - 701ms/step
# Epoch 15/1000
#
# Epoch 15: val_loss improved from 68797.00781 to 40135.70703, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 7s - loss: 2346781.0000 - val_loss: 40135.7070 - 7s/epoch - 1s/step
# Epoch 16/1000
#
# Epoch 16: val_loss improved from 40135.70703 to 36067.24609, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 5s - loss: 2023936.8750 - val_loss: 36067.2461 - 5s/epoch - 713ms/step
# Epoch 17/1000
#
# Epoch 17: val_loss improved from 36067.24609 to 25561.38281, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 5s - loss: 2143328.2500 - val_loss: 25561.3828 - 5s/epoch - 728ms/step
# Epoch 18/1000
#
# Epoch 18: val_loss did not improve from 25561.38281
# 7/7 - 7s - loss: 2188975.0000 - val_loss: 53797.2617 - 7s/epoch - 984ms/step
# Epoch 19/1000
#
# Epoch 19: val_loss did not improve from 25561.38281
# 7/7 - 5s - loss: 2240852.5000 - val_loss: 115989.5312 - 5s/epoch - 674ms/step
# Epoch 20/1000
#
# Epoch 20: val_loss did not improve from 25561.38281
# 7/7 - 5s - loss: 1964747.5000 - val_loss: 380965.7188 - 5s/epoch - 671ms/step
# Epoch 21/1000
#
# Epoch 21: val_loss did not improve from 25561.38281
# 7/7 - 6s - loss: 2146312.5000 - val_loss: 633560.1875 - 6s/epoch - 909ms/step
# Epoch 22/1000
#
# Epoch 22: val_loss did not improve from 25561.38281
# 7/7 - 5s - loss: 2089337.2500 - val_loss: 43287.3750 - 5s/epoch - 780ms/step
# Epoch 23/1000
#
# Epoch 23: val_loss improved from 25561.38281 to 18469.81836, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 5s - loss: 1782419.7500 - val_loss: 18469.8184 - 5s/epoch - 686ms/step
# Epoch 24/1000
#
# Epoch 24: val_loss did not improve from 18469.81836
# 7/7 - 6s - loss: 1659863.1250 - val_loss: 29257.3594 - 6s/epoch - 824ms/step
# Epoch 25/1000
#
# Epoch 25: val_loss did not improve from 18469.81836
# 7/7 - 6s - loss: 1530358.7500 - val_loss: 315802.3125 - 6s/epoch - 852ms/step
# Epoch 26/1000
#
# Epoch 26: val_loss did not improve from 18469.81836
# 7/7 - 5s - loss: 1576832.8750 - val_loss: 117266.3281 - 5s/epoch - 657ms/step
# Epoch 27/1000
#
# Epoch 27: val_loss did not improve from 18469.81836
# 7/7 - 5s - loss: 1428196.6250 - val_loss: 155185.5938 - 5s/epoch - 733ms/step
# Epoch 28/1000
#
# Epoch 28: val_loss did not improve from 18469.81836
# 7/7 - 7s - loss: 1205255.7500 - val_loss: 134919.5938 - 7s/epoch - 946ms/step
# Epoch 29/1000
#
# Epoch 29: val_loss did not improve from 18469.81836
# 7/7 - 5s - loss: 1184073.6250 - val_loss: 71535.8516 - 5s/epoch - 663ms/step
# Epoch 30/1000
#
# Epoch 30: val_loss did not improve from 18469.81836
# 7/7 - 5s - loss: 1252116.0000 - val_loss: 40271.8359 - 5s/epoch - 649ms/step
# Epoch 31/1000
#
# Epoch 31: val_loss did not improve from 18469.81836
# 7/7 - 7s - loss: 1129120.8750 - val_loss: 78836.7031 - 7s/epoch - 952ms/step
# Epoch 32/1000
#
# Epoch 32: val_loss did not improve from 18469.81836
# 7/7 - 5s - loss: 1198762.5000 - val_loss: 61995.0156 - 5s/epoch - 717ms/step
# Epoch 33/1000
#
# Epoch 33: val_loss improved from 18469.81836 to 8432.53223, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 5s - loss: 1135401.2500 - val_loss: 8432.5322 - 5s/epoch - 686ms/step
# Epoch 34/1000
#
# Epoch 34: val_loss did not improve from 8432.53223
# 7/7 - 6s - loss: 995753.5000 - val_loss: 54288.0898 - 6s/epoch - 867ms/step
# Epoch 35/1000
#
# Epoch 35: val_loss did not improve from 8432.53223
# 7/7 - 6s - loss: 989640.8750 - val_loss: 105861.9297 - 6s/epoch - 817ms/step
# Epoch 36/1000
#
# Epoch 36: val_loss did not improve from 8432.53223
# 7/7 - 5s - loss: 1019009.4375 - val_loss: 299783.5000 - 5s/epoch - 655ms/step
# Epoch 37/1000
#
# Epoch 37: val_loss did not improve from 8432.53223
# 7/7 - 5s - loss: 1003263.0625 - val_loss: 63502.8867 - 5s/epoch - 772ms/step
# Epoch 38/1000
#
# Epoch 38: val_loss improved from 8432.53223 to 6846.09424, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 7s - loss: 1048370.6875 - val_loss: 6846.0942 - 7s/epoch - 936ms/step
# Epoch 39/1000
#
# Epoch 39: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 1000438.0000 - val_loss: 223930.6250 - 5s/epoch - 649ms/step
# Epoch 40/1000
#
# Epoch 40: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 1027491.3750 - val_loss: 283518.3125 - 5s/epoch - 703ms/step
# Epoch 41/1000
#
# Epoch 41: val_loss did not improve from 6846.09424
# 7/7 - 7s - loss: 902301.0625 - val_loss: 175730.0000 - 7s/epoch - 990ms/step
# Epoch 42/1000
#
# Epoch 42: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 1095163.5000 - val_loss: 207034.2656 - 5s/epoch - 656ms/step
# Epoch 43/1000
#
# Epoch 43: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 919118.1875 - val_loss: 68403.1562 - 5s/epoch - 662ms/step
# Epoch 44/1000
#
# Epoch 44: val_loss did not improve from 6846.09424
# 7/7 - 6s - loss: 1031103.0625 - val_loss: 50286.1406 - 6s/epoch - 916ms/step
# Epoch 45/1000
#
# Epoch 45: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 946496.7500 - val_loss: 113186.6797 - 5s/epoch - 757ms/step
# Epoch 46/1000
#
# Epoch 46: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 1009870.0000 - val_loss: 66811.3984 - 5s/epoch - 645ms/step
# Epoch 47/1000
#
# Epoch 47: val_loss did not improve from 6846.09424
# 7/7 - 6s - loss: 874650.1875 - val_loss: 128275.6172 - 6s/epoch - 821ms/step
# Epoch 48/1000
#
# Epoch 48: val_loss did not improve from 6846.09424
# 7/7 - 6s - loss: 782937.5625 - val_loss: 29030.9473 - 6s/epoch - 852ms/step
# Epoch 49/1000
#
# Epoch 49: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 923754.8125 - val_loss: 233744.0469 - 5s/epoch - 646ms/step
# Epoch 50/1000
#
# Epoch 50: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 857343.1250 - val_loss: 203860.3125 - 5s/epoch - 721ms/step
# Epoch 51/1000
#
# Epoch 51: val_loss did not improve from 6846.09424
# 7/7 - 7s - loss: 881735.2500 - val_loss: 165015.9844 - 7s/epoch - 954ms/step
# Epoch 52/1000
#
# Epoch 52: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 896136.9375 - val_loss: 101079.3594 - 5s/epoch - 662ms/step
# Epoch 53/1000
#
# Epoch 53: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 773668.7500 - val_loss: 191230.9375 - 5s/epoch - 658ms/step
# Epoch 54/1000
#
# Epoch 54: val_loss did not improve from 6846.09424
# 7/7 - 7s - loss: 904113.8125 - val_loss: 114436.4531 - 7s/epoch - 945ms/step
# Epoch 55/1000
#
# Epoch 55: val_loss did not improve from 6846.09424
# 7/7 - 7s - loss: 992398.9375 - val_loss: 306550.5938 - 7s/epoch - 991ms/step
# Epoch 56/1000
#
# Epoch 56: val_loss did not improve from 6846.09424
# 7/7 - 6s - loss: 876717.6875 - val_loss: 213958.5938 - 6s/epoch - 823ms/step
# Epoch 57/1000
#
# Epoch 57: val_loss did not improve from 6846.09424
# 7/7 - 7s - loss: 848136.7500 - val_loss: 381893.1250 - 7s/epoch - 957ms/step
# Epoch 58/1000
#
# Epoch 58: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 862595.0000 - val_loss: 175437.1250 - 5s/epoch - 657ms/step
# Epoch 59/1000
#
# Epoch 59: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 834275.3750 - val_loss: 438163.3125 - 5s/epoch - 647ms/step
# Epoch 60/1000
#
# Epoch 60: val_loss did not improve from 6846.09424
# 7/7 - 6s - loss: 967409.8750 - val_loss: 125724.4375 - 6s/epoch - 925ms/step
# Epoch 61/1000
#
# Epoch 61: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 834104.9375 - val_loss: 601359.9375 - 5s/epoch - 761ms/step
# Epoch 62/1000
#
# Epoch 62: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 822016.5625 - val_loss: 432332.0000 - 5s/epoch - 653ms/step
# Epoch 63/1000
#
# Epoch 63: val_loss did not improve from 6846.09424
# 7/7 - 6s - loss: 866473.3750 - val_loss: 223146.9844 - 6s/epoch - 855ms/step
# Epoch 64/1000
#
# Epoch 64: val_loss did not improve from 6846.09424
# 7/7 - 6s - loss: 1005975.2500 - val_loss: 448435.4062 - 6s/epoch - 839ms/step
# Epoch 65/1000
#
# Epoch 65: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 857591.4375 - val_loss: 329476.3750 - 5s/epoch - 661ms/step
# Epoch 66/1000
#
# Epoch 66: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 768013.5625 - val_loss: 131257.0781 - 5s/epoch - 751ms/step
# Epoch 67/1000
#
# Epoch 67: val_loss did not improve from 6846.09424
# 7/7 - 6s - loss: 886713.3750 - val_loss: 542257.6875 - 6s/epoch - 925ms/step
# Epoch 68/1000
#
# Epoch 68: val_loss did not improve from 6846.09424
# 7/7 - 4s - loss: 863157.5000 - val_loss: 195186.2656 - 4s/epoch - 642ms/step
# Epoch 69/1000
#
# Epoch 69: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 902317.9375 - val_loss: 614284.8125 - 5s/epoch - 653ms/step
# Epoch 70/1000
#
# Epoch 70: val_loss did not improve from 6846.09424
# 7/7 - 7s - loss: 827727.9375 - val_loss: 138804.0625 - 7s/epoch - 968ms/step
# Epoch 71/1000
#
# Epoch 71: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 926191.8125 - val_loss: 419218.4688 - 5s/epoch - 712ms/step
# Epoch 72/1000
#
# Epoch 72: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 843356.1875 - val_loss: 182780.0469 - 5s/epoch - 670ms/step
# Epoch 73/1000
#
# Epoch 73: val_loss did not improve from 6846.09424
# 7/7 - 6s - loss: 771235.7500 - val_loss: 282494.8750 - 6s/epoch - 874ms/step
# Epoch 74/1000
#
# Epoch 74: val_loss did not improve from 6846.09424
# 7/7 - 6s - loss: 853049.8125 - val_loss: 284843.8125 - 6s/epoch - 800ms/step
# Epoch 75/1000
#
# Epoch 75: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 807495.9375 - val_loss: 198612.8594 - 5s/epoch - 658ms/step
# Epoch 76/1000
#
# Epoch 76: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 775856.7500 - val_loss: 452024.8438 - 5s/epoch - 769ms/step
# Epoch 77/1000
#
# Epoch 77: val_loss did not improve from 6846.09424
# 7/7 - 6s - loss: 759171.9375 - val_loss: 76686.4688 - 6s/epoch - 905ms/step
# Epoch 78/1000
#
# Epoch 78: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 817149.8125 - val_loss: 162649.1250 - 5s/epoch - 657ms/step
# Epoch 79/1000
#
# Epoch 79: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 765946.7500 - val_loss: 205942.2188 - 5s/epoch - 652ms/step
# Epoch 80/1000
#
# Epoch 80: val_loss did not improve from 6846.09424
# 7/7 - 7s - loss: 832976.4375 - val_loss: 99507.4062 - 7s/epoch - 998ms/step
# Epoch 81/1000
#
# Epoch 81: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 811654.6250 - val_loss: 237763.0469 - 5s/epoch - 685ms/step
# Epoch 82/1000
#
# Epoch 82: val_loss did not improve from 6846.09424
# 7/7 - 4s - loss: 851848.8750 - val_loss: 239255.0469 - 4s/epoch - 640ms/step
# Epoch 83/1000
#
# Epoch 83: val_loss did not improve from 6846.09424
# 7/7 - 6s - loss: 728093.2500 - val_loss: 276048.0938 - 6s/epoch - 863ms/step
# Epoch 84/1000
#
# Epoch 84: val_loss did not improve from 6846.09424
# 7/7 - 6s - loss: 671991.4375 - val_loss: 196420.3750 - 6s/epoch - 809ms/step
# Epoch 85/1000
#
# Epoch 85: val_loss did not improve from 6846.09424
# 7/7 - 4s - loss: 833886.8750 - val_loss: 228350.7031 - 4s/epoch - 642ms/step
# Epoch 86/1000
#
# Epoch 86: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 781501.2500 - val_loss: 168922.1562 - 5s/epoch - 747ms/step
# Epoch 87/1000
#
# Epoch 87: val_loss did not improve from 6846.09424
# 7/7 - 6s - loss: 753748.7500 - val_loss: 219038.4375 - 6s/epoch - 915ms/step
# Epoch 88/1000
#
# Epoch 88: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 773856.1250 - val_loss: 263478.4375 - 5s/epoch - 652ms/step
# Epoch 89/1000
#
# Epoch 89: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 795369.2500 - val_loss: 218610.8750 - 5s/epoch - 652ms/step
# Epoch 90/1000
#
# Epoch 90: val_loss did not improve from 6846.09424
# 7/7 - 7s - loss: 745296.0000 - val_loss: 173077.4844 - 7s/epoch - 974ms/step
# Epoch 91/1000
#
# Epoch 91: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 766893.3125 - val_loss: 259577.7812 - 5s/epoch - 699ms/step
# Epoch 92/1000
#
# Epoch 92: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 762842.8125 - val_loss: 244325.0469 - 5s/epoch - 649ms/step
# Epoch 93/1000
#
# Epoch 93: val_loss did not improve from 6846.09424
# 7/7 - 6s - loss: 765857.6875 - val_loss: 246836.7969 - 6s/epoch - 887ms/step
# Epoch 94/1000
#
# Epoch 94: val_loss did not improve from 6846.09424
# 7/7 - 6s - loss: 776791.5000 - val_loss: 182197.2812 - 6s/epoch - 800ms/step
# Epoch 95/1000
#
# Epoch 95: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 730928.5625 - val_loss: 169664.3125 - 5s/epoch - 670ms/step
# Epoch 96/1000
#
# Epoch 96: val_loss did not improve from 6846.09424
# 7/7 - 6s - loss: 788443.0000 - val_loss: 199179.0781 - 6s/epoch - 816ms/step
# Epoch 97/1000
#
# Epoch 97: val_loss did not improve from 6846.09424
# 7/7 - 6s - loss: 787053.0000 - val_loss: 167741.8750 - 6s/epoch - 889ms/step
# Epoch 98/1000
#
# Epoch 98: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 743541.6250 - val_loss: 239790.0000 - 5s/epoch - 675ms/step
# Epoch 99/1000
#
# Epoch 99: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 756139.1250 - val_loss: 219922.9844 - 5s/epoch - 722ms/step
# Epoch 100/1000
#
# Epoch 100: val_loss did not improve from 6846.09424
# 7/7 - 7s - loss: 833897.7500 - val_loss: 324195.5312 - 7s/epoch - 962ms/step
# Epoch 101/1000
#
# Epoch 101: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 763601.0625 - val_loss: 233020.2344 - 5s/epoch - 675ms/step
# Epoch 102/1000
#
# Epoch 102: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 718619.0000 - val_loss: 434888.1250 - 5s/epoch - 688ms/step
# Epoch 103/1000
#
# Epoch 103: val_loss did not improve from 6846.09424
# 7/7 - 7s - loss: 737940.7500 - val_loss: 199424.5781 - 7s/epoch - 986ms/step
# Epoch 104/1000
#
# Epoch 104: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 839940.5625 - val_loss: 292400.4062 - 5s/epoch - 697ms/step
# Epoch 105/1000
#
# Epoch 105: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 737632.8750 - val_loss: 323126.4375 - 5s/epoch - 780ms/step
# Epoch 106/1000
#
# Epoch 106: val_loss did not improve from 6846.09424
# 7/7 - 8s - loss: 685984.5625 - val_loss: 170851.7969 - 8s/epoch - 1s/step
# Epoch 107/1000
#
# Epoch 107: val_loss did not improve from 6846.09424
# 7/7 - 6s - loss: 887119.8125 - val_loss: 251553.4531 - 6s/epoch - 910ms/step
# Epoch 108/1000
#
# Epoch 108: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 719776.9375 - val_loss: 238716.7031 - 5s/epoch - 660ms/step
# Epoch 109/1000
#
# Epoch 109: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 796684.6250 - val_loss: 152521.7969 - 5s/epoch - 709ms/step
# Epoch 110/1000
#
# Epoch 110: val_loss did not improve from 6846.09424
# 7/7 - 7s - loss: 735380.7500 - val_loss: 192748.5000 - 7s/epoch - 974ms/step
# Epoch 111/1000
#
# Epoch 111: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 721988.3750 - val_loss: 226458.8594 - 5s/epoch - 661ms/step
# Epoch 112/1000
#
# Epoch 112: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 639906.8750 - val_loss: 292243.7500 - 5s/epoch - 658ms/step
# Epoch 113/1000
#
# Epoch 113: val_loss did not improve from 6846.09424
# 7/7 - 7s - loss: 647713.5625 - val_loss: 261817.3594 - 7s/epoch - 946ms/step
# Epoch 114/1000
#
# Epoch 114: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 712647.0625 - val_loss: 209494.7656 - 5s/epoch - 725ms/step
# Epoch 115/1000
#
# Epoch 115: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 767178.2500 - val_loss: 477612.9688 - 5s/epoch - 647ms/step
# Epoch 116/1000
#
# Epoch 116: val_loss did not improve from 6846.09424
# 7/7 - 6s - loss: 789188.6875 - val_loss: 176896.2656 - 6s/epoch - 836ms/step
# Epoch 117/1000
#
# Epoch 117: val_loss did not improve from 6846.09424
# 7/7 - 6s - loss: 717584.6250 - val_loss: 329069.6875 - 6s/epoch - 854ms/step
# Epoch 118/1000
#
# Epoch 118: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 729253.7500 - val_loss: 242450.9375 - 5s/epoch - 643ms/step
# Epoch 119/1000
#
# Epoch 119: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 782198.6250 - val_loss: 284808.6250 - 5s/epoch - 688ms/step
# Epoch 120/1000
#
# Epoch 120: val_loss did not improve from 6846.09424
# 7/7 - 7s - loss: 757734.3125 - val_loss: 382410.4688 - 7s/epoch - 966ms/step
# Epoch 121/1000
#
# Epoch 121: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 758966.6875 - val_loss: 128728.2969 - 5s/epoch - 654ms/step
# Epoch 122/1000
#
# Epoch 122: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 824907.6875 - val_loss: 331361.2500 - 5s/epoch - 666ms/step
# Epoch 123/1000
#
# Epoch 123: val_loss did not improve from 6846.09424
# 7/7 - 6s - loss: 719759.1875 - val_loss: 194137.6406 - 6s/epoch - 925ms/step
# Epoch 124/1000
#
# Epoch 124: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 701534.5625 - val_loss: 336233.9688 - 5s/epoch - 746ms/step
# Epoch 125/1000
#
# Epoch 125: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 739078.1875 - val_loss: 183036.3750 - 5s/epoch - 671ms/step
# Epoch 126/1000
#
# Epoch 126: val_loss did not improve from 6846.09424
# 7/7 - 6s - loss: 715275.6250 - val_loss: 286374.9062 - 6s/epoch - 823ms/step
# Epoch 127/1000
#
# Epoch 127: val_loss did not improve from 6846.09424
# 7/7 - 6s - loss: 708243.1875 - val_loss: 397375.0000 - 6s/epoch - 862ms/step
# Epoch 128/1000
#
# Epoch 128: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 808338.6250 - val_loss: 163372.6094 - 5s/epoch - 655ms/step
# Epoch 129/1000
#
# Epoch 129: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 632115.4375 - val_loss: 281119.8125 - 5s/epoch - 754ms/step
# Epoch 130/1000
#
# Epoch 130: val_loss did not improve from 6846.09424
# 7/7 - 7s - loss: 701097.0000 - val_loss: 287604.4688 - 7s/epoch - 932ms/step
# Epoch 131/1000
#
# Epoch 131: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 743641.8750 - val_loss: 379250.6875 - 5s/epoch - 660ms/step
# Epoch 132/1000
#
# Epoch 132: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 767015.5625 - val_loss: 149937.0781 - 5s/epoch - 656ms/step
# Epoch 133/1000
#
# Epoch 133: val_loss did not improve from 6846.09424
# 7/7 - 7s - loss: 792003.8750 - val_loss: 300460.7188 - 7s/epoch - 971ms/step
# Epoch 134/1000
#
# Epoch 134: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 616797.1250 - val_loss: 263545.9062 - 5s/epoch - 717ms/step
# Epoch 135/1000
#
# Epoch 135: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 839475.7500 - val_loss: 237710.3125 - 5s/epoch - 655ms/step
# Epoch 136/1000
#
# Epoch 136: val_loss did not improve from 6846.09424
# 7/7 - 6s - loss: 650482.3125 - val_loss: 290081.6250 - 6s/epoch - 867ms/step
# Epoch 137/1000
#
# Epoch 137: val_loss did not improve from 6846.09424
# 7/7 - 6s - loss: 694583.0000 - val_loss: 475020.5625 - 6s/epoch - 803ms/step
# Epoch 138/1000
#
# Epoch 138: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 654881.7500 - val_loss: 347703.4375 - 5s/epoch - 654ms/step
# Epoch 139/1000
#
# Epoch 139: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 771327.6875 - val_loss: 399874.1562 - 5s/epoch - 781ms/step
# Epoch 140/1000
#
# Epoch 140: val_loss did not improve from 6846.09424
# 7/7 - 6s - loss: 693610.3750 - val_loss: 361534.5938 - 6s/epoch - 910ms/step
# Epoch 141/1000
#
# Epoch 141: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 757528.3125 - val_loss: 265120.1875 - 5s/epoch - 649ms/step
# Epoch 142/1000
#
# Epoch 142: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 690408.5625 - val_loss: 226181.6406 - 5s/epoch - 664ms/step
# Epoch 143/1000
#
# Epoch 143: val_loss did not improve from 6846.09424
# 7/7 - 7s - loss: 799608.0625 - val_loss: 130049.4062 - 7s/epoch - 1s/step
# Epoch 144/1000
#
# Epoch 144: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 692248.0000 - val_loss: 71208.1719 - 5s/epoch - 680ms/step
# Epoch 145/1000
#
# Epoch 145: val_loss did not improve from 6846.09424
# 7/7 - 5s - loss: 720934.7500 - val_loss: 34289.4141 - 5s/epoch - 655ms/step
# Epoch 146/1000
#
# Epoch 146: val_loss improved from 6846.09424 to 6103.85254, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 7s - loss: 690519.5000 - val_loss: 6103.8525 - 7s/epoch - 988ms/step
# Epoch 147/1000
#
# Epoch 147: val_loss improved from 6103.85254 to 5468.51562, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 5s - loss: 768547.8125 - val_loss: 5468.5156 - 5s/epoch - 770ms/step
# Epoch 148/1000
#
# Epoch 148: val_loss did not improve from 5468.51562
# 7/7 - 5s - loss: 621325.0625 - val_loss: 10461.7734 - 5s/epoch - 667ms/step
# Epoch 149/1000
#
# Epoch 149: val_loss did not improve from 5468.51562
# 7/7 - 6s - loss: 590157.7500 - val_loss: 93765.7031 - 6s/epoch - 894ms/step
# Epoch 150/1000
#
# Epoch 150: val_loss did not improve from 5468.51562
# 7/7 - 6s - loss: 668108.3750 - val_loss: 124499.5391 - 6s/epoch - 792ms/step
# Epoch 151/1000
#
# Epoch 151: val_loss did not improve from 5468.51562
# 7/7 - 5s - loss: 638268.2500 - val_loss: 347815.3125 - 5s/epoch - 656ms/step
# Epoch 152/1000
#
# Epoch 152: val_loss did not improve from 5468.51562
# 7/7 - 5s - loss: 650362.9375 - val_loss: 173321.5000 - 5s/epoch - 740ms/step
# Epoch 153/1000
#
# Epoch 153: val_loss did not improve from 5468.51562
# 7/7 - 6s - loss: 653802.1875 - val_loss: 56779.3281 - 6s/epoch - 924ms/step
# Epoch 154/1000
#
# Epoch 154: val_loss did not improve from 5468.51562
# 7/7 - 5s - loss: 619217.1250 - val_loss: 172526.5156 - 5s/epoch - 672ms/step
# Epoch 155/1000
#
# Epoch 155: val_loss did not improve from 5468.51562
# 7/7 - 5s - loss: 636764.8125 - val_loss: 207609.4375 - 5s/epoch - 677ms/step
# Epoch 156/1000
#
# Epoch 156: val_loss did not improve from 5468.51562
# 7/7 - 8s - loss: 668036.1875 - val_loss: 69046.6719 - 8s/epoch - 1s/step
# Epoch 157/1000
#
# Epoch 157: val_loss did not improve from 5468.51562
# 7/7 - 7s - loss: 668164.4375 - val_loss: 159304.1250 - 7s/epoch - 1s/step
# Epoch 158/1000
#
# Epoch 158: val_loss did not improve from 5468.51562
# 7/7 - 5s - loss: 701035.8125 - val_loss: 170336.0781 - 5s/epoch - 657ms/step
# Epoch 159/1000
#
# Epoch 159: val_loss did not improve from 5468.51562
# 7/7 - 4s - loss: 640919.8750 - val_loss: 124202.0781 - 4s/epoch - 639ms/step
# Epoch 160/1000
#
# Epoch 160: val_loss did not improve from 5468.51562
# 7/7 - 7s - loss: 546209.8125 - val_loss: 200279.6875 - 7s/epoch - 998ms/step
# Epoch 161/1000
#
# Epoch 161: val_loss did not improve from 5468.51562
# 7/7 - 5s - loss: 623980.5625 - val_loss: 87591.2422 - 5s/epoch - 694ms/step
# Epoch 162/1000
#
# Epoch 162: val_loss did not improve from 5468.51562
# 7/7 - 4s - loss: 640049.1250 - val_loss: 274895.3125 - 4s/epoch - 642ms/step
# Epoch 163/1000
#
# Epoch 163: val_loss did not improve from 5468.51562
# 7/7 - 6s - loss: 623681.0000 - val_loss: 179535.1875 - 6s/epoch - 896ms/step
# Epoch 164/1000
#
# Epoch 164: val_loss did not improve from 5468.51562
# 7/7 - 5s - loss: 712933.6875 - val_loss: 172629.9531 - 5s/epoch - 783ms/step
# Epoch 165/1000
#
# Epoch 165: val_loss did not improve from 5468.51562
# 7/7 - 5s - loss: 682729.5625 - val_loss: 240639.0156 - 5s/epoch - 646ms/step
# Epoch 166/1000
#
# Epoch 166: val_loss did not improve from 5468.51562
# 7/7 - 6s - loss: 669900.8750 - val_loss: 196284.4844 - 6s/epoch - 792ms/step
# Epoch 167/1000
#
# Epoch 167: val_loss did not improve from 5468.51562
# 7/7 - 6s - loss: 582118.1875 - val_loss: 181722.6875 - 6s/epoch - 889ms/step
# Epoch 168/1000
#
# Epoch 168: val_loss did not improve from 5468.51562
# 7/7 - 5s - loss: 680256.1875 - val_loss: 221029.7656 - 5s/epoch - 644ms/step
# Epoch 169/1000
#
# Epoch 169: val_loss did not improve from 5468.51562
# 7/7 - 5s - loss: 567359.9375 - val_loss: 208089.1562 - 5s/epoch - 683ms/step
# Epoch 170/1000
#
# Epoch 170: val_loss did not improve from 5468.51562
# 7/7 - 7s - loss: 593709.0625 - val_loss: 150588.6875 - 7s/epoch - 986ms/step
# Epoch 171/1000
#
# Epoch 171: val_loss did not improve from 5468.51562
# 7/7 - 5s - loss: 684585.6875 - val_loss: 131963.9531 - 5s/epoch - 665ms/step
# Epoch 172/1000
#
# Epoch 172: val_loss did not improve from 5468.51562
# 7/7 - 5s - loss: 689478.5625 - val_loss: 176968.6406 - 5s/epoch - 661ms/step
# Epoch 173/1000
#
# Epoch 173: val_loss did not improve from 5468.51562
# 7/7 - 6s - loss: 686534.0625 - val_loss: 66731.4141 - 6s/epoch - 888ms/step
# Epoch 174/1000
#
# Epoch 174: val_loss did not improve from 5468.51562
# 7/7 - 5s - loss: 524816.1875 - val_loss: 193107.5469 - 5s/epoch - 776ms/step
# Epoch 175/1000
#
# Epoch 175: val_loss did not improve from 5468.51562
# 7/7 - 5s - loss: 568308.5000 - val_loss: 229087.4531 - 5s/epoch - 655ms/step
# Epoch 176/1000
#
# Epoch 176: val_loss did not improve from 5468.51562
# 7/7 - 6s - loss: 557828.8125 - val_loss: 163276.1094 - 6s/epoch - 800ms/step
# Epoch 177/1000
#
# Epoch 177: val_loss did not improve from 5468.51562
# 7/7 - 6s - loss: 560767.0625 - val_loss: 168568.8125 - 6s/epoch - 876ms/step
# Epoch 178/1000
#
# Epoch 178: val_loss did not improve from 5468.51562
# 7/7 - 5s - loss: 618202.1875 - val_loss: 239330.5000 - 5s/epoch - 656ms/step
# Epoch 179/1000
#
# Epoch 179: val_loss did not improve from 5468.51562
# 7/7 - 5s - loss: 632215.5000 - val_loss: 232868.7812 - 5s/epoch - 693ms/step
# Epoch 180/1000
#
# Epoch 180: val_loss did not improve from 5468.51562
# 7/7 - 7s - loss: 569817.4375 - val_loss: 113252.6172 - 7s/epoch - 987ms/step
# Epoch 181/1000
#
# Epoch 181: val_loss did not improve from 5468.51562
# 7/7 - 5s - loss: 566003.2500 - val_loss: 179034.2031 - 5s/epoch - 695ms/step
# Epoch 182/1000
#
# Epoch 182: val_loss did not improve from 5468.51562
# 7/7 - 5s - loss: 680702.7500 - val_loss: 159533.4531 - 5s/epoch - 652ms/step
# Epoch 183/1000
#
# Epoch 183: val_loss did not improve from 5468.51562
# 7/7 - 7s - loss: 641202.0000 - val_loss: 167438.9531 - 7s/epoch - 972ms/step
# Epoch 184/1000
#
# Epoch 184: val_loss did not improve from 5468.51562
# 7/7 - 5s - loss: 545597.3125 - val_loss: 243232.9062 - 5s/epoch - 741ms/step
# Epoch 185/1000
#
# Epoch 185: val_loss improved from 5468.51562 to 4774.85791, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 5s - loss: 648712.1250 - val_loss: 4774.8579 - 5s/epoch - 681ms/step
# Epoch 186/1000
#
# Epoch 186: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 619253.1250 - val_loss: 256660.6562 - 6s/epoch - 880ms/step
# Epoch 187/1000
#
# Epoch 187: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 592341.0000 - val_loss: 6946.7798 - 6s/epoch - 810ms/step
# Epoch 188/1000
#
# Epoch 188: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 636136.9375 - val_loss: 21630.6504 - 5s/epoch - 663ms/step
# Epoch 189/1000
#
# Epoch 189: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 572200.3125 - val_loss: 6955.3442 - 6s/epoch - 798ms/step
# Epoch 190/1000
#
# Epoch 190: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 577380.3750 - val_loss: 32928.0508 - 6s/epoch - 895ms/step
# Epoch 191/1000
#
# Epoch 191: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 645570.6250 - val_loss: 98944.7031 - 5s/epoch - 658ms/step
# Epoch 192/1000
#
# Epoch 192: val_loss did not improve from 4774.85791
# 7/7 - 8s - loss: 651957.5625 - val_loss: 26244.4609 - 8s/epoch - 1s/step
# Epoch 193/1000
#
# Epoch 193: val_loss did not improve from 4774.85791
# 7/7 - 8s - loss: 520434.8125 - val_loss: 65753.4609 - 8s/epoch - 1s/step
# Epoch 194/1000
#
# Epoch 194: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 560687.6250 - val_loss: 40291.0273 - 5s/epoch - 659ms/step
# Epoch 195/1000
#
# Epoch 195: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 640636.3750 - val_loss: 107073.4688 - 5s/epoch - 656ms/step
# Epoch 196/1000
#
# Epoch 196: val_loss did not improve from 4774.85791
# 7/7 - 7s - loss: 531794.6875 - val_loss: 25101.7891 - 7s/epoch - 961ms/step
# Epoch 197/1000
#
# Epoch 197: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 587769.5625 - val_loss: 70604.2969 - 5s/epoch - 738ms/step
# Epoch 198/1000
#
# Epoch 198: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 559038.4375 - val_loss: 75400.8125 - 5s/epoch - 670ms/step
# Epoch 199/1000
#
# Epoch 199: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 576074.1875 - val_loss: 81571.6875 - 6s/epoch - 875ms/step
# Epoch 200/1000
#
# Epoch 200: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 606201.8750 - val_loss: 71352.3203 - 6s/epoch - 826ms/step
# Epoch 201/1000
#
# Epoch 201: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 607401.3750 - val_loss: 31017.2344 - 5s/epoch - 671ms/step
# Epoch 202/1000
#
# Epoch 202: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 545102.6875 - val_loss: 68705.7031 - 6s/epoch - 787ms/step
# Epoch 203/1000
#
# Epoch 203: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 564917.5625 - val_loss: 40325.7695 - 6s/epoch - 911ms/step
# Epoch 204/1000
#
# Epoch 204: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 562084.3750 - val_loss: 66162.7031 - 5s/epoch - 667ms/step
# Epoch 205/1000
#
# Epoch 205: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 572527.8125 - val_loss: 46546.1133 - 5s/epoch - 693ms/step
# Epoch 206/1000
#
# Epoch 206: val_loss did not improve from 4774.85791
# 7/7 - 7s - loss: 500015.1250 - val_loss: 41450.0508 - 7s/epoch - 1s/step
# Epoch 207/1000
#
# Epoch 207: val_loss did not improve from 4774.85791
# 7/7 - 7s - loss: 573762.2500 - val_loss: 23086.4727 - 7s/epoch - 1s/step
# Epoch 208/1000
#
# Epoch 208: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 565504.0625 - val_loss: 107661.8281 - 5s/epoch - 653ms/step
# Epoch 209/1000
#
# Epoch 209: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 556705.0000 - val_loss: 7153.1558 - 5s/epoch - 673ms/step
# Epoch 210/1000
#
# Epoch 210: val_loss did not improve from 4774.85791
# 7/7 - 7s - loss: 591797.4375 - val_loss: 81481.9922 - 7s/epoch - 1s/step
# Epoch 211/1000
#
# Epoch 211: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 540966.1250 - val_loss: 17848.4043 - 5s/epoch - 681ms/step
# Epoch 212/1000
#
# Epoch 212: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 619050.1875 - val_loss: 62741.3945 - 5s/epoch - 682ms/step
# Epoch 213/1000
#
# Epoch 213: val_loss did not improve from 4774.85791
# 7/7 - 7s - loss: 655395.3125 - val_loss: 64513.8516 - 7s/epoch - 960ms/step
# Epoch 214/1000
#
# Epoch 214: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 533063.2500 - val_loss: 14590.2754 - 5s/epoch - 764ms/step
# Epoch 215/1000
#
# Epoch 215: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 547634.0000 - val_loss: 174100.8750 - 5s/epoch - 671ms/step
# Epoch 216/1000
#
# Epoch 216: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 580346.0000 - val_loss: 5493.0220 - 6s/epoch - 891ms/step
# Epoch 217/1000
#
# Epoch 217: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 528369.4375 - val_loss: 116190.5938 - 6s/epoch - 811ms/step
# Epoch 218/1000
#
# Epoch 218: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 558054.2500 - val_loss: 27790.2070 - 5s/epoch - 674ms/step
# Epoch 219/1000
#
# Epoch 219: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 586819.5000 - val_loss: 59264.9883 - 5s/epoch - 773ms/step
# Epoch 220/1000
#
# Epoch 220: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 539452.1875 - val_loss: 21892.4355 - 6s/epoch - 914ms/step
# Epoch 221/1000
#
# Epoch 221: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 527790.4375 - val_loss: 102628.0938 - 5s/epoch - 678ms/step
# Epoch 222/1000
#
# Epoch 222: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 566104.9375 - val_loss: 16824.5898 - 5s/epoch - 721ms/step
# Epoch 223/1000
#
# Epoch 223: val_loss did not improve from 4774.85791
# 7/7 - 7s - loss: 544711.3750 - val_loss: 151841.3125 - 7s/epoch - 996ms/step
# Epoch 224/1000
#
# Epoch 224: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 567960.3750 - val_loss: 32219.0820 - 5s/epoch - 656ms/step
# Epoch 225/1000
#
# Epoch 225: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 574051.1875 - val_loss: 60839.9805 - 5s/epoch - 666ms/step
# Epoch 226/1000
#
# Epoch 226: val_loss did not improve from 4774.85791
# 7/7 - 7s - loss: 507853.2188 - val_loss: 23126.8730 - 7s/epoch - 957ms/step
# Epoch 227/1000
#
# Epoch 227: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 503586.9688 - val_loss: 64322.3281 - 5s/epoch - 747ms/step
# Epoch 228/1000
#
# Epoch 228: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 485615.1250 - val_loss: 83503.0078 - 5s/epoch - 676ms/step
# Epoch 229/1000
#
# Epoch 229: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 571924.0000 - val_loss: 28008.1367 - 6s/epoch - 871ms/step
# Epoch 230/1000
#
# Epoch 230: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 490171.0938 - val_loss: 82413.3672 - 6s/epoch - 836ms/step
# Epoch 231/1000
#
# Epoch 231: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 556131.8750 - val_loss: 62418.8047 - 5s/epoch - 669ms/step
# Epoch 232/1000
#
# Epoch 232: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 537146.4375 - val_loss: 61157.2617 - 6s/epoch - 812ms/step
# Epoch 233/1000
#
# Epoch 233: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 511448.7500 - val_loss: 64893.9805 - 6s/epoch - 904ms/step
# Epoch 234/1000
#
# Epoch 234: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 538378.0625 - val_loss: 102255.0703 - 5s/epoch - 664ms/step
# Epoch 235/1000
#
# Epoch 235: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 547379.3750 - val_loss: 57364.2500 - 5s/epoch - 711ms/step
# Epoch 236/1000
#
# Epoch 236: val_loss did not improve from 4774.85791
# 7/7 - 7s - loss: 519556.0000 - val_loss: 50631.5391 - 7s/epoch - 1s/step
# Epoch 237/1000
#
# Epoch 237: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 546998.0625 - val_loss: 69912.0625 - 5s/epoch - 661ms/step
# Epoch 238/1000
#
# Epoch 238: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 542673.7500 - val_loss: 72059.1953 - 5s/epoch - 675ms/step
# Epoch 239/1000
#
# Epoch 239: val_loss did not improve from 4774.85791
# 7/7 - 7s - loss: 533061.6875 - val_loss: 56679.8594 - 7s/epoch - 975ms/step
# Epoch 240/1000
#
# Epoch 240: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 599879.4375 - val_loss: 48792.7500 - 5s/epoch - 719ms/step
# Epoch 241/1000
#
# Epoch 241: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 541162.0000 - val_loss: 60994.3594 - 5s/epoch - 655ms/step
# Epoch 242/1000
#
# Epoch 242: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 578512.0625 - val_loss: 79222.2109 - 6s/epoch - 895ms/step
# Epoch 243/1000
#
# Epoch 243: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 553564.3750 - val_loss: 17157.8848 - 6s/epoch - 801ms/step
# Epoch 244/1000
#
# Epoch 244: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 584567.0000 - val_loss: 45590.8008 - 5s/epoch - 663ms/step
# Epoch 245/1000
#
# Epoch 245: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 542880.3750 - val_loss: 117925.7578 - 5s/epoch - 783ms/step
# Epoch 246/1000
#
# Epoch 246: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 496546.2188 - val_loss: 25223.5020 - 6s/epoch - 909ms/step
# Epoch 247/1000
#
# Epoch 247: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 504868.0312 - val_loss: 87016.4922 - 5s/epoch - 666ms/step
# Epoch 248/1000
#
# Epoch 248: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 542598.5625 - val_loss: 43705.5938 - 5s/epoch - 684ms/step
# Epoch 249/1000
#
# Epoch 249: val_loss did not improve from 4774.85791
# 7/7 - 7s - loss: 539360.8125 - val_loss: 153567.7344 - 7s/epoch - 1s/step
# Epoch 250/1000
#
# Epoch 250: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 558346.8750 - val_loss: 31161.1348 - 5s/epoch - 659ms/step
# Epoch 251/1000
#
# Epoch 251: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 569677.9375 - val_loss: 66725.5469 - 5s/epoch - 662ms/step
# Epoch 252/1000
#
# Epoch 252: val_loss did not improve from 4774.85791
# 7/7 - 7s - loss: 493443.5938 - val_loss: 66168.2812 - 7s/epoch - 929ms/step
# Epoch 253/1000
#
# Epoch 253: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 476319.9062 - val_loss: 53440.1484 - 5s/epoch - 767ms/step
# Epoch 254/1000
#
# Epoch 254: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 598854.8750 - val_loss: 49419.5898 - 5s/epoch - 674ms/step
# Epoch 255/1000
#
# Epoch 255: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 504012.6562 - val_loss: 35671.7695 - 6s/epoch - 870ms/step
# Epoch 256/1000
#
# Epoch 256: val_loss did not improve from 4774.85791
# 7/7 - 7s - loss: 588947.0000 - val_loss: 55626.2383 - 7s/epoch - 994ms/step
# Epoch 257/1000
#
# Epoch 257: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 534878.9375 - val_loss: 80058.8438 - 6s/epoch - 881ms/step
# Epoch 258/1000
#
# Epoch 258: val_loss did not improve from 4774.85791
# 7/7 - 7s - loss: 470280.4062 - val_loss: 107417.4688 - 7s/epoch - 966ms/step
# Epoch 259/1000
#
# Epoch 259: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 532910.9375 - val_loss: 26662.1973 - 5s/epoch - 726ms/step
# Epoch 260/1000
#
# Epoch 260: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 572092.0000 - val_loss: 124203.8984 - 5s/epoch - 673ms/step
# Epoch 261/1000
#
# Epoch 261: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 481602.2812 - val_loss: 63378.3398 - 6s/epoch - 872ms/step
# Epoch 262/1000
#
# Epoch 262: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 646759.0625 - val_loss: 102567.1797 - 6s/epoch - 822ms/step
# Epoch 263/1000
#
# Epoch 263: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 611599.1875 - val_loss: 61441.8359 - 5s/epoch - 675ms/step
# Epoch 264/1000
#
# Epoch 264: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 563667.4375 - val_loss: 49154.9453 - 6s/epoch - 818ms/step
# Epoch 265/1000
#
# Epoch 265: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 529376.7500 - val_loss: 61186.9297 - 6s/epoch - 875ms/step
# Epoch 266/1000
#
# Epoch 266: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 583961.4375 - val_loss: 117983.1484 - 5s/epoch - 661ms/step
# Epoch 267/1000
#
# Epoch 267: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 500496.3125 - val_loss: 89354.9609 - 5s/epoch - 733ms/step
# Epoch 268/1000
#
# Epoch 268: val_loss did not improve from 4774.85791
# 7/7 - 7s - loss: 523108.9062 - val_loss: 83504.8281 - 7s/epoch - 968ms/step
# Epoch 269/1000
#
# Epoch 269: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 559010.2500 - val_loss: 64674.4336 - 5s/epoch - 664ms/step
# Epoch 270/1000
#
# Epoch 270: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 568193.9375 - val_loss: 71417.3203 - 5s/epoch - 650ms/step
# Epoch 271/1000
#
# Epoch 271: val_loss did not improve from 4774.85791
# 7/7 - 7s - loss: 500919.8125 - val_loss: 47317.3906 - 7s/epoch - 946ms/step
# Epoch 272/1000
#
# Epoch 272: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 497285.0312 - val_loss: 57836.8750 - 5s/epoch - 725ms/step
# Epoch 273/1000
#
# Epoch 273: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 516140.2188 - val_loss: 92821.5781 - 5s/epoch - 661ms/step
# Epoch 274/1000
#
# Epoch 274: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 508729.9062 - val_loss: 82102.5625 - 6s/epoch - 873ms/step
# Epoch 275/1000
#
# Epoch 275: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 503465.8750 - val_loss: 73240.5625 - 6s/epoch - 812ms/step
# Epoch 276/1000
#
# Epoch 276: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 492576.8750 - val_loss: 79870.2734 - 5s/epoch - 671ms/step
# Epoch 277/1000
#
# Epoch 277: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 542241.7500 - val_loss: 94564.8906 - 6s/epoch - 797ms/step
# Epoch 278/1000
#
# Epoch 278: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 485050.8750 - val_loss: 78291.9375 - 6s/epoch - 902ms/step
# Epoch 279/1000
#
# Epoch 279: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 531209.0625 - val_loss: 61384.4688 - 5s/epoch - 674ms/step
# Epoch 280/1000
#
# Epoch 280: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 498977.5000 - val_loss: 82046.5000 - 5s/epoch - 729ms/step
# Epoch 281/1000
#
# Epoch 281: val_loss did not improve from 4774.85791
# 7/7 - 7s - loss: 586733.9375 - val_loss: 121997.1875 - 7s/epoch - 993ms/step
# Epoch 282/1000
#
# Epoch 282: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 543601.8125 - val_loss: 84968.9297 - 5s/epoch - 678ms/step
# Epoch 283/1000
#
# Epoch 283: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 469389.1562 - val_loss: 89111.7969 - 5s/epoch - 668ms/step
# Epoch 284/1000
#
# Epoch 284: val_loss did not improve from 4774.85791
# 7/7 - 7s - loss: 516434.8125 - val_loss: 142205.3750 - 7s/epoch - 1s/step
# Epoch 285/1000
#
# Epoch 285: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 536171.2500 - val_loss: 35941.9531 - 5s/epoch - 714ms/step
# Epoch 286/1000
#
# Epoch 286: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 546124.7500 - val_loss: 105290.3906 - 5s/epoch - 686ms/step
# Epoch 287/1000
#
# Epoch 287: val_loss did not improve from 4774.85791
# 7/7 - 7s - loss: 488992.8438 - val_loss: 97070.1016 - 7s/epoch - 929ms/step
# Epoch 288/1000
#
# Epoch 288: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 554150.3125 - val_loss: 113296.8672 - 6s/epoch - 789ms/step
# Epoch 289/1000
#
# Epoch 289: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 494766.3750 - val_loss: 95625.9297 - 5s/epoch - 675ms/step
# Epoch 290/1000
#
# Epoch 290: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 553727.1250 - val_loss: 72344.1406 - 6s/epoch - 823ms/step
# Epoch 291/1000
#
# Epoch 291: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 495423.0625 - val_loss: 56548.6719 - 6s/epoch - 887ms/step
# Epoch 292/1000
#
# Epoch 292: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 597041.1250 - val_loss: 94406.7422 - 5s/epoch - 678ms/step
# Epoch 293/1000
#
# Epoch 293: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 526325.0625 - val_loss: 77248.6016 - 5s/epoch - 781ms/step
# Epoch 294/1000
#
# Epoch 294: val_loss did not improve from 4774.85791
# 7/7 - 7s - loss: 528997.9375 - val_loss: 43385.0781 - 7s/epoch - 948ms/step
# Epoch 295/1000
#
# Epoch 295: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 528946.6250 - val_loss: 114718.6797 - 5s/epoch - 670ms/step
# Epoch 296/1000
#
# Epoch 296: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 528989.4375 - val_loss: 28314.5918 - 5s/epoch - 722ms/step
# Epoch 297/1000
#
# Epoch 297: val_loss did not improve from 4774.85791
# 7/7 - 7s - loss: 572350.1250 - val_loss: 149878.0781 - 7s/epoch - 1s/step
# Epoch 298/1000
#
# Epoch 298: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 555704.1250 - val_loss: 37180.8984 - 5s/epoch - 666ms/step
# Epoch 299/1000
#
# Epoch 299: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 553057.2500 - val_loss: 98558.5938 - 5s/epoch - 675ms/step
# Epoch 300/1000
#
# Epoch 300: val_loss did not improve from 4774.85791
# 7/7 - 7s - loss: 536407.3750 - val_loss: 82389.0234 - 7s/epoch - 964ms/step
# Epoch 301/1000
#
# Epoch 301: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 501768.4375 - val_loss: 59279.8047 - 5s/epoch - 723ms/step
# Epoch 302/1000
#
# Epoch 302: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 549371.6250 - val_loss: 124509.0781 - 5s/epoch - 664ms/step
# Epoch 303/1000
#
# Epoch 303: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 598422.1875 - val_loss: 71933.6094 - 6s/epoch - 923ms/step
# Epoch 304/1000
#
# Epoch 304: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 453612.0938 - val_loss: 89505.9609 - 6s/epoch - 788ms/step
# Epoch 305/1000
#
# Epoch 305: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 510643.6875 - val_loss: 70730.7422 - 5s/epoch - 670ms/step
# Epoch 306/1000
#
# Epoch 306: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 543673.1875 - val_loss: 55035.7852 - 6s/epoch - 857ms/step
# Epoch 307/1000
#
# Epoch 307: val_loss did not improve from 4774.85791
# 7/7 - 7s - loss: 541476.3125 - val_loss: 91844.2812 - 7s/epoch - 1s/step
# Epoch 308/1000
#
# Epoch 308: val_loss did not improve from 4774.85791
# 7/7 - 7s - loss: 551795.8125 - val_loss: 43050.0586 - 7s/epoch - 939ms/step
# Epoch 309/1000
#
# Epoch 309: val_loss did not improve from 4774.85791
# 7/7 - 9s - loss: 494722.8750 - val_loss: 74539.5469 - 9s/epoch - 1s/step
# Epoch 310/1000
#
# Epoch 310: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 485770.6562 - val_loss: 29343.4980 - 6s/epoch - 810ms/step
# Epoch 311/1000
#
# Epoch 311: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 578014.8750 - val_loss: 180183.5156 - 5s/epoch - 655ms/step
# Epoch 312/1000
#
# Epoch 312: val_loss did not improve from 4774.85791
# ...
# 7/7 - 5s - loss: 337698.8125 - val_loss: 27003.8418 - 5s/epoch - 706ms/step
# Epoch 892/1000
#
# Epoch 892: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 361080.4375 - val_loss: 10629.5430 - 5s/epoch - 668ms/step
# Epoch 893/1000
#
# Epoch 893: val_loss did not improve from 4774.85791
# 7/7 - 7s - loss: 394559.0625 - val_loss: 11479.7148 - 7s/epoch - 956ms/step
# Epoch 894/1000
#
# Epoch 894: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 371359.3438 - val_loss: 25366.7500 - 5s/epoch - 771ms/step
# Epoch 895/1000
#
# Epoch 895: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 375115.3438 - val_loss: 5794.1606 - 5s/epoch - 676ms/step
# Epoch 896/1000
#
# Epoch 896: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 383097.2188 - val_loss: 21902.3203 - 6s/epoch - 874ms/step
# Epoch 897/1000
#
# Epoch 897: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 434185.1875 - val_loss: 15592.2471 - 6s/epoch - 845ms/step
# Epoch 898/1000
#
# Epoch 898: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 389777.0312 - val_loss: 18051.4004 - 5s/epoch - 664ms/step
# Epoch 899/1000
#
# Epoch 899: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 366513.0938 - val_loss: 18392.7246 - 6s/epoch - 805ms/step
# Epoch 900/1000
#
# Epoch 900: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 404373.2500 - val_loss: 8848.3750 - 6s/epoch - 923ms/step
# Epoch 901/1000
#
# Epoch 901: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 375826.1250 - val_loss: 19885.6641 - 5s/epoch - 661ms/step
# Epoch 902/1000
#
# Epoch 902: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 424821.6250 - val_loss: 18168.9531 - 5s/epoch - 703ms/step
# Epoch 903/1000
#
# Epoch 903: val_loss did not improve from 4774.85791
# 7/7 - 7s - loss: 347802.5312 - val_loss: 29515.6172 - 7s/epoch - 1s/step
# Epoch 904/1000
#
# Epoch 904: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 369948.7188 - val_loss: 26051.6680 - 5s/epoch - 669ms/step
# Epoch 905/1000
#
# Epoch 905: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 379891.1562 - val_loss: 21038.6895 - 5s/epoch - 669ms/step
# Epoch 906/1000
#
# Epoch 906: val_loss did not improve from 4774.85791
# 7/7 - 7s - loss: 365752.7188 - val_loss: 9066.9766 - 7s/epoch - 962ms/step
# Epoch 907/1000
#
# Epoch 907: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 331642.5000 - val_loss: 7856.1724 - 5s/epoch - 745ms/step
# Epoch 908/1000
#
# Epoch 908: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 376090.8750 - val_loss: 11325.7861 - 5s/epoch - 687ms/step
# Epoch 909/1000
#
# Epoch 909: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 390038.5312 - val_loss: 7679.4092 - 6s/epoch - 895ms/step
# Epoch 910/1000
#
# Epoch 910: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 399491.0625 - val_loss: 17171.8594 - 6s/epoch - 800ms/step
# Epoch 911/1000
#
# Epoch 911: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 398871.6875 - val_loss: 9446.0879 - 5s/epoch - 683ms/step
# Epoch 912/1000
#
# Epoch 912: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 392441.7188 - val_loss: 25871.2520 - 6s/epoch - 830ms/step
# Epoch 913/1000
#
# Epoch 913: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 388116.6562 - val_loss: 19546.9102 - 6s/epoch - 866ms/step
# Epoch 914/1000
#
# Epoch 914: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 378196.4062 - val_loss: 29335.4199 - 5s/epoch - 668ms/step
# Epoch 915/1000
#
# Epoch 915: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 337868.1562 - val_loss: 11357.2959 - 5s/epoch - 749ms/step
# Epoch 916/1000
#
# Epoch 916: val_loss did not improve from 4774.85791
# 7/7 - 7s - loss: 358983.8438 - val_loss: 13544.3203 - 7s/epoch - 961ms/step
# Epoch 917/1000
#
# Epoch 917: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 417981.1875 - val_loss: 29464.1992 - 5s/epoch - 677ms/step
# Epoch 918/1000
#
# Epoch 918: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 345054.6250 - val_loss: 14826.4316 - 5s/epoch - 656ms/step
# Epoch 919/1000
#
# Epoch 919: val_loss did not improve from 4774.85791
# 7/7 - 7s - loss: 373219.4688 - val_loss: 18864.2129 - 7s/epoch - 979ms/step
# Epoch 920/1000
#
# Epoch 920: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 393192.9062 - val_loss: 17896.8535 - 5s/epoch - 707ms/step
# Epoch 921/1000
#
# Epoch 921: val_loss did not improve from 4774.85791
# 7/7 - 5s - loss: 400791.7500 - val_loss: 8601.0664 - 5s/epoch - 659ms/step
# Epoch 922/1000
#
# Epoch 922: val_loss did not improve from 4774.85791
# 7/7 - 6s - loss: 399068.4688 - val_loss: 20492.6133 - 6s/epoch - 921ms/step
# Epoch 923/1000
#
# Epoch 923: val_loss improved from 4774.85791 to 4663.83496, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 6s - loss: 355446.5625 - val_loss: 4663.8350 - 6s/epoch - 835ms/step
# Epoch 924/1000
#
# Epoch 924: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 396247.0938 - val_loss: 5091.7915 - 5s/epoch - 668ms/step
# Epoch 925/1000
#
# Epoch 925: val_loss did not improve from 4663.83496
# 7/7 - 6s - loss: 384426.5938 - val_loss: 9092.5010 - 6s/epoch - 859ms/step
# Epoch 926/1000
#
# Epoch 926: val_loss did not improve from 4663.83496
# 7/7 - 6s - loss: 392526.1250 - val_loss: 10315.9590 - 6s/epoch - 843ms/step
# Epoch 927/1000
#
# Epoch 927: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 367812.6250 - val_loss: 43048.7031 - 5s/epoch - 674ms/step
# Epoch 928/1000
#
# Epoch 928: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 404149.5938 - val_loss: 12851.6250 - 5s/epoch - 774ms/step
# Epoch 929/1000
#
# Epoch 929: val_loss did not improve from 4663.83496
# 7/7 - 6s - loss: 367195.0312 - val_loss: 26624.6992 - 6s/epoch - 917ms/step
# Epoch 930/1000
#
# Epoch 930: val_loss did not improve from 4663.83496
# 7/7 - 6s - loss: 410325.7812 - val_loss: 23079.9492 - 6s/epoch - 791ms/step
# Epoch 931/1000
#
# Epoch 931: val_loss did not improve from 4663.83496
# 7/7 - 7s - loss: 352945.3125 - val_loss: 13050.6260 - 7s/epoch - 1s/step
# Epoch 932/1000
#
# Epoch 932: val_loss did not improve from 4663.83496
# 7/7 - 6s - loss: 454096.5312 - val_loss: 9511.7754 - 6s/epoch - 901ms/step
# Epoch 933/1000
#
# Epoch 933: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 390976.0625 - val_loss: 5881.3145 - 5s/epoch - 658ms/step
# Epoch 934/1000
#
# Epoch 934: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 384829.0938 - val_loss: 11373.9150 - 5s/epoch - 697ms/step
# Epoch 935/1000
#
# Epoch 935: val_loss did not improve from 4663.83496
# 7/7 - 7s - loss: 331390.0625 - val_loss: 26406.1992 - 7s/epoch - 1s/step
# Epoch 936/1000
#
# Epoch 936: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 332399.3750 - val_loss: 20779.7480 - 5s/epoch - 669ms/step
# Epoch 937/1000
#
# Epoch 937: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 390066.1562 - val_loss: 14028.1924 - 5s/epoch - 686ms/step
# Epoch 938/1000
#
# Epoch 938: val_loss did not improve from 4663.83496
# 7/7 - 7s - loss: 366097.5000 - val_loss: 51167.3594 - 7s/epoch - 956ms/step
# Epoch 939/1000
#
# Epoch 939: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 344771.0312 - val_loss: 5153.8887 - 5s/epoch - 735ms/step
# Epoch 940/1000
#
# Epoch 940: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 433499.2188 - val_loss: 23725.2656 - 5s/epoch - 665ms/step
# Epoch 941/1000
#
# Epoch 941: val_loss did not improve from 4663.83496
# 7/7 - 6s - loss: 391930.3750 - val_loss: 8796.3955 - 6s/epoch - 881ms/step
# Epoch 942/1000
#
# Epoch 942: val_loss did not improve from 4663.83496
# 7/7 - 6s - loss: 370809.0938 - val_loss: 20611.6934 - 6s/epoch - 821ms/step
# Epoch 943/1000
#
# Epoch 943: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 373347.2188 - val_loss: 23086.8555 - 5s/epoch - 663ms/step
# Epoch 944/1000
#
# Epoch 944: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 343311.0000 - val_loss: 13231.8525 - 5s/epoch - 753ms/step
# Epoch 945/1000
#
# Epoch 945: val_loss did not improve from 4663.83496
# 7/7 - 7s - loss: 354034.9062 - val_loss: 17386.9121 - 7s/epoch - 931ms/step
# Epoch 946/1000
#
# Epoch 946: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 404325.8125 - val_loss: 8589.9912 - 5s/epoch - 661ms/step
# Epoch 947/1000
#
# Epoch 947: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 373869.6562 - val_loss: 6949.8496 - 5s/epoch - 659ms/step
# Epoch 948/1000
#
# Epoch 948: val_loss did not improve from 4663.83496
# 7/7 - 7s - loss: 314490.5938 - val_loss: 22048.4746 - 7s/epoch - 986ms/step
# Epoch 949/1000
#
# Epoch 949: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 425973.1875 - val_loss: 18394.3223 - 5s/epoch - 707ms/step
# Epoch 950/1000
#
# Epoch 950: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 428713.3125 - val_loss: 20921.9727 - 5s/epoch - 670ms/step
# Epoch 951/1000
#
# Epoch 951: val_loss did not improve from 4663.83496
# 7/7 - 7s - loss: 375493.6875 - val_loss: 12593.6025 - 7s/epoch - 932ms/step
# Epoch 952/1000
#
# Epoch 952: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 348555.3125 - val_loss: 17211.6641 - 5s/epoch - 781ms/step
# Epoch 953/1000
#
# Epoch 953: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 358163.8438 - val_loss: 24841.8145 - 5s/epoch - 667ms/step
# Epoch 954/1000
#
# Epoch 954: val_loss did not improve from 4663.83496
# 7/7 - 6s - loss: 381968.9375 - val_loss: 21710.1152 - 6s/epoch - 894ms/step
# Epoch 955/1000
#
# Epoch 955: val_loss did not improve from 4663.83496
# 7/7 - 6s - loss: 347578.3438 - val_loss: 30317.3945 - 6s/epoch - 826ms/step
# Epoch 956/1000
#
# Epoch 956: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 354796.7188 - val_loss: 35852.9219 - 5s/epoch - 674ms/step
# Epoch 957/1000
#
# Epoch 957: val_loss did not improve from 4663.83496
# 7/7 - 6s - loss: 420093.0000 - val_loss: 16138.7617 - 6s/epoch - 809ms/step
# Epoch 958/1000
#
# Epoch 958: val_loss did not improve from 4663.83496
# 7/7 - 6s - loss: 373498.5625 - val_loss: 16956.4492 - 6s/epoch - 907ms/step
# Epoch 959/1000
#
# Epoch 959: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 369920.0938 - val_loss: 4972.7808 - 5s/epoch - 677ms/step
# Epoch 960/1000
#
# Epoch 960: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 398964.8750 - val_loss: 16643.1602 - 5s/epoch - 744ms/step
# Epoch 961/1000
#
# Epoch 961: val_loss did not improve from 4663.83496
# 7/7 - 7s - loss: 382368.0625 - val_loss: 19591.6797 - 7s/epoch - 967ms/step
# Epoch 962/1000
#
# Epoch 962: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 363902.0625 - val_loss: 6679.1548 - 5s/epoch - 675ms/step
# Epoch 963/1000
#
# Epoch 963: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 376574.6250 - val_loss: 18709.7051 - 5s/epoch - 690ms/step
# Epoch 964/1000
#
# Epoch 964: val_loss did not improve from 4663.83496
# 7/7 - 7s - loss: 401784.0625 - val_loss: 12211.2412 - 7s/epoch - 983ms/step
# Epoch 965/1000
#
# Epoch 965: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 368723.9375 - val_loss: 5073.4102 - 5s/epoch - 711ms/step
# Epoch 966/1000
#
# Epoch 966: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 377310.5000 - val_loss: 27409.2559 - 5s/epoch - 669ms/step
# Epoch 967/1000
#
# Epoch 967: val_loss did not improve from 4663.83496
# 7/7 - 6s - loss: 377132.6875 - val_loss: 12173.4717 - 6s/epoch - 902ms/step
# Epoch 968/1000
#
# Epoch 968: val_loss did not improve from 4663.83496
# 7/7 - 6s - loss: 342784.7812 - val_loss: 18467.7383 - 6s/epoch - 787ms/step
# Epoch 969/1000
#
# Epoch 969: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 367527.5000 - val_loss: 18448.9258 - 5s/epoch - 675ms/step
# Epoch 970/1000
#
# Epoch 970: val_loss did not improve from 4663.83496
# 7/7 - 6s - loss: 395264.1562 - val_loss: 11397.1777 - 6s/epoch - 848ms/step
# Epoch 971/1000
#
# Epoch 971: val_loss did not improve from 4663.83496
# 7/7 - 6s - loss: 384505.6562 - val_loss: 7714.9629 - 6s/epoch - 866ms/step
# Epoch 972/1000
#
# Epoch 972: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 393658.3125 - val_loss: 14607.3838 - 5s/epoch - 671ms/step
# Epoch 973/1000
#
# Epoch 973: val_loss did not improve from 4663.83496
# 7/7 - 6s - loss: 381626.8750 - val_loss: 9167.9707 - 6s/epoch - 792ms/step
# Epoch 974/1000
#
# Epoch 974: val_loss did not improve from 4663.83496
# 7/7 - 6s - loss: 338860.7812 - val_loss: 23196.2617 - 6s/epoch - 922ms/step
# Epoch 975/1000
#
# Epoch 975: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 425034.2188 - val_loss: 16839.4688 - 5s/epoch - 671ms/step
# Epoch 976/1000
#
# Epoch 976: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 368586.0312 - val_loss: 27439.5508 - 5s/epoch - 693ms/step
# Epoch 977/1000
#
# Epoch 977: val_loss did not improve from 4663.83496
# 7/7 - 7s - loss: 407839.2812 - val_loss: 10892.5586 - 7s/epoch - 1s/step
# Epoch 978/1000
#
# Epoch 978: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 347790.8125 - val_loss: 7399.8618 - 5s/epoch - 676ms/step
# Epoch 979/1000
#
# Epoch 979: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 357118.2812 - val_loss: 31738.0957 - 5s/epoch - 679ms/step
# Epoch 980/1000
#
# Epoch 980: val_loss did not improve from 4663.83496
# 7/7 - 7s - loss: 375944.9688 - val_loss: 23883.6973 - 7s/epoch - 990ms/step
# Epoch 981/1000
#
# Epoch 981: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 354041.3750 - val_loss: 12391.9590 - 5s/epoch - 724ms/step
# Epoch 982/1000
#
# Epoch 982: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 350388.4688 - val_loss: 9728.5205 - 5s/epoch - 660ms/step
# Epoch 983/1000
#
# Epoch 983: val_loss did not improve from 4663.83496
# 7/7 - 7s - loss: 379800.5312 - val_loss: 20863.1406 - 7s/epoch - 938ms/step
# Epoch 984/1000
#
# Epoch 984: val_loss did not improve from 4663.83496
# 7/7 - 8s - loss: 408199.5625 - val_loss: 25645.4531 - 8s/epoch - 1s/step
# Epoch 985/1000
#
# Epoch 985: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 390475.8438 - val_loss: 23299.3359 - 5s/epoch - 739ms/step
# Epoch 986/1000
#
# Epoch 986: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 351379.1562 - val_loss: 5802.1782 - 5s/epoch - 668ms/step
# Epoch 987/1000
#
# Epoch 987: val_loss did not improve from 4663.83496
# 7/7 - 7s - loss: 369877.5625 - val_loss: 8761.0264 - 7s/epoch - 992ms/step
# Epoch 988/1000
#
# Epoch 988: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 383887.5000 - val_loss: 8268.4092 - 5s/epoch - 715ms/step
# Epoch 989/1000
#
# Epoch 989: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 397028.4375 - val_loss: 15117.8125 - 5s/epoch - 674ms/step
# Epoch 990/1000
#
# Epoch 990: val_loss did not improve from 4663.83496
# 7/7 - 6s - loss: 392372.0625 - val_loss: 6576.7559 - 6s/epoch - 917ms/step
# Epoch 991/1000
#
# Epoch 991: val_loss did not improve from 4663.83496
# 7/7 - 6s - loss: 384958.2812 - val_loss: 14021.6074 - 6s/epoch - 802ms/step
# Epoch 992/1000
#
# Epoch 992: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 373526.8438 - val_loss: 5286.7427 - 5s/epoch - 674ms/step
# Epoch 993/1000
#
# Epoch 993: val_loss did not improve from 4663.83496
# 7/7 - 6s - loss: 405508.4688 - val_loss: 8492.3643 - 6s/epoch - 840ms/step
# Epoch 994/1000
#
# Epoch 994: val_loss did not improve from 4663.83496
# 7/7 - 6s - loss: 349088.5312 - val_loss: 9530.9346 - 6s/epoch - 880ms/step
# Epoch 995/1000
#
# Epoch 995: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 384184.9062 - val_loss: 23382.0234 - 5s/epoch - 677ms/step
# Epoch 996/1000
#
# Epoch 996: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 395368.0312 - val_loss: 16161.5312 - 5s/epoch - 778ms/step
# Epoch 997/1000
#
# Epoch 997: val_loss did not improve from 4663.83496
# 7/7 - 6s - loss: 342552.3750 - val_loss: 8240.0635 - 6s/epoch - 928ms/step
# Epoch 998/1000
#
# Epoch 998: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 363214.3750 - val_loss: 12671.5049 - 5s/epoch - 652ms/step
# Epoch 999/1000
#
# Epoch 999: val_loss did not improve from 4663.83496
# 7/7 - 5s - loss: 417256.0625 - val_loss: 18079.3145 - 5s/epoch - 671ms/step
# Epoch 1000/1000
#
# Epoch 1000: val_loss did not improve from 4663.83496
# 7/7 - 7s - loss: 386469.4688 - val_loss: 14874.9092 - 7s/epoch - 963ms/step
# 16/16 [==============================] - 4s 147ms/step
# 3/3 [==============================] - 0s 128ms/step
# Training MSE: 31142.748774683736
# Testing MSE: 14441.792063170495
# accuracy : 57
