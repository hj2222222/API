# %% [markdown]
# <a href="https://colab.research.google.com/github/hj2222222/API/blob/main/V5_2_experiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import os
import math
import matplotlib.pyplot as plt
import keras
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras import optimizers
from tensorflow.keras.layers import LSTM, Dropout, Dense, Conv1D, MaxPooling1D, Flatten
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Bidirectional
from keras.layers import Dropout, Flatten,TimeDistributed
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from tensorflow.keras.losses import Huber
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


stock_data = pd.read_csv('/content/drive/MyDrive/산업 AI 캡스톤/DATA/Total_Data/Final_Feature_kospi_sen_all.csv')
stock_data
# Out:
#          Date  Kospi_close  Kospi_high  ko_interest  oil_open  ex_JP_low  \
# 0    20210105      2990.57       0.795          0.0     0.213      0.590
# 1    20210106      2968.21       0.819          0.0     0.219      0.596
# 2    20210107      3031.68       0.839          0.0     0.225      0.597
# 3    20210108      3152.18       0.855          0.0     0.230      0.584
# 4    20210111      3148.45       0.914          0.0     0.232      0.584
# ..        ...          ...         ...          ...       ...        ...
# 583  20230623      2570.10       0.601          1.0     0.651      0.028
# 584  20230626      2582.20       0.602          1.0     0.651      0.024
# 585  20230627      2581.39       0.594          1.0     0.651      0.000
# 586  20230628      2564.19       0.592          1.0     0.651      0.011
# 587  20230629      2550.02       0.597          1.0     0.651      0.020
#
#      gold_low  us500_low  klue_bert_score_summarize_content  oil_vol  \
# 0       0.661      0.581                             -0.536    0.013
# 1       0.650      0.585                              1.381    0.006
# 2       0.670      0.608                              1.845    0.007
# 3       0.631      0.615                              2.497    0.004
# 4       0.623      0.617                             -0.951    0.009
# ..        ...        ...                                ...      ...
# 583     0.212      0.830                              0.402    0.000
# 584     0.212      0.825                             -0.385    0.000
# 585     0.208      0.828                             -0.447    0.000
# 586     0.217      0.838                              0.777    0.000
# 587     0.208      0.842                             -0.038    0.000
#
#      research_kospi  dji_vol  us500_vol  \
# 0             0.413    0.280      0.349
# 1             0.628    0.470      0.527
# 2             0.427    0.378      0.410
# 3             0.512    0.318      0.371
# 4             0.881    0.287      0.334
# ..              ...      ...        ...
# 583           0.125    0.316      0.526
# 584           0.120    0.170      0.207
# 585           0.118    0.206      0.226
# 586           0.128    0.174      0.246
# 587           0.127    0.189      0.241
#
#      kofinbert_score_summarize_content_kospi  kofinbert_score_title_kospi  \
# 0                                      0.157                        0.195
# 1                                      1.236                        0.569
# 2                                      0.537                        1.395
# 3                                      0.697                       -1.382
# 4                                      0.331                       -0.044
# ..                                       ...                          ...
# 583                                    0.834                       -0.339
# 584                                   -0.196                        0.681
# 585                                   -0.208                        0.625
# 586                                    1.099                        0.892
# 587                                    0.382                       -0.145
#
#      klue_bert_score_title
# 0                    0.823
# 1                    0.722
# 2                   -0.675
# 3                    1.124
# 4                    0.730
# ..                     ...
# 583                  0.831
# 584                 -0.001
# 585                 -0.097
# 586                  0.253
# 587                 -0.378
#
# [588 rows x 16 columns]

# %%
# 데이터 전처리
data = stock_data['Kospi_close'].values.reshape(-1, 1)
stock_data = stock_data.drop(['Kospi_close'],axis=1)
stock_data = stock_data.drop(['Date'],axis=1)

# %%
name = [stock_data.columns]

close_1 = ['klue_bert_score_summarize_content',
        'kofinbert_score_summarize_content_kospi']

stock_data_1 = stock_data.drop(close_1, axis=1)

# %%
# 데이터 분할
train_size = int(len(data) * 0.85)
train_data, test_data = data[:train_size], data[train_size:]
train_data_t_1, test_data_t_1 = stock_data_1[:train_size], stock_data_1[train_size:]
train_data_t_2, test_data_t_2 = stock_data[:train_size], stock_data[train_size:]

def create_dataset(dataset, data, look_back=10):
    X, y = [], []
    for i in range(len(data) - look_back):
        X.append(dataset[i:(i + look_back)])
        y.append(data[i + look_back])
    return np.array(X), np.array(y)

look_back = 10  # 몇 일 동안의 데이터를 사용할 것인지 설정

trainX, trainY = create_dataset(train_data_t_1, train_data, look_back)
testX, testY = create_dataset(test_data_t_1,test_data, look_back)
print(trainX.shape)
print(trainY.shape)
print(testX.shape)
print(testY.shape)
# Out:
# (489, 10, 12)
# (489, 1)
# (79, 10, 12)
# (79, 1)

# %%
def accuracy(list1,list2):
  list1 = list1.flatten().tolist()
  list2 = list2.flatten().tolist()
  value_1 = []
  value_2 = []
  j = 0
  if len(list1) == len(list2):
    for i in range(len(list1)-1):
      if list1[i+1] > list1[i]:
        value_1.append(1)
      elif list1[i+1] == list1[i]:
        value_1.append(0)
      else:
        value_1.append(-1)
    for i in range(len(list1)-1):
      if list2[i+1] > list2[i]:
        value_2.append(1)
      elif list2[i+1] == list2[i]:
        value_2.append(0)
      else:
        value_2.append(-1)
    for i in range(len(value_1)):
      if value_1[i] == value_2[i]:
        j = j + 1
    accuracy = j/len(value_1) * 100
    print("accuracy : %d" % accuracy)
  else:
    print("길이가 다릅니다.")

# %%
# 모델 생성 GRU+CNN
model = Sequential()
model.add(Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(MaxPooling1D(pool_size=2))
model.add(GRU(units=1024, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=512, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=256, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=128, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=64, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=32, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=16, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(units=1))
model.summary()


# loss = Huber()
# optimizer = Adam(0.0005)
# model.compile(loss=Huber(), optimizer=optimizer, metrics=['mse'])
model.compile(optimizer='adam', loss='mean_squared_error')

filename = os.path.join('tmp', 'ckeckpointer.ckpt')
checkpoint = ModelCheckpoint(filename,
                             save_weights_only=True,
                             save_best_only=True,
                             monitor='loss',
                             verbose=1)

# 모델 학습
history = model.fit(trainX, trainY, epochs=2000, batch_size=64,
          validation_split=0.1, verbose=2,callbacks=[checkpoint])

model.save_weights('./ko_sum_CNN_GRU__weights.h2')

model.load_weights(filename)

plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()
plt.show()

# 예측
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# MSE 계산
trainMSE = mean_squared_error(trainY, trainPredict)
testMSE = mean_squared_error(testY, testPredict)

print(f'Training MSE: {trainMSE}')
print(f'Testing MSE: {testMSE}')

accuracy(testPredict,testY)

# 예측 시각화
plt.plot(trainY, label='Actual Price')
plt.plot(trainPredict, label='Predicted Price')
plt.legend()
plt.title('Training Data')
plt.show()

plt.plot(testY, label='Actual Price')
plt.plot(testPredict, label='Predicted Price')
plt.legend()
plt.title('Testing Data')
plt.show()
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Epoch 751/2000
#
# Epoch 751: loss did not improve from 265301.90625
# 7/7 - 1s - loss: 282223.9688 - val_loss: 13898.5742 - 608ms/epoch - 87ms/step
# Epoch 752/2000
#
# Epoch 752: loss did not improve from 265301.90625
# 7/7 - 1s - loss: 282082.9375 - val_loss: 11733.0234 - 520ms/epoch - 74ms/step
# Epoch 753/2000
#
# Epoch 753: loss did not improve from 265301.90625
# 7/7 - 1s - loss: 308934.8438 - val_loss: 7448.7485 - 601ms/epoch - 86ms/step
# Epoch 754/2000
#
# Epoch 754: loss did not improve from 265301.90625
# 7/7 - 1s - loss: 277376.4375 - val_loss: 9993.8281 - 559ms/epoch - 80ms/step
# Epoch 755/2000
#
# Epoch 755: loss did not improve from 265301.90625
# 7/7 - 1s - loss: 329632.0625 - val_loss: 5662.6880 - 518ms/epoch - 74ms/step
# Epoch 756/2000
#
# Epoch 756: loss did not improve from 265301.90625
# 7/7 - 1s - loss: 276621.9688 - val_loss: 10365.6426 - 552ms/epoch - 79ms/step
# Epoch 757/2000
#
# Epoch 757: loss did not improve from 265301.90625
# 7/7 - 0s - loss: 273956.0938 - val_loss: 7332.7212 - 499ms/epoch - 71ms/step
# Epoch 758/2000
#
# Epoch 758: loss did not improve from 265301.90625
# 7/7 - 1s - loss: 282004.6875 - val_loss: 15541.8711 - 521ms/epoch - 74ms/step
# Epoch 759/2000
#
# Epoch 759: loss improved from 265301.90625 to 255018.64062, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 255018.6406 - val_loss: 7772.3188 - 770ms/epoch - 110ms/step
# Epoch 760/2000
#
# Epoch 760: loss did not improve from 255018.64062
# 7/7 - 1s - loss: 284004.1875 - val_loss: 33510.5625 - 534ms/epoch - 76ms/step
# Epoch 761/2000
#
# Epoch 761: loss did not improve from 255018.64062
# 7/7 - 1s - loss: 301202.5000 - val_loss: 13414.2334 - 556ms/epoch - 79ms/step
# Epoch 762/2000
#
# Epoch 762: loss did not improve from 255018.64062
# 7/7 - 1s - loss: 287609.1562 - val_loss: 5476.4019 - 540ms/epoch - 77ms/step
# Epoch 763/2000
#
# Epoch 763: loss did not improve from 255018.64062
# 7/7 - 1s - loss: 310030.9375 - val_loss: 5511.6475 - 523ms/epoch - 75ms/step
# Epoch 764/2000
#
# Epoch 764: loss did not improve from 255018.64062
# 7/7 - 1s - loss: 279540.2812 - val_loss: 7678.9785 - 545ms/epoch - 78ms/step
# Epoch 765/2000
#
# Epoch 765: loss did not improve from 255018.64062
# 7/7 - 1s - loss: 262164.0312 - val_loss: 22414.1328 - 524ms/epoch - 75ms/step
# Epoch 766/2000
#
# Epoch 766: loss did not improve from 255018.64062
# 7/7 - 1s - loss: 285757.0625 - val_loss: 6863.1641 - 539ms/epoch - 77ms/step
# Epoch 767/2000
#
# Epoch 767: loss improved from 255018.64062 to 253593.64062, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 253593.6406 - val_loss: 18559.7559 - 771ms/epoch - 110ms/step
# Epoch 768/2000
#
# Epoch 768: loss did not improve from 253593.64062
# 7/7 - 1s - loss: 279921.3750 - val_loss: 13486.0781 - 743ms/epoch - 106ms/step
# Epoch 769/2000
#
# Epoch 769: loss did not improve from 253593.64062
# 7/7 - 1s - loss: 287420.5000 - val_loss: 25476.3926 - 1s/epoch - 167ms/step
# Epoch 770/2000
#
# Epoch 770: loss did not improve from 253593.64062
# 7/7 - 1s - loss: 313098.1562 - val_loss: 14548.4756 - 1s/epoch - 144ms/step
# Epoch 771/2000
#
# Epoch 771: loss did not improve from 253593.64062
# 7/7 - 1s - loss: 266024.5312 - val_loss: 21543.5508 - 1s/epoch - 157ms/step
# Epoch 772/2000
#
# Epoch 772: loss improved from 253593.64062 to 242635.46875, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 242635.4688 - val_loss: 7803.1084 - 1s/epoch - 197ms/step
# Epoch 773/2000
#
# Epoch 773: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 287189.3750 - val_loss: 6645.2437 - 790ms/epoch - 113ms/step
# Epoch 774/2000
#
# Epoch 774: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 274760.3750 - val_loss: 10554.4258 - 599ms/epoch - 86ms/step
# Epoch 775/2000
#
# Epoch 775: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 290585.4062 - val_loss: 11031.5049 - 556ms/epoch - 79ms/step
# Epoch 776/2000
#
# Epoch 776: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 268576.5312 - val_loss: 31560.1230 - 517ms/epoch - 74ms/step
# Epoch 777/2000
#
# Epoch 777: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 285903.8750 - val_loss: 7118.3931 - 582ms/epoch - 83ms/step
# Epoch 778/2000
#
# Epoch 778: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 289823.5625 - val_loss: 13653.6592 - 520ms/epoch - 74ms/step
# Epoch 779/2000
#
# Epoch 779: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 273468.9062 - val_loss: 15180.0088 - 526ms/epoch - 75ms/step
# Epoch 780/2000
#
# Epoch 780: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 286031.4688 - val_loss: 12546.6484 - 520ms/epoch - 74ms/step
# Epoch 781/2000
#
# Epoch 781: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 288674.4062 - val_loss: 18989.1445 - 548ms/epoch - 78ms/step
# Epoch 782/2000
#
# Epoch 782: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 267463.5312 - val_loss: 8480.4512 - 524ms/epoch - 75ms/step
# Epoch 783/2000
#
# Epoch 783: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 278712.6250 - val_loss: 18944.8086 - 506ms/epoch - 72ms/step
# Epoch 784/2000
#
# Epoch 784: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 307283.9688 - val_loss: 18206.6133 - 548ms/epoch - 78ms/step
# Epoch 785/2000
#
# Epoch 785: loss did not improve from 242635.46875
# 7/7 - 0s - loss: 258242.6875 - val_loss: 44281.7148 - 494ms/epoch - 71ms/step
# Epoch 786/2000
#
# Epoch 786: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 317467.4062 - val_loss: 7686.1924 - 531ms/epoch - 76ms/step
# Epoch 787/2000
#
# Epoch 787: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 295072.3438 - val_loss: 22286.2441 - 506ms/epoch - 72ms/step
# Epoch 788/2000
#
# Epoch 788: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 315126.6250 - val_loss: 5930.3745 - 540ms/epoch - 77ms/step
# Epoch 789/2000
#
# Epoch 789: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 294400.5938 - val_loss: 38772.4805 - 504ms/epoch - 72ms/step
# Epoch 790/2000
#
# Epoch 790: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 290022.1562 - val_loss: 5503.1226 - 534ms/epoch - 76ms/step
# Epoch 791/2000
#
# Epoch 791: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 266843.7500 - val_loss: 31307.3574 - 521ms/epoch - 74ms/step
# Epoch 792/2000
#
# Epoch 792: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 276660.6875 - val_loss: 6253.1870 - 511ms/epoch - 73ms/step
# Epoch 793/2000
#
# Epoch 793: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 254228.2344 - val_loss: 17448.3262 - 831ms/epoch - 119ms/step
# Epoch 794/2000
#
# Epoch 794: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 295994.7188 - val_loss: 6829.8608 - 1s/epoch - 162ms/step
# Epoch 795/2000
#
# Epoch 795: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 264832.3750 - val_loss: 11614.3701 - 1s/epoch - 166ms/step
# Epoch 796/2000
#
# Epoch 796: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 266816.0625 - val_loss: 7457.2437 - 995ms/epoch - 142ms/step
# Epoch 797/2000
#
# Epoch 797: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 270892.0938 - val_loss: 5237.2578 - 1s/epoch - 157ms/step
# Epoch 798/2000
#
# Epoch 798: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 288131.1562 - val_loss: 11897.1904 - 970ms/epoch - 139ms/step
# Epoch 799/2000
#
# Epoch 799: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 268816.1875 - val_loss: 16692.7930 - 530ms/epoch - 76ms/step
# Epoch 800/2000
#
# Epoch 800: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 278100.9688 - val_loss: 5709.7036 - 515ms/epoch - 74ms/step
# Epoch 801/2000
#
# Epoch 801: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 303876.0625 - val_loss: 33952.8984 - 547ms/epoch - 78ms/step
# Epoch 802/2000
#
# Epoch 802: loss did not improve from 242635.46875
# 7/7 - 0s - loss: 255971.5625 - val_loss: 16098.5537 - 499ms/epoch - 71ms/step
# Epoch 803/2000
#
# Epoch 803: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 286852.7188 - val_loss: 26434.9590 - 561ms/epoch - 80ms/step
# Epoch 804/2000
#
# Epoch 804: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 275188.8125 - val_loss: 19682.2773 - 528ms/epoch - 75ms/step
# Epoch 805/2000
#
# Epoch 805: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 291063.5938 - val_loss: 15895.7402 - 512ms/epoch - 73ms/step
# Epoch 806/2000
#
# Epoch 806: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 271435.1250 - val_loss: 5956.9180 - 524ms/epoch - 75ms/step
# Epoch 807/2000
#
# Epoch 807: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 268902.7812 - val_loss: 6193.4590 - 523ms/epoch - 75ms/step
# Epoch 808/2000
#
# Epoch 808: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 300217.4062 - val_loss: 16973.9570 - 515ms/epoch - 74ms/step
# Epoch 809/2000
#
# Epoch 809: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 284802.1562 - val_loss: 5434.6714 - 517ms/epoch - 74ms/step
# Epoch 810/2000
#
# Epoch 810: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 294910.8125 - val_loss: 11120.2783 - 582ms/epoch - 83ms/step
# Epoch 811/2000
#
# Epoch 811: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 258581.6250 - val_loss: 9173.4863 - 521ms/epoch - 74ms/step
# Epoch 812/2000
#
# Epoch 812: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 265536.4062 - val_loss: 19980.4844 - 523ms/epoch - 75ms/step
# Epoch 813/2000
#
# Epoch 813: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 274229.2500 - val_loss: 5308.5566 - 527ms/epoch - 75ms/step
# Epoch 814/2000
#
# Epoch 814: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 250426.7031 - val_loss: 5872.8589 - 622ms/epoch - 89ms/step
# Epoch 815/2000
#
# Epoch 815: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 310655.9688 - val_loss: 5523.0986 - 525ms/epoch - 75ms/step
# Epoch 816/2000
#
# Epoch 816: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 245185.3750 - val_loss: 6021.7627 - 529ms/epoch - 76ms/step
# Epoch 817/2000
#
# Epoch 817: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 286904.6250 - val_loss: 21582.9805 - 808ms/epoch - 115ms/step
# Epoch 818/2000
#
# Epoch 818: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 290672.4375 - val_loss: 11390.5234 - 1s/epoch - 168ms/step
# Epoch 819/2000
#
# Epoch 819: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 284995.2188 - val_loss: 9422.2305 - 1s/epoch - 159ms/step
# Epoch 820/2000
#
# Epoch 820: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 289907.2500 - val_loss: 6983.0122 - 1s/epoch - 164ms/step
# Epoch 821/2000
#
# Epoch 821: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 259540.7344 - val_loss: 19318.4746 - 1s/epoch - 154ms/step
# Epoch 822/2000
#
# Epoch 822: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 266589.3750 - val_loss: 16136.8369 - 924ms/epoch - 132ms/step
# Epoch 823/2000
#
# Epoch 823: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 301752.5312 - val_loss: 8414.9863 - 563ms/epoch - 80ms/step
# Epoch 824/2000
#
# Epoch 824: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 310778.8438 - val_loss: 11738.0303 - 522ms/epoch - 75ms/step
# Epoch 825/2000
#
# Epoch 825: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 274866.5938 - val_loss: 11531.5264 - 555ms/epoch - 79ms/step
# Epoch 826/2000
#
# Epoch 826: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 265378.2500 - val_loss: 32314.7500 - 504ms/epoch - 72ms/step
# Epoch 827/2000
#
# Epoch 827: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 283244.7812 - val_loss: 11526.9873 - 544ms/epoch - 78ms/step
# Epoch 828/2000
#
# Epoch 828: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 279957.8125 - val_loss: 7366.5664 - 503ms/epoch - 72ms/step
# Epoch 829/2000
#
# Epoch 829: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 316608.4062 - val_loss: 8270.7305 - 531ms/epoch - 76ms/step
# Epoch 830/2000
#
# Epoch 830: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 284440.4688 - val_loss: 24976.0918 - 536ms/epoch - 77ms/step
# Epoch 831/2000
#
# Epoch 831: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 285018.6250 - val_loss: 14137.2598 - 555ms/epoch - 79ms/step
# Epoch 832/2000
#
# Epoch 832: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 273728.0938 - val_loss: 23122.9609 - 528ms/epoch - 75ms/step
# Epoch 833/2000
#
# Epoch 833: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 273512.4375 - val_loss: 5873.3799 - 514ms/epoch - 73ms/step
# Epoch 834/2000
#
# Epoch 834: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 312010.1562 - val_loss: 9711.9355 - 575ms/epoch - 82ms/step
# Epoch 835/2000
#
# Epoch 835: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 282262.9062 - val_loss: 7046.7231 - 532ms/epoch - 76ms/step
# Epoch 836/2000
#
# Epoch 836: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 291969.7812 - val_loss: 9473.8330 - 547ms/epoch - 78ms/step
# Epoch 837/2000
#
# Epoch 837: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 249698.2969 - val_loss: 23518.2031 - 523ms/epoch - 75ms/step
# Epoch 838/2000
#
# Epoch 838: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 279169.0625 - val_loss: 7303.6060 - 531ms/epoch - 76ms/step
# Epoch 839/2000
#
# Epoch 839: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 307666.4688 - val_loss: 7815.2026 - 500ms/epoch - 71ms/step
# Epoch 840/2000
#
# Epoch 840: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 291254.0625 - val_loss: 11969.1963 - 542ms/epoch - 77ms/step
# Epoch 841/2000
#
# Epoch 841: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 261629.7344 - val_loss: 8456.4414 - 627ms/epoch - 90ms/step
# Epoch 842/2000
#
# Epoch 842: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 287162.3750 - val_loss: 17774.5273 - 1s/epoch - 158ms/step
# Epoch 843/2000
#
# Epoch 843: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 293400.6250 - val_loss: 5780.7104 - 1s/epoch - 165ms/step
# Epoch 844/2000
#
# Epoch 844: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 257849.5312 - val_loss: 15822.6680 - 1s/epoch - 163ms/step
# Epoch 845/2000
#
# Epoch 845: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 315122.8125 - val_loss: 7050.6836 - 1s/epoch - 169ms/step
# Epoch 846/2000
#
# Epoch 846: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 270416.3750 - val_loss: 11032.9668 - 934ms/epoch - 133ms/step
# Epoch 847/2000
#
# Epoch 847: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 259331.0938 - val_loss: 11951.0586 - 672ms/epoch - 96ms/step
# Epoch 848/2000
#
# Epoch 848: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 260512.0312 - val_loss: 14473.0693 - 518ms/epoch - 74ms/step
# Epoch 849/2000
#
# Epoch 849: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 311328.6562 - val_loss: 5498.0103 - 610ms/epoch - 87ms/step
# Epoch 850/2000
#
# Epoch 850: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 315387.3438 - val_loss: 11626.3545 - 545ms/epoch - 78ms/step
# Epoch 851/2000
#
# Epoch 851: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 319894.9375 - val_loss: 14605.4912 - 532ms/epoch - 76ms/step
# Epoch 852/2000
#
# Epoch 852: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 260332.4375 - val_loss: 17198.1113 - 513ms/epoch - 73ms/step
# Epoch 853/2000
#
# Epoch 853: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 304425.8125 - val_loss: 11135.0908 - 551ms/epoch - 79ms/step
# Epoch 854/2000
#
# Epoch 854: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 291291.0938 - val_loss: 18675.8965 - 539ms/epoch - 77ms/step
# Epoch 855/2000
#
# Epoch 855: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 254223.2344 - val_loss: 7406.3008 - 516ms/epoch - 74ms/step
# Epoch 856/2000
#
# Epoch 856: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 274745.9062 - val_loss: 15985.2295 - 576ms/epoch - 82ms/step
# Epoch 857/2000
#
# Epoch 857: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 302299.7812 - val_loss: 5450.7485 - 545ms/epoch - 78ms/step
# Epoch 858/2000
#
# Epoch 858: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 301757.5625 - val_loss: 8545.7500 - 545ms/epoch - 78ms/step
# Epoch 859/2000
#
# Epoch 859: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 268251.8750 - val_loss: 5323.7085 - 510ms/epoch - 73ms/step
# Epoch 860/2000
#
# Epoch 860: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 287265.1250 - val_loss: 5579.3584 - 515ms/epoch - 74ms/step
# Epoch 861/2000
#
# Epoch 861: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 257570.0156 - val_loss: 11406.3174 - 547ms/epoch - 78ms/step
# Epoch 862/2000
#
# Epoch 862: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 259020.0469 - val_loss: 5975.7466 - 506ms/epoch - 72ms/step
# Epoch 863/2000
#
# Epoch 863: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 274351.2500 - val_loss: 15878.1904 - 548ms/epoch - 78ms/step
# Epoch 864/2000
#
# Epoch 864: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 261010.1094 - val_loss: 16843.9512 - 512ms/epoch - 73ms/step
# Epoch 865/2000
#
# Epoch 865: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 267280.3125 - val_loss: 5325.6255 - 674ms/epoch - 96ms/step
# Epoch 866/2000
#
# Epoch 866: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 301664.4062 - val_loss: 8129.1338 - 1s/epoch - 157ms/step
# Epoch 867/2000
#
# Epoch 867: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 278249.2500 - val_loss: 7894.9795 - 1s/epoch - 153ms/step
# Epoch 868/2000
#
# Epoch 868: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 271146.7188 - val_loss: 11613.5469 - 1s/epoch - 152ms/step
# Epoch 869/2000
#
# Epoch 869: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 273480.4375 - val_loss: 7473.6230 - 1s/epoch - 144ms/step
# Epoch 870/2000
#
# Epoch 870: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 253566.9062 - val_loss: 6914.6982 - 978ms/epoch - 140ms/step
# Epoch 871/2000
#
# Epoch 871: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 285496.2500 - val_loss: 9214.6426 - 833ms/epoch - 119ms/step
# Epoch 872/2000
#
# Epoch 872: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 310936.7500 - val_loss: 6500.0923 - 504ms/epoch - 72ms/step
# Epoch 873/2000
#
# Epoch 873: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 268657.6250 - val_loss: 6022.5562 - 539ms/epoch - 77ms/step
# Epoch 874/2000
#
# Epoch 874: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 298046.5000 - val_loss: 8147.2935 - 512ms/epoch - 73ms/step
# Epoch 875/2000
#
# Epoch 875: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 272373.5000 - val_loss: 12074.2949 - 534ms/epoch - 76ms/step
# Epoch 876/2000
#
# Epoch 876: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 256476.6875 - val_loss: 7394.2617 - 528ms/epoch - 75ms/step
# Epoch 877/2000
#
# Epoch 877: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 274801.4062 - val_loss: 9700.8701 - 511ms/epoch - 73ms/step
# Epoch 878/2000
#
# Epoch 878: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 272875.0625 - val_loss: 7291.3232 - 549ms/epoch - 78ms/step
# Epoch 879/2000
#
# Epoch 879: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 284301.4375 - val_loss: 5419.3403 - 583ms/epoch - 83ms/step
# Epoch 880/2000
#
# Epoch 880: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 256410.2344 - val_loss: 8360.0986 - 551ms/epoch - 79ms/step
# Epoch 881/2000
#
# Epoch 881: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 279689.3125 - val_loss: 7642.6021 - 544ms/epoch - 78ms/step
# Epoch 882/2000
#
# Epoch 882: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 282598.8125 - val_loss: 11185.4297 - 529ms/epoch - 76ms/step
# Epoch 883/2000
#
# Epoch 883: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 257865.2969 - val_loss: 5634.7485 - 524ms/epoch - 75ms/step
# Epoch 884/2000
#
# Epoch 884: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 271628.5312 - val_loss: 7655.3535 - 545ms/epoch - 78ms/step
# Epoch 885/2000
#
# Epoch 885: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 256800.9688 - val_loss: 5763.4976 - 526ms/epoch - 75ms/step
# Epoch 886/2000
#
# Epoch 886: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 252319.8906 - val_loss: 6111.2153 - 548ms/epoch - 78ms/step
# Epoch 887/2000
#
# Epoch 887: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 252105.3438 - val_loss: 6448.5952 - 515ms/epoch - 74ms/step
# Epoch 888/2000
#
# Epoch 888: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 253991.6875 - val_loss: 7041.3125 - 523ms/epoch - 75ms/step
# Epoch 889/2000
#
# Epoch 889: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 247058.8594 - val_loss: 11375.1338 - 519ms/epoch - 74ms/step
# Epoch 890/2000
#
# Epoch 890: loss did not improve from 242635.46875
# 7/7 - 1s - loss: 258679.1250 - val_loss: 6685.3481 - 1s/epoch - 157ms/step
# Epoch 891/2000
#
# Epoch 891: loss improved from 242635.46875 to 233548.76562, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 2s - loss: 233548.7656 - val_loss: 5628.2837 - 2s/epoch - 215ms/step
# Epoch 892/2000
#
# Epoch 892: loss did not improve from 233548.76562
# 7/7 - 1s - loss: 251627.5312 - val_loss: 6728.7812 - 1s/epoch - 169ms/step
# Epoch 893/2000
#
# Epoch 893: loss did not improve from 233548.76562
# 7/7 - 1s - loss: 263721.5938 - val_loss: 6897.4233 - 1s/epoch - 153ms/step
# Epoch 894/2000
#
# Epoch 894: loss did not improve from 233548.76562
# 7/7 - 1s - loss: 273167.5000 - val_loss: 8686.1533 - 1s/epoch - 154ms/step
# Epoch 895/2000
#
# Epoch 895: loss did not improve from 233548.76562
# 7/7 - 1s - loss: 257676.2500 - val_loss: 9321.2568 - 699ms/epoch - 100ms/step
# Epoch 896/2000
#
# Epoch 896: loss did not improve from 233548.76562
# 7/7 - 1s - loss: 252489.3750 - val_loss: 31961.9277 - 541ms/epoch - 77ms/step
# Epoch 897/2000
#
# Epoch 897: loss did not improve from 233548.76562
# 7/7 - 1s - loss: 261908.7500 - val_loss: 13385.5410 - 543ms/epoch - 78ms/step
# Epoch 898/2000
#
# Epoch 898: loss improved from 233548.76562 to 229466.31250, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 229466.3125 - val_loss: 15497.0557 - 764ms/epoch - 109ms/step
# Epoch 899/2000
#
# Epoch 899: loss did not improve from 229466.31250
# 7/7 - 1s - loss: 259353.2656 - val_loss: 5665.7871 - 514ms/epoch - 73ms/step
# Epoch 900/2000
#
# Epoch 900: loss did not improve from 229466.31250
# 7/7 - 1s - loss: 275198.6250 - val_loss: 5021.6748 - 563ms/epoch - 80ms/step
# Epoch 901/2000
#
# Epoch 901: loss did not improve from 229466.31250
# 7/7 - 1s - loss: 244197.9219 - val_loss: 17410.1836 - 564ms/epoch - 81ms/step
# Epoch 902/2000
#
# Epoch 902: loss did not improve from 229466.31250
# 7/7 - 1s - loss: 252167.2969 - val_loss: 6547.2524 - 532ms/epoch - 76ms/step
# Epoch 903/2000
#
# Epoch 903: loss did not improve from 229466.31250
# 7/7 - 1s - loss: 239455.9688 - val_loss: 7432.7192 - 530ms/epoch - 76ms/step
# Epoch 904/2000
#
# Epoch 904: loss did not improve from 229466.31250
# 7/7 - 1s - loss: 229931.8906 - val_loss: 10621.7930 - 551ms/epoch - 79ms/step
# Epoch 905/2000
#
# Epoch 905: loss did not improve from 229466.31250
# 7/7 - 1s - loss: 242471.9844 - val_loss: 9986.7725 - 550ms/epoch - 79ms/step
# Epoch 906/2000
#
# Epoch 906: loss did not improve from 229466.31250
# 7/7 - 1s - loss: 274495.7188 - val_loss: 9673.1797 - 516ms/epoch - 74ms/step
# Epoch 907/2000
#
# Epoch 907: loss did not improve from 229466.31250
# 7/7 - 1s - loss: 241970.9531 - val_loss: 17895.4180 - 549ms/epoch - 78ms/step
# Epoch 908/2000
#
# Epoch 908: loss did not improve from 229466.31250
# 7/7 - 1s - loss: 269881.0312 - val_loss: 9291.0957 - 534ms/epoch - 76ms/step
# Epoch 909/2000
#
# Epoch 909: loss did not improve from 229466.31250
# 7/7 - 1s - loss: 254663.3125 - val_loss: 11456.8906 - 597ms/epoch - 85ms/step
# Epoch 910/2000
#
# Epoch 910: loss did not improve from 229466.31250
# 7/7 - 1s - loss: 244564.9844 - val_loss: 6210.0601 - 566ms/epoch - 81ms/step
# Epoch 911/2000
#
# Epoch 911: loss did not improve from 229466.31250
# 7/7 - 1s - loss: 254882.8750 - val_loss: 10499.2314 - 565ms/epoch - 81ms/step
# Epoch 912/2000
#
# Epoch 912: loss improved from 229466.31250 to 227220.75000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 227220.7500 - val_loss: 6354.6064 - 899ms/epoch - 128ms/step
# Epoch 913/2000
#
# Epoch 913: loss improved from 227220.75000 to 225019.81250, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 225019.8125 - val_loss: 9210.9150 - 1s/epoch - 214ms/step
# Epoch 914/2000
#
# Epoch 914: loss did not improve from 225019.81250
# 7/7 - 1s - loss: 259790.4375 - val_loss: 5828.0562 - 1s/epoch - 155ms/step
# Epoch 915/2000
#
# Epoch 915: loss did not improve from 225019.81250
# 7/7 - 1s - loss: 252564.5469 - val_loss: 5600.2549 - 968ms/epoch - 138ms/step
# Epoch 916/2000
#
# Epoch 916: loss did not improve from 225019.81250
# 7/7 - 1s - loss: 247953.2344 - val_loss: 7908.6953 - 1s/epoch - 170ms/step
# Epoch 917/2000
#
# Epoch 917: loss did not improve from 225019.81250
# 7/7 - 1s - loss: 237963.1094 - val_loss: 7237.9028 - 922ms/epoch - 132ms/step
# Epoch 918/2000
#
# Epoch 918: loss did not improve from 225019.81250
# 7/7 - 1s - loss: 227630.4688 - val_loss: 5849.8765 - 550ms/epoch - 79ms/step
# Epoch 919/2000
#
# Epoch 919: loss did not improve from 225019.81250
# 7/7 - 1s - loss: 238256.1094 - val_loss: 7615.8916 - 526ms/epoch - 75ms/step
# Epoch 920/2000
#
# Epoch 920: loss did not improve from 225019.81250
# 7/7 - 1s - loss: 277277.0312 - val_loss: 7094.1528 - 517ms/epoch - 74ms/step
# Epoch 921/2000
#
# Epoch 921: loss did not improve from 225019.81250
# 7/7 - 1s - loss: 266840.5000 - val_loss: 6139.0835 - 544ms/epoch - 78ms/step
# Epoch 922/2000
#
# Epoch 922: loss did not improve from 225019.81250
# 7/7 - 1s - loss: 243413.6719 - val_loss: 8709.8203 - 513ms/epoch - 73ms/step
# Epoch 923/2000
#
# Epoch 923: loss did not improve from 225019.81250
# 7/7 - 1s - loss: 235359.4844 - val_loss: 6169.3730 - 535ms/epoch - 76ms/step
# Epoch 924/2000
#
# Epoch 924: loss did not improve from 225019.81250
# 7/7 - 1s - loss: 279859.8438 - val_loss: 6431.1035 - 536ms/epoch - 77ms/step
# Epoch 925/2000
#
# Epoch 925: loss did not improve from 225019.81250
# 7/7 - 1s - loss: 267362.6250 - val_loss: 8732.8535 - 535ms/epoch - 76ms/step
# Epoch 926/2000
#
# Epoch 926: loss did not improve from 225019.81250
# 7/7 - 1s - loss: 271932.3125 - val_loss: 5670.8125 - 543ms/epoch - 78ms/step
# Epoch 927/2000
#
# Epoch 927: loss did not improve from 225019.81250
# 7/7 - 1s - loss: 233248.4531 - val_loss: 6753.1953 - 563ms/epoch - 80ms/step
# Epoch 928/2000
#
# Epoch 928: loss did not improve from 225019.81250
# 7/7 - 1s - loss: 230062.3438 - val_loss: 6440.4644 - 566ms/epoch - 81ms/step
# Epoch 929/2000
#
# Epoch 929: loss did not improve from 225019.81250
# 7/7 - 0s - loss: 273609.8750 - val_loss: 5179.6431 - 497ms/epoch - 71ms/step
# Epoch 930/2000
#
# Epoch 930: loss did not improve from 225019.81250
# 7/7 - 1s - loss: 259255.1875 - val_loss: 6399.1880 - 571ms/epoch - 82ms/step
# Epoch 931/2000
#
# Epoch 931: loss did not improve from 225019.81250
# 7/7 - 1s - loss: 257224.7969 - val_loss: 8644.1777 - 533ms/epoch - 76ms/step
# Epoch 932/2000
#
# Epoch 932: loss did not improve from 225019.81250
# 7/7 - 1s - loss: 243470.4844 - val_loss: 17382.3418 - 529ms/epoch - 76ms/step
# Epoch 933/2000
#
# Epoch 933: loss did not improve from 225019.81250
# 7/7 - 1s - loss: 270388.0312 - val_loss: 6641.1514 - 532ms/epoch - 76ms/step
# Epoch 934/2000
#
# Epoch 934: loss did not improve from 225019.81250
# 7/7 - 1s - loss: 278288.0938 - val_loss: 5360.5293 - 519ms/epoch - 74ms/step
# Epoch 935/2000
#
# Epoch 935: loss did not improve from 225019.81250
# 7/7 - 1s - loss: 248350.8125 - val_loss: 18080.7891 - 531ms/epoch - 76ms/step
# Epoch 936/2000
#
# Epoch 936: loss did not improve from 225019.81250
# 7/7 - 1s - loss: 245430.8125 - val_loss: 5517.2920 - 858ms/epoch - 123ms/step
# Epoch 937/2000
#
# Epoch 937: loss did not improve from 225019.81250
# 7/7 - 1s - loss: 231968.1094 - val_loss: 24109.2891 - 1s/epoch - 164ms/step
# Epoch 938/2000
#
# Epoch 938: loss did not improve from 225019.81250
# 7/7 - 1s - loss: 252887.1094 - val_loss: 10984.3330 - 1s/epoch - 170ms/step
# Epoch 939/2000
#
# Epoch 939: loss did not improve from 225019.81250
# 7/7 - 1s - loss: 252574.9688 - val_loss: 9714.5625 - 1s/epoch - 165ms/step
# Epoch 940/2000
#
# Epoch 940: loss did not improve from 225019.81250
# 7/7 - 1s - loss: 276923.3125 - val_loss: 19018.5605 - 1s/epoch - 161ms/step
# Epoch 941/2000
#
# Epoch 941: loss did not improve from 225019.81250
# 7/7 - 1s - loss: 269384.5312 - val_loss: 6011.1040 - 916ms/epoch - 131ms/step
# Epoch 942/2000
#
# Epoch 942: loss did not improve from 225019.81250
# 7/7 - 1s - loss: 272447.6875 - val_loss: 17216.1270 - 521ms/epoch - 74ms/step
# Epoch 943/2000
#
# Epoch 943: loss did not improve from 225019.81250
# 7/7 - 1s - loss: 259524.8438 - val_loss: 8282.3594 - 543ms/epoch - 78ms/step
# Epoch 944/2000
#
# Epoch 944: loss improved from 225019.81250 to 222366.29688, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 222366.2969 - val_loss: 6288.7715 - 772ms/epoch - 110ms/step
# Epoch 945/2000
#
# Epoch 945: loss did not improve from 222366.29688
# 7/7 - 1s - loss: 232443.9844 - val_loss: 22607.6016 - 517ms/epoch - 74ms/step
# Epoch 946/2000
#
# Epoch 946: loss did not improve from 222366.29688
# 7/7 - 1s - loss: 285684.2188 - val_loss: 6257.2183 - 557ms/epoch - 80ms/step
# Epoch 947/2000
#
# Epoch 947: loss did not improve from 222366.29688
# 7/7 - 1s - loss: 247219.9844 - val_loss: 8448.6709 - 528ms/epoch - 75ms/step
# Epoch 948/2000
#
# Epoch 948: loss did not improve from 222366.29688
# 7/7 - 1s - loss: 247151.2344 - val_loss: 9797.8320 - 558ms/epoch - 80ms/step
# Epoch 949/2000
#
# Epoch 949: loss did not improve from 222366.29688
# 7/7 - 1s - loss: 272196.8125 - val_loss: 6209.1411 - 542ms/epoch - 77ms/step
# Epoch 950/2000
#
# Epoch 950: loss did not improve from 222366.29688
# 7/7 - 1s - loss: 259949.9844 - val_loss: 8542.5781 - 572ms/epoch - 82ms/step
# Epoch 951/2000
#
# Epoch 951: loss did not improve from 222366.29688
# 7/7 - 1s - loss: 269541.8750 - val_loss: 7830.9565 - 529ms/epoch - 76ms/step
# Epoch 952/2000
#
# Epoch 952: loss did not improve from 222366.29688
# 7/7 - 1s - loss: 249470.5156 - val_loss: 8886.8193 - 530ms/epoch - 76ms/step
# Epoch 953/2000
#
# Epoch 953: loss improved from 222366.29688 to 220371.01562, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 220371.0156 - val_loss: 5192.4565 - 839ms/epoch - 120ms/step
# Epoch 954/2000
#
# Epoch 954: loss did not improve from 220371.01562
# 7/7 - 1s - loss: 254944.3750 - val_loss: 13023.9180 - 533ms/epoch - 76ms/step
# Epoch 955/2000
#
# Epoch 955: loss did not improve from 220371.01562
# 7/7 - 1s - loss: 250294.4844 - val_loss: 5455.4453 - 521ms/epoch - 74ms/step
# Epoch 956/2000
#
# Epoch 956: loss improved from 220371.01562 to 218989.85938, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 218989.8594 - val_loss: 14008.5742 - 782ms/epoch - 112ms/step
# Epoch 957/2000
#
# Epoch 957: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 285199.3125 - val_loss: 35769.5312 - 547ms/epoch - 78ms/step
# Epoch 958/2000
#
# Epoch 958: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 243547.1094 - val_loss: 20722.4277 - 665ms/epoch - 95ms/step
# Epoch 959/2000
#
# Epoch 959: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 235458.0156 - val_loss: 9847.5029 - 1s/epoch - 146ms/step
# Epoch 960/2000
#
# Epoch 960: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 242437.4688 - val_loss: 5108.8003 - 985ms/epoch - 141ms/step
# Epoch 961/2000
#
# Epoch 961: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 279815.9688 - val_loss: 5667.1670 - 1s/epoch - 152ms/step
# Epoch 962/2000
#
# Epoch 962: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 245575.9688 - val_loss: 10342.6035 - 944ms/epoch - 135ms/step
# Epoch 963/2000
#
# Epoch 963: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 247120.5156 - val_loss: 6763.9399 - 1s/epoch - 174ms/step
# Epoch 964/2000
#
# Epoch 964: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 272468.0000 - val_loss: 7343.8960 - 844ms/epoch - 121ms/step
# Epoch 965/2000
#
# Epoch 965: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 250272.9688 - val_loss: 9914.7041 - 528ms/epoch - 75ms/step
# Epoch 966/2000
#
# Epoch 966: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 232270.8125 - val_loss: 9519.9209 - 531ms/epoch - 76ms/step
# Epoch 967/2000
#
# Epoch 967: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 241135.0000 - val_loss: 15278.3418 - 544ms/epoch - 78ms/step
# Epoch 968/2000
#
# Epoch 968: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 241305.3594 - val_loss: 12363.7119 - 500ms/epoch - 71ms/step
# Epoch 969/2000
#
# Epoch 969: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 251947.6406 - val_loss: 13415.3164 - 543ms/epoch - 78ms/step
# Epoch 970/2000
#
# Epoch 970: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 261971.2031 - val_loss: 13533.2500 - 564ms/epoch - 81ms/step
# Epoch 971/2000
#
# Epoch 971: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 254591.7031 - val_loss: 12015.0576 - 522ms/epoch - 75ms/step
# Epoch 972/2000
#
# Epoch 972: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 261215.4688 - val_loss: 7432.8628 - 537ms/epoch - 77ms/step
# Epoch 973/2000
#
# Epoch 973: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 244572.1094 - val_loss: 16928.9863 - 515ms/epoch - 74ms/step
# Epoch 974/2000
#
# Epoch 974: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 292227.8125 - val_loss: 9072.5225 - 528ms/epoch - 75ms/step
# Epoch 975/2000
#
# Epoch 975: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 287696.6875 - val_loss: 10215.4863 - 523ms/epoch - 75ms/step
# Epoch 976/2000
#
# Epoch 976: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 220315.2500 - val_loss: 21112.9355 - 544ms/epoch - 78ms/step
# Epoch 977/2000
#
# Epoch 977: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 243545.0781 - val_loss: 16774.7656 - 608ms/epoch - 87ms/step
# Epoch 978/2000
#
# Epoch 978: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 278661.3750 - val_loss: 5692.0771 - 538ms/epoch - 77ms/step
# Epoch 979/2000
#
# Epoch 979: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 277585.3750 - val_loss: 8185.5371 - 546ms/epoch - 78ms/step
# Epoch 980/2000
#
# Epoch 980: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 245971.6875 - val_loss: 9999.5078 - 520ms/epoch - 74ms/step
# Epoch 981/2000
#
# Epoch 981: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 228128.2188 - val_loss: 18761.2246 - 525ms/epoch - 75ms/step
# Epoch 982/2000
#
# Epoch 982: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 254908.6250 - val_loss: 21593.3770 - 590ms/epoch - 84ms/step
# Epoch 983/2000
#
# Epoch 983: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 278736.3125 - val_loss: 25322.2031 - 1s/epoch - 166ms/step
# Epoch 984/2000
#
# Epoch 984: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 260223.7344 - val_loss: 9018.8887 - 1s/epoch - 164ms/step
# Epoch 985/2000
#
# Epoch 985: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 245575.3750 - val_loss: 7934.1353 - 1s/epoch - 173ms/step
# Epoch 986/2000
#
# Epoch 986: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 222078.3438 - val_loss: 7115.3164 - 950ms/epoch - 136ms/step
# Epoch 987/2000
#
# Epoch 987: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 247426.4062 - val_loss: 13516.8164 - 1s/epoch - 173ms/step
# Epoch 988/2000
#
# Epoch 988: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 256371.4062 - val_loss: 7778.7729 - 839ms/epoch - 120ms/step
# Epoch 989/2000
#
# Epoch 989: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 243588.0312 - val_loss: 16465.1836 - 533ms/epoch - 76ms/step
# Epoch 990/2000
#
# Epoch 990: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 256900.7969 - val_loss: 7520.1924 - 535ms/epoch - 76ms/step
# Epoch 991/2000
#
# Epoch 991: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 241921.3594 - val_loss: 4991.0576 - 525ms/epoch - 75ms/step
# Epoch 992/2000
#
# Epoch 992: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 257575.2656 - val_loss: 4955.0747 - 539ms/epoch - 77ms/step
# Epoch 993/2000
#
# Epoch 993: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 248896.2656 - val_loss: 4900.0923 - 553ms/epoch - 79ms/step
# Epoch 994/2000
#
# Epoch 994: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 265904.6250 - val_loss: 6262.8701 - 578ms/epoch - 83ms/step
# Epoch 995/2000
#
# Epoch 995: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 292514.0625 - val_loss: 8163.9126 - 546ms/epoch - 78ms/step
# Epoch 996/2000
#
# Epoch 996: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 249705.7656 - val_loss: 6549.5103 - 626ms/epoch - 89ms/step
# Epoch 997/2000
#
# Epoch 997: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 265458.2500 - val_loss: 5476.8584 - 528ms/epoch - 75ms/step
# Epoch 998/2000
#
# Epoch 998: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 239415.3281 - val_loss: 7541.5820 - 515ms/epoch - 74ms/step
# Epoch 999/2000
#
# Epoch 999: loss did not improve from 218989.85938
# 7/7 - 0s - loss: 247054.0000 - val_loss: 9188.7471 - 481ms/epoch - 69ms/step
# Epoch 1000/2000
#
# Epoch 1000: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 252891.4844 - val_loss: 5311.2773 - 510ms/epoch - 73ms/step
# Epoch 1001/2000
#
# Epoch 1001: loss did not improve from 218989.85938
# 7/7 - 0s - loss: 253459.0469 - val_loss: 7409.3877 - 495ms/epoch - 71ms/step
# Epoch 1002/2000
#
# Epoch 1002: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 246635.8438 - val_loss: 5312.6104 - 547ms/epoch - 78ms/step
# Epoch 1003/2000
#
# Epoch 1003: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 230822.7656 - val_loss: 13119.8965 - 500ms/epoch - 71ms/step
# Epoch 1004/2000
#
# Epoch 1004: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 243333.0938 - val_loss: 12346.5654 - 520ms/epoch - 74ms/step
# Epoch 1005/2000
#
# Epoch 1005: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 253036.1094 - val_loss: 11401.8750 - 504ms/epoch - 72ms/step
# Epoch 1006/2000
#
# Epoch 1006: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 272861.2812 - val_loss: 10114.7344 - 567ms/epoch - 81ms/step
# Epoch 1007/2000
#
# Epoch 1007: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 238221.6406 - val_loss: 13256.4736 - 950ms/epoch - 136ms/step
# Epoch 1008/2000
#
# Epoch 1008: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 264548.7188 - val_loss: 9746.6514 - 1s/epoch - 153ms/step
# Epoch 1009/2000
#
# Epoch 1009: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 264620.1562 - val_loss: 11682.5381 - 1s/epoch - 158ms/step
# Epoch 1010/2000
#
# Epoch 1010: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 277126.0625 - val_loss: 4883.4463 - 1s/epoch - 144ms/step
# Epoch 1011/2000
#
# Epoch 1011: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 262854.9688 - val_loss: 5520.1724 - 1s/epoch - 166ms/step
# Epoch 1012/2000
#
# Epoch 1012: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 251167.4531 - val_loss: 8920.3574 - 1s/epoch - 158ms/step
# Epoch 1013/2000
#
# Epoch 1013: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 248096.4844 - val_loss: 7683.5752 - 1s/epoch - 160ms/step
# Epoch 1014/2000
#
# Epoch 1014: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 255108.2500 - val_loss: 8074.5166 - 1s/epoch - 147ms/step
# Epoch 1015/2000
#
# Epoch 1015: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 265520.3750 - val_loss: 15524.4863 - 1s/epoch - 161ms/step
# Epoch 1016/2000
#
# Epoch 1016: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 254085.8125 - val_loss: 22858.4980 - 1s/epoch - 165ms/step
# Epoch 1017/2000
#
# Epoch 1017: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 239403.3125 - val_loss: 6936.1440 - 829ms/epoch - 118ms/step
# Epoch 1018/2000
#
# Epoch 1018: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 256692.2656 - val_loss: 4917.3613 - 728ms/epoch - 104ms/step
# Epoch 1019/2000
#
# Epoch 1019: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 273417.5938 - val_loss: 12653.2471 - 530ms/epoch - 76ms/step
# Epoch 1020/2000
#
# Epoch 1020: loss did not improve from 218989.85938
# 7/7 - 1s - loss: 287622.9375 - val_loss: 4977.1841 - 551ms/epoch - 79ms/step
# Epoch 1021/2000
#
# Epoch 1021: loss improved from 218989.85938 to 214108.43750, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 214108.4375 - val_loss: 11843.6953 - 787ms/epoch - 112ms/step
# Epoch 1022/2000
#
# Epoch 1022: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 228041.2656 - val_loss: 10987.9072 - 502ms/epoch - 72ms/step
# Epoch 1023/2000
#
# Epoch 1023: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 287503.2812 - val_loss: 15340.0332 - 573ms/epoch - 82ms/step
# Epoch 1024/2000
#
# Epoch 1024: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 260929.8594 - val_loss: 16985.5352 - 519ms/epoch - 74ms/step
# Epoch 1025/2000
#
# Epoch 1025: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 219850.7500 - val_loss: 5928.8975 - 628ms/epoch - 90ms/step
# Epoch 1026/2000
#
# Epoch 1026: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 258923.5938 - val_loss: 12538.8555 - 1s/epoch - 155ms/step
# Epoch 1027/2000
#
# Epoch 1027: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 239820.5469 - val_loss: 5174.0923 - 990ms/epoch - 141ms/step
# Epoch 1028/2000
#
# Epoch 1028: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 280796.8125 - val_loss: 6648.8892 - 956ms/epoch - 137ms/step
# Epoch 1029/2000
#
# Epoch 1029: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 246582.5312 - val_loss: 6135.3267 - 956ms/epoch - 137ms/step
# Epoch 1030/2000
#
# Epoch 1030: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 275040.9688 - val_loss: 7194.8560 - 1s/epoch - 163ms/step
# Epoch 1031/2000
#
# Epoch 1031: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 269709.0938 - val_loss: 9911.3887 - 804ms/epoch - 115ms/step
# Epoch 1032/2000
#
# Epoch 1032: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 236244.9062 - val_loss: 5294.5659 - 582ms/epoch - 83ms/step
# Epoch 1033/2000
#
# Epoch 1033: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 239547.6562 - val_loss: 7101.1963 - 508ms/epoch - 73ms/step
# Epoch 1034/2000
#
# Epoch 1034: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 245183.4219 - val_loss: 6166.9609 - 528ms/epoch - 75ms/step
# Epoch 1035/2000
#
# Epoch 1035: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 235689.4531 - val_loss: 12104.1963 - 552ms/epoch - 79ms/step
# Epoch 1036/2000
#
# Epoch 1036: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 242572.9531 - val_loss: 20912.1152 - 538ms/epoch - 77ms/step
# Epoch 1037/2000
#
# Epoch 1037: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 286721.2188 - val_loss: 14343.2490 - 520ms/epoch - 74ms/step
# Epoch 1038/2000
#
# Epoch 1038: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 261433.0000 - val_loss: 15702.5869 - 507ms/epoch - 72ms/step
# Epoch 1039/2000
#
# Epoch 1039: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 256525.1406 - val_loss: 8943.1113 - 562ms/epoch - 80ms/step
# Epoch 1040/2000
#
# Epoch 1040: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 266319.1875 - val_loss: 15197.3408 - 546ms/epoch - 78ms/step
# Epoch 1041/2000
#
# Epoch 1041: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 297349.5000 - val_loss: 10498.7051 - 535ms/epoch - 76ms/step
# Epoch 1042/2000
#
# Epoch 1042: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 260293.5156 - val_loss: 15445.4287 - 553ms/epoch - 79ms/step
# Epoch 1043/2000
#
# Epoch 1043: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 252005.7031 - val_loss: 14845.6445 - 537ms/epoch - 77ms/step
# Epoch 1044/2000
#
# Epoch 1044: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 259369.4219 - val_loss: 20320.1113 - 547ms/epoch - 78ms/step
# Epoch 1045/2000
#
# Epoch 1045: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 255833.7344 - val_loss: 9140.2637 - 517ms/epoch - 74ms/step
# Epoch 1046/2000
#
# Epoch 1046: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 254635.9688 - val_loss: 11305.2305 - 509ms/epoch - 73ms/step
# Epoch 1047/2000
#
# Epoch 1047: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 288017.6250 - val_loss: 4999.5117 - 523ms/epoch - 75ms/step
# Epoch 1048/2000
#
# Epoch 1048: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 238341.0156 - val_loss: 4955.2222 - 502ms/epoch - 72ms/step
# Epoch 1049/2000
#
# Epoch 1049: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 235563.3750 - val_loss: 5708.7222 - 554ms/epoch - 79ms/step
# Epoch 1050/2000
#
# Epoch 1050: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 215867.7344 - val_loss: 5165.7729 - 1s/epoch - 151ms/step
# Epoch 1051/2000
#
# Epoch 1051: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 247624.0312 - val_loss: 5701.2212 - 1s/epoch - 157ms/step
# Epoch 1052/2000
#
# Epoch 1052: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 224961.7812 - val_loss: 6440.8711 - 1s/epoch - 156ms/step
# Epoch 1053/2000
#
# Epoch 1053: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 291539.1875 - val_loss: 14814.6426 - 898ms/epoch - 128ms/step
# Epoch 1054/2000
#
# Epoch 1054: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 269750.8125 - val_loss: 5493.9561 - 1s/epoch - 157ms/step
# Epoch 1055/2000
#
# Epoch 1055: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 259234.9844 - val_loss: 8935.8389 - 879ms/epoch - 126ms/step
# Epoch 1056/2000
#
# Epoch 1056: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 247349.6562 - val_loss: 5029.7461 - 516ms/epoch - 74ms/step
# Epoch 1057/2000
#
# Epoch 1057: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 234971.8906 - val_loss: 20020.7559 - 576ms/epoch - 82ms/step
# Epoch 1058/2000
#
# Epoch 1058: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 246441.0469 - val_loss: 7423.3979 - 591ms/epoch - 84ms/step
# Epoch 1059/2000
#
# Epoch 1059: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 226814.1562 - val_loss: 10859.7744 - 536ms/epoch - 77ms/step
# Epoch 1060/2000
#
# Epoch 1060: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 244027.7812 - val_loss: 6241.9976 - 522ms/epoch - 75ms/step
# Epoch 1061/2000
#
# Epoch 1061: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 252665.4688 - val_loss: 5722.0767 - 515ms/epoch - 74ms/step
# Epoch 1062/2000
#
# Epoch 1062: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 265856.8438 - val_loss: 5656.2578 - 557ms/epoch - 80ms/step
# Epoch 1063/2000
#
# Epoch 1063: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 238228.4375 - val_loss: 6440.8369 - 553ms/epoch - 79ms/step
# Epoch 1064/2000
#
# Epoch 1064: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 273444.6250 - val_loss: 6122.6416 - 546ms/epoch - 78ms/step
# Epoch 1065/2000
#
# Epoch 1065: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 228804.5781 - val_loss: 7972.7373 - 522ms/epoch - 75ms/step
# Epoch 1066/2000
#
# Epoch 1066: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 231524.0000 - val_loss: 5604.5464 - 534ms/epoch - 76ms/step
# Epoch 1067/2000
#
# Epoch 1067: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 223058.2031 - val_loss: 7045.1963 - 512ms/epoch - 73ms/step
# Epoch 1068/2000
#
# Epoch 1068: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 244606.6719 - val_loss: 7239.3379 - 531ms/epoch - 76ms/step
# Epoch 1069/2000
#
# Epoch 1069: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 268208.0938 - val_loss: 5661.4233 - 505ms/epoch - 72ms/step
# Epoch 1070/2000
#
# Epoch 1070: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 254240.7969 - val_loss: 5686.7705 - 555ms/epoch - 79ms/step
# Epoch 1071/2000
#
# Epoch 1071: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 260911.0469 - val_loss: 5401.1143 - 578ms/epoch - 83ms/step
# Epoch 1072/2000
#
# Epoch 1072: loss did not improve from 214108.43750
# 7/7 - 1s - loss: 262982.4688 - val_loss: 9073.3799 - 551ms/epoch - 79ms/step
# Epoch 1073/2000
#
# ...
# Epoch 1892/2000
#
# Epoch 1892: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 212102.1250 - val_loss: 5169.5361 - 696ms/epoch - 99ms/step
# Epoch 1893/2000
#
# Epoch 1893: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 204779.2656 - val_loss: 7000.4126 - 1s/epoch - 160ms/step
# Epoch 1894/2000
#
# Epoch 1894: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 233084.0312 - val_loss: 12442.7461 - 1s/epoch - 159ms/step
# Epoch 1895/2000
#
# Epoch 1895: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 193282.5625 - val_loss: 5665.0547 - 1s/epoch - 154ms/step
# Epoch 1896/2000
#
# Epoch 1896: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 215341.3750 - val_loss: 9764.2422 - 970ms/epoch - 139ms/step
# Epoch 1897/2000
#
# Epoch 1897: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 221086.3125 - val_loss: 5221.7739 - 1s/epoch - 144ms/step
# Epoch 1898/2000
#
# Epoch 1898: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 230717.9688 - val_loss: 5519.1914 - 737ms/epoch - 105ms/step
# Epoch 1899/2000
#
# Epoch 1899: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 188461.5156 - val_loss: 7505.3931 - 533ms/epoch - 76ms/step
# Epoch 1900/2000
#
# Epoch 1900: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 213258.6875 - val_loss: 7676.5254 - 535ms/epoch - 76ms/step
# Epoch 1901/2000
#
# Epoch 1901: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 235971.4375 - val_loss: 11984.5596 - 526ms/epoch - 75ms/step
# Epoch 1902/2000
#
# Epoch 1902: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 225559.8750 - val_loss: 8798.1074 - 552ms/epoch - 79ms/step
# Epoch 1903/2000
#
# Epoch 1903: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 189588.4688 - val_loss: 8709.6445 - 530ms/epoch - 76ms/step
# Epoch 1904/2000
#
# Epoch 1904: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 257972.3438 - val_loss: 9856.1299 - 610ms/epoch - 87ms/step
# Epoch 1905/2000
#
# Epoch 1905: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 224327.2031 - val_loss: 5043.5977 - 518ms/epoch - 74ms/step
# Epoch 1906/2000
#
# Epoch 1906: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 217822.4375 - val_loss: 7415.5820 - 547ms/epoch - 78ms/step
# Epoch 1907/2000
#
# Epoch 1907: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 239827.8750 - val_loss: 5303.6274 - 535ms/epoch - 76ms/step
# Epoch 1908/2000
#
# Epoch 1908: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 195882.9844 - val_loss: 5620.1548 - 528ms/epoch - 75ms/step
# Epoch 1909/2000
#
# Epoch 1909: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 220399.8125 - val_loss: 29624.8672 - 537ms/epoch - 77ms/step
# Epoch 1910/2000
#
# Epoch 1910: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 214415.6562 - val_loss: 5268.2725 - 557ms/epoch - 80ms/step
# Epoch 1911/2000
#
# Epoch 1911: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 235714.9531 - val_loss: 7342.6514 - 527ms/epoch - 75ms/step
# Epoch 1912/2000
#
# Epoch 1912: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 223343.6562 - val_loss: 13564.8867 - 519ms/epoch - 74ms/step
# Epoch 1913/2000
#
# Epoch 1913: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 216253.1875 - val_loss: 4912.2607 - 519ms/epoch - 74ms/step
# Epoch 1914/2000
#
# Epoch 1914: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 228845.5625 - val_loss: 6178.6118 - 505ms/epoch - 72ms/step
# Epoch 1915/2000
#
# Epoch 1915: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 234748.8125 - val_loss: 6254.7368 - 515ms/epoch - 74ms/step
# Epoch 1916/2000
#
# Epoch 1916: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 209434.2188 - val_loss: 4884.5903 - 875ms/epoch - 125ms/step
# Epoch 1917/2000
#
# Epoch 1917: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 235797.0312 - val_loss: 10249.5244 - 1s/epoch - 160ms/step
# Epoch 1918/2000
#
# Epoch 1918: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 210997.5312 - val_loss: 5825.2749 - 1s/epoch - 145ms/step
# Epoch 1919/2000
#
# Epoch 1919: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 254264.1406 - val_loss: 7523.7002 - 1s/epoch - 161ms/step
# Epoch 1920/2000
#
# Epoch 1920: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 206279.3281 - val_loss: 13578.0244 - 988ms/epoch - 141ms/step
# Epoch 1921/2000
#
# Epoch 1921: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 211729.6719 - val_loss: 5043.9248 - 981ms/epoch - 140ms/step
# Epoch 1922/2000
#
# Epoch 1922: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 210064.1406 - val_loss: 12437.8408 - 631ms/epoch - 90ms/step
# Epoch 1923/2000
#
# Epoch 1923: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 209918.1562 - val_loss: 9414.1973 - 530ms/epoch - 76ms/step
# Epoch 1924/2000
#
# Epoch 1924: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 193278.6875 - val_loss: 5270.9902 - 544ms/epoch - 78ms/step
# Epoch 1925/2000
#
# Epoch 1925: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 220580.2656 - val_loss: 5207.4653 - 568ms/epoch - 81ms/step
# Epoch 1926/2000
#
# Epoch 1926: loss did not improve from 162013.26562
# 7/7 - 0s - loss: 215758.4219 - val_loss: 5767.8022 - 499ms/epoch - 71ms/step
# Epoch 1927/2000
#
# Epoch 1927: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 227630.8125 - val_loss: 5375.3892 - 515ms/epoch - 74ms/step
# Epoch 1928/2000
#
# Epoch 1928: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 250856.5781 - val_loss: 6386.0229 - 547ms/epoch - 78ms/step
# Epoch 1929/2000
#
# Epoch 1929: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 215689.1562 - val_loss: 5072.1265 - 539ms/epoch - 77ms/step
# Epoch 1930/2000
#
# Epoch 1930: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 224611.4688 - val_loss: 9434.7744 - 501ms/epoch - 72ms/step
# Epoch 1931/2000
#
# Epoch 1931: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 198542.6250 - val_loss: 7952.6318 - 548ms/epoch - 78ms/step
# Epoch 1932/2000
#
# Epoch 1932: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 208610.8594 - val_loss: 5719.1899 - 529ms/epoch - 76ms/step
# Epoch 1933/2000
#
# Epoch 1933: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 222862.4375 - val_loss: 10188.9932 - 503ms/epoch - 72ms/step
# Epoch 1934/2000
#
# Epoch 1934: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 215791.9844 - val_loss: 10646.5488 - 556ms/epoch - 79ms/step
# Epoch 1935/2000
#
# Epoch 1935: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 199383.1406 - val_loss: 5151.3501 - 507ms/epoch - 72ms/step
# Epoch 1936/2000
#
# Epoch 1936: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 215738.4375 - val_loss: 5388.1367 - 507ms/epoch - 72ms/step
# Epoch 1937/2000
#
# Epoch 1937: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 214094.4844 - val_loss: 5984.4521 - 520ms/epoch - 74ms/step
# Epoch 1938/2000
#
# Epoch 1938: loss did not improve from 162013.26562
# 7/7 - 0s - loss: 213685.7969 - val_loss: 5269.9829 - 498ms/epoch - 71ms/step
# Epoch 1939/2000
#
# Epoch 1939: loss did not improve from 162013.26562
# 7/7 - 0s - loss: 248158.3438 - val_loss: 5120.8965 - 500ms/epoch - 71ms/step
# Epoch 1940/2000
#
# Epoch 1940: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 221022.0312 - val_loss: 5226.8872 - 522ms/epoch - 75ms/step
# Epoch 1941/2000
#
# Epoch 1941: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 207822.0000 - val_loss: 5294.7393 - 937ms/epoch - 134ms/step
# Epoch 1942/2000
#
# Epoch 1942: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 205536.0781 - val_loss: 4954.3423 - 1s/epoch - 153ms/step
# Epoch 1943/2000
#
# Epoch 1943: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 226298.6719 - val_loss: 6020.2505 - 1s/epoch - 162ms/step
# Epoch 1944/2000
#
# Epoch 1944: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 206256.6406 - val_loss: 5028.9727 - 1s/epoch - 143ms/step
# Epoch 1945/2000
#
# Epoch 1945: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 215891.7500 - val_loss: 6611.5566 - 1s/epoch - 153ms/step
# Epoch 1946/2000
#
# Epoch 1946: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 219952.7344 - val_loss: 9139.8340 - 960ms/epoch - 137ms/step
# Epoch 1947/2000
#
# Epoch 1947: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 218791.5312 - val_loss: 5681.5059 - 556ms/epoch - 79ms/step
# Epoch 1948/2000
#
# Epoch 1948: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 232681.3438 - val_loss: 5029.2520 - 528ms/epoch - 75ms/step
# Epoch 1949/2000
#
# Epoch 1949: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 206936.0469 - val_loss: 6964.0034 - 525ms/epoch - 75ms/step
# Epoch 1950/2000
#
# Epoch 1950: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 227330.4688 - val_loss: 7627.2939 - 539ms/epoch - 77ms/step
# Epoch 1951/2000
#
# Epoch 1951: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 192660.8750 - val_loss: 8611.6416 - 574ms/epoch - 82ms/step
# Epoch 1952/2000
#
# Epoch 1952: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 207350.4375 - val_loss: 5341.6948 - 520ms/epoch - 74ms/step
# Epoch 1953/2000
#
# Epoch 1953: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 240311.4531 - val_loss: 9096.3574 - 531ms/epoch - 76ms/step
# Epoch 1954/2000
#
# Epoch 1954: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 247750.3125 - val_loss: 11908.4707 - 504ms/epoch - 72ms/step
# Epoch 1955/2000
#
# Epoch 1955: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 230666.6875 - val_loss: 5040.8589 - 516ms/epoch - 74ms/step
# Epoch 1956/2000
#
# Epoch 1956: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 249138.9844 - val_loss: 5909.0210 - 554ms/epoch - 79ms/step
# Epoch 1957/2000
#
# Epoch 1957: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 225346.8906 - val_loss: 6032.4883 - 508ms/epoch - 73ms/step
# Epoch 1958/2000
#
# Epoch 1958: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 231818.4375 - val_loss: 5280.6436 - 552ms/epoch - 79ms/step
# Epoch 1959/2000
#
# Epoch 1959: loss did not improve from 162013.26562
# 7/7 - 0s - loss: 211142.7812 - val_loss: 7353.3228 - 497ms/epoch - 71ms/step
# Epoch 1960/2000
#
# Epoch 1960: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 226206.3594 - val_loss: 9534.1787 - 593ms/epoch - 85ms/step
# Epoch 1961/2000
#
# Epoch 1961: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 224549.9531 - val_loss: 5170.4341 - 563ms/epoch - 80ms/step
# Epoch 1962/2000
#
# Epoch 1962: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 249082.0312 - val_loss: 5707.4165 - 550ms/epoch - 79ms/step
# Epoch 1963/2000
#
# Epoch 1963: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 218205.1406 - val_loss: 8590.2031 - 517ms/epoch - 74ms/step
# Epoch 1964/2000
#
# Epoch 1964: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 244760.4375 - val_loss: 6032.8433 - 541ms/epoch - 77ms/step
# Epoch 1965/2000
#
# Epoch 1965: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 219115.6875 - val_loss: 5416.6040 - 948ms/epoch - 135ms/step
# Epoch 1966/2000
#
# Epoch 1966: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 229185.7344 - val_loss: 6487.3506 - 1s/epoch - 159ms/step
# Epoch 1967/2000
#
# Epoch 1967: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 229842.2344 - val_loss: 17003.9141 - 1s/epoch - 165ms/step
# Epoch 1968/2000
#
# Epoch 1968: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 237769.5312 - val_loss: 8093.6528 - 970ms/epoch - 139ms/step
# Epoch 1969/2000
#
# Epoch 1969: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 206092.9531 - val_loss: 7199.3354 - 1s/epoch - 158ms/step
# Epoch 1970/2000
#
# Epoch 1970: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 199361.7812 - val_loss: 5183.2744 - 827ms/epoch - 118ms/step
# Epoch 1971/2000
#
# Epoch 1971: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 229617.4844 - val_loss: 5388.6270 - 544ms/epoch - 78ms/step
# Epoch 1972/2000
#
# Epoch 1972: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 208114.1094 - val_loss: 6090.4492 - 513ms/epoch - 73ms/step
# Epoch 1973/2000
#
# Epoch 1973: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 225121.1250 - val_loss: 11976.8164 - 501ms/epoch - 72ms/step
# Epoch 1974/2000
#
# Epoch 1974: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 211839.6250 - val_loss: 11640.1973 - 552ms/epoch - 79ms/step
# Epoch 1975/2000
#
# Epoch 1975: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 200099.7812 - val_loss: 9358.8955 - 816ms/epoch - 117ms/step
# Epoch 1976/2000
#
# Epoch 1976: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 228455.0000 - val_loss: 12026.6504 - 1s/epoch - 161ms/step
# Epoch 1977/2000
#
# Epoch 1977: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 226200.0156 - val_loss: 5180.8018 - 1s/epoch - 166ms/step
# Epoch 1978/2000
#
# Epoch 1978: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 201450.5156 - val_loss: 5976.7520 - 1s/epoch - 153ms/step
# Epoch 1979/2000
#
# Epoch 1979: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 212483.9219 - val_loss: 7331.4331 - 1s/epoch - 158ms/step
# Epoch 1980/2000
#
# Epoch 1980: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 222730.5156 - val_loss: 5706.0039 - 1s/epoch - 150ms/step
# Epoch 1981/2000
#
# Epoch 1981: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 239075.8906 - val_loss: 10338.7266 - 507ms/epoch - 72ms/step
# Epoch 1982/2000
#
# Epoch 1982: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 223253.3438 - val_loss: 5636.1528 - 533ms/epoch - 76ms/step
# Epoch 1983/2000
#
# Epoch 1983: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 238422.4531 - val_loss: 5779.3633 - 641ms/epoch - 92ms/step
# Epoch 1984/2000
#
# Epoch 1984: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 236621.4688 - val_loss: 5267.1494 - 1s/epoch - 147ms/step
# Epoch 1985/2000
#
# Epoch 1985: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 204539.1562 - val_loss: 5148.2505 - 1s/epoch - 150ms/step
# Epoch 1986/2000
#
# Epoch 1986: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 230653.9531 - val_loss: 18486.5039 - 1s/epoch - 157ms/step
# Epoch 1987/2000
#
# Epoch 1987: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 224543.9219 - val_loss: 8163.0767 - 968ms/epoch - 138ms/step
# Epoch 1988/2000
#
# Epoch 1988: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 224586.9531 - val_loss: 5435.3145 - 986ms/epoch - 141ms/step
# Epoch 1989/2000
#
# Epoch 1989: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 218507.4219 - val_loss: 5541.8545 - 755ms/epoch - 108ms/step
# Epoch 1990/2000
#
# Epoch 1990: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 272788.3125 - val_loss: 5856.2705 - 536ms/epoch - 77ms/step
# Epoch 1991/2000
#
# Epoch 1991: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 208128.7812 - val_loss: 6557.3662 - 568ms/epoch - 81ms/step
# Epoch 1992/2000
#
# Epoch 1992: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 224969.4219 - val_loss: 5582.6270 - 579ms/epoch - 83ms/step
# Epoch 1993/2000
#
# Epoch 1993: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 243569.3281 - val_loss: 5059.5986 - 539ms/epoch - 77ms/step
# Epoch 1994/2000
#
# Epoch 1994: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 178641.3594 - val_loss: 5140.6758 - 559ms/epoch - 80ms/step
# Epoch 1995/2000
#
# Epoch 1995: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 193058.2188 - val_loss: 5183.9478 - 520ms/epoch - 74ms/step
# Epoch 1996/2000
#
# Epoch 1996: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 200737.5781 - val_loss: 5074.0894 - 536ms/epoch - 77ms/step
# Epoch 1997/2000
#
# Epoch 1997: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 232865.9531 - val_loss: 5403.8315 - 537ms/epoch - 77ms/step
# Epoch 1998/2000
#
# Epoch 1998: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 230009.0469 - val_loss: 5592.9492 - 548ms/epoch - 78ms/step
# Epoch 1999/2000
#
# Epoch 1999: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 226894.6562 - val_loss: 11176.3008 - 523ms/epoch - 75ms/step
# Epoch 2000/2000
#
# Epoch 2000: loss did not improve from 162013.26562
# 7/7 - 1s - loss: 201904.0781 - val_loss: 5423.7734 - 512ms/epoch - 73ms/step
# 16/16 [==============================] - 1s 10ms/step
# 3/3 [==============================] - 0s 19ms/step
# Training MSE: 12028.338784178011
# Testing MSE: 9264.926310932364
# accuracy : 57

# %%
trainX, trainY = create_dataset(train_data_t_2, train_data, look_back)
testX, testY = create_dataset(test_data_t_2,test_data, look_back)

print(trainX.shape)
print(trainY.shape)
print(testX.shape)
print(testY.shape)
# Out:
# (489, 10, 14)
# (489, 1)
# (79, 10, 14)
# (79, 1)

# %%
# 모델 생성 GRU+CNN
model = Sequential()
model.add(Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(MaxPooling1D(pool_size=2))
model.add(GRU(units=1024, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=512, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=256, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=128, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=64, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=32, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=16, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(units=1))
model.summary()


# loss = Huber()
# optimizer = Adam(0.0005)
# model.compile(loss=Huber(), optimizer=optimizer, metrics=['mse'])
model.compile(optimizer='adam', loss='mean_squared_error')

filename = os.path.join('tmp', 'ckeckpointer.ckpt')
checkpoint = ModelCheckpoint(filename,
                             save_weights_only=True,
                             save_best_only=True,
                             monitor='loss',
                             verbose=1)

# 모델 학습
history = model.fit(trainX, trainY, epochs=2000, batch_size=64,
          validation_split=0.1, verbose=2,callbacks=[checkpoint])

model.save_weights('./ko_sum_CNN_GRU__weights.h2')

model.load_weights(filename)

plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()
plt.show()

# 예측
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# MSE 계산
trainMSE = mean_squared_error(trainY, trainPredict)
testMSE = mean_squared_error(testY, testPredict)

print(f'Training MSE: {trainMSE}')
print(f'Testing MSE: {testMSE}')

accuracy(testPredict,testY)

# 예측 시각화
plt.plot(trainY, label='Actual Price')
plt.plot(trainPredict, label='Predicted Price')
plt.legend()
plt.title('Training Data')
plt.show()

plt.plot(testY, label='Actual Price')
plt.plot(testPredict, label='Predicted Price')
plt.legend()
plt.title('Testing Data')
plt.show()
# Out:
# WARNING:tensorflow:Layer gru_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Epoch 751/2000
#
# Epoch 751: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 384135.3125 - val_loss: 27278.0938 - 1s/epoch - 157ms/step
# Epoch 752/2000
#
# Epoch 752: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 374889.0625 - val_loss: 10248.2793 - 1s/epoch - 145ms/step
# Epoch 753/2000
#
# Epoch 753: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 356789.1562 - val_loss: 23242.2441 - 1s/epoch - 150ms/step
# Epoch 754/2000
#
# Epoch 754: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 351347.1875 - val_loss: 93636.9375 - 614ms/epoch - 88ms/step
# Epoch 755/2000
#
# Epoch 755: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 406582.9375 - val_loss: 21388.1680 - 509ms/epoch - 73ms/step
# Epoch 756/2000
#
# Epoch 756: loss did not improve from 308156.53125
# 7/7 - 0s - loss: 386644.0625 - val_loss: 51355.8672 - 498ms/epoch - 71ms/step
# Epoch 757/2000
#
# Epoch 757: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 376890.5000 - val_loss: 10834.6758 - 523ms/epoch - 75ms/step
# Epoch 758/2000
#
# Epoch 758: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 397394.3750 - val_loss: 57379.2148 - 541ms/epoch - 77ms/step
# Epoch 759/2000
#
# Epoch 759: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 326721.5938 - val_loss: 45645.9883 - 523ms/epoch - 75ms/step
# Epoch 760/2000
#
# Epoch 760: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 371560.2812 - val_loss: 33349.3438 - 503ms/epoch - 72ms/step
# Epoch 761/2000
#
# Epoch 761: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 329789.5000 - val_loss: 76789.2422 - 534ms/epoch - 76ms/step
# Epoch 762/2000
#
# Epoch 762: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 367954.7500 - val_loss: 122650.5938 - 585ms/epoch - 84ms/step
# Epoch 763/2000
#
# Epoch 763: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 341615.8125 - val_loss: 40115.7109 - 559ms/epoch - 80ms/step
# Epoch 764/2000
#
# Epoch 764: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 386154.9062 - val_loss: 43377.3555 - 509ms/epoch - 73ms/step
# Epoch 765/2000
#
# Epoch 765: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 339689.3750 - val_loss: 74684.1094 - 539ms/epoch - 77ms/step
# Epoch 766/2000
#
# Epoch 766: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 347332.3125 - val_loss: 44100.2773 - 546ms/epoch - 78ms/step
# Epoch 767/2000
#
# Epoch 767: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 367587.9062 - val_loss: 89849.3281 - 516ms/epoch - 74ms/step
# Epoch 768/2000
#
# Epoch 768: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 353344.9062 - val_loss: 40582.8867 - 519ms/epoch - 74ms/step
# Epoch 769/2000
#
# Epoch 769: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 343311.1875 - val_loss: 83158.9297 - 502ms/epoch - 72ms/step
# Epoch 770/2000
#
# Epoch 770: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 316523.2812 - val_loss: 29334.8730 - 528ms/epoch - 75ms/step
# Epoch 771/2000
#
# Epoch 771: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 364993.2500 - val_loss: 47398.1211 - 550ms/epoch - 79ms/step
# Epoch 772/2000
#
# Epoch 772: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 356092.0000 - val_loss: 41989.1289 - 523ms/epoch - 75ms/step
# Epoch 773/2000
#
# Epoch 773: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 330421.2500 - val_loss: 43101.3281 - 1s/epoch - 156ms/step
# Epoch 774/2000
#
# Epoch 774: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 351082.4375 - val_loss: 43395.8281 - 1s/epoch - 148ms/step
# Epoch 775/2000
#
# Epoch 775: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 372483.1562 - val_loss: 52739.6523 - 1s/epoch - 169ms/step
# Epoch 776/2000
#
# Epoch 776: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 317791.2500 - val_loss: 55823.7227 - 1s/epoch - 150ms/step
# Epoch 777/2000
#
# Epoch 777: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 359173.3438 - val_loss: 29434.3730 - 1s/epoch - 154ms/step
# Epoch 778/2000
#
# Epoch 778: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 345323.5625 - val_loss: 31204.4395 - 764ms/epoch - 109ms/step
# Epoch 779/2000
#
# Epoch 779: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 346500.9062 - val_loss: 54191.7227 - 519ms/epoch - 74ms/step
# Epoch 780/2000
#
# Epoch 780: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 361254.8750 - val_loss: 60429.7852 - 523ms/epoch - 75ms/step
# Epoch 781/2000
#
# Epoch 781: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 376165.3750 - val_loss: 25593.8066 - 518ms/epoch - 74ms/step
# Epoch 782/2000
#
# Epoch 782: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 407480.2500 - val_loss: 35922.4531 - 530ms/epoch - 76ms/step
# Epoch 783/2000
#
# Epoch 783: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 374486.0938 - val_loss: 52888.1523 - 532ms/epoch - 76ms/step
# Epoch 784/2000
#
# Epoch 784: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 362335.3438 - val_loss: 100351.4766 - 541ms/epoch - 77ms/step
# Epoch 785/2000
#
# Epoch 785: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 353199.1250 - val_loss: 53709.8672 - 535ms/epoch - 76ms/step
# Epoch 786/2000
#
# Epoch 786: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 331096.4062 - val_loss: 62275.4688 - 549ms/epoch - 78ms/step
# Epoch 787/2000
#
# Epoch 787: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 375333.1250 - val_loss: 11015.8867 - 510ms/epoch - 73ms/step
# Epoch 788/2000
#
# Epoch 788: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 393991.7812 - val_loss: 100334.1562 - 538ms/epoch - 77ms/step
# Epoch 789/2000
#
# Epoch 789: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 359975.7500 - val_loss: 53262.4180 - 505ms/epoch - 72ms/step
# Epoch 790/2000
#
# Epoch 790: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 395621.9375 - val_loss: 140740.0000 - 542ms/epoch - 77ms/step
# Epoch 791/2000
#
# Epoch 791: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 340381.1562 - val_loss: 23025.9434 - 540ms/epoch - 77ms/step
# Epoch 792/2000
#
# Epoch 792: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 325620.4688 - val_loss: 44252.3203 - 525ms/epoch - 75ms/step
# Epoch 793/2000
#
# Epoch 793: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 388417.3750 - val_loss: 25822.1523 - 535ms/epoch - 76ms/step
# Epoch 794/2000
#
# Epoch 794: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 344999.5625 - val_loss: 63637.8789 - 565ms/epoch - 81ms/step
# Epoch 795/2000
#
# Epoch 795: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 354501.6250 - val_loss: 72636.7578 - 555ms/epoch - 79ms/step
# Epoch 796/2000
#
# Epoch 796: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 377984.9688 - val_loss: 79537.8047 - 569ms/epoch - 81ms/step
# Epoch 797/2000
#
# Epoch 797: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 338788.8125 - val_loss: 26683.3887 - 983ms/epoch - 140ms/step
# Epoch 798/2000
#
# Epoch 798: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 327757.1562 - val_loss: 8485.0840 - 1s/epoch - 158ms/step
# Epoch 799/2000
#
# Epoch 799: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 351226.2500 - val_loss: 46335.6680 - 994ms/epoch - 142ms/step
# Epoch 800/2000
#
# Epoch 800: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 453719.0625 - val_loss: 14616.4922 - 1s/epoch - 158ms/step
# Epoch 801/2000
#
# Epoch 801: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 372295.5312 - val_loss: 28195.8887 - 1s/epoch - 158ms/step
# Epoch 802/2000
#
# Epoch 802: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 381762.9375 - val_loss: 85583.8281 - 847ms/epoch - 121ms/step
# Epoch 803/2000
#
# Epoch 803: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 364029.7500 - val_loss: 22081.2578 - 521ms/epoch - 74ms/step
# Epoch 804/2000
#
# Epoch 804: loss did not improve from 308156.53125
# 7/7 - 0s - loss: 328350.3125 - val_loss: 32004.7168 - 490ms/epoch - 70ms/step
# Epoch 805/2000
#
# Epoch 805: loss did not improve from 308156.53125
# 7/7 - 1s - loss: 384882.7500 - val_loss: 22576.9336 - 568ms/epoch - 81ms/step
# Epoch 806/2000
#
# Epoch 806: loss improved from 308156.53125 to 306087.03125, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 306087.0312 - val_loss: 41029.4062 - 737ms/epoch - 105ms/step
# Epoch 807/2000
#
# Epoch 807: loss did not improve from 306087.03125
# 7/7 - 1s - loss: 396132.7500 - val_loss: 46591.1641 - 599ms/epoch - 86ms/step
# Epoch 808/2000
#
# Epoch 808: loss did not improve from 306087.03125
# 7/7 - 1s - loss: 351507.8438 - val_loss: 88818.0000 - 569ms/epoch - 81ms/step
# Epoch 809/2000
#
# Epoch 809: loss did not improve from 306087.03125
# 7/7 - 1s - loss: 360891.7500 - val_loss: 12453.9307 - 546ms/epoch - 78ms/step
# Epoch 810/2000
#
# Epoch 810: loss did not improve from 306087.03125
# 7/7 - 1s - loss: 404164.0625 - val_loss: 9507.3252 - 582ms/epoch - 83ms/step
# Epoch 811/2000
#
# Epoch 811: loss did not improve from 306087.03125
# 7/7 - 1s - loss: 343661.0938 - val_loss: 54934.6211 - 556ms/epoch - 79ms/step
# Epoch 812/2000
#
# Epoch 812: loss did not improve from 306087.03125
# 7/7 - 1s - loss: 341854.6875 - val_loss: 29294.1738 - 561ms/epoch - 80ms/step
# Epoch 813/2000
#
# Epoch 813: loss improved from 306087.03125 to 303794.71875, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 303794.7188 - val_loss: 58724.1289 - 768ms/epoch - 110ms/step
# Epoch 814/2000
#
# Epoch 814: loss did not improve from 303794.71875
# 7/7 - 1s - loss: 343827.3438 - val_loss: 6164.1880 - 586ms/epoch - 84ms/step
# Epoch 815/2000
#
# Epoch 815: loss did not improve from 303794.71875
# 7/7 - 1s - loss: 326353.9688 - val_loss: 35346.7109 - 574ms/epoch - 82ms/step
# Epoch 816/2000
#
# Epoch 816: loss did not improve from 303794.71875
# 7/7 - 1s - loss: 343994.0000 - val_loss: 7482.9121 - 516ms/epoch - 74ms/step
# Epoch 817/2000
#
# Epoch 817: loss did not improve from 303794.71875
# 7/7 - 1s - loss: 380062.3125 - val_loss: 52619.3047 - 542ms/epoch - 77ms/step
# Epoch 818/2000
#
# Epoch 818: loss did not improve from 303794.71875
# 7/7 - 1s - loss: 343897.5625 - val_loss: 24536.1602 - 546ms/epoch - 78ms/step
# Epoch 819/2000
#
# Epoch 819: loss did not improve from 303794.71875
# 7/7 - 1s - loss: 344632.6875 - val_loss: 57073.6328 - 566ms/epoch - 81ms/step
# Epoch 820/2000
#
# Epoch 820: loss did not improve from 303794.71875
# 7/7 - 1s - loss: 366219.3438 - val_loss: 22382.6602 - 1s/epoch - 164ms/step
# Epoch 821/2000
#
# Epoch 821: loss did not improve from 303794.71875
# 7/7 - 1s - loss: 350469.0938 - val_loss: 21383.4941 - 1s/epoch - 154ms/step
# Epoch 822/2000
#
# Epoch 822: loss did not improve from 303794.71875
# 7/7 - 1s - loss: 379365.1250 - val_loss: 56317.4492 - 1s/epoch - 159ms/step
# Epoch 823/2000
#
# Epoch 823: loss did not improve from 303794.71875
# 7/7 - 1s - loss: 307949.1250 - val_loss: 23768.9902 - 994ms/epoch - 142ms/step
# Epoch 824/2000
#
# Epoch 824: loss improved from 303794.71875 to 296690.96875, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 296690.9688 - val_loss: 49691.7500 - 1s/epoch - 188ms/step
# Epoch 825/2000
#
# Epoch 825: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 354461.6250 - val_loss: 68659.3906 - 590ms/epoch - 84ms/step
# Epoch 826/2000
#
# Epoch 826: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 345166.1562 - val_loss: 29165.6172 - 598ms/epoch - 85ms/step
# Epoch 827/2000
#
# Epoch 827: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 317873.0625 - val_loss: 9329.8379 - 536ms/epoch - 77ms/step
# Epoch 828/2000
#
# Epoch 828: loss did not improve from 296690.96875
# 7/7 - 0s - loss: 356960.6875 - val_loss: 27450.0664 - 499ms/epoch - 71ms/step
# Epoch 829/2000
#
# Epoch 829: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 322274.5312 - val_loss: 28437.0859 - 592ms/epoch - 85ms/step
# Epoch 830/2000
#
# Epoch 830: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 349408.3125 - val_loss: 14487.8613 - 542ms/epoch - 77ms/step
# Epoch 831/2000
#
# Epoch 831: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 332371.4688 - val_loss: 6256.6631 - 563ms/epoch - 80ms/step
# Epoch 832/2000
#
# Epoch 832: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 330953.2812 - val_loss: 63366.1172 - 523ms/epoch - 75ms/step
# Epoch 833/2000
#
# Epoch 833: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 348165.8125 - val_loss: 42141.0703 - 573ms/epoch - 82ms/step
# Epoch 834/2000
#
# Epoch 834: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 362795.3750 - val_loss: 32585.7910 - 514ms/epoch - 73ms/step
# Epoch 835/2000
#
# Epoch 835: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 334054.0312 - val_loss: 52678.4648 - 502ms/epoch - 72ms/step
# Epoch 836/2000
#
# Epoch 836: loss did not improve from 296690.96875
# 7/7 - 0s - loss: 348281.6250 - val_loss: 22518.7695 - 498ms/epoch - 71ms/step
# Epoch 837/2000
#
# Epoch 837: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 358212.2188 - val_loss: 61561.8359 - 514ms/epoch - 73ms/step
# Epoch 838/2000
#
# Epoch 838: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 322710.4062 - val_loss: 31143.9434 - 536ms/epoch - 77ms/step
# Epoch 839/2000
#
# Epoch 839: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 357849.4688 - val_loss: 21390.1562 - 524ms/epoch - 75ms/step
# Epoch 840/2000
#
# Epoch 840: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 304761.8125 - val_loss: 46627.5117 - 561ms/epoch - 80ms/step
# Epoch 841/2000
#
# Epoch 841: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 330609.7188 - val_loss: 33828.4961 - 521ms/epoch - 74ms/step
# Epoch 842/2000
#
# Epoch 842: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 321328.5938 - val_loss: 35838.1406 - 571ms/epoch - 82ms/step
# Epoch 843/2000
#
# Epoch 843: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 323070.2500 - val_loss: 17566.7344 - 708ms/epoch - 101ms/step
# Epoch 844/2000
#
# Epoch 844: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 366052.7500 - val_loss: 54076.0703 - 1s/epoch - 161ms/step
# Epoch 845/2000
#
# Epoch 845: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 337309.6250 - val_loss: 29291.7734 - 1s/epoch - 157ms/step
# Epoch 846/2000
#
# Epoch 846: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 356337.3125 - val_loss: 54504.4609 - 1s/epoch - 167ms/step
# Epoch 847/2000
#
# Epoch 847: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 339029.9062 - val_loss: 43184.2344 - 1s/epoch - 160ms/step
# Epoch 848/2000
#
# Epoch 848: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 316824.5000 - val_loss: 7018.2168 - 961ms/epoch - 137ms/step
# Epoch 849/2000
#
# Epoch 849: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 365990.5000 - val_loss: 31461.2598 - 580ms/epoch - 83ms/step
# Epoch 850/2000
#
# Epoch 850: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 343151.7188 - val_loss: 6586.3232 - 526ms/epoch - 75ms/step
# Epoch 851/2000
#
# Epoch 851: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 311076.5938 - val_loss: 59139.7852 - 541ms/epoch - 77ms/step
# Epoch 852/2000
#
# Epoch 852: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 335975.3438 - val_loss: 6615.8359 - 538ms/epoch - 77ms/step
# Epoch 853/2000
#
# Epoch 853: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 341371.6250 - val_loss: 47411.4609 - 515ms/epoch - 74ms/step
# Epoch 854/2000
#
# Epoch 854: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 375588.5938 - val_loss: 13346.5654 - 623ms/epoch - 89ms/step
# Epoch 855/2000
#
# Epoch 855: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 363318.9375 - val_loss: 49596.1836 - 527ms/epoch - 75ms/step
# Epoch 856/2000
#
# Epoch 856: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 336718.2500 - val_loss: 36987.3438 - 503ms/epoch - 72ms/step
# Epoch 857/2000
#
# Epoch 857: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 315265.1250 - val_loss: 56778.5859 - 578ms/epoch - 83ms/step
# Epoch 858/2000
#
# Epoch 858: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 357307.1250 - val_loss: 31078.2148 - 512ms/epoch - 73ms/step
# Epoch 859/2000
#
# Epoch 859: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 302254.2812 - val_loss: 109307.7344 - 545ms/epoch - 78ms/step
# Epoch 860/2000
#
# Epoch 860: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 347617.9688 - val_loss: 19516.0605 - 549ms/epoch - 78ms/step
# Epoch 861/2000
#
# Epoch 861: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 354933.0625 - val_loss: 30384.2168 - 546ms/epoch - 78ms/step
# Epoch 862/2000
#
# Epoch 862: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 311159.6875 - val_loss: 18280.8105 - 521ms/epoch - 74ms/step
# Epoch 863/2000
#
# Epoch 863: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 320217.0625 - val_loss: 39614.4727 - 580ms/epoch - 83ms/step
# Epoch 864/2000
#
# Epoch 864: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 301381.0625 - val_loss: 33750.4258 - 539ms/epoch - 77ms/step
# Epoch 865/2000
#
# Epoch 865: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 359555.4062 - val_loss: 10127.4619 - 543ms/epoch - 78ms/step
# Epoch 866/2000
#
# Epoch 866: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 307299.7500 - val_loss: 29571.1348 - 529ms/epoch - 76ms/step
# Epoch 867/2000
#
# Epoch 867: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 307778.3125 - val_loss: 9574.2139 - 758ms/epoch - 108ms/step
# Epoch 868/2000
#
# Epoch 868: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 322189.7188 - val_loss: 36971.1328 - 1s/epoch - 153ms/step
# Epoch 869/2000
#
# Epoch 869: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 353928.6562 - val_loss: 6884.2231 - 1s/epoch - 166ms/step
# Epoch 870/2000
#
# Epoch 870: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 296804.6875 - val_loss: 22583.1895 - 1s/epoch - 162ms/step
# Epoch 871/2000
#
# Epoch 871: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 339560.3750 - val_loss: 47205.6211 - 1s/epoch - 146ms/step
# Epoch 872/2000
#
# Epoch 872: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 338939.6250 - val_loss: 13906.3672 - 1s/epoch - 145ms/step
# Epoch 873/2000
#
# Epoch 873: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 337365.1875 - val_loss: 72552.1641 - 585ms/epoch - 84ms/step
# Epoch 874/2000
#
# Epoch 874: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 328213.9688 - val_loss: 8623.3623 - 521ms/epoch - 74ms/step
# Epoch 875/2000
#
# Epoch 875: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 315708.2188 - val_loss: 28766.0664 - 551ms/epoch - 79ms/step
# Epoch 876/2000
#
# Epoch 876: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 369152.1562 - val_loss: 14682.6865 - 563ms/epoch - 80ms/step
# Epoch 877/2000
#
# Epoch 877: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 305748.2812 - val_loss: 11141.1777 - 559ms/epoch - 80ms/step
# Epoch 878/2000
#
# Epoch 878: loss did not improve from 296690.96875
# 7/7 - 1s - loss: 317239.0938 - val_loss: 15388.6221 - 529ms/epoch - 76ms/step
# Epoch 879/2000
#
# Epoch 879: loss improved from 296690.96875 to 286284.28125, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 286284.2812 - val_loss: 19803.7617 - 765ms/epoch - 109ms/step
# Epoch 880/2000
#
# Epoch 880: loss did not improve from 286284.28125
# 7/7 - 1s - loss: 341696.5000 - val_loss: 56868.8789 - 535ms/epoch - 76ms/step
# Epoch 881/2000
#
# Epoch 881: loss did not improve from 286284.28125
# 7/7 - 1s - loss: 333128.4375 - val_loss: 33644.5469 - 511ms/epoch - 73ms/step
# Epoch 882/2000
#
# Epoch 882: loss did not improve from 286284.28125
# 7/7 - 1s - loss: 322809.3750 - val_loss: 10708.7002 - 553ms/epoch - 79ms/step
# Epoch 883/2000
#
# Epoch 883: loss did not improve from 286284.28125
# 7/7 - 1s - loss: 328834.3125 - val_loss: 9894.9121 - 1s/epoch - 154ms/step
# Epoch 884/2000
#
# Epoch 884: loss did not improve from 286284.28125
# 7/7 - 1s - loss: 331109.5000 - val_loss: 16562.4668 - 1s/epoch - 160ms/step
# Epoch 885/2000
#
# Epoch 885: loss did not improve from 286284.28125
# 7/7 - 1s - loss: 338697.5625 - val_loss: 33308.0781 - 1s/epoch - 162ms/step
# Epoch 886/2000
#
# Epoch 886: loss did not improve from 286284.28125
# 7/7 - 1s - loss: 321428.8750 - val_loss: 31985.8730 - 1s/epoch - 152ms/step
# Epoch 887/2000
#
# Epoch 887: loss did not improve from 286284.28125
# 7/7 - 1s - loss: 376559.2812 - val_loss: 20670.6523 - 1s/epoch - 161ms/step
# Epoch 888/2000
#
# Epoch 888: loss did not improve from 286284.28125
# 7/7 - 1s - loss: 354689.4688 - val_loss: 9489.7148 - 1s/epoch - 155ms/step
# Epoch 889/2000
#
# Epoch 889: loss did not improve from 286284.28125
# 7/7 - 1s - loss: 342546.5312 - val_loss: 44826.5664 - 1s/epoch - 160ms/step
# Epoch 890/2000
#
# Epoch 890: loss did not improve from 286284.28125
# 7/7 - 1s - loss: 329743.6875 - val_loss: 27331.8730 - 1s/epoch - 154ms/step
# Epoch 891/2000
#
# Epoch 891: loss did not improve from 286284.28125
# 7/7 - 1s - loss: 331319.7500 - val_loss: 34527.9844 - 999ms/epoch - 143ms/step
# Epoch 892/2000
#
# Epoch 892: loss did not improve from 286284.28125
# 7/7 - 1s - loss: 344539.3750 - val_loss: 52122.7461 - 1s/epoch - 167ms/step
# Epoch 893/2000
#
# Epoch 893: loss did not improve from 286284.28125
# 7/7 - 1s - loss: 294383.6875 - val_loss: 24428.7480 - 952ms/epoch - 136ms/step
# Epoch 894/2000
#
# Epoch 894: loss did not improve from 286284.28125
# 7/7 - 1s - loss: 337290.0000 - val_loss: 30128.9570 - 551ms/epoch - 79ms/step
# Epoch 895/2000
#
# Epoch 895: loss did not improve from 286284.28125
# 7/7 - 1s - loss: 368531.1250 - val_loss: 33205.5234 - 549ms/epoch - 78ms/step
# Epoch 896/2000
#
# Epoch 896: loss improved from 286284.28125 to 276981.40625, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 276981.4062 - val_loss: 11411.6592 - 763ms/epoch - 109ms/step
# Epoch 897/2000
#
# Epoch 897: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 284287.5000 - val_loss: 27326.5996 - 527ms/epoch - 75ms/step
# Epoch 898/2000
#
# Epoch 898: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 336448.9375 - val_loss: 54477.8164 - 509ms/epoch - 73ms/step
# Epoch 899/2000
#
# Epoch 899: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 338769.2812 - val_loss: 48256.2852 - 548ms/epoch - 78ms/step
# Epoch 900/2000
#
# Epoch 900: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 340360.3125 - val_loss: 36300.2422 - 529ms/epoch - 76ms/step
# Epoch 901/2000
#
# Epoch 901: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 303144.5000 - val_loss: 19055.8574 - 598ms/epoch - 85ms/step
# Epoch 902/2000
#
# Epoch 902: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 312807.4062 - val_loss: 55412.5664 - 523ms/epoch - 75ms/step
# Epoch 903/2000
#
# Epoch 903: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 301004.8438 - val_loss: 31355.9004 - 529ms/epoch - 76ms/step
# Epoch 904/2000
#
# Epoch 904: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 350911.3125 - val_loss: 20211.0879 - 545ms/epoch - 78ms/step
# Epoch 905/2000
#
# Epoch 905: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 320970.6562 - val_loss: 61479.6367 - 524ms/epoch - 75ms/step
# Epoch 906/2000
#
# Epoch 906: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 284559.2812 - val_loss: 34010.7539 - 518ms/epoch - 74ms/step
# Epoch 907/2000
#
# Epoch 907: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 335483.2500 - val_loss: 34134.7656 - 528ms/epoch - 75ms/step
# Epoch 908/2000
#
# Epoch 908: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 359703.5312 - val_loss: 12335.7988 - 557ms/epoch - 80ms/step
# Epoch 909/2000
#
# Epoch 909: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 341709.0312 - val_loss: 6608.6665 - 542ms/epoch - 77ms/step
# Epoch 910/2000
#
# Epoch 910: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 308705.7812 - val_loss: 18354.5273 - 535ms/epoch - 76ms/step
# Epoch 911/2000
#
# Epoch 911: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 329965.8438 - val_loss: 44228.5195 - 600ms/epoch - 86ms/step
# Epoch 912/2000
#
# Epoch 912: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 371954.5312 - val_loss: 31808.3984 - 1s/epoch - 161ms/step
# Epoch 913/2000
#
# Epoch 913: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 312686.0938 - val_loss: 25515.0664 - 1s/epoch - 161ms/step
# Epoch 914/2000
#
# Epoch 914: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 296331.6875 - val_loss: 20939.9727 - 1s/epoch - 147ms/step
# Epoch 915/2000
#
# Epoch 915: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 323985.6250 - val_loss: 51401.8477 - 1s/epoch - 145ms/step
# Epoch 916/2000
#
# Epoch 916: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 360368.1562 - val_loss: 33397.5547 - 1s/epoch - 146ms/step
# Epoch 917/2000
#
# Epoch 917: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 306839.8438 - val_loss: 53488.5508 - 703ms/epoch - 100ms/step
# Epoch 918/2000
#
# Epoch 918: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 300180.2500 - val_loss: 10702.2783 - 506ms/epoch - 72ms/step
# Epoch 919/2000
#
# Epoch 919: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 341264.2812 - val_loss: 87337.7578 - 524ms/epoch - 75ms/step
# Epoch 920/2000
#
# Epoch 920: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 333998.4375 - val_loss: 39378.6797 - 556ms/epoch - 79ms/step
# Epoch 921/2000
#
# Epoch 921: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 307405.9375 - val_loss: 95163.1250 - 530ms/epoch - 76ms/step
# Epoch 922/2000
#
# Epoch 922: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 327307.1250 - val_loss: 13442.3574 - 545ms/epoch - 78ms/step
# Epoch 923/2000
#
# Epoch 923: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 296813.2500 - val_loss: 34969.5352 - 531ms/epoch - 76ms/step
# Epoch 924/2000
#
# Epoch 924: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 335167.3125 - val_loss: 8380.5879 - 553ms/epoch - 79ms/step
# Epoch 925/2000
#
# Epoch 925: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 341080.2812 - val_loss: 19850.6523 - 523ms/epoch - 75ms/step
# Epoch 926/2000
#
# Epoch 926: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 329551.0938 - val_loss: 41285.8398 - 538ms/epoch - 77ms/step
# Epoch 927/2000
#
# Epoch 927: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 309746.3750 - val_loss: 15192.7363 - 529ms/epoch - 76ms/step
# Epoch 928/2000
#
# Epoch 928: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 316339.4062 - val_loss: 15561.0693 - 563ms/epoch - 80ms/step
# Epoch 929/2000
#
# Epoch 929: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 304270.0312 - val_loss: 20021.0977 - 551ms/epoch - 79ms/step
# Epoch 930/2000
#
# Epoch 930: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 339332.0625 - val_loss: 31696.5176 - 561ms/epoch - 80ms/step
# Epoch 931/2000
#
# Epoch 931: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 315737.9062 - val_loss: 9478.5020 - 531ms/epoch - 76ms/step
# Epoch 932/2000
#
# Epoch 932: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 333799.3438 - val_loss: 33507.4375 - 512ms/epoch - 73ms/step
# Epoch 933/2000
#
# Epoch 933: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 343108.6562 - val_loss: 8490.1162 - 571ms/epoch - 82ms/step
# Epoch 934/2000
#
# Epoch 934: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 323626.9375 - val_loss: 24538.3027 - 523ms/epoch - 75ms/step
# Epoch 935/2000
#
# Epoch 935: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 307687.9062 - val_loss: 30929.9395 - 556ms/epoch - 79ms/step
# Epoch 936/2000
#
# Epoch 936: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 340797.9062 - val_loss: 6940.0576 - 1s/epoch - 157ms/step
# Epoch 937/2000
#
# Epoch 937: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 308376.2188 - val_loss: 38922.3359 - 1s/epoch - 165ms/step
# Epoch 938/2000
#
# Epoch 938: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 336438.6250 - val_loss: 9012.6221 - 1s/epoch - 160ms/step
# Epoch 939/2000
#
# Epoch 939: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 324130.4688 - val_loss: 27654.0488 - 1s/epoch - 153ms/step
# Epoch 940/2000
#
# Epoch 940: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 314482.4688 - val_loss: 6514.5371 - 1s/epoch - 149ms/step
# Epoch 941/2000
#
# Epoch 941: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 371594.3125 - val_loss: 42040.1484 - 821ms/epoch - 117ms/step
# Epoch 942/2000
#
# Epoch 942: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 326684.9062 - val_loss: 15929.0742 - 507ms/epoch - 72ms/step
# Epoch 943/2000
#
# Epoch 943: loss did not improve from 276981.40625
# 7/7 - 1s - loss: 312777.3438 - val_loss: 20299.3730 - 570ms/epoch - 81ms/step
# Epoch 944/2000
#
# Epoch 944: loss improved from 276981.40625 to 262375.75000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 262375.7500 - val_loss: 5614.0317 - 768ms/epoch - 110ms/step
# Epoch 945/2000
#
# Epoch 945: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 298659.8438 - val_loss: 33426.5742 - 516ms/epoch - 74ms/step
# Epoch 946/2000
#
# Epoch 946: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 361537.7812 - val_loss: 31080.4336 - 521ms/epoch - 74ms/step
# Epoch 947/2000
#
# Epoch 947: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 338641.2812 - val_loss: 9809.1465 - 536ms/epoch - 77ms/step
# Epoch 948/2000
#
# Epoch 948: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 350993.9688 - val_loss: 33612.8867 - 535ms/epoch - 76ms/step
# Epoch 949/2000
#
# Epoch 949: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 327075.3750 - val_loss: 12396.4873 - 596ms/epoch - 85ms/step
# Epoch 950/2000
#
# Epoch 950: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 304918.1562 - val_loss: 30916.1738 - 531ms/epoch - 76ms/step
# Epoch 951/2000
#
# Epoch 951: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 326447.6250 - val_loss: 16458.6719 - 517ms/epoch - 74ms/step
# Epoch 952/2000
#
# Epoch 952: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 360312.0312 - val_loss: 8962.0830 - 554ms/epoch - 79ms/step
# Epoch 953/2000
#
# Epoch 953: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 325709.5938 - val_loss: 14343.1377 - 519ms/epoch - 74ms/step
# Epoch 954/2000
#
# Epoch 954: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 349350.9062 - val_loss: 5796.2627 - 545ms/epoch - 78ms/step
# Epoch 955/2000
#
# Epoch 955: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 347670.0938 - val_loss: 14135.6738 - 531ms/epoch - 76ms/step
# Epoch 956/2000
#
# Epoch 956: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 298200.4375 - val_loss: 21149.1816 - 510ms/epoch - 73ms/step
# Epoch 957/2000
#
# Epoch 957: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 347990.9688 - val_loss: 24222.9277 - 514ms/epoch - 73ms/step
# Epoch 958/2000
#
# Epoch 958: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 321634.7500 - val_loss: 9208.2158 - 538ms/epoch - 77ms/step
# Epoch 959/2000
#
# Epoch 959: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 309146.6562 - val_loss: 7514.3306 - 692ms/epoch - 99ms/step
# Epoch 960/2000
#
# Epoch 960: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 308284.6250 - val_loss: 13436.3291 - 1s/epoch - 164ms/step
# Epoch 961/2000
#
# Epoch 961: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 333109.3750 - val_loss: 8726.3135 - 1s/epoch - 166ms/step
# Epoch 962/2000
#
# Epoch 962: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 313980.9375 - val_loss: 7287.7124 - 1s/epoch - 148ms/step
# Epoch 963/2000
#
# Epoch 963: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 296568.7500 - val_loss: 19390.8613 - 983ms/epoch - 140ms/step
# Epoch 964/2000
#
# Epoch 964: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 310477.3125 - val_loss: 7621.8076 - 1s/epoch - 153ms/step
# Epoch 965/2000
#
# Epoch 965: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 316048.9688 - val_loss: 55661.2227 - 658ms/epoch - 94ms/step
# Epoch 966/2000
#
# Epoch 966: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 292068.5938 - val_loss: 18255.9160 - 519ms/epoch - 74ms/step
# Epoch 967/2000
#
# Epoch 967: loss did not improve from 262375.75000
# 7/7 - 0s - loss: 323685.9062 - val_loss: 7406.8481 - 499ms/epoch - 71ms/step
# Epoch 968/2000
#
# Epoch 968: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 290734.3750 - val_loss: 6795.4644 - 550ms/epoch - 79ms/step
# Epoch 969/2000
#
# Epoch 969: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 327729.0938 - val_loss: 22578.7188 - 520ms/epoch - 74ms/step
# Epoch 970/2000
#
# Epoch 970: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 364536.9062 - val_loss: 15589.4795 - 518ms/epoch - 74ms/step
# Epoch 971/2000
#
# Epoch 971: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 301553.9375 - val_loss: 5691.4023 - 549ms/epoch - 78ms/step
# Epoch 972/2000
#
# Epoch 972: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 311221.6875 - val_loss: 14885.3340 - 554ms/epoch - 79ms/step
# Epoch 973/2000
#
# Epoch 973: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 350748.4688 - val_loss: 14680.0635 - 567ms/epoch - 81ms/step
# Epoch 974/2000
#
# Epoch 974: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 305595.3125 - val_loss: 77716.8125 - 535ms/epoch - 76ms/step
# Epoch 975/2000
#
# Epoch 975: loss did not improve from 262375.75000
# 7/7 - 0s - loss: 330962.3125 - val_loss: 9368.6943 - 499ms/epoch - 71ms/step
# Epoch 976/2000
#
# Epoch 976: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 357049.5938 - val_loss: 26581.2324 - 530ms/epoch - 76ms/step
# Epoch 977/2000
#
# Epoch 977: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 319547.2500 - val_loss: 6378.0923 - 550ms/epoch - 79ms/step
# Epoch 978/2000
#
# Epoch 978: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 320169.8438 - val_loss: 20302.0176 - 578ms/epoch - 83ms/step
# Epoch 979/2000
#
# Epoch 979: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 328899.7188 - val_loss: 14361.0693 - 531ms/epoch - 76ms/step
# Epoch 980/2000
#
# Epoch 980: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 327398.1562 - val_loss: 30173.9082 - 585ms/epoch - 84ms/step
# Epoch 981/2000
#
# Epoch 981: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 347535.5312 - val_loss: 14743.0820 - 573ms/epoch - 82ms/step
# Epoch 982/2000
#
# Epoch 982: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 305041.3125 - val_loss: 8458.3652 - 502ms/epoch - 72ms/step
# Epoch 983/2000
#
# Epoch 983: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 287069.5000 - val_loss: 6557.0713 - 628ms/epoch - 90ms/step
# Epoch 984/2000
#
# Epoch 984: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 329682.0625 - val_loss: 10801.7910 - 1s/epoch - 182ms/step
# Epoch 985/2000
#
# Epoch 985: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 343177.0938 - val_loss: 5920.8730 - 1s/epoch - 143ms/step
# Epoch 986/2000
#
# Epoch 986: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 317232.2500 - val_loss: 21259.9023 - 1s/epoch - 169ms/step
# Epoch 987/2000
#
# Epoch 987: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 283648.5312 - val_loss: 18744.6738 - 1s/epoch - 158ms/step
# Epoch 988/2000
#
# Epoch 988: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 334796.4375 - val_loss: 7282.9604 - 1s/epoch - 160ms/step
# Epoch 989/2000
#
# Epoch 989: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 291580.9062 - val_loss: 23759.0469 - 765ms/epoch - 109ms/step
# Epoch 990/2000
#
# Epoch 990: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 342757.3750 - val_loss: 6229.9121 - 513ms/epoch - 73ms/step
# Epoch 991/2000
#
# Epoch 991: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 348407.8125 - val_loss: 17909.3145 - 528ms/epoch - 75ms/step
# Epoch 992/2000
#
# Epoch 992: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 361280.5000 - val_loss: 6421.7749 - 521ms/epoch - 74ms/step
# Epoch 993/2000
#
# Epoch 993: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 308255.7188 - val_loss: 14741.6992 - 583ms/epoch - 83ms/step
# Epoch 994/2000
#
# Epoch 994: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 302428.9375 - val_loss: 6899.7422 - 553ms/epoch - 79ms/step
# Epoch 995/2000
#
# Epoch 995: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 265816.6875 - val_loss: 36927.5664 - 508ms/epoch - 73ms/step
# Epoch 996/2000
#
# Epoch 996: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 312711.7812 - val_loss: 19861.4902 - 570ms/epoch - 81ms/step
# Epoch 997/2000
#
# Epoch 997: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 285722.5938 - val_loss: 22963.6270 - 540ms/epoch - 77ms/step
# Epoch 998/2000
#
# Epoch 998: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 329737.0938 - val_loss: 7210.4214 - 531ms/epoch - 76ms/step
# Epoch 999/2000
#
# Epoch 999: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 307036.9062 - val_loss: 20974.5430 - 519ms/epoch - 74ms/step
# Epoch 1000/2000
#
# Epoch 1000: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 274579.3750 - val_loss: 6554.0371 - 531ms/epoch - 76ms/step
# Epoch 1001/2000
#
# Epoch 1001: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 332425.3438 - val_loss: 54827.3359 - 542ms/epoch - 77ms/step
# Epoch 1002/2000
#
# Epoch 1002: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 326380.2188 - val_loss: 16813.4609 - 560ms/epoch - 80ms/step
# Epoch 1003/2000
#
# Epoch 1003: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 348909.0312 - val_loss: 31804.0605 - 524ms/epoch - 75ms/step
# Epoch 1004/2000
#
# Epoch 1004: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 388855.7188 - val_loss: 22055.5723 - 512ms/epoch - 73ms/step
# Epoch 1005/2000
#
# Epoch 1005: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 368240.8125 - val_loss: 12227.6074 - 561ms/epoch - 80ms/step
# Epoch 1006/2000
#
# Epoch 1006: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 335803.3438 - val_loss: 22852.1113 - 530ms/epoch - 76ms/step
# Epoch 1007/2000
#
# Epoch 1007: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 323492.8750 - val_loss: 8559.9238 - 694ms/epoch - 99ms/step
# Epoch 1008/2000
#
# Epoch 1008: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 323302.5312 - val_loss: 10169.4551 - 1s/epoch - 157ms/step
# Epoch 1009/2000
#
# Epoch 1009: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 324730.6250 - val_loss: 16658.0000 - 1s/epoch - 174ms/step
# Epoch 1010/2000
#
# Epoch 1010: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 309220.4688 - val_loss: 32219.5156 - 1s/epoch - 163ms/step
# Epoch 1011/2000
#
# Epoch 1011: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 344742.8438 - val_loss: 17015.2344 - 1s/epoch - 183ms/step
# Epoch 1012/2000
#
# Epoch 1012: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 328702.9375 - val_loss: 6594.5493 - 1s/epoch - 157ms/step
# Epoch 1013/2000
#
# Epoch 1013: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 352277.1875 - val_loss: 6083.5879 - 564ms/epoch - 81ms/step
# Epoch 1014/2000
#
# Epoch 1014: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 318777.9062 - val_loss: 7037.0435 - 549ms/epoch - 78ms/step
# Epoch 1015/2000
#
# Epoch 1015: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 314164.5000 - val_loss: 7581.9517 - 521ms/epoch - 74ms/step
# Epoch 1016/2000
#
# Epoch 1016: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 294158.2500 - val_loss: 19239.6367 - 513ms/epoch - 73ms/step
# Epoch 1017/2000
#
# Epoch 1017: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 344460.8438 - val_loss: 15751.2822 - 582ms/epoch - 83ms/step
# Epoch 1018/2000
#
# Epoch 1018: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 292864.5312 - val_loss: 14760.3164 - 536ms/epoch - 77ms/step
# Epoch 1019/2000
#
# Epoch 1019: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 287883.7188 - val_loss: 11293.8965 - 546ms/epoch - 78ms/step
# Epoch 1020/2000
#
# Epoch 1020: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 303882.6250 - val_loss: 11913.1152 - 548ms/epoch - 78ms/step
# Epoch 1021/2000
#
# Epoch 1021: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 304940.7188 - val_loss: 10347.7871 - 510ms/epoch - 73ms/step
# Epoch 1022/2000
#
# Epoch 1022: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 284081.5000 - val_loss: 30476.0195 - 545ms/epoch - 78ms/step
# Epoch 1023/2000
#
# Epoch 1023: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 313092.0000 - val_loss: 43783.1797 - 569ms/epoch - 81ms/step
# Epoch 1024/2000
#
# Epoch 1024: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 322426.0000 - val_loss: 6653.4336 - 524ms/epoch - 75ms/step
# Epoch 1025/2000
#
# Epoch 1025: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 318293.3750 - val_loss: 31074.9355 - 554ms/epoch - 79ms/step
# Epoch 1026/2000
#
# Epoch 1026: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 283253.4062 - val_loss: 6310.0757 - 517ms/epoch - 74ms/step
# Epoch 1027/2000
#
# Epoch 1027: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 317914.8750 - val_loss: 26612.7852 - 559ms/epoch - 80ms/step
# Epoch 1028/2000
#
# Epoch 1028: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 311155.4688 - val_loss: 18055.0820 - 521ms/epoch - 74ms/step
# Epoch 1029/2000
#
# Epoch 1029: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 308807.6250 - val_loss: 31623.7910 - 524ms/epoch - 75ms/step
# Epoch 1030/2000
#
# Epoch 1030: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 306683.5000 - val_loss: 13955.6348 - 539ms/epoch - 77ms/step
# Epoch 1031/2000
#
# Epoch 1031: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 295865.6875 - val_loss: 5999.7437 - 760ms/epoch - 109ms/step
# Epoch 1032/2000
#
# Epoch 1032: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 310206.9688 - val_loss: 29026.7969 - 1s/epoch - 169ms/step
# Epoch 1033/2000
#
# Epoch 1033: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 314103.6250 - val_loss: 7694.9351 - 1s/epoch - 157ms/step
# Epoch 1034/2000
#
# Epoch 1034: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 324581.1562 - val_loss: 10262.1846 - 1s/epoch - 148ms/step
# Epoch 1035/2000
#
# Epoch 1035: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 279744.8750 - val_loss: 16889.8945 - 1s/epoch - 172ms/step
# Epoch 1036/2000
#
# Epoch 1036: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 338920.7188 - val_loss: 56966.8555 - 890ms/epoch - 127ms/step
# Epoch 1037/2000
#
# Epoch 1037: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 289094.4062 - val_loss: 34429.9141 - 587ms/epoch - 84ms/step
# Epoch 1038/2000
#
# Epoch 1038: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 301041.5625 - val_loss: 7309.4019 - 533ms/epoch - 76ms/step
# Epoch 1039/2000
#
# Epoch 1039: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 317756.1562 - val_loss: 30573.5312 - 561ms/epoch - 80ms/step
# Epoch 1040/2000
#
# Epoch 1040: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 335338.2812 - val_loss: 7528.5815 - 544ms/epoch - 78ms/step
# Epoch 1041/2000
#
# Epoch 1041: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 322160.9688 - val_loss: 10063.3096 - 592ms/epoch - 85ms/step
# Epoch 1042/2000
#
# Epoch 1042: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 336646.7188 - val_loss: 19106.5430 - 542ms/epoch - 77ms/step
# Epoch 1043/2000
#
# Epoch 1043: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 365186.4062 - val_loss: 8660.1201 - 517ms/epoch - 74ms/step
# Epoch 1044/2000
#
# Epoch 1044: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 309830.5938 - val_loss: 33059.4883 - 529ms/epoch - 76ms/step
# Epoch 1045/2000
#
# Epoch 1045: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 317667.3125 - val_loss: 6865.6938 - 567ms/epoch - 81ms/step
# Epoch 1046/2000
#
# Epoch 1046: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 296312.4688 - val_loss: 40819.4570 - 524ms/epoch - 75ms/step
# Epoch 1047/2000
#
# Epoch 1047: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 329637.1562 - val_loss: 14365.3701 - 602ms/epoch - 86ms/step
# Epoch 1048/2000
#
# Epoch 1048: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 305904.4062 - val_loss: 19862.1777 - 549ms/epoch - 78ms/step
# Epoch 1049/2000
#
# Epoch 1049: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 327818.8750 - val_loss: 36010.0625 - 528ms/epoch - 75ms/step
# Epoch 1050/2000
#
# Epoch 1050: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 367610.8750 - val_loss: 12939.6162 - 545ms/epoch - 78ms/step
# Epoch 1051/2000
#
# Epoch 1051: loss did not improve from 262375.75000
# 7/7 - 0s - loss: 339302.6875 - val_loss: 33415.5117 - 497ms/epoch - 71ms/step
# Epoch 1052/2000
#
# Epoch 1052: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 336452.8125 - val_loss: 8850.5723 - 524ms/epoch - 75ms/step
# Epoch 1053/2000
#
# Epoch 1053: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 304705.8438 - val_loss: 18081.9395 - 504ms/epoch - 72ms/step
# Epoch 1054/2000
#
# Epoch 1054: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 318746.2500 - val_loss: 21589.3730 - 521ms/epoch - 74ms/step
# Epoch 1055/2000
#
# Epoch 1055: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 367446.6250 - val_loss: 16230.0332 - 725ms/epoch - 104ms/step
# Epoch 1056/2000
#
# Epoch 1056: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 296560.1562 - val_loss: 44260.7852 - 1s/epoch - 165ms/step
# Epoch 1057/2000
#
# Epoch 1057: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 314045.7812 - val_loss: 21343.4844 - 992ms/epoch - 142ms/step
# Epoch 1058/2000
#
# Epoch 1058: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 312726.1875 - val_loss: 16536.8516 - 1s/epoch - 146ms/step
# Epoch 1059/2000
#
# Epoch 1059: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 312689.6250 - val_loss: 45850.4648 - 877ms/epoch - 125ms/step
# Epoch 1060/2000
#
# Epoch 1060: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 267157.3750 - val_loss: 12479.2197 - 968ms/epoch - 138ms/step
# Epoch 1061/2000
#
# Epoch 1061: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 333119.1562 - val_loss: 52184.4805 - 789ms/epoch - 113ms/step
# Epoch 1062/2000
#
# Epoch 1062: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 307136.2812 - val_loss: 30856.4941 - 542ms/epoch - 77ms/step
# Epoch 1063/2000
#
# Epoch 1063: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 318005.1562 - val_loss: 32936.5664 - 552ms/epoch - 79ms/step
# Epoch 1064/2000
#
# Epoch 1064: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 307878.4688 - val_loss: 13262.8389 - 549ms/epoch - 78ms/step
# Epoch 1065/2000
#
# Epoch 1065: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 272919.0938 - val_loss: 22484.1738 - 535ms/epoch - 76ms/step
# Epoch 1066/2000
#
# Epoch 1066: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 297444.3125 - val_loss: 11182.7178 - 528ms/epoch - 75ms/step
# Epoch 1067/2000
#
# Epoch 1067: loss did not improve from 262375.75000
# 7/7 - 1s - loss: 323033.8125 - val_loss: 9916.3076 - 570ms/epoch - 81ms/step
# Epoch 1068/2000
#
# Epoch 1068: loss improved from 262375.75000 to 257324.03125, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 257324.0312 - val_loss: 49016.2539 - 797ms/epoch - 114ms/step
# Epoch 1069/2000
#
# Epoch 1069: loss did not improve from 257324.03125
# 7/7 - 1s - loss: 316068.9062 - val_loss: 24517.0391 - 568ms/epoch - 81ms/step
# Epoch 1070/2000
#
# Epoch 1070: loss did not improve from 257324.03125
# 7/7 - 1s - loss: 288666.2812 - val_loss: 17615.4922 - 504ms/epoch - 72ms/step
# Epoch 1071/2000
#
# Epoch 1071: loss did not improve from 257324.03125
# 7/7 - 1s - loss: 297081.3125 - val_loss: 11991.2090 - 566ms/epoch - 81ms/step
# Epoch 1072/2000
#
# Epoch 1072: loss did not improve from 257324.03125
# 7/7 - 1s - loss: 308003.5000 - val_loss: 17308.3691 - 523ms/epoch - 75ms/step
# Epoch 1073/2000
#
# Epoch 1073: loss did not improve from 257324.03125
# ...
# Epoch 1892/2000
#
# Epoch 1892: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 228932.7812 - val_loss: 7105.6670 - 606ms/epoch - 87ms/step
# Epoch 1893/2000
#
# Epoch 1893: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 216336.4219 - val_loss: 5596.5508 - 1s/epoch - 152ms/step
# Epoch 1894/2000
#
# Epoch 1894: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 226285.0156 - val_loss: 9999.5225 - 1s/epoch - 167ms/step
# Epoch 1895/2000
#
# Epoch 1895: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 234792.9062 - val_loss: 5648.7920 - 1s/epoch - 156ms/step
# Epoch 1896/2000
#
# Epoch 1896: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 225129.3594 - val_loss: 6117.7935 - 973ms/epoch - 139ms/step
# Epoch 1897/2000
#
# Epoch 1897: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 221070.7656 - val_loss: 6948.7876 - 994ms/epoch - 142ms/step
# Epoch 1898/2000
#
# Epoch 1898: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 200127.5312 - val_loss: 6057.4683 - 771ms/epoch - 110ms/step
# Epoch 1899/2000
#
# Epoch 1899: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 237256.6406 - val_loss: 12484.7295 - 538ms/epoch - 77ms/step
# Epoch 1900/2000
#
# Epoch 1900: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 253432.0781 - val_loss: 10593.1162 - 562ms/epoch - 80ms/step
# Epoch 1901/2000
#
# Epoch 1901: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 231929.3125 - val_loss: 8344.0029 - 586ms/epoch - 84ms/step
# Epoch 1902/2000
#
# Epoch 1902: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 215169.8438 - val_loss: 5912.0933 - 540ms/epoch - 77ms/step
# Epoch 1903/2000
#
# Epoch 1903: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 236937.2344 - val_loss: 16556.3887 - 532ms/epoch - 76ms/step
# Epoch 1904/2000
#
# Epoch 1904: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 197136.3438 - val_loss: 6174.4248 - 549ms/epoch - 78ms/step
# Epoch 1905/2000
#
# Epoch 1905: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 237522.5781 - val_loss: 19033.7773 - 550ms/epoch - 79ms/step
# Epoch 1906/2000
#
# Epoch 1906: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 222272.5469 - val_loss: 5341.3560 - 527ms/epoch - 75ms/step
# Epoch 1907/2000
#
# Epoch 1907: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 216324.2969 - val_loss: 5553.8374 - 544ms/epoch - 78ms/step
# Epoch 1908/2000
#
# Epoch 1908: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 203807.5938 - val_loss: 6407.2910 - 563ms/epoch - 80ms/step
# Epoch 1909/2000
#
# Epoch 1909: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 225055.0156 - val_loss: 7029.0117 - 525ms/epoch - 75ms/step
# Epoch 1910/2000
#
# Epoch 1910: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 238232.0312 - val_loss: 12550.4512 - 608ms/epoch - 87ms/step
# Epoch 1911/2000
#
# Epoch 1911: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 225560.5469 - val_loss: 8190.2773 - 525ms/epoch - 75ms/step
# Epoch 1912/2000
#
# Epoch 1912: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 208938.5938 - val_loss: 8623.1104 - 577ms/epoch - 82ms/step
# Epoch 1913/2000
#
# Epoch 1913: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 241197.2656 - val_loss: 11437.8555 - 542ms/epoch - 77ms/step
# Epoch 1914/2000
#
# Epoch 1914: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 233517.3594 - val_loss: 9161.1963 - 534ms/epoch - 76ms/step
# Epoch 1915/2000
#
# Epoch 1915: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 227701.3750 - val_loss: 8857.3438 - 508ms/epoch - 73ms/step
# Epoch 1916/2000
#
# Epoch 1916: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 216302.2031 - val_loss: 11441.2070 - 630ms/epoch - 90ms/step
# Epoch 1917/2000
#
# Epoch 1917: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 211461.1094 - val_loss: 5309.0068 - 973ms/epoch - 139ms/step
# Epoch 1918/2000
#
# Epoch 1918: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 213696.2188 - val_loss: 6779.4258 - 947ms/epoch - 135ms/step
# Epoch 1919/2000
#
# Epoch 1919: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 231672.3750 - val_loss: 7606.4126 - 1s/epoch - 152ms/step
# Epoch 1920/2000
#
# Epoch 1920: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 225435.0000 - val_loss: 7105.6973 - 911ms/epoch - 130ms/step
# Epoch 1921/2000
#
# Epoch 1921: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 214236.5938 - val_loss: 5526.6099 - 1s/epoch - 158ms/step
# Epoch 1922/2000
#
# Epoch 1922: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 211719.2344 - val_loss: 6594.7314 - 820ms/epoch - 117ms/step
# Epoch 1923/2000
#
# Epoch 1923: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 193088.0312 - val_loss: 5318.3784 - 531ms/epoch - 76ms/step
# Epoch 1924/2000
#
# Epoch 1924: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 213548.7656 - val_loss: 5212.3374 - 533ms/epoch - 76ms/step
# Epoch 1925/2000
#
# Epoch 1925: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 237174.1094 - val_loss: 13100.8838 - 606ms/epoch - 87ms/step
# Epoch 1926/2000
#
# Epoch 1926: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 196730.5625 - val_loss: 7893.6133 - 551ms/epoch - 79ms/step
# Epoch 1927/2000
#
# Epoch 1927: loss did not improve from 180728.64062
# 7/7 - 0s - loss: 195975.0781 - val_loss: 12116.5381 - 494ms/epoch - 71ms/step
# Epoch 1928/2000
#
# Epoch 1928: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 213700.9844 - val_loss: 13804.5000 - 544ms/epoch - 78ms/step
# Epoch 1929/2000
#
# Epoch 1929: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 208255.9531 - val_loss: 6420.4160 - 519ms/epoch - 74ms/step
# Epoch 1930/2000
#
# Epoch 1930: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 221810.7812 - val_loss: 7182.9653 - 533ms/epoch - 76ms/step
# Epoch 1931/2000
#
# Epoch 1931: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 211162.4375 - val_loss: 6346.2603 - 621ms/epoch - 89ms/step
# Epoch 1932/2000
#
# Epoch 1932: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 213420.9531 - val_loss: 5809.6494 - 544ms/epoch - 78ms/step
# Epoch 1933/2000
#
# Epoch 1933: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 247286.6406 - val_loss: 5758.4922 - 537ms/epoch - 77ms/step
# Epoch 1934/2000
#
# Epoch 1934: loss did not improve from 180728.64062
# 7/7 - 0s - loss: 256590.1562 - val_loss: 13348.1514 - 489ms/epoch - 70ms/step
# Epoch 1935/2000
#
# Epoch 1935: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 219665.0156 - val_loss: 5271.8291 - 522ms/epoch - 75ms/step
# Epoch 1936/2000
#
# Epoch 1936: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 209324.1875 - val_loss: 9635.1562 - 521ms/epoch - 74ms/step
# Epoch 1937/2000
#
# Epoch 1937: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 246936.7656 - val_loss: 8330.4531 - 542ms/epoch - 77ms/step
# Epoch 1938/2000
#
# Epoch 1938: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 242354.4688 - val_loss: 5899.4922 - 524ms/epoch - 75ms/step
# Epoch 1939/2000
#
# Epoch 1939: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 194833.0156 - val_loss: 18471.6426 - 527ms/epoch - 75ms/step
# Epoch 1940/2000
#
# Epoch 1940: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 233441.5156 - val_loss: 7546.0996 - 510ms/epoch - 73ms/step
# Epoch 1941/2000
#
# Epoch 1941: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 237995.2031 - val_loss: 27180.4434 - 869ms/epoch - 124ms/step
# Epoch 1942/2000
#
# Epoch 1942: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 205966.2500 - val_loss: 9773.2197 - 1s/epoch - 160ms/step
# Epoch 1943/2000
#
# Epoch 1943: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 217351.1094 - val_loss: 10196.0791 - 1s/epoch - 162ms/step
# Epoch 1944/2000
#
# Epoch 1944: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 237801.7812 - val_loss: 5100.6997 - 994ms/epoch - 142ms/step
# Epoch 1945/2000
#
# Epoch 1945: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 241430.4844 - val_loss: 5254.5405 - 1s/epoch - 155ms/step
# Epoch 1946/2000
#
# Epoch 1946: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 217990.4531 - val_loss: 9165.3027 - 888ms/epoch - 127ms/step
# Epoch 1947/2000
#
# Epoch 1947: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 197471.7812 - val_loss: 6072.8730 - 563ms/epoch - 80ms/step
# Epoch 1948/2000
#
# Epoch 1948: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 223770.0000 - val_loss: 6588.4692 - 520ms/epoch - 74ms/step
# Epoch 1949/2000
#
# Epoch 1949: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 226415.8906 - val_loss: 8843.9814 - 519ms/epoch - 74ms/step
# Epoch 1950/2000
#
# Epoch 1950: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 239903.7656 - val_loss: 5905.3647 - 514ms/epoch - 73ms/step
# Epoch 1951/2000
#
# Epoch 1951: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 217528.7656 - val_loss: 6552.3579 - 524ms/epoch - 75ms/step
# Epoch 1952/2000
#
# Epoch 1952: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 218911.4531 - val_loss: 9147.7012 - 529ms/epoch - 76ms/step
# Epoch 1953/2000
#
# Epoch 1953: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 226457.3125 - val_loss: 16591.0098 - 579ms/epoch - 83ms/step
# Epoch 1954/2000
#
# Epoch 1954: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 256993.4844 - val_loss: 6035.2749 - 540ms/epoch - 77ms/step
# Epoch 1955/2000
#
# Epoch 1955: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 230912.2656 - val_loss: 6543.9131 - 533ms/epoch - 76ms/step
# Epoch 1956/2000
#
# Epoch 1956: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 215635.7812 - val_loss: 9978.6250 - 538ms/epoch - 77ms/step
# Epoch 1957/2000
#
# Epoch 1957: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 241858.6250 - val_loss: 9630.0059 - 541ms/epoch - 77ms/step
# Epoch 1958/2000
#
# Epoch 1958: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 245325.6406 - val_loss: 7071.2168 - 567ms/epoch - 81ms/step
# Epoch 1959/2000
#
# Epoch 1959: loss did not improve from 180728.64062
# 7/7 - 0s - loss: 251203.4531 - val_loss: 5879.7422 - 486ms/epoch - 69ms/step
# Epoch 1960/2000
#
# Epoch 1960: loss did not improve from 180728.64062
# 7/7 - 0s - loss: 232222.9688 - val_loss: 5521.1309 - 494ms/epoch - 71ms/step
# Epoch 1961/2000
#
# Epoch 1961: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 226078.7969 - val_loss: 6105.8940 - 510ms/epoch - 73ms/step
# Epoch 1962/2000
#
# Epoch 1962: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 209272.3594 - val_loss: 6821.7437 - 526ms/epoch - 75ms/step
# Epoch 1963/2000
#
# Epoch 1963: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 198050.9062 - val_loss: 5552.4878 - 536ms/epoch - 77ms/step
# Epoch 1964/2000
#
# Epoch 1964: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 226526.3125 - val_loss: 5735.1577 - 567ms/epoch - 81ms/step
# Epoch 1965/2000
#
# Epoch 1965: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 227699.3594 - val_loss: 10684.7061 - 629ms/epoch - 90ms/step
# Epoch 1966/2000
#
# Epoch 1966: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 217610.6250 - val_loss: 13309.1152 - 1s/epoch - 169ms/step
# Epoch 1967/2000
#
# Epoch 1967: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 212096.6250 - val_loss: 5717.1128 - 1s/epoch - 155ms/step
# Epoch 1968/2000
#
# Epoch 1968: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 243016.4844 - val_loss: 5595.5015 - 1s/epoch - 161ms/step
# Epoch 1969/2000
#
# Epoch 1969: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 225802.2188 - val_loss: 15221.7754 - 945ms/epoch - 135ms/step
# Epoch 1970/2000
#
# Epoch 1970: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 220117.7812 - val_loss: 8507.2285 - 1s/epoch - 149ms/step
# Epoch 1971/2000
#
# Epoch 1971: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 218913.2969 - val_loss: 5550.9438 - 750ms/epoch - 107ms/step
# Epoch 1972/2000
#
# Epoch 1972: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 232089.4062 - val_loss: 7202.2002 - 509ms/epoch - 73ms/step
# Epoch 1973/2000
#
# Epoch 1973: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 214601.2344 - val_loss: 11480.7529 - 504ms/epoch - 72ms/step
# Epoch 1974/2000
#
# Epoch 1974: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 236450.3594 - val_loss: 10455.3926 - 511ms/epoch - 73ms/step
# Epoch 1975/2000
#
# Epoch 1975: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 239033.3750 - val_loss: 5813.3433 - 527ms/epoch - 75ms/step
# Epoch 1976/2000
#
# Epoch 1976: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 198765.1875 - val_loss: 6970.1250 - 602ms/epoch - 86ms/step
# Epoch 1977/2000
#
# Epoch 1977: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 218766.5156 - val_loss: 8103.4707 - 512ms/epoch - 73ms/step
# Epoch 1978/2000
#
# Epoch 1978: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 226257.1250 - val_loss: 8883.1914 - 508ms/epoch - 73ms/step
# Epoch 1979/2000
#
# Epoch 1979: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 224525.8438 - val_loss: 7668.7246 - 511ms/epoch - 73ms/step
# Epoch 1980/2000
#
# Epoch 1980: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 250186.1094 - val_loss: 11861.5908 - 541ms/epoch - 77ms/step
# Epoch 1981/2000
#
# Epoch 1981: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 206091.6719 - val_loss: 15947.2656 - 505ms/epoch - 72ms/step
# Epoch 1982/2000
#
# Epoch 1982: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 247218.3750 - val_loss: 6990.1982 - 503ms/epoch - 72ms/step
# Epoch 1983/2000
#
# Epoch 1983: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 199986.8438 - val_loss: 13989.1758 - 521ms/epoch - 74ms/step
# Epoch 1984/2000
#
# Epoch 1984: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 203588.6719 - val_loss: 7451.4810 - 563ms/epoch - 80ms/step
# Epoch 1985/2000
#
# Epoch 1985: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 231326.3281 - val_loss: 8792.4424 - 611ms/epoch - 87ms/step
# Epoch 1986/2000
#
# Epoch 1986: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 243044.7344 - val_loss: 5250.0332 - 527ms/epoch - 75ms/step
# Epoch 1987/2000
#
# Epoch 1987: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 210879.6250 - val_loss: 6234.9985 - 575ms/epoch - 82ms/step
# Epoch 1988/2000
#
# Epoch 1988: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 208791.0469 - val_loss: 15001.1055 - 563ms/epoch - 80ms/step
# Epoch 1989/2000
#
# Epoch 1989: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 230174.5938 - val_loss: 6692.1685 - 530ms/epoch - 76ms/step
# Epoch 1990/2000
#
# Epoch 1990: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 199000.8594 - val_loss: 8446.8652 - 1s/epoch - 150ms/step
# Epoch 1991/2000
#
# Epoch 1991: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 199909.7812 - val_loss: 6660.9995 - 1s/epoch - 163ms/step
# Epoch 1992/2000
#
# Epoch 1992: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 241596.0781 - val_loss: 6200.9561 - 1s/epoch - 153ms/step
# Epoch 1993/2000
#
# Epoch 1993: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 238604.5469 - val_loss: 6875.7563 - 1s/epoch - 155ms/step
# Epoch 1994/2000
#
# Epoch 1994: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 210686.7969 - val_loss: 11259.2334 - 1s/epoch - 161ms/step
# Epoch 1995/2000
#
# Epoch 1995: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 225370.7656 - val_loss: 10468.1035 - 812ms/epoch - 116ms/step
# Epoch 1996/2000
#
# Epoch 1996: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 239998.8906 - val_loss: 10044.6797 - 531ms/epoch - 76ms/step
# Epoch 1997/2000
#
# Epoch 1997: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 211380.5781 - val_loss: 6247.6416 - 532ms/epoch - 76ms/step
# Epoch 1998/2000
#
# Epoch 1998: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 210302.2969 - val_loss: 7854.3774 - 514ms/epoch - 73ms/step
# Epoch 1999/2000
#
# Epoch 1999: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 224664.4062 - val_loss: 8266.6943 - 550ms/epoch - 79ms/step
# Epoch 2000/2000
#
# Epoch 2000: loss did not improve from 180728.64062
# 7/7 - 1s - loss: 199140.4688 - val_loss: 5783.4438 - 528ms/epoch - 75ms/step
# 16/16 [==============================] - 1s 10ms/step
# 3/3 [==============================] - 0s 19ms/step
# Training MSE: 7359.029656570849
# Testing MSE: 20030.70018896464
# accuracy : 57
