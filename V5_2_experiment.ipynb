# %% [markdown]
# <a href="https://colab.research.google.com/github/hj2222222/API/blob/main/V5_2_experiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import math
import matplotlib.pyplot as plt
import keras
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras import optimizers
from tensorflow.keras.layers import LSTM, Dropout, Dense, Conv1D, MaxPooling1D, Flatten
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Bidirectional
from keras.layers import Dropout, Flatten,TimeDistributed
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from tensorflow.keras.losses import Huber
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


stock_data = pd.read_csv('/content/drive/MyDrive/산업 AI 캡스톤/DATA/Total_Data/Final_Feature_kospi_sen_all.csv')
stock_data
# Out:
#          Date  Kospi_close  Kospi_high  ko_interest  oil_open  ex_JP_low  \
# 0    20210105      2990.57       0.795          0.0     0.213      0.590
# 1    20210106      2968.21       0.819          0.0     0.219      0.596
# 2    20210107      3031.68       0.839          0.0     0.225      0.597
# 3    20210108      3152.18       0.855          0.0     0.230      0.584
# 4    20210111      3148.45       0.914          0.0     0.232      0.584
# ..        ...          ...         ...          ...       ...        ...
# 583  20230623      2570.10       0.601          1.0     0.651      0.028
# 584  20230626      2582.20       0.602          1.0     0.651      0.024
# 585  20230627      2581.39       0.594          1.0     0.651      0.000
# 586  20230628      2564.19       0.592          1.0     0.651      0.011
# 587  20230629      2550.02       0.597          1.0     0.651      0.020
#
#      gold_low  us500_low  klue_bert_score_summarize_content  oil_vol  \
# 0       0.661      0.581                             -0.536    0.013
# 1       0.650      0.585                              1.381    0.006
# 2       0.670      0.608                              1.845    0.007
# 3       0.631      0.615                              2.497    0.004
# 4       0.623      0.617                             -0.951    0.009
# ..        ...        ...                                ...      ...
# 583     0.212      0.830                              0.402    0.000
# 584     0.212      0.825                             -0.385    0.000
# 585     0.208      0.828                             -0.447    0.000
# 586     0.217      0.838                              0.777    0.000
# 587     0.208      0.842                             -0.038    0.000
#
#      research_kospi  dji_vol  us500_vol  \
# 0             0.413    0.280      0.349
# 1             0.628    0.470      0.527
# 2             0.427    0.378      0.410
# 3             0.512    0.318      0.371
# 4             0.881    0.287      0.334
# ..              ...      ...        ...
# 583           0.125    0.316      0.526
# 584           0.120    0.170      0.207
# 585           0.118    0.206      0.226
# 586           0.128    0.174      0.246
# 587           0.127    0.189      0.241
#
#      kofinbert_score_summarize_content_kospi  kofinbert_score_title_kospi  \
# 0                                      0.157                        0.195
# 1                                      1.236                        0.569
# 2                                      0.537                        1.395
# 3                                      0.697                       -1.382
# 4                                      0.331                       -0.044
# ..                                       ...                          ...
# 583                                    0.834                       -0.339
# 584                                   -0.196                        0.681
# 585                                   -0.208                        0.625
# 586                                    1.099                        0.892
# 587                                    0.382                       -0.145
#
#      klue_bert_score_title
# 0                    0.823
# 1                    0.722
# 2                   -0.675
# 3                    1.124
# 4                    0.730
# ..                     ...
# 583                  0.831
# 584                 -0.001
# 585                 -0.097
# 586                  0.253
# 587                 -0.378
#
# [588 rows x 16 columns]

# %%
# 데이터 전처리
data = stock_data['Kospi_close'].values.reshape(-1, 1)
stock_data = stock_data.drop(['Kospi_close'],axis=1)
stock_data = stock_data.drop(['Date'],axis=1)

# %%
name = [stock_data.columns]

close_1 = ['klue_bert_score_summarize_content',
        'kofinbert_score_summarize_content_kospi']

stock_data_1 = stock_data.drop(close_1, axis=1)

# %%
# 데이터 분할
train_size = int(len(data) * 0.85)
train_data, test_data = data[:train_size], data[train_size:]
train_data_t_1, test_data_t_1 = stock_data_1[:train_size], stock_data_1[train_size:]
train_data_t_2, test_data_t_2 = stock_data[:train_size], stock_data[train_size:]

def create_dataset(dataset, data, look_back=10):
    X, y = [], []
    for i in range(len(data) - look_back):
        X.append(dataset[i:(i + look_back)])
        y.append(data[i + look_back])
    return np.array(X), np.array(y)

look_back = 10  # 몇 일 동안의 데이터를 사용할 것인지 설정

trainX, trainY = create_dataset(train_data_t_1, train_data, look_back)
testX, testY = create_dataset(test_data_t_1,test_data, look_back)
print(trainX.shape)
print(trainY.shape)
print(testX.shape)
print(testY.shape)
# Out:
# (489, 10, 12)
# (489, 1)
# (79, 10, 12)
# (79, 1)

# %%
def accuracy(list1,list2):
  list1 = list1.flatten().tolist()
  list2 = list2.flatten().tolist()
  value_1 = []
  value_2 = []
  j = 0
  if len(list1) == len(list2):
    for i in range(len(list1)-1):
      if list1[i+1] > list1[i]:
        value_1.append(1)
      elif list1[i+1] == list1[i]:
        value_1.append(0)
      else:
        value_1.append(-1)
    for i in range(len(list1)-1):
      if list2[i+1] > list2[i]:
        value_2.append(1)
      elif list2[i+1] == list2[i]:
        value_2.append(0)
      else:
        value_2.append(-1)
    for i in range(len(value_1)):
      if value_1[i] == value_2[i]:
        j = j + 1
    accuracy = j/len(value_1) * 100
    print("accuracy : %d" % accuracy)
  else:
    print("길이가 다릅니다.")

# %%
# 모델 생성 GRU+CNN
model = Sequential()
model.add(Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(MaxPooling1D(pool_size=2))
model.add(GRU(units=1024, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=512, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=256, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=128, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=64, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=32, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=16, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(units=1))
model.summary()


# loss = Huber()
# optimizer = Adam(0.0005)
# model.compile(loss=Huber(), optimizer=optimizer, metrics=['mse'])
model.compile(optimizer='adam', loss='mean_squared_error')

filename = os.path.join('tmp', 'ckeckpointer.ckpt')
checkpoint = ModelCheckpoint(filename,
                             save_weights_only=True,
                             save_best_only=True,
                             monitor='loss',
                             verbose=1)

# 모델 학습
history = model.fit(trainX, trainY, epochs=2000, batch_size=64,
          validation_split=0.1, verbose=2,callbacks=[checkpoint])

model.save_weights('./ko_sum_CNN_GRU__weights.h2')

model.load_weights(filename)

plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()
plt.show()

# 예측
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# MSE 계산
trainMSE = mean_squared_error(trainY, trainPredict)
testMSE = mean_squared_error(testY, testPredict)

print(f'Training MSE: {trainMSE}')
print(f'Testing MSE: {testMSE}')

accuracy(testPredict,testY)

# 예측 시각화
plt.plot(trainY, label='Actual Price')
plt.plot(trainPredict, label='Predicted Price')
plt.legend()
plt.title('Training Data')
plt.show()

plt.plot(testY, label='Actual Price')
plt.plot(testPredict, label='Predicted Price')
plt.legend()
plt.title('Testing Data')
plt.show()
# Out:
# WARNING:tensorflow:Layer gru_28 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_29 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_30 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_31 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_32 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_33 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_34 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Epoch 751/2000
#
# Epoch 751: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 270960.5000 - val_loss: 18070.2227 - 527ms/epoch - 75ms/step
# Epoch 752/2000
#
# Epoch 752: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 309318.2188 - val_loss: 20826.7988 - 505ms/epoch - 72ms/step
# Epoch 753/2000
#
# Epoch 753: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 307688.1875 - val_loss: 14434.1172 - 516ms/epoch - 74ms/step
# Epoch 754/2000
#
# Epoch 754: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 315933.8125 - val_loss: 11490.4883 - 521ms/epoch - 74ms/step
# Epoch 755/2000
#
# Epoch 755: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 300090.9688 - val_loss: 24573.0996 - 514ms/epoch - 73ms/step
# Epoch 756/2000
#
# Epoch 756: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 308014.4375 - val_loss: 11584.1709 - 506ms/epoch - 72ms/step
# Epoch 757/2000
#
# Epoch 757: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 302298.4688 - val_loss: 14146.7422 - 527ms/epoch - 75ms/step
# Epoch 758/2000
#
# Epoch 758: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 313835.9375 - val_loss: 34974.5820 - 562ms/epoch - 80ms/step
# Epoch 759/2000
#
# Epoch 759: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 327101.9062 - val_loss: 9878.1592 - 526ms/epoch - 75ms/step
# Epoch 760/2000
#
# Epoch 760: loss did not improve from 257171.56250
# 7/7 - 0s - loss: 328498.1562 - val_loss: 31130.9492 - 493ms/epoch - 70ms/step
# Epoch 761/2000
#
# Epoch 761: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 296867.6250 - val_loss: 14766.3174 - 547ms/epoch - 78ms/step
# Epoch 762/2000
#
# Epoch 762: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 311600.8125 - val_loss: 10087.8721 - 503ms/epoch - 72ms/step
# Epoch 763/2000
#
# Epoch 763: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 363637.3438 - val_loss: 27546.9160 - 518ms/epoch - 74ms/step
# Epoch 764/2000
#
# Epoch 764: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 298161.6250 - val_loss: 6372.2305 - 520ms/epoch - 74ms/step
# Epoch 765/2000
#
# Epoch 765: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 304373.1875 - val_loss: 30096.8066 - 570ms/epoch - 81ms/step
# Epoch 766/2000
#
# Epoch 766: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 339836.4062 - val_loss: 32174.2402 - 522ms/epoch - 75ms/step
# Epoch 767/2000
#
# Epoch 767: loss did not improve from 257171.56250
# 7/7 - 0s - loss: 325240.1875 - val_loss: 17385.3262 - 482ms/epoch - 69ms/step
# Epoch 768/2000
#
# Epoch 768: loss did not improve from 257171.56250
# 7/7 - 0s - loss: 299910.7188 - val_loss: 6597.1167 - 496ms/epoch - 71ms/step
# Epoch 769/2000
#
# Epoch 769: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 348584.6250 - val_loss: 22810.4141 - 774ms/epoch - 111ms/step
# Epoch 770/2000
#
# Epoch 770: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 294915.3125 - val_loss: 32620.7520 - 1s/epoch - 153ms/step
# Epoch 771/2000
#
# Epoch 771: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 284589.7500 - val_loss: 59347.9375 - 1s/epoch - 151ms/step
# Epoch 772/2000
#
# Epoch 772: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 342304.7188 - val_loss: 20502.0352 - 1s/epoch - 151ms/step
# Epoch 773/2000
#
# Epoch 773: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 309746.5000 - val_loss: 19142.1406 - 1s/epoch - 147ms/step
# Epoch 774/2000
#
# Epoch 774: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 287299.3438 - val_loss: 12573.1572 - 1s/epoch - 143ms/step
# Epoch 775/2000
#
# Epoch 775: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 277122.0312 - val_loss: 23760.6973 - 531ms/epoch - 76ms/step
# Epoch 776/2000
#
# Epoch 776: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 293574.1250 - val_loss: 19967.1484 - 500ms/epoch - 71ms/step
# Epoch 777/2000
#
# Epoch 777: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 285642.4375 - val_loss: 14982.5049 - 527ms/epoch - 75ms/step
# Epoch 778/2000
#
# Epoch 778: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 292331.4062 - val_loss: 19844.8184 - 558ms/epoch - 80ms/step
# Epoch 779/2000
#
# Epoch 779: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 291228.6562 - val_loss: 17465.9824 - 564ms/epoch - 81ms/step
# Epoch 780/2000
#
# Epoch 780: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 293229.6875 - val_loss: 24157.0254 - 535ms/epoch - 76ms/step
# Epoch 781/2000
#
# Epoch 781: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 311802.2188 - val_loss: 40742.0039 - 525ms/epoch - 75ms/step
# Epoch 782/2000
#
# Epoch 782: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 295527.6875 - val_loss: 20595.1348 - 511ms/epoch - 73ms/step
# Epoch 783/2000
#
# Epoch 783: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 294074.0625 - val_loss: 28811.7188 - 545ms/epoch - 78ms/step
# Epoch 784/2000
#
# Epoch 784: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 298788.6562 - val_loss: 20709.2539 - 510ms/epoch - 73ms/step
# Epoch 785/2000
#
# Epoch 785: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 322991.2812 - val_loss: 5852.2935 - 533ms/epoch - 76ms/step
# Epoch 786/2000
#
# Epoch 786: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 314565.2500 - val_loss: 11095.6084 - 502ms/epoch - 72ms/step
# Epoch 787/2000
#
# Epoch 787: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 286855.2812 - val_loss: 22291.9492 - 528ms/epoch - 75ms/step
# Epoch 788/2000
#
# Epoch 788: loss did not improve from 257171.56250
# 7/7 - 0s - loss: 286451.6875 - val_loss: 13216.2549 - 494ms/epoch - 71ms/step
# Epoch 789/2000
#
# Epoch 789: loss did not improve from 257171.56250
# 7/7 - 0s - loss: 334808.2188 - val_loss: 10927.7139 - 481ms/epoch - 69ms/step
# Epoch 790/2000
#
# Epoch 790: loss did not improve from 257171.56250
# 7/7 - 0s - loss: 278935.9062 - val_loss: 5528.6108 - 491ms/epoch - 70ms/step
# Epoch 791/2000
#
# Epoch 791: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 273198.2500 - val_loss: 21338.3691 - 502ms/epoch - 72ms/step
# Epoch 792/2000
#
# Epoch 792: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 330426.3750 - val_loss: 8307.5859 - 528ms/epoch - 75ms/step
# Epoch 793/2000
#
# Epoch 793: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 322739.3750 - val_loss: 35665.1875 - 507ms/epoch - 72ms/step
# Epoch 794/2000
#
# Epoch 794: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 330326.4375 - val_loss: 5760.8008 - 1s/epoch - 156ms/step
# Epoch 795/2000
#
# Epoch 795: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 316409.9375 - val_loss: 5399.8892 - 1s/epoch - 147ms/step
# Epoch 796/2000
#
# Epoch 796: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 307230.9375 - val_loss: 9896.4277 - 1s/epoch - 164ms/step
# Epoch 797/2000
#
# Epoch 797: loss did not improve from 257171.56250
# 7/7 - 1s - loss: 312414.2500 - val_loss: 6478.1172 - 960ms/epoch - 137ms/step
# Epoch 798/2000
#
# Epoch 798: loss improved from 257171.56250 to 255071.34375, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 255071.3438 - val_loss: 5185.4019 - 1s/epoch - 204ms/step
# Epoch 799/2000
#
# Epoch 799: loss did not improve from 255071.34375
# 7/7 - 1s - loss: 311031.5938 - val_loss: 12219.4238 - 610ms/epoch - 87ms/step
# Epoch 800/2000
#
# Epoch 800: loss did not improve from 255071.34375
# 7/7 - 1s - loss: 327906.6562 - val_loss: 26969.7402 - 525ms/epoch - 75ms/step
# Epoch 801/2000
#
# Epoch 801: loss did not improve from 255071.34375
# 7/7 - 1s - loss: 293758.9062 - val_loss: 14750.2568 - 532ms/epoch - 76ms/step
# Epoch 802/2000
#
# Epoch 802: loss did not improve from 255071.34375
# 7/7 - 1s - loss: 275944.7812 - val_loss: 14758.4443 - 527ms/epoch - 75ms/step
# Epoch 803/2000
#
# Epoch 803: loss did not improve from 255071.34375
# 7/7 - 1s - loss: 263065.0938 - val_loss: 25013.2441 - 534ms/epoch - 76ms/step
# Epoch 804/2000
#
# Epoch 804: loss did not improve from 255071.34375
# 7/7 - 1s - loss: 283228.6250 - val_loss: 11903.8701 - 516ms/epoch - 74ms/step
# Epoch 805/2000
#
# Epoch 805: loss did not improve from 255071.34375
# 7/7 - 1s - loss: 288769.6875 - val_loss: 16276.8467 - 525ms/epoch - 75ms/step
# Epoch 806/2000
#
# Epoch 806: loss did not improve from 255071.34375
# 7/7 - 1s - loss: 290538.5000 - val_loss: 6747.4541 - 542ms/epoch - 77ms/step
# Epoch 807/2000
#
# Epoch 807: loss improved from 255071.34375 to 243045.75000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 243045.7500 - val_loss: 37751.4414 - 765ms/epoch - 109ms/step
# Epoch 808/2000
#
# Epoch 808: loss did not improve from 243045.75000
# 7/7 - 1s - loss: 276895.3750 - val_loss: 18299.7930 - 555ms/epoch - 79ms/step
# Epoch 809/2000
#
# Epoch 809: loss did not improve from 243045.75000
# 7/7 - 1s - loss: 325785.9688 - val_loss: 29491.4277 - 508ms/epoch - 73ms/step
# Epoch 810/2000
#
# Epoch 810: loss did not improve from 243045.75000
# 7/7 - 1s - loss: 322184.7188 - val_loss: 10185.5547 - 564ms/epoch - 81ms/step
# Epoch 811/2000
#
# Epoch 811: loss did not improve from 243045.75000
# 7/7 - 1s - loss: 273548.7500 - val_loss: 5937.3901 - 550ms/epoch - 79ms/step
# Epoch 812/2000
#
# Epoch 812: loss did not improve from 243045.75000
# 7/7 - 1s - loss: 248343.9062 - val_loss: 24113.4180 - 519ms/epoch - 74ms/step
# Epoch 813/2000
#
# Epoch 813: loss did not improve from 243045.75000
# 7/7 - 1s - loss: 274050.7812 - val_loss: 28449.4590 - 564ms/epoch - 81ms/step
# Epoch 814/2000
#
# Epoch 814: loss did not improve from 243045.75000
# 7/7 - 0s - loss: 335804.6875 - val_loss: 14870.8984 - 493ms/epoch - 70ms/step
# Epoch 815/2000
#
# Epoch 815: loss did not improve from 243045.75000
# 7/7 - 1s - loss: 272024.4375 - val_loss: 20008.4668 - 527ms/epoch - 75ms/step
# Epoch 816/2000
#
# Epoch 816: loss did not improve from 243045.75000
# 7/7 - 1s - loss: 276105.6250 - val_loss: 9148.6924 - 519ms/epoch - 74ms/step
# Epoch 817/2000
#
# Epoch 817: loss did not improve from 243045.75000
# 7/7 - 1s - loss: 287149.0312 - val_loss: 24493.1836 - 687ms/epoch - 98ms/step
# Epoch 818/2000
#
# Epoch 818: loss did not improve from 243045.75000
# 7/7 - 1s - loss: 255845.8125 - val_loss: 28334.3008 - 999ms/epoch - 143ms/step
# Epoch 819/2000
#
# Epoch 819: loss did not improve from 243045.75000
# 7/7 - 1s - loss: 259186.8750 - val_loss: 7709.4683 - 1s/epoch - 149ms/step
# Epoch 820/2000
#
# Epoch 820: loss did not improve from 243045.75000
# 7/7 - 1s - loss: 294760.5938 - val_loss: 5923.3188 - 1s/epoch - 143ms/step
# Epoch 821/2000
#
# Epoch 821: loss did not improve from 243045.75000
# 7/7 - 1s - loss: 284841.0000 - val_loss: 12192.0303 - 952ms/epoch - 136ms/step
# Epoch 822/2000
#
# Epoch 822: loss did not improve from 243045.75000
# 7/7 - 1s - loss: 269138.6875 - val_loss: 9531.7256 - 999ms/epoch - 143ms/step
# Epoch 823/2000
#
# Epoch 823: loss did not improve from 243045.75000
# 7/7 - 1s - loss: 261444.6562 - val_loss: 6376.1680 - 702ms/epoch - 100ms/step
# Epoch 824/2000
#
# Epoch 824: loss did not improve from 243045.75000
# 7/7 - 1s - loss: 281304.9688 - val_loss: 10285.0723 - 592ms/epoch - 85ms/step
# Epoch 825/2000
#
# Epoch 825: loss did not improve from 243045.75000
# 7/7 - 1s - loss: 312528.0312 - val_loss: 13144.4619 - 523ms/epoch - 75ms/step
# Epoch 826/2000
#
# Epoch 826: loss did not improve from 243045.75000
# 7/7 - 1s - loss: 260359.9844 - val_loss: 8864.9912 - 521ms/epoch - 74ms/step
# Epoch 827/2000
#
# Epoch 827: loss did not improve from 243045.75000
# 7/7 - 1s - loss: 307220.2188 - val_loss: 30253.4648 - 511ms/epoch - 73ms/step
# Epoch 828/2000
#
# Epoch 828: loss did not improve from 243045.75000
# 7/7 - 1s - loss: 283683.0312 - val_loss: 13074.3418 - 517ms/epoch - 74ms/step
# Epoch 829/2000
#
# Epoch 829: loss did not improve from 243045.75000
# 7/7 - 1s - loss: 279955.0312 - val_loss: 17837.4492 - 510ms/epoch - 73ms/step
# Epoch 830/2000
#
# Epoch 830: loss did not improve from 243045.75000
# 7/7 - 1s - loss: 305464.4375 - val_loss: 26092.2695 - 538ms/epoch - 77ms/step
# Epoch 831/2000
#
# Epoch 831: loss did not improve from 243045.75000
# 7/7 - 1s - loss: 287504.0938 - val_loss: 11892.5010 - 1s/epoch - 147ms/step
# Epoch 832/2000
#
# Epoch 832: loss did not improve from 243045.75000
# 7/7 - 1s - loss: 308084.8125 - val_loss: 6244.2007 - 1s/epoch - 148ms/step
# Epoch 833/2000
#
# Epoch 833: loss did not improve from 243045.75000
# 7/7 - 1s - loss: 265334.7500 - val_loss: 15652.6553 - 1s/epoch - 162ms/step
# Epoch 834/2000
#
# Epoch 834: loss did not improve from 243045.75000
# 7/7 - 1s - loss: 269855.2812 - val_loss: 6079.8359 - 1s/epoch - 152ms/step
# Epoch 835/2000
#
# Epoch 835: loss did not improve from 243045.75000
# 7/7 - 1s - loss: 316355.9375 - val_loss: 6649.0820 - 1s/epoch - 155ms/step
# Epoch 836/2000
#
# Epoch 836: loss improved from 243045.75000 to 240654.75000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 240654.7500 - val_loss: 21071.6602 - 1s/epoch - 176ms/step
# Epoch 837/2000
#
# Epoch 837: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 255714.4375 - val_loss: 14253.4570 - 970ms/epoch - 139ms/step
# Epoch 838/2000
#
# Epoch 838: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 286586.6875 - val_loss: 12238.6943 - 1s/epoch - 152ms/step
# Epoch 839/2000
#
# Epoch 839: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 326556.0000 - val_loss: 25896.6172 - 1s/epoch - 151ms/step
# Epoch 840/2000
#
# Epoch 840: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 280185.5312 - val_loss: 5616.5820 - 987ms/epoch - 141ms/step
# Epoch 841/2000
#
# Epoch 841: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 266193.5312 - val_loss: 55898.4883 - 992ms/epoch - 142ms/step
# Epoch 842/2000
#
# Epoch 842: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 272265.1875 - val_loss: 6657.6924 - 638ms/epoch - 91ms/step
# Epoch 843/2000
#
# Epoch 843: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 260716.4844 - val_loss: 16911.0391 - 560ms/epoch - 80ms/step
# Epoch 844/2000
#
# Epoch 844: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 285896.6875 - val_loss: 23091.1504 - 529ms/epoch - 76ms/step
# Epoch 845/2000
#
# Epoch 845: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 273975.5000 - val_loss: 6951.5723 - 503ms/epoch - 72ms/step
# Epoch 846/2000
#
# Epoch 846: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 277700.6250 - val_loss: 14472.4072 - 580ms/epoch - 83ms/step
# Epoch 847/2000
#
# Epoch 847: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 273190.5312 - val_loss: 18559.3672 - 523ms/epoch - 75ms/step
# Epoch 848/2000
#
# Epoch 848: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 300354.6250 - val_loss: 27781.5859 - 579ms/epoch - 83ms/step
# Epoch 849/2000
#
# Epoch 849: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 269369.5938 - val_loss: 10898.3984 - 527ms/epoch - 75ms/step
# Epoch 850/2000
#
# Epoch 850: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 277282.0625 - val_loss: 22988.3223 - 564ms/epoch - 81ms/step
# Epoch 851/2000
#
# Epoch 851: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 293761.2500 - val_loss: 7121.6377 - 513ms/epoch - 73ms/step
# Epoch 852/2000
#
# Epoch 852: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 251237.7500 - val_loss: 18878.3320 - 506ms/epoch - 72ms/step
# Epoch 853/2000
#
# Epoch 853: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 257513.5156 - val_loss: 5663.1953 - 554ms/epoch - 79ms/step
# Epoch 854/2000
#
# Epoch 854: loss did not improve from 240654.75000
# 7/7 - 0s - loss: 288263.8438 - val_loss: 9091.5293 - 489ms/epoch - 70ms/step
# Epoch 855/2000
#
# Epoch 855: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 293443.7188 - val_loss: 12237.5068 - 539ms/epoch - 77ms/step
# Epoch 856/2000
#
# Epoch 856: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 254132.1406 - val_loss: 11170.9619 - 588ms/epoch - 84ms/step
# Epoch 857/2000
#
# Epoch 857: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 274895.3438 - val_loss: 6458.3062 - 571ms/epoch - 82ms/step
# Epoch 858/2000
#
# Epoch 858: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 317849.6875 - val_loss: 7908.0498 - 545ms/epoch - 78ms/step
# Epoch 859/2000
#
# Epoch 859: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 247507.4062 - val_loss: 33383.4180 - 535ms/epoch - 76ms/step
# Epoch 860/2000
#
# Epoch 860: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 294390.2812 - val_loss: 5644.2139 - 726ms/epoch - 104ms/step
# Epoch 861/2000
#
# Epoch 861: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 316930.6562 - val_loss: 24499.6836 - 1s/epoch - 160ms/step
# Epoch 862/2000
#
# Epoch 862: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 303261.5000 - val_loss: 26622.4746 - 943ms/epoch - 135ms/step
# Epoch 863/2000
#
# Epoch 863: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 285973.1562 - val_loss: 21583.9219 - 1s/epoch - 151ms/step
# Epoch 864/2000
#
# Epoch 864: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 273684.1875 - val_loss: 6792.4048 - 1s/epoch - 147ms/step
# Epoch 865/2000
#
# Epoch 865: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 319775.3125 - val_loss: 42924.0391 - 875ms/epoch - 125ms/step
# Epoch 866/2000
#
# Epoch 866: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 312594.2188 - val_loss: 9164.7842 - 629ms/epoch - 90ms/step
# Epoch 867/2000
#
# Epoch 867: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 271703.2500 - val_loss: 11897.5664 - 535ms/epoch - 76ms/step
# Epoch 868/2000
#
# Epoch 868: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 264033.8125 - val_loss: 12313.9824 - 527ms/epoch - 75ms/step
# Epoch 869/2000
#
# Epoch 869: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 272610.5000 - val_loss: 5815.5410 - 513ms/epoch - 73ms/step
# Epoch 870/2000
#
# Epoch 870: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 295195.3125 - val_loss: 13132.5654 - 521ms/epoch - 74ms/step
# Epoch 871/2000
#
# Epoch 871: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 268646.2500 - val_loss: 13618.5527 - 515ms/epoch - 74ms/step
# Epoch 872/2000
#
# Epoch 872: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 257506.6875 - val_loss: 11048.5361 - 520ms/epoch - 74ms/step
# Epoch 873/2000
#
# Epoch 873: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 241109.2969 - val_loss: 15645.1094 - 548ms/epoch - 78ms/step
# Epoch 874/2000
#
# Epoch 874: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 244317.4688 - val_loss: 11918.9756 - 525ms/epoch - 75ms/step
# Epoch 875/2000
#
# Epoch 875: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 283346.0312 - val_loss: 8017.1265 - 506ms/epoch - 72ms/step
# Epoch 876/2000
#
# Epoch 876: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 313862.7500 - val_loss: 13886.6836 - 531ms/epoch - 76ms/step
# Epoch 877/2000
#
# Epoch 877: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 284126.1875 - val_loss: 5836.2090 - 513ms/epoch - 73ms/step
# Epoch 878/2000
#
# Epoch 878: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 267158.9062 - val_loss: 5558.5942 - 508ms/epoch - 73ms/step
# Epoch 879/2000
#
# Epoch 879: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 274746.2188 - val_loss: 7330.8433 - 521ms/epoch - 74ms/step
# Epoch 880/2000
#
# Epoch 880: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 272511.9375 - val_loss: 8520.1299 - 532ms/epoch - 76ms/step
# Epoch 881/2000
#
# Epoch 881: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 284363.1562 - val_loss: 14427.0889 - 541ms/epoch - 77ms/step
# Epoch 882/2000
#
# Epoch 882: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 265012.6562 - val_loss: 6138.4160 - 510ms/epoch - 73ms/step
# Epoch 883/2000
#
# Epoch 883: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 271062.5938 - val_loss: 8024.2603 - 551ms/epoch - 79ms/step
# Epoch 884/2000
#
# Epoch 884: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 283048.5000 - val_loss: 29456.1895 - 580ms/epoch - 83ms/step
# Epoch 885/2000
#
# Epoch 885: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 263043.1250 - val_loss: 6025.9189 - 1s/epoch - 152ms/step
# Epoch 886/2000
#
# Epoch 886: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 313771.9688 - val_loss: 10896.8135 - 1s/epoch - 146ms/step
# Epoch 887/2000
#
# Epoch 887: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 296475.7188 - val_loss: 5882.3994 - 1s/epoch - 152ms/step
# Epoch 888/2000
#
# Epoch 888: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 294184.0312 - val_loss: 11019.3135 - 996ms/epoch - 142ms/step
# Epoch 889/2000
#
# Epoch 889: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 251825.4062 - val_loss: 27848.0234 - 1s/epoch - 151ms/step
# Epoch 890/2000
#
# Epoch 890: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 281525.5625 - val_loss: 7644.0913 - 761ms/epoch - 109ms/step
# Epoch 891/2000
#
# Epoch 891: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 277100.0938 - val_loss: 7275.1211 - 522ms/epoch - 75ms/step
# Epoch 892/2000
#
# Epoch 892: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 305382.0625 - val_loss: 6438.8789 - 544ms/epoch - 78ms/step
# Epoch 893/2000
#
# Epoch 893: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 260208.9844 - val_loss: 22726.7812 - 550ms/epoch - 79ms/step
# Epoch 894/2000
#
# Epoch 894: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 260526.9531 - val_loss: 9037.0264 - 501ms/epoch - 72ms/step
# Epoch 895/2000
#
# Epoch 895: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 281463.7500 - val_loss: 19983.7695 - 527ms/epoch - 75ms/step
# Epoch 896/2000
#
# Epoch 896: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 270023.3438 - val_loss: 10380.7119 - 559ms/epoch - 80ms/step
# Epoch 897/2000
#
# Epoch 897: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 317283.7500 - val_loss: 5654.3579 - 574ms/epoch - 82ms/step
# Epoch 898/2000
#
# Epoch 898: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 301227.3125 - val_loss: 5680.5957 - 502ms/epoch - 72ms/step
# Epoch 899/2000
#
# Epoch 899: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 286055.3750 - val_loss: 8876.4463 - 527ms/epoch - 75ms/step
# Epoch 900/2000
#
# Epoch 900: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 293563.8125 - val_loss: 5374.8711 - 524ms/epoch - 75ms/step
# Epoch 901/2000
#
# Epoch 901: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 320334.8438 - val_loss: 8302.0273 - 541ms/epoch - 77ms/step
# Epoch 902/2000
#
# Epoch 902: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 289999.4062 - val_loss: 5636.8667 - 540ms/epoch - 77ms/step
# Epoch 903/2000
#
# Epoch 903: loss did not improve from 240654.75000
# 7/7 - 1s - loss: 309245.1250 - val_loss: 5571.3516 - 556ms/epoch - 79ms/step
# Epoch 904/2000
#
# Epoch 904: loss improved from 240654.75000 to 240337.01562, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 240337.0156 - val_loss: 7455.9707 - 801ms/epoch - 114ms/step
# Epoch 905/2000
#
# Epoch 905: loss did not improve from 240337.01562
# 7/7 - 0s - loss: 314470.7188 - val_loss: 9941.1670 - 499ms/epoch - 71ms/step
# Epoch 906/2000
#
# Epoch 906: loss did not improve from 240337.01562
# 7/7 - 1s - loss: 273218.6875 - val_loss: 9345.6904 - 551ms/epoch - 79ms/step
# Epoch 907/2000
#
# Epoch 907: loss did not improve from 240337.01562
# 7/7 - 1s - loss: 284715.0625 - val_loss: 21708.1973 - 508ms/epoch - 73ms/step
# Epoch 908/2000
#
# Epoch 908: loss did not improve from 240337.01562
# 7/7 - 1s - loss: 261658.4375 - val_loss: 21024.1895 - 742ms/epoch - 106ms/step
# Epoch 909/2000
#
# Epoch 909: loss did not improve from 240337.01562
# 7/7 - 1s - loss: 299127.3125 - val_loss: 7585.3945 - 1s/epoch - 154ms/step
# Epoch 910/2000
#
# Epoch 910: loss did not improve from 240337.01562
# 7/7 - 1s - loss: 278947.3125 - val_loss: 6289.3159 - 1s/epoch - 161ms/step
# Epoch 911/2000
#
# Epoch 911: loss did not improve from 240337.01562
# 7/7 - 1s - loss: 294409.1562 - val_loss: 8151.6890 - 1s/epoch - 146ms/step
# Epoch 912/2000
#
# Epoch 912: loss did not improve from 240337.01562
# 7/7 - 1s - loss: 288350.6250 - val_loss: 6387.4067 - 993ms/epoch - 142ms/step
# Epoch 913/2000
#
# Epoch 913: loss did not improve from 240337.01562
# 7/7 - 1s - loss: 308498.8125 - val_loss: 8685.9014 - 782ms/epoch - 112ms/step
# Epoch 914/2000
#
# Epoch 914: loss did not improve from 240337.01562
# 7/7 - 1s - loss: 267771.9062 - val_loss: 5634.8833 - 643ms/epoch - 92ms/step
# Epoch 915/2000
#
# Epoch 915: loss did not improve from 240337.01562
# 7/7 - 1s - loss: 293554.8125 - val_loss: 12585.5635 - 514ms/epoch - 73ms/step
# Epoch 916/2000
#
# Epoch 916: loss did not improve from 240337.01562
# 7/7 - 1s - loss: 282757.7500 - val_loss: 9911.4658 - 553ms/epoch - 79ms/step
# Epoch 917/2000
#
# Epoch 917: loss did not improve from 240337.01562
# 7/7 - 1s - loss: 249053.7500 - val_loss: 26519.2676 - 519ms/epoch - 74ms/step
# Epoch 918/2000
#
# Epoch 918: loss did not improve from 240337.01562
# 7/7 - 1s - loss: 284064.8750 - val_loss: 6180.4526 - 531ms/epoch - 76ms/step
# Epoch 919/2000
#
# Epoch 919: loss did not improve from 240337.01562
# 7/7 - 0s - loss: 301636.9688 - val_loss: 8253.8086 - 497ms/epoch - 71ms/step
# Epoch 920/2000
#
# Epoch 920: loss did not improve from 240337.01562
# 7/7 - 1s - loss: 259846.4062 - val_loss: 9651.5811 - 517ms/epoch - 74ms/step
# Epoch 921/2000
#
# Epoch 921: loss did not improve from 240337.01562
# 7/7 - 1s - loss: 300750.5938 - val_loss: 8295.9746 - 518ms/epoch - 74ms/step
# Epoch 922/2000
#
# Epoch 922: loss did not improve from 240337.01562
# 7/7 - 0s - loss: 278006.7812 - val_loss: 20476.9238 - 482ms/epoch - 69ms/step
# Epoch 923/2000
#
# Epoch 923: loss did not improve from 240337.01562
# 7/7 - 1s - loss: 288502.4688 - val_loss: 8167.0498 - 507ms/epoch - 72ms/step
# Epoch 924/2000
#
# Epoch 924: loss did not improve from 240337.01562
# 7/7 - 1s - loss: 274405.1875 - val_loss: 8853.9297 - 526ms/epoch - 75ms/step
# Epoch 925/2000
#
# Epoch 925: loss did not improve from 240337.01562
# 7/7 - 1s - loss: 256437.4844 - val_loss: 9238.5098 - 506ms/epoch - 72ms/step
# Epoch 926/2000
#
# Epoch 926: loss did not improve from 240337.01562
# 7/7 - 1s - loss: 313067.8125 - val_loss: 14111.3037 - 517ms/epoch - 74ms/step
# Epoch 927/2000
#
# Epoch 927: loss did not improve from 240337.01562
# 7/7 - 1s - loss: 280003.8750 - val_loss: 12566.6592 - 570ms/epoch - 81ms/step
# Epoch 928/2000
#
# Epoch 928: loss did not improve from 240337.01562
# 7/7 - 1s - loss: 256305.0938 - val_loss: 7163.6641 - 503ms/epoch - 72ms/step
# Epoch 929/2000
#
# Epoch 929: loss did not improve from 240337.01562
# 7/7 - 1s - loss: 273899.3750 - val_loss: 5858.0601 - 546ms/epoch - 78ms/step
# Epoch 930/2000
#
# Epoch 930: loss improved from 240337.01562 to 233281.48438, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 233281.4844 - val_loss: 10338.4619 - 822ms/epoch - 117ms/step
# Epoch 931/2000
#
# Epoch 931: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 291170.9688 - val_loss: 19887.8418 - 517ms/epoch - 74ms/step
# Epoch 932/2000
#
# Epoch 932: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 294752.6875 - val_loss: 12860.4766 - 703ms/epoch - 100ms/step
# Epoch 933/2000
#
# Epoch 933: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 279216.1562 - val_loss: 11624.3330 - 1s/epoch - 149ms/step
# Epoch 934/2000
#
# Epoch 934: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 269895.5938 - val_loss: 9510.8301 - 926ms/epoch - 132ms/step
# Epoch 935/2000
#
# Epoch 935: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 265095.9375 - val_loss: 8359.0674 - 1s/epoch - 161ms/step
# Epoch 936/2000
#
# Epoch 936: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 304323.2812 - val_loss: 7502.6133 - 1s/epoch - 146ms/step
# Epoch 937/2000
#
# Epoch 937: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 248136.6250 - val_loss: 6504.5933 - 980ms/epoch - 140ms/step
# Epoch 938/2000
#
# Epoch 938: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 283998.0625 - val_loss: 12271.4502 - 652ms/epoch - 93ms/step
# Epoch 939/2000
#
# Epoch 939: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 272900.2812 - val_loss: 5918.0879 - 544ms/epoch - 78ms/step
# Epoch 940/2000
#
# Epoch 940: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 300079.1562 - val_loss: 5813.9600 - 544ms/epoch - 78ms/step
# Epoch 941/2000
#
# Epoch 941: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 261535.5938 - val_loss: 31086.8262 - 556ms/epoch - 79ms/step
# Epoch 942/2000
#
# Epoch 942: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 278719.7500 - val_loss: 11776.6416 - 571ms/epoch - 82ms/step
# Epoch 943/2000
#
# Epoch 943: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 273111.0312 - val_loss: 5655.7578 - 509ms/epoch - 73ms/step
# Epoch 944/2000
#
# Epoch 944: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 276401.7500 - val_loss: 10505.3887 - 537ms/epoch - 77ms/step
# Epoch 945/2000
#
# Epoch 945: loss did not improve from 233281.48438
# 7/7 - 0s - loss: 303681.0625 - val_loss: 6039.1250 - 495ms/epoch - 71ms/step
# Epoch 946/2000
#
# Epoch 946: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 278971.8438 - val_loss: 8114.0439 - 521ms/epoch - 74ms/step
# Epoch 947/2000
#
# Epoch 947: loss did not improve from 233281.48438
# 7/7 - 0s - loss: 258819.9219 - val_loss: 13180.2529 - 498ms/epoch - 71ms/step
# Epoch 948/2000
#
# Epoch 948: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 271596.4688 - val_loss: 13507.5234 - 513ms/epoch - 73ms/step
# Epoch 949/2000
#
# Epoch 949: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 300547.4688 - val_loss: 30206.5391 - 530ms/epoch - 76ms/step
# Epoch 950/2000
#
# Epoch 950: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 270481.0938 - val_loss: 6703.7764 - 536ms/epoch - 77ms/step
# Epoch 951/2000
#
# Epoch 951: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 282291.9062 - val_loss: 11468.2285 - 530ms/epoch - 76ms/step
# Epoch 952/2000
#
# Epoch 952: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 251270.4062 - val_loss: 10048.9727 - 518ms/epoch - 74ms/step
# Epoch 953/2000
#
# Epoch 953: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 260575.3750 - val_loss: 29692.0977 - 550ms/epoch - 79ms/step
# Epoch 954/2000
#
# Epoch 954: loss did not improve from 233281.48438
# 7/7 - 0s - loss: 259573.7500 - val_loss: 36579.9141 - 484ms/epoch - 69ms/step
# Epoch 955/2000
#
# Epoch 955: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 300682.5312 - val_loss: 12500.5029 - 508ms/epoch - 73ms/step
# Epoch 956/2000
#
# Epoch 956: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 280012.9688 - val_loss: 8315.4561 - 522ms/epoch - 75ms/step
# Epoch 957/2000
#
# Epoch 957: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 339597.0625 - val_loss: 6151.7520 - 1s/epoch - 145ms/step
# Epoch 958/2000
#
# Epoch 958: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 280883.9375 - val_loss: 13063.8711 - 1s/epoch - 144ms/step
# Epoch 959/2000
#
# Epoch 959: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 244305.5312 - val_loss: 14249.7871 - 1s/epoch - 147ms/step
# Epoch 960/2000
#
# Epoch 960: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 280830.9688 - val_loss: 11578.8672 - 939ms/epoch - 134ms/step
# Epoch 961/2000
#
# Epoch 961: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 276474.1875 - val_loss: 5931.4644 - 1s/epoch - 155ms/step
# Epoch 962/2000
#
# Epoch 962: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 317207.4062 - val_loss: 5282.6538 - 850ms/epoch - 121ms/step
# Epoch 963/2000
#
# Epoch 963: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 284594.4062 - val_loss: 5682.3828 - 532ms/epoch - 76ms/step
# Epoch 964/2000
#
# Epoch 964: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 259579.5625 - val_loss: 9053.4629 - 541ms/epoch - 77ms/step
# Epoch 965/2000
#
# Epoch 965: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 314344.1562 - val_loss: 9078.1885 - 587ms/epoch - 84ms/step
# Epoch 966/2000
#
# Epoch 966: loss did not improve from 233281.48438
# 7/7 - 0s - loss: 265342.9062 - val_loss: 20800.3477 - 498ms/epoch - 71ms/step
# Epoch 967/2000
#
# Epoch 967: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 280883.4062 - val_loss: 9567.3574 - 534ms/epoch - 76ms/step
# Epoch 968/2000
#
# Epoch 968: loss did not improve from 233281.48438
# 7/7 - 0s - loss: 307382.3125 - val_loss: 8553.1641 - 480ms/epoch - 69ms/step
# Epoch 969/2000
#
# Epoch 969: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 329035.8438 - val_loss: 7637.5562 - 537ms/epoch - 77ms/step
# Epoch 970/2000
#
# Epoch 970: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 271357.4062 - val_loss: 6273.9453 - 549ms/epoch - 78ms/step
# Epoch 971/2000
#
# Epoch 971: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 253403.7500 - val_loss: 8941.9834 - 538ms/epoch - 77ms/step
# Epoch 972/2000
#
# Epoch 972: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 284688.1875 - val_loss: 6241.2285 - 506ms/epoch - 72ms/step
# Epoch 973/2000
#
# Epoch 973: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 256661.9062 - val_loss: 6976.4351 - 525ms/epoch - 75ms/step
# Epoch 974/2000
#
# Epoch 974: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 268072.7500 - val_loss: 6407.8159 - 526ms/epoch - 75ms/step
# Epoch 975/2000
#
# Epoch 975: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 273385.9688 - val_loss: 13958.0195 - 536ms/epoch - 77ms/step
# Epoch 976/2000
#
# Epoch 976: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 261873.6719 - val_loss: 14600.9131 - 505ms/epoch - 72ms/step
# Epoch 977/2000
#
# Epoch 977: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 280023.5000 - val_loss: 6656.2144 - 595ms/epoch - 85ms/step
# Epoch 978/2000
#
# Epoch 978: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 271618.2500 - val_loss: 6501.5142 - 510ms/epoch - 73ms/step
# Epoch 979/2000
#
# Epoch 979: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 256367.3594 - val_loss: 7713.4248 - 533ms/epoch - 76ms/step
# Epoch 980/2000
#
# Epoch 980: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 239877.5469 - val_loss: 6389.7539 - 549ms/epoch - 78ms/step
# Epoch 981/2000
#
# Epoch 981: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 256314.0312 - val_loss: 17490.0391 - 868ms/epoch - 124ms/step
# Epoch 982/2000
#
# Epoch 982: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 271621.5938 - val_loss: 6240.2153 - 1s/epoch - 150ms/step
# Epoch 983/2000
#
# Epoch 983: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 307930.3125 - val_loss: 11293.8242 - 1s/epoch - 152ms/step
# Epoch 984/2000
#
# Epoch 984: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 284517.4688 - val_loss: 11432.0928 - 936ms/epoch - 134ms/step
# Epoch 985/2000
#
# Epoch 985: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 294691.5312 - val_loss: 9817.9531 - 1s/epoch - 153ms/step
# Epoch 986/2000
#
# Epoch 986: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 308757.5312 - val_loss: 16191.2471 - 942ms/epoch - 135ms/step
# Epoch 987/2000
#
# Epoch 987: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 271427.0625 - val_loss: 9940.1553 - 506ms/epoch - 72ms/step
# Epoch 988/2000
#
# Epoch 988: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 251030.8906 - val_loss: 8277.3818 - 565ms/epoch - 81ms/step
# Epoch 989/2000
#
# Epoch 989: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 295718.6875 - val_loss: 35874.1172 - 576ms/epoch - 82ms/step
# Epoch 990/2000
#
# Epoch 990: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 263628.1875 - val_loss: 22313.2598 - 541ms/epoch - 77ms/step
# Epoch 991/2000
#
# Epoch 991: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 288807.1562 - val_loss: 8494.4805 - 599ms/epoch - 86ms/step
# Epoch 992/2000
#
# Epoch 992: loss did not improve from 233281.48438
# 7/7 - 0s - loss: 267557.8438 - val_loss: 21349.4531 - 488ms/epoch - 70ms/step
# Epoch 993/2000
#
# Epoch 993: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 262028.8125 - val_loss: 7947.0166 - 500ms/epoch - 71ms/step
# Epoch 994/2000
#
# Epoch 994: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 280077.4062 - val_loss: 5555.7002 - 508ms/epoch - 73ms/step
# Epoch 995/2000
#
# Epoch 995: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 274975.5938 - val_loss: 7405.2661 - 517ms/epoch - 74ms/step
# Epoch 996/2000
#
# Epoch 996: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 288185.4062 - val_loss: 6023.4146 - 519ms/epoch - 74ms/step
# Epoch 997/2000
#
# Epoch 997: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 289965.5938 - val_loss: 10017.8320 - 511ms/epoch - 73ms/step
# Epoch 998/2000
#
# Epoch 998: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 261051.6406 - val_loss: 9248.8633 - 543ms/epoch - 78ms/step
# Epoch 999/2000
#
# Epoch 999: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 262236.9688 - val_loss: 7931.6709 - 521ms/epoch - 74ms/step
# Epoch 1000/2000
#
# Epoch 1000: loss did not improve from 233281.48438
# 7/7 - 0s - loss: 285545.7188 - val_loss: 14937.9453 - 499ms/epoch - 71ms/step
# Epoch 1001/2000
#
# Epoch 1001: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 320130.9375 - val_loss: 7539.8579 - 510ms/epoch - 73ms/step
# Epoch 1002/2000
#
# Epoch 1002: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 258609.3438 - val_loss: 6152.0640 - 538ms/epoch - 77ms/step
# Epoch 1003/2000
#
# Epoch 1003: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 274033.1250 - val_loss: 6401.7627 - 519ms/epoch - 74ms/step
# Epoch 1004/2000
#
# Epoch 1004: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 272141.1875 - val_loss: 8554.5771 - 523ms/epoch - 75ms/step
# Epoch 1005/2000
#
# Epoch 1005: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 285837.0312 - val_loss: 22007.5996 - 811ms/epoch - 116ms/step
# Epoch 1006/2000
#
# Epoch 1006: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 245438.8125 - val_loss: 8620.9336 - 1s/epoch - 154ms/step
# Epoch 1007/2000
#
# Epoch 1007: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 269016.0625 - val_loss: 10650.3867 - 1s/epoch - 155ms/step
# Epoch 1008/2000
#
# Epoch 1008: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 242836.2500 - val_loss: 6531.9233 - 1s/epoch - 147ms/step
# Epoch 1009/2000
#
# Epoch 1009: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 296566.8438 - val_loss: 15404.2695 - 1s/epoch - 148ms/step
# Epoch 1010/2000
#
# Epoch 1010: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 266699.7812 - val_loss: 9235.4570 - 1s/epoch - 155ms/step
# Epoch 1011/2000
#
# Epoch 1011: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 309561.1562 - val_loss: 11182.8701 - 540ms/epoch - 77ms/step
# Epoch 1012/2000
#
# Epoch 1012: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 271127.6875 - val_loss: 14022.4658 - 513ms/epoch - 73ms/step
# Epoch 1013/2000
#
# Epoch 1013: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 256817.7031 - val_loss: 23179.8477 - 503ms/epoch - 72ms/step
# Epoch 1014/2000
#
# Epoch 1014: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 267774.8125 - val_loss: 9559.1299 - 519ms/epoch - 74ms/step
# Epoch 1015/2000
#
# Epoch 1015: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 268429.4688 - val_loss: 6223.3057 - 507ms/epoch - 72ms/step
# Epoch 1016/2000
#
# Epoch 1016: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 275446.4688 - val_loss: 9174.4141 - 505ms/epoch - 72ms/step
# Epoch 1017/2000
#
# Epoch 1017: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 262306.8438 - val_loss: 7194.0269 - 607ms/epoch - 87ms/step
# Epoch 1018/2000
#
# Epoch 1018: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 283501.4688 - val_loss: 10786.1426 - 512ms/epoch - 73ms/step
# Epoch 1019/2000
#
# Epoch 1019: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 316759.4062 - val_loss: 6355.6724 - 516ms/epoch - 74ms/step
# Epoch 1020/2000
#
# Epoch 1020: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 288204.2500 - val_loss: 7675.5234 - 528ms/epoch - 75ms/step
# Epoch 1021/2000
#
# Epoch 1021: loss did not improve from 233281.48438
# 7/7 - 0s - loss: 279580.2500 - val_loss: 13112.6123 - 496ms/epoch - 71ms/step
# Epoch 1022/2000
#
# Epoch 1022: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 251671.1875 - val_loss: 6482.7129 - 508ms/epoch - 73ms/step
# Epoch 1023/2000
#
# Epoch 1023: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 265847.3750 - val_loss: 18269.7773 - 526ms/epoch - 75ms/step
# Epoch 1024/2000
#
# Epoch 1024: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 273446.1875 - val_loss: 6715.7979 - 558ms/epoch - 80ms/step
# Epoch 1025/2000
#
# Epoch 1025: loss did not improve from 233281.48438
# 7/7 - 0s - loss: 257812.6562 - val_loss: 10991.4834 - 489ms/epoch - 70ms/step
# Epoch 1026/2000
#
# Epoch 1026: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 300764.0000 - val_loss: 10730.1504 - 523ms/epoch - 75ms/step
# Epoch 1027/2000
#
# Epoch 1027: loss did not improve from 233281.48438
# 7/7 - 0s - loss: 287061.0000 - val_loss: 9228.6611 - 487ms/epoch - 70ms/step
# Epoch 1028/2000
#
# Epoch 1028: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 277266.7500 - val_loss: 14536.4111 - 544ms/epoch - 78ms/step
# Epoch 1029/2000
#
# Epoch 1029: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 270055.7500 - val_loss: 9575.0371 - 520ms/epoch - 74ms/step
# Epoch 1030/2000
#
# Epoch 1030: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 257598.1875 - val_loss: 6651.6606 - 1s/epoch - 146ms/step
# Epoch 1031/2000
#
# Epoch 1031: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 260245.6406 - val_loss: 6167.8252 - 1s/epoch - 160ms/step
# Epoch 1032/2000
#
# Epoch 1032: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 284094.1875 - val_loss: 14333.2500 - 1s/epoch - 150ms/step
# Epoch 1033/2000
#
# Epoch 1033: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 310944.8750 - val_loss: 6143.6860 - 936ms/epoch - 134ms/step
# Epoch 1034/2000
#
# Epoch 1034: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 289356.0312 - val_loss: 11601.0098 - 1s/epoch - 151ms/step
# Epoch 1035/2000
#
# Epoch 1035: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 308947.2500 - val_loss: 8627.9658 - 881ms/epoch - 126ms/step
# Epoch 1036/2000
#
# Epoch 1036: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 258091.5469 - val_loss: 5208.3867 - 523ms/epoch - 75ms/step
# Epoch 1037/2000
#
# Epoch 1037: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 272287.3125 - val_loss: 16113.3652 - 525ms/epoch - 75ms/step
# Epoch 1038/2000
#
# Epoch 1038: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 276689.0938 - val_loss: 7266.6338 - 564ms/epoch - 81ms/step
# Epoch 1039/2000
#
# Epoch 1039: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 276596.1562 - val_loss: 9092.8652 - 542ms/epoch - 77ms/step
# Epoch 1040/2000
#
# Epoch 1040: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 276040.8750 - val_loss: 16438.4590 - 514ms/epoch - 73ms/step
# Epoch 1041/2000
#
# Epoch 1041: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 251155.3750 - val_loss: 18599.4355 - 556ms/epoch - 79ms/step
# Epoch 1042/2000
#
# Epoch 1042: loss did not improve from 233281.48438
# 7/7 - 0s - loss: 255690.9844 - val_loss: 25313.3594 - 490ms/epoch - 70ms/step
# Epoch 1043/2000
#
# Epoch 1043: loss did not improve from 233281.48438
# 7/7 - 0s - loss: 257900.4062 - val_loss: 9431.3887 - 494ms/epoch - 71ms/step
# Epoch 1044/2000
#
# Epoch 1044: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 271898.8438 - val_loss: 6034.5371 - 569ms/epoch - 81ms/step
# Epoch 1045/2000
#
# Epoch 1045: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 234006.2188 - val_loss: 14326.4873 - 531ms/epoch - 76ms/step
# Epoch 1046/2000
#
# Epoch 1046: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 279092.0938 - val_loss: 15299.0869 - 526ms/epoch - 75ms/step
# Epoch 1047/2000
#
# Epoch 1047: loss did not improve from 233281.48438
# 7/7 - 1s - loss: 248371.3281 - val_loss: 9038.1758 - 559ms/epoch - 80ms/step
# Epoch 1048/2000
#
# Epoch 1048: loss improved from 233281.48438 to 217841.51562, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 217841.5156 - val_loss: 15086.8467 - 777ms/epoch - 111ms/step
# Epoch 1049/2000
#
# Epoch 1049: loss did not improve from 217841.51562
# 7/7 - 1s - loss: 271853.2500 - val_loss: 13603.1709 - 537ms/epoch - 77ms/step
# Epoch 1050/2000
#
# Epoch 1050: loss did not improve from 217841.51562
# 7/7 - 1s - loss: 290280.3438 - val_loss: 7385.0278 - 515ms/epoch - 74ms/step
# Epoch 1051/2000
#
# Epoch 1051: loss did not improve from 217841.51562
# 7/7 - 1s - loss: 279005.9375 - val_loss: 5068.5244 - 513ms/epoch - 73ms/step
# Epoch 1052/2000
#
# Epoch 1052: loss did not improve from 217841.51562
# 7/7 - 0s - loss: 263114.6875 - val_loss: 7065.9258 - 485ms/epoch - 69ms/step
# Epoch 1053/2000
#
# Epoch 1053: loss did not improve from 217841.51562
# 7/7 - 1s - loss: 296458.0938 - val_loss: 12003.2246 - 560ms/epoch - 80ms/step
# Epoch 1054/2000
#
# Epoch 1054: loss did not improve from 217841.51562
# 7/7 - 1s - loss: 277461.7500 - val_loss: 21033.1777 - 1s/epoch - 144ms/step
# Epoch 1055/2000
#
# Epoch 1055: loss did not improve from 217841.51562
# 7/7 - 1s - loss: 255061.4531 - val_loss: 7013.4810 - 1s/epoch - 158ms/step
# Epoch 1056/2000
#
# Epoch 1056: loss did not improve from 217841.51562
# 7/7 - 1s - loss: 290765.9688 - val_loss: 7006.7310 - 1s/epoch - 156ms/step
# Epoch 1057/2000
#
# Epoch 1057: loss did not improve from 217841.51562
# 7/7 - 1s - loss: 259247.7031 - val_loss: 7135.2627 - 905ms/epoch - 129ms/step
# Epoch 1058/2000
#
# Epoch 1058: loss did not improve from 217841.51562
# 7/7 - 1s - loss: 284941.0312 - val_loss: 7890.4141 - 923ms/epoch - 132ms/step
# Epoch 1059/2000
#
# Epoch 1059: loss did not improve from 217841.51562
# 7/7 - 1s - loss: 263698.1875 - val_loss: 7116.7007 - 738ms/epoch - 105ms/step
# Epoch 1060/2000
#
# Epoch 1060: loss did not improve from 217841.51562
# 7/7 - 1s - loss: 293964.0625 - val_loss: 9424.4307 - 510ms/epoch - 73ms/step
# Epoch 1061/2000
#
# Epoch 1061: loss did not improve from 217841.51562
# 7/7 - 1s - loss: 279024.4688 - val_loss: 8097.9731 - 609ms/epoch - 87ms/step
# Epoch 1062/2000
#
# Epoch 1062: loss did not improve from 217841.51562
# 7/7 - 1s - loss: 288911.0312 - val_loss: 6281.5938 - 555ms/epoch - 79ms/step
# Epoch 1063/2000
#
# Epoch 1063: loss did not improve from 217841.51562
# 7/7 - 1s - loss: 263998.7500 - val_loss: 28831.0098 - 542ms/epoch - 77ms/step
# Epoch 1064/2000
#
# Epoch 1064: loss did not improve from 217841.51562
# 7/7 - 1s - loss: 271525.4062 - val_loss: 18511.3809 - 504ms/epoch - 72ms/step
# Epoch 1065/2000
#
# Epoch 1065: loss did not improve from 217841.51562
# 7/7 - 1s - loss: 250214.7500 - val_loss: 14414.9385 - 515ms/epoch - 74ms/step
# Epoch 1066/2000
#
# Epoch 1066: loss did not improve from 217841.51562
# 7/7 - 1s - loss: 275576.7500 - val_loss: 9887.2275 - 588ms/epoch - 84ms/step
# Epoch 1067/2000
#
# Epoch 1067: loss did not improve from 217841.51562
# 7/7 - 1s - loss: 318960.5938 - val_loss: 5636.0640 - 559ms/epoch - 80ms/step
# Epoch 1068/2000
#
# Epoch 1068: loss did not improve from 217841.51562
# 7/7 - 0s - loss: 281926.7188 - val_loss: 8774.3193 - 482ms/epoch - 69ms/step
# Epoch 1069/2000
#
# Epoch 1069: loss did not improve from 217841.51562
# 7/7 - 1s - loss: 273430.9062 - val_loss: 13022.3428 - 525ms/epoch - 75ms/step
# Epoch 1070/2000
#
# Epoch 1070: loss did not improve from 217841.51562
# 7/7 - 1s - loss: 275541.9062 - val_loss: 5474.1631 - 520ms/epoch - 74ms/step
# Epoch 1071/2000
#
# Epoch 1071: loss did not improve from 217841.51562
# 7/7 - 1s - loss: 245197.0156 - val_loss: 10754.9287 - 535ms/epoch - 76ms/step
# Epoch 1072/2000
#
# Epoch 1072: loss did not improve from 217841.51562
# 7/7 - 1s - loss: 278040.8438 - val_loss: 5269.2412 - 584ms/epoch - 83ms/step
# Epoch 1073/2000
#
# Epoch 1073: loss did not improve from 217841.51562
# 7/7 - 1s - loss: 266116.6562 - val_loss: 5340.7734 - 569ms/epoch - 81ms/step
# Epoch 1074/2000
#
# Epoch 1074: loss did not improve from 217841.51562
# ...
# Epoch 1892/2000
#
# Epoch 1892: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 249972.6406 - val_loss: 5569.9194 - 531ms/epoch - 76ms/step
# Epoch 1893/2000
#
# Epoch 1893: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 229949.2031 - val_loss: 6277.5195 - 531ms/epoch - 76ms/step
# Epoch 1894/2000
#
# Epoch 1894: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 256963.3750 - val_loss: 5065.2036 - 511ms/epoch - 73ms/step
# Epoch 1895/2000
#
# Epoch 1895: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 252919.2031 - val_loss: 5264.9067 - 568ms/epoch - 81ms/step
# Epoch 1896/2000
#
# Epoch 1896: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 204235.7031 - val_loss: 5365.5435 - 516ms/epoch - 74ms/step
# Epoch 1897/2000
#
# Epoch 1897: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 216247.7969 - val_loss: 13929.5889 - 562ms/epoch - 80ms/step
# Epoch 1898/2000
#
# Epoch 1898: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 236389.7656 - val_loss: 12698.1055 - 532ms/epoch - 76ms/step
# Epoch 1899/2000
#
# Epoch 1899: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 241590.6562 - val_loss: 5398.8799 - 551ms/epoch - 79ms/step
# Epoch 1900/2000
#
# Epoch 1900: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 248306.0781 - val_loss: 5709.0127 - 556ms/epoch - 79ms/step
# Epoch 1901/2000
#
# Epoch 1901: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 262693.5938 - val_loss: 7441.6797 - 555ms/epoch - 79ms/step
# Epoch 1902/2000
#
# Epoch 1902: loss did not improve from 197300.31250
# 7/7 - 0s - loss: 240998.8594 - val_loss: 5823.7310 - 494ms/epoch - 71ms/step
# Epoch 1903/2000
#
# Epoch 1903: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 252942.1875 - val_loss: 5239.0811 - 514ms/epoch - 73ms/step
# Epoch 1904/2000
#
# Epoch 1904: loss did not improve from 197300.31250
# 7/7 - 0s - loss: 240083.0000 - val_loss: 5670.0674 - 495ms/epoch - 71ms/step
# Epoch 1905/2000
#
# Epoch 1905: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 247284.5312 - val_loss: 5517.2920 - 525ms/epoch - 75ms/step
# Epoch 1906/2000
#
# Epoch 1906: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 264271.7500 - val_loss: 5972.7588 - 516ms/epoch - 74ms/step
# Epoch 1907/2000
#
# Epoch 1907: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 223727.2344 - val_loss: 4929.6377 - 505ms/epoch - 72ms/step
# Epoch 1908/2000
#
# Epoch 1908: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 278685.4062 - val_loss: 5606.8726 - 512ms/epoch - 73ms/step
# Epoch 1909/2000
#
# Epoch 1909: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 278029.3125 - val_loss: 5928.8945 - 535ms/epoch - 76ms/step
# Epoch 1910/2000
#
# Epoch 1910: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 246150.9219 - val_loss: 5357.5630 - 967ms/epoch - 138ms/step
# Epoch 1911/2000
#
# Epoch 1911: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 284429.7812 - val_loss: 6363.5332 - 1s/epoch - 163ms/step
# Epoch 1912/2000
#
# Epoch 1912: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 245352.9844 - val_loss: 5621.0063 - 1s/epoch - 166ms/step
# Epoch 1913/2000
#
# Epoch 1913: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 231731.6719 - val_loss: 5790.6670 - 994ms/epoch - 142ms/step
# Epoch 1914/2000
#
# Epoch 1914: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 251478.1562 - val_loss: 6794.5195 - 1s/epoch - 166ms/step
# Epoch 1915/2000
#
# Epoch 1915: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 257255.8750 - val_loss: 7286.4375 - 722ms/epoch - 103ms/step
# Epoch 1916/2000
#
# Epoch 1916: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 250117.5469 - val_loss: 4852.4268 - 512ms/epoch - 73ms/step
# Epoch 1917/2000
#
# Epoch 1917: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 264044.0000 - val_loss: 5210.5757 - 536ms/epoch - 77ms/step
# Epoch 1918/2000
#
# Epoch 1918: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 243509.8125 - val_loss: 8692.1455 - 521ms/epoch - 74ms/step
# Epoch 1919/2000
#
# Epoch 1919: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 236896.7344 - val_loss: 4961.3989 - 541ms/epoch - 77ms/step
# Epoch 1920/2000
#
# Epoch 1920: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 247279.8594 - val_loss: 5059.4805 - 518ms/epoch - 74ms/step
# Epoch 1921/2000
#
# Epoch 1921: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 245085.6250 - val_loss: 4795.6318 - 541ms/epoch - 77ms/step
# Epoch 1922/2000
#
# Epoch 1922: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 226098.1875 - val_loss: 6612.6978 - 507ms/epoch - 72ms/step
# Epoch 1923/2000
#
# Epoch 1923: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 235528.1875 - val_loss: 6109.2666 - 529ms/epoch - 76ms/step
# Epoch 1924/2000
#
# Epoch 1924: loss did not improve from 197300.31250
# 7/7 - 0s - loss: 235981.0469 - val_loss: 5377.9912 - 496ms/epoch - 71ms/step
# Epoch 1925/2000
#
# Epoch 1925: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 264108.8750 - val_loss: 6236.3252 - 523ms/epoch - 75ms/step
# Epoch 1926/2000
#
# Epoch 1926: loss did not improve from 197300.31250
# 7/7 - 0s - loss: 219869.9219 - val_loss: 5594.2476 - 499ms/epoch - 71ms/step
# Epoch 1927/2000
#
# Epoch 1927: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 235405.4531 - val_loss: 5991.6172 - 545ms/epoch - 78ms/step
# Epoch 1928/2000
#
# Epoch 1928: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 273686.9375 - val_loss: 5237.8784 - 530ms/epoch - 76ms/step
# Epoch 1929/2000
#
# Epoch 1929: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 266515.0938 - val_loss: 4872.4111 - 568ms/epoch - 81ms/step
# Epoch 1930/2000
#
# Epoch 1930: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 222325.1094 - val_loss: 4901.0083 - 582ms/epoch - 83ms/step
# Epoch 1931/2000
#
# Epoch 1931: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 269887.2812 - val_loss: 6058.1777 - 526ms/epoch - 75ms/step
# Epoch 1932/2000
#
# Epoch 1932: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 254094.0000 - val_loss: 5372.6538 - 545ms/epoch - 78ms/step
# Epoch 1933/2000
#
# Epoch 1933: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 223963.4062 - val_loss: 5498.8750 - 502ms/epoch - 72ms/step
# Epoch 1934/2000
#
# Epoch 1934: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 240889.2656 - val_loss: 7414.8442 - 685ms/epoch - 98ms/step
# Epoch 1935/2000
#
# Epoch 1935: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 267968.5312 - val_loss: 5021.6226 - 1s/epoch - 165ms/step
# Epoch 1936/2000
#
# Epoch 1936: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 230113.9688 - val_loss: 4909.6465 - 1s/epoch - 157ms/step
# Epoch 1937/2000
#
# Epoch 1937: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 242223.1562 - val_loss: 4959.4780 - 1s/epoch - 155ms/step
# Epoch 1938/2000
#
# Epoch 1938: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 230363.4531 - val_loss: 5541.8398 - 1s/epoch - 147ms/step
# Epoch 1939/2000
#
# Epoch 1939: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 255949.1562 - val_loss: 6653.8584 - 903ms/epoch - 129ms/step
# Epoch 1940/2000
#
# Epoch 1940: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 237255.4844 - val_loss: 4948.0938 - 626ms/epoch - 89ms/step
# Epoch 1941/2000
#
# Epoch 1941: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 265435.8438 - val_loss: 5459.5625 - 509ms/epoch - 73ms/step
# Epoch 1942/2000
#
# Epoch 1942: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 252112.0312 - val_loss: 5025.5327 - 533ms/epoch - 76ms/step
# Epoch 1943/2000
#
# Epoch 1943: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 229205.6719 - val_loss: 5081.7363 - 514ms/epoch - 73ms/step
# Epoch 1944/2000
#
# Epoch 1944: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 249403.5938 - val_loss: 6544.4985 - 526ms/epoch - 75ms/step
# Epoch 1945/2000
#
# Epoch 1945: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 235780.2656 - val_loss: 5198.4565 - 534ms/epoch - 76ms/step
# Epoch 1946/2000
#
# Epoch 1946: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 225739.4844 - val_loss: 5465.7983 - 564ms/epoch - 81ms/step
# Epoch 1947/2000
#
# Epoch 1947: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 225419.5156 - val_loss: 9942.2061 - 505ms/epoch - 72ms/step
# Epoch 1948/2000
#
# Epoch 1948: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 234808.1250 - val_loss: 6869.5171 - 535ms/epoch - 76ms/step
# Epoch 1949/2000
#
# Epoch 1949: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 260503.5781 - val_loss: 10268.1992 - 543ms/epoch - 78ms/step
# Epoch 1950/2000
#
# Epoch 1950: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 240535.8125 - val_loss: 5376.2041 - 544ms/epoch - 78ms/step
# Epoch 1951/2000
#
# Epoch 1951: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 205796.9062 - val_loss: 6791.7578 - 555ms/epoch - 79ms/step
# Epoch 1952/2000
#
# Epoch 1952: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 258969.2031 - val_loss: 5292.3481 - 538ms/epoch - 77ms/step
# Epoch 1953/2000
#
# Epoch 1953: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 218311.8125 - val_loss: 4988.0747 - 510ms/epoch - 73ms/step
# Epoch 1954/2000
#
# Epoch 1954: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 230973.9219 - val_loss: 5060.5464 - 550ms/epoch - 79ms/step
# Epoch 1955/2000
#
# Epoch 1955: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 229207.8750 - val_loss: 5685.2778 - 512ms/epoch - 73ms/step
# Epoch 1956/2000
#
# Epoch 1956: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 236147.2344 - val_loss: 8997.7764 - 536ms/epoch - 77ms/step
# Epoch 1957/2000
#
# Epoch 1957: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 219671.3438 - val_loss: 13311.5908 - 529ms/epoch - 76ms/step
# Epoch 1958/2000
#
# Epoch 1958: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 243200.0938 - val_loss: 5286.8101 - 602ms/epoch - 86ms/step
# Epoch 1959/2000
#
# Epoch 1959: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 256953.0156 - val_loss: 5821.5186 - 1s/epoch - 161ms/step
# Epoch 1960/2000
#
# Epoch 1960: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 230295.2344 - val_loss: 12166.5420 - 1s/epoch - 159ms/step
# Epoch 1961/2000
#
# Epoch 1961: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 232236.0469 - val_loss: 5035.2769 - 1s/epoch - 153ms/step
# Epoch 1962/2000
#
# Epoch 1962: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 254530.3750 - val_loss: 14489.6963 - 1s/epoch - 160ms/step
# Epoch 1963/2000
#
# Epoch 1963: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 254622.6562 - val_loss: 5066.5034 - 1s/epoch - 151ms/step
# Epoch 1964/2000
#
# Epoch 1964: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 256890.3281 - val_loss: 4871.8213 - 695ms/epoch - 99ms/step
# Epoch 1965/2000
#
# Epoch 1965: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 247921.5781 - val_loss: 7710.9653 - 523ms/epoch - 75ms/step
# Epoch 1966/2000
#
# Epoch 1966: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 259347.3594 - val_loss: 5818.1938 - 548ms/epoch - 78ms/step
# Epoch 1967/2000
#
# Epoch 1967: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 247813.1562 - val_loss: 5252.2275 - 535ms/epoch - 76ms/step
# Epoch 1968/2000
#
# Epoch 1968: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 215573.3438 - val_loss: 4735.1909 - 550ms/epoch - 79ms/step
# Epoch 1969/2000
#
# Epoch 1969: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 219156.8125 - val_loss: 4937.0366 - 557ms/epoch - 80ms/step
# Epoch 1970/2000
#
# Epoch 1970: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 258268.4531 - val_loss: 5807.6367 - 535ms/epoch - 76ms/step
# Epoch 1971/2000
#
# Epoch 1971: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 259282.1562 - val_loss: 5696.0371 - 557ms/epoch - 80ms/step
# Epoch 1972/2000
#
# Epoch 1972: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 291477.9062 - val_loss: 13754.6377 - 510ms/epoch - 73ms/step
# Epoch 1973/2000
#
# Epoch 1973: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 263203.0312 - val_loss: 6470.3091 - 519ms/epoch - 74ms/step
# Epoch 1974/2000
#
# Epoch 1974: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 243435.7812 - val_loss: 5513.1167 - 572ms/epoch - 82ms/step
# Epoch 1975/2000
#
# Epoch 1975: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 243657.0156 - val_loss: 5881.3506 - 566ms/epoch - 81ms/step
# Epoch 1976/2000
#
# Epoch 1976: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 249636.4062 - val_loss: 6110.6436 - 523ms/epoch - 75ms/step
# Epoch 1977/2000
#
# Epoch 1977: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 238667.3438 - val_loss: 7089.1582 - 515ms/epoch - 74ms/step
# Epoch 1978/2000
#
# Epoch 1978: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 269080.4375 - val_loss: 5233.8203 - 518ms/epoch - 74ms/step
# Epoch 1979/2000
#
# Epoch 1979: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 258077.8906 - val_loss: 5608.9795 - 532ms/epoch - 76ms/step
# Epoch 1980/2000
#
# Epoch 1980: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 237357.1250 - val_loss: 16461.7422 - 517ms/epoch - 74ms/step
# Epoch 1981/2000
#
# Epoch 1981: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 233007.5312 - val_loss: 9023.7158 - 523ms/epoch - 75ms/step
# Epoch 1982/2000
#
# Epoch 1982: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 257116.3281 - val_loss: 7015.7046 - 756ms/epoch - 108ms/step
# Epoch 1983/2000
#
# Epoch 1983: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 218724.7500 - val_loss: 4968.3188 - 1s/epoch - 170ms/step
# Epoch 1984/2000
#
# Epoch 1984: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 263015.2500 - val_loss: 7552.7441 - 1s/epoch - 158ms/step
# Epoch 1985/2000
#
# Epoch 1985: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 237190.4688 - val_loss: 4956.6406 - 1s/epoch - 164ms/step
# Epoch 1986/2000
#
# Epoch 1986: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 237181.6875 - val_loss: 8090.0229 - 1s/epoch - 155ms/step
# Epoch 1987/2000
#
# Epoch 1987: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 220974.8750 - val_loss: 5135.1035 - 891ms/epoch - 127ms/step
# Epoch 1988/2000
#
# Epoch 1988: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 268290.1875 - val_loss: 7014.4126 - 526ms/epoch - 75ms/step
# Epoch 1989/2000
#
# Epoch 1989: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 258880.5938 - val_loss: 5528.9106 - 506ms/epoch - 72ms/step
# Epoch 1990/2000
#
# Epoch 1990: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 256710.5469 - val_loss: 7537.5293 - 546ms/epoch - 78ms/step
# Epoch 1991/2000
#
# Epoch 1991: loss did not improve from 197300.31250
# 7/7 - 0s - loss: 266620.1875 - val_loss: 5621.0850 - 498ms/epoch - 71ms/step
# Epoch 1992/2000
#
# Epoch 1992: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 259476.9219 - val_loss: 4866.6533 - 518ms/epoch - 74ms/step
# Epoch 1993/2000
#
# Epoch 1993: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 241335.2656 - val_loss: 7920.3369 - 509ms/epoch - 73ms/step
# Epoch 1994/2000
#
# Epoch 1994: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 256504.3281 - val_loss: 5741.8770 - 519ms/epoch - 74ms/step
# Epoch 1995/2000
#
# Epoch 1995: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 211026.1562 - val_loss: 6806.6943 - 584ms/epoch - 83ms/step
# Epoch 1996/2000
#
# Epoch 1996: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 226174.2656 - val_loss: 4846.7642 - 500ms/epoch - 71ms/step
# Epoch 1997/2000
#
# Epoch 1997: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 248761.0000 - val_loss: 4721.5557 - 514ms/epoch - 73ms/step
# Epoch 1998/2000
#
# Epoch 1998: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 237906.6250 - val_loss: 5753.0918 - 524ms/epoch - 75ms/step
# Epoch 1999/2000
#
# Epoch 1999: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 243350.2969 - val_loss: 4885.4819 - 528ms/epoch - 75ms/step
# Epoch 2000/2000
#
# Epoch 2000: loss did not improve from 197300.31250
# 7/7 - 1s - loss: 208508.3281 - val_loss: 5150.6382 - 564ms/epoch - 81ms/step
# 16/16 [==============================] - 1s 13ms/step
# 3/3 [==============================] - 0s 15ms/step
# Training MSE: 7059.874206189308
# Testing MSE: 21875.652398941605
# accuracy : 56

# %%
trainX, trainY = create_dataset(train_data_t_2, train_data, look_back)
testX, testY = create_dataset(test_data_t_2,test_data, look_back)

print(trainX.shape)
print(trainY.shape)
print(testX.shape)
print(testY.shape)
# Out:
# (489, 10, 14)
# (489, 1)
# (79, 10, 14)
# (79, 1)

# %%
# 모델 생성 GRU+CNN
model = Sequential()
model.add(Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(MaxPooling1D(pool_size=2))
model.add(GRU(units=1024, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=512, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=256, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=128, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=64, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=32, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=16, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(units=1))
model.summary()


# loss = Huber()
# optimizer = Adam(0.0005)
# model.compile(loss=Huber(), optimizer=optimizer, metrics=['mse'])
model.compile(optimizer='adam', loss='mean_squared_error')

filename = os.path.join('tmp', 'ckeckpointer.ckpt')
checkpoint = ModelCheckpoint(filename,
                             save_weights_only=True,
                             save_best_only=True,
                             monitor='loss',
                             verbose=1)

# 모델 학습
history = model.fit(trainX, trainY, epochs=2000, batch_size=64,
          validation_split=0.1, verbose=2,callbacks=[checkpoint])

model.save_weights('./ko_sum_CNN_GRU__weights.h2')

model.load_weights(filename)

plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()
plt.show()

# 예측
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# MSE 계산
trainMSE = mean_squared_error(trainY, trainPredict)
testMSE = mean_squared_error(testY, testPredict)

print(f'Training MSE: {trainMSE}')
print(f'Testing MSE: {testMSE}')

accuracy(testPredict,testY)

# 예측 시각화
plt.plot(trainY, label='Actual Price')
plt.plot(trainPredict, label='Predicted Price')
plt.legend()
plt.title('Training Data')
plt.show()

plt.plot(testY, label='Actual Price')
plt.plot(testPredict, label='Predicted Price')
plt.legend()
plt.title('Testing Data')
plt.show()
# Out:
# WARNING:tensorflow:Layer gru_35 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_36 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_37 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_38 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_39 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_40 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer gru_41 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Epoch 751/2000
#
# Epoch 751: loss did not improve from 327405.71875
# 7/7 - 1s - loss: 394443.0938 - val_loss: 313886.8438 - 547ms/epoch - 78ms/step
# Epoch 752/2000
#
# Epoch 752: loss did not improve from 327405.71875
# 7/7 - 1s - loss: 424261.7500 - val_loss: 484944.0938 - 522ms/epoch - 75ms/step
# Epoch 753/2000
#
# Epoch 753: loss did not improve from 327405.71875
# 7/7 - 1s - loss: 457997.2500 - val_loss: 550799.8125 - 534ms/epoch - 76ms/step
# Epoch 754/2000
#
# Epoch 754: loss did not improve from 327405.71875
# 7/7 - 1s - loss: 446373.5312 - val_loss: 317019.9375 - 520ms/epoch - 74ms/step
# Epoch 755/2000
#
# Epoch 755: loss did not improve from 327405.71875
# 7/7 - 1s - loss: 366609.7500 - val_loss: 369476.3125 - 501ms/epoch - 72ms/step
# Epoch 756/2000
#
# Epoch 756: loss did not improve from 327405.71875
# 7/7 - 1s - loss: 411383.9375 - val_loss: 547976.0625 - 534ms/epoch - 76ms/step
# Epoch 757/2000
#
# Epoch 757: loss did not improve from 327405.71875
# 7/7 - 1s - loss: 421527.1875 - val_loss: 410246.8438 - 502ms/epoch - 72ms/step
# Epoch 758/2000
#
# Epoch 758: loss did not improve from 327405.71875
# 7/7 - 0s - loss: 420707.5625 - val_loss: 565680.8750 - 483ms/epoch - 69ms/step
# Epoch 759/2000
#
# Epoch 759: loss did not improve from 327405.71875
# 7/7 - 0s - loss: 396388.9375 - val_loss: 401693.0625 - 497ms/epoch - 71ms/step
# Epoch 760/2000
#
# Epoch 760: loss did not improve from 327405.71875
# 7/7 - 1s - loss: 361222.4062 - val_loss: 274044.5625 - 537ms/epoch - 77ms/step
# Epoch 761/2000
#
# Epoch 761: loss did not improve from 327405.71875
# 7/7 - 0s - loss: 422746.3750 - val_loss: 289842.5000 - 492ms/epoch - 70ms/step
# Epoch 762/2000
#
# Epoch 762: loss did not improve from 327405.71875
# 7/7 - 0s - loss: 400537.3750 - val_loss: 330770.4062 - 496ms/epoch - 71ms/step
# Epoch 763/2000
#
# Epoch 763: loss did not improve from 327405.71875
# 7/7 - 1s - loss: 451428.7188 - val_loss: 437439.6875 - 513ms/epoch - 73ms/step
# Epoch 764/2000
#
# Epoch 764: loss did not improve from 327405.71875
# 7/7 - 1s - loss: 419401.1250 - val_loss: 300574.7812 - 1s/epoch - 173ms/step
# Epoch 765/2000
#
# Epoch 765: loss did not improve from 327405.71875
# 7/7 - 1s - loss: 382937.1562 - val_loss: 293315.0625 - 1s/epoch - 159ms/step
# Epoch 766/2000
#
# Epoch 766: loss did not improve from 327405.71875
# 7/7 - 1s - loss: 473214.3125 - val_loss: 523319.5000 - 1s/epoch - 146ms/step
# Epoch 767/2000
#
# Epoch 767: loss did not improve from 327405.71875
# 7/7 - 1s - loss: 433202.8750 - val_loss: 423714.4062 - 881ms/epoch - 126ms/step
# Epoch 768/2000
#
# Epoch 768: loss did not improve from 327405.71875
# 7/7 - 1s - loss: 404236.4375 - val_loss: 425699.4688 - 621ms/epoch - 89ms/step
# Epoch 769/2000
#
# Epoch 769: loss did not improve from 327405.71875
# 7/7 - 1s - loss: 408542.4062 - val_loss: 366189.6875 - 531ms/epoch - 76ms/step
# Epoch 770/2000
#
# Epoch 770: loss did not improve from 327405.71875
# 7/7 - 1s - loss: 373888.6250 - val_loss: 321725.5000 - 526ms/epoch - 75ms/step
# Epoch 771/2000
#
# Epoch 771: loss did not improve from 327405.71875
# 7/7 - 1s - loss: 393132.2188 - val_loss: 694550.1875 - 503ms/epoch - 72ms/step
# Epoch 772/2000
#
# Epoch 772: loss did not improve from 327405.71875
# 7/7 - 1s - loss: 465970.6875 - val_loss: 216787.1094 - 526ms/epoch - 75ms/step
# Epoch 773/2000
#
# Epoch 773: loss did not improve from 327405.71875
# 7/7 - 1s - loss: 403397.3750 - val_loss: 418563.2500 - 523ms/epoch - 75ms/step
# Epoch 774/2000
#
# Epoch 774: loss did not improve from 327405.71875
# 7/7 - 0s - loss: 481520.0625 - val_loss: 535320.3125 - 490ms/epoch - 70ms/step
# Epoch 775/2000
#
# Epoch 775: loss did not improve from 327405.71875
# 7/7 - 1s - loss: 351262.2500 - val_loss: 287397.3750 - 514ms/epoch - 73ms/step
# Epoch 776/2000
#
# Epoch 776: loss did not improve from 327405.71875
# 7/7 - 0s - loss: 388781.8125 - val_loss: 555403.0000 - 499ms/epoch - 71ms/step
# Epoch 777/2000
#
# Epoch 777: loss did not improve from 327405.71875
# 7/7 - 1s - loss: 418710.2188 - val_loss: 352802.8438 - 514ms/epoch - 73ms/step
# Epoch 778/2000
#
# Epoch 778: loss did not improve from 327405.71875
# 7/7 - 1s - loss: 416505.3438 - val_loss: 308948.8438 - 508ms/epoch - 73ms/step
# Epoch 779/2000
#
# Epoch 779: loss did not improve from 327405.71875
# 7/7 - 0s - loss: 369607.8438 - val_loss: 335110.8750 - 492ms/epoch - 70ms/step
# Epoch 780/2000
#
# Epoch 780: loss improved from 327405.71875 to 326108.15625, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 326108.1562 - val_loss: 376130.2500 - 858ms/epoch - 123ms/step
# Epoch 781/2000
#
# Epoch 781: loss did not improve from 326108.15625
# 7/7 - 1s - loss: 378367.5000 - val_loss: 268223.9062 - 521ms/epoch - 74ms/step
# Epoch 782/2000
#
# Epoch 782: loss did not improve from 326108.15625
# 7/7 - 1s - loss: 400057.8125 - val_loss: 207693.3438 - 525ms/epoch - 75ms/step
# Epoch 783/2000
#
# Epoch 783: loss did not improve from 326108.15625
# 7/7 - 1s - loss: 425856.8125 - val_loss: 447683.2500 - 501ms/epoch - 72ms/step
# Epoch 784/2000
#
# Epoch 784: loss did not improve from 326108.15625
# 7/7 - 1s - loss: 366857.5625 - val_loss: 396539.7188 - 521ms/epoch - 74ms/step
# Epoch 785/2000
#
# Epoch 785: loss did not improve from 326108.15625
# 7/7 - 1s - loss: 415077.0625 - val_loss: 279443.7500 - 543ms/epoch - 78ms/step
# Epoch 786/2000
#
# Epoch 786: loss improved from 326108.15625 to 315534.75000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 315534.7500 - val_loss: 315175.6875 - 1s/epoch - 144ms/step
# Epoch 787/2000
#
# Epoch 787: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 359744.8125 - val_loss: 353450.6250 - 925ms/epoch - 132ms/step
# Epoch 788/2000
#
# Epoch 788: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 435110.0000 - val_loss: 371032.5312 - 999ms/epoch - 143ms/step
# Epoch 789/2000
#
# Epoch 789: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 386577.9688 - val_loss: 260744.6250 - 1s/epoch - 147ms/step
# Epoch 790/2000
#
# Epoch 790: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 381198.3125 - val_loss: 418380.5312 - 837ms/epoch - 120ms/step
# Epoch 791/2000
#
# Epoch 791: loss did not improve from 315534.75000
# 7/7 - 0s - loss: 388833.2500 - val_loss: 220865.6719 - 499ms/epoch - 71ms/step
# Epoch 792/2000
#
# Epoch 792: loss did not improve from 315534.75000
# 7/7 - 0s - loss: 385234.8438 - val_loss: 515271.7500 - 480ms/epoch - 69ms/step
# Epoch 793/2000
#
# Epoch 793: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 386667.0312 - val_loss: 310690.6250 - 529ms/epoch - 76ms/step
# Epoch 794/2000
#
# Epoch 794: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 391228.9688 - val_loss: 360788.5312 - 509ms/epoch - 73ms/step
# Epoch 795/2000
#
# Epoch 795: loss did not improve from 315534.75000
# 7/7 - 0s - loss: 384603.3125 - val_loss: 498347.3438 - 499ms/epoch - 71ms/step
# Epoch 796/2000
#
# Epoch 796: loss did not improve from 315534.75000
# 7/7 - 0s - loss: 410619.0625 - val_loss: 298777.4688 - 482ms/epoch - 69ms/step
# Epoch 797/2000
#
# Epoch 797: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 353832.8125 - val_loss: 422299.2500 - 554ms/epoch - 79ms/step
# Epoch 798/2000
#
# Epoch 798: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 372098.3750 - val_loss: 301693.9688 - 508ms/epoch - 73ms/step
# Epoch 799/2000
#
# Epoch 799: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 367497.1250 - val_loss: 338607.9375 - 526ms/epoch - 75ms/step
# Epoch 800/2000
#
# Epoch 800: loss did not improve from 315534.75000
# 7/7 - 0s - loss: 405481.5312 - val_loss: 361030.8438 - 499ms/epoch - 71ms/step
# Epoch 801/2000
#
# Epoch 801: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 333471.6875 - val_loss: 328755.3125 - 509ms/epoch - 73ms/step
# Epoch 802/2000
#
# Epoch 802: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 416836.8750 - val_loss: 491837.0625 - 540ms/epoch - 77ms/step
# Epoch 803/2000
#
# Epoch 803: loss did not improve from 315534.75000
# 7/7 - 0s - loss: 382894.2188 - val_loss: 334176.2500 - 483ms/epoch - 69ms/step
# Epoch 804/2000
#
# Epoch 804: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 402539.9375 - val_loss: 280772.0312 - 505ms/epoch - 72ms/step
# Epoch 805/2000
#
# Epoch 805: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 387629.7500 - val_loss: 335717.5625 - 515ms/epoch - 74ms/step
# Epoch 806/2000
#
# Epoch 806: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 387043.5625 - val_loss: 407424.1562 - 548ms/epoch - 78ms/step
# Epoch 807/2000
#
# Epoch 807: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 405596.9688 - val_loss: 329772.7500 - 534ms/epoch - 76ms/step
# Epoch 808/2000
#
# Epoch 808: loss did not improve from 315534.75000
# 7/7 - 0s - loss: 351968.9375 - val_loss: 238027.9531 - 498ms/epoch - 71ms/step
# Epoch 809/2000
#
# Epoch 809: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 408426.9062 - val_loss: 279807.3750 - 511ms/epoch - 73ms/step
# Epoch 810/2000
#
# Epoch 810: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 381807.4062 - val_loss: 251199.7969 - 813ms/epoch - 116ms/step
# Epoch 811/2000
#
# Epoch 811: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 372210.8750 - val_loss: 286634.0000 - 1s/epoch - 148ms/step
# Epoch 812/2000
#
# Epoch 812: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 377450.9062 - val_loss: 193185.1875 - 996ms/epoch - 142ms/step
# Epoch 813/2000
#
# Epoch 813: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 353148.8125 - val_loss: 268627.4062 - 1s/epoch - 149ms/step
# Epoch 814/2000
#
# Epoch 814: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 346199.5625 - val_loss: 274650.7812 - 869ms/epoch - 124ms/step
# Epoch 815/2000
#
# Epoch 815: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 363606.4375 - val_loss: 196584.4062 - 509ms/epoch - 73ms/step
# Epoch 816/2000
#
# Epoch 816: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 381607.1562 - val_loss: 367892.5000 - 543ms/epoch - 78ms/step
# Epoch 817/2000
#
# Epoch 817: loss did not improve from 315534.75000
# 7/7 - 0s - loss: 346084.1562 - val_loss: 313058.5625 - 485ms/epoch - 69ms/step
# Epoch 818/2000
#
# Epoch 818: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 408774.8438 - val_loss: 148372.3125 - 501ms/epoch - 72ms/step
# Epoch 819/2000
#
# Epoch 819: loss did not improve from 315534.75000
# 7/7 - 0s - loss: 414386.7500 - val_loss: 271795.8438 - 491ms/epoch - 70ms/step
# Epoch 820/2000
#
# Epoch 820: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 378705.4062 - val_loss: 385434.9375 - 524ms/epoch - 75ms/step
# Epoch 821/2000
#
# Epoch 821: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 399142.9688 - val_loss: 178731.3438 - 510ms/epoch - 73ms/step
# Epoch 822/2000
#
# Epoch 822: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 369435.5938 - val_loss: 268856.9375 - 543ms/epoch - 78ms/step
# Epoch 823/2000
#
# Epoch 823: loss did not improve from 315534.75000
# 7/7 - 0s - loss: 356013.2812 - val_loss: 299093.9062 - 489ms/epoch - 70ms/step
# Epoch 824/2000
#
# Epoch 824: loss did not improve from 315534.75000
# 7/7 - 0s - loss: 374507.5938 - val_loss: 255433.4688 - 490ms/epoch - 70ms/step
# Epoch 825/2000
#
# Epoch 825: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 402918.9062 - val_loss: 197372.5312 - 580ms/epoch - 83ms/step
# Epoch 826/2000
#
# Epoch 826: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 396286.2500 - val_loss: 415913.2188 - 507ms/epoch - 72ms/step
# Epoch 827/2000
#
# Epoch 827: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 347092.0938 - val_loss: 255371.3906 - 538ms/epoch - 77ms/step
# Epoch 828/2000
#
# Epoch 828: loss did not improve from 315534.75000
# 7/7 - 0s - loss: 381127.1250 - val_loss: 343656.9688 - 488ms/epoch - 70ms/step
# Epoch 829/2000
#
# Epoch 829: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 392125.5312 - val_loss: 348595.0938 - 518ms/epoch - 74ms/step
# Epoch 830/2000
#
# Epoch 830: loss did not improve from 315534.75000
# 7/7 - 0s - loss: 375204.8750 - val_loss: 360767.5000 - 492ms/epoch - 70ms/step
# Epoch 831/2000
#
# Epoch 831: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 395219.2500 - val_loss: 347529.4688 - 506ms/epoch - 72ms/step
# Epoch 832/2000
#
# Epoch 832: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 424695.7188 - val_loss: 267823.2500 - 516ms/epoch - 74ms/step
# Epoch 833/2000
#
# Epoch 833: loss did not improve from 315534.75000
# 7/7 - 0s - loss: 394648.2500 - val_loss: 293189.1562 - 498ms/epoch - 71ms/step
# Epoch 834/2000
#
# Epoch 834: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 411628.2500 - val_loss: 348353.8750 - 1s/epoch - 147ms/step
# Epoch 835/2000
#
# Epoch 835: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 374510.1562 - val_loss: 308158.2188 - 981ms/epoch - 140ms/step
# Epoch 836/2000
#
# Epoch 836: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 342539.3125 - val_loss: 251817.9375 - 1s/epoch - 151ms/step
# Epoch 837/2000
#
# Epoch 837: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 401218.8438 - val_loss: 459968.9062 - 986ms/epoch - 141ms/step
# Epoch 838/2000
#
# Epoch 838: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 424587.6250 - val_loss: 316824.4688 - 714ms/epoch - 102ms/step
# Epoch 839/2000
#
# Epoch 839: loss did not improve from 315534.75000
# 7/7 - 0s - loss: 373542.0625 - val_loss: 229684.3281 - 499ms/epoch - 71ms/step
# Epoch 840/2000
#
# Epoch 840: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 395420.0625 - val_loss: 363185.9062 - 503ms/epoch - 72ms/step
# Epoch 841/2000
#
# Epoch 841: loss did not improve from 315534.75000
# 7/7 - 0s - loss: 401241.5312 - val_loss: 277360.0000 - 492ms/epoch - 70ms/step
# Epoch 842/2000
#
# Epoch 842: loss did not improve from 315534.75000
# 7/7 - 0s - loss: 370097.9688 - val_loss: 360454.2188 - 484ms/epoch - 69ms/step
# Epoch 843/2000
#
# Epoch 843: loss did not improve from 315534.75000
# 7/7 - 0s - loss: 352691.7188 - val_loss: 355241.4375 - 490ms/epoch - 70ms/step
# Epoch 844/2000
#
# Epoch 844: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 372552.7188 - val_loss: 291742.7812 - 502ms/epoch - 72ms/step
# Epoch 845/2000
#
# Epoch 845: loss did not improve from 315534.75000
# 7/7 - 0s - loss: 371701.4688 - val_loss: 322801.0000 - 483ms/epoch - 69ms/step
# Epoch 846/2000
#
# Epoch 846: loss did not improve from 315534.75000
# 7/7 - 0s - loss: 385758.7500 - val_loss: 296087.8438 - 495ms/epoch - 71ms/step
# Epoch 847/2000
#
# Epoch 847: loss did not improve from 315534.75000
# 7/7 - 0s - loss: 382724.4375 - val_loss: 286601.1875 - 482ms/epoch - 69ms/step
# Epoch 848/2000
#
# Epoch 848: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 385580.8438 - val_loss: 250697.5938 - 526ms/epoch - 75ms/step
# Epoch 849/2000
#
# Epoch 849: loss did not improve from 315534.75000
# 7/7 - 0s - loss: 339359.6250 - val_loss: 219306.6719 - 485ms/epoch - 69ms/step
# Epoch 850/2000
#
# Epoch 850: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 359211.6875 - val_loss: 193453.6094 - 543ms/epoch - 78ms/step
# Epoch 851/2000
#
# Epoch 851: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 412190.2188 - val_loss: 168683.2812 - 516ms/epoch - 74ms/step
# Epoch 852/2000
#
# Epoch 852: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 374594.2188 - val_loss: 268219.2188 - 526ms/epoch - 75ms/step
# Epoch 853/2000
#
# Epoch 853: loss did not improve from 315534.75000
# 7/7 - 0s - loss: 370191.8125 - val_loss: 186253.4688 - 485ms/epoch - 69ms/step
# Epoch 854/2000
#
# Epoch 854: loss did not improve from 315534.75000
# 7/7 - 1s - loss: 349535.6250 - val_loss: 292531.4375 - 544ms/epoch - 78ms/step
# Epoch 855/2000
#
# Epoch 855: loss improved from 315534.75000 to 315041.68750, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 315041.6875 - val_loss: 241568.8906 - 739ms/epoch - 106ms/step
# Epoch 856/2000
#
# Epoch 856: loss did not improve from 315041.68750
# 7/7 - 1s - loss: 344774.7500 - val_loss: 238431.3125 - 503ms/epoch - 72ms/step
# Epoch 857/2000
#
# Epoch 857: loss did not improve from 315041.68750
# 7/7 - 1s - loss: 355677.4062 - val_loss: 265273.0312 - 673ms/epoch - 96ms/step
# Epoch 858/2000
#
# Epoch 858: loss did not improve from 315041.68750
# 7/7 - 1s - loss: 358199.0938 - val_loss: 211697.2188 - 956ms/epoch - 137ms/step
# Epoch 859/2000
#
# Epoch 859: loss improved from 315041.68750 to 313636.93750, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 313636.9375 - val_loss: 208517.3281 - 1s/epoch - 193ms/step
# Epoch 860/2000
#
# Epoch 860: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 378181.2500 - val_loss: 203021.4688 - 1s/epoch - 149ms/step
# Epoch 861/2000
#
# Epoch 861: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 391655.0312 - val_loss: 195487.9219 - 878ms/epoch - 125ms/step
# Epoch 862/2000
#
# Epoch 862: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 369319.1875 - val_loss: 282614.5000 - 506ms/epoch - 72ms/step
# Epoch 863/2000
#
# Epoch 863: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 395819.3125 - val_loss: 269051.0312 - 529ms/epoch - 76ms/step
# Epoch 864/2000
#
# Epoch 864: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 347523.9375 - val_loss: 133431.2500 - 541ms/epoch - 77ms/step
# Epoch 865/2000
#
# Epoch 865: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 412302.0000 - val_loss: 244970.4531 - 501ms/epoch - 72ms/step
# Epoch 866/2000
#
# Epoch 866: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 406232.7188 - val_loss: 340198.9688 - 505ms/epoch - 72ms/step
# Epoch 867/2000
#
# Epoch 867: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 382734.7500 - val_loss: 92242.4688 - 582ms/epoch - 83ms/step
# Epoch 868/2000
#
# Epoch 868: loss did not improve from 313636.93750
# 7/7 - 0s - loss: 328499.7188 - val_loss: 335650.2188 - 499ms/epoch - 71ms/step
# Epoch 869/2000
#
# Epoch 869: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 344339.8125 - val_loss: 238050.6094 - 573ms/epoch - 82ms/step
# Epoch 870/2000
#
# Epoch 870: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 336835.1250 - val_loss: 184142.5469 - 502ms/epoch - 72ms/step
# Epoch 871/2000
#
# Epoch 871: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 349862.8438 - val_loss: 327439.9688 - 537ms/epoch - 77ms/step
# Epoch 872/2000
#
# Epoch 872: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 334951.5312 - val_loss: 149608.3281 - 522ms/epoch - 75ms/step
# Epoch 873/2000
#
# Epoch 873: loss did not improve from 313636.93750
# 7/7 - 0s - loss: 383809.9688 - val_loss: 299557.0625 - 483ms/epoch - 69ms/step
# Epoch 874/2000
#
# Epoch 874: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 374655.1562 - val_loss: 223751.6719 - 542ms/epoch - 77ms/step
# Epoch 875/2000
#
# Epoch 875: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 363201.4688 - val_loss: 260705.8750 - 522ms/epoch - 75ms/step
# Epoch 876/2000
#
# Epoch 876: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 327509.1250 - val_loss: 326354.6875 - 564ms/epoch - 81ms/step
# Epoch 877/2000
#
# Epoch 877: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 354543.9375 - val_loss: 241738.7344 - 536ms/epoch - 77ms/step
# Epoch 878/2000
#
# Epoch 878: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 375983.2812 - val_loss: 277978.8125 - 504ms/epoch - 72ms/step
# Epoch 879/2000
#
# Epoch 879: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 405337.7188 - val_loss: 119180.1094 - 537ms/epoch - 77ms/step
# Epoch 880/2000
#
# Epoch 880: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 384802.6562 - val_loss: 297014.0938 - 665ms/epoch - 95ms/step
# Epoch 881/2000
#
# Epoch 881: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 372777.0625 - val_loss: 250349.9531 - 998ms/epoch - 143ms/step
# Epoch 882/2000
#
# Epoch 882: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 374567.0625 - val_loss: 252864.2031 - 1s/epoch - 144ms/step
# Epoch 883/2000
#
# Epoch 883: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 345503.0938 - val_loss: 349271.7812 - 1s/epoch - 158ms/step
# Epoch 884/2000
#
# Epoch 884: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 375451.1875 - val_loss: 351747.0312 - 961ms/epoch - 137ms/step
# Epoch 885/2000
#
# Epoch 885: loss did not improve from 313636.93750
# 7/7 - 0s - loss: 353807.3125 - val_loss: 177043.6250 - 498ms/epoch - 71ms/step
# Epoch 886/2000
#
# Epoch 886: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 381331.1250 - val_loss: 355243.0938 - 501ms/epoch - 72ms/step
# Epoch 887/2000
#
# Epoch 887: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 398126.0938 - val_loss: 248514.4062 - 511ms/epoch - 73ms/step
# Epoch 888/2000
#
# Epoch 888: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 400634.2188 - val_loss: 278492.2812 - 515ms/epoch - 74ms/step
# Epoch 889/2000
#
# Epoch 889: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 373188.3750 - val_loss: 269391.0625 - 531ms/epoch - 76ms/step
# Epoch 890/2000
#
# Epoch 890: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 359147.9375 - val_loss: 268120.0312 - 537ms/epoch - 77ms/step
# Epoch 891/2000
#
# Epoch 891: loss did not improve from 313636.93750
# 7/7 - 0s - loss: 320133.1875 - val_loss: 344618.7812 - 480ms/epoch - 69ms/step
# Epoch 892/2000
#
# Epoch 892: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 332917.2500 - val_loss: 223831.9219 - 555ms/epoch - 79ms/step
# Epoch 893/2000
#
# Epoch 893: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 387574.5938 - val_loss: 437541.0312 - 547ms/epoch - 78ms/step
# Epoch 894/2000
#
# Epoch 894: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 391177.0312 - val_loss: 237038.9375 - 525ms/epoch - 75ms/step
# Epoch 895/2000
#
# Epoch 895: loss did not improve from 313636.93750
# 7/7 - 0s - loss: 360001.0312 - val_loss: 258887.5469 - 492ms/epoch - 70ms/step
# Epoch 896/2000
#
# Epoch 896: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 365871.4062 - val_loss: 416888.2500 - 517ms/epoch - 74ms/step
# Epoch 897/2000
#
# Epoch 897: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 384899.7188 - val_loss: 250724.1250 - 511ms/epoch - 73ms/step
# Epoch 898/2000
#
# Epoch 898: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 367498.1875 - val_loss: 366519.7500 - 517ms/epoch - 74ms/step
# Epoch 899/2000
#
# Epoch 899: loss did not improve from 313636.93750
# 7/7 - 0s - loss: 372203.1250 - val_loss: 275327.6250 - 495ms/epoch - 71ms/step
# Epoch 900/2000
#
# Epoch 900: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 406608.4062 - val_loss: 355552.3750 - 508ms/epoch - 73ms/step
# Epoch 901/2000
#
# Epoch 901: loss did not improve from 313636.93750
# 7/7 - 0s - loss: 367048.7500 - val_loss: 398927.7812 - 484ms/epoch - 69ms/step
# Epoch 902/2000
#
# Epoch 902: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 351081.0625 - val_loss: 184813.0625 - 516ms/epoch - 74ms/step
# Epoch 903/2000
#
# Epoch 903: loss did not improve from 313636.93750
# 7/7 - 0s - loss: 391320.0000 - val_loss: 189883.8750 - 493ms/epoch - 70ms/step
# Epoch 904/2000
#
# Epoch 904: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 399976.8438 - val_loss: 199302.0000 - 820ms/epoch - 117ms/step
# Epoch 905/2000
#
# Epoch 905: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 322650.5000 - val_loss: 380681.7188 - 1s/epoch - 159ms/step
# Epoch 906/2000
#
# Epoch 906: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 372458.0312 - val_loss: 249554.5312 - 967ms/epoch - 138ms/step
# Epoch 907/2000
#
# Epoch 907: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 358372.5000 - val_loss: 235194.7344 - 950ms/epoch - 136ms/step
# Epoch 908/2000
#
# Epoch 908: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 356935.7188 - val_loss: 240456.7344 - 830ms/epoch - 119ms/step
# Epoch 909/2000
#
# Epoch 909: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 377972.6875 - val_loss: 327277.0625 - 508ms/epoch - 73ms/step
# Epoch 910/2000
#
# Epoch 910: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 382982.8438 - val_loss: 249818.5781 - 505ms/epoch - 72ms/step
# Epoch 911/2000
#
# Epoch 911: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 398573.7812 - val_loss: 369499.7500 - 507ms/epoch - 72ms/step
# Epoch 912/2000
#
# Epoch 912: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 376999.7188 - val_loss: 220941.2188 - 524ms/epoch - 75ms/step
# Epoch 913/2000
#
# Epoch 913: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 369325.4062 - val_loss: 332364.5938 - 511ms/epoch - 73ms/step
# Epoch 914/2000
#
# Epoch 914: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 377409.5938 - val_loss: 201907.1094 - 566ms/epoch - 81ms/step
# Epoch 915/2000
#
# Epoch 915: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 366056.6875 - val_loss: 219945.6562 - 505ms/epoch - 72ms/step
# Epoch 916/2000
#
# Epoch 916: loss did not improve from 313636.93750
# 7/7 - 0s - loss: 318900.4375 - val_loss: 255044.6094 - 497ms/epoch - 71ms/step
# Epoch 917/2000
#
# Epoch 917: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 372801.4688 - val_loss: 253534.5156 - 517ms/epoch - 74ms/step
# Epoch 918/2000
#
# Epoch 918: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 360092.0000 - val_loss: 330290.3750 - 521ms/epoch - 74ms/step
# Epoch 919/2000
#
# Epoch 919: loss did not improve from 313636.93750
# 7/7 - 1s - loss: 366737.5312 - val_loss: 236179.0625 - 542ms/epoch - 77ms/step
# Epoch 920/2000
#
# Epoch 920: loss improved from 313636.93750 to 302559.62500, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 302559.6250 - val_loss: 394204.6562 - 751ms/epoch - 107ms/step
# Epoch 921/2000
#
# Epoch 921: loss did not improve from 302559.62500
# 7/7 - 1s - loss: 375172.8438 - val_loss: 254217.3750 - 555ms/epoch - 79ms/step
# Epoch 922/2000
#
# Epoch 922: loss did not improve from 302559.62500
# 7/7 - 0s - loss: 318449.2500 - val_loss: 312673.6250 - 491ms/epoch - 70ms/step
# Epoch 923/2000
#
# Epoch 923: loss did not improve from 302559.62500
# 7/7 - 1s - loss: 335732.4062 - val_loss: 214859.2656 - 556ms/epoch - 79ms/step
# Epoch 924/2000
#
# Epoch 924: loss did not improve from 302559.62500
# 7/7 - 0s - loss: 351660.1875 - val_loss: 228820.2031 - 495ms/epoch - 71ms/step
# Epoch 925/2000
#
# Epoch 925: loss did not improve from 302559.62500
# 7/7 - 1s - loss: 318240.5938 - val_loss: 270475.2188 - 511ms/epoch - 73ms/step
# Epoch 926/2000
#
# Epoch 926: loss did not improve from 302559.62500
# 7/7 - 0s - loss: 362836.9688 - val_loss: 194671.1875 - 490ms/epoch - 70ms/step
# Epoch 927/2000
#
# Epoch 927: loss did not improve from 302559.62500
# 7/7 - 1s - loss: 358276.7500 - val_loss: 266681.7500 - 654ms/epoch - 93ms/step
# Epoch 928/2000
#
# Epoch 928: loss improved from 302559.62500 to 300255.06250, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 300255.0625 - val_loss: 215653.3750 - 1s/epoch - 197ms/step
# Epoch 929/2000
#
# Epoch 929: loss did not improve from 300255.06250
# 7/7 - 1s - loss: 333887.1250 - val_loss: 200144.7188 - 1s/epoch - 157ms/step
# Epoch 930/2000
#
# Epoch 930: loss did not improve from 300255.06250
# 7/7 - 1s - loss: 373239.5938 - val_loss: 196566.9375 - 984ms/epoch - 141ms/step
# Epoch 931/2000
#
# Epoch 931: loss did not improve from 300255.06250
# 7/7 - 1s - loss: 348383.0938 - val_loss: 141533.2031 - 730ms/epoch - 104ms/step
# Epoch 932/2000
#
# Epoch 932: loss did not improve from 300255.06250
# 7/7 - 0s - loss: 318169.9688 - val_loss: 250081.8438 - 490ms/epoch - 70ms/step
# Epoch 933/2000
#
# Epoch 933: loss did not improve from 300255.06250
# 7/7 - 0s - loss: 332040.3125 - val_loss: 194344.2500 - 488ms/epoch - 70ms/step
# Epoch 934/2000
#
# Epoch 934: loss did not improve from 300255.06250
# 7/7 - 1s - loss: 351550.4375 - val_loss: 171468.3906 - 507ms/epoch - 72ms/step
# Epoch 935/2000
#
# Epoch 935: loss did not improve from 300255.06250
# 7/7 - 0s - loss: 336723.0938 - val_loss: 249359.0625 - 483ms/epoch - 69ms/step
# Epoch 936/2000
#
# Epoch 936: loss did not improve from 300255.06250
# 7/7 - 1s - loss: 307614.4688 - val_loss: 194073.0625 - 513ms/epoch - 73ms/step
# Epoch 937/2000
#
# Epoch 937: loss did not improve from 300255.06250
# 7/7 - 1s - loss: 318613.2500 - val_loss: 282100.6562 - 503ms/epoch - 72ms/step
# Epoch 938/2000
#
# Epoch 938: loss did not improve from 300255.06250
# 7/7 - 1s - loss: 323139.5000 - val_loss: 213112.4844 - 523ms/epoch - 75ms/step
# Epoch 939/2000
#
# Epoch 939: loss did not improve from 300255.06250
# 7/7 - 1s - loss: 309980.6250 - val_loss: 147319.4219 - 515ms/epoch - 74ms/step
# Epoch 940/2000
#
# Epoch 940: loss improved from 300255.06250 to 298299.34375, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 298299.3438 - val_loss: 247694.1562 - 756ms/epoch - 108ms/step
# Epoch 941/2000
#
# Epoch 941: loss did not improve from 298299.34375
# 7/7 - 1s - loss: 351039.9062 - val_loss: 232112.3281 - 508ms/epoch - 73ms/step
# Epoch 942/2000
#
# Epoch 942: loss did not improve from 298299.34375
# 7/7 - 0s - loss: 381362.1562 - val_loss: 205430.8594 - 497ms/epoch - 71ms/step
# Epoch 943/2000
#
# Epoch 943: loss did not improve from 298299.34375
# 7/7 - 1s - loss: 324604.9375 - val_loss: 133470.7344 - 563ms/epoch - 80ms/step
# Epoch 944/2000
#
# Epoch 944: loss did not improve from 298299.34375
# 7/7 - 1s - loss: 304289.9062 - val_loss: 161466.9688 - 505ms/epoch - 72ms/step
# Epoch 945/2000
#
# Epoch 945: loss improved from 298299.34375 to 296123.53125, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 296123.5312 - val_loss: 111056.6562 - 812ms/epoch - 116ms/step
# Epoch 946/2000
#
# Epoch 946: loss did not improve from 296123.53125
# 7/7 - 1s - loss: 347393.3438 - val_loss: 237643.1094 - 532ms/epoch - 76ms/step
# Epoch 947/2000
#
# Epoch 947: loss did not improve from 296123.53125
# 7/7 - 1s - loss: 332139.3438 - val_loss: 185298.1875 - 513ms/epoch - 73ms/step
# Epoch 948/2000
#
# Epoch 948: loss did not improve from 296123.53125
# 7/7 - 1s - loss: 344648.8750 - val_loss: 82247.1250 - 515ms/epoch - 74ms/step
# Epoch 949/2000
#
# Epoch 949: loss did not improve from 296123.53125
# 7/7 - 1s - loss: 381653.8438 - val_loss: 279723.8438 - 585ms/epoch - 84ms/step
# Epoch 950/2000
#
# Epoch 950: loss did not improve from 296123.53125
# 7/7 - 1s - loss: 345229.5625 - val_loss: 249871.2656 - 1s/epoch - 145ms/step
# Epoch 951/2000
#
# Epoch 951: loss did not improve from 296123.53125
# 7/7 - 1s - loss: 384767.6250 - val_loss: 135859.3125 - 1s/epoch - 146ms/step
# Epoch 952/2000
#
# Epoch 952: loss did not improve from 296123.53125
# 7/7 - 1s - loss: 344333.4688 - val_loss: 193302.7344 - 940ms/epoch - 134ms/step
# Epoch 953/2000
#
# Epoch 953: loss did not improve from 296123.53125
# 7/7 - 1s - loss: 335523.7188 - val_loss: 226488.3438 - 1s/epoch - 144ms/step
# Epoch 954/2000
#
# Epoch 954: loss did not improve from 296123.53125
# 7/7 - 1s - loss: 338449.7188 - val_loss: 60234.4492 - 635ms/epoch - 91ms/step
# Epoch 955/2000
#
# Epoch 955: loss did not improve from 296123.53125
# 7/7 - 1s - loss: 338232.0625 - val_loss: 285993.9688 - 528ms/epoch - 75ms/step
# Epoch 956/2000
#
# Epoch 956: loss did not improve from 296123.53125
# 7/7 - 0s - loss: 382913.1562 - val_loss: 153358.8750 - 493ms/epoch - 70ms/step
# Epoch 957/2000
#
# Epoch 957: loss did not improve from 296123.53125
# 7/7 - 1s - loss: 331626.3125 - val_loss: 153144.0000 - 574ms/epoch - 82ms/step
# Epoch 958/2000
#
# Epoch 958: loss did not improve from 296123.53125
# 7/7 - 1s - loss: 332801.6875 - val_loss: 333365.3125 - 518ms/epoch - 74ms/step
# Epoch 959/2000
#
# Epoch 959: loss did not improve from 296123.53125
# 7/7 - 1s - loss: 357564.8750 - val_loss: 92253.2656 - 510ms/epoch - 73ms/step
# Epoch 960/2000
#
# Epoch 960: loss did not improve from 296123.53125
# 7/7 - 1s - loss: 312041.2812 - val_loss: 104302.3047 - 509ms/epoch - 73ms/step
# Epoch 961/2000
#
# Epoch 961: loss did not improve from 296123.53125
# 7/7 - 1s - loss: 373907.5938 - val_loss: 163229.5469 - 511ms/epoch - 73ms/step
# Epoch 962/2000
#
# Epoch 962: loss did not improve from 296123.53125
# 7/7 - 0s - loss: 330052.5312 - val_loss: 155756.8594 - 486ms/epoch - 69ms/step
# Epoch 963/2000
#
# Epoch 963: loss did not improve from 296123.53125
# 7/7 - 0s - loss: 357419.9062 - val_loss: 116779.6328 - 495ms/epoch - 71ms/step
# Epoch 964/2000
#
# Epoch 964: loss did not improve from 296123.53125
# 7/7 - 1s - loss: 329631.3438 - val_loss: 153635.5469 - 528ms/epoch - 75ms/step
# Epoch 965/2000
#
# Epoch 965: loss did not improve from 296123.53125
# 7/7 - 1s - loss: 317141.2500 - val_loss: 79193.2344 - 550ms/epoch - 79ms/step
# Epoch 966/2000
#
# Epoch 966: loss did not improve from 296123.53125
# 7/7 - 1s - loss: 406687.5938 - val_loss: 103563.1016 - 507ms/epoch - 72ms/step
# Epoch 967/2000
#
# Epoch 967: loss did not improve from 296123.53125
# 7/7 - 1s - loss: 350204.0312 - val_loss: 225555.7188 - 571ms/epoch - 82ms/step
# Epoch 968/2000
#
# Epoch 968: loss did not improve from 296123.53125
# 7/7 - 1s - loss: 410518.2188 - val_loss: 94629.8750 - 507ms/epoch - 72ms/step
# Epoch 969/2000
#
# Epoch 969: loss did not improve from 296123.53125
# 7/7 - 1s - loss: 343656.8125 - val_loss: 129501.1953 - 534ms/epoch - 76ms/step
# Epoch 970/2000
#
# Epoch 970: loss did not improve from 296123.53125
# 7/7 - 1s - loss: 374756.0312 - val_loss: 161304.4531 - 506ms/epoch - 72ms/step
# Epoch 971/2000
#
# Epoch 971: loss did not improve from 296123.53125
# 7/7 - 1s - loss: 353178.2500 - val_loss: 65411.5156 - 522ms/epoch - 75ms/step
# Epoch 972/2000
#
# Epoch 972: loss did not improve from 296123.53125
# 7/7 - 0s - loss: 370624.2812 - val_loss: 272646.9688 - 479ms/epoch - 68ms/step
# Epoch 973/2000
#
# Epoch 973: loss did not improve from 296123.53125
# 7/7 - 1s - loss: 328158.8750 - val_loss: 88540.1875 - 766ms/epoch - 109ms/step
# Epoch 974/2000
#
# Epoch 974: loss did not improve from 296123.53125
# 7/7 - 1s - loss: 372686.8750 - val_loss: 307458.8438 - 874ms/epoch - 125ms/step
# Epoch 975/2000
#
# Epoch 975: loss did not improve from 296123.53125
# 7/7 - 1s - loss: 332403.6250 - val_loss: 124364.5078 - 1s/epoch - 151ms/step
# Epoch 976/2000
#
# Epoch 976: loss did not improve from 296123.53125
# 7/7 - 1s - loss: 308475.7812 - val_loss: 172169.3125 - 995ms/epoch - 142ms/step
# Epoch 977/2000
#
# Epoch 977: loss did not improve from 296123.53125
# 7/7 - 1s - loss: 378624.4062 - val_loss: 87347.9922 - 896ms/epoch - 128ms/step
# Epoch 978/2000
#
# Epoch 978: loss did not improve from 296123.53125
# 7/7 - 0s - loss: 322440.8750 - val_loss: 161071.9844 - 491ms/epoch - 70ms/step
# Epoch 979/2000
#
# Epoch 979: loss improved from 296123.53125 to 291887.59375, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 291887.5938 - val_loss: 129606.4922 - 749ms/epoch - 107ms/step
# Epoch 980/2000
#
# Epoch 980: loss did not improve from 291887.59375
# 7/7 - 1s - loss: 297024.6875 - val_loss: 199875.4688 - 525ms/epoch - 75ms/step
# Epoch 981/2000
#
# Epoch 981: loss did not improve from 291887.59375
# 7/7 - 0s - loss: 356569.9062 - val_loss: 120111.2891 - 498ms/epoch - 71ms/step
# Epoch 982/2000
#
# Epoch 982: loss did not improve from 291887.59375
# 7/7 - 1s - loss: 345915.6875 - val_loss: 122297.3438 - 503ms/epoch - 72ms/step
# Epoch 983/2000
#
# Epoch 983: loss did not improve from 291887.59375
# 7/7 - 0s - loss: 340497.1875 - val_loss: 90639.1641 - 498ms/epoch - 71ms/step
# Epoch 984/2000
#
# Epoch 984: loss did not improve from 291887.59375
# 7/7 - 1s - loss: 306501.1562 - val_loss: 143978.9219 - 503ms/epoch - 72ms/step
# Epoch 985/2000
#
# Epoch 985: loss did not improve from 291887.59375
# 7/7 - 0s - loss: 327596.0312 - val_loss: 181011.5938 - 481ms/epoch - 69ms/step
# Epoch 986/2000
#
# Epoch 986: loss improved from 291887.59375 to 267654.18750, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 267654.1875 - val_loss: 154062.6875 - 853ms/epoch - 122ms/step
# Epoch 987/2000
#
# Epoch 987: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 305051.0625 - val_loss: 177538.9844 - 523ms/epoch - 75ms/step
# Epoch 988/2000
#
# Epoch 988: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 311195.7812 - val_loss: 161812.3125 - 509ms/epoch - 73ms/step
# Epoch 989/2000
#
# Epoch 989: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 325254.1875 - val_loss: 159410.3125 - 555ms/epoch - 79ms/step
# Epoch 990/2000
#
# Epoch 990: loss did not improve from 267654.18750
# 7/7 - 0s - loss: 342988.2188 - val_loss: 134866.8906 - 488ms/epoch - 70ms/step
# Epoch 991/2000
#
# Epoch 991: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 353306.9688 - val_loss: 159886.9531 - 508ms/epoch - 73ms/step
# Epoch 992/2000
#
# Epoch 992: loss did not improve from 267654.18750
# 7/7 - 0s - loss: 332429.3438 - val_loss: 164941.1250 - 487ms/epoch - 70ms/step
# Epoch 993/2000
#
# Epoch 993: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 283219.0625 - val_loss: 82140.9219 - 512ms/epoch - 73ms/step
# Epoch 994/2000
#
# Epoch 994: loss did not improve from 267654.18750
# 7/7 - 0s - loss: 344500.1875 - val_loss: 255933.6094 - 494ms/epoch - 71ms/step
# Epoch 995/2000
#
# Epoch 995: loss did not improve from 267654.18750
# 7/7 - 0s - loss: 329207.1250 - val_loss: 48588.3672 - 498ms/epoch - 71ms/step
# Epoch 996/2000
#
# Epoch 996: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 280801.4688 - val_loss: 198467.7188 - 978ms/epoch - 140ms/step
# Epoch 997/2000
#
# Epoch 997: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 356176.4062 - val_loss: 117482.3906 - 1s/epoch - 148ms/step
# Epoch 998/2000
#
# Epoch 998: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 322903.0312 - val_loss: 139731.2031 - 1s/epoch - 153ms/step
# Epoch 999/2000
#
# Epoch 999: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 331248.6562 - val_loss: 85429.2812 - 1s/epoch - 153ms/step
# Epoch 1000/2000
#
# Epoch 1000: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 325974.5938 - val_loss: 93846.4297 - 578ms/epoch - 83ms/step
# Epoch 1001/2000
#
# Epoch 1001: loss did not improve from 267654.18750
# 7/7 - 0s - loss: 360859.8125 - val_loss: 68450.6953 - 494ms/epoch - 71ms/step
# Epoch 1002/2000
#
# Epoch 1002: loss did not improve from 267654.18750
# 7/7 - 0s - loss: 268605.1562 - val_loss: 140080.1094 - 482ms/epoch - 69ms/step
# Epoch 1003/2000
#
# Epoch 1003: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 302510.8438 - val_loss: 99694.7344 - 530ms/epoch - 76ms/step
# Epoch 1004/2000
#
# Epoch 1004: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 360269.0312 - val_loss: 144268.1250 - 553ms/epoch - 79ms/step
# Epoch 1005/2000
#
# Epoch 1005: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 308693.5312 - val_loss: 109161.1406 - 521ms/epoch - 74ms/step
# Epoch 1006/2000
#
# Epoch 1006: loss did not improve from 267654.18750
# 7/7 - 0s - loss: 328036.1875 - val_loss: 108004.6953 - 500ms/epoch - 71ms/step
# Epoch 1007/2000
#
# Epoch 1007: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 280180.9688 - val_loss: 118660.9688 - 555ms/epoch - 79ms/step
# Epoch 1008/2000
#
# Epoch 1008: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 284424.6562 - val_loss: 98318.0781 - 524ms/epoch - 75ms/step
# Epoch 1009/2000
#
# Epoch 1009: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 339294.3125 - val_loss: 103883.4688 - 508ms/epoch - 73ms/step
# Epoch 1010/2000
#
# Epoch 1010: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 321250.9688 - val_loss: 143390.2188 - 542ms/epoch - 77ms/step
# Epoch 1011/2000
#
# Epoch 1011: loss did not improve from 267654.18750
# 7/7 - 0s - loss: 323927.7188 - val_loss: 101043.5312 - 494ms/epoch - 71ms/step
# Epoch 1012/2000
#
# Epoch 1012: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 300458.2812 - val_loss: 111611.7734 - 502ms/epoch - 72ms/step
# Epoch 1013/2000
#
# Epoch 1013: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 290180.1875 - val_loss: 170181.3906 - 531ms/epoch - 76ms/step
# Epoch 1014/2000
#
# Epoch 1014: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 293060.1875 - val_loss: 124868.0781 - 583ms/epoch - 83ms/step
# Epoch 1015/2000
#
# Epoch 1015: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 363267.5312 - val_loss: 95242.1094 - 584ms/epoch - 83ms/step
# Epoch 1016/2000
#
# Epoch 1016: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 318648.3750 - val_loss: 170498.9219 - 536ms/epoch - 77ms/step
# Epoch 1017/2000
#
# Epoch 1017: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 319070.3125 - val_loss: 68691.1875 - 522ms/epoch - 75ms/step
# Epoch 1018/2000
#
# Epoch 1018: loss did not improve from 267654.18750
# 7/7 - 0s - loss: 311404.0625 - val_loss: 157069.0469 - 498ms/epoch - 71ms/step
# Epoch 1019/2000
#
# Epoch 1019: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 299493.4688 - val_loss: 119322.4688 - 849ms/epoch - 121ms/step
# Epoch 1020/2000
#
# Epoch 1020: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 304368.3750 - val_loss: 103595.1875 - 1s/epoch - 156ms/step
# Epoch 1021/2000
#
# Epoch 1021: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 329614.5938 - val_loss: 129441.9375 - 1s/epoch - 149ms/step
# Epoch 1022/2000
#
# Epoch 1022: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 280672.3125 - val_loss: 120839.7734 - 1s/epoch - 144ms/step
# Epoch 1023/2000
#
# Epoch 1023: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 326894.3125 - val_loss: 126997.5703 - 742ms/epoch - 106ms/step
# Epoch 1024/2000
#
# Epoch 1024: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 307600.1875 - val_loss: 89097.2344 - 501ms/epoch - 72ms/step
# Epoch 1025/2000
#
# Epoch 1025: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 304728.5000 - val_loss: 79154.6875 - 536ms/epoch - 77ms/step
# Epoch 1026/2000
#
# Epoch 1026: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 338316.0938 - val_loss: 98304.0000 - 500ms/epoch - 71ms/step
# Epoch 1027/2000
#
# Epoch 1027: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 278228.8750 - val_loss: 160708.0469 - 510ms/epoch - 73ms/step
# Epoch 1028/2000
#
# Epoch 1028: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 321095.9688 - val_loss: 97372.6719 - 519ms/epoch - 74ms/step
# Epoch 1029/2000
#
# Epoch 1029: loss did not improve from 267654.18750
# 7/7 - 0s - loss: 350925.1562 - val_loss: 103231.0625 - 490ms/epoch - 70ms/step
# Epoch 1030/2000
#
# Epoch 1030: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 285614.9062 - val_loss: 71506.8203 - 529ms/epoch - 76ms/step
# Epoch 1031/2000
#
# Epoch 1031: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 308888.0000 - val_loss: 133979.0000 - 502ms/epoch - 72ms/step
# Epoch 1032/2000
#
# Epoch 1032: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 294329.5938 - val_loss: 71611.1641 - 572ms/epoch - 82ms/step
# Epoch 1033/2000
#
# Epoch 1033: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 324416.0312 - val_loss: 156907.1250 - 514ms/epoch - 73ms/step
# Epoch 1034/2000
#
# Epoch 1034: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 297767.3750 - val_loss: 55662.4492 - 546ms/epoch - 78ms/step
# Epoch 1035/2000
#
# Epoch 1035: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 342610.0938 - val_loss: 124039.4453 - 539ms/epoch - 77ms/step
# Epoch 1036/2000
#
# Epoch 1036: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 345525.4688 - val_loss: 41588.4531 - 520ms/epoch - 74ms/step
# Epoch 1037/2000
#
# Epoch 1037: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 319526.5312 - val_loss: 119965.3594 - 509ms/epoch - 73ms/step
# Epoch 1038/2000
#
# Epoch 1038: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 308136.4375 - val_loss: 82407.9531 - 520ms/epoch - 74ms/step
# Epoch 1039/2000
#
# Epoch 1039: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 319852.4688 - val_loss: 62820.6523 - 523ms/epoch - 75ms/step
# Epoch 1040/2000
#
# Epoch 1040: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 324603.6250 - val_loss: 155619.7500 - 508ms/epoch - 73ms/step
# Epoch 1041/2000
#
# Epoch 1041: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 318136.0625 - val_loss: 62434.1445 - 508ms/epoch - 73ms/step
# Epoch 1042/2000
#
# Epoch 1042: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 303934.5000 - val_loss: 109193.3125 - 672ms/epoch - 96ms/step
# Epoch 1043/2000
#
# Epoch 1043: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 287321.2188 - val_loss: 155179.4531 - 990ms/epoch - 141ms/step
# Epoch 1044/2000
#
# Epoch 1044: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 325045.3438 - val_loss: 110996.9688 - 1s/epoch - 144ms/step
# Epoch 1045/2000
#
# Epoch 1045: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 304290.4688 - val_loss: 68991.2266 - 1s/epoch - 148ms/step
# Epoch 1046/2000
#
# Epoch 1046: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 274386.0938 - val_loss: 105159.0625 - 899ms/epoch - 128ms/step
# Epoch 1047/2000
#
# Epoch 1047: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 326463.3438 - val_loss: 79664.5625 - 558ms/epoch - 80ms/step
# Epoch 1048/2000
#
# Epoch 1048: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 268188.3750 - val_loss: 104970.0625 - 512ms/epoch - 73ms/step
# Epoch 1049/2000
#
# Epoch 1049: loss did not improve from 267654.18750
# 7/7 - 0s - loss: 327988.5000 - val_loss: 53760.5938 - 480ms/epoch - 69ms/step
# Epoch 1050/2000
#
# Epoch 1050: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 339745.6875 - val_loss: 162646.9844 - 547ms/epoch - 78ms/step
# Epoch 1051/2000
#
# Epoch 1051: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 306975.1875 - val_loss: 100485.1328 - 545ms/epoch - 78ms/step
# Epoch 1052/2000
#
# Epoch 1052: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 353661.5312 - val_loss: 80875.2344 - 535ms/epoch - 76ms/step
# Epoch 1053/2000
#
# Epoch 1053: loss did not improve from 267654.18750
# 7/7 - 0s - loss: 284427.0938 - val_loss: 91466.5312 - 491ms/epoch - 70ms/step
# Epoch 1054/2000
#
# Epoch 1054: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 292214.0625 - val_loss: 75271.5547 - 504ms/epoch - 72ms/step
# Epoch 1055/2000
#
# Epoch 1055: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 316121.9688 - val_loss: 142811.3438 - 500ms/epoch - 71ms/step
# Epoch 1056/2000
#
# Epoch 1056: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 312139.0625 - val_loss: 47387.6367 - 571ms/epoch - 82ms/step
# Epoch 1057/2000
#
# Epoch 1057: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 330246.5938 - val_loss: 129599.4688 - 504ms/epoch - 72ms/step
# Epoch 1058/2000
#
# Epoch 1058: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 312337.7500 - val_loss: 31237.3398 - 540ms/epoch - 77ms/step
# Epoch 1059/2000
#
# Epoch 1059: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 299373.8438 - val_loss: 111578.2031 - 544ms/epoch - 78ms/step
# Epoch 1060/2000
#
# Epoch 1060: loss did not improve from 267654.18750
# 7/7 - 0s - loss: 344572.6562 - val_loss: 107233.5938 - 488ms/epoch - 70ms/step
# Epoch 1061/2000
#
# Epoch 1061: loss did not improve from 267654.18750
# 7/7 - 0s - loss: 318951.5938 - val_loss: 85319.1094 - 486ms/epoch - 69ms/step
# Epoch 1062/2000
#
# Epoch 1062: loss did not improve from 267654.18750
# 7/7 - 0s - loss: 305424.0000 - val_loss: 103046.3281 - 498ms/epoch - 71ms/step
# Epoch 1063/2000
#
# Epoch 1063: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 268378.7812 - val_loss: 45573.5195 - 565ms/epoch - 81ms/step
# Epoch 1064/2000
#
# Epoch 1064: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 305868.3750 - val_loss: 66137.9766 - 545ms/epoch - 78ms/step
# Epoch 1065/2000
#
# Epoch 1065: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 276967.5625 - val_loss: 42509.1367 - 530ms/epoch - 76ms/step
# Epoch 1066/2000
#
# Epoch 1066: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 288648.8438 - val_loss: 80237.6562 - 936ms/epoch - 134ms/step
# Epoch 1067/2000
#
# Epoch 1067: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 292586.6875 - val_loss: 71879.2734 - 1s/epoch - 154ms/step
# Epoch 1068/2000
#
# Epoch 1068: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 330289.7812 - val_loss: 55730.6133 - 977ms/epoch - 140ms/step
# Epoch 1069/2000
#
# Epoch 1069: loss did not improve from 267654.18750
# 7/7 - 1s - loss: 307294.0938 - val_loss: 132306.4219 - 948ms/epoch - 135ms/step
# Epoch 1070/2000
#
# ...
# Epoch 1892: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 205786.6562 - val_loss: 8307.3965 - 539ms/epoch - 77ms/step
# Epoch 1893/2000
#
# Epoch 1893: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 237584.6406 - val_loss: 6365.5332 - 512ms/epoch - 73ms/step
# Epoch 1894/2000
#
# Epoch 1894: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 234893.7500 - val_loss: 9460.6904 - 547ms/epoch - 78ms/step
# Epoch 1895/2000
#
# Epoch 1895: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 257784.9062 - val_loss: 4911.1162 - 525ms/epoch - 75ms/step
# Epoch 1896/2000
#
# Epoch 1896: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 243334.4219 - val_loss: 5025.5566 - 501ms/epoch - 72ms/step
# Epoch 1897/2000
#
# Epoch 1897: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 230350.1094 - val_loss: 5422.1548 - 589ms/epoch - 84ms/step
# Epoch 1898/2000
#
# Epoch 1898: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 238126.4688 - val_loss: 7292.0352 - 561ms/epoch - 80ms/step
# Epoch 1899/2000
#
# Epoch 1899: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 240387.9844 - val_loss: 10382.9414 - 512ms/epoch - 73ms/step
# Epoch 1900/2000
#
# Epoch 1900: loss did not improve from 181796.85938
# 7/7 - 0s - loss: 242499.5469 - val_loss: 15378.4658 - 497ms/epoch - 71ms/step
# Epoch 1901/2000
#
# Epoch 1901: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 232224.8438 - val_loss: 5886.1357 - 536ms/epoch - 77ms/step
# Epoch 1902/2000
#
# Epoch 1902: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 212592.9531 - val_loss: 5227.8291 - 569ms/epoch - 81ms/step
# Epoch 1903/2000
#
# Epoch 1903: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 251568.0000 - val_loss: 6303.7817 - 531ms/epoch - 76ms/step
# Epoch 1904/2000
#
# Epoch 1904: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 236015.2969 - val_loss: 5653.8911 - 526ms/epoch - 75ms/step
# Epoch 1905/2000
#
# Epoch 1905: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 212220.2500 - val_loss: 8262.7402 - 573ms/epoch - 82ms/step
# Epoch 1906/2000
#
# Epoch 1906: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 214218.7031 - val_loss: 5570.7046 - 515ms/epoch - 74ms/step
# Epoch 1907/2000
#
# Epoch 1907: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 236156.9844 - val_loss: 5596.1377 - 887ms/epoch - 127ms/step
# Epoch 1908/2000
#
# Epoch 1908: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 250063.1250 - val_loss: 8970.8115 - 993ms/epoch - 142ms/step
# Epoch 1909/2000
#
# Epoch 1909: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 220875.4844 - val_loss: 6253.1860 - 1s/epoch - 155ms/step
# Epoch 1910/2000
#
# Epoch 1910: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 214066.1562 - val_loss: 7178.5493 - 975ms/epoch - 139ms/step
# Epoch 1911/2000
#
# Epoch 1911: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 202045.5625 - val_loss: 5581.1724 - 801ms/epoch - 114ms/step
# Epoch 1912/2000
#
# Epoch 1912: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 247273.7344 - val_loss: 8105.0938 - 517ms/epoch - 74ms/step
# Epoch 1913/2000
#
# Epoch 1913: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 230931.7500 - val_loss: 5043.0737 - 522ms/epoch - 75ms/step
# Epoch 1914/2000
#
# Epoch 1914: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 237873.6406 - val_loss: 4947.2949 - 509ms/epoch - 73ms/step
# Epoch 1915/2000
#
# Epoch 1915: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 221833.7969 - val_loss: 7688.9731 - 539ms/epoch - 77ms/step
# Epoch 1916/2000
#
# Epoch 1916: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 250088.2500 - val_loss: 6090.4443 - 514ms/epoch - 73ms/step
# Epoch 1917/2000
#
# Epoch 1917: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 231185.9688 - val_loss: 11929.9639 - 526ms/epoch - 75ms/step
# Epoch 1918/2000
#
# Epoch 1918: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 237051.7500 - val_loss: 5472.0229 - 567ms/epoch - 81ms/step
# Epoch 1919/2000
#
# Epoch 1919: loss did not improve from 181796.85938
# 7/7 - 0s - loss: 226975.0781 - val_loss: 7423.7222 - 493ms/epoch - 70ms/step
# Epoch 1920/2000
#
# Epoch 1920: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 224572.7031 - val_loss: 4999.6851 - 509ms/epoch - 73ms/step
# Epoch 1921/2000
#
# Epoch 1921: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 226370.7500 - val_loss: 10669.6533 - 555ms/epoch - 79ms/step
# Epoch 1922/2000
#
# Epoch 1922: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 239352.4844 - val_loss: 12040.2988 - 546ms/epoch - 78ms/step
# Epoch 1923/2000
#
# Epoch 1923: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 235469.9219 - val_loss: 5221.0161 - 525ms/epoch - 75ms/step
# Epoch 1924/2000
#
# Epoch 1924: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 213400.1406 - val_loss: 4979.8755 - 563ms/epoch - 80ms/step
# Epoch 1925/2000
#
# Epoch 1925: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 225509.4219 - val_loss: 6101.9336 - 532ms/epoch - 76ms/step
# Epoch 1926/2000
#
# Epoch 1926: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 239413.1094 - val_loss: 12428.5879 - 544ms/epoch - 78ms/step
# Epoch 1927/2000
#
# Epoch 1927: loss did not improve from 181796.85938
# 7/7 - 0s - loss: 233830.8438 - val_loss: 14642.4570 - 493ms/epoch - 70ms/step
# Epoch 1928/2000
#
# Epoch 1928: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 211156.4531 - val_loss: 6332.5537 - 560ms/epoch - 80ms/step
# Epoch 1929/2000
#
# Epoch 1929: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 223094.3125 - val_loss: 8322.1074 - 509ms/epoch - 73ms/step
# Epoch 1930/2000
#
# Epoch 1930: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 220708.9062 - val_loss: 7820.7339 - 944ms/epoch - 135ms/step
# Epoch 1931/2000
#
# Epoch 1931: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 241432.8750 - val_loss: 8963.1484 - 1s/epoch - 154ms/step
# Epoch 1932/2000
#
# Epoch 1932: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 250357.8125 - val_loss: 5041.0435 - 904ms/epoch - 129ms/step
# Epoch 1933/2000
#
# Epoch 1933: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 255020.5625 - val_loss: 10972.2500 - 975ms/epoch - 139ms/step
# Epoch 1934/2000
#
# Epoch 1934: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 203608.5781 - val_loss: 5339.0068 - 832ms/epoch - 119ms/step
# Epoch 1935/2000
#
# Epoch 1935: loss did not improve from 181796.85938
# 7/7 - 0s - loss: 210714.0938 - val_loss: 8813.9307 - 499ms/epoch - 71ms/step
# Epoch 1936/2000
#
# Epoch 1936: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 218172.0938 - val_loss: 7687.5996 - 537ms/epoch - 77ms/step
# Epoch 1937/2000
#
# Epoch 1937: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 248898.5469 - val_loss: 9308.1836 - 541ms/epoch - 77ms/step
# Epoch 1938/2000
#
# Epoch 1938: loss did not improve from 181796.85938
# 7/7 - 0s - loss: 215126.3125 - val_loss: 11731.4297 - 494ms/epoch - 71ms/step
# Epoch 1939/2000
#
# Epoch 1939: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 211520.7344 - val_loss: 8217.4805 - 528ms/epoch - 75ms/step
# Epoch 1940/2000
#
# Epoch 1940: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 258212.0312 - val_loss: 5453.5205 - 524ms/epoch - 75ms/step
# Epoch 1941/2000
#
# Epoch 1941: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 270262.8750 - val_loss: 5053.3662 - 587ms/epoch - 84ms/step
# Epoch 1942/2000
#
# Epoch 1942: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 241901.5625 - val_loss: 6057.2310 - 544ms/epoch - 78ms/step
# Epoch 1943/2000
#
# Epoch 1943: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 246326.5156 - val_loss: 8573.4258 - 513ms/epoch - 73ms/step
# Epoch 1944/2000
#
# Epoch 1944: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 240107.7969 - val_loss: 6280.1455 - 509ms/epoch - 73ms/step
# Epoch 1945/2000
#
# Epoch 1945: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 243031.2500 - val_loss: 8806.6826 - 516ms/epoch - 74ms/step
# Epoch 1946/2000
#
# Epoch 1946: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 261297.8125 - val_loss: 5425.5254 - 561ms/epoch - 80ms/step
# Epoch 1947/2000
#
# Epoch 1947: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 242150.6406 - val_loss: 5581.0479 - 532ms/epoch - 76ms/step
# Epoch 1948/2000
#
# Epoch 1948: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 259410.3750 - val_loss: 16237.1074 - 531ms/epoch - 76ms/step
# Epoch 1949/2000
#
# Epoch 1949: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 208007.7031 - val_loss: 4797.0430 - 532ms/epoch - 76ms/step
# Epoch 1950/2000
#
# Epoch 1950: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 239292.5156 - val_loss: 10825.1494 - 512ms/epoch - 73ms/step
# Epoch 1951/2000
#
# Epoch 1951: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 248247.4688 - val_loss: 8376.7041 - 544ms/epoch - 78ms/step
# Epoch 1952/2000
#
# Epoch 1952: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 235848.4375 - val_loss: 15476.2471 - 503ms/epoch - 72ms/step
# Epoch 1953/2000
#
# Epoch 1953: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 238351.9219 - val_loss: 4501.0312 - 762ms/epoch - 109ms/step
# Epoch 1954/2000
#
# Epoch 1954: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 253078.2344 - val_loss: 4937.8091 - 1s/epoch - 150ms/step
# Epoch 1955/2000
#
# Epoch 1955: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 251130.0000 - val_loss: 4566.3013 - 867ms/epoch - 124ms/step
# Epoch 1956/2000
#
# Epoch 1956: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 247360.2344 - val_loss: 19112.3613 - 943ms/epoch - 135ms/step
# Epoch 1957/2000
#
# Epoch 1957: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 236158.4375 - val_loss: 20125.3789 - 859ms/epoch - 123ms/step
# Epoch 1958/2000
#
# Epoch 1958: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 224535.7344 - val_loss: 5236.3140 - 600ms/epoch - 86ms/step
# Epoch 1959/2000
#
# Epoch 1959: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 210753.7500 - val_loss: 5372.4297 - 542ms/epoch - 77ms/step
# Epoch 1960/2000
#
# Epoch 1960: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 214556.9219 - val_loss: 6991.1792 - 525ms/epoch - 75ms/step
# Epoch 1961/2000
#
# Epoch 1961: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 239015.4219 - val_loss: 13335.0742 - 538ms/epoch - 77ms/step
# Epoch 1962/2000
#
# Epoch 1962: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 235993.4531 - val_loss: 5254.1172 - 544ms/epoch - 78ms/step
# Epoch 1963/2000
#
# Epoch 1963: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 226788.4688 - val_loss: 9575.2490 - 596ms/epoch - 85ms/step
# Epoch 1964/2000
#
# Epoch 1964: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 240891.0000 - val_loss: 5392.1548 - 573ms/epoch - 82ms/step
# Epoch 1965/2000
#
# Epoch 1965: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 228278.6875 - val_loss: 6950.4683 - 516ms/epoch - 74ms/step
# Epoch 1966/2000
#
# Epoch 1966: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 238543.4375 - val_loss: 18485.0508 - 544ms/epoch - 78ms/step
# Epoch 1967/2000
#
# Epoch 1967: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 254311.5156 - val_loss: 6749.0918 - 518ms/epoch - 74ms/step
# Epoch 1968/2000
#
# Epoch 1968: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 229042.1094 - val_loss: 7224.5415 - 542ms/epoch - 77ms/step
# Epoch 1969/2000
#
# Epoch 1969: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 225394.2969 - val_loss: 8742.8379 - 534ms/epoch - 76ms/step
# Epoch 1970/2000
#
# Epoch 1970: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 235723.1250 - val_loss: 4847.2007 - 579ms/epoch - 83ms/step
# Epoch 1971/2000
#
# Epoch 1971: loss did not improve from 181796.85938
# 7/7 - 0s - loss: 234929.4062 - val_loss: 8636.5283 - 495ms/epoch - 71ms/step
# Epoch 1972/2000
#
# Epoch 1972: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 242044.4688 - val_loss: 23747.2773 - 535ms/epoch - 76ms/step
# Epoch 1973/2000
#
# Epoch 1973: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 244275.7656 - val_loss: 4901.8735 - 552ms/epoch - 79ms/step
# Epoch 1974/2000
#
# Epoch 1974: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 240972.5312 - val_loss: 10014.3242 - 582ms/epoch - 83ms/step
# Epoch 1975/2000
#
# Epoch 1975: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 214211.9062 - val_loss: 6516.6440 - 541ms/epoch - 77ms/step
# Epoch 1976/2000
#
# Epoch 1976: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 232682.1406 - val_loss: 10047.6436 - 731ms/epoch - 104ms/step
# Epoch 1977/2000
#
# Epoch 1977: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 236071.0000 - val_loss: 10694.3926 - 1s/epoch - 168ms/step
# Epoch 1978/2000
#
# Epoch 1978: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 227492.5938 - val_loss: 8450.8369 - 994ms/epoch - 142ms/step
# Epoch 1979/2000
#
# Epoch 1979: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 249941.3438 - val_loss: 5270.4448 - 989ms/epoch - 141ms/step
# Epoch 1980/2000
#
# Epoch 1980: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 221716.2969 - val_loss: 9992.3330 - 867ms/epoch - 124ms/step
# Epoch 1981/2000
#
# Epoch 1981: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 218371.6562 - val_loss: 7015.6230 - 515ms/epoch - 74ms/step
# Epoch 1982/2000
#
# Epoch 1982: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 229468.4062 - val_loss: 15877.8867 - 510ms/epoch - 73ms/step
# Epoch 1983/2000
#
# Epoch 1983: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 241106.5156 - val_loss: 7597.8701 - 532ms/epoch - 76ms/step
# Epoch 1984/2000
#
# Epoch 1984: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 264194.2188 - val_loss: 6384.2998 - 522ms/epoch - 75ms/step
# Epoch 1985/2000
#
# Epoch 1985: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 215533.6875 - val_loss: 5951.5923 - 530ms/epoch - 76ms/step
# Epoch 1986/2000
#
# Epoch 1986: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 241556.5781 - val_loss: 4671.8242 - 514ms/epoch - 73ms/step
# Epoch 1987/2000
#
# Epoch 1987: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 197354.4688 - val_loss: 16928.3086 - 505ms/epoch - 72ms/step
# Epoch 1988/2000
#
# Epoch 1988: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 235558.2344 - val_loss: 5153.3047 - 515ms/epoch - 74ms/step
# Epoch 1989/2000
#
# Epoch 1989: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 226763.1094 - val_loss: 5847.4858 - 538ms/epoch - 77ms/step
# Epoch 1990/2000
#
# Epoch 1990: loss did not improve from 181796.85938
# 7/7 - 0s - loss: 217327.4219 - val_loss: 7592.1826 - 496ms/epoch - 71ms/step
# Epoch 1991/2000
#
# Epoch 1991: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 216949.7656 - val_loss: 5091.5874 - 573ms/epoch - 82ms/step
# Epoch 1992/2000
#
# Epoch 1992: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 219644.5625 - val_loss: 4854.8232 - 511ms/epoch - 73ms/step
# Epoch 1993/2000
#
# Epoch 1993: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 236203.7500 - val_loss: 9122.9014 - 556ms/epoch - 79ms/step
# Epoch 1994/2000
#
# Epoch 1994: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 249072.5781 - val_loss: 6970.7852 - 556ms/epoch - 79ms/step
# Epoch 1995/2000
#
# Epoch 1995: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 234514.9844 - val_loss: 7548.9438 - 523ms/epoch - 75ms/step
# Epoch 1996/2000
#
# Epoch 1996: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 238773.7812 - val_loss: 8375.1514 - 576ms/epoch - 82ms/step
# Epoch 1997/2000
#
# Epoch 1997: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 260074.0312 - val_loss: 5648.3003 - 518ms/epoch - 74ms/step
# Epoch 1998/2000
#
# Epoch 1998: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 240891.8594 - val_loss: 9091.0264 - 517ms/epoch - 74ms/step
# Epoch 1999/2000
#
# Epoch 1999: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 227260.7344 - val_loss: 5560.8833 - 895ms/epoch - 128ms/step
# Epoch 2000/2000
#
# Epoch 2000: loss did not improve from 181796.85938
# 7/7 - 1s - loss: 230974.2500 - val_loss: 5185.3320 - 1s/epoch - 161ms/step
# 16/16 [==============================] - 1s 10ms/step
# 3/3 [==============================] - 0s 13ms/step
# Training MSE: 17034.247637210403
# Testing MSE: 9767.16228871789
# accuracy : 64
