# %% [markdown]
# <a href="https://colab.research.google.com/github/hj2222222/API/blob/main/RNN_no_sentiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import os
import math
import matplotlib.pyplot as plt
import keras
import pandas as pd
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras import optimizers
from tensorflow.keras.layers import LSTM, Dropout, Dense, Conv1D, MaxPooling1D, Flatten
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Bidirectional
from keras.layers import Dropout,TimeDistributed, Flatten
from keras.layers import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from tensorflow.keras.losses import Huber
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


stock_data = pd.read_csv('/content/drive/MyDrive/산업 AI 캡스톤/DATA/Total_Data/Final_Feature_kospi_sen_all.csv')
stock_data
# Out:
#          Date  Kospi_close  Kospi_high  ko_interest  oil_open  ex_JP_low  \
# 0    20210105      2990.57       0.795          0.0     0.213      0.590
# 1    20210106      2968.21       0.819          0.0     0.219      0.596
# 2    20210107      3031.68       0.839          0.0     0.225      0.597
# 3    20210108      3152.18       0.855          0.0     0.230      0.584
# 4    20210111      3148.45       0.914          0.0     0.232      0.584
# ..        ...          ...         ...          ...       ...        ...
# 583  20230623      2570.10       0.601          1.0     0.651      0.028
# 584  20230626      2582.20       0.602          1.0     0.651      0.024
# 585  20230627      2581.39       0.594          1.0     0.651      0.000
# 586  20230628      2564.19       0.592          1.0     0.651      0.011
# 587  20230629      2550.02       0.597          1.0     0.651      0.020
#
#      gold_low  us500_low  klue_bert_score_summarize_content  oil_vol  \
# 0       0.661      0.581                             -0.536    0.013
# 1       0.650      0.585                              1.381    0.006
# 2       0.670      0.608                              1.845    0.007
# 3       0.631      0.615                              2.497    0.004
# 4       0.623      0.617                             -0.951    0.009
# ..        ...        ...                                ...      ...
# 583     0.212      0.830                              0.402    0.000
# 584     0.212      0.825                             -0.385    0.000
# 585     0.208      0.828                             -0.447    0.000
# 586     0.217      0.838                              0.777    0.000
# 587     0.208      0.842                             -0.038    0.000
#
#      research_kospi  dji_vol  us500_vol  \
# 0             0.413    0.280      0.349
# 1             0.628    0.470      0.527
# 2             0.427    0.378      0.410
# 3             0.512    0.318      0.371
# 4             0.881    0.287      0.334
# ..              ...      ...        ...
# 583           0.125    0.316      0.526
# 584           0.120    0.170      0.207
# 585           0.118    0.206      0.226
# 586           0.128    0.174      0.246
# 587           0.127    0.189      0.241
#
#      kofinbert_score_summarize_content_kospi  kofinbert_score_title_kospi  \
# 0                                      0.157                        0.195
# 1                                      1.236                        0.569
# 2                                      0.537                        1.395
# 3                                      0.697                       -1.382
# 4                                      0.331                       -0.044
# ..                                       ...                          ...
# 583                                    0.834                       -0.339
# 584                                   -0.196                        0.681
# 585                                   -0.208                        0.625
# 586                                    1.099                        0.892
# 587                                    0.382                       -0.145
#
#      klue_bert_score_title
# 0                    0.823
# 1                    0.722
# 2                   -0.675
# 3                    1.124
# 4                    0.730
# ..                     ...
# 583                  0.831
# 584                 -0.001
# 585                 -0.097
# 586                  0.253
# 587                 -0.378
#
# [588 rows x 16 columns]

# %%
def accuracy(list1,list2):
  list1 = list1.flatten().tolist()
  list2 = list2.flatten().tolist()
  value_1 = []
  value_2 = []
  j = 0
  if len(list1) == len(list2):
    for i in range(len(list1)-1):
      if list1[i+1] > list1[i]:
        value_1.append(1)
      elif list1[i+1] == list1[i]:
        value_1.append(0)
      else:
        value_1.append(-1)
    for i in range(len(list1)-1):
      if list2[i+1] > list2[i]:
        value_2.append(1)
      elif list2[i+1] == list2[i]:
        value_2.append(0)
      else:
        value_2.append(-1)
    for i in range(len(value_1)):
      if value_1[i] == value_2[i]:
        j = j + 1
    accuracy = j/len(value_1) * 100
    print("accuracy : %d" % accuracy)
  else:
    print("길이가 다릅니다.")

# %%
# 데이터 전처리
data = stock_data['Kospi_close'].values.reshape(-1, 1)
stock_data = stock_data.drop(['Kospi_close'],axis=1)
stock_data = stock_data.drop(['Date'],axis=1)

# %%
name = [stock_data.columns]

close = ['kofinbert_score_summarize_content_kospi',
        'kofinbert_score_title_kospi', 'klue_bert_score_summarize_content',
        'klue_bert_score_title']

stock_data = stock_data.drop(close, axis=1)

# %%
# 데이터 분할
train_size = int(len(data) * 0.85)
train_data, test_data = data[:train_size], data[train_size:]
train_data_t, test_data_t = stock_data[:train_size], stock_data[train_size:]

def create_dataset(dataset, data, look_back=10):
    X, y = [], []
    for i in range(len(data) - look_back):
        X.append(dataset[i:(i + look_back)])
        y.append(data[i + look_back])
    return np.array(X), np.array(y)

look_back = 5  # 몇 일 동안의 데이터를 사용할 것인지 설정

trainX, trainY = create_dataset(train_data_t, train_data, look_back)
testX, testY = create_dataset(test_data_t,test_data, look_back)
print(trainX.shape)
print(trainY.shape)
print(testX.shape)
print(testY.shape)
# Out:
# (494, 5, 10)
# (494, 1)
# (84, 5, 10)
# (84, 1)

# %%
earlystopping = EarlyStopping(monitor='val_loss', patience=50)

# %%
# 모델 생성
model = Sequential()
model.add(GRU(units=1024, activation='relu', return_sequences=True, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dropout(0.3))
model.add(GRU(units=512, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=256, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=128, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=64, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=32, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(units=1))
model.summary()

# loss = Huber()
# optimizer = Adam(0.0005)
# model.compile(loss=Huber(), optimizer=optimizer, metrics=['mse'])
model.compile(optimizer='adam', loss='mean_squared_error')

filename = os.path.join('tmp', 'ckeckpointer.ckpt')
checkpoint = ModelCheckpoint(filename,
                             save_weights_only=True,
                             save_best_only=True,
                             monitor='val_loss',
                             verbose=1)

# 모델 학습
history = model.fit(trainX, trainY, epochs=1000, batch_size=64,
          validation_split=0.1, verbose=2,callbacks=[checkpoint])

model.save_weights('./lstm_weights.h1')

model.load_weights(filename)

plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()
plt.show()

# 예측
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# MSE 계산
trainMSE = mean_squared_error(trainY, trainPredict)
testMSE = mean_squared_error(testY, testPredict)

print(f'Training MSE: {trainMSE}')
print(f'Testing MSE: {testMSE}')

accuracy(testPredict,testY)

# 예측 시각화
plt.plot(trainY, label='Actual Price')
plt.plot(trainPredict, label='Predicted Price')
plt.legend()
plt.title('Training Data')
plt.show()

plt.plot(testY, label='Actual Price')
plt.plot(testPredict, label='Predicted Price')
plt.legend()
plt.title('Testing Data')
plt.show()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_13 (GRU)                (None, 5, 1024)           3182592
#
#  dropout_20 (Dropout)        (None, 5, 1024)           0
#
#  gru_14 (GRU)                (None, 5, 512)            2362368
#
#  dropout_21 (Dropout)        (None, 5, 512)            0
#
#  gru_15 (GRU)                (None, 5, 256)            591360
#
#  dropout_22 (Dropout)        (None, 5, 256)            0
#
#  gru_16 (GRU)                (None, 5, 128)            148224
#
#  dropout_23 (Dropout)        (None, 5, 128)            0
#
#  gru_17 (GRU)                (None, 5, 64)             37248
#
#  dropout_24 (Dropout)        (None, 5, 64)             0
#
#  gru_18 (GRU)                (None, 32)                9408
#
#  dropout_25 (Dropout)        (None, 32)                0
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 6331233 (24.15 MB)
# Trainable params: 6331233 (24.15 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/1000
#
# Epoch 1: val_loss improved from inf to 5668793.50000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 15s - loss: 8163963.5000 - val_loss: 5668793.5000 - 15s/epoch - 2s/step
# Epoch 2/1000
#
# Epoch 2: val_loss did not improve from 5668793.50000
# 7/7 - 3s - loss: 5887745.0000 - val_loss: 5683905.5000 - 3s/epoch - 462ms/step
# Epoch 3/1000
#
# Epoch 3: val_loss improved from 5668793.50000 to 859631.75000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 4s - loss: 2285243.0000 - val_loss: 859631.7500 - 4s/epoch - 609ms/step
# Epoch 4/1000
#
# Epoch 4: val_loss improved from 859631.75000 to 97527.92188, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 5s - loss: 1578365.0000 - val_loss: 97527.9219 - 5s/epoch - 768ms/step
# Epoch 5/1000
#
# Epoch 5: val_loss improved from 97527.92188 to 19123.03906, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 4s - loss: 1073291.0000 - val_loss: 19123.0391 - 4s/epoch - 500ms/step
# Epoch 6/1000
#
# Epoch 6: val_loss did not improve from 19123.03906
# 7/7 - 3s - loss: 952703.5625 - val_loss: 171164.9219 - 3s/epoch - 459ms/step
# Epoch 7/1000
#
# Epoch 7: val_loss improved from 19123.03906 to 14383.22852, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 3s - loss: 822768.3750 - val_loss: 14383.2285 - 3s/epoch - 493ms/step
# Epoch 8/1000
#
# Epoch 8: val_loss did not improve from 14383.22852
# 7/7 - 5s - loss: 775922.6250 - val_loss: 246319.4844 - 5s/epoch - 708ms/step
# Epoch 9/1000
#
# Epoch 9: val_loss improved from 14383.22852 to 11725.54102, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 4s - loss: 844847.5000 - val_loss: 11725.5410 - 4s/epoch - 633ms/step
# Epoch 10/1000
#
# Epoch 10: val_loss did not improve from 11725.54102
# 7/7 - 3s - loss: 778040.5000 - val_loss: 93816.1016 - 3s/epoch - 465ms/step
# Epoch 11/1000
#
# Epoch 11: val_loss did not improve from 11725.54102
# 7/7 - 3s - loss: 660585.3125 - val_loss: 91666.9062 - 3s/epoch - 459ms/step
# Epoch 12/1000
#
# Epoch 12: val_loss did not improve from 11725.54102
# 7/7 - 4s - loss: 642077.0625 - val_loss: 68706.4844 - 4s/epoch - 563ms/step
# Epoch 13/1000
#
# Epoch 13: val_loss did not improve from 11725.54102
# 7/7 - 5s - loss: 604381.5000 - val_loss: 13189.5947 - 5s/epoch - 721ms/step
# Epoch 14/1000
#
# Epoch 14: val_loss did not improve from 11725.54102
# 7/7 - 3s - loss: 614674.8750 - val_loss: 62736.5000 - 3s/epoch - 495ms/step
# Epoch 15/1000
#
# Epoch 15: val_loss did not improve from 11725.54102
# 7/7 - 3s - loss: 597404.2500 - val_loss: 55736.7891 - 3s/epoch - 459ms/step
# Epoch 16/1000
#
# Epoch 16: val_loss improved from 11725.54102 to 7226.27539, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 3s - loss: 624260.1875 - val_loss: 7226.2754 - 3s/epoch - 490ms/step
# Epoch 17/1000
#
# Epoch 17: val_loss did not improve from 7226.27539
# 7/7 - 5s - loss: 524838.2500 - val_loss: 139771.0781 - 5s/epoch - 687ms/step
# Epoch 18/1000
#
# Epoch 18: val_loss did not improve from 7226.27539
# 7/7 - 4s - loss: 501294.6875 - val_loss: 326851.5312 - 4s/epoch - 640ms/step
# Epoch 19/1000
#
# Epoch 19: val_loss did not improve from 7226.27539
# 7/7 - 3s - loss: 522590.4062 - val_loss: 77592.1016 - 3s/epoch - 475ms/step
# Epoch 20/1000
#
# Epoch 20: val_loss did not improve from 7226.27539
# 7/7 - 3s - loss: 533540.7500 - val_loss: 15989.2910 - 3s/epoch - 496ms/step
# Epoch 21/1000
#
# Epoch 21: val_loss did not improve from 7226.27539
# 7/7 - 4s - loss: 542924.3750 - val_loss: 125464.9062 - 4s/epoch - 626ms/step
# Epoch 22/1000
#
# Epoch 22: val_loss did not improve from 7226.27539
# 7/7 - 5s - loss: 447117.5625 - val_loss: 271972.7812 - 5s/epoch - 729ms/step
# Epoch 23/1000
#
# Epoch 23: val_loss did not improve from 7226.27539
# 7/7 - 3s - loss: 517313.3750 - val_loss: 22938.0117 - 3s/epoch - 478ms/step
# Epoch 24/1000
#
# Epoch 24: val_loss did not improve from 7226.27539
# 7/7 - 3s - loss: 473786.5312 - val_loss: 10534.4346 - 3s/epoch - 460ms/step
# Epoch 25/1000
#
# Epoch 25: val_loss did not improve from 7226.27539
# 7/7 - 3s - loss: 453066.7500 - val_loss: 23832.5977 - 3s/epoch - 468ms/step
# Epoch 26/1000
#
# Epoch 26: val_loss did not improve from 7226.27539
# 7/7 - 5s - loss: 428608.8438 - val_loss: 134320.9688 - 5s/epoch - 719ms/step
# Epoch 27/1000
#
# Epoch 27: val_loss did not improve from 7226.27539
# 7/7 - 4s - loss: 459969.5938 - val_loss: 91188.6484 - 4s/epoch - 600ms/step
# Epoch 28/1000
#
# Epoch 28: val_loss improved from 7226.27539 to 3933.61353, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 3s - loss: 386801.2188 - val_loss: 3933.6135 - 3s/epoch - 493ms/step
# Epoch 29/1000
#
# Epoch 29: val_loss did not improve from 3933.61353
# 7/7 - 3s - loss: 414533.4375 - val_loss: 4279.7886 - 3s/epoch - 467ms/step
# Epoch 30/1000
#
# Epoch 30: val_loss did not improve from 3933.61353
# 7/7 - 4s - loss: 354016.6250 - val_loss: 27136.6230 - 4s/epoch - 557ms/step
# Epoch 31/1000
#
# Epoch 31: val_loss did not improve from 3933.61353
# 7/7 - 5s - loss: 376004.5000 - val_loss: 87248.4922 - 5s/epoch - 710ms/step
# Epoch 32/1000
#
# Epoch 32: val_loss did not improve from 3933.61353
# 7/7 - 3s - loss: 317975.7812 - val_loss: 104815.9219 - 3s/epoch - 493ms/step
# Epoch 33/1000
#
# Epoch 33: val_loss did not improve from 3933.61353
# 7/7 - 3s - loss: 396656.7188 - val_loss: 76489.2188 - 3s/epoch - 464ms/step
# Epoch 34/1000
#
# Epoch 34: val_loss did not improve from 3933.61353
# 7/7 - 3s - loss: 352562.9062 - val_loss: 16507.1777 - 3s/epoch - 469ms/step
# Epoch 35/1000
#
# Epoch 35: val_loss did not improve from 3933.61353
# 7/7 - 5s - loss: 380825.8125 - val_loss: 15810.9062 - 5s/epoch - 665ms/step
# Epoch 36/1000
#
# Epoch 36: val_loss improved from 3933.61353 to 3570.81055, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 5s - loss: 375388.2500 - val_loss: 3570.8105 - 5s/epoch - 686ms/step
# Epoch 37/1000
#
# Epoch 37: val_loss did not improve from 3570.81055
# 7/7 - 3s - loss: 332516.2188 - val_loss: 69597.0078 - 3s/epoch - 469ms/step
# Epoch 38/1000
#
# Epoch 38: val_loss did not improve from 3570.81055
# 7/7 - 3s - loss: 349351.2188 - val_loss: 39506.6328 - 3s/epoch - 464ms/step
# Epoch 39/1000
#
# Epoch 39: val_loss did not improve from 3570.81055
# 7/7 - 4s - loss: 339177.4375 - val_loss: 11287.9014 - 4s/epoch - 546ms/step
# Epoch 40/1000
#
# Epoch 40: val_loss did not improve from 3570.81055
# 7/7 - 5s - loss: 313329.2188 - val_loss: 20897.8047 - 5s/epoch - 724ms/step
# Epoch 41/1000
#
# Epoch 41: val_loss did not improve from 3570.81055
# 7/7 - 4s - loss: 327895.9688 - val_loss: 30554.8984 - 4s/epoch - 600ms/step
# Epoch 42/1000
#
# Epoch 42: val_loss did not improve from 3570.81055
# 7/7 - 4s - loss: 290684.0938 - val_loss: 58209.9883 - 4s/epoch - 545ms/step
# Epoch 43/1000
#
# Epoch 43: val_loss did not improve from 3570.81055
# 7/7 - 4s - loss: 285076.7188 - val_loss: 27716.4766 - 4s/epoch - 510ms/step
# Epoch 44/1000
#
# Epoch 44: val_loss did not improve from 3570.81055
# 7/7 - 5s - loss: 326720.5625 - val_loss: 46421.4688 - 5s/epoch - 773ms/step
# Epoch 45/1000
#
# Epoch 45: val_loss did not improve from 3570.81055
# 7/7 - 6s - loss: 325877.0938 - val_loss: 6700.6836 - 6s/epoch - 799ms/step
# Epoch 46/1000
#
# Epoch 46: val_loss did not improve from 3570.81055
# 7/7 - 4s - loss: 324123.9062 - val_loss: 4987.1768 - 4s/epoch - 616ms/step
# Epoch 47/1000
#
# Epoch 47: val_loss did not improve from 3570.81055
# 7/7 - 3s - loss: 279415.3125 - val_loss: 6264.4194 - 3s/epoch - 461ms/step
# Epoch 48/1000
#
# Epoch 48: val_loss did not improve from 3570.81055
# 7/7 - 4s - loss: 302866.7500 - val_loss: 5568.8755 - 4s/epoch - 562ms/step
# Epoch 49/1000
#
# Epoch 49: val_loss did not improve from 3570.81055
# 7/7 - 5s - loss: 273696.7188 - val_loss: 17527.6582 - 5s/epoch - 716ms/step
# Epoch 50/1000
#
# Epoch 50: val_loss did not improve from 3570.81055
# 7/7 - 4s - loss: 277839.2188 - val_loss: 75166.1719 - 4s/epoch - 510ms/step
# Epoch 51/1000
#
# Epoch 51: val_loss did not improve from 3570.81055
# 7/7 - 3s - loss: 330816.5000 - val_loss: 10354.6416 - 3s/epoch - 464ms/step
# Epoch 52/1000
#
# Epoch 52: val_loss improved from 3570.81055 to 2966.64478, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 3s - loss: 303651.1250 - val_loss: 2966.6448 - 3s/epoch - 492ms/step
# Epoch 53/1000
#
# Epoch 53: val_loss did not improve from 2966.64478
# 7/7 - 5s - loss: 277825.2500 - val_loss: 4397.2305 - 5s/epoch - 712ms/step
# Epoch 54/1000
#
# Epoch 54: val_loss did not improve from 2966.64478
# 7/7 - 4s - loss: 282874.1250 - val_loss: 18948.6641 - 4s/epoch - 624ms/step
# Epoch 55/1000
#
# Epoch 55: val_loss did not improve from 2966.64478
# 7/7 - 3s - loss: 293398.0625 - val_loss: 65848.6953 - 3s/epoch - 475ms/step
# Epoch 56/1000
#
# Epoch 56: val_loss did not improve from 2966.64478
# 7/7 - 3s - loss: 250942.1562 - val_loss: 7503.1733 - 3s/epoch - 468ms/step
# Epoch 57/1000
#
# Epoch 57: val_loss did not improve from 2966.64478
# 7/7 - 4s - loss: 251601.3750 - val_loss: 8552.3555 - 4s/epoch - 565ms/step
# Epoch 58/1000
#
# Epoch 58: val_loss did not improve from 2966.64478
# 7/7 - 5s - loss: 275260.1250 - val_loss: 11775.2891 - 5s/epoch - 727ms/step
# Epoch 59/1000
#
# Epoch 59: val_loss did not improve from 2966.64478
# 7/7 - 4s - loss: 293015.9062 - val_loss: 23906.4297 - 4s/epoch - 514ms/step
# Epoch 60/1000
#
# Epoch 60: val_loss improved from 2966.64478 to 2423.39868, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 3s - loss: 222767.2500 - val_loss: 2423.3987 - 3s/epoch - 498ms/step
# Epoch 61/1000
#
# Epoch 61: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 263027.1875 - val_loss: 4033.5818 - 3s/epoch - 471ms/step
# Epoch 62/1000
#
# Epoch 62: val_loss did not improve from 2423.39868
# 7/7 - 5s - loss: 258482.7812 - val_loss: 7555.7900 - 5s/epoch - 698ms/step
# Epoch 63/1000
#
# Epoch 63: val_loss did not improve from 2423.39868
# 7/7 - 6s - loss: 296085.0312 - val_loss: 6052.1538 - 6s/epoch - 798ms/step
# Epoch 64/1000
#
# Epoch 64: val_loss did not improve from 2423.39868
# 7/7 - 5s - loss: 238260.7812 - val_loss: 3125.4700 - 5s/epoch - 690ms/step
# Epoch 65/1000
#
# Epoch 65: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 254889.5469 - val_loss: 34922.7695 - 3s/epoch - 480ms/step
# Epoch 66/1000
#
# Epoch 66: val_loss did not improve from 2423.39868
# 7/7 - 5s - loss: 268974.6562 - val_loss: 6848.2593 - 5s/epoch - 664ms/step
# Epoch 67/1000
#
# Epoch 67: val_loss did not improve from 2423.39868
# 7/7 - 5s - loss: 252704.1250 - val_loss: 8588.3027 - 5s/epoch - 678ms/step
# Epoch 68/1000
#
# Epoch 68: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 269452.4062 - val_loss: 29435.9004 - 3s/epoch - 470ms/step
# Epoch 69/1000
#
# Epoch 69: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 268609.1875 - val_loss: 35911.8203 - 3s/epoch - 475ms/step
# Epoch 70/1000
#
# Epoch 70: val_loss did not improve from 2423.39868
# 7/7 - 4s - loss: 232668.5156 - val_loss: 59157.8516 - 4s/epoch - 513ms/step
# Epoch 71/1000
#
# Epoch 71: val_loss did not improve from 2423.39868
# 7/7 - 5s - loss: 277762.1250 - val_loss: 39399.9336 - 5s/epoch - 720ms/step
# Epoch 72/1000
#
# Epoch 72: val_loss did not improve from 2423.39868
# 7/7 - 4s - loss: 251555.6562 - val_loss: 24311.5684 - 4s/epoch - 557ms/step
# Epoch 73/1000
#
# Epoch 73: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 257985.2031 - val_loss: 27402.0918 - 3s/epoch - 467ms/step
# Epoch 74/1000
#
# Epoch 74: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 261736.7344 - val_loss: 4438.3008 - 3s/epoch - 472ms/step
# Epoch 75/1000
#
# Epoch 75: val_loss did not improve from 2423.39868
# 7/7 - 4s - loss: 270548.7188 - val_loss: 3164.7043 - 4s/epoch - 629ms/step
# Epoch 76/1000
#
# Epoch 76: val_loss did not improve from 2423.39868
# 7/7 - 5s - loss: 234093.2812 - val_loss: 10235.0479 - 5s/epoch - 696ms/step
# Epoch 77/1000
#
# Epoch 77: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 257586.2344 - val_loss: 20167.8574 - 3s/epoch - 469ms/step
# Epoch 78/1000
#
# Epoch 78: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 270707.0625 - val_loss: 7640.3813 - 3s/epoch - 466ms/step
# Epoch 79/1000
#
# Epoch 79: val_loss did not improve from 2423.39868
# 7/7 - 4s - loss: 232789.4219 - val_loss: 4632.9912 - 4s/epoch - 504ms/step
# Epoch 80/1000
#
# Epoch 80: val_loss did not improve from 2423.39868
# 7/7 - 5s - loss: 252134.5469 - val_loss: 46372.2148 - 5s/epoch - 753ms/step
# Epoch 81/1000
#
# Epoch 81: val_loss did not improve from 2423.39868
# 7/7 - 4s - loss: 260731.7500 - val_loss: 42852.9688 - 4s/epoch - 551ms/step
# Epoch 82/1000
#
# Epoch 82: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 273232.7500 - val_loss: 34355.3984 - 3s/epoch - 470ms/step
# Epoch 83/1000
#
# Epoch 83: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 246615.2656 - val_loss: 13644.0352 - 3s/epoch - 473ms/step
# Epoch 84/1000
#
# Epoch 84: val_loss did not improve from 2423.39868
# 7/7 - 4s - loss: 244197.9219 - val_loss: 8918.9961 - 4s/epoch - 634ms/step
# Epoch 85/1000
#
# Epoch 85: val_loss did not improve from 2423.39868
# 7/7 - 5s - loss: 261034.4844 - val_loss: 40730.0312 - 5s/epoch - 697ms/step
# Epoch 86/1000
#
# Epoch 86: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 274253.0000 - val_loss: 18325.4141 - 3s/epoch - 482ms/step
# Epoch 87/1000
#
# Epoch 87: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 229344.0938 - val_loss: 16096.4258 - 3s/epoch - 468ms/step
# Epoch 88/1000
#
# Epoch 88: val_loss did not improve from 2423.39868
# 7/7 - 4s - loss: 246498.6094 - val_loss: 3680.0056 - 4s/epoch - 510ms/step
# Epoch 89/1000
#
# Epoch 89: val_loss did not improve from 2423.39868
# 7/7 - 5s - loss: 219893.1094 - val_loss: 17298.3770 - 5s/epoch - 733ms/step
# Epoch 90/1000
#
# Epoch 90: val_loss did not improve from 2423.39868
# 7/7 - 4s - loss: 249419.4531 - val_loss: 44534.6250 - 4s/epoch - 544ms/step
# Epoch 91/1000
#
# Epoch 91: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 275765.6875 - val_loss: 53164.7695 - 3s/epoch - 473ms/step
# Epoch 92/1000
#
# Epoch 92: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 223338.3125 - val_loss: 32935.5312 - 3s/epoch - 482ms/step
# Epoch 93/1000
#
# Epoch 93: val_loss did not improve from 2423.39868
# 7/7 - 4s - loss: 291063.5938 - val_loss: 26811.8594 - 4s/epoch - 642ms/step
# Epoch 94/1000
#
# Epoch 94: val_loss did not improve from 2423.39868
# 7/7 - 5s - loss: 259968.5000 - val_loss: 25642.3691 - 5s/epoch - 687ms/step
# Epoch 95/1000
#
# Epoch 95: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 233638.6094 - val_loss: 38065.5703 - 3s/epoch - 478ms/step
# Epoch 96/1000
#
# Epoch 96: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 221260.9844 - val_loss: 6335.1743 - 3s/epoch - 481ms/step
# Epoch 97/1000
#
# Epoch 97: val_loss did not improve from 2423.39868
# 7/7 - 4s - loss: 238253.2031 - val_loss: 8718.0215 - 4s/epoch - 537ms/step
# Epoch 98/1000
#
# Epoch 98: val_loss did not improve from 2423.39868
# 7/7 - 5s - loss: 224268.4688 - val_loss: 12169.5654 - 5s/epoch - 713ms/step
# Epoch 99/1000
#
# Epoch 99: val_loss did not improve from 2423.39868
# 7/7 - 4s - loss: 228241.4531 - val_loss: 25561.4316 - 4s/epoch - 539ms/step
# Epoch 100/1000
#
# Epoch 100: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 236257.4531 - val_loss: 57585.9141 - 3s/epoch - 462ms/step
# Epoch 101/1000
#
# Epoch 101: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 219229.9219 - val_loss: 28579.9844 - 3s/epoch - 465ms/step
# Epoch 102/1000
#
# Epoch 102: val_loss did not improve from 2423.39868
# 7/7 - 4s - loss: 213902.7344 - val_loss: 30339.3555 - 4s/epoch - 612ms/step
# Epoch 103/1000
#
# Epoch 103: val_loss did not improve from 2423.39868
# 7/7 - 5s - loss: 237720.1094 - val_loss: 59081.6719 - 5s/epoch - 712ms/step
# Epoch 104/1000
#
# Epoch 104: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 227541.0469 - val_loss: 57420.9844 - 3s/epoch - 468ms/step
# Epoch 105/1000
#
# Epoch 105: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 254159.1719 - val_loss: 39334.3008 - 3s/epoch - 474ms/step
# Epoch 106/1000
#
# Epoch 106: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 230578.8438 - val_loss: 26190.1602 - 3s/epoch - 471ms/step
# Epoch 107/1000
#
# Epoch 107: val_loss did not improve from 2423.39868
# 7/7 - 5s - loss: 230006.6875 - val_loss: 3603.4844 - 5s/epoch - 714ms/step
# Epoch 108/1000
#
# Epoch 108: val_loss did not improve from 2423.39868
# 7/7 - 4s - loss: 253721.4844 - val_loss: 3697.7654 - 4s/epoch - 610ms/step
# Epoch 109/1000
#
# Epoch 109: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 243285.0625 - val_loss: 13012.4326 - 3s/epoch - 474ms/step
# Epoch 110/1000
#
# Epoch 110: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 247437.0781 - val_loss: 2500.5400 - 3s/epoch - 471ms/step
# Epoch 111/1000
#
# Epoch 111: val_loss did not improve from 2423.39868
# 7/7 - 4s - loss: 218752.5156 - val_loss: 26227.3750 - 4s/epoch - 613ms/step
# Epoch 112/1000
#
# Epoch 112: val_loss did not improve from 2423.39868
# 7/7 - 5s - loss: 262053.9062 - val_loss: 9165.2539 - 5s/epoch - 725ms/step
# Epoch 113/1000
#
# Epoch 113: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 241901.9688 - val_loss: 24566.9043 - 3s/epoch - 477ms/step
# Epoch 114/1000
#
# Epoch 114: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 239874.3125 - val_loss: 43408.3359 - 3s/epoch - 474ms/step
# Epoch 115/1000
#
# Epoch 115: val_loss did not improve from 2423.39868
# 7/7 - 4s - loss: 218008.9688 - val_loss: 3515.7173 - 4s/epoch - 503ms/step
# Epoch 116/1000
#
# Epoch 116: val_loss did not improve from 2423.39868
# 7/7 - 6s - loss: 248325.8906 - val_loss: 2853.3154 - 6s/epoch - 796ms/step
# Epoch 117/1000
#
# Epoch 117: val_loss did not improve from 2423.39868
# 7/7 - 6s - loss: 249662.4219 - val_loss: 5129.5981 - 6s/epoch - 814ms/step
# Epoch 118/1000
#
# Epoch 118: val_loss did not improve from 2423.39868
# 7/7 - 4s - loss: 249886.1406 - val_loss: 7829.5762 - 4s/epoch - 630ms/step
# Epoch 119/1000
#
# Epoch 119: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 252598.2656 - val_loss: 5319.0732 - 3s/epoch - 474ms/step
# Epoch 120/1000
#
# Epoch 120: val_loss did not improve from 2423.39868
# 7/7 - 4s - loss: 214391.3125 - val_loss: 3156.0098 - 4s/epoch - 525ms/step
# Epoch 121/1000
#
# Epoch 121: val_loss did not improve from 2423.39868
# 7/7 - 5s - loss: 221223.8125 - val_loss: 3396.1541 - 5s/epoch - 743ms/step
# Epoch 122/1000
#
# Epoch 122: val_loss did not improve from 2423.39868
# 7/7 - 4s - loss: 243198.4688 - val_loss: 9141.8379 - 4s/epoch - 533ms/step
# Epoch 123/1000
#
# Epoch 123: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 247882.4844 - val_loss: 3004.8311 - 3s/epoch - 471ms/step
# Epoch 124/1000
#
# Epoch 124: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 245973.1875 - val_loss: 4869.8296 - 3s/epoch - 462ms/step
# Epoch 125/1000
#
# Epoch 125: val_loss did not improve from 2423.39868
# 7/7 - 4s - loss: 236280.3125 - val_loss: 2722.1250 - 4s/epoch - 624ms/step
# Epoch 126/1000
#
# Epoch 126: val_loss did not improve from 2423.39868
# 7/7 - 5s - loss: 216143.4844 - val_loss: 51021.2109 - 5s/epoch - 699ms/step
# Epoch 127/1000
#
# Epoch 127: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 231441.9844 - val_loss: 35198.0469 - 3s/epoch - 468ms/step
# Epoch 128/1000
#
# Epoch 128: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 231940.5781 - val_loss: 91302.1562 - 3s/epoch - 466ms/step
# Epoch 129/1000
#
# Epoch 129: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 267416.8750 - val_loss: 75654.0859 - 3s/epoch - 493ms/step
# Epoch 130/1000
#
# Epoch 130: val_loss did not improve from 2423.39868
# 7/7 - 5s - loss: 217048.3438 - val_loss: 37695.1367 - 5s/epoch - 721ms/step
# Epoch 131/1000
#
# Epoch 131: val_loss did not improve from 2423.39868
# 7/7 - 4s - loss: 236307.7812 - val_loss: 18308.1680 - 4s/epoch - 575ms/step
# Epoch 132/1000
#
# Epoch 132: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 210468.3750 - val_loss: 8062.7754 - 3s/epoch - 480ms/step
# Epoch 133/1000
#
# Epoch 133: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 246108.6562 - val_loss: 6226.5854 - 3s/epoch - 471ms/step
# Epoch 134/1000
#
# Epoch 134: val_loss did not improve from 2423.39868
# 7/7 - 4s - loss: 246073.2500 - val_loss: 3242.4800 - 4s/epoch - 602ms/step
# Epoch 135/1000
#
# Epoch 135: val_loss did not improve from 2423.39868
# 7/7 - 5s - loss: 278606.1875 - val_loss: 10320.6416 - 5s/epoch - 724ms/step
# Epoch 136/1000
#
# Epoch 136: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 208665.4375 - val_loss: 3294.6619 - 3s/epoch - 467ms/step
# Epoch 137/1000
#
# Epoch 137: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 232478.5938 - val_loss: 2480.9963 - 3s/epoch - 462ms/step
# Epoch 138/1000
#
# Epoch 138: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 224151.2969 - val_loss: 5432.7007 - 3s/epoch - 468ms/step
# Epoch 139/1000
#
# Epoch 139: val_loss did not improve from 2423.39868
# 7/7 - 5s - loss: 288767.2188 - val_loss: 7523.5610 - 5s/epoch - 716ms/step
# Epoch 140/1000
#
# Epoch 140: val_loss did not improve from 2423.39868
# 7/7 - 4s - loss: 237506.6094 - val_loss: 51602.6367 - 4s/epoch - 613ms/step
# Epoch 141/1000
#
# Epoch 141: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 222674.1094 - val_loss: 7141.6655 - 3s/epoch - 476ms/step
# Epoch 142/1000
#
# Epoch 142: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 217170.1094 - val_loss: 24398.2520 - 3s/epoch - 466ms/step
# Epoch 143/1000
#
# Epoch 143: val_loss did not improve from 2423.39868
# 7/7 - 4s - loss: 197319.9219 - val_loss: 4057.0234 - 4s/epoch - 574ms/step
# Epoch 144/1000
#
# Epoch 144: val_loss did not improve from 2423.39868
# 7/7 - 5s - loss: 215789.2656 - val_loss: 35753.2109 - 5s/epoch - 757ms/step
# Epoch 145/1000
#
# Epoch 145: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 212839.3125 - val_loss: 34266.7148 - 3s/epoch - 472ms/step
# Epoch 146/1000
#
# Epoch 146: val_loss did not improve from 2423.39868
# 7/7 - 3s - loss: 227742.0469 - val_loss: 6859.2812 - 3s/epoch - 463ms/step
# Epoch 147/1000
#
# Epoch 147: val_loss improved from 2423.39868 to 2410.49585, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 4s - loss: 226889.0312 - val_loss: 2410.4958 - 4s/epoch - 508ms/step
# Epoch 148/1000
#
# Epoch 148: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 240316.0938 - val_loss: 6027.2656 - 5s/epoch - 734ms/step
# Epoch 149/1000
#
# Epoch 149: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 200995.4219 - val_loss: 5149.3652 - 4s/epoch - 602ms/step
# Epoch 150/1000
#
# Epoch 150: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 214327.7188 - val_loss: 42849.6836 - 3s/epoch - 474ms/step
# Epoch 151/1000
#
# Epoch 151: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 233780.2812 - val_loss: 51520.6484 - 3s/epoch - 468ms/step
# Epoch 152/1000
#
# Epoch 152: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 220091.0312 - val_loss: 27433.7246 - 4s/epoch - 600ms/step
# Epoch 153/1000
#
# Epoch 153: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 238617.4531 - val_loss: 15642.4199 - 5s/epoch - 714ms/step
# Epoch 154/1000
#
# Epoch 154: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 222195.9062 - val_loss: 35354.4922 - 3s/epoch - 473ms/step
# Epoch 155/1000
#
# Epoch 155: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 234306.0312 - val_loss: 18268.2578 - 3s/epoch - 465ms/step
# Epoch 156/1000
#
# Epoch 156: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 221052.3438 - val_loss: 4121.2910 - 3s/epoch - 465ms/step
# Epoch 157/1000
#
# Epoch 157: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 244128.9062 - val_loss: 2601.3003 - 5s/epoch - 681ms/step
# Epoch 158/1000
#
# Epoch 158: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 223219.8594 - val_loss: 2506.9983 - 4s/epoch - 642ms/step
# Epoch 159/1000
#
# Epoch 159: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 195639.0156 - val_loss: 19095.6758 - 3s/epoch - 472ms/step
# Epoch 160/1000
#
# Epoch 160: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 229637.6562 - val_loss: 49169.5781 - 3s/epoch - 467ms/step
# Epoch 161/1000
#
# Epoch 161: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 238413.4062 - val_loss: 71451.6797 - 4s/epoch - 554ms/step
# Epoch 162/1000
#
# Epoch 162: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 242539.2656 - val_loss: 14844.2959 - 5s/epoch - 730ms/step
# Epoch 163/1000
#
# Epoch 163: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 229565.1406 - val_loss: 46281.8906 - 4s/epoch - 508ms/step
# Epoch 164/1000
#
# Epoch 164: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 213680.6719 - val_loss: 56212.4492 - 3s/epoch - 467ms/step
# Epoch 165/1000
#
# Epoch 165: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 210844.3125 - val_loss: 16065.9248 - 3s/epoch - 472ms/step
# Epoch 166/1000
#
# Epoch 166: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 234520.7812 - val_loss: 18548.1035 - 5s/epoch - 690ms/step
# Epoch 167/1000
#
# Epoch 167: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 219035.3125 - val_loss: 27347.7246 - 4s/epoch - 642ms/step
# Epoch 168/1000
#
# Epoch 168: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 216670.5000 - val_loss: 10596.1787 - 3s/epoch - 467ms/step
# Epoch 169/1000
#
# Epoch 169: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 209727.6562 - val_loss: 10275.9873 - 3s/epoch - 476ms/step
# Epoch 170/1000
#
# Epoch 170: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 220278.8281 - val_loss: 8783.1514 - 4s/epoch - 556ms/step
# Epoch 171/1000
#
# Epoch 171: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 210168.1094 - val_loss: 44557.9102 - 5s/epoch - 736ms/step
# Epoch 172/1000
#
# Epoch 172: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 210725.5625 - val_loss: 97670.5938 - 4s/epoch - 520ms/step
# Epoch 173/1000
#
# Epoch 173: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 252176.2812 - val_loss: 164279.8906 - 3s/epoch - 474ms/step
# Epoch 174/1000
#
# Epoch 174: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 253858.0938 - val_loss: 163751.0625 - 3s/epoch - 479ms/step
# Epoch 175/1000
#
# Epoch 175: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 222758.4844 - val_loss: 25237.2051 - 5s/epoch - 677ms/step
# Epoch 176/1000
#
# Epoch 176: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 243050.6719 - val_loss: 45560.4258 - 5s/epoch - 660ms/step
# Epoch 177/1000
#
# Epoch 177: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 229467.6250 - val_loss: 79099.5547 - 3s/epoch - 474ms/step
# Epoch 178/1000
#
# Epoch 178: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 246079.8438 - val_loss: 82699.4453 - 3s/epoch - 471ms/step
# Epoch 179/1000
#
# Epoch 179: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 229714.0781 - val_loss: 76346.7500 - 4s/epoch - 548ms/step
# Epoch 180/1000
#
# Epoch 180: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 235708.7344 - val_loss: 148727.7500 - 5s/epoch - 742ms/step
# Epoch 181/1000
#
# Epoch 181: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 260321.5156 - val_loss: 67934.0156 - 4s/epoch - 534ms/step
# Epoch 182/1000
#
# Epoch 182: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 265638.3125 - val_loss: 5748.7695 - 3s/epoch - 476ms/step
# Epoch 183/1000
#
# Epoch 183: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 222301.4844 - val_loss: 2672.1917 - 3s/epoch - 470ms/step
# Epoch 184/1000
#
# Epoch 184: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 235431.3281 - val_loss: 3789.8345 - 5s/epoch - 691ms/step
# Epoch 185/1000
#
# Epoch 185: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 247854.3125 - val_loss: 11752.7773 - 4s/epoch - 632ms/step
# Epoch 186/1000
#
# Epoch 186: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 222741.6094 - val_loss: 94637.1328 - 3s/epoch - 476ms/step
# Epoch 187/1000
#
# Epoch 187: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 223366.2500 - val_loss: 20031.8691 - 3s/epoch - 486ms/step
# Epoch 188/1000
#
# Epoch 188: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 236042.7031 - val_loss: 29879.8945 - 4s/epoch - 554ms/step
# Epoch 189/1000
#
# Epoch 189: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 214713.4219 - val_loss: 52440.6250 - 5s/epoch - 762ms/step
# Epoch 190/1000
#
# Epoch 190: val_loss did not improve from 2410.49585
# 7/7 - 6s - loss: 220428.6562 - val_loss: 4543.8906 - 6s/epoch - 791ms/step
# Epoch 191/1000
#
# Epoch 191: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 217391.8906 - val_loss: 29269.5059 - 4s/epoch - 596ms/step
# Epoch 192/1000
#
# Epoch 192: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 236176.1094 - val_loss: 31026.6328 - 3s/epoch - 471ms/step
# Epoch 193/1000
#
# Epoch 193: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 188492.2188 - val_loss: 25680.8926 - 4s/epoch - 608ms/step
# Epoch 194/1000
#
# Epoch 194: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 228600.7969 - val_loss: 38907.8320 - 5s/epoch - 719ms/step
# Epoch 195/1000
#
# Epoch 195: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 206956.1875 - val_loss: 11994.3711 - 3s/epoch - 483ms/step
# Epoch 196/1000
#
# Epoch 196: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 197453.8125 - val_loss: 2808.6704 - 3s/epoch - 474ms/step
# Epoch 197/1000
#
# Epoch 197: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 223857.8438 - val_loss: 5058.5942 - 3s/epoch - 468ms/step
# Epoch 198/1000
#
# Epoch 198: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 212613.3750 - val_loss: 17726.1465 - 5s/epoch - 709ms/step
# Epoch 199/1000
#
# Epoch 199: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 202764.1406 - val_loss: 5595.1602 - 4s/epoch - 604ms/step
# Epoch 200/1000
#
# Epoch 200: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 196586.9062 - val_loss: 3771.6284 - 3s/epoch - 462ms/step
# Epoch 201/1000
#
# Epoch 201: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 215998.8125 - val_loss: 27103.4492 - 3s/epoch - 467ms/step
# Epoch 202/1000
#
# Epoch 202: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 223776.0469 - val_loss: 39393.7305 - 4s/epoch - 558ms/step
# Epoch 203/1000
#
# Epoch 203: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 202463.5156 - val_loss: 46992.2617 - 5s/epoch - 734ms/step
# Epoch 204/1000
#
# Epoch 204: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 242091.9688 - val_loss: 36433.6953 - 4s/epoch - 502ms/step
# Epoch 205/1000
#
# Epoch 205: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 212399.7500 - val_loss: 17365.3594 - 3s/epoch - 475ms/step
# Epoch 206/1000
#
# Epoch 206: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 214152.4375 - val_loss: 14557.2441 - 3s/epoch - 476ms/step
# Epoch 207/1000
#
# Epoch 207: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 200614.5000 - val_loss: 29208.8848 - 5s/epoch - 705ms/step
# Epoch 208/1000
#
# Epoch 208: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 199026.1562 - val_loss: 38834.5508 - 4s/epoch - 635ms/step
# Epoch 209/1000
#
# Epoch 209: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 240916.8281 - val_loss: 48701.8906 - 3s/epoch - 471ms/step
# Epoch 210/1000
#
# Epoch 210: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 211320.1875 - val_loss: 11580.3213 - 3s/epoch - 476ms/step
# Epoch 211/1000
#
# Epoch 211: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 233756.5625 - val_loss: 3092.6238 - 4s/epoch - 571ms/step
# Epoch 212/1000
#
# Epoch 212: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 244171.2188 - val_loss: 21716.1191 - 5s/epoch - 725ms/step
# Epoch 213/1000
#
# Epoch 213: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 243897.6719 - val_loss: 41315.6406 - 4s/epoch - 507ms/step
# Epoch 214/1000
#
# Epoch 214: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 227365.3125 - val_loss: 17287.9531 - 3s/epoch - 482ms/step
# Epoch 215/1000
#
# Epoch 215: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 229112.9531 - val_loss: 64393.6367 - 3s/epoch - 486ms/step
# Epoch 216/1000
#
# Epoch 216: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 224146.9531 - val_loss: 53775.9102 - 5s/epoch - 721ms/step
# Epoch 217/1000
#
# Epoch 217: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 234074.5156 - val_loss: 27998.9941 - 4s/epoch - 622ms/step
# Epoch 218/1000
#
# Epoch 218: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 230813.8906 - val_loss: 17846.7637 - 3s/epoch - 473ms/step
# Epoch 219/1000
#
# Epoch 219: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 218341.5312 - val_loss: 14042.8760 - 3s/epoch - 463ms/step
# Epoch 220/1000
#
# Epoch 220: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 205329.2969 - val_loss: 16235.1562 - 4s/epoch - 552ms/step
# Epoch 221/1000
#
# Epoch 221: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 230808.6094 - val_loss: 25859.2871 - 5s/epoch - 721ms/step
# Epoch 222/1000
#
# Epoch 222: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 241389.9062 - val_loss: 47901.5469 - 4s/epoch - 517ms/step
# Epoch 223/1000
#
# Epoch 223: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 215649.8125 - val_loss: 23616.2227 - 3s/epoch - 471ms/step
# Epoch 224/1000
#
# Epoch 224: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 242109.2031 - val_loss: 31673.1797 - 3s/epoch - 476ms/step
# Epoch 225/1000
#
# Epoch 225: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 212234.7188 - val_loss: 48072.8281 - 5s/epoch - 695ms/step
# Epoch 226/1000
#
# Epoch 226: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 217073.1719 - val_loss: 64633.3711 - 4s/epoch - 626ms/step
# Epoch 227/1000
#
# Epoch 227: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 210976.5469 - val_loss: 16930.1289 - 3s/epoch - 470ms/step
# Epoch 228/1000
#
# Epoch 228: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 222931.3438 - val_loss: 3040.6294 - 3s/epoch - 479ms/step
# Epoch 229/1000
#
# Epoch 229: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 227301.6406 - val_loss: 4205.2222 - 4s/epoch - 543ms/step
# Epoch 230/1000
#
# Epoch 230: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 196669.5000 - val_loss: 27548.4395 - 5s/epoch - 724ms/step
# Epoch 231/1000
#
# Epoch 231: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 254466.5625 - val_loss: 39293.0703 - 4s/epoch - 531ms/step
# Epoch 232/1000
#
# Epoch 232: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 249013.6719 - val_loss: 90318.3438 - 3s/epoch - 467ms/step
# Epoch 233/1000
#
# Epoch 233: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 215969.7344 - val_loss: 35122.0625 - 3s/epoch - 472ms/step
# Epoch 234/1000
#
# Epoch 234: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 237297.5000 - val_loss: 43453.7188 - 5s/epoch - 674ms/step
# Epoch 235/1000
#
# Epoch 235: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 198008.3750 - val_loss: 5843.1792 - 5s/epoch - 650ms/step
# Epoch 236/1000
#
# Epoch 236: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 219899.0312 - val_loss: 16887.3906 - 3s/epoch - 472ms/step
# Epoch 237/1000
#
# Epoch 237: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 225078.4531 - val_loss: 63700.4531 - 3s/epoch - 465ms/step
# Epoch 238/1000
#
# Epoch 238: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 238462.5938 - val_loss: 44650.4062 - 4s/epoch - 554ms/step
# Epoch 239/1000
#
# Epoch 239: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 219036.8281 - val_loss: 38098.6719 - 5s/epoch - 734ms/step
# Epoch 240/1000
#
# Epoch 240: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 209132.7031 - val_loss: 8821.5723 - 4s/epoch - 513ms/step
# Epoch 241/1000
#
# Epoch 241: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 212069.6094 - val_loss: 4041.5715 - 3s/epoch - 465ms/step
# Epoch 242/1000
#
# Epoch 242: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 201688.0312 - val_loss: 10414.9814 - 3s/epoch - 470ms/step
# Epoch 243/1000
#
# Epoch 243: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 222595.4531 - val_loss: 24767.2656 - 5s/epoch - 688ms/step
# Epoch 244/1000
#
# Epoch 244: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 204143.3125 - val_loss: 24433.9551 - 5s/epoch - 646ms/step
# Epoch 245/1000
#
# Epoch 245: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 202981.6719 - val_loss: 8503.2002 - 3s/epoch - 468ms/step
# Epoch 246/1000
#
# Epoch 246: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 215871.9219 - val_loss: 11303.9062 - 3s/epoch - 480ms/step
# Epoch 247/1000
#
# Epoch 247: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 231432.2656 - val_loss: 6827.4062 - 4s/epoch - 575ms/step
# Epoch 248/1000
#
# Epoch 248: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 229153.6406 - val_loss: 71824.7188 - 5s/epoch - 726ms/step
# Epoch 249/1000
#
# Epoch 249: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 227365.3125 - val_loss: 21154.2969 - 4s/epoch - 506ms/step
# Epoch 250/1000
#
# Epoch 250: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 214618.9062 - val_loss: 20103.4043 - 3s/epoch - 462ms/step
# Epoch 251/1000
#
# Epoch 251: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 214583.4062 - val_loss: 6057.2285 - 3s/epoch - 461ms/step
# Epoch 252/1000
#
# Epoch 252: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 226270.7188 - val_loss: 4340.9370 - 4s/epoch - 636ms/step
# Epoch 253/1000
#
# Epoch 253: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 231951.5625 - val_loss: 39021.4141 - 5s/epoch - 679ms/step
# Epoch 254/1000
#
# Epoch 254: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 196293.4531 - val_loss: 28969.0781 - 3s/epoch - 478ms/step
# Epoch 255/1000
#
# Epoch 255: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 234349.7812 - val_loss: 38671.4023 - 3s/epoch - 471ms/step
# Epoch 256/1000
#
# Epoch 256: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 212882.9531 - val_loss: 31527.7383 - 4s/epoch - 504ms/step
# Epoch 257/1000
#
# Epoch 257: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 196067.1719 - val_loss: 4639.9639 - 5s/epoch - 763ms/step
# Epoch 258/1000
#
# Epoch 258: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 208320.2344 - val_loss: 17093.4199 - 4s/epoch - 539ms/step
# Epoch 259/1000
#
# Epoch 259: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 217890.7969 - val_loss: 8109.5254 - 3s/epoch - 475ms/step
# Epoch 260/1000
#
# Epoch 260: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 204071.3438 - val_loss: 5739.5151 - 3s/epoch - 470ms/step
# Epoch 261/1000
#
# Epoch 261: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 235221.9844 - val_loss: 55632.0586 - 5s/epoch - 691ms/step
# Epoch 262/1000
#
# Epoch 262: val_loss did not improve from 2410.49585
# 7/7 - 6s - loss: 231177.9062 - val_loss: 40350.3711 - 6s/epoch - 800ms/step
# Epoch 263/1000
#
# Epoch 263: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 240864.3906 - val_loss: 21790.5801 - 5s/epoch - 768ms/step
# Epoch 264/1000
#
# Epoch 264: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 202316.3906 - val_loss: 3834.8523 - 3s/epoch - 462ms/step
# Epoch 265/1000
#
# Epoch 265: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 212566.5938 - val_loss: 18091.5469 - 3s/epoch - 469ms/step
# Epoch 266/1000
#
# Epoch 266: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 224636.8594 - val_loss: 11235.2812 - 4s/epoch - 565ms/step
# Epoch 267/1000
#
# Epoch 267: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 237401.3125 - val_loss: 12870.1641 - 5s/epoch - 719ms/step
# Epoch 268/1000
#
# Epoch 268: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 209171.9531 - val_loss: 8443.8584 - 4s/epoch - 510ms/step
# Epoch 269/1000
#
# Epoch 269: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 257383.8125 - val_loss: 12822.7197 - 3s/epoch - 457ms/step
# Epoch 270/1000
#
# Epoch 270: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 193243.4375 - val_loss: 13760.9365 - 3s/epoch - 465ms/step
# Epoch 271/1000
#
# Epoch 271: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 221411.6250 - val_loss: 4328.3818 - 5s/epoch - 667ms/step
# Epoch 272/1000
#
# Epoch 272: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 229186.6250 - val_loss: 4398.5210 - 5s/epoch - 654ms/step
# Epoch 273/1000
#
# Epoch 273: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 248502.1406 - val_loss: 5622.2007 - 3s/epoch - 494ms/step
# Epoch 274/1000
#
# Epoch 274: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 203638.0156 - val_loss: 12034.8926 - 3s/epoch - 461ms/step
# Epoch 275/1000
#
# Epoch 275: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 196660.2344 - val_loss: 13216.0527 - 4s/epoch - 523ms/step
# Epoch 276/1000
#
# Epoch 276: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 234411.2031 - val_loss: 6868.9624 - 5s/epoch - 727ms/step
# Epoch 277/1000
#
# Epoch 277: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 202644.5781 - val_loss: 35783.7070 - 4s/epoch - 543ms/step
# Epoch 278/1000
#
# Epoch 278: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 220599.5625 - val_loss: 90145.8516 - 3s/epoch - 471ms/step
# Epoch 279/1000
#
# Epoch 279: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 229430.5625 - val_loss: 70379.1484 - 3s/epoch - 485ms/step
# Epoch 280/1000
#
# Epoch 280: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 241834.5625 - val_loss: 7570.4263 - 5s/epoch - 657ms/step
# Epoch 281/1000
#
# Epoch 281: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 255940.2500 - val_loss: 17906.2969 - 5s/epoch - 691ms/step
# Epoch 282/1000
#
# Epoch 282: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 210900.4219 - val_loss: 3688.3469 - 3s/epoch - 477ms/step
# Epoch 283/1000
#
# Epoch 283: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 248361.4844 - val_loss: 27858.1855 - 3s/epoch - 472ms/step
# Epoch 284/1000
#
# Epoch 284: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 233141.1562 - val_loss: 78672.8516 - 4s/epoch - 553ms/step
# Epoch 285/1000
#
# Epoch 285: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 243990.1875 - val_loss: 83516.7422 - 5s/epoch - 734ms/step
# Epoch 286/1000
#
# Epoch 286: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 241496.5000 - val_loss: 7232.5356 - 4s/epoch - 540ms/step
# Epoch 287/1000
#
# Epoch 287: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 225479.5469 - val_loss: 5571.5840 - 3s/epoch - 474ms/step
# Epoch 288/1000
#
# Epoch 288: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 196014.0781 - val_loss: 24439.0527 - 3s/epoch - 470ms/step
# Epoch 289/1000
#
# Epoch 289: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 204338.8594 - val_loss: 25106.8496 - 5s/epoch - 652ms/step
# Epoch 290/1000
#
# Epoch 290: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 215968.9688 - val_loss: 32732.7109 - 5s/epoch - 680ms/step
# Epoch 291/1000
#
# Epoch 291: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 230242.3750 - val_loss: 7501.9907 - 3s/epoch - 465ms/step
# Epoch 292/1000
#
# Epoch 292: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 211208.8281 - val_loss: 20123.3848 - 3s/epoch - 471ms/step
# Epoch 293/1000
#
# Epoch 293: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 197971.2812 - val_loss: 6995.7783 - 4s/epoch - 532ms/step
# Epoch 294/1000
#
# Epoch 294: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 239458.8594 - val_loss: 29827.0605 - 5s/epoch - 757ms/step
# Epoch 295/1000
#
# Epoch 295: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 229852.7969 - val_loss: 37313.4805 - 4s/epoch - 530ms/step
# Epoch 296/1000
#
# Epoch 296: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 203557.7500 - val_loss: 9653.1924 - 3s/epoch - 463ms/step
# Epoch 297/1000
#
# Epoch 297: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 225174.4844 - val_loss: 3524.5120 - 3s/epoch - 462ms/step
# Epoch 298/1000
#
# Epoch 298: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 214128.3281 - val_loss: 5291.2007 - 4s/epoch - 625ms/step
# Epoch 299/1000
#
# Epoch 299: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 210687.0312 - val_loss: 10236.6797 - 5s/epoch - 693ms/step
# Epoch 300/1000
#
# Epoch 300: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 215354.7969 - val_loss: 5835.3042 - 3s/epoch - 465ms/step
# Epoch 301/1000
#
# Epoch 301: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 186083.5000 - val_loss: 3707.0583 - 3s/epoch - 464ms/step
# Epoch 302/1000
#
# Epoch 302: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 228816.1094 - val_loss: 18917.7188 - 3s/epoch - 469ms/step
# Epoch 303/1000
#
# Epoch 303: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 223605.3281 - val_loss: 50043.9062 - 5s/epoch - 754ms/step
# Epoch 304/1000
#
# Epoch 304: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 234573.1562 - val_loss: 6435.0806 - 4s/epoch - 569ms/step
# Epoch 305/1000
#
# Epoch 305: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 214397.4531 - val_loss: 6436.4507 - 3s/epoch - 468ms/step
# Epoch 306/1000
#
# Epoch 306: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 215167.2031 - val_loss: 5038.9595 - 3s/epoch - 482ms/step
# Epoch 307/1000
#
# Epoch 307: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 196488.9062 - val_loss: 44464.7969 - 5s/epoch - 662ms/step
# Epoch 308/1000
#
# Epoch 308: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 211485.4062 - val_loss: 33208.7031 - 5s/epoch - 691ms/step
# Epoch 309/1000
#
# Epoch 309: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 210857.5312 - val_loss: 23530.5195 - 3s/epoch - 481ms/step
# Epoch 310/1000
#
# Epoch 310: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 189924.6562 - val_loss: 20017.7969 - 3s/epoch - 473ms/step
# Epoch 311/1000
#
# Epoch 311: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 204804.7969 - val_loss: 22357.3672 - 4s/epoch - 534ms/step
# Epoch 312/1000
#
# Epoch 312: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 213646.9375 - val_loss: 8207.5684 - 5s/epoch - 725ms/step
# Epoch 313/1000
#
# Epoch 313: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 197856.9531 - val_loss: 22517.3477 - 4s/epoch - 549ms/step
# Epoch 314/1000
#
# Epoch 314: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 220910.1250 - val_loss: 46063.0117 - 3s/epoch - 468ms/step
# Epoch 315/1000
#
# Epoch 315: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 193060.9844 - val_loss: 29167.4746 - 3s/epoch - 463ms/step
# Epoch 316/1000
#
# Epoch 316: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 212970.6562 - val_loss: 5360.8911 - 4s/epoch - 627ms/step
# Epoch 317/1000
#
# ...
# Epoch 891/1000
#
# Epoch 891: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 198012.3906 - val_loss: 4345.7583 - 4s/epoch - 590ms/step
# Epoch 892/1000
#
# Epoch 892: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 173011.3438 - val_loss: 22592.1523 - 3s/epoch - 465ms/step
# Epoch 893/1000
#
# Epoch 893: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 186637.5625 - val_loss: 7406.7114 - 3s/epoch - 469ms/step
# Epoch 894/1000
#
# Epoch 894: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 171223.3125 - val_loss: 4079.8040 - 4s/epoch - 586ms/step
# Epoch 895/1000
#
# Epoch 895: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 191087.5156 - val_loss: 7217.2739 - 5s/epoch - 702ms/step
# Epoch 896/1000
#
# Epoch 896: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 165651.5000 - val_loss: 6054.1431 - 3s/epoch - 490ms/step
# Epoch 897/1000
#
# Epoch 897: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 178112.6562 - val_loss: 6316.0537 - 3s/epoch - 469ms/step
# Epoch 898/1000
#
# Epoch 898: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 172781.5312 - val_loss: 4499.7217 - 3s/epoch - 476ms/step
# Epoch 899/1000
#
# Epoch 899: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 161453.2812 - val_loss: 3415.8379 - 5s/epoch - 732ms/step
# Epoch 900/1000
#
# Epoch 900: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 198765.7500 - val_loss: 3692.5249 - 4s/epoch - 600ms/step
# Epoch 901/1000
#
# Epoch 901: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 160972.5000 - val_loss: 3162.8018 - 3s/epoch - 452ms/step
# Epoch 902/1000
#
# Epoch 902: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 198296.0469 - val_loss: 16509.6973 - 3s/epoch - 459ms/step
# Epoch 903/1000
#
# Epoch 903: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 186127.8438 - val_loss: 12465.6777 - 4s/epoch - 540ms/step
# Epoch 904/1000
#
# Epoch 904: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 167405.0625 - val_loss: 4777.8140 - 5s/epoch - 740ms/step
# Epoch 905/1000
#
# Epoch 905: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 178558.8906 - val_loss: 3215.0803 - 4s/epoch - 507ms/step
# Epoch 906/1000
#
# Epoch 906: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 161239.5469 - val_loss: 12122.4648 - 3s/epoch - 473ms/step
# Epoch 907/1000
#
# Epoch 907: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 178747.5156 - val_loss: 18723.5547 - 4s/epoch - 581ms/step
# Epoch 908/1000
#
# Epoch 908: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 185724.0781 - val_loss: 10835.7217 - 5s/epoch - 784ms/step
# Epoch 909/1000
#
# Epoch 909: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 179161.0781 - val_loss: 3619.1414 - 5s/epoch - 764ms/step
# Epoch 910/1000
#
# Epoch 910: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 190244.8281 - val_loss: 26661.1191 - 4s/epoch - 547ms/step
# Epoch 911/1000
#
# Epoch 911: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 200570.9531 - val_loss: 45471.5508 - 3s/epoch - 459ms/step
# Epoch 912/1000
#
# Epoch 912: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 242703.5312 - val_loss: 3371.2231 - 3s/epoch - 464ms/step
# Epoch 913/1000
#
# Epoch 913: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 192885.6875 - val_loss: 6134.0801 - 4s/epoch - 639ms/step
# Epoch 914/1000
#
# Epoch 914: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 196214.0938 - val_loss: 22802.7070 - 5s/epoch - 692ms/step
# Epoch 915/1000
#
# Epoch 915: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 195231.0469 - val_loss: 16455.0684 - 3s/epoch - 462ms/step
# Epoch 916/1000
#
# Epoch 916: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 183145.1875 - val_loss: 5587.2383 - 3s/epoch - 468ms/step
# Epoch 917/1000
#
# Epoch 917: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 171334.3125 - val_loss: 16042.8311 - 3s/epoch - 483ms/step
# Epoch 918/1000
#
# Epoch 918: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 162109.6406 - val_loss: 18447.3516 - 5s/epoch - 724ms/step
# Epoch 919/1000
#
# Epoch 919: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 170839.6094 - val_loss: 14083.7412 - 4s/epoch - 583ms/step
# Epoch 920/1000
#
# Epoch 920: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 154032.7188 - val_loss: 5299.7100 - 3s/epoch - 465ms/step
# Epoch 921/1000
#
# Epoch 921: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 192020.2188 - val_loss: 3193.5801 - 3s/epoch - 470ms/step
# Epoch 922/1000
#
# Epoch 922: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 181352.0156 - val_loss: 11428.7314 - 4s/epoch - 620ms/step
# Epoch 923/1000
#
# Epoch 923: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 180270.6719 - val_loss: 21200.7559 - 5s/epoch - 714ms/step
# Epoch 924/1000
#
# Epoch 924: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 198088.8438 - val_loss: 3455.8848 - 3s/epoch - 454ms/step
# Epoch 925/1000
#
# Epoch 925: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 184975.7500 - val_loss: 5837.6064 - 3s/epoch - 464ms/step
# Epoch 926/1000
#
# Epoch 926: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 204060.5781 - val_loss: 13817.0752 - 3s/epoch - 460ms/step
# Epoch 927/1000
#
# Epoch 927: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 186551.3438 - val_loss: 7803.1045 - 5s/epoch - 693ms/step
# Epoch 928/1000
#
# Epoch 928: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 181178.8594 - val_loss: 3253.8640 - 4s/epoch - 622ms/step
# Epoch 929/1000
#
# Epoch 929: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 191355.2969 - val_loss: 13256.8574 - 3s/epoch - 457ms/step
# Epoch 930/1000
#
# Epoch 930: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 163126.2188 - val_loss: 24756.6699 - 3s/epoch - 457ms/step
# Epoch 931/1000
#
# Epoch 931: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 193224.6562 - val_loss: 16183.6465 - 4s/epoch - 529ms/step
# Epoch 932/1000
#
# Epoch 932: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 176038.5156 - val_loss: 3775.4631 - 5s/epoch - 748ms/step
# Epoch 933/1000
#
# Epoch 933: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 187920.7500 - val_loss: 3394.4700 - 4s/epoch - 522ms/step
# Epoch 934/1000
#
# Epoch 934: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 165392.9062 - val_loss: 3710.4312 - 3s/epoch - 472ms/step
# Epoch 935/1000
#
# Epoch 935: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 150898.6875 - val_loss: 11419.4658 - 3s/epoch - 464ms/step
# Epoch 936/1000
#
# Epoch 936: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 177646.6250 - val_loss: 13111.1035 - 5s/epoch - 675ms/step
# Epoch 937/1000
#
# Epoch 937: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 182903.1094 - val_loss: 32813.6836 - 5s/epoch - 654ms/step
# Epoch 938/1000
#
# Epoch 938: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 162799.8438 - val_loss: 8962.7285 - 3s/epoch - 463ms/step
# Epoch 939/1000
#
# Epoch 939: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 189768.9219 - val_loss: 4060.7988 - 3s/epoch - 464ms/step
# Epoch 940/1000
#
# Epoch 940: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 189082.1250 - val_loss: 11293.3174 - 4s/epoch - 500ms/step
# Epoch 941/1000
#
# Epoch 941: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 189300.3438 - val_loss: 10581.4883 - 5s/epoch - 708ms/step
# Epoch 942/1000
#
# Epoch 942: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 169555.5469 - val_loss: 5079.5645 - 4s/epoch - 553ms/step
# Epoch 943/1000
#
# Epoch 943: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 171019.8750 - val_loss: 4186.9541 - 3s/epoch - 471ms/step
# Epoch 944/1000
#
# Epoch 944: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 185729.8906 - val_loss: 10441.2998 - 3s/epoch - 466ms/step
# Epoch 945/1000
#
# Epoch 945: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 187443.6719 - val_loss: 4169.1626 - 4s/epoch - 640ms/step
# Epoch 946/1000
#
# Epoch 946: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 169838.2656 - val_loss: 5984.1650 - 5s/epoch - 707ms/step
# Epoch 947/1000
#
# Epoch 947: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 179435.8750 - val_loss: 8501.2021 - 3s/epoch - 480ms/step
# Epoch 948/1000
#
# Epoch 948: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 173660.0312 - val_loss: 5870.7598 - 3s/epoch - 473ms/step
# Epoch 949/1000
#
# Epoch 949: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 188791.4531 - val_loss: 5159.2280 - 4s/epoch - 518ms/step
# Epoch 950/1000
#
# Epoch 950: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 196821.5156 - val_loss: 3931.0522 - 5s/epoch - 728ms/step
# Epoch 951/1000
#
# Epoch 951: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 181198.7812 - val_loss: 3486.6438 - 4s/epoch - 551ms/step
# Epoch 952/1000
#
# Epoch 952: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 170577.2188 - val_loss: 3286.8091 - 3s/epoch - 477ms/step
# Epoch 953/1000
#
# Epoch 953: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 184890.3906 - val_loss: 3170.2429 - 3s/epoch - 478ms/step
# Epoch 954/1000
#
# Epoch 954: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 169117.5469 - val_loss: 24881.9824 - 5s/epoch - 659ms/step
# Epoch 955/1000
#
# Epoch 955: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 176848.9844 - val_loss: 4739.7607 - 5s/epoch - 676ms/step
# Epoch 956/1000
#
# Epoch 956: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 176415.0312 - val_loss: 20348.5957 - 3s/epoch - 463ms/step
# Epoch 957/1000
#
# Epoch 957: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 175586.4688 - val_loss: 32492.2754 - 3s/epoch - 471ms/step
# Epoch 958/1000
#
# Epoch 958: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 176537.5625 - val_loss: 4976.4961 - 3s/epoch - 497ms/step
# Epoch 959/1000
#
# Epoch 959: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 183974.7188 - val_loss: 3793.2976 - 5s/epoch - 731ms/step
# Epoch 960/1000
#
# Epoch 960: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 162307.0312 - val_loss: 4471.1313 - 4s/epoch - 567ms/step
# Epoch 961/1000
#
# Epoch 961: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 172490.1094 - val_loss: 4203.6357 - 3s/epoch - 469ms/step
# Epoch 962/1000
#
# Epoch 962: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 179914.3438 - val_loss: 6296.1992 - 3s/epoch - 461ms/step
# Epoch 963/1000
#
# Epoch 963: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 188355.9844 - val_loss: 5759.7788 - 4s/epoch - 608ms/step
# Epoch 964/1000
#
# Epoch 964: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 180390.8125 - val_loss: 3015.8977 - 5s/epoch - 726ms/step
# Epoch 965/1000
#
# Epoch 965: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 168530.0781 - val_loss: 3621.0581 - 3s/epoch - 472ms/step
# Epoch 966/1000
#
# Epoch 966: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 183024.5781 - val_loss: 11140.4199 - 3s/epoch - 472ms/step
# Epoch 967/1000
#
# Epoch 967: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 171239.4844 - val_loss: 10648.9834 - 3s/epoch - 473ms/step
# Epoch 968/1000
#
# Epoch 968: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 141447.9844 - val_loss: 3224.9153 - 5s/epoch - 728ms/step
# Epoch 969/1000
#
# Epoch 969: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 183601.8750 - val_loss: 3915.9221 - 4s/epoch - 596ms/step
# Epoch 970/1000
#
# Epoch 970: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 153874.3906 - val_loss: 3001.0293 - 3s/epoch - 467ms/step
# Epoch 971/1000
#
# Epoch 971: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 206510.7031 - val_loss: 6064.7388 - 3s/epoch - 468ms/step
# Epoch 972/1000
#
# Epoch 972: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 165089.5469 - val_loss: 10149.0176 - 4s/epoch - 565ms/step
# Epoch 973/1000
#
# Epoch 973: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 209651.6719 - val_loss: 3247.5264 - 5s/epoch - 720ms/step
# Epoch 974/1000
#
# Epoch 974: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 201110.4531 - val_loss: 6006.6914 - 3s/epoch - 499ms/step
# Epoch 975/1000
#
# Epoch 975: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 184668.1250 - val_loss: 4579.2993 - 3s/epoch - 477ms/step
# Epoch 976/1000
#
# Epoch 976: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 168066.7500 - val_loss: 9156.5527 - 3s/epoch - 471ms/step
# Epoch 977/1000
#
# Epoch 977: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 189559.3438 - val_loss: 5886.2373 - 5s/epoch - 698ms/step
# Epoch 978/1000
#
# Epoch 978: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 160131.7188 - val_loss: 13158.5850 - 4s/epoch - 629ms/step
# Epoch 979/1000
#
# Epoch 979: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 178626.2188 - val_loss: 17167.4160 - 5s/epoch - 703ms/step
# Epoch 980/1000
#
# Epoch 980: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 186048.0156 - val_loss: 3180.8396 - 5s/epoch - 701ms/step
# Epoch 981/1000
#
# Epoch 981: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 175813.2188 - val_loss: 5230.7466 - 5s/epoch - 721ms/step
# Epoch 982/1000
#
# Epoch 982: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 173695.7969 - val_loss: 5431.9683 - 4s/epoch - 536ms/step
# Epoch 983/1000
#
# Epoch 983: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 171904.4688 - val_loss: 10731.6699 - 3s/epoch - 471ms/step
# Epoch 984/1000
#
# Epoch 984: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 190455.9219 - val_loss: 11880.0742 - 3s/epoch - 474ms/step
# Epoch 985/1000
#
# Epoch 985: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 174062.4844 - val_loss: 3670.0010 - 5s/epoch - 651ms/step
# Epoch 986/1000
#
# Epoch 986: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 178110.9219 - val_loss: 29113.0352 - 5s/epoch - 669ms/step
# Epoch 987/1000
#
# Epoch 987: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 172612.7188 - val_loss: 14009.4805 - 3s/epoch - 464ms/step
# Epoch 988/1000
#
# Epoch 988: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 170614.2031 - val_loss: 5770.7539 - 3s/epoch - 466ms/step
# Epoch 989/1000
#
# Epoch 989: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 191066.0156 - val_loss: 17526.4023 - 3s/epoch - 496ms/step
# Epoch 990/1000
#
# Epoch 990: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 196279.8594 - val_loss: 5122.5957 - 5s/epoch - 748ms/step
# Epoch 991/1000
#
# Epoch 991: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 160186.2188 - val_loss: 5677.1299 - 4s/epoch - 557ms/step
# Epoch 992/1000
#
# Epoch 992: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 186677.7188 - val_loss: 3533.7881 - 3s/epoch - 475ms/step
# Epoch 993/1000
#
# Epoch 993: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 189895.6094 - val_loss: 3985.3809 - 3s/epoch - 477ms/step
# Epoch 994/1000
#
# Epoch 994: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 165760.1094 - val_loss: 8994.0713 - 4s/epoch - 641ms/step
# Epoch 995/1000
#
# Epoch 995: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 174544.6875 - val_loss: 3004.4509 - 5s/epoch - 697ms/step
# Epoch 996/1000
#
# Epoch 996: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 171079.0938 - val_loss: 2857.9915 - 3s/epoch - 485ms/step
# Epoch 997/1000
#
# Epoch 997: val_loss did not improve from 2410.49585
# 7/7 - 3s - loss: 178265.0938 - val_loss: 8860.3438 - 3s/epoch - 495ms/step
# Epoch 998/1000
#
# Epoch 998: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 151978.1562 - val_loss: 2938.7954 - 4s/epoch - 551ms/step
# Epoch 999/1000
#
# Epoch 999: val_loss did not improve from 2410.49585
# 7/7 - 5s - loss: 168765.9688 - val_loss: 4677.1528 - 5s/epoch - 753ms/step
# Epoch 1000/1000
#
# Epoch 1000: val_loss did not improve from 2410.49585
# 7/7 - 4s - loss: 168041.2656 - val_loss: 4712.8916 - 4s/epoch - 529ms/step
# 16/16 [==============================] - 3s 112ms/step
# 3/3 [==============================] - 0s 90ms/step
# Training MSE: 6707.278263027342
# Testing MSE: 3769.270468932615
# accuracy : 51

# %%
# 모델 생성
model = Sequential()
model.add(Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(MaxPooling1D(pool_size=2))
model.add(GRU(units=1024, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=512, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=256, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=128, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=64, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=32, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(GRU(units=16, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(units=1))
model.summary()


# loss = Huber()
# optimizer = Adam(0.0005)
# model.compile(loss=Huber(), optimizer=optimizer, metrics=['mse'])
model.compile(optimizer='adam', loss='mean_squared_error')

filename = os.path.join('tmp', 'ckeckpointer.ckpt')
checkpoint = ModelCheckpoint(filename,
                             save_weights_only=True,
                             save_best_only=True,
                             monitor='val_loss',
                             verbose=1)

# 모델 학습
history = model.fit(trainX, trainY, epochs=1000, batch_size=64,
          validation_split=0.1, verbose=2,callbacks=[checkpoint])

model.save_weights('./lstm_weights.h2')

model.load_weights(filename)

plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()
plt.show()

# 예측
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# MSE 계산
trainMSE = mean_squared_error(trainY, trainPredict)
testMSE = mean_squared_error(testY, testPredict)

print(f'Training MSE: {trainMSE}')
print(f'Testing MSE: {testMSE}')

accuracy(testPredict,testY)

# 예측 시각화
plt.plot(trainY, label='Actual Price')
plt.plot(trainPredict, label='Predicted Price')
plt.legend()
plt.title('Training Data')
plt.show()

plt.plot(testY, label='Actual Price')
plt.plot(testPredict, label='Predicted Price')
plt.legend()
plt.title('Testing Data')
plt.show()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 3, 256)            7936
#
#  max_pooling1d_2 (MaxPoolin  (None, 1, 256)            0
#  g1D)
#
#  gru_19 (GRU)                (None, 1, 1024)           3938304
#
#  dropout_26 (Dropout)        (None, 1, 1024)           0
#
#  gru_20 (GRU)                (None, 1, 512)            2362368
#
#  dropout_27 (Dropout)        (None, 1, 512)            0
#
#  gru_21 (GRU)                (None, 1, 256)            591360
#
#  dropout_28 (Dropout)        (None, 1, 256)            0
#
#  gru_22 (GRU)                (None, 1, 128)            148224
#
#  dropout_29 (Dropout)        (None, 1, 128)            0
#
#  gru_23 (GRU)                (None, 1, 64)             37248
#
#  dropout_30 (Dropout)        (None, 1, 64)             0
#
#  gru_24 (GRU)                (None, 1, 32)             9408
#
#  dropout_31 (Dropout)        (None, 1, 32)             0
#
#  gru_25 (GRU)                (None, 16)                2400
#
#  dropout_32 (Dropout)        (None, 16)                0
#
#  dense_4 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 7097265 (27.07 MB)
# Trainable params: 7097265 (27.07 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/1000
#
# Epoch 1: val_loss improved from inf to 5710838.50000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 16s - loss: 8167922.5000 - val_loss: 5710838.5000 - 16s/epoch - 2s/step
# Epoch 2/1000
#
# Epoch 2: val_loss improved from 5710838.50000 to 5709206.50000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 8167488.5000 - val_loss: 5709206.5000 - 1s/epoch - 196ms/step
# Epoch 3/1000
#
# Epoch 3: val_loss improved from 5709206.50000 to 5638742.50000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 8144763.0000 - val_loss: 5638742.5000 - 1s/epoch - 193ms/step
# Epoch 4/1000
#
# Epoch 4: val_loss improved from 5638742.50000 to 4924968.50000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 2s - loss: 7820771.5000 - val_loss: 4924968.5000 - 2s/epoch - 290ms/step
# Epoch 5/1000
#
# Epoch 5: val_loss improved from 4924968.50000 to 1991959.37500, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 6177714.5000 - val_loss: 1991959.3750 - 1s/epoch - 203ms/step
# Epoch 6/1000
#
# Epoch 6: val_loss improved from 1991959.37500 to 257077.85938, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 3316741.2500 - val_loss: 257077.8594 - 1s/epoch - 190ms/step
# Epoch 7/1000
#
# Epoch 7: val_loss did not improve from 257077.85938
# 7/7 - 1s - loss: 2590906.7500 - val_loss: 273002.6250 - 1s/epoch - 173ms/step
# Epoch 8/1000
#
# Epoch 8: val_loss did not improve from 257077.85938
# 7/7 - 2s - loss: 2334965.2500 - val_loss: 926024.2500 - 2s/epoch - 235ms/step
# Epoch 9/1000
#
# Epoch 9: val_loss improved from 257077.85938 to 240977.21875, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 2s - loss: 2383327.2500 - val_loss: 240977.2188 - 2s/epoch - 270ms/step
# Epoch 10/1000
#
# Epoch 10: val_loss improved from 240977.21875 to 220897.79688, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 2s - loss: 2261849.7500 - val_loss: 220897.7969 - 2s/epoch - 273ms/step
# Epoch 11/1000
#
# Epoch 11: val_loss did not improve from 220897.79688
# 7/7 - 2s - loss: 2145726.7500 - val_loss: 661095.0625 - 2s/epoch - 230ms/step
# Epoch 12/1000
#
# Epoch 12: val_loss did not improve from 220897.79688
# 7/7 - 1s - loss: 2448109.5000 - val_loss: 698626.3125 - 1s/epoch - 168ms/step
# Epoch 13/1000
#
# Epoch 13: val_loss did not improve from 220897.79688
# 7/7 - 1s - loss: 1827524.8750 - val_loss: 525597.5625 - 1s/epoch - 159ms/step
# Epoch 14/1000
#
# Epoch 14: val_loss did not improve from 220897.79688
# 7/7 - 1s - loss: 1864299.2500 - val_loss: 534235.4375 - 1s/epoch - 155ms/step
# Epoch 15/1000
#
# Epoch 15: val_loss did not improve from 220897.79688
# 7/7 - 1s - loss: 1901104.6250 - val_loss: 759191.7500 - 1s/epoch - 152ms/step
# Epoch 16/1000
#
# Epoch 16: val_loss did not improve from 220897.79688
# 7/7 - 1s - loss: 1910896.1250 - val_loss: 744032.3125 - 1s/epoch - 152ms/step
# Epoch 17/1000
#
# Epoch 17: val_loss did not improve from 220897.79688
# 7/7 - 1s - loss: 1710007.6250 - val_loss: 396854.2500 - 1s/epoch - 156ms/step
# Epoch 18/1000
#
# Epoch 18: val_loss did not improve from 220897.79688
# 7/7 - 1s - loss: 1862642.6250 - val_loss: 518922.7500 - 1s/epoch - 151ms/step
# Epoch 19/1000
#
# Epoch 19: val_loss did not improve from 220897.79688
# 7/7 - 1s - loss: 1833980.0000 - val_loss: 486743.3125 - 1s/epoch - 156ms/step
# Epoch 20/1000
#
# Epoch 20: val_loss did not improve from 220897.79688
# 7/7 - 1s - loss: 1706661.7500 - val_loss: 272730.3750 - 1s/epoch - 155ms/step
# Epoch 21/1000
#
# Epoch 21: val_loss did not improve from 220897.79688
# 7/7 - 1s - loss: 1790111.1250 - val_loss: 387160.1562 - 1s/epoch - 212ms/step
# Epoch 22/1000
#
# Epoch 22: val_loss did not improve from 220897.79688
# 7/7 - 2s - loss: 1845033.7500 - val_loss: 407070.1250 - 2s/epoch - 231ms/step
# Epoch 23/1000
#
# Epoch 23: val_loss improved from 220897.79688 to 143243.50000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 2s - loss: 1648300.8750 - val_loss: 143243.5000 - 2s/epoch - 276ms/step
# Epoch 24/1000
#
# Epoch 24: val_loss did not improve from 143243.50000
# 7/7 - 2s - loss: 1644917.8750 - val_loss: 184450.0938 - 2s/epoch - 232ms/step
# Epoch 25/1000
#
# Epoch 25: val_loss did not improve from 143243.50000
# 7/7 - 1s - loss: 1533820.6250 - val_loss: 260521.7969 - 1s/epoch - 203ms/step
# Epoch 26/1000
#
# Epoch 26: val_loss did not improve from 143243.50000
# 7/7 - 1s - loss: 1509958.6250 - val_loss: 272252.7188 - 1s/epoch - 156ms/step
# Epoch 27/1000
#
# Epoch 27: val_loss improved from 143243.50000 to 113863.35938, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 1704172.3750 - val_loss: 113863.3594 - 1s/epoch - 183ms/step
# Epoch 28/1000
#
# Epoch 28: val_loss did not improve from 113863.35938
# 7/7 - 1s - loss: 1817901.8750 - val_loss: 406586.5312 - 1s/epoch - 159ms/step
# Epoch 29/1000
#
# Epoch 29: val_loss did not improve from 113863.35938
# 7/7 - 1s - loss: 1536345.6250 - val_loss: 301360.3125 - 1s/epoch - 159ms/step
# Epoch 30/1000
#
# Epoch 30: val_loss did not improve from 113863.35938
# 7/7 - 1s - loss: 1520391.2500 - val_loss: 351443.2500 - 1s/epoch - 158ms/step
# Epoch 31/1000
#
# Epoch 31: val_loss did not improve from 113863.35938
# 7/7 - 1s - loss: 1470717.1250 - val_loss: 327986.4062 - 1s/epoch - 153ms/step
# Epoch 32/1000
#
# Epoch 32: val_loss did not improve from 113863.35938
# 7/7 - 1s - loss: 1423540.1250 - val_loss: 384096.4375 - 1s/epoch - 157ms/step
# Epoch 33/1000
#
# Epoch 33: val_loss did not improve from 113863.35938
# 7/7 - 1s - loss: 1510817.8750 - val_loss: 253907.5938 - 1s/epoch - 153ms/step
# Epoch 34/1000
#
# Epoch 34: val_loss did not improve from 113863.35938
# 7/7 - 1s - loss: 1460778.3750 - val_loss: 425190.3125 - 1s/epoch - 197ms/step
# Epoch 35/1000
#
# Epoch 35: val_loss did not improve from 113863.35938
# 7/7 - 2s - loss: 1379473.6250 - val_loss: 484466.8750 - 2s/epoch - 245ms/step
# Epoch 36/1000
#
# Epoch 36: val_loss did not improve from 113863.35938
# 7/7 - 2s - loss: 1432025.7500 - val_loss: 412803.0312 - 2s/epoch - 236ms/step
# Epoch 37/1000
#
# Epoch 37: val_loss did not improve from 113863.35938
# 7/7 - 2s - loss: 1362773.6250 - val_loss: 259170.2969 - 2s/epoch - 239ms/step
# Epoch 38/1000
#
# Epoch 38: val_loss did not improve from 113863.35938
# 7/7 - 2s - loss: 1430808.5000 - val_loss: 470002.0312 - 2s/epoch - 231ms/step
# Epoch 39/1000
#
# Epoch 39: val_loss did not improve from 113863.35938
# 7/7 - 1s - loss: 1346735.3750 - val_loss: 322550.9062 - 1s/epoch - 159ms/step
# Epoch 40/1000
#
# Epoch 40: val_loss did not improve from 113863.35938
# 7/7 - 1s - loss: 1266494.0000 - val_loss: 326695.7188 - 1s/epoch - 156ms/step
# Epoch 41/1000
#
# Epoch 41: val_loss did not improve from 113863.35938
# 7/7 - 1s - loss: 1385509.0000 - val_loss: 298860.3750 - 1s/epoch - 162ms/step
# Epoch 42/1000
#
# Epoch 42: val_loss did not improve from 113863.35938
# 7/7 - 1s - loss: 1338196.6250 - val_loss: 333785.1562 - 1s/epoch - 159ms/step
# Epoch 43/1000
#
# Epoch 43: val_loss did not improve from 113863.35938
# 7/7 - 1s - loss: 1298800.3750 - val_loss: 266147.0312 - 1s/epoch - 155ms/step
# Epoch 44/1000
#
# Epoch 44: val_loss did not improve from 113863.35938
# 7/7 - 1s - loss: 1276306.1250 - val_loss: 293434.0625 - 1s/epoch - 155ms/step
# Epoch 45/1000
#
# Epoch 45: val_loss did not improve from 113863.35938
# 7/7 - 1s - loss: 1380738.0000 - val_loss: 467639.8125 - 1s/epoch - 154ms/step
# Epoch 46/1000
#
# Epoch 46: val_loss did not improve from 113863.35938
# 7/7 - 1s - loss: 1235655.5000 - val_loss: 265433.5938 - 1s/epoch - 156ms/step
# Epoch 47/1000
#
# Epoch 47: val_loss improved from 113863.35938 to 96324.10938, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 1349485.8750 - val_loss: 96324.1094 - 1s/epoch - 190ms/step
# Epoch 48/1000
#
# Epoch 48: val_loss did not improve from 96324.10938
# 7/7 - 2s - loss: 1167777.1250 - val_loss: 499863.9062 - 2s/epoch - 234ms/step
# Epoch 49/1000
#
# Epoch 49: val_loss did not improve from 96324.10938
# 7/7 - 2s - loss: 1294679.6250 - val_loss: 198084.6875 - 2s/epoch - 233ms/step
# Epoch 50/1000
#
# Epoch 50: val_loss did not improve from 96324.10938
# 7/7 - 2s - loss: 1172671.3750 - val_loss: 377092.0312 - 2s/epoch - 234ms/step
# Epoch 51/1000
#
# Epoch 51: val_loss did not improve from 96324.10938
# 7/7 - 2s - loss: 1213504.8750 - val_loss: 167971.2188 - 2s/epoch - 232ms/step
# Epoch 52/1000
#
# Epoch 52: val_loss did not improve from 96324.10938
# 7/7 - 1s - loss: 1272875.2500 - val_loss: 574470.5625 - 1s/epoch - 189ms/step
# Epoch 53/1000
#
# Epoch 53: val_loss improved from 96324.10938 to 65955.63281, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 1132055.1250 - val_loss: 65955.6328 - 1s/epoch - 189ms/step
# Epoch 54/1000
#
# Epoch 54: val_loss did not improve from 65955.63281
# 7/7 - 1s - loss: 1065800.7500 - val_loss: 266563.6250 - 1s/epoch - 158ms/step
# Epoch 55/1000
#
# Epoch 55: val_loss did not improve from 65955.63281
# 7/7 - 1s - loss: 1159887.5000 - val_loss: 257893.0938 - 1s/epoch - 157ms/step
# Epoch 56/1000
#
# Epoch 56: val_loss did not improve from 65955.63281
# 7/7 - 1s - loss: 1051149.0000 - val_loss: 94271.9219 - 1s/epoch - 158ms/step
# Epoch 57/1000
#
# Epoch 57: val_loss did not improve from 65955.63281
# 7/7 - 1s - loss: 1155976.0000 - val_loss: 492806.5625 - 1s/epoch - 159ms/step
# Epoch 58/1000
#
# Epoch 58: val_loss did not improve from 65955.63281
# 7/7 - 1s - loss: 1055546.3750 - val_loss: 158212.7812 - 1s/epoch - 158ms/step
# Epoch 59/1000
#
# Epoch 59: val_loss did not improve from 65955.63281
# 7/7 - 1s - loss: 1133305.2500 - val_loss: 227128.9844 - 1s/epoch - 155ms/step
# Epoch 60/1000
#
# Epoch 60: val_loss did not improve from 65955.63281
# 7/7 - 1s - loss: 1026481.0000 - val_loss: 427859.4688 - 1s/epoch - 162ms/step
# Epoch 61/1000
#
# Epoch 61: val_loss did not improve from 65955.63281
# 7/7 - 2s - loss: 1126258.0000 - val_loss: 403531.4375 - 2s/epoch - 220ms/step
# Epoch 62/1000
#
# Epoch 62: val_loss did not improve from 65955.63281
# 7/7 - 2s - loss: 1061326.0000 - val_loss: 314528.5938 - 2s/epoch - 240ms/step
# Epoch 63/1000
#
# Epoch 63: val_loss did not improve from 65955.63281
# 7/7 - 2s - loss: 1141698.6250 - val_loss: 239697.4062 - 2s/epoch - 237ms/step
# Epoch 64/1000
#
# Epoch 64: val_loss did not improve from 65955.63281
# 7/7 - 2s - loss: 940018.3750 - val_loss: 183436.2031 - 2s/epoch - 236ms/step
# Epoch 65/1000
#
# Epoch 65: val_loss did not improve from 65955.63281
# 7/7 - 1s - loss: 1129054.3750 - val_loss: 409499.2500 - 1s/epoch - 207ms/step
# Epoch 66/1000
#
# Epoch 66: val_loss did not improve from 65955.63281
# 7/7 - 1s - loss: 1005545.8750 - val_loss: 152101.1250 - 1s/epoch - 151ms/step
# Epoch 67/1000
#
# Epoch 67: val_loss did not improve from 65955.63281
# 7/7 - 1s - loss: 1141475.3750 - val_loss: 358824.2812 - 1s/epoch - 156ms/step
# Epoch 68/1000
#
# Epoch 68: val_loss did not improve from 65955.63281
# 7/7 - 1s - loss: 1020904.3125 - val_loss: 200392.6562 - 1s/epoch - 152ms/step
# Epoch 69/1000
#
# Epoch 69: val_loss did not improve from 65955.63281
# 7/7 - 1s - loss: 1040042.3750 - val_loss: 88967.5625 - 1s/epoch - 155ms/step
# Epoch 70/1000
#
# Epoch 70: val_loss did not improve from 65955.63281
# 7/7 - 1s - loss: 1091062.2500 - val_loss: 280450.9062 - 1s/epoch - 161ms/step
# Epoch 71/1000
#
# Epoch 71: val_loss did not improve from 65955.63281
# 7/7 - 1s - loss: 1243213.5000 - val_loss: 129826.3594 - 1s/epoch - 159ms/step
# Epoch 72/1000
#
# Epoch 72: val_loss did not improve from 65955.63281
# 7/7 - 1s - loss: 997564.5625 - val_loss: 281577.5312 - 1s/epoch - 157ms/step
# Epoch 73/1000
#
# Epoch 73: val_loss did not improve from 65955.63281
# 7/7 - 1s - loss: 1040906.8125 - val_loss: 223400.3750 - 1s/epoch - 155ms/step
# Epoch 74/1000
#
# Epoch 74: val_loss did not improve from 65955.63281
# 7/7 - 1s - loss: 1028481.3125 - val_loss: 248441.0938 - 1s/epoch - 169ms/step
# Epoch 75/1000
#
# Epoch 75: val_loss did not improve from 65955.63281
# 7/7 - 2s - loss: 979619.8750 - val_loss: 165849.2031 - 2s/epoch - 233ms/step
# Epoch 76/1000
#
# Epoch 76: val_loss did not improve from 65955.63281
# 7/7 - 2s - loss: 1002915.4375 - val_loss: 326986.0312 - 2s/epoch - 237ms/step
# Epoch 77/1000
#
# Epoch 77: val_loss improved from 65955.63281 to 65543.50000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 2s - loss: 944077.5000 - val_loss: 65543.5000 - 2s/epoch - 283ms/step
# Epoch 78/1000
#
# Epoch 78: val_loss did not improve from 65543.50000
# 7/7 - 2s - loss: 968648.3750 - val_loss: 388066.8125 - 2s/epoch - 237ms/step
# Epoch 79/1000
#
# Epoch 79: val_loss did not improve from 65543.50000
# 7/7 - 1s - loss: 1041798.9375 - val_loss: 195325.0625 - 1s/epoch - 165ms/step
# Epoch 80/1000
#
# Epoch 80: val_loss did not improve from 65543.50000
# 7/7 - 1s - loss: 987293.3125 - val_loss: 166150.7812 - 1s/epoch - 165ms/step
# Epoch 81/1000
#
# Epoch 81: val_loss did not improve from 65543.50000
# 7/7 - 1s - loss: 948772.6875 - val_loss: 296617.6875 - 1s/epoch - 162ms/step
# Epoch 82/1000
#
# Epoch 82: val_loss improved from 65543.50000 to 42598.80078, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 961771.3750 - val_loss: 42598.8008 - 1s/epoch - 189ms/step
# Epoch 83/1000
#
# Epoch 83: val_loss did not improve from 42598.80078
# 7/7 - 1s - loss: 988632.6250 - val_loss: 223079.5781 - 1s/epoch - 160ms/step
# Epoch 84/1000
#
# Epoch 84: val_loss did not improve from 42598.80078
# 7/7 - 1s - loss: 895828.8750 - val_loss: 56378.8398 - 1s/epoch - 156ms/step
# Epoch 85/1000
#
# Epoch 85: val_loss did not improve from 42598.80078
# 7/7 - 1s - loss: 1032476.6875 - val_loss: 146297.4531 - 1s/epoch - 159ms/step
# Epoch 86/1000
#
# Epoch 86: val_loss improved from 42598.80078 to 6368.93701, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 1s - loss: 844428.7500 - val_loss: 6368.9370 - 1s/epoch - 184ms/step
# Epoch 87/1000
#
# Epoch 87: val_loss did not improve from 6368.93701
# 7/7 - 1s - loss: 1005647.9375 - val_loss: 318172.1875 - 1s/epoch - 188ms/step
# Epoch 88/1000
#
# Epoch 88: val_loss did not improve from 6368.93701
# 7/7 - 2s - loss: 991068.2500 - val_loss: 10292.5635 - 2s/epoch - 228ms/step
# Epoch 89/1000
#
# Epoch 89: val_loss did not improve from 6368.93701
# 7/7 - 2s - loss: 1116278.8750 - val_loss: 296273.8438 - 2s/epoch - 232ms/step
# Epoch 90/1000
#
# Epoch 90: val_loss improved from 6368.93701 to 3336.16821, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 2s - loss: 875460.5625 - val_loss: 3336.1682 - 2s/epoch - 274ms/step
# Epoch 91/1000
#
# Epoch 91: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 1164806.6250 - val_loss: 242081.5000 - 2s/epoch - 239ms/step
# Epoch 92/1000
#
# Epoch 92: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 887746.0000 - val_loss: 4523.9722 - 1s/epoch - 159ms/step
# Epoch 93/1000
#
# Epoch 93: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 1018494.9375 - val_loss: 168757.8594 - 1s/epoch - 163ms/step
# Epoch 94/1000
#
# Epoch 94: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 865728.3750 - val_loss: 20905.4922 - 1s/epoch - 161ms/step
# Epoch 95/1000
#
# Epoch 95: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 1037638.5625 - val_loss: 239810.2188 - 1s/epoch - 158ms/step
# Epoch 96/1000
#
# Epoch 96: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 989271.5625 - val_loss: 64476.4766 - 1s/epoch - 164ms/step
# Epoch 97/1000
#
# Epoch 97: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 983224.1250 - val_loss: 140791.5000 - 1s/epoch - 154ms/step
# Epoch 98/1000
#
# Epoch 98: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 1020363.7500 - val_loss: 145313.5469 - 1s/epoch - 162ms/step
# Epoch 99/1000
#
# Epoch 99: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 1000750.0000 - val_loss: 207338.7344 - 1s/epoch - 159ms/step
# Epoch 100/1000
#
# Epoch 100: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 1083448.3750 - val_loss: 56848.5703 - 1s/epoch - 166ms/step
# Epoch 101/1000
#
# Epoch 101: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 1010756.8125 - val_loss: 121249.6797 - 2s/epoch - 230ms/step
# Epoch 102/1000
#
# Epoch 102: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 1058545.6250 - val_loss: 74148.4922 - 2s/epoch - 232ms/step
# Epoch 103/1000
#
# Epoch 103: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 923060.2500 - val_loss: 127820.9766 - 2s/epoch - 260ms/step
# Epoch 104/1000
#
# Epoch 104: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 935859.5625 - val_loss: 116067.4688 - 2s/epoch - 280ms/step
# Epoch 105/1000
#
# Epoch 105: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 897856.6250 - val_loss: 52128.3945 - 2s/epoch - 269ms/step
# Epoch 106/1000
#
# Epoch 106: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 854392.0000 - val_loss: 42765.1250 - 2s/epoch - 286ms/step
# Epoch 107/1000
#
# Epoch 107: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 876546.1875 - val_loss: 117673.5078 - 2s/epoch - 237ms/step
# Epoch 108/1000
#
# Epoch 108: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 907642.0000 - val_loss: 16323.1641 - 2s/epoch - 227ms/step
# Epoch 109/1000
#
# Epoch 109: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 883419.6250 - val_loss: 41685.4102 - 1s/epoch - 157ms/step
# Epoch 110/1000
#
# Epoch 110: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 964662.7500 - val_loss: 157283.6250 - 1s/epoch - 157ms/step
# Epoch 111/1000
#
# Epoch 111: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 964166.5625 - val_loss: 46643.5039 - 1s/epoch - 156ms/step
# Epoch 112/1000
#
# Epoch 112: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 906715.8750 - val_loss: 205859.4062 - 1s/epoch - 158ms/step
# Epoch 113/1000
#
# Epoch 113: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 923731.4375 - val_loss: 56824.6992 - 1s/epoch - 157ms/step
# Epoch 114/1000
#
# Epoch 114: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 862693.9375 - val_loss: 97530.0312 - 1s/epoch - 160ms/step
# Epoch 115/1000
#
# Epoch 115: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 914615.6875 - val_loss: 221576.5938 - 1s/epoch - 203ms/step
# Epoch 116/1000
#
# Epoch 116: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 904001.4375 - val_loss: 35103.5078 - 2s/epoch - 234ms/step
# Epoch 117/1000
#
# Epoch 117: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 1044024.5000 - val_loss: 243339.1250 - 2s/epoch - 243ms/step
# Epoch 118/1000
#
# Epoch 118: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 879187.8125 - val_loss: 43234.2188 - 2s/epoch - 231ms/step
# Epoch 119/1000
#
# Epoch 119: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 896347.6875 - val_loss: 115120.4531 - 1s/epoch - 212ms/step
# Epoch 120/1000
#
# Epoch 120: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 924951.8125 - val_loss: 164139.5625 - 1s/epoch - 153ms/step
# Epoch 121/1000
#
# Epoch 121: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 934663.4375 - val_loss: 41720.8008 - 1s/epoch - 153ms/step
# Epoch 122/1000
#
# Epoch 122: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 763458.6875 - val_loss: 119628.4609 - 1s/epoch - 154ms/step
# Epoch 123/1000
#
# Epoch 123: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 946433.3750 - val_loss: 64639.3203 - 1s/epoch - 154ms/step
# Epoch 124/1000
#
# Epoch 124: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 934359.4375 - val_loss: 142647.7031 - 1s/epoch - 155ms/step
# Epoch 125/1000
#
# Epoch 125: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 864182.0000 - val_loss: 162312.3281 - 1s/epoch - 153ms/step
# Epoch 126/1000
#
# Epoch 126: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 808305.8750 - val_loss: 189052.6875 - 1s/epoch - 151ms/step
# Epoch 127/1000
#
# Epoch 127: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 854816.1875 - val_loss: 157808.6562 - 1s/epoch - 155ms/step
# Epoch 128/1000
#
# Epoch 128: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 836482.0625 - val_loss: 192887.6406 - 1s/epoch - 154ms/step
# Epoch 129/1000
#
# Epoch 129: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 801028.1875 - val_loss: 35033.1719 - 1s/epoch - 214ms/step
# Epoch 130/1000
#
# Epoch 130: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 899395.3750 - val_loss: 280261.0625 - 2s/epoch - 223ms/step
# Epoch 131/1000
#
# Epoch 131: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 897448.4375 - val_loss: 70798.2969 - 2s/epoch - 220ms/step
# Epoch 132/1000
#
# Epoch 132: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 887848.4375 - val_loss: 214160.2031 - 2s/epoch - 219ms/step
# Epoch 133/1000
#
# Epoch 133: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 814945.7500 - val_loss: 45259.1367 - 2s/epoch - 221ms/step
# Epoch 134/1000
#
# Epoch 134: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 898421.3125 - val_loss: 158739.9844 - 1s/epoch - 152ms/step
# Epoch 135/1000
#
# Epoch 135: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 911217.4375 - val_loss: 119380.0625 - 1s/epoch - 154ms/step
# Epoch 136/1000
#
# Epoch 136: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 961536.0625 - val_loss: 123804.1172 - 1s/epoch - 154ms/step
# Epoch 137/1000
#
# Epoch 137: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 929243.5625 - val_loss: 178046.7344 - 1s/epoch - 161ms/step
# Epoch 138/1000
#
# Epoch 138: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 859076.1875 - val_loss: 39658.0508 - 1s/epoch - 155ms/step
# Epoch 139/1000
#
# Epoch 139: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 840394.8125 - val_loss: 202588.6250 - 1s/epoch - 153ms/step
# Epoch 140/1000
#
# Epoch 140: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 872035.3750 - val_loss: 58432.1094 - 1s/epoch - 154ms/step
# Epoch 141/1000
#
# Epoch 141: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 860376.7500 - val_loss: 177402.7031 - 1s/epoch - 151ms/step
# Epoch 142/1000
#
# Epoch 142: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 881401.6875 - val_loss: 77269.2500 - 1s/epoch - 156ms/step
# Epoch 143/1000
#
# Epoch 143: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 821791.4375 - val_loss: 91694.7109 - 2s/epoch - 215ms/step
# Epoch 144/1000
#
# Epoch 144: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 807980.3750 - val_loss: 226683.6875 - 2s/epoch - 227ms/step
# Epoch 145/1000
#
# Epoch 145: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 842171.7500 - val_loss: 159478.2812 - 2s/epoch - 223ms/step
# Epoch 146/1000
#
# Epoch 146: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 810334.8750 - val_loss: 165730.7656 - 2s/epoch - 229ms/step
# Epoch 147/1000
#
# Epoch 147: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 857220.1875 - val_loss: 50565.4609 - 2s/epoch - 224ms/step
# Epoch 148/1000
#
# Epoch 148: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 868372.6875 - val_loss: 141123.2969 - 1s/epoch - 159ms/step
# Epoch 149/1000
#
# Epoch 149: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 805418.0625 - val_loss: 173274.6250 - 1s/epoch - 158ms/step
# Epoch 150/1000
#
# Epoch 150: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 785070.9375 - val_loss: 112809.2109 - 1s/epoch - 159ms/step
# Epoch 151/1000
#
# Epoch 151: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 829992.3125 - val_loss: 153811.6250 - 1s/epoch - 161ms/step
# Epoch 152/1000
#
# Epoch 152: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 795527.1875 - val_loss: 61447.1289 - 1s/epoch - 159ms/step
# Epoch 153/1000
#
# Epoch 153: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 831699.1875 - val_loss: 305001.9688 - 1s/epoch - 157ms/step
# Epoch 154/1000
#
# Epoch 154: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 895603.8750 - val_loss: 13670.2197 - 1s/epoch - 160ms/step
# Epoch 155/1000
#
# Epoch 155: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 855904.1875 - val_loss: 324089.9062 - 1s/epoch - 154ms/step
# Epoch 156/1000
#
# Epoch 156: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 885260.4375 - val_loss: 87840.0469 - 1s/epoch - 170ms/step
# Epoch 157/1000
#
# Epoch 157: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 808536.8125 - val_loss: 170853.2031 - 2s/epoch - 240ms/step
# Epoch 158/1000
#
# Epoch 158: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 766449.0625 - val_loss: 105274.8828 - 2s/epoch - 234ms/step
# Epoch 159/1000
#
# Epoch 159: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 766079.2500 - val_loss: 116643.0312 - 2s/epoch - 234ms/step
# Epoch 160/1000
#
# Epoch 160: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 874654.8750 - val_loss: 113455.3828 - 2s/epoch - 218ms/step
# Epoch 161/1000
#
# Epoch 161: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 751641.7500 - val_loss: 143786.0469 - 1s/epoch - 186ms/step
# Epoch 162/1000
#
# Epoch 162: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 725226.9375 - val_loss: 244849.6406 - 1s/epoch - 152ms/step
# Epoch 163/1000
#
# Epoch 163: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 715027.9375 - val_loss: 9292.6719 - 1s/epoch - 152ms/step
# Epoch 164/1000
#
# Epoch 164: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 849001.0625 - val_loss: 537597.1250 - 1s/epoch - 152ms/step
# Epoch 165/1000
#
# Epoch 165: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 930938.7500 - val_loss: 14697.6035 - 1s/epoch - 153ms/step
# Epoch 166/1000
#
# Epoch 166: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 890136.6250 - val_loss: 129903.6719 - 1s/epoch - 154ms/step
# Epoch 167/1000
#
# Epoch 167: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 812181.7500 - val_loss: 96565.0000 - 1s/epoch - 151ms/step
# Epoch 168/1000
#
# Epoch 168: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 834962.1875 - val_loss: 123775.6016 - 1s/epoch - 152ms/step
# Epoch 169/1000
#
# Epoch 169: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 785085.9375 - val_loss: 166718.3594 - 1s/epoch - 153ms/step
# Epoch 170/1000
#
# Epoch 170: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 751231.2500 - val_loss: 106535.6016 - 1s/epoch - 167ms/step
# Epoch 171/1000
#
# Epoch 171: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 698234.2500 - val_loss: 73139.0234 - 2s/epoch - 225ms/step
# Epoch 172/1000
#
# Epoch 172: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 849231.0625 - val_loss: 50996.0117 - 2s/epoch - 225ms/step
# Epoch 173/1000
#
# Epoch 173: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 879268.1875 - val_loss: 417290.7188 - 2s/epoch - 220ms/step
# Epoch 174/1000
#
# Epoch 174: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 856990.7500 - val_loss: 23472.8203 - 2s/epoch - 238ms/step
# Epoch 175/1000
#
# Epoch 175: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 795955.8125 - val_loss: 184149.3125 - 1s/epoch - 192ms/step
# Epoch 176/1000
#
# Epoch 176: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 773625.7500 - val_loss: 130322.7188 - 1s/epoch - 156ms/step
# Epoch 177/1000
#
# Epoch 177: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 739414.6875 - val_loss: 79682.2344 - 1s/epoch - 156ms/step
# Epoch 178/1000
#
# Epoch 178: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 828447.2500 - val_loss: 304254.4688 - 1s/epoch - 156ms/step
# Epoch 179/1000
#
# Epoch 179: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 667872.3750 - val_loss: 46382.7148 - 1s/epoch - 157ms/step
# Epoch 180/1000
#
# Epoch 180: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 792610.0000 - val_loss: 130865.8516 - 1s/epoch - 153ms/step
# Epoch 181/1000
#
# Epoch 181: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 737001.6875 - val_loss: 215719.1875 - 1s/epoch - 158ms/step
# Epoch 182/1000
#
# Epoch 182: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 768720.9375 - val_loss: 264548.8125 - 1s/epoch - 153ms/step
# Epoch 183/1000
#
# Epoch 183: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 833203.1875 - val_loss: 85503.5391 - 1s/epoch - 155ms/step
# Epoch 184/1000
#
# Epoch 184: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 737736.6250 - val_loss: 249027.4219 - 1s/epoch - 187ms/step
# Epoch 185/1000
#
# Epoch 185: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 760026.5000 - val_loss: 91365.2109 - 2s/epoch - 227ms/step
# Epoch 186/1000
#
# Epoch 186: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 781370.8125 - val_loss: 98626.1094 - 2s/epoch - 228ms/step
# Epoch 187/1000
#
# Epoch 187: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 791137.3125 - val_loss: 145221.2969 - 2s/epoch - 226ms/step
# Epoch 188/1000
#
# Epoch 188: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 842800.0000 - val_loss: 139813.7188 - 2s/epoch - 229ms/step
# Epoch 189/1000
#
# Epoch 189: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 769285.2500 - val_loss: 178950.3438 - 1s/epoch - 179ms/step
# Epoch 190/1000
#
# Epoch 190: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 792238.6250 - val_loss: 97656.0781 - 1s/epoch - 158ms/step
# Epoch 191/1000
#
# Epoch 191: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 757753.1250 - val_loss: 179670.2188 - 1s/epoch - 161ms/step
# Epoch 192/1000
#
# Epoch 192: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 804335.0625 - val_loss: 93243.1797 - 1s/epoch - 156ms/step
# Epoch 193/1000
#
# Epoch 193: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 745747.5625 - val_loss: 164093.8594 - 1s/epoch - 158ms/step
# Epoch 194/1000
#
# Epoch 194: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 719740.6250 - val_loss: 98065.5391 - 1s/epoch - 162ms/step
# Epoch 195/1000
#
# Epoch 195: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 857151.2500 - val_loss: 115879.0391 - 1s/epoch - 157ms/step
# Epoch 196/1000
#
# Epoch 196: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 732348.7500 - val_loss: 237545.9219 - 1s/epoch - 158ms/step
# Epoch 197/1000
#
# Epoch 197: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 841097.2500 - val_loss: 67043.1484 - 1s/epoch - 163ms/step
# Epoch 198/1000
#
# Epoch 198: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 769407.1875 - val_loss: 136145.5625 - 1s/epoch - 211ms/step
# Epoch 199/1000
#
# Epoch 199: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 811061.6250 - val_loss: 198692.7188 - 2s/epoch - 241ms/step
# Epoch 200/1000
#
# Epoch 200: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 962186.6250 - val_loss: 151384.6875 - 2s/epoch - 234ms/step
# Epoch 201/1000
#
# Epoch 201: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 785183.5000 - val_loss: 259646.9844 - 2s/epoch - 228ms/step
# Epoch 202/1000
#
# Epoch 202: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 759761.1250 - val_loss: 48137.8906 - 2s/epoch - 229ms/step
# Epoch 203/1000
#
# Epoch 203: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 862500.3125 - val_loss: 291418.7500 - 1s/epoch - 156ms/step
# Epoch 204/1000
#
# Epoch 204: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 731376.9375 - val_loss: 64155.2969 - 1s/epoch - 159ms/step
# Epoch 205/1000
#
# Epoch 205: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 864077.1250 - val_loss: 113042.6328 - 1s/epoch - 157ms/step
# Epoch 206/1000
#
# Epoch 206: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 809852.8750 - val_loss: 295708.8750 - 1s/epoch - 162ms/step
# Epoch 207/1000
#
# Epoch 207: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 723541.5000 - val_loss: 119484.1797 - 1s/epoch - 166ms/step
# Epoch 208/1000
#
# Epoch 208: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 773455.0625 - val_loss: 167204.9062 - 1s/epoch - 158ms/step
# Epoch 209/1000
#
# Epoch 209: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 713456.9375 - val_loss: 189074.2656 - 1s/epoch - 160ms/step
# Epoch 210/1000
#
# Epoch 210: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 842514.8750 - val_loss: 137801.5312 - 1s/epoch - 160ms/step
# Epoch 211/1000
#
# Epoch 211: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 750232.4375 - val_loss: 216640.2812 - 1s/epoch - 171ms/step
# Epoch 212/1000
#
# Epoch 212: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 750613.5000 - val_loss: 73158.5625 - 2s/epoch - 234ms/step
# Epoch 213/1000
#
# Epoch 213: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 846907.1250 - val_loss: 275624.3125 - 2s/epoch - 232ms/step
# Epoch 214/1000
#
# Epoch 214: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 846157.1875 - val_loss: 69504.2656 - 2s/epoch - 235ms/step
# Epoch 215/1000
#
# Epoch 215: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 790930.8750 - val_loss: 269008.7500 - 2s/epoch - 239ms/step
# Epoch 216/1000
#
# Epoch 216: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 805967.6875 - val_loss: 129261.4531 - 1s/epoch - 184ms/step
# Epoch 217/1000
#
# Epoch 217: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 817286.9375 - val_loss: 52601.0117 - 1s/epoch - 156ms/step
# Epoch 218/1000
#
# Epoch 218: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 653795.7500 - val_loss: 119731.9375 - 1s/epoch - 160ms/step
# Epoch 219/1000
#
# Epoch 219: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 767550.3125 - val_loss: 99481.7578 - 1s/epoch - 156ms/step
# Epoch 220/1000
#
# Epoch 220: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 687301.6250 - val_loss: 105081.3125 - 1s/epoch - 158ms/step
# Epoch 221/1000
#
# Epoch 221: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 778292.3125 - val_loss: 226539.4219 - 1s/epoch - 155ms/step
# Epoch 222/1000
#
# Epoch 222: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 719415.6250 - val_loss: 12390.5195 - 1s/epoch - 159ms/step
# Epoch 223/1000
#
# Epoch 223: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 848224.8750 - val_loss: 122700.8984 - 1s/epoch - 156ms/step
# Epoch 224/1000
#
# Epoch 224: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 778164.8125 - val_loss: 192167.5938 - 1s/epoch - 155ms/step
# Epoch 225/1000
#
# Epoch 225: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 761007.8750 - val_loss: 14479.0654 - 1s/epoch - 211ms/step
# Epoch 226/1000
#
# Epoch 226: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 715984.3125 - val_loss: 311352.2500 - 2s/epoch - 237ms/step
# Epoch 227/1000
#
# Epoch 227: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 754054.7500 - val_loss: 80261.8516 - 2s/epoch - 240ms/step
# Epoch 228/1000
#
# Epoch 228: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 787552.3125 - val_loss: 132832.4844 - 2s/epoch - 234ms/step
# Epoch 229/1000
#
# Epoch 229: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 739576.3125 - val_loss: 129268.6719 - 2s/epoch - 215ms/step
# Epoch 230/1000
#
# Epoch 230: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 734605.0625 - val_loss: 27894.6953 - 1s/epoch - 157ms/step
# Epoch 231/1000
#
# Epoch 231: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 791741.1875 - val_loss: 171869.5000 - 1s/epoch - 155ms/step
# Epoch 232/1000
#
# Epoch 232: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 763914.8750 - val_loss: 6803.3374 - 1s/epoch - 156ms/step
# Epoch 233/1000
#
# Epoch 233: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 814334.5625 - val_loss: 243180.4062 - 1s/epoch - 156ms/step
# Epoch 234/1000
#
# Epoch 234: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 761787.6875 - val_loss: 58247.6992 - 1s/epoch - 160ms/step
# Epoch 235/1000
#
# Epoch 235: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 730929.8750 - val_loss: 120779.6562 - 1s/epoch - 157ms/step
# Epoch 236/1000
#
# Epoch 236: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 701804.1250 - val_loss: 101322.4297 - 1s/epoch - 157ms/step
# Epoch 237/1000
#
# Epoch 237: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 710198.6875 - val_loss: 65528.8984 - 1s/epoch - 157ms/step
# Epoch 238/1000
#
# Epoch 238: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 758784.7500 - val_loss: 80186.8281 - 1s/epoch - 164ms/step
# Epoch 239/1000
#
# Epoch 239: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 887328.3750 - val_loss: 187680.2812 - 2s/epoch - 238ms/step
# Epoch 240/1000
#
# Epoch 240: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 718955.9375 - val_loss: 87542.8906 - 2s/epoch - 228ms/step
# Epoch 241/1000
#
# Epoch 241: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 740116.0625 - val_loss: 47147.3086 - 2s/epoch - 244ms/step
# Epoch 242/1000
#
# Epoch 242: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 810221.0625 - val_loss: 115304.0625 - 2s/epoch - 234ms/step
# Epoch 243/1000
#
# Epoch 243: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 766321.4375 - val_loss: 9125.7812 - 1s/epoch - 191ms/step
# Epoch 244/1000
#
# Epoch 244: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 847469.5625 - val_loss: 191818.8750 - 1s/epoch - 155ms/step
# Epoch 245/1000
#
# Epoch 245: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 839833.5000 - val_loss: 71617.0078 - 1s/epoch - 156ms/step
# Epoch 246/1000
#
# Epoch 246: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 720201.6875 - val_loss: 23900.8516 - 1s/epoch - 157ms/step
# Epoch 247/1000
#
# Epoch 247: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 732923.8750 - val_loss: 134803.7656 - 1s/epoch - 157ms/step
# Epoch 248/1000
#
# Epoch 248: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 698499.3750 - val_loss: 96471.3281 - 1s/epoch - 158ms/step
# Epoch 249/1000
#
# Epoch 249: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 734423.5000 - val_loss: 71591.1484 - 1s/epoch - 155ms/step
# Epoch 250/1000
#
# Epoch 250: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 747497.5625 - val_loss: 87916.6562 - 1s/epoch - 159ms/step
# Epoch 251/1000
#
# Epoch 251: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 748854.2500 - val_loss: 23597.2930 - 1s/epoch - 157ms/step
# Epoch 252/1000
#
# Epoch 252: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 700426.3750 - val_loss: 95366.4219 - 1s/epoch - 196ms/step
# Epoch 253/1000
#
# Epoch 253: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 821208.0625 - val_loss: 26429.8379 - 2s/epoch - 231ms/step
# Epoch 254/1000
#
# Epoch 254: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 751118.1875 - val_loss: 35705.8086 - 2s/epoch - 226ms/step
# Epoch 255/1000
#
# Epoch 255: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 763533.1875 - val_loss: 40608.7734 - 2s/epoch - 220ms/step
# Epoch 256/1000
#
# Epoch 256: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 721086.5000 - val_loss: 239886.3594 - 2s/epoch - 234ms/step
# Epoch 257/1000
#
# Epoch 257: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 821219.4375 - val_loss: 3994.0762 - 1s/epoch - 172ms/step
# Epoch 258/1000
#
# Epoch 258: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 936055.0000 - val_loss: 259525.9531 - 1s/epoch - 158ms/step
# Epoch 259/1000
#
# Epoch 259: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 722771.0000 - val_loss: 20868.7832 - 1s/epoch - 155ms/step
# Epoch 260/1000
#
# Epoch 260: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 763254.2500 - val_loss: 79552.7500 - 1s/epoch - 160ms/step
# Epoch 261/1000
#
# Epoch 261: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 816075.2500 - val_loss: 56705.2734 - 1s/epoch - 156ms/step
# Epoch 262/1000
#
# Epoch 262: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 787591.6875 - val_loss: 182969.5938 - 1s/epoch - 157ms/step
# Epoch 263/1000
#
# Epoch 263: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 872860.2500 - val_loss: 140698.0469 - 1s/epoch - 159ms/step
# Epoch 264/1000
#
# Epoch 264: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 617874.8750 - val_loss: 83372.8438 - 1s/epoch - 155ms/step
# Epoch 265/1000
#
# Epoch 265: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 711158.5000 - val_loss: 139059.3281 - 1s/epoch - 160ms/step
# Epoch 266/1000
#
# Epoch 266: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 705152.6250 - val_loss: 78423.2422 - 2s/epoch - 225ms/step
# Epoch 267/1000
#
# Epoch 267: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 697810.0000 - val_loss: 172564.2031 - 2s/epoch - 241ms/step
# Epoch 268/1000
#
# Epoch 268: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 787529.7500 - val_loss: 82670.4766 - 2s/epoch - 232ms/step
# Epoch 269/1000
#
# Epoch 269: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 786873.0625 - val_loss: 205700.5000 - 2s/epoch - 240ms/step
# Epoch 270/1000
#
# Epoch 270: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 723762.2500 - val_loss: 191198.9844 - 1s/epoch - 204ms/step
# Epoch 271/1000
#
# Epoch 271: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 712444.1875 - val_loss: 100678.6875 - 1s/epoch - 161ms/step
# Epoch 272/1000
#
# Epoch 272: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 754035.1250 - val_loss: 280873.2500 - 1s/epoch - 159ms/step
# Epoch 273/1000
#
# Epoch 273: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 684898.5000 - val_loss: 76993.6172 - 1s/epoch - 164ms/step
# Epoch 274/1000
#
# Epoch 274: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 826252.4375 - val_loss: 159494.7969 - 1s/epoch - 155ms/step
# Epoch 275/1000
#
# Epoch 275: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 772923.1250 - val_loss: 167956.4062 - 1s/epoch - 161ms/step
# Epoch 276/1000
#
# Epoch 276: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 742271.0000 - val_loss: 96993.7109 - 1s/epoch - 162ms/step
# Epoch 277/1000
#
# Epoch 277: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 788170.9375 - val_loss: 254714.3750 - 1s/epoch - 161ms/step
# Epoch 278/1000
#
# Epoch 278: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 720828.2500 - val_loss: 74730.0469 - 1s/epoch - 156ms/step
# Epoch 279/1000
#
# Epoch 279: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 726506.7500 - val_loss: 154508.2969 - 1s/epoch - 203ms/step
# Epoch 280/1000
#
# Epoch 280: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 712157.8125 - val_loss: 52221.2656 - 2s/epoch - 245ms/step
# Epoch 281/1000
#
# Epoch 281: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 821677.1875 - val_loss: 215826.9219 - 2s/epoch - 237ms/step
# Epoch 282/1000
#
# Epoch 282: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 766947.7500 - val_loss: 194219.0000 - 2s/epoch - 241ms/step
# Epoch 283/1000
#
# Epoch 283: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 719721.0625 - val_loss: 87013.2812 - 2s/epoch - 231ms/step
# Epoch 284/1000
#
# Epoch 284: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 810750.6875 - val_loss: 176015.0938 - 1s/epoch - 154ms/step
# Epoch 285/1000
#
# Epoch 285: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 706294.3125 - val_loss: 150777.2969 - 1s/epoch - 153ms/step
# Epoch 286/1000
#
# Epoch 286: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 857021.0625 - val_loss: 75264.6172 - 1s/epoch - 154ms/step
# Epoch 287/1000
#
# Epoch 287: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 682605.5625 - val_loss: 38255.3281 - 1s/epoch - 159ms/step
# Epoch 288/1000
#
# Epoch 288: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 748428.3750 - val_loss: 271924.7500 - 1s/epoch - 153ms/step
# Epoch 289/1000
#
# Epoch 289: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 811237.1875 - val_loss: 165829.9375 - 1s/epoch - 156ms/step
# Epoch 290/1000
#
# Epoch 290: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 782746.1875 - val_loss: 179321.2812 - 1s/epoch - 159ms/step
# Epoch 291/1000
#
# Epoch 291: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 793536.3750 - val_loss: 277825.0625 - 1s/epoch - 154ms/step
# Epoch 292/1000
#
# Epoch 292: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 705102.5625 - val_loss: 281505.0312 - 1s/epoch - 158ms/step
# Epoch 293/1000
#
# Epoch 293: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 718567.4375 - val_loss: 226184.3125 - 2s/epoch - 220ms/step
# Epoch 294/1000
#
# Epoch 294: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 756219.1250 - val_loss: 107078.1016 - 2s/epoch - 231ms/step
# Epoch 295/1000
#
# Epoch 295: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 693459.8750 - val_loss: 138546.0938 - 2s/epoch - 223ms/step
# Epoch 296/1000
#
# Epoch 296: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 701767.5000 - val_loss: 108828.9297 - 2s/epoch - 227ms/step
# Epoch 297/1000
#
# Epoch 297: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 718978.3750 - val_loss: 52952.6016 - 1s/epoch - 209ms/step
# Epoch 298/1000
#
# Epoch 298: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 715885.1250 - val_loss: 250762.4062 - 1s/epoch - 152ms/step
# Epoch 299/1000
#
# Epoch 299: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 654123.4375 - val_loss: 18105.9121 - 1s/epoch - 151ms/step
# Epoch 300/1000
#
# Epoch 300: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 694848.7500 - val_loss: 275893.3438 - 1s/epoch - 154ms/step
# Epoch 301/1000
#
# Epoch 301: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 766616.3750 - val_loss: 183488.2188 - 1s/epoch - 153ms/step
# Epoch 302/1000
#
# Epoch 302: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 904292.7500 - val_loss: 209345.5625 - 1s/epoch - 155ms/step
# Epoch 303/1000
#
# Epoch 303: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 675825.9375 - val_loss: 166428.7344 - 1s/epoch - 153ms/step
# Epoch 304/1000
#
# Epoch 304: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 699291.1875 - val_loss: 108383.4062 - 1s/epoch - 153ms/step
# Epoch 305/1000
#
# Epoch 305: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 813658.3125 - val_loss: 119684.2188 - 1s/epoch - 159ms/step
# Epoch 306/1000
#
# Epoch 306: val_loss did not improve from 3336.16821
# 7/7 - 1s - loss: 849279.5000 - val_loss: 299819.0938 - 1s/epoch - 156ms/step
# Epoch 307/1000
#
# Epoch 307: val_loss did not improve from 3336.16821
# 7/7 - 2s - loss: 734474.0000 - val_loss: 148263.9531 - 2s/epoch - 225ms/step
# Epoch 308/1000
#
# ...
# Epoch 892/1000
#
# Epoch 892: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 636669.7500 - val_loss: 179373.7031 - 2s/epoch - 232ms/step
# Epoch 893/1000
#
# Epoch 893: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 643149.3125 - val_loss: 101219.4297 - 2s/epoch - 236ms/step
# Epoch 894/1000
#
# Epoch 894: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 614752.0000 - val_loss: 154648.2969 - 2s/epoch - 227ms/step
# Epoch 895/1000
#
# Epoch 895: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 645225.3125 - val_loss: 135958.7031 - 2s/epoch - 246ms/step
# Epoch 896/1000
#
# Epoch 896: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 611699.0000 - val_loss: 167716.0781 - 1s/epoch - 207ms/step
# Epoch 897/1000
#
# Epoch 897: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 564999.3125 - val_loss: 211330.5781 - 1s/epoch - 156ms/step
# Epoch 898/1000
#
# Epoch 898: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 654255.2500 - val_loss: 213109.7656 - 1s/epoch - 156ms/step
# Epoch 899/1000
#
# Epoch 899: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 626779.8125 - val_loss: 215820.7188 - 1s/epoch - 159ms/step
# Epoch 900/1000
#
# Epoch 900: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 580554.1875 - val_loss: 95396.3281 - 1s/epoch - 173ms/step
# Epoch 901/1000
#
# Epoch 901: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 653406.6250 - val_loss: 230199.0781 - 1s/epoch - 181ms/step
# Epoch 902/1000
#
# Epoch 902: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 661650.6250 - val_loss: 174719.8594 - 1s/epoch - 166ms/step
# Epoch 903/1000
#
# Epoch 903: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 520353.1562 - val_loss: 107490.0625 - 1s/epoch - 163ms/step
# Epoch 904/1000
#
# Epoch 904: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 629246.7500 - val_loss: 242312.3594 - 1s/epoch - 163ms/step
# Epoch 905/1000
#
# Epoch 905: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 680968.7500 - val_loss: 164454.4375 - 1s/epoch - 206ms/step
# Epoch 906/1000
#
# Epoch 906: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 618058.8750 - val_loss: 200121.7188 - 2s/epoch - 242ms/step
# Epoch 907/1000
#
# Epoch 907: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 619666.3125 - val_loss: 225495.3438 - 2s/epoch - 239ms/step
# Epoch 908/1000
#
# Epoch 908: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 672868.4375 - val_loss: 165572.4688 - 2s/epoch - 242ms/step
# Epoch 909/1000
#
# Epoch 909: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 654258.7500 - val_loss: 200361.3438 - 2s/epoch - 239ms/step
# Epoch 910/1000
#
# Epoch 910: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 571776.8125 - val_loss: 148661.1562 - 2s/epoch - 215ms/step
# Epoch 911/1000
#
# Epoch 911: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 717081.7500 - val_loss: 249844.5781 - 1s/epoch - 171ms/step
# Epoch 912/1000
#
# Epoch 912: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 684038.4375 - val_loss: 226707.3750 - 1s/epoch - 172ms/step
# Epoch 913/1000
#
# Epoch 913: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 703960.1250 - val_loss: 114348.6094 - 1s/epoch - 172ms/step
# Epoch 914/1000
#
# Epoch 914: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 634278.0000 - val_loss: 180148.0781 - 1s/epoch - 166ms/step
# Epoch 915/1000
#
# Epoch 915: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 577561.5000 - val_loss: 247253.4219 - 1s/epoch - 157ms/step
# Epoch 916/1000
#
# Epoch 916: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 682101.5625 - val_loss: 150279.8125 - 1s/epoch - 164ms/step
# Epoch 917/1000
#
# Epoch 917: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 622049.6875 - val_loss: 276286.5000 - 1s/epoch - 162ms/step
# Epoch 918/1000
#
# Epoch 918: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 612426.6875 - val_loss: 80055.1406 - 1s/epoch - 178ms/step
# Epoch 919/1000
#
# Epoch 919: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 627977.8125 - val_loss: 239441.7969 - 2s/epoch - 252ms/step
# Epoch 920/1000
#
# Epoch 920: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 644308.4375 - val_loss: 166802.9062 - 2s/epoch - 240ms/step
# Epoch 921/1000
#
# Epoch 921: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 615300.6250 - val_loss: 244541.8125 - 2s/epoch - 250ms/step
# Epoch 922/1000
#
# Epoch 922: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 626548.8750 - val_loss: 150161.2344 - 2s/epoch - 259ms/step
# Epoch 923/1000
#
# Epoch 923: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 635353.9375 - val_loss: 263811.1875 - 2s/epoch - 227ms/step
# Epoch 924/1000
#
# Epoch 924: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 609983.6875 - val_loss: 169650.5156 - 1s/epoch - 173ms/step
# Epoch 925/1000
#
# Epoch 925: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 576698.0625 - val_loss: 238538.3438 - 1s/epoch - 176ms/step
# Epoch 926/1000
#
# Epoch 926: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 683948.4375 - val_loss: 180737.3594 - 1s/epoch - 165ms/step
# Epoch 927/1000
#
# Epoch 927: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 698772.4375 - val_loss: 147757.4844 - 1s/epoch - 166ms/step
# Epoch 928/1000
#
# Epoch 928: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 662263.6250 - val_loss: 144550.1562 - 1s/epoch - 167ms/step
# Epoch 929/1000
#
# Epoch 929: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 614894.0000 - val_loss: 151515.5625 - 1s/epoch - 172ms/step
# Epoch 930/1000
#
# Epoch 930: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 698571.1250 - val_loss: 195783.0781 - 1s/epoch - 171ms/step
# Epoch 931/1000
#
# Epoch 931: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 580674.6875 - val_loss: 188496.1875 - 1s/epoch - 181ms/step
# Epoch 932/1000
#
# Epoch 932: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 612022.3125 - val_loss: 122647.0391 - 2s/epoch - 252ms/step
# Epoch 933/1000
#
# Epoch 933: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 607450.0625 - val_loss: 213167.5000 - 2s/epoch - 248ms/step
# Epoch 934/1000
#
# Epoch 934: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 602364.3750 - val_loss: 125132.5469 - 2s/epoch - 257ms/step
# Epoch 935/1000
#
# Epoch 935: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 572522.7500 - val_loss: 148573.7969 - 2s/epoch - 248ms/step
# Epoch 936/1000
#
# Epoch 936: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 660673.8750 - val_loss: 224849.4375 - 2s/epoch - 225ms/step
# Epoch 937/1000
#
# Epoch 937: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 668704.5000 - val_loss: 196580.0000 - 1s/epoch - 163ms/step
# Epoch 938/1000
#
# Epoch 938: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 629898.0000 - val_loss: 153750.1094 - 1s/epoch - 162ms/step
# Epoch 939/1000
#
# Epoch 939: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 593328.7500 - val_loss: 226988.2344 - 1s/epoch - 160ms/step
# Epoch 940/1000
#
# Epoch 940: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 702638.6875 - val_loss: 169459.7031 - 1s/epoch - 164ms/step
# Epoch 941/1000
#
# Epoch 941: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 621478.0000 - val_loss: 201583.7188 - 1s/epoch - 161ms/step
# Epoch 942/1000
#
# Epoch 942: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 621414.3125 - val_loss: 213215.5469 - 1s/epoch - 165ms/step
# Epoch 943/1000
#
# Epoch 943: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 625130.4375 - val_loss: 163281.0625 - 1s/epoch - 166ms/step
# Epoch 944/1000
#
# Epoch 944: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 637231.5625 - val_loss: 313317.5312 - 1s/epoch - 161ms/step
# Epoch 945/1000
#
# Epoch 945: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 679559.8125 - val_loss: 187208.9531 - 1s/epoch - 208ms/step
# Epoch 946/1000
#
# Epoch 946: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 661937.8125 - val_loss: 246677.8125 - 2s/epoch - 242ms/step
# Epoch 947/1000
#
# Epoch 947: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 673507.8125 - val_loss: 291281.0000 - 2s/epoch - 231ms/step
# Epoch 948/1000
#
# Epoch 948: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 661380.7500 - val_loss: 216153.7812 - 2s/epoch - 240ms/step
# Epoch 949/1000
#
# Epoch 949: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 670809.9375 - val_loss: 322962.2188 - 2s/epoch - 223ms/step
# Epoch 950/1000
#
# Epoch 950: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 650842.0000 - val_loss: 163058.0469 - 1s/epoch - 189ms/step
# Epoch 951/1000
#
# Epoch 951: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 607066.2500 - val_loss: 326450.3125 - 1s/epoch - 172ms/step
# Epoch 952/1000
#
# Epoch 952: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 607350.6875 - val_loss: 149124.7969 - 1s/epoch - 170ms/step
# Epoch 953/1000
#
# Epoch 953: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 679601.8750 - val_loss: 248227.6406 - 1s/epoch - 167ms/step
# Epoch 954/1000
#
# Epoch 954: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 556311.0625 - val_loss: 181250.1406 - 1s/epoch - 166ms/step
# Epoch 955/1000
#
# Epoch 955: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 656721.9375 - val_loss: 173743.4375 - 1s/epoch - 166ms/step
# Epoch 956/1000
#
# Epoch 956: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 650460.8750 - val_loss: 198580.2656 - 1s/epoch - 170ms/step
# Epoch 957/1000
#
# Epoch 957: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 594018.2500 - val_loss: 230406.5469 - 1s/epoch - 169ms/step
# Epoch 958/1000
#
# Epoch 958: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 571193.9375 - val_loss: 208611.8438 - 1s/epoch - 206ms/step
# Epoch 959/1000
#
# Epoch 959: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 621845.0625 - val_loss: 253971.7969 - 2s/epoch - 249ms/step
# Epoch 960/1000
#
# Epoch 960: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 688072.7500 - val_loss: 218888.3125 - 2s/epoch - 266ms/step
# Epoch 961/1000
#
# Epoch 961: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 641209.8750 - val_loss: 202815.1250 - 2s/epoch - 266ms/step
# Epoch 962/1000
#
# Epoch 962: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 582192.0625 - val_loss: 195497.0000 - 2s/epoch - 291ms/step
# Epoch 963/1000
#
# Epoch 963: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 593487.8125 - val_loss: 250685.9844 - 2s/epoch - 300ms/step
# Epoch 964/1000
#
# Epoch 964: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 652914.4375 - val_loss: 120377.3438 - 2s/epoch - 283ms/step
# Epoch 965/1000
#
# Epoch 965: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 683404.5625 - val_loss: 205617.0938 - 2s/epoch - 250ms/step
# Epoch 966/1000
#
# Epoch 966: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 619089.8750 - val_loss: 233032.3750 - 2s/epoch - 237ms/step
# Epoch 967/1000
#
# Epoch 967: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 593923.9375 - val_loss: 108477.8281 - 1s/epoch - 161ms/step
# Epoch 968/1000
#
# Epoch 968: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 613375.8750 - val_loss: 298678.8125 - 1s/epoch - 162ms/step
# Epoch 969/1000
#
# Epoch 969: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 601884.1875 - val_loss: 54686.6133 - 1s/epoch - 168ms/step
# Epoch 970/1000
#
# Epoch 970: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 669617.8125 - val_loss: 300779.9062 - 1s/epoch - 163ms/step
# Epoch 971/1000
#
# Epoch 971: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 613284.7500 - val_loss: 81416.0547 - 1s/epoch - 161ms/step
# Epoch 972/1000
#
# Epoch 972: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 530355.6875 - val_loss: 245459.1250 - 1s/epoch - 161ms/step
# Epoch 973/1000
#
# Epoch 973: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 632311.8750 - val_loss: 178085.8594 - 2s/epoch - 223ms/step
# Epoch 974/1000
#
# Epoch 974: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 650005.3125 - val_loss: 186676.2969 - 2s/epoch - 235ms/step
# Epoch 975/1000
#
# Epoch 975: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 618029.9375 - val_loss: 226912.7031 - 2s/epoch - 246ms/step
# Epoch 976/1000
#
# Epoch 976: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 707037.8125 - val_loss: 179344.7656 - 2s/epoch - 239ms/step
# Epoch 977/1000
#
# Epoch 977: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 638371.5625 - val_loss: 262139.4219 - 1s/epoch - 208ms/step
# Epoch 978/1000
#
# Epoch 978: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 599102.1875 - val_loss: 227762.1250 - 1s/epoch - 163ms/step
# Epoch 979/1000
#
# Epoch 979: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 650529.1250 - val_loss: 202306.4062 - 1s/epoch - 159ms/step
# Epoch 980/1000
#
# Epoch 980: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 732235.2500 - val_loss: 239735.6562 - 1s/epoch - 157ms/step
# Epoch 981/1000
#
# Epoch 981: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 623422.9375 - val_loss: 221557.5781 - 1s/epoch - 170ms/step
# Epoch 982/1000
#
# Epoch 982: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 645948.8125 - val_loss: 152198.4531 - 1s/epoch - 187ms/step
# Epoch 983/1000
#
# Epoch 983: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 702373.2500 - val_loss: 259741.0156 - 1s/epoch - 179ms/step
# Epoch 984/1000
#
# Epoch 984: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 613289.3125 - val_loss: 195676.9375 - 1s/epoch - 169ms/step
# Epoch 985/1000
#
# Epoch 985: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 651191.8750 - val_loss: 228989.9062 - 1s/epoch - 171ms/step
# Epoch 986/1000
#
# Epoch 986: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 579094.1875 - val_loss: 251903.5156 - 2s/epoch - 236ms/step
# Epoch 987/1000
#
# Epoch 987: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 636353.9375 - val_loss: 188094.0156 - 2s/epoch - 229ms/step
# Epoch 988/1000
#
# Epoch 988: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 601796.0625 - val_loss: 154729.8438 - 2s/epoch - 235ms/step
# Epoch 989/1000
#
# Epoch 989: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 696783.8750 - val_loss: 291803.9375 - 2s/epoch - 241ms/step
# Epoch 990/1000
#
# Epoch 990: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 722921.3750 - val_loss: 129949.8438 - 2s/epoch - 217ms/step
# Epoch 991/1000
#
# Epoch 991: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 606766.0625 - val_loss: 272726.6250 - 1s/epoch - 167ms/step
# Epoch 992/1000
#
# Epoch 992: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 578016.1250 - val_loss: 260890.2344 - 1s/epoch - 167ms/step
# Epoch 993/1000
#
# Epoch 993: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 599826.3750 - val_loss: 233017.5156 - 1s/epoch - 160ms/step
# Epoch 994/1000
#
# Epoch 994: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 627013.6875 - val_loss: 264239.6562 - 1s/epoch - 162ms/step
# Epoch 995/1000
#
# Epoch 995: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 617259.8125 - val_loss: 130359.0234 - 1s/epoch - 160ms/step
# Epoch 996/1000
#
# Epoch 996: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 603918.4375 - val_loss: 181746.8750 - 1s/epoch - 164ms/step
# Epoch 997/1000
#
# Epoch 997: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 604408.9375 - val_loss: 159220.0156 - 1s/epoch - 175ms/step
# Epoch 998/1000
#
# Epoch 998: val_loss did not improve from 2440.53149
# 7/7 - 1s - loss: 612115.4375 - val_loss: 231191.4219 - 1s/epoch - 163ms/step
# Epoch 999/1000
#
# Epoch 999: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 658577.3125 - val_loss: 267850.1562 - 2s/epoch - 225ms/step
# Epoch 1000/1000
#
# Epoch 1000: val_loss did not improve from 2440.53149
# 7/7 - 2s - loss: 570418.6250 - val_loss: 147674.6406 - 2s/epoch - 247ms/step
# 16/16 [==============================] - 2s 32ms/step
# 3/3 [==============================] - 0s 28ms/step
# Training MSE: 21478.622875360128
# Testing MSE: 3236.2216918451995
# accuracy : 53

# %%
# 모델 생성
model = Sequential()
model.add(Conv1D(filters=256, kernel_size=3, activation='relu', input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(units=1024, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(units=512, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(units=256, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(units=128, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(units=64, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(units=32, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(units=16, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(units=1))
model.summary()

# loss = Huber()
# optimizer = Adam(0.0005)
# model.compile(loss=Huber(), optimizer=optimizer, metrics=['mse'])

model.compile(optimizer='adam', loss='mean_squared_error')

filename = os.path.join('tmp', 'ckeckpointer.ckpt')
checkpoint = ModelCheckpoint(filename,
                             save_weights_only=True,
                             save_best_only=True,
                             monitor='val_loss',
                             verbose=1)

# 모델 학습
history = model.fit(trainX, trainY, epochs=1000, batch_size=64,
          validation_split=0.1, verbose=2,callbacks=[checkpoint])

model.save_weights('./lstm_weights.h3')

model.load_weights(filename)

plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()
plt.show()

# 예측
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# MSE 계산
trainMSE = mean_squared_error(trainY, trainPredict)
testMSE = mean_squared_error(testY, testPredict)

print(f'Training MSE: {trainMSE}')
print(f'Testing MSE: {testMSE}')

accuracy(testPredict,testY)

# 예측 시각화
plt.plot(trainY, label='Actual Price')
plt.plot(trainPredict, label='Predicted Price')
plt.legend()
plt.title('Training Data')
plt.show()

plt.plot(testY, label='Actual Price')
plt.plot(testPredict, label='Predicted Price')
plt.legend()
plt.title('Testing Data')
plt.show()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 3, 256)            7936
#
#  max_pooling1d_3 (MaxPoolin  (None, 1, 256)            0
#  g1D)
#
#  lstm_7 (LSTM)               (None, 1, 1024)           5246976
#
#  dropout_33 (Dropout)        (None, 1, 1024)           0
#
#  lstm_8 (LSTM)               (None, 1, 512)            3147776
#
#  dropout_34 (Dropout)        (None, 1, 512)            0
#
#  lstm_9 (LSTM)               (None, 1, 256)            787456
#
#  dropout_35 (Dropout)        (None, 1, 256)            0
#
#  lstm_10 (LSTM)              (None, 1, 128)            197120
#
#  dropout_36 (Dropout)        (None, 1, 128)            0
#
#  lstm_11 (LSTM)              (None, 1, 64)             49408
#
#  dropout_37 (Dropout)        (None, 1, 64)             0
#
#  lstm_12 (LSTM)              (None, 1, 32)             12416
#
#  dropout_38 (Dropout)        (None, 1, 32)             0
#
#  lstm_13 (LSTM)              (None, 16)                3136
#
#  dropout_39 (Dropout)        (None, 16)                0
#
#  dense_5 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 9452241 (36.06 MB)
# Trainable params: 9452241 (36.06 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/1000
#
# Epoch 1: val_loss improved from inf to 5710925.50000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 15s - loss: 8167959.5000 - val_loss: 5710925.5000 - 15s/epoch - 2s/step
# Epoch 2/1000
#
# Epoch 2: val_loss improved from 5710925.50000 to 5710848.50000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 2s - loss: 8167885.5000 - val_loss: 5710848.5000 - 2s/epoch - 256ms/step
# Epoch 3/1000
#
# Epoch 3: val_loss improved from 5710848.50000 to 5687499.00000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 4s - loss: 8165974.5000 - val_loss: 5687499.0000 - 4s/epoch - 541ms/step
# Epoch 4/1000
#
# Epoch 4: val_loss improved from 5687499.00000 to 5041527.50000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 2s - loss: 8020067.0000 - val_loss: 5041527.5000 - 2s/epoch - 246ms/step
# Epoch 5/1000
#
# Epoch 5: val_loss improved from 5041527.50000 to 2680002.00000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 2s - loss: 7006464.0000 - val_loss: 2680002.0000 - 2s/epoch - 254ms/step
# Epoch 6/1000
#
# Epoch 6: val_loss improved from 2680002.00000 to 1725690.25000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 2s - loss: 4246331.0000 - val_loss: 1725690.2500 - 2s/epoch - 347ms/step
# Epoch 7/1000
#
# Epoch 7: val_loss improved from 1725690.25000 to 963458.75000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 3s - loss: 3313042.2500 - val_loss: 963458.7500 - 3s/epoch - 370ms/step
# Epoch 8/1000
#
# Epoch 8: val_loss improved from 963458.75000 to 13866.39453, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 3s - loss: 3041574.2500 - val_loss: 13866.3945 - 3s/epoch - 369ms/step
# Epoch 9/1000
#
# Epoch 9: val_loss did not improve from 13866.39453
# 7/7 - 1s - loss: 2874917.5000 - val_loss: 30483.3496 - 1s/epoch - 213ms/step
# Epoch 10/1000
#
# Epoch 10: val_loss did not improve from 13866.39453
# 7/7 - 1s - loss: 2753359.5000 - val_loss: 199502.7031 - 1s/epoch - 213ms/step
# Epoch 11/1000
#
# Epoch 11: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 2573951.5000 - val_loss: 60436.3359 - 2s/epoch - 218ms/step
# Epoch 12/1000
#
# Epoch 12: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 2391789.7500 - val_loss: 81143.9766 - 2s/epoch - 219ms/step
# Epoch 13/1000
#
# Epoch 13: val_loss did not improve from 13866.39453
# 7/7 - 1s - loss: 2318182.0000 - val_loss: 36702.6875 - 1s/epoch - 214ms/step
# Epoch 14/1000
#
# Epoch 14: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 2415935.5000 - val_loss: 103755.3594 - 2s/epoch - 229ms/step
# Epoch 15/1000
#
# Epoch 15: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 2348485.2500 - val_loss: 556054.8125 - 2s/epoch - 269ms/step
# Epoch 16/1000
#
# Epoch 16: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 2298829.0000 - val_loss: 211171.0938 - 2s/epoch - 298ms/step
# Epoch 17/1000
#
# Epoch 17: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 2111529.7500 - val_loss: 180698.0781 - 2s/epoch - 298ms/step
# Epoch 18/1000
#
# Epoch 18: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1970818.5000 - val_loss: 496637.9688 - 2s/epoch - 302ms/step
# Epoch 19/1000
#
# Epoch 19: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 2004815.0000 - val_loss: 405702.0938 - 2s/epoch - 223ms/step
# Epoch 20/1000
#
# Epoch 20: val_loss did not improve from 13866.39453
# 7/7 - 1s - loss: 2012218.5000 - val_loss: 831974.2500 - 1s/epoch - 212ms/step
# Epoch 21/1000
#
# Epoch 21: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1810213.8750 - val_loss: 689937.2500 - 2s/epoch - 216ms/step
# Epoch 22/1000
#
# Epoch 22: val_loss did not improve from 13866.39453
# 7/7 - 1s - loss: 1983899.8750 - val_loss: 460444.5938 - 1s/epoch - 214ms/step
# Epoch 23/1000
#
# Epoch 23: val_loss did not improve from 13866.39453
# 7/7 - 1s - loss: 1786194.8750 - val_loss: 725019.7500 - 1s/epoch - 214ms/step
# Epoch 24/1000
#
# Epoch 24: val_loss did not improve from 13866.39453
# 7/7 - 1s - loss: 1880031.8750 - val_loss: 544056.9375 - 1s/epoch - 211ms/step
# Epoch 25/1000
#
# Epoch 25: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1913572.8750 - val_loss: 1000483.7500 - 2s/epoch - 228ms/step
# Epoch 26/1000
#
# Epoch 26: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1809376.0000 - val_loss: 693298.2500 - 2s/epoch - 301ms/step
# Epoch 27/1000
#
# Epoch 27: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1855681.2500 - val_loss: 522632.8750 - 2s/epoch - 305ms/step
# Epoch 28/1000
#
# Epoch 28: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1764389.5000 - val_loss: 784194.9375 - 2s/epoch - 301ms/step
# Epoch 29/1000
#
# Epoch 29: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1557307.1250 - val_loss: 577075.8125 - 2s/epoch - 238ms/step
# Epoch 30/1000
#
# Epoch 30: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1698756.1250 - val_loss: 405109.1562 - 2s/epoch - 215ms/step
# Epoch 31/1000
#
# Epoch 31: val_loss did not improve from 13866.39453
# 7/7 - 1s - loss: 1737995.5000 - val_loss: 203068.6406 - 1s/epoch - 213ms/step
# Epoch 32/1000
#
# Epoch 32: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1948357.2500 - val_loss: 232437.4062 - 2s/epoch - 215ms/step
# Epoch 33/1000
#
# Epoch 33: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1721697.6250 - val_loss: 151140.0156 - 2s/epoch - 216ms/step
# Epoch 34/1000
#
# Epoch 34: val_loss did not improve from 13866.39453
# 7/7 - 1s - loss: 2077384.5000 - val_loss: 216341.3125 - 1s/epoch - 212ms/step
# Epoch 35/1000
#
# Epoch 35: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1791691.2500 - val_loss: 419792.8750 - 2s/epoch - 220ms/step
# Epoch 36/1000
#
# Epoch 36: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1585698.5000 - val_loss: 326347.0625 - 2s/epoch - 306ms/step
# Epoch 37/1000
#
# Epoch 37: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1698799.8750 - val_loss: 102348.5703 - 2s/epoch - 307ms/step
# Epoch 38/1000
#
# Epoch 38: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1643245.8750 - val_loss: 253920.2969 - 2s/epoch - 306ms/step
# Epoch 39/1000
#
# Epoch 39: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1656624.0000 - val_loss: 344260.7188 - 2s/epoch - 250ms/step
# Epoch 40/1000
#
# Epoch 40: val_loss did not improve from 13866.39453
# 7/7 - 1s - loss: 1553147.5000 - val_loss: 273185.5312 - 1s/epoch - 214ms/step
# Epoch 41/1000
#
# Epoch 41: val_loss did not improve from 13866.39453
# 7/7 - 1s - loss: 1478855.6250 - val_loss: 123694.4922 - 1s/epoch - 213ms/step
# Epoch 42/1000
#
# Epoch 42: val_loss did not improve from 13866.39453
# 7/7 - 1s - loss: 1636561.7500 - val_loss: 114474.4531 - 1s/epoch - 213ms/step
# Epoch 43/1000
#
# Epoch 43: val_loss did not improve from 13866.39453
# 7/7 - 1s - loss: 1409855.8750 - val_loss: 185721.4531 - 1s/epoch - 211ms/step
# Epoch 44/1000
#
# Epoch 44: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1605321.2500 - val_loss: 153200.2344 - 2s/epoch - 215ms/step
# Epoch 45/1000
#
# Epoch 45: val_loss did not improve from 13866.39453
# 7/7 - 1s - loss: 1411098.7500 - val_loss: 270972.6250 - 1s/epoch - 212ms/step
# Epoch 46/1000
#
# Epoch 46: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1348208.1250 - val_loss: 141295.7969 - 2s/epoch - 294ms/step
# Epoch 47/1000
#
# Epoch 47: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1376503.3750 - val_loss: 191200.4844 - 2s/epoch - 311ms/step
# Epoch 48/1000
#
# Epoch 48: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1377083.6250 - val_loss: 416527.3750 - 2s/epoch - 321ms/step
# Epoch 49/1000
#
# Epoch 49: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1377652.0000 - val_loss: 183265.4062 - 2s/epoch - 286ms/step
# Epoch 50/1000
#
# Epoch 50: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1314826.3750 - val_loss: 308988.2500 - 2s/epoch - 222ms/step
# Epoch 51/1000
#
# Epoch 51: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1378483.7500 - val_loss: 440183.8125 - 2s/epoch - 218ms/step
# Epoch 52/1000
#
# Epoch 52: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1438985.3750 - val_loss: 221803.6562 - 2s/epoch - 224ms/step
# Epoch 53/1000
#
# Epoch 53: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1369835.0000 - val_loss: 435989.5312 - 2s/epoch - 227ms/step
# Epoch 54/1000
#
# Epoch 54: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1264149.8750 - val_loss: 289063.7188 - 2s/epoch - 222ms/step
# Epoch 55/1000
#
# Epoch 55: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1251106.5000 - val_loss: 221999.3750 - 2s/epoch - 221ms/step
# Epoch 56/1000
#
# Epoch 56: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1331094.3750 - val_loss: 718559.1875 - 2s/epoch - 312ms/step
# Epoch 57/1000
#
# Epoch 57: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1447837.1250 - val_loss: 664236.8750 - 2s/epoch - 313ms/step
# Epoch 58/1000
#
# Epoch 58: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1325254.6250 - val_loss: 408745.9062 - 2s/epoch - 314ms/step
# Epoch 59/1000
#
# Epoch 59: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1283010.1250 - val_loss: 561921.8750 - 2s/epoch - 261ms/step
# Epoch 60/1000
#
# Epoch 60: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1161768.2500 - val_loss: 676858.8125 - 2s/epoch - 216ms/step
# Epoch 61/1000
#
# Epoch 61: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1275290.5000 - val_loss: 885283.2500 - 2s/epoch - 219ms/step
# Epoch 62/1000
#
# Epoch 62: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1264902.6250 - val_loss: 855656.8125 - 2s/epoch - 218ms/step
# Epoch 63/1000
#
# Epoch 63: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1234527.0000 - val_loss: 644901.3750 - 2s/epoch - 219ms/step
# Epoch 64/1000
#
# Epoch 64: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1333867.2500 - val_loss: 739548.9375 - 2s/epoch - 219ms/step
# Epoch 65/1000
#
# Epoch 65: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1352533.8750 - val_loss: 337106.7188 - 2s/epoch - 217ms/step
# Epoch 66/1000
#
# Epoch 66: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1069705.2500 - val_loss: 201461.9375 - 2s/epoch - 320ms/step
# Epoch 67/1000
#
# Epoch 67: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1290793.6250 - val_loss: 390979.1875 - 2s/epoch - 322ms/step
# Epoch 68/1000
#
# Epoch 68: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1188691.3750 - val_loss: 235774.5625 - 2s/epoch - 325ms/step
# Epoch 69/1000
#
# Epoch 69: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1174285.3750 - val_loss: 163614.0625 - 2s/epoch - 262ms/step
# Epoch 70/1000
#
# Epoch 70: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1192553.2500 - val_loss: 373755.7500 - 2s/epoch - 224ms/step
# Epoch 71/1000
#
# Epoch 71: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1080813.5000 - val_loss: 183719.9531 - 2s/epoch - 215ms/step
# Epoch 72/1000
#
# Epoch 72: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1183494.6250 - val_loss: 522256.9688 - 2s/epoch - 218ms/step
# Epoch 73/1000
#
# Epoch 73: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1254187.2500 - val_loss: 704230.0625 - 2s/epoch - 216ms/step
# Epoch 74/1000
#
# Epoch 74: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1169773.1250 - val_loss: 131935.8438 - 2s/epoch - 219ms/step
# Epoch 75/1000
#
# Epoch 75: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1223819.2500 - val_loss: 43575.1250 - 2s/epoch - 221ms/step
# Epoch 76/1000
#
# Epoch 76: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1141486.1250 - val_loss: 175624.0000 - 2s/epoch - 322ms/step
# Epoch 77/1000
#
# Epoch 77: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1260698.3750 - val_loss: 142763.3750 - 2s/epoch - 310ms/step
# Epoch 78/1000
#
# Epoch 78: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1160133.3750 - val_loss: 159779.5312 - 2s/epoch - 314ms/step
# Epoch 79/1000
#
# Epoch 79: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1046063.6250 - val_loss: 35867.8398 - 2s/epoch - 250ms/step
# Epoch 80/1000
#
# Epoch 80: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1056513.2500 - val_loss: 25354.2617 - 2s/epoch - 218ms/step
# Epoch 81/1000
#
# Epoch 81: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1048271.2500 - val_loss: 521953.0000 - 2s/epoch - 217ms/step
# Epoch 82/1000
#
# Epoch 82: val_loss did not improve from 13866.39453
# 7/7 - 1s - loss: 1203155.3750 - val_loss: 396877.2812 - 1s/epoch - 214ms/step
# Epoch 83/1000
#
# Epoch 83: val_loss did not improve from 13866.39453
# 7/7 - 1s - loss: 1197030.3750 - val_loss: 128995.8984 - 1s/epoch - 212ms/step
# Epoch 84/1000
#
# Epoch 84: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1306284.5000 - val_loss: 255054.5156 - 2s/epoch - 215ms/step
# Epoch 85/1000
#
# Epoch 85: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1134949.6250 - val_loss: 118461.3281 - 2s/epoch - 221ms/step
# Epoch 86/1000
#
# Epoch 86: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1125477.3750 - val_loss: 179192.2188 - 2s/epoch - 317ms/step
# Epoch 87/1000
#
# Epoch 87: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1215089.1250 - val_loss: 214387.3750 - 2s/epoch - 323ms/step
# Epoch 88/1000
#
# Epoch 88: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1108884.0000 - val_loss: 259810.0781 - 2s/epoch - 323ms/step
# Epoch 89/1000
#
# Epoch 89: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 995238.9375 - val_loss: 46049.8242 - 2s/epoch - 240ms/step
# Epoch 90/1000
#
# Epoch 90: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 989638.0625 - val_loss: 320629.1562 - 2s/epoch - 216ms/step
# Epoch 91/1000
#
# Epoch 91: val_loss did not improve from 13866.39453
# 7/7 - 1s - loss: 1143470.3750 - val_loss: 437779.9688 - 1s/epoch - 214ms/step
# Epoch 92/1000
#
# Epoch 92: val_loss did not improve from 13866.39453
# 7/7 - 1s - loss: 1102513.3750 - val_loss: 358881.7188 - 1s/epoch - 206ms/step
# Epoch 93/1000
#
# Epoch 93: val_loss did not improve from 13866.39453
# 7/7 - 1s - loss: 919128.5000 - val_loss: 284053.3125 - 1s/epoch - 209ms/step
# Epoch 94/1000
#
# Epoch 94: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1080738.5000 - val_loss: 368454.5938 - 2s/epoch - 215ms/step
# Epoch 95/1000
#
# Epoch 95: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1084776.8750 - val_loss: 329731.3750 - 2s/epoch - 221ms/step
# Epoch 96/1000
#
# Epoch 96: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1068861.5000 - val_loss: 297340.0312 - 2s/epoch - 314ms/step
# Epoch 97/1000
#
# Epoch 97: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1136956.3750 - val_loss: 70891.3750 - 2s/epoch - 326ms/step
# Epoch 98/1000
#
# Epoch 98: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1198922.7500 - val_loss: 470652.2500 - 2s/epoch - 315ms/step
# Epoch 99/1000
#
# Epoch 99: val_loss did not improve from 13866.39453
# 7/7 - 2s - loss: 1006321.3125 - val_loss: 26896.4648 - 2s/epoch - 239ms/step
# Epoch 100/1000
#
# Epoch 100: val_loss improved from 13866.39453 to 3620.86060, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 2s - loss: 995904.1875 - val_loss: 3620.8606 - 2s/epoch - 244ms/step
# Epoch 101/1000
#
# Epoch 101: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1015662.5000 - val_loss: 23967.4395 - 2s/epoch - 216ms/step
# Epoch 102/1000
#
# Epoch 102: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1061378.1250 - val_loss: 78358.2266 - 2s/epoch - 217ms/step
# Epoch 103/1000
#
# Epoch 103: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1209027.8750 - val_loss: 18306.6699 - 2s/epoch - 217ms/step
# Epoch 104/1000
#
# Epoch 104: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 967277.1250 - val_loss: 55718.6016 - 2s/epoch - 218ms/step
# Epoch 105/1000
#
# Epoch 105: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1016195.1875 - val_loss: 86666.9922 - 2s/epoch - 222ms/step
# Epoch 106/1000
#
# Epoch 106: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1040315.8750 - val_loss: 19567.9219 - 2s/epoch - 299ms/step
# Epoch 107/1000
#
# Epoch 107: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1085534.3750 - val_loss: 100710.5469 - 2s/epoch - 326ms/step
# Epoch 108/1000
#
# Epoch 108: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1011211.9375 - val_loss: 95126.8281 - 2s/epoch - 310ms/step
# Epoch 109/1000
#
# Epoch 109: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1110377.3750 - val_loss: 97707.5000 - 2s/epoch - 242ms/step
# Epoch 110/1000
#
# Epoch 110: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 1050486.0000 - val_loss: 86603.8281 - 1s/epoch - 213ms/step
# Epoch 111/1000
#
# Epoch 111: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 996621.1250 - val_loss: 148272.8438 - 1s/epoch - 211ms/step
# Epoch 112/1000
#
# Epoch 112: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 1114411.0000 - val_loss: 23503.5918 - 1s/epoch - 213ms/step
# Epoch 113/1000
#
# Epoch 113: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1020866.0000 - val_loss: 162963.2969 - 2s/epoch - 216ms/step
# Epoch 114/1000
#
# Epoch 114: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1094864.5000 - val_loss: 15331.9971 - 2s/epoch - 253ms/step
# Epoch 115/1000
#
# Epoch 115: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1058926.7500 - val_loss: 133259.2188 - 2s/epoch - 338ms/step
# Epoch 116/1000
#
# Epoch 116: val_loss did not improve from 3620.86060
# 7/7 - 3s - loss: 1038197.3125 - val_loss: 180414.9531 - 3s/epoch - 374ms/step
# Epoch 117/1000
#
# Epoch 117: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 979830.0625 - val_loss: 146128.3906 - 2s/epoch - 349ms/step
# Epoch 118/1000
#
# Epoch 118: val_loss did not improve from 3620.86060
# 7/7 - 3s - loss: 1049899.1250 - val_loss: 143044.9688 - 3s/epoch - 378ms/step
# Epoch 119/1000
#
# Epoch 119: val_loss did not improve from 3620.86060
# 7/7 - 3s - loss: 1033905.1250 - val_loss: 128302.1172 - 3s/epoch - 359ms/step
# Epoch 120/1000
#
# Epoch 120: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 974100.6250 - val_loss: 182877.7812 - 2s/epoch - 264ms/step
# Epoch 121/1000
#
# Epoch 121: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1024596.4375 - val_loss: 201956.8438 - 2s/epoch - 217ms/step
# Epoch 122/1000
#
# Epoch 122: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 998700.3125 - val_loss: 104561.4766 - 2s/epoch - 219ms/step
# Epoch 123/1000
#
# Epoch 123: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1050098.0000 - val_loss: 70382.9922 - 2s/epoch - 217ms/step
# Epoch 124/1000
#
# Epoch 124: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1050769.7500 - val_loss: 312371.2188 - 2s/epoch - 220ms/step
# Epoch 125/1000
#
# Epoch 125: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1057183.3750 - val_loss: 100888.1016 - 2s/epoch - 214ms/step
# Epoch 126/1000
#
# Epoch 126: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1087315.5000 - val_loss: 349381.6875 - 2s/epoch - 217ms/step
# Epoch 127/1000
#
# Epoch 127: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1105806.8750 - val_loss: 268320.3750 - 2s/epoch - 303ms/step
# Epoch 128/1000
#
# Epoch 128: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 912850.3750 - val_loss: 44741.3398 - 2s/epoch - 301ms/step
# Epoch 129/1000
#
# Epoch 129: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1105619.5000 - val_loss: 476117.5312 - 2s/epoch - 309ms/step
# Epoch 130/1000
#
# Epoch 130: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 994611.8125 - val_loss: 220439.1562 - 2s/epoch - 273ms/step
# Epoch 131/1000
#
# Epoch 131: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 997433.2500 - val_loss: 414292.5312 - 1s/epoch - 214ms/step
# Epoch 132/1000
#
# Epoch 132: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1046758.8750 - val_loss: 300928.4688 - 2s/epoch - 220ms/step
# Epoch 133/1000
#
# Epoch 133: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1091998.3750 - val_loss: 289589.6875 - 2s/epoch - 216ms/step
# Epoch 134/1000
#
# Epoch 134: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 966599.9375 - val_loss: 409767.5938 - 1s/epoch - 210ms/step
# Epoch 135/1000
#
# Epoch 135: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 939740.6250 - val_loss: 359083.4062 - 2s/epoch - 221ms/step
# Epoch 136/1000
#
# Epoch 136: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 951116.5625 - val_loss: 297970.3125 - 1s/epoch - 214ms/step
# Epoch 137/1000
#
# Epoch 137: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1116628.8750 - val_loss: 510223.0000 - 2s/epoch - 297ms/step
# Epoch 138/1000
#
# Epoch 138: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1099545.0000 - val_loss: 447206.1875 - 2s/epoch - 305ms/step
# Epoch 139/1000
#
# Epoch 139: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 965135.0625 - val_loss: 516729.9688 - 2s/epoch - 318ms/step
# Epoch 140/1000
#
# Epoch 140: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1059173.2500 - val_loss: 377316.4375 - 2s/epoch - 285ms/step
# Epoch 141/1000
#
# Epoch 141: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 970670.0000 - val_loss: 416095.0312 - 2s/epoch - 226ms/step
# Epoch 142/1000
#
# Epoch 142: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1050508.3750 - val_loss: 536735.5000 - 2s/epoch - 223ms/step
# Epoch 143/1000
#
# Epoch 143: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1065423.0000 - val_loss: 512606.7188 - 2s/epoch - 229ms/step
# Epoch 144/1000
#
# Epoch 144: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1011090.9375 - val_loss: 416193.4375 - 2s/epoch - 220ms/step
# Epoch 145/1000
#
# Epoch 145: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1009468.3125 - val_loss: 493169.9688 - 2s/epoch - 224ms/step
# Epoch 146/1000
#
# Epoch 146: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1023684.0625 - val_loss: 444386.0312 - 2s/epoch - 216ms/step
# Epoch 147/1000
#
# Epoch 147: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 909313.0625 - val_loss: 403302.8750 - 2s/epoch - 296ms/step
# Epoch 148/1000
#
# Epoch 148: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 996752.1250 - val_loss: 354378.0938 - 2s/epoch - 306ms/step
# Epoch 149/1000
#
# Epoch 149: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1046931.3750 - val_loss: 482636.4688 - 2s/epoch - 328ms/step
# Epoch 150/1000
#
# Epoch 150: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1017636.4375 - val_loss: 432225.9062 - 2s/epoch - 276ms/step
# Epoch 151/1000
#
# Epoch 151: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1020436.6250 - val_loss: 678717.0625 - 2s/epoch - 221ms/step
# Epoch 152/1000
#
# Epoch 152: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 1030557.9375 - val_loss: 603121.5000 - 1s/epoch - 211ms/step
# Epoch 153/1000
#
# Epoch 153: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 961830.1250 - val_loss: 589225.0625 - 2s/epoch - 217ms/step
# Epoch 154/1000
#
# Epoch 154: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 949977.2500 - val_loss: 729023.1875 - 2s/epoch - 218ms/step
# Epoch 155/1000
#
# Epoch 155: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 987873.5000 - val_loss: 693294.5625 - 2s/epoch - 218ms/step
# Epoch 156/1000
#
# Epoch 156: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 966384.0625 - val_loss: 442472.7500 - 1s/epoch - 214ms/step
# Epoch 157/1000
#
# Epoch 157: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 993615.6875 - val_loss: 445988.7500 - 2s/epoch - 304ms/step
# Epoch 158/1000
#
# Epoch 158: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1012814.0625 - val_loss: 826748.2500 - 2s/epoch - 324ms/step
# Epoch 159/1000
#
# Epoch 159: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1033106.0625 - val_loss: 260697.2188 - 2s/epoch - 321ms/step
# Epoch 160/1000
#
# Epoch 160: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1058353.6250 - val_loss: 569613.6250 - 2s/epoch - 256ms/step
# Epoch 161/1000
#
# Epoch 161: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 848422.6875 - val_loss: 381924.2500 - 2s/epoch - 221ms/step
# Epoch 162/1000
#
# Epoch 162: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1021669.3125 - val_loss: 538953.5000 - 2s/epoch - 221ms/step
# Epoch 163/1000
#
# Epoch 163: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 962881.3750 - val_loss: 469660.3125 - 2s/epoch - 220ms/step
# Epoch 164/1000
#
# Epoch 164: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 942349.2500 - val_loss: 600450.1250 - 2s/epoch - 218ms/step
# Epoch 165/1000
#
# Epoch 165: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 980782.4375 - val_loss: 801401.4375 - 2s/epoch - 223ms/step
# Epoch 166/1000
#
# Epoch 166: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 929600.8750 - val_loss: 582492.6875 - 2s/epoch - 234ms/step
# Epoch 167/1000
#
# Epoch 167: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1047602.1875 - val_loss: 648069.8750 - 2s/epoch - 323ms/step
# Epoch 168/1000
#
# Epoch 168: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 945875.6875 - val_loss: 362423.9688 - 2s/epoch - 321ms/step
# Epoch 169/1000
#
# Epoch 169: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 972995.1250 - val_loss: 289659.5312 - 2s/epoch - 305ms/step
# Epoch 170/1000
#
# Epoch 170: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 958374.4375 - val_loss: 85399.2812 - 2s/epoch - 233ms/step
# Epoch 171/1000
#
# Epoch 171: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 937218.9375 - val_loss: 146555.6094 - 1s/epoch - 212ms/step
# Epoch 172/1000
#
# Epoch 172: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 934106.8125 - val_loss: 62718.5586 - 1s/epoch - 210ms/step
# Epoch 173/1000
#
# Epoch 173: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 991873.0000 - val_loss: 343796.4375 - 1s/epoch - 211ms/step
# Epoch 174/1000
#
# Epoch 174: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 962264.1875 - val_loss: 72958.7031 - 2s/epoch - 215ms/step
# Epoch 175/1000
#
# Epoch 175: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 941213.8125 - val_loss: 379751.2500 - 1s/epoch - 207ms/step
# Epoch 176/1000
#
# Epoch 176: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 1009762.7500 - val_loss: 163385.2344 - 1s/epoch - 212ms/step
# Epoch 177/1000
#
# Epoch 177: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 947015.2500 - val_loss: 316766.7500 - 2s/epoch - 299ms/step
# Epoch 178/1000
#
# Epoch 178: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 888241.3125 - val_loss: 517054.4375 - 2s/epoch - 306ms/step
# Epoch 179/1000
#
# Epoch 179: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1067780.8750 - val_loss: 374090.7188 - 2s/epoch - 316ms/step
# Epoch 180/1000
#
# Epoch 180: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 977407.4375 - val_loss: 354722.1562 - 2s/epoch - 255ms/step
# Epoch 181/1000
#
# Epoch 181: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 910741.7500 - val_loss: 268425.0625 - 1s/epoch - 209ms/step
# Epoch 182/1000
#
# Epoch 182: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 1011074.9375 - val_loss: 472305.4688 - 1s/epoch - 210ms/step
# Epoch 183/1000
#
# Epoch 183: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 958494.5000 - val_loss: 346290.1250 - 1s/epoch - 212ms/step
# Epoch 184/1000
#
# Epoch 184: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 900541.1250 - val_loss: 436925.4375 - 1s/epoch - 212ms/step
# Epoch 185/1000
#
# Epoch 185: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 1023212.6875 - val_loss: 299870.6875 - 1s/epoch - 213ms/step
# Epoch 186/1000
#
# Epoch 186: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 954262.0000 - val_loss: 376916.6875 - 2s/epoch - 216ms/step
# Epoch 187/1000
#
# Epoch 187: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1029294.1250 - val_loss: 283519.3750 - 2s/epoch - 281ms/step
# Epoch 188/1000
#
# Epoch 188: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1003810.5000 - val_loss: 349525.1250 - 2s/epoch - 307ms/step
# Epoch 189/1000
#
# Epoch 189: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 949666.6250 - val_loss: 345901.4688 - 2s/epoch - 302ms/step
# Epoch 190/1000
#
# Epoch 190: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 934819.9375 - val_loss: 263912.8125 - 2s/epoch - 286ms/step
# Epoch 191/1000
#
# Epoch 191: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 927695.4375 - val_loss: 327269.2812 - 2s/epoch - 226ms/step
# Epoch 192/1000
#
# Epoch 192: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 912197.5000 - val_loss: 357562.7188 - 2s/epoch - 221ms/step
# Epoch 193/1000
#
# Epoch 193: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 1036632.0625 - val_loss: 294388.8750 - 1s/epoch - 212ms/step
# Epoch 194/1000
#
# Epoch 194: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 916943.0000 - val_loss: 332002.5000 - 2s/epoch - 214ms/step
# Epoch 195/1000
#
# Epoch 195: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1043414.1875 - val_loss: 363774.8750 - 2s/epoch - 217ms/step
# Epoch 196/1000
#
# Epoch 196: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 869475.1250 - val_loss: 236648.6875 - 1s/epoch - 212ms/step
# Epoch 197/1000
#
# Epoch 197: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 986054.7500 - val_loss: 464050.2812 - 2s/epoch - 265ms/step
# Epoch 198/1000
#
# Epoch 198: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 999418.0000 - val_loss: 176062.4844 - 2s/epoch - 315ms/step
# Epoch 199/1000
#
# Epoch 199: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 970594.9375 - val_loss: 469807.9062 - 2s/epoch - 309ms/step
# Epoch 200/1000
#
# Epoch 200: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1046038.2500 - val_loss: 355401.5938 - 2s/epoch - 286ms/step
# Epoch 201/1000
#
# Epoch 201: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 889869.2500 - val_loss: 329883.2500 - 1s/epoch - 209ms/step
# Epoch 202/1000
#
# Epoch 202: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 968597.1875 - val_loss: 492985.0312 - 1s/epoch - 205ms/step
# Epoch 203/1000
#
# Epoch 203: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 946738.3750 - val_loss: 367490.8750 - 1s/epoch - 210ms/step
# Epoch 204/1000
#
# Epoch 204: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 988332.1250 - val_loss: 512275.0000 - 1s/epoch - 210ms/step
# Epoch 205/1000
#
# Epoch 205: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 841972.0625 - val_loss: 314841.2500 - 1s/epoch - 207ms/step
# Epoch 206/1000
#
# Epoch 206: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 890291.5625 - val_loss: 537272.7500 - 1s/epoch - 210ms/step
# Epoch 207/1000
#
# Epoch 207: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 917622.7500 - val_loss: 347088.1875 - 2s/epoch - 240ms/step
# Epoch 208/1000
#
# Epoch 208: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 990916.4375 - val_loss: 771367.5000 - 2s/epoch - 297ms/step
# Epoch 209/1000
#
# Epoch 209: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1031028.6250 - val_loss: 540941.5000 - 2s/epoch - 295ms/step
# Epoch 210/1000
#
# Epoch 210: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 876518.1875 - val_loss: 418020.1250 - 2s/epoch - 295ms/step
# Epoch 211/1000
#
# Epoch 211: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1000180.8750 - val_loss: 680417.0625 - 2s/epoch - 241ms/step
# Epoch 212/1000
#
# Epoch 212: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 913259.2500 - val_loss: 346609.0000 - 1s/epoch - 212ms/step
# Epoch 213/1000
#
# Epoch 213: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 980443.1875 - val_loss: 765138.6250 - 1s/epoch - 210ms/step
# Epoch 214/1000
#
# Epoch 214: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 954412.8750 - val_loss: 321150.3750 - 1s/epoch - 212ms/step
# Epoch 215/1000
#
# Epoch 215: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 996798.6875 - val_loss: 736965.3750 - 1s/epoch - 212ms/step
# Epoch 216/1000
#
# Epoch 216: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 1040745.1250 - val_loss: 618660.1250 - 1s/epoch - 211ms/step
# Epoch 217/1000
#
# Epoch 217: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 971069.0000 - val_loss: 415076.5625 - 1s/epoch - 213ms/step
# Epoch 218/1000
#
# Epoch 218: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 902176.4375 - val_loss: 704980.0625 - 2s/epoch - 301ms/step
# Epoch 219/1000
#
# Epoch 219: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 965745.6875 - val_loss: 153983.3125 - 2s/epoch - 315ms/step
# Epoch 220/1000
#
# Epoch 220: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 875362.8125 - val_loss: 537848.7500 - 2s/epoch - 303ms/step
# Epoch 221/1000
#
# Epoch 221: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 950346.6875 - val_loss: 460828.3750 - 2s/epoch - 258ms/step
# Epoch 222/1000
#
# Epoch 222: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 883038.5625 - val_loss: 558187.4375 - 1s/epoch - 212ms/step
# Epoch 223/1000
#
# Epoch 223: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 954189.1250 - val_loss: 639858.4375 - 1s/epoch - 209ms/step
# Epoch 224/1000
#
# Epoch 224: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 951730.4375 - val_loss: 386590.0938 - 1s/epoch - 212ms/step
# Epoch 225/1000
#
# Epoch 225: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 963115.3750 - val_loss: 514118.6875 - 1s/epoch - 214ms/step
# Epoch 226/1000
#
# Epoch 226: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 925223.5000 - val_loss: 339519.3125 - 2s/epoch - 217ms/step
# Epoch 227/1000
#
# Epoch 227: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 905115.8750 - val_loss: 623013.8125 - 1s/epoch - 213ms/step
# Epoch 228/1000
#
# Epoch 228: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 946836.2500 - val_loss: 447035.2500 - 2s/epoch - 275ms/step
# Epoch 229/1000
#
# Epoch 229: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 983884.8750 - val_loss: 557678.3750 - 2s/epoch - 299ms/step
# Epoch 230/1000
#
# Epoch 230: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 982624.5000 - val_loss: 497910.5938 - 2s/epoch - 322ms/step
# Epoch 231/1000
#
# Epoch 231: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 894959.3750 - val_loss: 451085.5938 - 2s/epoch - 299ms/step
# Epoch 232/1000
#
# Epoch 232: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 906877.2500 - val_loss: 519777.0312 - 2s/epoch - 225ms/step
# Epoch 233/1000
#
# Epoch 233: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 840725.9375 - val_loss: 457377.7188 - 2s/epoch - 222ms/step
# Epoch 234/1000
#
# Epoch 234: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 890918.5000 - val_loss: 507729.7500 - 2s/epoch - 217ms/step
# Epoch 235/1000
#
# Epoch 235: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 846529.2500 - val_loss: 532014.7500 - 1s/epoch - 214ms/step
# Epoch 236/1000
#
# Epoch 236: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 894992.1250 - val_loss: 492349.6250 - 1s/epoch - 214ms/step
# Epoch 237/1000
#
# Epoch 237: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 855728.8125 - val_loss: 252796.5625 - 2s/epoch - 221ms/step
# Epoch 238/1000
#
# Epoch 238: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 872462.5000 - val_loss: 604212.6875 - 2s/epoch - 276ms/step
# Epoch 239/1000
#
# Epoch 239: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 923337.8125 - val_loss: 457128.8750 - 2s/epoch - 323ms/step
# Epoch 240/1000
#
# Epoch 240: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 841107.7500 - val_loss: 590514.7500 - 2s/epoch - 315ms/step
# Epoch 241/1000
#
# Epoch 241: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 915527.0625 - val_loss: 529958.5000 - 2s/epoch - 282ms/step
# Epoch 242/1000
#
# Epoch 242: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 904706.6875 - val_loss: 587732.4375 - 1s/epoch - 211ms/step
# Epoch 243/1000
#
# Epoch 243: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 914607.3750 - val_loss: 502474.5625 - 2s/epoch - 216ms/step
# Epoch 244/1000
#
# Epoch 244: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 852725.0625 - val_loss: 690315.2500 - 1s/epoch - 210ms/step
# Epoch 245/1000
#
# Epoch 245: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 828062.9375 - val_loss: 449091.1250 - 2s/epoch - 219ms/step
# Epoch 246/1000
#
# Epoch 246: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 880867.6250 - val_loss: 575703.9375 - 1s/epoch - 214ms/step
# Epoch 247/1000
#
# Epoch 247: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 871379.9375 - val_loss: 497213.1875 - 1s/epoch - 214ms/step
# Epoch 248/1000
#
# Epoch 248: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 906679.5625 - val_loss: 586885.2500 - 2s/epoch - 265ms/step
# Epoch 249/1000
#
# Epoch 249: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 818092.5625 - val_loss: 598895.8125 - 2s/epoch - 317ms/step
# Epoch 250/1000
#
# Epoch 250: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 860032.1875 - val_loss: 547331.0000 - 2s/epoch - 308ms/step
# Epoch 251/1000
#
# Epoch 251: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 894523.0000 - val_loss: 544337.3750 - 2s/epoch - 288ms/step
# Epoch 252/1000
#
# Epoch 252: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 823067.6875 - val_loss: 532400.1250 - 2s/epoch - 216ms/step
# Epoch 253/1000
#
# Epoch 253: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 899348.4375 - val_loss: 519089.9688 - 2s/epoch - 219ms/step
# Epoch 254/1000
#
# Epoch 254: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 940485.0625 - val_loss: 680434.8125 - 2s/epoch - 217ms/step
# Epoch 255/1000
#
# Epoch 255: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 822538.8125 - val_loss: 529626.6250 - 2s/epoch - 216ms/step
# Epoch 256/1000
#
# Epoch 256: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 903706.3750 - val_loss: 465605.0312 - 2s/epoch - 217ms/step
# Epoch 257/1000
#
# Epoch 257: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 952446.6875 - val_loss: 774311.6250 - 1s/epoch - 208ms/step
# Epoch 258/1000
#
# Epoch 258: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 927563.3750 - val_loss: 480937.7188 - 2s/epoch - 256ms/step
# Epoch 259/1000
#
# Epoch 259: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 951704.7500 - val_loss: 683133.3750 - 2s/epoch - 308ms/step
# Epoch 260/1000
#
# Epoch 260: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 893078.9375 - val_loss: 323627.3438 - 2s/epoch - 307ms/step
# Epoch 261/1000
#
# Epoch 261: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 833971.0000 - val_loss: 400381.0938 - 2s/epoch - 304ms/step
# Epoch 262/1000
#
# Epoch 262: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1008251.0000 - val_loss: 450844.2500 - 2s/epoch - 219ms/step
# Epoch 263/1000
#
# Epoch 263: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 909629.1250 - val_loss: 318878.9062 - 1s/epoch - 211ms/step
# Epoch 264/1000
#
# Epoch 264: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 901311.1250 - val_loss: 328683.9688 - 1s/epoch - 211ms/step
# Epoch 265/1000
#
# Epoch 265: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 1072269.5000 - val_loss: 735180.5000 - 1s/epoch - 213ms/step
# Epoch 266/1000
#
# Epoch 266: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 957172.8750 - val_loss: 383579.7188 - 2s/epoch - 216ms/step
# Epoch 267/1000
#
# Epoch 267: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 857317.1250 - val_loss: 464358.8438 - 2s/epoch - 218ms/step
# Epoch 268/1000
#
# Epoch 268: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 919713.3125 - val_loss: 436219.4688 - 2s/epoch - 239ms/step
# Epoch 269/1000
#
# Epoch 269: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 921641.4375 - val_loss: 347646.9688 - 2s/epoch - 301ms/step
# Epoch 270/1000
#
# Epoch 270: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 929056.4375 - val_loss: 477909.7500 - 2s/epoch - 302ms/step
# Epoch 271/1000
#
# Epoch 271: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 889215.2500 - val_loss: 473421.3750 - 2s/epoch - 305ms/step
# Epoch 272/1000
#
# Epoch 272: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 886399.5625 - val_loss: 395861.8125 - 2s/epoch - 245ms/step
# Epoch 273/1000
#
# Epoch 273: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 936698.8125 - val_loss: 425733.9062 - 2s/epoch - 226ms/step
# Epoch 274/1000
#
# Epoch 274: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 860669.9375 - val_loss: 404081.5625 - 2s/epoch - 306ms/step
# Epoch 275/1000
#
# Epoch 275: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 790347.4375 - val_loss: 447513.2500 - 2s/epoch - 309ms/step
# Epoch 276/1000
#
# Epoch 276: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 905236.2500 - val_loss: 558585.3750 - 2s/epoch - 304ms/step
# Epoch 277/1000
#
# Epoch 277: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 891057.2500 - val_loss: 729838.2500 - 2s/epoch - 305ms/step
# Epoch 278/1000
#
# Epoch 278: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 897636.8750 - val_loss: 426804.1875 - 2s/epoch - 308ms/step
# Epoch 279/1000
#
# Epoch 279: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 944043.3750 - val_loss: 731775.3750 - 2s/epoch - 306ms/step
# Epoch 280/1000
#
# Epoch 280: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 941748.3125 - val_loss: 419489.5625 - 2s/epoch - 305ms/step
# Epoch 281/1000
#
# Epoch 281: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 869316.4375 - val_loss: 654066.1250 - 2s/epoch - 220ms/step
# Epoch 282/1000
#
# Epoch 282: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 809480.1875 - val_loss: 535269.0000 - 2s/epoch - 217ms/step
# Epoch 283/1000
#
# Epoch 283: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 860385.5000 - val_loss: 778653.6250 - 2s/epoch - 225ms/step
# Epoch 284/1000
#
# Epoch 284: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 975682.0625 - val_loss: 389707.0000 - 2s/epoch - 226ms/step
# Epoch 285/1000
#
# Epoch 285: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 930861.9375 - val_loss: 712320.7500 - 2s/epoch - 225ms/step
# Epoch 286/1000
#
# Epoch 286: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 767656.5000 - val_loss: 370334.3125 - 2s/epoch - 216ms/step
# Epoch 287/1000
#
# Epoch 287: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 934959.0625 - val_loss: 916819.0625 - 2s/epoch - 271ms/step
# Epoch 288/1000
#
# Epoch 288: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 869180.3125 - val_loss: 545092.0625 - 2s/epoch - 306ms/step
# Epoch 289/1000
#
# Epoch 289: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 860668.1250 - val_loss: 897787.6875 - 2s/epoch - 307ms/step
# Epoch 290/1000
#
# Epoch 290: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 1000936.1250 - val_loss: 437745.8125 - 2s/epoch - 291ms/step
# Epoch 291/1000
#
# Epoch 291: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 975866.6875 - val_loss: 873832.5625 - 2s/epoch - 215ms/step
# Epoch 292/1000
#
# Epoch 292: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 846721.8125 - val_loss: 260440.5625 - 2s/epoch - 218ms/step
# Epoch 293/1000
#
# Epoch 293: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 865047.5000 - val_loss: 525434.3750 - 2s/epoch - 219ms/step
# Epoch 294/1000
#
# Epoch 294: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 825281.8750 - val_loss: 259702.5469 - 2s/epoch - 216ms/step
# Epoch 295/1000
#
# Epoch 295: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 878130.8750 - val_loss: 429122.4062 - 2s/epoch - 225ms/step
# Epoch 296/1000
#
# Epoch 296: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 877089.3125 - val_loss: 369048.0000 - 1s/epoch - 209ms/step
# Epoch 297/1000
#
# Epoch 297: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 860271.6875 - val_loss: 370741.5625 - 2s/epoch - 267ms/step
# Epoch 298/1000
#
# Epoch 298: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 933142.1250 - val_loss: 577324.8125 - 2s/epoch - 332ms/step
# Epoch 299/1000
#
# Epoch 299: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 971684.8750 - val_loss: 279738.4375 - 2s/epoch - 317ms/step
# Epoch 300/1000
#
# Epoch 300: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 945763.7500 - val_loss: 591517.0000 - 2s/epoch - 292ms/step
# Epoch 301/1000
#
# Epoch 301: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 954634.4375 - val_loss: 191754.0000 - 2s/epoch - 240ms/step
# Epoch 302/1000
#
# Epoch 302: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 853302.1875 - val_loss: 448771.8438 - 2s/epoch - 225ms/step
# Epoch 303/1000
#
# Epoch 303: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 849275.1875 - val_loss: 223647.0938 - 2s/epoch - 220ms/step
# Epoch 304/1000
#
# Epoch 304: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 868449.0625 - val_loss: 454389.6875 - 2s/epoch - 220ms/step
# Epoch 305/1000
#
# Epoch 305: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 910307.2500 - val_loss: 151941.0625 - 2s/epoch - 223ms/step
# Epoch 306/1000
#
# Epoch 306: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 833708.0625 - val_loss: 414679.6875 - 2s/epoch - 223ms/step
# Epoch 307/1000
#
# Epoch 307: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 971860.3125 - val_loss: 309292.9062 - 2s/epoch - 303ms/step
# Epoch 308/1000
#
# Epoch 308: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 828790.6250 - val_loss: 283513.1562 - 2s/epoch - 315ms/step
# Epoch 309/1000
#
# Epoch 309: val_loss did not improve from 3620.86060
# ...
# Epoch 892/1000
#
# Epoch 892: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 580443.3125 - val_loss: 528247.9375 - 2s/epoch - 312ms/step
# Epoch 893/1000
#
# Epoch 893: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 607255.1875 - val_loss: 640357.9375 - 2s/epoch - 325ms/step
# Epoch 894/1000
#
# Epoch 894: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 654000.5625 - val_loss: 338486.9688 - 2s/epoch - 317ms/step
# Epoch 895/1000
#
# Epoch 895: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 679015.5625 - val_loss: 715993.0625 - 2s/epoch - 240ms/step
# Epoch 896/1000
#
# Epoch 896: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 633928.0000 - val_loss: 255883.6406 - 2s/epoch - 217ms/step
# Epoch 897/1000
#
# Epoch 897: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 708014.2500 - val_loss: 367832.8125 - 2s/epoch - 216ms/step
# Epoch 898/1000
#
# Epoch 898: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 660454.7500 - val_loss: 618116.0625 - 1s/epoch - 214ms/step
# Epoch 899/1000
#
# Epoch 899: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 620407.1875 - val_loss: 390204.9688 - 2s/epoch - 219ms/step
# Epoch 900/1000
#
# Epoch 900: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 610796.1875 - val_loss: 709238.9375 - 2s/epoch - 221ms/step
# Epoch 901/1000
#
# Epoch 901: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 571484.0625 - val_loss: 412381.9688 - 2s/epoch - 234ms/step
# Epoch 902/1000
#
# Epoch 902: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 606428.5625 - val_loss: 549335.7500 - 2s/epoch - 331ms/step
# Epoch 903/1000
#
# Epoch 903: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 641898.5000 - val_loss: 475025.8750 - 2s/epoch - 325ms/step
# Epoch 904/1000
#
# Epoch 904: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 663817.3125 - val_loss: 458880.1875 - 2s/epoch - 312ms/step
# Epoch 905/1000
#
# Epoch 905: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 629243.1875 - val_loss: 424190.6875 - 2s/epoch - 231ms/step
# Epoch 906/1000
#
# Epoch 906: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 629115.0000 - val_loss: 541442.9375 - 2s/epoch - 220ms/step
# Epoch 907/1000
#
# Epoch 907: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 591423.7500 - val_loss: 574258.8750 - 2s/epoch - 223ms/step
# Epoch 908/1000
#
# Epoch 908: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 627716.4375 - val_loss: 633442.6250 - 2s/epoch - 221ms/step
# Epoch 909/1000
#
# Epoch 909: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 638820.0625 - val_loss: 722486.3125 - 2s/epoch - 217ms/step
# Epoch 910/1000
#
# Epoch 910: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 556408.1875 - val_loss: 469180.3750 - 2s/epoch - 217ms/step
# Epoch 911/1000
#
# Epoch 911: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 617983.4375 - val_loss: 569324.5625 - 2s/epoch - 239ms/step
# Epoch 912/1000
#
# Epoch 912: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 676529.3125 - val_loss: 833608.6250 - 2s/epoch - 325ms/step
# Epoch 913/1000
#
# Epoch 913: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 638139.8750 - val_loss: 268306.7500 - 2s/epoch - 325ms/step
# Epoch 914/1000
#
# Epoch 914: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 662461.9375 - val_loss: 825586.9375 - 2s/epoch - 321ms/step
# Epoch 915/1000
#
# Epoch 915: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 658571.2500 - val_loss: 316785.1562 - 1s/epoch - 212ms/step
# Epoch 916/1000
#
# Epoch 916: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 592211.5625 - val_loss: 414902.1875 - 1s/epoch - 212ms/step
# Epoch 917/1000
#
# Epoch 917: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 585121.3750 - val_loss: 749569.5000 - 1s/epoch - 207ms/step
# Epoch 918/1000
#
# Epoch 918: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 656957.7500 - val_loss: 466435.6250 - 1s/epoch - 211ms/step
# Epoch 919/1000
#
# Epoch 919: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 643483.5625 - val_loss: 423615.8125 - 1s/epoch - 211ms/step
# Epoch 920/1000
#
# Epoch 920: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 649895.1875 - val_loss: 946266.1875 - 1s/epoch - 207ms/step
# Epoch 921/1000
#
# Epoch 921: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 710568.1875 - val_loss: 392977.5312 - 2s/epoch - 228ms/step
# Epoch 922/1000
#
# Epoch 922: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 555399.8750 - val_loss: 444966.0000 - 2s/epoch - 317ms/step
# Epoch 923/1000
#
# Epoch 923: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 654104.0000 - val_loss: 466658.9062 - 2s/epoch - 318ms/step
# Epoch 924/1000
#
# Epoch 924: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 617961.5625 - val_loss: 489335.1250 - 2s/epoch - 299ms/step
# Epoch 925/1000
#
# Epoch 925: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 638627.1250 - val_loss: 628223.5625 - 2s/epoch - 232ms/step
# Epoch 926/1000
#
# Epoch 926: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 626854.2500 - val_loss: 339312.1562 - 1s/epoch - 213ms/step
# Epoch 927/1000
#
# Epoch 927: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 569097.9375 - val_loss: 702158.8750 - 1s/epoch - 212ms/step
# Epoch 928/1000
#
# Epoch 928: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 633360.3125 - val_loss: 346653.4062 - 1s/epoch - 211ms/step
# Epoch 929/1000
#
# Epoch 929: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 695535.9375 - val_loss: 604176.0625 - 1s/epoch - 210ms/step
# Epoch 930/1000
#
# Epoch 930: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 574201.3125 - val_loss: 753193.0625 - 1s/epoch - 209ms/step
# Epoch 931/1000
#
# Epoch 931: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 639223.8750 - val_loss: 465090.8438 - 1s/epoch - 207ms/step
# Epoch 932/1000
#
# Epoch 932: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 669459.2500 - val_loss: 737259.1250 - 2s/epoch - 288ms/step
# Epoch 933/1000
#
# Epoch 933: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 615354.2500 - val_loss: 656371.8125 - 2s/epoch - 298ms/step
# Epoch 934/1000
#
# Epoch 934: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 634133.2500 - val_loss: 298027.9688 - 2s/epoch - 300ms/step
# Epoch 935/1000
#
# Epoch 935: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 747417.1250 - val_loss: 738664.2500 - 2s/epoch - 273ms/step
# Epoch 936/1000
#
# Epoch 936: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 672265.5000 - val_loss: 437167.4375 - 1s/epoch - 202ms/step
# Epoch 937/1000
#
# Epoch 937: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 590132.3750 - val_loss: 570533.7500 - 1s/epoch - 207ms/step
# Epoch 938/1000
#
# Epoch 938: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 624554.9375 - val_loss: 806467.6875 - 1s/epoch - 206ms/step
# Epoch 939/1000
#
# Epoch 939: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 647491.6250 - val_loss: 495810.2500 - 1s/epoch - 209ms/step
# Epoch 940/1000
#
# Epoch 940: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 673334.5625 - val_loss: 585816.5000 - 1s/epoch - 209ms/step
# Epoch 941/1000
#
# Epoch 941: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 642719.5625 - val_loss: 558573.7500 - 1s/epoch - 208ms/step
# Epoch 942/1000
#
# Epoch 942: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 620296.3750 - val_loss: 361080.8125 - 2s/epoch - 253ms/step
# Epoch 943/1000
#
# Epoch 943: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 564268.0625 - val_loss: 498622.0938 - 2s/epoch - 303ms/step
# Epoch 944/1000
#
# Epoch 944: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 528435.6875 - val_loss: 568129.5625 - 2s/epoch - 334ms/step
# Epoch 945/1000
#
# Epoch 945: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 666632.8750 - val_loss: 525772.8125 - 2s/epoch - 309ms/step
# Epoch 946/1000
#
# Epoch 946: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 661045.3750 - val_loss: 823219.3750 - 1s/epoch - 212ms/step
# Epoch 947/1000
#
# Epoch 947: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 736769.8750 - val_loss: 544275.1875 - 1s/epoch - 214ms/step
# Epoch 948/1000
#
# Epoch 948: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 550676.6875 - val_loss: 704477.1250 - 1s/epoch - 214ms/step
# Epoch 949/1000
#
# Epoch 949: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 639191.6875 - val_loss: 426134.4375 - 1s/epoch - 214ms/step
# Epoch 950/1000
#
# Epoch 950: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 612706.3125 - val_loss: 564942.8125 - 2s/epoch - 217ms/step
# Epoch 951/1000
#
# Epoch 951: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 630167.8125 - val_loss: 625792.0625 - 2s/epoch - 221ms/step
# Epoch 952/1000
#
# Epoch 952: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 676182.0625 - val_loss: 365692.0938 - 2s/epoch - 262ms/step
# Epoch 953/1000
#
# Epoch 953: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 754998.4375 - val_loss: 949976.1875 - 2s/epoch - 293ms/step
# Epoch 954/1000
#
# Epoch 954: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 643136.7500 - val_loss: 424066.2812 - 2s/epoch - 290ms/step
# Epoch 955/1000
#
# Epoch 955: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 651148.3125 - val_loss: 588553.1875 - 2s/epoch - 301ms/step
# Epoch 956/1000
#
# Epoch 956: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 622143.4375 - val_loss: 449839.1250 - 2s/epoch - 236ms/step
# Epoch 957/1000
#
# Epoch 957: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 622993.3125 - val_loss: 440873.3750 - 1s/epoch - 204ms/step
# Epoch 958/1000
#
# Epoch 958: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 680972.4375 - val_loss: 504251.5938 - 1s/epoch - 212ms/step
# Epoch 959/1000
#
# Epoch 959: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 590058.2500 - val_loss: 299998.1562 - 1s/epoch - 213ms/step
# Epoch 960/1000
#
# Epoch 960: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 576364.5625 - val_loss: 702034.8125 - 1s/epoch - 214ms/step
# Epoch 961/1000
#
# Epoch 961: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 650770.5000 - val_loss: 432433.6875 - 1s/epoch - 206ms/step
# Epoch 962/1000
#
# Epoch 962: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 575515.6250 - val_loss: 699726.7500 - 1s/epoch - 207ms/step
# Epoch 963/1000
#
# Epoch 963: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 569412.3125 - val_loss: 485980.2500 - 2s/epoch - 311ms/step
# Epoch 964/1000
#
# Epoch 964: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 635938.6875 - val_loss: 441175.5312 - 2s/epoch - 311ms/step
# Epoch 965/1000
#
# Epoch 965: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 720030.6875 - val_loss: 747489.8125 - 2s/epoch - 317ms/step
# Epoch 966/1000
#
# Epoch 966: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 629136.8750 - val_loss: 483362.4375 - 2s/epoch - 258ms/step
# Epoch 967/1000
#
# Epoch 967: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 672608.7500 - val_loss: 484983.4375 - 1s/epoch - 213ms/step
# Epoch 968/1000
#
# Epoch 968: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 632726.1250 - val_loss: 722329.0625 - 1s/epoch - 214ms/step
# Epoch 969/1000
#
# Epoch 969: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 592805.0000 - val_loss: 518973.9688 - 1s/epoch - 211ms/step
# Epoch 970/1000
#
# Epoch 970: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 626250.3125 - val_loss: 570326.3750 - 1s/epoch - 210ms/step
# Epoch 971/1000
#
# Epoch 971: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 635550.2500 - val_loss: 631212.0625 - 1s/epoch - 206ms/step
# Epoch 972/1000
#
# Epoch 972: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 607452.5625 - val_loss: 503410.5625 - 1s/epoch - 208ms/step
# Epoch 973/1000
#
# Epoch 973: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 623645.9375 - val_loss: 591992.0000 - 2s/epoch - 267ms/step
# Epoch 974/1000
#
# Epoch 974: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 566540.5000 - val_loss: 883552.5625 - 2s/epoch - 300ms/step
# Epoch 975/1000
#
# Epoch 975: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 599574.2500 - val_loss: 622203.1875 - 2s/epoch - 297ms/step
# Epoch 976/1000
#
# Epoch 976: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 572105.0000 - val_loss: 635705.1875 - 2s/epoch - 289ms/step
# Epoch 977/1000
#
# Epoch 977: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 589888.1250 - val_loss: 580343.8125 - 1s/epoch - 209ms/step
# Epoch 978/1000
#
# Epoch 978: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 642013.3125 - val_loss: 542497.9375 - 1s/epoch - 204ms/step
# Epoch 979/1000
#
# Epoch 979: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 565720.3125 - val_loss: 571210.9375 - 1s/epoch - 208ms/step
# Epoch 980/1000
#
# Epoch 980: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 572540.3750 - val_loss: 576132.8750 - 1s/epoch - 203ms/step
# Epoch 981/1000
#
# Epoch 981: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 562339.6250 - val_loss: 682114.0625 - 1s/epoch - 210ms/step
# Epoch 982/1000
#
# Epoch 982: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 645815.8750 - val_loss: 569070.1250 - 1s/epoch - 207ms/step
# Epoch 983/1000
#
# Epoch 983: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 648510.1875 - val_loss: 668669.9375 - 1s/epoch - 214ms/step
# Epoch 984/1000
#
# Epoch 984: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 582379.9375 - val_loss: 514356.8750 - 2s/epoch - 294ms/step
# Epoch 985/1000
#
# Epoch 985: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 617474.6250 - val_loss: 892956.3750 - 2s/epoch - 298ms/step
# Epoch 986/1000
#
# Epoch 986: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 596415.1875 - val_loss: 431535.0312 - 2s/epoch - 295ms/step
# Epoch 987/1000
#
# Epoch 987: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 630981.5000 - val_loss: 715974.0000 - 2s/epoch - 260ms/step
# Epoch 988/1000
#
# Epoch 988: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 657337.4375 - val_loss: 475659.5312 - 1s/epoch - 208ms/step
# Epoch 989/1000
#
# Epoch 989: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 533985.5625 - val_loss: 598391.6250 - 1s/epoch - 207ms/step
# Epoch 990/1000
#
# Epoch 990: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 522903.5938 - val_loss: 600450.3750 - 1s/epoch - 206ms/step
# Epoch 991/1000
#
# Epoch 991: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 629505.1250 - val_loss: 746993.6250 - 1s/epoch - 209ms/step
# Epoch 992/1000
#
# Epoch 992: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 595007.5625 - val_loss: 569532.7500 - 1s/epoch - 209ms/step
# Epoch 993/1000
#
# Epoch 993: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 572978.8750 - val_loss: 809400.3125 - 1s/epoch - 208ms/step
# Epoch 994/1000
#
# Epoch 994: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 595780.8750 - val_loss: 539142.3750 - 2s/epoch - 250ms/step
# Epoch 995/1000
#
# Epoch 995: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 598419.8750 - val_loss: 581430.1875 - 2s/epoch - 304ms/step
# Epoch 996/1000
#
# Epoch 996: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 603115.5625 - val_loss: 647146.9375 - 2s/epoch - 298ms/step
# Epoch 997/1000
#
# Epoch 997: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 565878.5625 - val_loss: 517264.5312 - 2s/epoch - 295ms/step
# Epoch 998/1000
#
# Epoch 998: val_loss did not improve from 3620.86060
# 7/7 - 2s - loss: 582477.7500 - val_loss: 565189.9375 - 2s/epoch - 216ms/step
# Epoch 999/1000
#
# Epoch 999: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 549344.8750 - val_loss: 533080.4375 - 1s/epoch - 207ms/step
# Epoch 1000/1000
#
# Epoch 1000: val_loss did not improve from 3620.86060
# 7/7 - 1s - loss: 561456.5000 - val_loss: 554852.8750 - 1s/epoch - 202ms/step
# 16/16 [==============================] - 1s 26ms/step
# 3/3 [==============================] - 0s 24ms/step
# Training MSE: 44116.95034193978
# Testing MSE: 7956.79982930226
# accuracy : 59

# %%
# 모델 생성
model = Sequential()
model.add(LSTM(units=1024, activation='relu', return_sequences=True, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dropout(0.3))
model.add(LSTM(units=512, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(units=256, activation='relu', return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(units=128, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(units=64, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(units=32, activation='relu',return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(units=16, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(units=1))
model.summary()

# loss = Huber()
# optimizer = Adam(0.0005)
# model.compile(loss=Huber(), optimizer=optimizer, metrics=['mse'])

model.compile(optimizer='adam', loss='mean_squared_error')

filename = os.path.join('tmp', 'ckeckpointer.ckpt')
checkpoint = ModelCheckpoint(filename,
                             save_weights_only=True,
                             save_best_only=True,
                             monitor='val_loss',
                             verbose=1)

# 모델 학습
history = model.fit(trainX, trainY, epochs=1000, batch_size=64,
          validation_split=0.1, verbose=2,callbacks=[checkpoint])

model.save_weights('./lstm_weights.h3')

model.load_weights(filename)

plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()
plt.show()

# 예측
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# MSE 계산
trainMSE = mean_squared_error(trainY, trainPredict)
testMSE = mean_squared_error(testY, testPredict)

print(f'Training MSE: {trainMSE}')
print(f'Testing MSE: {testMSE}')

accuracy(testPredict,testY)

# 예측 시각화
plt.plot(trainY, label='Actual Price')
plt.plot(trainPredict, label='Predicted Price')
plt.legend()
plt.title('Training Data')
plt.show()

plt.plot(testY, label='Actual Price')
plt.plot(testPredict, label='Predicted Price')
plt.legend()
plt.title('Testing Data')
plt.show()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_14 (LSTM)              (None, 5, 1024)           4239360
#
#  dropout_40 (Dropout)        (None, 5, 1024)           0
#
#  lstm_15 (LSTM)              (None, 5, 512)            3147776
#
#  dropout_41 (Dropout)        (None, 5, 512)            0
#
#  lstm_16 (LSTM)              (None, 5, 256)            787456
#
#  dropout_42 (Dropout)        (None, 5, 256)            0
#
#  lstm_17 (LSTM)              (None, 5, 128)            197120
#
#  dropout_43 (Dropout)        (None, 5, 128)            0
#
#  lstm_18 (LSTM)              (None, 5, 64)             49408
#
#  dropout_44 (Dropout)        (None, 5, 64)             0
#
#  lstm_19 (LSTM)              (None, 5, 32)             12416
#
#  dropout_45 (Dropout)        (None, 5, 32)             0
#
#  lstm_20 (LSTM)              (None, 16)                3136
#
#  dropout_46 (Dropout)        (None, 16)                0
#
#  dense_6 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 8436689 (32.18 MB)
# Trainable params: 8436689 (32.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/1000
#
# Epoch 1: val_loss improved from inf to 5710862.50000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 17s - loss: 8167936.0000 - val_loss: 5710862.5000 - 17s/epoch - 2s/step
# Epoch 2/1000
#
# Epoch 2: val_loss improved from 5710862.50000 to 5630264.50000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 6s - loss: 8158370.5000 - val_loss: 5630264.5000 - 6s/epoch - 827ms/step
# Epoch 3/1000
#
# Epoch 3: val_loss improved from 5630264.50000 to 1496917.25000, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 7s - loss: 7305194.5000 - val_loss: 1496917.2500 - 7s/epoch - 942ms/step
# Epoch 4/1000
#
# Epoch 4: val_loss improved from 1496917.25000 to 25872.72266, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 5s - loss: 4163580.0000 - val_loss: 25872.7227 - 5s/epoch - 702ms/step
# Epoch 5/1000
#
# Epoch 5: val_loss did not improve from 25872.72266
# 7/7 - 5s - loss: 3819853.7500 - val_loss: 1081470.7500 - 5s/epoch - 741ms/step
# Epoch 6/1000
#
# Epoch 6: val_loss did not improve from 25872.72266
# 7/7 - 7s - loss: 3770199.7500 - val_loss: 83975.2031 - 7s/epoch - 933ms/step
# Epoch 7/1000
#
# Epoch 7: val_loss did not improve from 25872.72266
# 7/7 - 5s - loss: 3631887.2500 - val_loss: 120319.5469 - 5s/epoch - 660ms/step
# Epoch 8/1000
#
# Epoch 8: val_loss did not improve from 25872.72266
# 7/7 - 5s - loss: 3903236.5000 - val_loss: 608674.6250 - 5s/epoch - 670ms/step
# Epoch 9/1000
#
# Epoch 9: val_loss did not improve from 25872.72266
# 7/7 - 7s - loss: 3657611.2500 - val_loss: 702884.9375 - 7s/epoch - 1s/step
# Epoch 10/1000
#
# Epoch 10: val_loss did not improve from 25872.72266
# 7/7 - 5s - loss: 3242304.0000 - val_loss: 574589.2500 - 5s/epoch - 700ms/step
# Epoch 11/1000
#
# Epoch 11: val_loss did not improve from 25872.72266
# 7/7 - 4s - loss: 3029344.2500 - val_loss: 802713.5000 - 4s/epoch - 641ms/step
# Epoch 12/1000
#
# Epoch 12: val_loss did not improve from 25872.72266
# 7/7 - 6s - loss: 2627213.0000 - val_loss: 761396.0000 - 6s/epoch - 874ms/step
# Epoch 13/1000
#
# Epoch 13: val_loss did not improve from 25872.72266
# 7/7 - 6s - loss: 2934859.5000 - val_loss: 1019578.5625 - 6s/epoch - 803ms/step
# Epoch 14/1000
#
# Epoch 14: val_loss did not improve from 25872.72266
# 7/7 - 5s - loss: 2605383.2500 - val_loss: 220333.0781 - 5s/epoch - 672ms/step
# Epoch 15/1000
#
# Epoch 15: val_loss did not improve from 25872.72266
# 7/7 - 10s - loss: 2406705.5000 - val_loss: 532481.2500 - 10s/epoch - 1s/step
# Epoch 16/1000
#
# Epoch 16: val_loss did not improve from 25872.72266
# 7/7 - 6s - loss: 2286682.0000 - val_loss: 416533.3125 - 6s/epoch - 876ms/step
# Epoch 17/1000
#
# Epoch 17: val_loss did not improve from 25872.72266
# 7/7 - 5s - loss: 2383492.2500 - val_loss: 965158.0625 - 5s/epoch - 683ms/step
# Epoch 18/1000
#
# Epoch 18: val_loss improved from 25872.72266 to 22503.51953, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 8s - loss: 2220816.5000 - val_loss: 22503.5195 - 8s/epoch - 1s/step
# Epoch 19/1000
#
# Epoch 19: val_loss did not improve from 22503.51953
# 7/7 - 6s - loss: 2601086.0000 - val_loss: 1362647.3750 - 6s/epoch - 794ms/step
# Epoch 20/1000
#
# Epoch 20: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 2588496.5000 - val_loss: 863753.9375 - 5s/epoch - 709ms/step
# Epoch 21/1000
#
# Epoch 21: val_loss did not improve from 22503.51953
# 7/7 - 7s - loss: 1820936.1250 - val_loss: 783703.6875 - 7s/epoch - 995ms/step
# Epoch 22/1000
#
# Epoch 22: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 2343015.7500 - val_loss: 224310.7188 - 5s/epoch - 660ms/step
# Epoch 23/1000
#
# Epoch 23: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 1880173.2500 - val_loss: 77837.5469 - 5s/epoch - 658ms/step
# Epoch 24/1000
#
# Epoch 24: val_loss did not improve from 22503.51953
# 7/7 - 7s - loss: 1815022.8750 - val_loss: 531414.6250 - 7s/epoch - 943ms/step
# Epoch 25/1000
#
# Epoch 25: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 1587391.6250 - val_loss: 476302.0312 - 5s/epoch - 752ms/step
# Epoch 26/1000
#
# Epoch 26: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 1663507.1250 - val_loss: 350437.6875 - 5s/epoch - 664ms/step
# Epoch 27/1000
#
# Epoch 27: val_loss did not improve from 22503.51953
# 7/7 - 6s - loss: 1564146.1250 - val_loss: 224505.4844 - 6s/epoch - 861ms/step
# Epoch 28/1000
#
# Epoch 28: val_loss did not improve from 22503.51953
# 7/7 - 6s - loss: 1480645.7500 - val_loss: 69321.8828 - 6s/epoch - 832ms/step
# Epoch 29/1000
#
# Epoch 29: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 1353774.2500 - val_loss: 184778.0469 - 5s/epoch - 668ms/step
# Epoch 30/1000
#
# Epoch 30: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 1321970.8750 - val_loss: 66570.6953 - 5s/epoch - 785ms/step
# Epoch 31/1000
#
# Epoch 31: val_loss did not improve from 22503.51953
# 7/7 - 6s - loss: 1387810.2500 - val_loss: 152083.0469 - 6s/epoch - 895ms/step
# Epoch 32/1000
#
# Epoch 32: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 1369959.5000 - val_loss: 561413.3125 - 5s/epoch - 654ms/step
# Epoch 33/1000
#
# Epoch 33: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 1171593.6250 - val_loss: 149900.8125 - 5s/epoch - 681ms/step
# Epoch 34/1000
#
# Epoch 34: val_loss did not improve from 22503.51953
# 7/7 - 7s - loss: 1123122.6250 - val_loss: 518217.1250 - 7s/epoch - 1s/step
# Epoch 35/1000
#
# Epoch 35: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 1124312.8750 - val_loss: 544827.9375 - 5s/epoch - 650ms/step
# Epoch 36/1000
#
# Epoch 36: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 1155087.0000 - val_loss: 374030.1250 - 5s/epoch - 671ms/step
# Epoch 37/1000
#
# Epoch 37: val_loss did not improve from 22503.51953
# 7/7 - 7s - loss: 1069925.3750 - val_loss: 289083.6562 - 7s/epoch - 959ms/step
# Epoch 38/1000
#
# Epoch 38: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 1035794.1875 - val_loss: 69911.6406 - 5s/epoch - 757ms/step
# Epoch 39/1000
#
# Epoch 39: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 1077216.6250 - val_loss: 167636.4844 - 5s/epoch - 672ms/step
# Epoch 40/1000
#
# Epoch 40: val_loss did not improve from 22503.51953
# 7/7 - 6s - loss: 1102981.2500 - val_loss: 99947.1484 - 6s/epoch - 897ms/step
# Epoch 41/1000
#
# Epoch 41: val_loss did not improve from 22503.51953
# 7/7 - 6s - loss: 985641.2500 - val_loss: 86299.7812 - 6s/epoch - 810ms/step
# Epoch 42/1000
#
# Epoch 42: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 942322.8125 - val_loss: 112109.8281 - 5s/epoch - 653ms/step
# Epoch 43/1000
#
# Epoch 43: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 899860.5625 - val_loss: 169399.6875 - 5s/epoch - 769ms/step
# Epoch 44/1000
#
# Epoch 44: val_loss did not improve from 22503.51953
# 7/7 - 6s - loss: 987357.1875 - val_loss: 438107.8438 - 6s/epoch - 901ms/step
# Epoch 45/1000
#
# Epoch 45: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 1034944.8750 - val_loss: 54985.2500 - 5s/epoch - 650ms/step
# Epoch 46/1000
#
# Epoch 46: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 954102.0000 - val_loss: 171847.5000 - 5s/epoch - 669ms/step
# Epoch 47/1000
#
# Epoch 47: val_loss did not improve from 22503.51953
# 7/7 - 7s - loss: 975724.1250 - val_loss: 131454.3438 - 7s/epoch - 989ms/step
# Epoch 48/1000
#
# Epoch 48: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 864053.7500 - val_loss: 199049.3438 - 5s/epoch - 676ms/step
# Epoch 49/1000
#
# Epoch 49: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 933067.3750 - val_loss: 102125.3984 - 5s/epoch - 740ms/step
# Epoch 50/1000
#
# Epoch 50: val_loss did not improve from 22503.51953
# 7/7 - 7s - loss: 787811.6250 - val_loss: 342986.3750 - 7s/epoch - 975ms/step
# Epoch 51/1000
#
# Epoch 51: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 875901.0625 - val_loss: 459367.9062 - 5s/epoch - 731ms/step
# Epoch 52/1000
#
# Epoch 52: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 941288.8125 - val_loss: 208752.4844 - 5s/epoch - 654ms/step
# Epoch 53/1000
#
# Epoch 53: val_loss did not improve from 22503.51953
# 7/7 - 6s - loss: 867340.3125 - val_loss: 380639.0000 - 6s/epoch - 865ms/step
# Epoch 54/1000
#
# Epoch 54: val_loss did not improve from 22503.51953
# 7/7 - 6s - loss: 794240.3125 - val_loss: 130719.0781 - 6s/epoch - 812ms/step
# Epoch 55/1000
#
# Epoch 55: val_loss did not improve from 22503.51953
# 7/7 - 4s - loss: 863407.8750 - val_loss: 445839.9688 - 4s/epoch - 639ms/step
# Epoch 56/1000
#
# Epoch 56: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 798295.8125 - val_loss: 102676.1406 - 5s/epoch - 742ms/step
# Epoch 57/1000
#
# Epoch 57: val_loss did not improve from 22503.51953
# 7/7 - 6s - loss: 741126.3125 - val_loss: 163940.2031 - 6s/epoch - 927ms/step
# Epoch 58/1000
#
# Epoch 58: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 703559.0000 - val_loss: 102824.9609 - 5s/epoch - 663ms/step
# Epoch 59/1000
#
# Epoch 59: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 723280.3750 - val_loss: 301435.5938 - 5s/epoch - 694ms/step
# Epoch 60/1000
#
# Epoch 60: val_loss did not improve from 22503.51953
# 7/7 - 7s - loss: 752393.3750 - val_loss: 256099.3125 - 7s/epoch - 991ms/step
# Epoch 61/1000
#
# Epoch 61: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 792817.4375 - val_loss: 140234.2344 - 5s/epoch - 663ms/step
# Epoch 62/1000
#
# Epoch 62: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 764526.6250 - val_loss: 320519.7812 - 5s/epoch - 659ms/step
# Epoch 63/1000
#
# Epoch 63: val_loss did not improve from 22503.51953
# 7/7 - 7s - loss: 752562.5000 - val_loss: 158495.4844 - 7s/epoch - 935ms/step
# Epoch 64/1000
#
# Epoch 64: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 784539.3750 - val_loss: 60430.4219 - 5s/epoch - 756ms/step
# Epoch 65/1000
#
# Epoch 65: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 771074.0625 - val_loss: 244239.5625 - 5s/epoch - 660ms/step
# Epoch 66/1000
#
# Epoch 66: val_loss did not improve from 22503.51953
# 7/7 - 6s - loss: 770291.9375 - val_loss: 76379.1250 - 6s/epoch - 828ms/step
# Epoch 67/1000
#
# Epoch 67: val_loss did not improve from 22503.51953
# 7/7 - 6s - loss: 872789.0000 - val_loss: 161345.5000 - 6s/epoch - 856ms/step
# Epoch 68/1000
#
# Epoch 68: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 794081.6875 - val_loss: 120285.2500 - 5s/epoch - 655ms/step
# Epoch 69/1000
#
# Epoch 69: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 724385.5000 - val_loss: 207076.9844 - 5s/epoch - 738ms/step
# Epoch 70/1000
#
# Epoch 70: val_loss did not improve from 22503.51953
# 7/7 - 7s - loss: 840768.1875 - val_loss: 91713.3672 - 7s/epoch - 945ms/step
# Epoch 71/1000
#
# Epoch 71: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 713436.1250 - val_loss: 222013.3125 - 5s/epoch - 675ms/step
# Epoch 72/1000
#
# Epoch 72: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 690406.0000 - val_loss: 80015.9688 - 5s/epoch - 710ms/step
# Epoch 73/1000
#
# Epoch 73: val_loss did not improve from 22503.51953
# 7/7 - 7s - loss: 701152.8750 - val_loss: 90016.8438 - 7s/epoch - 1s/step
# Epoch 74/1000
#
# Epoch 74: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 750958.5000 - val_loss: 78192.5625 - 5s/epoch - 692ms/step
# Epoch 75/1000
#
# Epoch 75: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 752461.9375 - val_loss: 211454.7656 - 5s/epoch - 695ms/step
# Epoch 76/1000
#
# Epoch 76: val_loss did not improve from 22503.51953
# 7/7 - 7s - loss: 657364.3125 - val_loss: 27205.7344 - 7s/epoch - 1s/step
# Epoch 77/1000
#
# Epoch 77: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 728027.9375 - val_loss: 123464.8281 - 5s/epoch - 743ms/step
# Epoch 78/1000
#
# Epoch 78: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 681656.4375 - val_loss: 93471.2266 - 5s/epoch - 689ms/step
# Epoch 79/1000
#
# Epoch 79: val_loss did not improve from 22503.51953
# 7/7 - 7s - loss: 706174.6250 - val_loss: 34836.2188 - 7s/epoch - 940ms/step
# Epoch 80/1000
#
# Epoch 80: val_loss did not improve from 22503.51953
# 7/7 - 6s - loss: 721725.5000 - val_loss: 78507.4297 - 6s/epoch - 788ms/step
# Epoch 81/1000
#
# Epoch 81: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 717945.9375 - val_loss: 104473.7188 - 5s/epoch - 693ms/step
# Epoch 82/1000
#
# Epoch 82: val_loss did not improve from 22503.51953
# 7/7 - 6s - loss: 657601.5625 - val_loss: 35990.3008 - 6s/epoch - 828ms/step
# Epoch 83/1000
#
# Epoch 83: val_loss did not improve from 22503.51953
# 7/7 - 6s - loss: 662787.6250 - val_loss: 66363.0391 - 6s/epoch - 871ms/step
# Epoch 84/1000
#
# Epoch 84: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 687608.4375 - val_loss: 101805.9531 - 5s/epoch - 666ms/step
# Epoch 85/1000
#
# Epoch 85: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 675109.0000 - val_loss: 47300.3047 - 5s/epoch - 751ms/step
# Epoch 86/1000
#
# Epoch 86: val_loss did not improve from 22503.51953
# 7/7 - 7s - loss: 636231.6875 - val_loss: 76315.9766 - 7s/epoch - 981ms/step
# Epoch 87/1000
#
# Epoch 87: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 645582.7500 - val_loss: 67727.3906 - 5s/epoch - 685ms/step
# Epoch 88/1000
#
# Epoch 88: val_loss did not improve from 22503.51953
# 7/7 - 5s - loss: 707297.1250 - val_loss: 57083.3086 - 5s/epoch - 682ms/step
# Epoch 89/1000
#
# Epoch 89: val_loss did not improve from 22503.51953
# 7/7 - 7s - loss: 619570.6250 - val_loss: 95193.9375 - 7s/epoch - 1s/step
# Epoch 90/1000
#
# Epoch 90: val_loss improved from 22503.51953 to 15260.28711, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 5s - loss: 659418.8125 - val_loss: 15260.2871 - 5s/epoch - 740ms/step
# Epoch 91/1000
#
# Epoch 91: val_loss did not improve from 15260.28711
# 7/7 - 5s - loss: 593318.0000 - val_loss: 94846.8516 - 5s/epoch - 683ms/step
# Epoch 92/1000
#
# Epoch 92: val_loss did not improve from 15260.28711
# 7/7 - 6s - loss: 607281.0000 - val_loss: 125846.9766 - 6s/epoch - 912ms/step
# Epoch 93/1000
#
# Epoch 93: val_loss did not improve from 15260.28711
# 7/7 - 5s - loss: 597035.4375 - val_loss: 60829.2500 - 5s/epoch - 745ms/step
# Epoch 94/1000
#
# Epoch 94: val_loss did not improve from 15260.28711
# 7/7 - 4s - loss: 625851.3125 - val_loss: 75698.3438 - 4s/epoch - 636ms/step
# Epoch 95/1000
#
# Epoch 95: val_loss did not improve from 15260.28711
# 7/7 - 6s - loss: 667127.6875 - val_loss: 160991.1250 - 6s/epoch - 799ms/step
# Epoch 96/1000
#
# Epoch 96: val_loss improved from 15260.28711 to 3182.81494, saving model to tmp/ckeckpointer.ckpt
# 7/7 - 6s - loss: 625832.3125 - val_loss: 3182.8149 - 6s/epoch - 919ms/step
# Epoch 97/1000
#
# Epoch 97: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 653559.1250 - val_loss: 164908.6719 - 5s/epoch - 659ms/step
# Epoch 98/1000
#
# Epoch 98: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 614327.0625 - val_loss: 56241.8750 - 5s/epoch - 716ms/step
# Epoch 99/1000
#
# Epoch 99: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 547520.8750 - val_loss: 101941.9688 - 7s/epoch - 956ms/step
# Epoch 100/1000
#
# Epoch 100: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 692237.3750 - val_loss: 127859.7266 - 5s/epoch - 644ms/step
# Epoch 101/1000
#
# Epoch 101: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 647602.7500 - val_loss: 54186.5859 - 5s/epoch - 649ms/step
# Epoch 102/1000
#
# Epoch 102: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 550803.5625 - val_loss: 141791.9219 - 7s/epoch - 946ms/step
# Epoch 103/1000
#
# Epoch 103: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 625193.8125 - val_loss: 42584.0703 - 5s/epoch - 735ms/step
# Epoch 104/1000
#
# Epoch 104: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 648471.8750 - val_loss: 240002.8750 - 5s/epoch - 655ms/step
# Epoch 105/1000
#
# Epoch 105: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 600312.3125 - val_loss: 27560.5645 - 6s/epoch - 859ms/step
# Epoch 106/1000
#
# Epoch 106: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 565804.0625 - val_loss: 123002.2812 - 6s/epoch - 836ms/step
# Epoch 107/1000
#
# Epoch 107: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 623119.1250 - val_loss: 16823.7051 - 5s/epoch - 661ms/step
# Epoch 108/1000
#
# Epoch 108: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 640481.7500 - val_loss: 103370.3906 - 5s/epoch - 762ms/step
# Epoch 109/1000
#
# Epoch 109: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 604397.0000 - val_loss: 9656.2939 - 6s/epoch - 928ms/step
# Epoch 110/1000
#
# Epoch 110: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 704917.5000 - val_loss: 39632.5312 - 5s/epoch - 656ms/step
# Epoch 111/1000
#
# Epoch 111: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 629696.5625 - val_loss: 33951.2266 - 5s/epoch - 658ms/step
# Epoch 112/1000
#
# Epoch 112: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 603481.7500 - val_loss: 42307.0703 - 7s/epoch - 981ms/step
# Epoch 113/1000
#
# Epoch 113: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 552268.4375 - val_loss: 20611.3848 - 5s/epoch - 677ms/step
# Epoch 114/1000
#
# Epoch 114: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 633858.4375 - val_loss: 107502.8672 - 5s/epoch - 654ms/step
# Epoch 115/1000
#
# Epoch 115: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 693935.1875 - val_loss: 99960.1406 - 6s/epoch - 901ms/step
# Epoch 116/1000
#
# Epoch 116: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 625110.7500 - val_loss: 45667.8750 - 6s/epoch - 795ms/step
# Epoch 117/1000
#
# Epoch 117: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 634027.1250 - val_loss: 49063.9688 - 5s/epoch - 682ms/step
# Epoch 118/1000
#
# Epoch 118: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 596300.1875 - val_loss: 148454.8750 - 6s/epoch - 864ms/step
# Epoch 119/1000
#
# Epoch 119: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 568173.0625 - val_loss: 96402.9766 - 6s/epoch - 866ms/step
# Epoch 120/1000
#
# Epoch 120: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 557231.6875 - val_loss: 83682.8984 - 5s/epoch - 680ms/step
# Epoch 121/1000
#
# Epoch 121: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 648584.5000 - val_loss: 112962.2422 - 6s/epoch - 811ms/step
# Epoch 122/1000
#
# Epoch 122: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 631285.2500 - val_loss: 109964.6016 - 6s/epoch - 927ms/step
# Epoch 123/1000
#
# Epoch 123: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 579460.5625 - val_loss: 151715.0000 - 5s/epoch - 674ms/step
# Epoch 124/1000
#
# Epoch 124: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 665013.3750 - val_loss: 23740.0996 - 5s/epoch - 738ms/step
# Epoch 125/1000
#
# Epoch 125: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 577782.5625 - val_loss: 144133.1875 - 7s/epoch - 983ms/step
# Epoch 126/1000
#
# Epoch 126: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 587148.7500 - val_loss: 22742.7344 - 5s/epoch - 678ms/step
# Epoch 127/1000
#
# Epoch 127: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 540039.1250 - val_loss: 71223.8281 - 5s/epoch - 676ms/step
# Epoch 128/1000
#
# Epoch 128: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 554483.7500 - val_loss: 72755.9688 - 7s/epoch - 986ms/step
# Epoch 129/1000
#
# Epoch 129: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 545253.0000 - val_loss: 111123.7812 - 5s/epoch - 705ms/step
# Epoch 130/1000
#
# Epoch 130: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 588897.1250 - val_loss: 92696.3594 - 5s/epoch - 648ms/step
# Epoch 131/1000
#
# Epoch 131: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 549742.1250 - val_loss: 96966.8203 - 6s/epoch - 869ms/step
# Epoch 132/1000
#
# Epoch 132: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 558969.5000 - val_loss: 156566.0625 - 6s/epoch - 804ms/step
# Epoch 133/1000
#
# Epoch 133: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 559933.9375 - val_loss: 190164.5938 - 5s/epoch - 648ms/step
# Epoch 134/1000
#
# Epoch 134: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 559964.1875 - val_loss: 56123.8516 - 6s/epoch - 796ms/step
# Epoch 135/1000
#
# Epoch 135: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 567245.8125 - val_loss: 85288.5703 - 6s/epoch - 910ms/step
# Epoch 136/1000
#
# Epoch 136: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 600610.3750 - val_loss: 73683.2891 - 5s/epoch - 644ms/step
# Epoch 137/1000
#
# Epoch 137: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 562475.2500 - val_loss: 50917.5000 - 5s/epoch - 682ms/step
# Epoch 138/1000
#
# Epoch 138: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 614654.0000 - val_loss: 123329.2266 - 7s/epoch - 1s/step
# Epoch 139/1000
#
# Epoch 139: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 576169.1250 - val_loss: 49229.1992 - 5s/epoch - 685ms/step
# Epoch 140/1000
#
# Epoch 140: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 547180.3750 - val_loss: 147603.0156 - 5s/epoch - 681ms/step
# Epoch 141/1000
#
# Epoch 141: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 594506.1250 - val_loss: 25726.2207 - 7s/epoch - 978ms/step
# Epoch 142/1000
#
# Epoch 142: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 581013.6875 - val_loss: 234672.9531 - 5s/epoch - 713ms/step
# Epoch 143/1000
#
# Epoch 143: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 603297.3125 - val_loss: 37168.0586 - 5s/epoch - 647ms/step
# Epoch 144/1000
#
# Epoch 144: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 613485.6250 - val_loss: 90471.5391 - 6s/epoch - 898ms/step
# Epoch 145/1000
#
# Epoch 145: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 580807.6875 - val_loss: 21645.4727 - 6s/epoch - 821ms/step
# Epoch 146/1000
#
# Epoch 146: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 537981.0625 - val_loss: 123067.6094 - 5s/epoch - 668ms/step
# Epoch 147/1000
#
# Epoch 147: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 539143.1875 - val_loss: 50780.7305 - 6s/epoch - 808ms/step
# Epoch 148/1000
#
# Epoch 148: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 599132.1250 - val_loss: 124129.1562 - 6s/epoch - 866ms/step
# Epoch 149/1000
#
# Epoch 149: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 532712.3125 - val_loss: 41588.5391 - 5s/epoch - 662ms/step
# Epoch 150/1000
#
# Epoch 150: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 599096.6875 - val_loss: 49759.2383 - 5s/epoch - 703ms/step
# Epoch 151/1000
#
# Epoch 151: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 579745.8125 - val_loss: 158770.7656 - 7s/epoch - 972ms/step
# Epoch 152/1000
#
# Epoch 152: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 571145.8125 - val_loss: 72527.8672 - 5s/epoch - 645ms/step
# Epoch 153/1000
#
# Epoch 153: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 572798.2500 - val_loss: 55468.3359 - 5s/epoch - 652ms/step
# Epoch 154/1000
#
# Epoch 154: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 582736.3750 - val_loss: 74738.7734 - 7s/epoch - 938ms/step
# Epoch 155/1000
#
# Epoch 155: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 622719.5625 - val_loss: 21669.0547 - 5s/epoch - 737ms/step
# Epoch 156/1000
#
# Epoch 156: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 527068.4375 - val_loss: 139409.0938 - 5s/epoch - 651ms/step
# Epoch 157/1000
#
# Epoch 157: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 573365.3125 - val_loss: 54659.3594 - 6s/epoch - 843ms/step
# Epoch 158/1000
#
# Epoch 158: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 544771.5625 - val_loss: 104103.5781 - 6s/epoch - 872ms/step
# Epoch 159/1000
#
# Epoch 159: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 575357.5625 - val_loss: 105010.8203 - 5s/epoch - 670ms/step
# Epoch 160/1000
#
# Epoch 160: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 596118.2500 - val_loss: 55301.9102 - 5s/epoch - 738ms/step
# Epoch 161/1000
#
# Epoch 161: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 627259.6875 - val_loss: 84443.0234 - 6s/epoch - 917ms/step
# Epoch 162/1000
#
# Epoch 162: val_loss did not improve from 3182.81494
# 7/7 - 4s - loss: 624638.3125 - val_loss: 63524.4141 - 4s/epoch - 639ms/step
# Epoch 163/1000
#
# Epoch 163: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 566590.7500 - val_loss: 75598.2109 - 5s/epoch - 649ms/step
# Epoch 164/1000
#
# Epoch 164: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 626796.8750 - val_loss: 73999.6328 - 7s/epoch - 962ms/step
# Epoch 165/1000
#
# Epoch 165: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 490082.8750 - val_loss: 71698.8672 - 5s/epoch - 733ms/step
# Epoch 166/1000
#
# Epoch 166: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 532243.0000 - val_loss: 51924.8711 - 5s/epoch - 669ms/step
# Epoch 167/1000
#
# Epoch 167: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 579564.6875 - val_loss: 40070.8555 - 6s/epoch - 886ms/step
# Epoch 168/1000
#
# Epoch 168: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 578609.2500 - val_loss: 90297.8906 - 5s/epoch - 777ms/step
# Epoch 169/1000
#
# Epoch 169: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 534578.8125 - val_loss: 61177.1133 - 5s/epoch - 656ms/step
# Epoch 170/1000
#
# Epoch 170: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 558467.6250 - val_loss: 105943.3125 - 6s/epoch - 813ms/step
# Epoch 171/1000
#
# Epoch 171: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 526931.0000 - val_loss: 73565.4688 - 6s/epoch - 895ms/step
# Epoch 172/1000
#
# Epoch 172: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 565956.0625 - val_loss: 92311.7578 - 5s/epoch - 657ms/step
# Epoch 173/1000
#
# Epoch 173: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 537990.1250 - val_loss: 90545.7578 - 5s/epoch - 734ms/step
# Epoch 174/1000
#
# Epoch 174: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 622692.0625 - val_loss: 130088.3516 - 7s/epoch - 980ms/step
# Epoch 175/1000
#
# Epoch 175: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 598803.2500 - val_loss: 84417.1016 - 5s/epoch - 674ms/step
# Epoch 176/1000
#
# Epoch 176: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 519684.0625 - val_loss: 61513.9688 - 5s/epoch - 675ms/step
# Epoch 177/1000
#
# Epoch 177: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 569647.1250 - val_loss: 106348.4766 - 7s/epoch - 996ms/step
# Epoch 178/1000
#
# Epoch 178: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 561041.6875 - val_loss: 83390.6172 - 5s/epoch - 709ms/step
# Epoch 179/1000
#
# Epoch 179: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 575086.5000 - val_loss: 105202.8125 - 5s/epoch - 672ms/step
# Epoch 180/1000
#
# Epoch 180: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 566442.6250 - val_loss: 80244.4844 - 6s/epoch - 907ms/step
# Epoch 181/1000
#
# Epoch 181: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 533488.8125 - val_loss: 92116.9766 - 5s/epoch - 760ms/step
# Epoch 182/1000
#
# Epoch 182: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 562137.0000 - val_loss: 59989.4102 - 5s/epoch - 653ms/step
# Epoch 183/1000
#
# Epoch 183: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 541872.8125 - val_loss: 115047.9375 - 6s/epoch - 838ms/step
# Epoch 184/1000
#
# Epoch 184: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 544711.6875 - val_loss: 52340.6211 - 6s/epoch - 861ms/step
# Epoch 185/1000
#
# Epoch 185: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 518565.6875 - val_loss: 103229.6797 - 5s/epoch - 671ms/step
# Epoch 186/1000
#
# Epoch 186: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 582302.8125 - val_loss: 29931.5820 - 5s/epoch - 758ms/step
# Epoch 187/1000
#
# Epoch 187: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 569825.0000 - val_loss: 89853.4297 - 7s/epoch - 960ms/step
# Epoch 188/1000
#
# Epoch 188: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 578056.8750 - val_loss: 63805.4883 - 5s/epoch - 690ms/step
# Epoch 189/1000
#
# Epoch 189: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 502633.3125 - val_loss: 89131.0703 - 5s/epoch - 697ms/step
# Epoch 190/1000
#
# Epoch 190: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 511327.7812 - val_loss: 52050.1914 - 7s/epoch - 1s/step
# Epoch 191/1000
#
# Epoch 191: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 544818.8125 - val_loss: 80487.5234 - 5s/epoch - 687ms/step
# Epoch 192/1000
#
# Epoch 192: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 557222.6250 - val_loss: 126936.2578 - 5s/epoch - 688ms/step
# Epoch 193/1000
#
# Epoch 193: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 503479.5625 - val_loss: 56781.4336 - 7s/epoch - 1s/step
# Epoch 194/1000
#
# Epoch 194: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 526613.5000 - val_loss: 93297.9688 - 5s/epoch - 723ms/step
# Epoch 195/1000
#
# Epoch 195: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 581821.5000 - val_loss: 46965.9805 - 5s/epoch - 671ms/step
# Epoch 196/1000
#
# Epoch 196: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 549503.0000 - val_loss: 120389.4219 - 6s/epoch - 923ms/step
# Epoch 197/1000
#
# Epoch 197: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 612441.2500 - val_loss: 63772.0938 - 6s/epoch - 807ms/step
# Epoch 198/1000
#
# Epoch 198: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 581319.8125 - val_loss: 51907.1719 - 5s/epoch - 668ms/step
# Epoch 199/1000
#
# Epoch 199: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 524773.2500 - val_loss: 46906.7500 - 6s/epoch - 847ms/step
# Epoch 200/1000
#
# Epoch 200: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 544093.4375 - val_loss: 38798.9531 - 6s/epoch - 852ms/step
# Epoch 201/1000
#
# Epoch 201: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 578198.7500 - val_loss: 113053.1328 - 5s/epoch - 677ms/step
# Epoch 202/1000
#
# Epoch 202: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 543842.3125 - val_loss: 41520.1289 - 6s/epoch - 789ms/step
# Epoch 203/1000
#
# Epoch 203: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 580324.8125 - val_loss: 74729.2422 - 7s/epoch - 930ms/step
# Epoch 204/1000
#
# Epoch 204: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 477502.8750 - val_loss: 152762.0938 - 5s/epoch - 686ms/step
# Epoch 205/1000
#
# Epoch 205: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 530410.0625 - val_loss: 55236.7500 - 5s/epoch - 755ms/step
# Epoch 206/1000
#
# Epoch 206: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 602618.6875 - val_loss: 235340.4375 - 7s/epoch - 978ms/step
# Epoch 207/1000
#
# Epoch 207: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 637803.7500 - val_loss: 30741.5156 - 5s/epoch - 689ms/step
# Epoch 208/1000
#
# Epoch 208: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 623277.8125 - val_loss: 140874.4062 - 5s/epoch - 712ms/step
# Epoch 209/1000
#
# Epoch 209: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 584273.5625 - val_loss: 40811.1367 - 7s/epoch - 1s/step
# Epoch 210/1000
#
# Epoch 210: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 587769.0625 - val_loss: 37748.0703 - 5s/epoch - 689ms/step
# Epoch 211/1000
#
# Epoch 211: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 508718.6875 - val_loss: 126656.8516 - 5s/epoch - 656ms/step
# Epoch 212/1000
#
# Epoch 212: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 569438.8750 - val_loss: 21907.8984 - 6s/epoch - 926ms/step
# Epoch 213/1000
#
# Epoch 213: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 589705.6250 - val_loss: 182475.9062 - 5s/epoch - 758ms/step
# Epoch 214/1000
#
# Epoch 214: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 584381.5000 - val_loss: 35954.9141 - 5s/epoch - 700ms/step
# Epoch 215/1000
#
# Epoch 215: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 505077.3125 - val_loss: 62094.8359 - 6s/epoch - 836ms/step
# Epoch 216/1000
#
# Epoch 216: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 505814.9688 - val_loss: 58482.2109 - 6s/epoch - 814ms/step
# Epoch 217/1000
#
# Epoch 217: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 560082.9375 - val_loss: 43200.8086 - 5s/epoch - 644ms/step
# Epoch 218/1000
#
# Epoch 218: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 517888.3125 - val_loss: 105474.1484 - 6s/epoch - 807ms/step
# Epoch 219/1000
#
# Epoch 219: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 541943.8750 - val_loss: 37927.6406 - 7s/epoch - 949ms/step
# Epoch 220/1000
#
# Epoch 220: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 586597.5000 - val_loss: 167551.6719 - 5s/epoch - 692ms/step
# Epoch 221/1000
#
# Epoch 221: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 545009.5000 - val_loss: 6178.1191 - 5s/epoch - 749ms/step
# Epoch 222/1000
#
# Epoch 222: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 591529.5000 - val_loss: 98290.5938 - 7s/epoch - 976ms/step
# Epoch 223/1000
#
# Epoch 223: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 513596.0312 - val_loss: 51500.9844 - 5s/epoch - 653ms/step
# Epoch 224/1000
#
# Epoch 224: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 606343.6250 - val_loss: 65724.6172 - 5s/epoch - 652ms/step
# Epoch 225/1000
#
# Epoch 225: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 540991.1875 - val_loss: 105040.5703 - 7s/epoch - 937ms/step
# Epoch 226/1000
#
# Epoch 226: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 581123.6250 - val_loss: 65987.0703 - 5s/epoch - 751ms/step
# Epoch 227/1000
#
# Epoch 227: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 593008.5000 - val_loss: 105648.6172 - 5s/epoch - 662ms/step
# Epoch 228/1000
#
# Epoch 228: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 610364.7500 - val_loss: 56671.5117 - 6s/epoch - 848ms/step
# Epoch 229/1000
#
# Epoch 229: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 533226.9375 - val_loss: 44690.9805 - 6s/epoch - 846ms/step
# Epoch 230/1000
#
# Epoch 230: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 528504.6875 - val_loss: 52336.4609 - 5s/epoch - 665ms/step
# Epoch 231/1000
#
# Epoch 231: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 566195.8750 - val_loss: 47635.6719 - 5s/epoch - 771ms/step
# Epoch 232/1000
#
# Epoch 232: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 535025.3125 - val_loss: 53003.4062 - 7s/epoch - 940ms/step
# Epoch 233/1000
#
# Epoch 233: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 548430.5625 - val_loss: 91663.3828 - 5s/epoch - 682ms/step
# Epoch 234/1000
#
# Epoch 234: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 528689.0625 - val_loss: 74426.7266 - 5s/epoch - 718ms/step
# Epoch 235/1000
#
# Epoch 235: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 584384.1250 - val_loss: 103072.6094 - 7s/epoch - 982ms/step
# Epoch 236/1000
#
# Epoch 236: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 507144.5312 - val_loss: 38157.2305 - 5s/epoch - 647ms/step
# Epoch 237/1000
#
# Epoch 237: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 580339.3750 - val_loss: 124362.9688 - 5s/epoch - 667ms/step
# Epoch 238/1000
#
# Epoch 238: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 504391.1562 - val_loss: 16762.9824 - 6s/epoch - 928ms/step
# Epoch 239/1000
#
# Epoch 239: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 488591.5938 - val_loss: 133533.3906 - 5s/epoch - 759ms/step
# Epoch 240/1000
#
# Epoch 240: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 562294.2500 - val_loss: 33900.3359 - 5s/epoch - 669ms/step
# Epoch 241/1000
#
# Epoch 241: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 607863.8750 - val_loss: 62907.7891 - 6s/epoch - 854ms/step
# Epoch 242/1000
#
# Epoch 242: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 505195.7812 - val_loss: 44495.8906 - 6s/epoch - 837ms/step
# Epoch 243/1000
#
# Epoch 243: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 591640.0625 - val_loss: 112976.7188 - 5s/epoch - 652ms/step
# Epoch 244/1000
#
# Epoch 244: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 576494.2500 - val_loss: 63168.9258 - 5s/epoch - 729ms/step
# Epoch 245/1000
#
# Epoch 245: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 541546.8750 - val_loss: 150382.4062 - 7s/epoch - 942ms/step
# Epoch 246/1000
#
# Epoch 246: val_loss did not improve from 3182.81494
# 7/7 - 4s - loss: 567364.0625 - val_loss: 86139.2734 - 4s/epoch - 640ms/step
# Epoch 247/1000
#
# Epoch 247: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 508873.0938 - val_loss: 62001.9062 - 5s/epoch - 651ms/step
# Epoch 248/1000
#
# Epoch 248: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 572488.0625 - val_loss: 100601.2578 - 7s/epoch - 957ms/step
# Epoch 249/1000
#
# Epoch 249: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 526870.6250 - val_loss: 60727.6289 - 5s/epoch - 743ms/step
# Epoch 250/1000
#
# Epoch 250: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 571400.4375 - val_loss: 76879.5703 - 5s/epoch - 674ms/step
# Epoch 251/1000
#
# Epoch 251: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 540278.1875 - val_loss: 38503.3398 - 6s/epoch - 897ms/step
# Epoch 252/1000
#
# Epoch 252: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 527478.6875 - val_loss: 16466.4023 - 6s/epoch - 815ms/step
# Epoch 253/1000
#
# Epoch 253: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 615227.7500 - val_loss: 7609.3521 - 5s/epoch - 687ms/step
# Epoch 254/1000
#
# Epoch 254: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 533816.5625 - val_loss: 17204.6816 - 6s/epoch - 843ms/step
# Epoch 255/1000
#
# Epoch 255: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 556353.5000 - val_loss: 21125.9004 - 6s/epoch - 889ms/step
# Epoch 256/1000
#
# Epoch 256: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 531802.9375 - val_loss: 16382.9727 - 5s/epoch - 676ms/step
# Epoch 257/1000
#
# Epoch 257: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 595090.8125 - val_loss: 28114.3477 - 6s/epoch - 825ms/step
# Epoch 258/1000
#
# Epoch 258: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 561141.8125 - val_loss: 35281.5977 - 7s/epoch - 935ms/step
# Epoch 259/1000
#
# Epoch 259: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 517310.4062 - val_loss: 27750.8770 - 5s/epoch - 666ms/step
# Epoch 260/1000
#
# Epoch 260: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 507964.9375 - val_loss: 43756.4688 - 5s/epoch - 709ms/step
# Epoch 261/1000
#
# Epoch 261: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 527379.3750 - val_loss: 24369.8105 - 7s/epoch - 971ms/step
# Epoch 262/1000
#
# Epoch 262: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 565867.5625 - val_loss: 22638.3477 - 5s/epoch - 661ms/step
# Epoch 263/1000
#
# Epoch 263: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 475079.2812 - val_loss: 21641.0527 - 5s/epoch - 647ms/step
# Epoch 264/1000
#
# Epoch 264: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 528086.5625 - val_loss: 21165.4922 - 7s/epoch - 982ms/step
# Epoch 265/1000
#
# Epoch 265: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 601838.5000 - val_loss: 24794.3633 - 6s/epoch - 854ms/step
# Epoch 266/1000
#
# Epoch 266: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 551419.0625 - val_loss: 4682.7324 - 5s/epoch - 662ms/step
# Epoch 267/1000
#
# Epoch 267: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 563689.1250 - val_loss: 42152.4062 - 6s/epoch - 898ms/step
# Epoch 268/1000
#
# Epoch 268: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 552722.7500 - val_loss: 29431.6992 - 6s/epoch - 833ms/step
# Epoch 269/1000
#
# Epoch 269: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 542734.3750 - val_loss: 30694.9395 - 5s/epoch - 658ms/step
# Epoch 270/1000
#
# Epoch 270: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 526899.2500 - val_loss: 48044.4336 - 6s/epoch - 792ms/step
# Epoch 271/1000
#
# Epoch 271: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 536116.1875 - val_loss: 38353.3945 - 6s/epoch - 886ms/step
# Epoch 272/1000
#
# Epoch 272: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 580220.8125 - val_loss: 38019.5312 - 5s/epoch - 653ms/step
# Epoch 273/1000
#
# Epoch 273: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 507391.1562 - val_loss: 19034.3848 - 5s/epoch - 728ms/step
# Epoch 274/1000
#
# Epoch 274: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 508051.4375 - val_loss: 53613.0781 - 7s/epoch - 963ms/step
# Epoch 275/1000
#
# Epoch 275: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 604820.8125 - val_loss: 20028.6230 - 5s/epoch - 670ms/step
# Epoch 276/1000
#
# Epoch 276: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 537505.6875 - val_loss: 12264.3760 - 5s/epoch - 661ms/step
# Epoch 277/1000
#
# Epoch 277: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 592292.0625 - val_loss: 18098.4453 - 7s/epoch - 977ms/step
# Epoch 278/1000
#
# Epoch 278: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 524801.5625 - val_loss: 45484.0938 - 5s/epoch - 731ms/step
# Epoch 279/1000
#
# Epoch 279: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 588084.0625 - val_loss: 22003.7441 - 5s/epoch - 676ms/step
# Epoch 280/1000
#
# Epoch 280: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 437052.2812 - val_loss: 65965.0469 - 6s/epoch - 899ms/step
# Epoch 281/1000
#
# Epoch 281: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 599465.8125 - val_loss: 51521.6094 - 6s/epoch - 806ms/step
# Epoch 282/1000
#
# Epoch 282: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 573982.0000 - val_loss: 94059.6328 - 5s/epoch - 671ms/step
# Epoch 283/1000
#
# Epoch 283: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 523437.7812 - val_loss: 43465.8164 - 6s/epoch - 858ms/step
# Epoch 284/1000
#
# Epoch 284: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 526106.4375 - val_loss: 77628.6094 - 6s/epoch - 855ms/step
# Epoch 285/1000
#
# Epoch 285: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 533398.2500 - val_loss: 28589.0859 - 5s/epoch - 665ms/step
# Epoch 286/1000
#
# Epoch 286: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 611965.3125 - val_loss: 36601.4922 - 5s/epoch - 750ms/step
# Epoch 287/1000
#
# Epoch 287: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 510897.6562 - val_loss: 27222.5273 - 7s/epoch - 938ms/step
# Epoch 288/1000
#
# Epoch 288: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 561629.0625 - val_loss: 80036.3828 - 5s/epoch - 656ms/step
# Epoch 289/1000
#
# Epoch 289: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 520197.1562 - val_loss: 22765.3125 - 5s/epoch - 647ms/step
# Epoch 290/1000
#
# Epoch 290: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 581940.9375 - val_loss: 39734.8516 - 7s/epoch - 999ms/step
# Epoch 291/1000
#
# Epoch 291: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 529553.2500 - val_loss: 17200.8438 - 5s/epoch - 687ms/step
# Epoch 292/1000
#
# Epoch 292: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 538599.8750 - val_loss: 29632.6992 - 5s/epoch - 664ms/step
# Epoch 293/1000
#
# Epoch 293: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 467617.7188 - val_loss: 76717.7344 - 6s/epoch - 925ms/step
# Epoch 294/1000
#
# Epoch 294: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 518642.6562 - val_loss: 11204.0713 - 5s/epoch - 781ms/step
# Epoch 295/1000
#
# Epoch 295: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 544307.8125 - val_loss: 54582.3203 - 5s/epoch - 666ms/step
# Epoch 296/1000
#
# Epoch 296: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 546780.7500 - val_loss: 33813.7266 - 6s/epoch - 847ms/step
# Epoch 297/1000
#
# Epoch 297: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 501571.0312 - val_loss: 113383.9922 - 6s/epoch - 870ms/step
# Epoch 298/1000
#
# Epoch 298: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 467071.5000 - val_loss: 40231.6406 - 5s/epoch - 651ms/step
# Epoch 299/1000
#
# Epoch 299: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 569783.6875 - val_loss: 46054.5508 - 5s/epoch - 727ms/step
# Epoch 300/1000
#
# Epoch 300: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 556947.1875 - val_loss: 16592.6250 - 7s/epoch - 944ms/step
# Epoch 301/1000
#
# Epoch 301: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 506726.3438 - val_loss: 51282.6289 - 5s/epoch - 662ms/step
# Epoch 302/1000
#
# Epoch 302: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 578579.2500 - val_loss: 15443.7803 - 5s/epoch - 659ms/step
# Epoch 303/1000
#
# Epoch 303: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 515765.7812 - val_loss: 91769.7734 - 7s/epoch - 965ms/step
# Epoch 304/1000
#
# Epoch 304: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 576869.8125 - val_loss: 25129.0156 - 5s/epoch - 721ms/step
# Epoch 305/1000
#
# Epoch 305: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 517050.6562 - val_loss: 107604.1016 - 5s/epoch - 690ms/step
# Epoch 306/1000
#
# Epoch 306: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 558772.0625 - val_loss: 16950.6406 - 7s/epoch - 930ms/step
# Epoch 307/1000
#
# Epoch 307: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 548842.6250 - val_loss: 66973.8281 - 6s/epoch - 807ms/step
# Epoch 308/1000
#
# Epoch 308: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 548632.7500 - val_loss: 24635.0527 - 5s/epoch - 677ms/step
# Epoch 309/1000
#
# Epoch 309: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 584440.7500 - val_loss: 19188.1191 - 6s/epoch - 890ms/step
# Epoch 310/1000
#
# Epoch 310: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 491620.1875 - val_loss: 60860.0703 - 6s/epoch - 836ms/step
# Epoch 311/1000
#
# Epoch 311: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 528101.3125 - val_loss: 59285.9062 - 5s/epoch - 690ms/step
# Epoch 312/1000
#
# Epoch 312: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 509875.1562 - val_loss: 52565.2891 - 6s/epoch - 858ms/step
# Epoch 313/1000
#
# Epoch 313: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 590172.6250 - val_loss: 42392.0664 - 6s/epoch - 900ms/step
# Epoch 314/1000
#
# Epoch 314: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 463693.1875 - val_loss: 17719.7598 - 5s/epoch - 684ms/step
# ...
# 7/7 - 6s - loss: 460650.5625 - val_loss: 62977.0664 - 6s/epoch - 809ms/step
# Epoch 892/1000
#
# Epoch 892: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 456458.5312 - val_loss: 66148.2812 - 6s/epoch - 880ms/step
# Epoch 893/1000
#
# Epoch 893: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 452679.9062 - val_loss: 24229.4883 - 5s/epoch - 652ms/step
# Epoch 894/1000
#
# Epoch 894: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 430524.5000 - val_loss: 51441.4883 - 5s/epoch - 739ms/step
# Epoch 895/1000
#
# Epoch 895: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 423185.4062 - val_loss: 66729.2031 - 7s/epoch - 989ms/step
# Epoch 896/1000
#
# Epoch 896: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 419241.0000 - val_loss: 23941.5449 - 5s/epoch - 657ms/step
# Epoch 897/1000
#
# Epoch 897: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 419505.0938 - val_loss: 61553.3242 - 5s/epoch - 656ms/step
# Epoch 898/1000
#
# Epoch 898: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 455512.3750 - val_loss: 37724.4062 - 7s/epoch - 942ms/step
# Epoch 899/1000
#
# Epoch 899: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 451477.5625 - val_loss: 49831.4258 - 5s/epoch - 744ms/step
# Epoch 900/1000
#
# Epoch 900: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 436075.7500 - val_loss: 68601.8672 - 5s/epoch - 689ms/step
# Epoch 901/1000
#
# Epoch 901: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 472875.3438 - val_loss: 42588.9609 - 6s/epoch - 915ms/step
# Epoch 902/1000
#
# Epoch 902: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 420825.5000 - val_loss: 43713.4766 - 6s/epoch - 813ms/step
# Epoch 903/1000
#
# Epoch 903: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 413351.5625 - val_loss: 45625.9414 - 5s/epoch - 679ms/step
# Epoch 904/1000
#
# Epoch 904: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 411000.5625 - val_loss: 73369.3438 - 6s/epoch - 870ms/step
# Epoch 905/1000
#
# Epoch 905: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 403925.6250 - val_loss: 83039.8516 - 6s/epoch - 880ms/step
# Epoch 906/1000
#
# Epoch 906: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 443943.6250 - val_loss: 30982.9766 - 5s/epoch - 691ms/step
# Epoch 907/1000
#
# Epoch 907: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 445863.2188 - val_loss: 22066.6973 - 6s/epoch - 822ms/step
# Epoch 908/1000
#
# Epoch 908: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 431143.9375 - val_loss: 43426.0586 - 6s/epoch - 907ms/step
# Epoch 909/1000
#
# Epoch 909: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 440557.7812 - val_loss: 79732.8281 - 5s/epoch - 685ms/step
# Epoch 910/1000
#
# Epoch 910: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 514969.7812 - val_loss: 36123.0508 - 5s/epoch - 780ms/step
# Epoch 911/1000
#
# Epoch 911: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 444402.4062 - val_loss: 70982.0938 - 7s/epoch - 954ms/step
# Epoch 912/1000
#
# Epoch 912: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 394471.0000 - val_loss: 54369.3164 - 5s/epoch - 653ms/step
# Epoch 913/1000
#
# Epoch 913: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 433548.0625 - val_loss: 55524.0156 - 5s/epoch - 667ms/step
# Epoch 914/1000
#
# Epoch 914: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 398710.8438 - val_loss: 28869.8066 - 7s/epoch - 1s/step
# Epoch 915/1000
#
# Epoch 915: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 438401.1875 - val_loss: 61587.6719 - 5s/epoch - 700ms/step
# Epoch 916/1000
#
# Epoch 916: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 444496.7812 - val_loss: 41504.8633 - 5s/epoch - 697ms/step
# Epoch 917/1000
#
# Epoch 917: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 475954.0625 - val_loss: 24852.4668 - 7s/epoch - 975ms/step
# Epoch 918/1000
#
# Epoch 918: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 395435.2812 - val_loss: 31390.2969 - 5s/epoch - 778ms/step
# Epoch 919/1000
#
# Epoch 919: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 436151.4375 - val_loss: 19850.0508 - 5s/epoch - 681ms/step
# Epoch 920/1000
#
# Epoch 920: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 415549.4688 - val_loss: 33172.6094 - 6s/epoch - 910ms/step
# Epoch 921/1000
#
# Epoch 921: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 386141.8438 - val_loss: 33013.4062 - 6s/epoch - 835ms/step
# Epoch 922/1000
#
# Epoch 922: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 439568.8438 - val_loss: 44783.3438 - 5s/epoch - 664ms/step
# Epoch 923/1000
#
# Epoch 923: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 399519.4688 - val_loss: 21855.2734 - 6s/epoch - 818ms/step
# Epoch 924/1000
#
# Epoch 924: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 407454.3438 - val_loss: 42397.5586 - 6s/epoch - 893ms/step
# Epoch 925/1000
#
# Epoch 925: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 430571.5312 - val_loss: 19391.5547 - 5s/epoch - 669ms/step
# Epoch 926/1000
#
# Epoch 926: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 417348.2812 - val_loss: 33578.5664 - 5s/epoch - 748ms/step
# Epoch 927/1000
#
# Epoch 927: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 461690.2188 - val_loss: 35703.5156 - 7s/epoch - 959ms/step
# Epoch 928/1000
#
# Epoch 928: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 402726.6875 - val_loss: 56864.8359 - 5s/epoch - 663ms/step
# Epoch 929/1000
#
# Epoch 929: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 448161.8125 - val_loss: 52673.0664 - 5s/epoch - 667ms/step
# Epoch 930/1000
#
# Epoch 930: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 396950.5625 - val_loss: 49902.7734 - 7s/epoch - 991ms/step
# Epoch 931/1000
#
# Epoch 931: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 437536.7812 - val_loss: 25937.7344 - 5s/epoch - 714ms/step
# Epoch 932/1000
#
# Epoch 932: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 426111.4688 - val_loss: 28503.0859 - 5s/epoch - 697ms/step
# Epoch 933/1000
#
# Epoch 933: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 393773.3125 - val_loss: 22554.7051 - 7s/epoch - 965ms/step
# Epoch 934/1000
#
# Epoch 934: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 439111.2188 - val_loss: 44174.4219 - 5s/epoch - 784ms/step
# Epoch 935/1000
#
# Epoch 935: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 483974.5000 - val_loss: 28179.0293 - 5s/epoch - 698ms/step
# Epoch 936/1000
#
# Epoch 936: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 405166.5312 - val_loss: 74029.8984 - 6s/epoch - 919ms/step
# Epoch 937/1000
#
# Epoch 937: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 446488.6875 - val_loss: 52113.7656 - 6s/epoch - 829ms/step
# Epoch 938/1000
#
# Epoch 938: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 404284.7812 - val_loss: 21451.6621 - 5s/epoch - 685ms/step
# Epoch 939/1000
#
# Epoch 939: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 413511.7188 - val_loss: 31169.9180 - 6s/epoch - 832ms/step
# Epoch 940/1000
#
# Epoch 940: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 417028.4062 - val_loss: 45610.5195 - 6s/epoch - 876ms/step
# Epoch 941/1000
#
# Epoch 941: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 421992.2500 - val_loss: 66474.6172 - 5s/epoch - 682ms/step
# Epoch 942/1000
#
# Epoch 942: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 438253.9688 - val_loss: 14967.6484 - 6s/epoch - 810ms/step
# Epoch 943/1000
#
# Epoch 943: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 346709.3438 - val_loss: 63903.5000 - 6s/epoch - 906ms/step
# Epoch 944/1000
#
# Epoch 944: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 481082.2188 - val_loss: 28983.4121 - 5s/epoch - 658ms/step
# Epoch 945/1000
#
# Epoch 945: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 446021.9688 - val_loss: 44001.6562 - 5s/epoch - 689ms/step
# Epoch 946/1000
#
# Epoch 946: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 445197.9688 - val_loss: 56707.5469 - 7s/epoch - 1s/step
# Epoch 947/1000
#
# Epoch 947: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 401878.8750 - val_loss: 26592.8809 - 5s/epoch - 662ms/step
# Epoch 948/1000
#
# Epoch 948: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 434679.9688 - val_loss: 49362.4453 - 5s/epoch - 664ms/step
# Epoch 949/1000
#
# Epoch 949: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 426877.3750 - val_loss: 18131.7598 - 7s/epoch - 951ms/step
# Epoch 950/1000
#
# Epoch 950: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 436113.3125 - val_loss: 21569.7266 - 5s/epoch - 743ms/step
# Epoch 951/1000
#
# Epoch 951: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 412431.5625 - val_loss: 49047.4219 - 5s/epoch - 660ms/step
# Epoch 952/1000
#
# Epoch 952: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 410453.8438 - val_loss: 27911.1973 - 6s/epoch - 855ms/step
# Epoch 953/1000
#
# Epoch 953: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 465375.9062 - val_loss: 61121.6133 - 6s/epoch - 837ms/step
# Epoch 954/1000
#
# Epoch 954: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 416854.5000 - val_loss: 60094.2109 - 5s/epoch - 688ms/step
# Epoch 955/1000
#
# Epoch 955: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 456538.5312 - val_loss: 37929.1055 - 6s/epoch - 821ms/step
# Epoch 956/1000
#
# Epoch 956: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 436789.6562 - val_loss: 37697.4688 - 6s/epoch - 901ms/step
# Epoch 957/1000
#
# Epoch 957: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 465559.9375 - val_loss: 21573.4375 - 5s/epoch - 661ms/step
# Epoch 958/1000
#
# Epoch 958: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 396536.4062 - val_loss: 35424.8438 - 5s/epoch - 690ms/step
# Epoch 959/1000
#
# Epoch 959: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 382707.1562 - val_loss: 18903.2344 - 7s/epoch - 997ms/step
# Epoch 960/1000
#
# Epoch 960: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 464082.7500 - val_loss: 42700.4609 - 5s/epoch - 663ms/step
# Epoch 961/1000
#
# Epoch 961: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 508060.7188 - val_loss: 45113.8594 - 5s/epoch - 661ms/step
# Epoch 962/1000
#
# Epoch 962: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 410020.7812 - val_loss: 41051.3594 - 7s/epoch - 975ms/step
# Epoch 963/1000
#
# Epoch 963: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 394118.8125 - val_loss: 69279.2969 - 5s/epoch - 782ms/step
# Epoch 964/1000
#
# Epoch 964: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 429798.2188 - val_loss: 53898.1211 - 5s/epoch - 694ms/step
# Epoch 965/1000
#
# Epoch 965: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 464484.3125 - val_loss: 31871.2109 - 7s/epoch - 976ms/step
# Epoch 966/1000
#
# Epoch 966: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 397584.7188 - val_loss: 45883.8633 - 5s/epoch - 757ms/step
# Epoch 967/1000
#
# Epoch 967: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 490650.0938 - val_loss: 10697.3574 - 5s/epoch - 673ms/step
# Epoch 968/1000
#
# Epoch 968: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 387156.4062 - val_loss: 73782.8438 - 6s/epoch - 889ms/step
# Epoch 969/1000
#
# Epoch 969: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 423571.0938 - val_loss: 37885.2930 - 6s/epoch - 824ms/step
# Epoch 970/1000
#
# Epoch 970: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 443763.5000 - val_loss: 41346.7227 - 5s/epoch - 682ms/step
# Epoch 971/1000
#
# Epoch 971: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 372876.6250 - val_loss: 74088.3906 - 6s/epoch - 806ms/step
# Epoch 972/1000
#
# Epoch 972: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 400753.0312 - val_loss: 18468.3594 - 6s/epoch - 899ms/step
# Epoch 973/1000
#
# Epoch 973: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 474629.7188 - val_loss: 61792.4531 - 5s/epoch - 665ms/step
# Epoch 974/1000
#
# Epoch 974: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 406048.0938 - val_loss: 23885.0332 - 5s/epoch - 702ms/step
# Epoch 975/1000
#
# Epoch 975: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 433721.7188 - val_loss: 46647.0898 - 7s/epoch - 1s/step
# Epoch 976/1000
#
# Epoch 976: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 393806.5625 - val_loss: 39522.9883 - 5s/epoch - 677ms/step
# Epoch 977/1000
#
# Epoch 977: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 442613.6562 - val_loss: 25848.8750 - 5s/epoch - 673ms/step
# Epoch 978/1000
#
# Epoch 978: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 443659.7188 - val_loss: 52793.5898 - 7s/epoch - 973ms/step
# Epoch 979/1000
#
# Epoch 979: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 422648.7812 - val_loss: 23363.6543 - 5s/epoch - 748ms/step
# Epoch 980/1000
#
# Epoch 980: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 396041.6875 - val_loss: 23629.6152 - 5s/epoch - 671ms/step
# Epoch 981/1000
#
# Epoch 981: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 407442.4375 - val_loss: 28403.4395 - 6s/epoch - 888ms/step
# Epoch 982/1000
#
# Epoch 982: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 434686.1250 - val_loss: 24206.2930 - 6s/epoch - 843ms/step
# Epoch 983/1000
#
# Epoch 983: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 463515.8438 - val_loss: 54372.3867 - 5s/epoch - 680ms/step
# Epoch 984/1000
#
# Epoch 984: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 432095.3750 - val_loss: 58788.3906 - 6s/epoch - 823ms/step
# Epoch 985/1000
#
# Epoch 985: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 464084.0312 - val_loss: 19432.5918 - 6s/epoch - 889ms/step
# Epoch 986/1000
#
# Epoch 986: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 436589.8125 - val_loss: 39105.7539 - 5s/epoch - 671ms/step
# Epoch 987/1000
#
# Epoch 987: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 420531.3438 - val_loss: 27648.7266 - 5s/epoch - 770ms/step
# Epoch 988/1000
#
# Epoch 988: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 469121.6250 - val_loss: 19549.3262 - 7s/epoch - 944ms/step
# Epoch 989/1000
#
# Epoch 989: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 457973.6875 - val_loss: 42392.9531 - 5s/epoch - 660ms/step
# Epoch 990/1000
#
# Epoch 990: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 395182.0625 - val_loss: 55195.3633 - 5s/epoch - 681ms/step
# Epoch 991/1000
#
# Epoch 991: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 405636.4688 - val_loss: 44917.8555 - 7s/epoch - 987ms/step
# Epoch 992/1000
#
# Epoch 992: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 459389.5000 - val_loss: 41484.3867 - 5s/epoch - 717ms/step
# Epoch 993/1000
#
# Epoch 993: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 374881.6875 - val_loss: 41776.7656 - 5s/epoch - 662ms/step
# Epoch 994/1000
#
# Epoch 994: val_loss did not improve from 3182.81494
# 7/7 - 7s - loss: 429544.6250 - val_loss: 60344.5781 - 7s/epoch - 960ms/step
# Epoch 995/1000
#
# Epoch 995: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 408349.8438 - val_loss: 41382.8047 - 5s/epoch - 751ms/step
# Epoch 996/1000
#
# Epoch 996: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 426531.2812 - val_loss: 26819.4941 - 5s/epoch - 657ms/step
# Epoch 997/1000
#
# Epoch 997: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 427104.0625 - val_loss: 50396.1562 - 6s/epoch - 845ms/step
# Epoch 998/1000
#
# Epoch 998: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 432643.6875 - val_loss: 23244.1797 - 6s/epoch - 856ms/step
# Epoch 999/1000
#
# Epoch 999: val_loss did not improve from 3182.81494
# 7/7 - 5s - loss: 439531.9375 - val_loss: 35436.8555 - 5s/epoch - 675ms/step
# Epoch 1000/1000
#
# Epoch 1000: val_loss did not improve from 3182.81494
# 7/7 - 6s - loss: 417129.2500 - val_loss: 57630.6289 - 6s/epoch - 809ms/step
# 16/16 [==============================] - 2s 92ms/step
# 3/3 [==============================] - 0s 108ms/step
# Training MSE: 23580.660304626337
# Testing MSE: 7556.069906735927
# accuracy : 55
